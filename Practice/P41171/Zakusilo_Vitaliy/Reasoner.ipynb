# %% [markdown]
# # Reasoner

# %% [markdown]
# ## install java

# %%
import os
# !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = '/usr/lib/jvm/java-8-openjdk-amd64'
# !java -version
# Out:
# openjdk version "11.0.11" 2021-04-20
# OpenJDK Runtime Environment (build 11.0.11+9-Ubuntu-0ubuntu2.18.04)
# OpenJDK 64-Bit Server VM (build 11.0.11+9-Ubuntu-0ubuntu2.18.04, mixed mode, sharing)

# %% [markdown]
# ## owlready

# %%
# !pip install owlready2

# %%
from owlready2 import *
import owlready2

base_path = '/content/drive/MyDrive/AnimeData/'
onto = get_ontology(f'{base_path}Anime_r.rdf').load()

with onto:
  sync_reasoner()
  onto.save(f'{base_path}Anime_inf.rdf', format='rdfxml')
#inferrences_onto = get_ontology('http://inferrences/')
#inferrences_onto.save(f'{base_path}Anime_rd.rdf', format='rdfxml')
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /usr/local/lib/python3.7/dist-packages/owlready2/hermit:/usr/local/lib/python3.7/dist-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpgd7om_ad
# * Owlready2 * HermiT took 161.68863224983215 seconds
# * Owlready * Reparenting Anime_r.hasSummury: {owl.ObjectProperty, Anime_r.hasContinuation} => {Anime_r.hasContinuation}
# * Owlready * Reparenting Anime_r.hasSpinOff: {owl.ObjectProperty, Anime_r.hasContinuation} => {Anime_r.hasContinuation}
# * Owlready * Reparenting Anime_r.hasPrequel: {owl.ObjectProperty, Anime_r.hasContinuation} => {Anime_r.hasContinuation}
# * Owlready * Reparenting Anime_r.hasSequel: {owl.ObjectProperty, Anime_r.hasContinuation} => {Anime_r.hasContinuation}
# * Owlready * Reparenting Anime_r.hasParentStory: {owl.ObjectProperty, Anime_r.hasContinuation} => {Anime_r.hasContinuation}
# ...

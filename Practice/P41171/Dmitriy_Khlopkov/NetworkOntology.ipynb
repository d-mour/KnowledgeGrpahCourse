# %%
# !pip install rdflib
import types
import typing
import os
import re

import pandas

import rdflib
from rdflib import RDF, OWL, XSD
# Out:
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (5.0.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib) (2.4.7)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rdflib) (1.15.0)

# %% [markdown]
# ## Parsing and printing ontology:

# %%
g = rdflib.Graph()

g.parse("NetworkOntology.owl", format="xml")

print("graph has {} statements.".format(len(g)))
print(g.serialize(format="turtle").decode("utf-8"))
# Out:
# graph has 225 statements.
# @prefix : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology> a owl:Ontology .
#
# <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a/h/j/n/ac/ax_frequencyRange> a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 5.895e+03 ;
#     :frequencyRangeLowerBound 4.91e+03 .
#
# <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ad/ay__frequencyRange> a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 7.02e+04 ;
#     :frequencyRangeLowerBound 5.724e+04 .
#
# :802.11ah_frequencyRange a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 9.28e+02 ;
#     :frequencyRangeLowerBound 7.55e+02 .
#
# :802.11j_frequencyRange a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 5e+03 ;
#     :frequencyRangeLowerBound 4.9e+03 .
#
# :802.11n a owl:NamedIndividual,
#         :802.11 ;
#     :hasFrequencyRange <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11b/g/n/ax__frequencyRange> .
#
# :Bluetooth1.0 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth1.1 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth1.2 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth2.0 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth2.1 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth3.0 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth4.0 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth4.1 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth4.2 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth5.0 a owl:NamedIndividual,
#         :802.15.1 .
#
# :Bluetooth5.1 a owl:NamedIndividual,
#         :802.15.1 .
#
# :BluetoothModule a owl:Class ;
#     rdfs:subClassOf :WirelessPhysicalNetworkDevice .
#
# :InvalidFrequencyRange a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 1e+01 ;
#     :frequencyRangeLowerBound 1.1e+01 .
#
# :WiFiNetworkModule a owl:Class ;
#     rdfs:subClassOf [ a owl:Class ;
#             owl:intersectionOf ( :WirelessPhysicalNetworkDevice [ a owl:Restriction ;
#                         owl:onProperty :deviceForProtocol ;
#                         owl:someValuesFrom :802.11 ] ) ] .
#
# :WiredPhysicalProtocol a owl:Class ;
#     rdfs:subClassOf :PhysicalProtocol .
#
# :application a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber 7 .
#
# :datagram a owl:NamedIndividual,
#         :ProtocolDataType ;
#     :usedInLayer :transport .
#
# :deviceDataRate a owl:DatatypeProperty ;
#     rdfs:domain :PhysicalNetworkDevice ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :deviceHasFrequencyRange a owl:ObjectProperty ;
#     rdfs:domain :WirelessPhysicalNetworkDevice ;
#     rdfs:range :FrequencyRange ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :deviceManufacturer a owl:DatatypeProperty ;
#     rdfs:domain :NetworkDevice ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :deviceMaxTemperature a owl:DatatypeProperty ;
#     rdfs:domain :NetworkDevice ;
#     rdfs:range xsd:double ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :deviceMinTemperature a owl:DatatypeProperty ;
#     rdfs:domain :NetworkDevice ;
#     rdfs:range xsd:double ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :frame a owl:NamedIndividual,
#         :ProtocolDataType ;
#     :usedInLayer :dataLink .
#
# :frequencyRangeHigherBound a owl:DatatypeProperty ;
#     rdfs:domain :FrequencyRange ;
#     rdfs:range xsd:double ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :frequencyRangeLowerBound a owl:DatatypeProperty ;
#     rdfs:domain :FrequencyRange ;
#     rdfs:range xsd:double .
#
# :hasLayerNumber a owl:DatatypeProperty ;
#     rdfs:domain :OSILayer ;
#     rdfs:range xsd:int ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :packet a owl:NamedIndividual,
#         :ProtocolDataType ;
#     :usedInLayer :network .
#
# :presentation a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber 6 .
#
# :segment a owl:NamedIndividual,
#         :ProtocolDataType ;
#     :usedInLayer :transport .
#
# :session a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber 5 .
#
# :usedInLayer a owl:ObjectProperty ;
#     rdfs:domain :ProtocolDataType ;
#     rdfs:range :OSILayer ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11b/g/n/ax__frequencyRange> a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 2.495e+03 ;
#     :frequencyRangeLowerBound 2.401e+03 .
#
# :ISM_FrequencyRange a owl:NamedIndividual,
#         :FrequencyRange ;
#     :frequencyRangeHigherBound 2.48e+03 ;
#     :frequencyRangeLowerBound 2.402e+03 .
#
# :belongsToLayer a owl:ObjectProperty ;
#     rdfs:domain :OSIProtocol ;
#     rdfs:range :OSILayer ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :bit a owl:NamedIndividual,
#         :ProtocolDataType ;
#     :usedInLayer :physical .
#
# :dataLink a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber "2"^^xsd:int .
#
# :deviceForOsiLayer a owl:ObjectProperty ;
#     rdfs:domain :NetworkDevice ;
#     rdfs:range :OSILayer ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :hasFrequencyRange a owl:ObjectProperty ;
#     rdfs:domain :WirelessPhysicalProtocol ;
#     rdfs:range :FrequencyRange ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :hasPDU a owl:ObjectProperty ;
#     rdfs:domain :OSIProtocol ;
#     rdfs:range :ProtocolDataType .
#
# :network a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber "3"^^xsd:int .
#
# :802.11 a owl:Class ;
#     rdfs:subClassOf :WirelessPhysicalProtocol .
#
# :PhysicalNetworkDevice a owl:Class ;
#     rdfs:subClassOf [ a owl:Class ;
#             owl:intersectionOf ( :NetworkDevice [ a owl:Restriction ;
#                         owl:onProperty :deviceForProtocol ;
#                         owl:someValuesFrom :PhysicalProtocol ] [ a owl:Restriction ;
#                         owl:hasValue :physical ;
#                         owl:onProperty :deviceForOsiLayer ] ) ] .
#
# :transport a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber 4 .
#
# :OSIModel a owl:Class .
#
# :PhysicalProtocol a owl:Class ;
#     rdfs:subClassOf [ a owl:Class ;
#             owl:intersectionOf ( :OSIProtocol [ a owl:Restriction ;
#                         owl:hasValue :physical ;
#                         owl:onProperty :belongsToLayer ] [ a owl:Restriction ;
#                         owl:hasValue :bit ;
#                         owl:onProperty :hasPDU ] ) ] .
#
# :WirelessPhysicalNetworkDevice a owl:Class ;
#     rdfs:subClassOf [ a owl:Class ;
#             owl:intersectionOf ( :PhysicalNetworkDevice [ a owl:Restriction ;
#                         owl:onProperty :deviceForProtocol ;
#                         owl:someValuesFrom :WirelessPhysicalProtocol ] ) ] .
#
# :deviceForProtocol a owl:ObjectProperty ;
#     rdfs:domain :NetworkDevice ;
#     rdfs:range :OSIProtocol ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# :physical a owl:NamedIndividual,
#         :OSILayer ;
#     :hasLayerNumber 1 .
#
# :OSIProtocol a owl:Class ;
#     rdfs:subClassOf :OSIModel .
#
# :WirelessPhysicalProtocol a owl:Class ;
#     rdfs:subClassOf :PhysicalProtocol .
#
# :NetworkDevice a owl:Class .
#
# :ProtocolDataType a owl:Class ;
#     rdfs:subClassOf :OSIModel .
#
# :802.15.1 a owl:Class ;
#     rdfs:subClassOf [ a owl:Class ;
#             owl:intersectionOf ( :WirelessPhysicalProtocol [ a owl:Restriction ;
#                         owl:hasValue :ISM_FrequencyRange ;
#                         owl:onProperty :hasFrequencyRange ] ) ] .
#
# :FrequencyRange a owl:Class ;
#     rdfs:subClassOf :WirelessPhysicalProtocol .
#
# :OSILayer a owl:Class ;
#     rdfs:subClassOf :OSIModel .

# %% [markdown]
# ### Print all classes in ontology

# %%
classes = g.triples((None, RDF.type, OWL.Class))
for s,v,o in classes:
  print(s, v, o)
# Out:
# N19c4e62f979144cbac045de461d7e83e http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#NetworkDevice http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#ProtocolDataType http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#FrequencyRange http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# Na2d2743917ab43648ab4942d804ee7cd http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# Na68016c8c09e45e8858de2ffb0597249 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#WirelessPhysicalProtocol http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.15.1 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# N1cf73b0caa754d798fa4af9a509e9ef4 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#WirelessPhysicalNetworkDevice http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#OSIProtocol http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#OSILayer http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#OSIModel http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#WiredPhysicalProtocol http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#PhysicalNetworkDevice http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#PhysicalProtocol http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#WiFiNetworkModule http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#BluetoothModule http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# N3bebef61d56b4be49951b4eeb1da472d http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class

# %% [markdown]
# ### Print Object Properties:

# %%
objectProps = g.triples((None, RDF.type, OWL.ObjectProperty))
for s,v,o in objectProps:
  print(s, v, o)
# Out:
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#hasFrequencyRange http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceHasFrequencyRange http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#hasPDU http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceForProtocol http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceForOsiLayer http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#belongsToLayer http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty
# https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#usedInLayer http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#ObjectProperty

# %% [markdown]
# ## Populate data

# %% [markdown]
# ### Get Classes and required data properties:

# %%
namespace = rdflib.Namespace('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#')

wifiNetworkModuleClass = namespace.WiFiNetworkModule
bluetoothNetworkModuleClass = namespace.BluetoothModule

deviceMinTemperature = namespace.deviceMinTemperature
deviceMaxTemperature = namespace.deviceMaxTemperature
deviceDataRate = namespace.deviceDataRate
deviceManufacturer = namespace.deviceManufacturer
deviceForProtocol = namespace.deviceForProtocol

# %% [markdown]
# ### Defining helpers for filling RDF graph from pandas

# %%
RowToSubject = typing.Callable[[pandas.Series], typing.Tuple[rdflib.URIRef, rdflib.URIRef, rdflib.URIRef]]
ColToPredicate = typing.Callable[[pandas.Series], rdflib.URIRef]
CellToObject = typing.Callable[[str], rdflib.URIRef]

def col_to_predicate_from_dict(col_to_predicate_dict: typing.Dict[str, rdflib.URIRef]) -> ColToPredicate:
  return lambda col: col_to_predicate_dict[col.name] if col.name in col_to_predicate_dict else None

def cell_to_literal(datatype: rdflib.URIRef):
  return lambda v: rdflib.Literal(v, datatype=datatype) if v is not None and len(str(v)) != 0 else None

class RdfGraphFiller:
  def __init__(self, row_to_subject: RowToSubject, col_to_predicate: ColToPredicate, cell_to_object: typing.Dict[str, CellToObject]):
    self.row_to_subject = row_to_subject
    self.col_to_predicate = col_to_predicate
    self.cell_to_object = cell_to_object
  
  def fill_from_dataframe(self, graph: rdflib.Graph, df: pandas.DataFrame):
    for idx, r in df.iterrows():
      subject = self.__get_subject(graph, r)
      for col_name, cell_value in r.items():
        col = df[col_name]
        predicate = self.col_to_predicate(col)
        objects = self.__get_objects(g, col, cell_value)
        if subject is not None and predicate is not None:
          for obj in objects:
            g.add((subject, predicate, obj))
  

  def __get_subject(self, graph: rdflib.Graph, r: pandas.Series):
    subject = self.row_to_subject(r)
    self.__add_to_graph_if_required(graph, subject)
    return subject[0]

  def __get_objects(self, graph: rdflib.Graph, col: pandas.Series, cell_value):
    objs = self.cell_to_object[col.name](cell_value) if col.name in self.cell_to_object else None
    if type(objs) is not list:
      objs = [objs]
    objs_converted = []
    for obj in objs:
      if self.__add_to_graph_if_required(graph, obj):
        objs_converted.append(obj[0])
      elif obj is not None:
        objs_converted.append(obj) 
    return objs_converted

  def __add_to_graph_if_required(self, graph: rdflib.Graph, v):
    if type(v) is tuple and len(v) == 3:
      g.add(v)
      return True
    return False

# %% [markdown]
# ### Add 802.11 protocols

# %%
def char_range(c1, c2):
    """Generates the characters from `c1` to `c2`, inclusive."""
    for c in range(ord(c1), ord(c2)+1):
        yield chr(c)

OSIProtocol802_11 = rdflib.URIRef(namespace + '802.11')
protocols_postfixes = [c for c in char_range('a', 'y')]
protocols_postfixes += ['ac', 'ad', 'ax', 'ay', 'az', 'be']

protocols_802_11 = set([rdflib.URIRef(namespace + '802.11' + postfix) for postfix in protocols_postfixes])
frequency_ranges = list(g.triples((None, RDF.type, namespace.FrequencyRange)))

for protocol in protocols_802_11:
  g.add((protocol, RDF.type, OSIProtocol802_11))
  proto_letter = protocol[protocol.index('802.11') + len('802.11'):]
  freq_range_regex = r'.*802\.1(1' + proto_letter + '(/|_)|1.*/' + proto_letter +'(/|_))'
  matched_freq_ranges = list(filter(lambda r: re.match(freq_range_regex, r[0]) is not None, frequency_ranges))
  for (r, _, _) in matched_freq_ranges:
    g.add((protocol, namespace.hasFrequencyRange, r))

# %% [markdown]
# ### Filling WiFiNetwrokModules properties

# %%
manufacturer_key = 'Mfr.'
max_temp_key = 'Maximum Operating Temperature'
min_temp_key = 'Minimum Operating Temperature'
data_rate_key = 'Data Rate'
wifi_protocol_key = 'Protocol Supported'

non_decimal = re.compile(r'[^\d.-]+')

wifi_row_to_subject: RowToSubject = lambda r: (rdflib.URIRef(namespace + r['Mouser Part Number']), RDF.type, wifiNetworkModuleClass)
wifi_col_to_predicate: ColToPredicate = col_to_predicate_from_dict(
    {
      manufacturer_key: deviceManufacturer,
      max_temp_key: deviceMaxTemperature,
      min_temp_key: deviceMinTemperature,
      data_rate_key: deviceDataRate,
      wifi_protocol_key: deviceForProtocol
    }
)

def str_to_wifi_protocol(protocol):
  protocol = str(protocol).replace(' ', '')
  if not protocol.startswith('802.11'):
    return None
  
  protocol_sections = protocol.split('/')
  protocols = [protocol_sections[0]]
  for protocol_postfix in protocol_sections[1:]:
    protocols.append("802.11" + protocol_postfix)
  
  protocols = [rdflib.URIRef(namespace + protocol_name) for protocol_name in protocols]
  protocols = filter(lambda p: p in protocols_802_11, protocols)
  return [protocol for protocol in protocols]
  


def temperature_str_to_literal(cell_value):
  digits = non_decimal.sub('', str(cell_value))
  if len(digits) == 0:
    return None
  else:
    return rdflib.Literal(digits, datatype=XSD.double)

wifi_col_and_cel_to_object: typing.Dict[str, CellToObject] = {
  manufacturer_key: cell_to_literal(XSD.string),
  max_temp_key: temperature_str_to_literal,
  min_temp_key: temperature_str_to_literal,
  data_rate_key: cell_to_literal(XSD.string),
  wifi_protocol_key: str_to_wifi_protocol
}
wifi_modules = pandas.read_csv("wifi-data.csv").fillna('')

converter = RdfGraphFiller(wifi_row_to_subject, wifi_col_to_predicate, wifi_col_and_cel_to_object)
converter.fill_from_dataframe(g, wifi_modules)

# %% [markdown]
# ### Filling BluetoothNetworkDevice module

# %%
manufacturer_key = 'Mfr.'
max_temp_key = 'Maximum Operating Temperature'
min_temp_key = 'Minimum Operating Temperature'
data_rate_key = 'Data Rate'
bluetooth_protocol_key = 'Protocol'

non_decimal = re.compile(r'[^\d.-]+')

def str_to_bluetooth_protocol(protocol):
  protocol = str(protocol).replace(' ', '')
  if not protocol.startswith('Bluetooth'):
    return None
  
  m = re.search(r'Bluetooth\d\.\d', protocol)
  if m is None:
    return None
  protocol_name = m.group(0)
  return [rdflib.URIRef(namespace + protocol_name)]
  
  #protocols = [rdflib.URIRef(namespace + protocol_name) for protocol_name in protocols]
  #return [protocol for protocol in protocols]
  

bluetooth_row_to_subject: RowToSubject = lambda r: (rdflib.URIRef(namespace + r['Mouser Part Number']), RDF.type, bluetoothNetworkModuleClass)
bluetooth_col_to_predicate: ColToPredicate = col_to_predicate_from_dict(
    {
      manufacturer_key: deviceManufacturer,
      max_temp_key: deviceMaxTemperature,
      min_temp_key: deviceMinTemperature,
      data_rate_key: deviceDataRate,
      bluetooth_protocol_key: deviceForProtocol
    }
)

bluetooth_col_and_cel_to_object: typing.Dict[str, CellToObject] = {
  manufacturer_key: cell_to_literal(XSD.string),
  max_temp_key: temperature_str_to_literal,
  min_temp_key: temperature_str_to_literal,
  data_rate_key: cell_to_literal(XSD.string),
  bluetooth_protocol_key: str_to_bluetooth_protocol,
}
bluetooth_modules = pandas.read_csv("bluetooth-data.csv").fillna('')

converter = RdfGraphFiller(bluetooth_row_to_subject, bluetooth_col_to_predicate, bluetooth_col_and_cel_to_object)
converter.fill_from_dataframe(g, bluetooth_modules)

# %% [markdown]
# ### Saving ontology

# %%
g.serialize("OutputOntology.owl")

# %% [markdown]
# ## Generate Documentation

# %%
# !pip install pylode
# Out:
# Collecting pylode
#   Downloading https://files.pythonhosted.org/packages/4e/df/97be1bb7693bab6505004fe9fde0cabfaf9b38ec89f1eb60187cd34d88ff/pyLODE-2.9.2-py2.py3-none-any.whl (134kB)
#      |████████████████████████████████| 143kB 6.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pylode) (2.23.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from pylode) (3.3.4)
# Requirement already satisfied: rdflib>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pylode) (5.0.0)
# Collecting rdflib-jsonld>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/f5/17/45e137be0d93b70827fe5529c0400731344a978bc792193d7d9152e6dbe4/rdflib-jsonld-0.5.0.tar.gz (55kB)
#      |████████████████████████████████| 61kB 4.1MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pylode) (2.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pylode) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pylode) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pylode) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pylode) (3.0.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown->pylode) (4.0.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=5.0.0->pylode) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rdflib>=5.0.0->pylode) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=5.0.0->pylode) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pylode) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown->pylode) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown->pylode) (3.7.4.3)
# Building wheels for collected packages: rdflib-jsonld
#   Building wheel for rdflib-jsonld (setup.py) ... done
#   Created wheel for rdflib-jsonld: filename=rdflib_jsonld-0.5.0-py2.py3-none-any.whl size=15348 sha256=0305c66e3fcfbecdedaebaf2123c9cfe295364b18003026d21587ededafb31ac
#   Stored in directory: /root/.cache/pip/wheels/8d/e4/7f/9ebcb3e400c694e645c3adba40ef3e9bda78384ac3b9b0d13d
# Successfully built rdflib-jsonld
# Installing collected packages: rdflib-jsonld, pylode
# Successfully installed pylode-2.9.2 rdflib-jsonld-0.5.0

# %%
import pylode

html = pylode.MakeDocco(
    input_data_file="OutputOntology.owl",
    outputformat="html"
).document()

file = open('doc.html', 'w')
file.write(html)
file.close()

# %% [markdown]
# ## Generaiting VoID

# %%
from rdflib.void import generateVoID

void_graph = generateVoID(g)[0]
void_graph.serialize('void.rdf')
print(void_graph.serialize(format="turtle").decode("utf-8"))
# Out:
# @prefix ns1: <http://rdfs.org/ns/void#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/Dataset> a ns1:Dataset ;
#     ns1:classPartition <http://example.org/Dataset_class0>,
#         <http://example.org/Dataset_class1>,
#         <http://example.org/Dataset_class10>,
#         <http://example.org/Dataset_class11>,
#         <http://example.org/Dataset_class12>,
#         <http://example.org/Dataset_class2>,
#         <http://example.org/Dataset_class3>,
#         <http://example.org/Dataset_class4>,
#         <http://example.org/Dataset_class5>,
#         <http://example.org/Dataset_class6>,
#         <http://example.org/Dataset_class7>,
#         <http://example.org/Dataset_class8>,
#         <http://example.org/Dataset_class9> ;
#     ns1:classes 13 ;
#     ns1:distinctObjects 208 ;
#     ns1:distinctSubjects 465 ;
#     ns1:properties 21 ;
#     ns1:propertyPartition <http://example.org/Dataset_property0>,
#         <http://example.org/Dataset_property1>,
#         <http://example.org/Dataset_property10>,
#         <http://example.org/Dataset_property11>,
#         <http://example.org/Dataset_property12>,
#         <http://example.org/Dataset_property13>,
#         <http://example.org/Dataset_property14>,
#         <http://example.org/Dataset_property15>,
#         <http://example.org/Dataset_property16>,
#         <http://example.org/Dataset_property17>,
#         <http://example.org/Dataset_property18>,
#         <http://example.org/Dataset_property19>,
#         <http://example.org/Dataset_property2>,
#         <http://example.org/Dataset_property20>,
#         <http://example.org/Dataset_property3>,
#         <http://example.org/Dataset_property4>,
#         <http://example.org/Dataset_property5>,
#         <http://example.org/Dataset_property6>,
#         <http://example.org/Dataset_property7>,
#         <http://example.org/Dataset_property8>,
#         <http://example.org/Dataset_property9> ;
#     ns1:triples 2216 .
#
# <http://example.org/Dataset_class0> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#WiFiNetworkModule> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 89 ;
#     ns1:distinctSubjects 150 ;
#     ns1:entities 150 ;
#     ns1:properties 6 ;
#     ns1:triples 922 .
#
# <http://example.org/Dataset_class1> a ns1:Dataset ;
#     ns1:class <http://www.w3.org/2002/07/owl#DatatypeProperty> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 8 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 4 ;
#     ns1:triples 25 .
#
# <http://example.org/Dataset_class10> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#OSILayer> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 9 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 2 ;
#     ns1:triples 21 .
#
# <http://example.org/Dataset_class11> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#ProtocolDataType> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 6 ;
#     ns1:distinctSubjects 5 ;
#     ns1:entities 5 ;
#     ns1:properties 2 ;
#     ns1:triples 15 .
#
# <http://example.org/Dataset_class12> a ns1:Dataset ;
#     ns1:class <http://www.w3.org/2002/07/owl#Ontology> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 1 ;
#     ns1:distinctSubjects 1 ;
#     ns1:entities 1 ;
#     ns1:properties 1 ;
#     ns1:triples 1 .
#
# <http://example.org/Dataset_class2> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.15.1> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 2 ;
#     ns1:distinctSubjects 11 ;
#     ns1:entities 11 ;
#     ns1:properties 1 ;
#     ns1:triples 22 .
#
# <http://example.org/Dataset_class3> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#BluetoothModule> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 69 ;
#     ns1:distinctSubjects 200 ;
#     ns1:entities 200 ;
#     ns1:properties 6 ;
#     ns1:triples 1027 .
#
# <http://example.org/Dataset_class4> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 6 ;
#     ns1:distinctSubjects 31 ;
#     ns1:entities 31 ;
#     ns1:properties 2 ;
#     ns1:triples 45 .
#
# <http://example.org/Dataset_class5> a ns1:Dataset ;
#     ns1:class <http://www.w3.org/2002/07/owl#Class> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 15 ;
#     ns1:distinctSubjects 20 ;
#     ns1:entities 20 ;
#     ns1:properties 3 ;
#     ns1:triples 38 .
#
# <http://example.org/Dataset_class6> a ns1:Dataset ;
#     ns1:class <http://www.w3.org/2002/07/owl#NamedIndividual> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 33 ;
#     ns1:distinctSubjects 31 ;
#     ns1:entities 31 ;
#     ns1:properties 6 ;
#     ns1:triples 90 .
#
# <http://example.org/Dataset_class7> a ns1:Dataset ;
#     ns1:class <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#FrequencyRange> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 16 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 3 ;
#     ns1:triples 28 .
#
# <http://example.org/Dataset_class8> a ns1:Dataset ;
#     ns1:class <http://www.w3.org/2002/07/owl#ObjectProperty> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 9 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 4 ;
#     ns1:triples 27 .
#
# <http://example.org/Dataset_class9> a ns1:Dataset ;
#     ns1:class <http://www.w3.org/2002/07/owl#Restriction> ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 12 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 4 ;
#     ns1:triples 21 .
#
# <http://example.org/Dataset_property0> a ns1:Dataset ;
#     ns1:classes 0 ;
#     ns1:distinctObjects 8 ;
#     ns1:distinctSubjects 12 ;
#     ns1:entities 0 ;
#     ns1:properties 1 ;
#     ns1:property rdf:rest ;
#     ns1:triples 12 .
#
# <http://example.org/Dataset_property1> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 15 ;
#     ns1:distinctSubjects 260 ;
#     ns1:entities 260 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceForProtocol> ;
#     ns1:triples 435 .
#
# <http://example.org/Dataset_property10> a ns1:Dataset ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 9 ;
#     ns1:distinctSubjects 13 ;
#     ns1:entities 13 ;
#     ns1:properties 1 ;
#     ns1:property rdfs:subClassOf ;
#     ns1:triples 13 .
#
# <http://example.org/Dataset_property11> a ns1:Dataset ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 5 ;
#     ns1:distinctSubjects 5 ;
#     ns1:entities 5 ;
#     ns1:properties 1 ;
#     ns1:property <http://www.w3.org/2002/07/owl#intersectionOf> ;
#     ns1:triples 5 .
#
# <http://example.org/Dataset_property12> a ns1:Dataset ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 3 ;
#     ns1:distinctSubjects 4 ;
#     ns1:entities 4 ;
#     ns1:properties 1 ;
#     ns1:property <http://www.w3.org/2002/07/owl#hasValue> ;
#     ns1:triples 4 .
#
# <http://example.org/Dataset_property13> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 10 ;
#     ns1:distinctSubjects 285 ;
#     ns1:entities 285 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceMaxTemperature> ;
#     ns1:triples 285 .
#
# <http://example.org/Dataset_property14> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 7 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#frequencyRangeLowerBound> ;
#     ns1:triples 7 .
#
# <http://example.org/Dataset_property15> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 38 ;
#     ns1:distinctSubjects 244 ;
#     ns1:entities 244 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceDataRate> ;
#     ns1:triples 244 .
#
# <http://example.org/Dataset_property16> a ns1:Dataset ;
#     ns1:classes 0 ;
#     ns1:distinctObjects 12 ;
#     ns1:distinctSubjects 12 ;
#     ns1:entities 12 ;
#     ns1:properties 1 ;
#     ns1:property rdf:first ;
#     ns1:triples 12 .
#
# <http://example.org/Dataset_property17> a ns1:Dataset ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 3 ;
#     ns1:distinctSubjects 3 ;
#     ns1:entities 3 ;
#     ns1:properties 1 ;
#     ns1:property <http://www.w3.org/2002/07/owl#someValuesFrom> ;
#     ns1:triples 3 .
#
# <http://example.org/Dataset_property18> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 7 ;
#     ns1:distinctSubjects 285 ;
#     ns1:entities 285 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceMinTemperature> ;
#     ns1:triples 285 .
#
# <http://example.org/Dataset_property19> a ns1:Dataset ;
#     ns1:classes 13 ;
#     ns1:distinctObjects 13 ;
#     ns1:distinctSubjects 453 ;
#     ns1:entities 453 ;
#     ns1:properties 1 ;
#     ns1:property rdf:type ;
#     ns1:triples 484 .
#
# <http://example.org/Dataset_property2> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 7 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#frequencyRangeHigherBound> ;
#     ns1:triples 7 .
#
# <http://example.org/Dataset_property20> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 4 ;
#     ns1:distinctSubjects 5 ;
#     ns1:entities 5 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#usedInLayer> ;
#     ns1:triples 5 .
#
# <http://example.org/Dataset_property3> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 2 ;
#     ns1:distinctSubjects 12 ;
#     ns1:entities 12 ;
#     ns1:properties 1 ;
#     ns1:property rdfs:subPropertyOf ;
#     ns1:triples 12 .
#
# <http://example.org/Dataset_property4> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 6 ;
#     ns1:distinctSubjects 12 ;
#     ns1:entities 12 ;
#     ns1:properties 1 ;
#     ns1:property rdfs:range ;
#     ns1:triples 12 .
#
# <http://example.org/Dataset_property5> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 53 ;
#     ns1:distinctSubjects 350 ;
#     ns1:entities 350 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#deviceManufacturer> ;
#     ns1:triples 350 .
#
# <http://example.org/Dataset_property6> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 4 ;
#     ns1:distinctSubjects 10 ;
#     ns1:entities 10 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#hasFrequencyRange> ;
#     ns1:triples 13 .
#
# <http://example.org/Dataset_property7> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 8 ;
#     ns1:distinctSubjects 14 ;
#     ns1:entities 14 ;
#     ns1:properties 1 ;
#     ns1:property rdfs:domain ;
#     ns1:triples 14 .
#
# <http://example.org/Dataset_property8> a ns1:Dataset ;
#     ns1:classes 1 ;
#     ns1:distinctObjects 5 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 1 ;
#     ns1:property <http://www.w3.org/2002/07/owl#onProperty> ;
#     ns1:triples 7 .
#
# <http://example.org/Dataset_property9> a ns1:Dataset ;
#     ns1:classes 2 ;
#     ns1:distinctObjects 7 ;
#     ns1:distinctSubjects 7 ;
#     ns1:entities 7 ;
#     ns1:properties 1 ;
#     ns1:property <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#hasLayerNumber> ;
#     ns1:triples 7 .

# %% [markdown]
# ## Reasoning

# %%
# !apt-get install -y openjdk8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = 'usr/lib/jvm/java8-openjdk-amd64'
# !java -version
# !pip install owlready2
# Out:
# E: Unable to locate package openjdk8-jdk-headless
# openjdk version "11.0.11" 2021-04-20
# OpenJDK Runtime Environment (build 11.0.11+9-Ubuntu-0ubuntu2.18.04)
# OpenJDK 64-Bit Server VM (build 11.0.11+9-Ubuntu-0ubuntu2.18.04, mixed mode, sharing)
# Collecting owlready2
#   Downloading https://files.pythonhosted.org/packages/a5/be/8202aa87b939a758acb997ab74a37951e5ca23adf44e68faa6386479e002/Owlready2-0.31.tar.gz (23.7MB)
#      |████████████████████████████████| 23.7MB 53.6MB/s
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (setup.py) ... done
#   Created wheel for owlready2: filename=Owlready2-0.31-cp37-cp37m-linux_x86_64.whl size=20409711 sha256=4e74e55da5f8a65ce55fa400aae2b600a626f90a66428484bb331fbd7d653086
#   Stored in directory: /root/.cache/pip/wheels/9d/17/e4/54fb8381c51746a0d686b06ef3e3f607789defd8e1580bcb1b
# Successfully built owlready2
# Installing collected packages: owlready2
# Successfully installed owlready2-0.31

# %%
from owlready2 import *
import owlready2

#ontology = get_ontology('OutputOntology.owl').load()

#with ontology:
#  sync_reasoner()
#  ontology.save('network-ontology-inferred.owl', format="rdfxml")

# %% [markdown]
# #SPARQL queries

# %% [markdown]
# ### Open Inferred OWL

# %%
g = g.parse("network-ontology-inferred.owl")

# %% [markdown]
# ### Which protocols belongs to OSI layer #1?

# %%
qres = g.query("""
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX owl: <http://www.w3.org/2002/07/owl#>
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
  PREFIX : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#>
  PREFIX inferred: <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology-inferred#>

  SELECT ?protocol ?layer ?layerNumber
	  WHERE  { 
		  # ?protocol rdf:type :OSIProtocol.
		  # ?protocol :belongsToLayer ?layer.
		  # ?layer :hasLayerNumber ?layerNumber.
		  FILTER(?layerNumber = 1)
	  }
""")

for row in qres:
  print(row)
# Out:
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11p'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth1.0'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11g'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11w'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#ISM_FrequencyRange'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11y'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11s'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11t'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11f'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11u'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.0'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11e'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11o'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11k'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11j_frequencyRange'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth1.2'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11r'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11be'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11h'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11c'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11b/g/n/ax__frequencyRange'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11b'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ah_frequencyRange'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a/h/j/n/ac/ax_frequencyRange'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11l'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth1.1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth3.0'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11m'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11i'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ad/ay__frequencyRange'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11q'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11j'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11x'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11v'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ay'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11d'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11az'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ad'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#physical'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %% [markdown]
# ### Which devices support 802.11n protocol?

# %%
qres = g.query("""
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX owl: <http://www.w3.org/2002/07/owl#>
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
  PREFIX : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#>
  PREFIX inferred: <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology-inferred#>

  
  SELECT ?device ?protocol
	  WHERE { 
		  # ?protocol rdf:type :OSIProtocol.
		  # ?device :deviceForProtocol ?protocol.
		  FILTER(?protocol = :802.11n)
	  }
""")

for row in qres:
  print(row)
# Out:
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#713-317060362'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF111-E-V1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00323'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM32D8MB'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSAGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF111-E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#755-BP3591'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#426-FIT0628'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF121-A'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF121-A-V2'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#976-AMPAKAP12356WIFI'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-49C01AYKF'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WGM110A1MV1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200US3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32S2WRM3200PH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WVIE23264UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#551-CMP9377-UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#888-XB2B-WFPS-001'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF111-A'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF111-N-V1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF121-E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#651-1043201'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-AMW007-1.2.0R'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#347-ISM43907WBML170'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#986-EMIO-5531'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-WLNN-SE-DP551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ES32WROOM32U16MB'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-2230C'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3R'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNA3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#923-EWMW158F01E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSEGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRM32UE28UH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM-02D'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-2U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200PS3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00315'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#673-TWR0063'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#651-1043193'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00318'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-2'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200SD'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32-PICOV3ZERO'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-3U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#365-L01'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-APMN-Q551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#595-C3235MODASM2MONR'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM-02U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#347-ISM43903R48L54U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32S2WRVI321PH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200D'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM02U(4MB)'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM32U8MB'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#81-CMWC1ZZABR-107'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRVE23264PC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-SIPT'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32S2WRMI320UH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNN3R'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#895-CLEO35-WIFI1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM02D(4MB)'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNN3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32-WROOM-32U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#556-1510MR210UB1140'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-2U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRVIE6464UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#81-LBWA1ZV1CD-716'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#724-DA1620MDAAC4WA32'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#409-UPWIFIKITA107001'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2610011025000'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM-32D'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'))

# %% [markdown]
# ### Which devices can work on temperature +100 C

# %%
qres = g.query("""
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX owl: <http://www.w3.org/2002/07/owl#>
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
  PREFIX : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#>
  PREFIX inferred: <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology-inferred#>

  
  SELECT ?device ?minTemperature ?maxTemperature
	  WHERE { 
		  # ?device rdf:type :NetworkDevice.
		  # ?device :deviceMaxTemperature ?maxTemperature.
		  # ?device :deviceMinTemperature ?minTemperature.
		  FILTER(?maxTemperature >= 100 && ?minTemperature <= 100)
	  }
""")

for row in qres:
  print(row)
# Out:
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BM833E'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM220PC22HNA2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200SD'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-NINA-B400-00B'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM220PC22HNA2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-EYSPBNZUA'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNN3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNA3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00041C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-NINA-B410-00B'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-MGM210PB22JIA2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('125.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00041R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNN3R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00039R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200D'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-224116-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BM833F'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00039C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200PS3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-NINA-B416-00B'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#359-ISP1907-HT-JT'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGX220P22HNA21R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))

# %% [markdown]
# ### Which devices can work with temperature -30 C

# %%
qres = g.query("""
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX owl: <http://www.w3.org/2002/07/owl#>
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
  PREFIX : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#>
  PREFIX inferred: <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology-inferred#>

  
  SELECT ?device ?minTemperature ?maxTemperature
	  WHERE { 
		  # ?device rdf:type :NetworkDevice.
		  # ?device :deviceMaxTemperature ?maxTemperature.
		  # ?device :deviceMinTemperature ?minTemperature.
		  FILTER(?maxTemperature >= -30 && ?minTemperature <= -30)
	  }
""")

for row in qres:
  print(row)
# Out:
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BM833E'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM220PC22HNA2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#364-ACN52832'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WVIE23264UC'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('65.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBT-353027-02'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#125-MTXDOT-EU1-A00-1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW89837AWKF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM32D8MB'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBT-343151-02'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#81-LBWA1ZV1CD-716'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM121A256V2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200SD'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-451-00004'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGX13S22GA-V31R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#888-XB2B-WFPS-001'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-NINA-B400-00B'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-450-0178C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-BT860-SA'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW89823A2KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2608036024011'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00049'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#551-B1010SP0-1-R'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM11S22F256GAV2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00006'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BL652-SC-01-T/R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-214015-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-014008-00'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89829A3KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#595-CC2650MODAMOHR'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BT730-SC'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89823A5KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32-PICOV3ZERO'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-202013-11'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BT900-US'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF121-A'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM-32D'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM220PC22HNA2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#741-450-0144C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BLED112-V1C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#359-ISP1507-AL-ST'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#724-DA14531MODF01002'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-49C01AYKF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#485-4078'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-WFI32E01UE-I'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-222014-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-WLNN-SE-DP551'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-202007-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#817-FWM8BLZ02A109047'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('60.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-ST60-2230C-UU'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BLE112-A-V1C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF121-A-V2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00006C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-BLE112-E'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-212006-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM02U(4MB)'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-EYSPBNZUA'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-MRF24WG0MA-I/RM'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WT11U-E-AI56'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNN3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-451-00002C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#125-MTDOT915X1PSMA1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2611011024000'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#741-450-0106C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-BT830-ST'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BT840'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNA3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#125-MTXDOTNA1A01100'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-71BLE01FC20B02AA'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89846A1KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#595-C3235MODASM2MONR'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM220PC22WGA2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#125-MTDOT868X1PSMA1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSEGVDXG'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00048'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#765-RN-42-SM'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-AMW007-1.2.0R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BTM431'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#755-BP3591'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#765-RN-XV-S'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-2230C'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-2U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRM32UE28UH'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200US3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00041C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BM832A'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM121N256V2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#595-CC2564MODNCMOER'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-212020-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2608011124000'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-3U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#771-QN9080-001-M17AZ'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BT820'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89854A3KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-BMD-360-A-R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM-02D'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRVIE6464UC'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('65.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-70BLE01FC20B03AA'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-NINA-B410-00B'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-451-00002'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-MGM210PB22JIA2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('125.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BL652-SC-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89823A3KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#359-ISP1507-AL-JT'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSACVLAY-XZ'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#741-450-0104'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BC840M'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM121A256V2R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BL620-US'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00041R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#551-CMP9377-UC'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#125-MTXDOT-NA1-A00-1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#556-1510MR210UB1140'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-BMD-380-A-R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#511-SPBTLE-RFTR'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-BT860-ST'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-E01FC2-0B05BA'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BT832A'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNN3R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00039R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-416045-02'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-0BLES1FC2-0B05BA'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#364-ACN52840'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGX13S22GA-V31'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WT12-A-AI'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#765-RN42XVP-I/RM'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200D'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-224116-01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#125-MTDOT915M1UFL1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM32U8MB'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-APMN-Q551'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BRBLU03-010A0'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WT12-A-AI5'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSACVLAY-WX'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF111-A'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BT830-SA-01'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BT832AF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-BM71BLE01FC2-B04'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF121-E'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW89835A1KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-F9203A1EF'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#755-BP35C0'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BT800'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-BLE113-A-M256K'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#741-450-0103C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BM833A'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#359-ISP1907-LL-RS'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-ST60-2230C-PU'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW89837AUKF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-BT850-SA'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM02D(4MB)'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BTM511'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('70.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#365-L01'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89849AZKF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# ...
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#579-BM70BLE01FC2-004'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32-WROOM-32U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-BLE112-A'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89852A1KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRVE23264PC'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('65.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BT840XE'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-013030-00'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89849A1KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGX13S22GA-V21R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW89819AYKF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BM833F'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#365-L04'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM-02U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BC840'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-BLED112'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-3U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2608011124010'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2608011024000'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#308-BT840F'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WT12-A-AI4'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-89853A1KF'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBT-333032-02'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00047C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2608011024010'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-EYSKJNZWB'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#923-EWMW158F01E'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-450-0177R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-BT900-SC'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#81-CMWC1ZZABR-107'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF111-N-V1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSAGVDXG'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2611036024001'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#239-453-00039C'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBT-333047-02'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-EYSKDNZWB'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBT-343026-01'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-SIPT'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#347-ISM43903R48L54U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGM11S12F256GAV2'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF111-E-V1'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200PS3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#377-NINA-B416-00B'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF111-E'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-BT851'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#511-SPBTLE-RF0TR'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#359-ISP1907-HT-JT'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2610011025000'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-2U'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-BGX220P22HNA21R'), rdflib.term.Literal('-40.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('105.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00318'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('70.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#727-CYBLE-013025-00'), rdflib.term.Literal('-30.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('85.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))

# %% [markdown]
# ### Which physical devices can work in frequency 5000MHz

# %%
qres = g.query("""
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX owl: <http://www.w3.org/2002/07/owl#>
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
  PREFIX : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#>
  PREFIX inferred: <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology-inferred#>

  
  SELECT ?device ?protocol ?freqLow ?freqHigh 
	  WHERE { 
		  # ?device rdf:type :NetworkDevice.
		  # ?device :deviceForOsiLayer :physical.
      # ?device :deviceForProtocol ?protocol.
      # ?protocol :hasFrequencyRange ?freqRange.
      # ?freqRange :frequencyRangeLowerBound ?freqLow.
      # ?freqRange :frequencyRangeHigherBound ?freqHigh.
      FILTER (?freqHigh >= 5000 && ?freqLow <= 5000)
	  }
""")

for row in qres:
  print(row)
# Out:
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201.NGWG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201NGWGW'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#742-KIT-WIFI-UDOOX86'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WVIE23264UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM32D8MB'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00323'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00323'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#81-LBWA1ZV1CD-716'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200SD'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#713-317060362'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#888-XB2B-WFPS-001'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32-PICOV3ZERO'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201.D2WG.NV'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF121-A'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#976-AMPAKAP12356WIFI'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#976-AMPAKAP12356WIFI'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#976-AMPAKAP12356WIFI'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM-32D'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#667-ENW-49C01AYKF'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-WLNN-SE-DP551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-WLNN-SE-DP551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF121-A-V2'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201.D2WG.L'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM02U(4MB)'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNN3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201D2WGNVW'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNA3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201D2WGLNVW'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#595-C3235MODASM2MONR'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#595-C3235MODASM2MONR'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSEGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSEGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSEGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#347-ISM43907WBML170'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-AMW007-1.2.0R'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#755-BP3591'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#724-DA1620MDAAC4WA32'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-2230C'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-2230C'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-2230C'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-3168.NGWG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-2U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRM32UE28UH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200US3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-2'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32S2WRMI320UH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-3U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#651-1043193'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#651-1043193'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM-02D'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRVIE6464UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201NGWGNVW'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3R'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32S2WRM3200PH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX200.D2WG.L'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX200.D2WG.LTNV'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#551-CMP9377-UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#551-CMP9377-UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#551-CMP9377-UC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-9560.NGWG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#556-1510MR210UB1140'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32S2WRVI321PH'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200S022XNN3R'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201.D2WG.LNV'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-NM-DB-3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF200D'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201D2WGW'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WROOM32U8MB'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-APMN-Q551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-APMN-Q551'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-9560.NGWG.NV'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF111-A'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#426-FIT0628'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF121-E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#986-EMIO-5531'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#673-TWR0063'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM02D(4MB)'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#365-L01'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201D2WGLW'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#895-CLEO35-WIFI1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WGM110A1MV1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX200D2WGLTNP'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ES32WROOM32U16MB'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00315'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00315'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00315'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32-WROOM-32U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESP32WRVE23264PC'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-8265.NGWMG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#409-UPWIFIKITA107001'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM-02U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#600-ABDN-ER-DP551U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-3U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX200D2WGLNVP'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#651-1043201'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#651-1043201'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#923-EWMW158F01E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#923-EWMW158F01E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#81-CMWC1ZZABR-107'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF111-N-V1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSAGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSAGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#963-WYSAGVDXG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX201.D2WG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-SIPT'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-SIPT'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#814-ST60-SIPT'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#347-ISM43903R48L54U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WF111-E-V1'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#356-ESPWROOM3200PS3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX200D2WGLP'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#603-WF111-E'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#634-WFM200SS22XNA3'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#710-2610011025000'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-2U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-2U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11a'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#332-ACM-DB-2U'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ac'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#924-EAR00318'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11n'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#607-AX200.NGWG'), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#802.11ax'), rdflib.term.Literal('4910.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')), rdflib.term.Literal('5895.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))

# %% [markdown]
# ### Which Manufacturers produce devices for Bluetooth protocols

# %%
qres = g.query("""
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX owl: <http://www.w3.org/2002/07/owl#>
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
  PREFIX : <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#>
  PREFIX inferred: <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology-inferred#>

  
  SELECT ?manufacturer ?protocol
	  WHERE { 
		  # ?device rdf:type :NetworkDevice.
      # ?device :deviceForProtocol ?protocol.
      # ?device :deviceManufacturer ?manufacturer.
      FILTER (regex(str(?protocol), "Bluetooth", "i"))
	  }
""")

for row in qres:
  print(row)
# Out:
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.2'))
# (rdflib.term.Literal('aconno', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Texas Instruments', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.0'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.2'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Insight SiP', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Adafruit', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Taiyo Yuden', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.2'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.2'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('ROBOTIS', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('NXP Semiconductors', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Terasic Technologies', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('u-blox', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('u-blox', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('4D Systems', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Microchip Technology / Atmel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Insight SiP', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('u-blox', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('STMicroelectronics', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Taiyo Yuden', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Taiyo Yuden', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('aconno', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('IoTize', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Olimex Ltd.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Insight SiP', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('IoTize', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Insight SiP', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.2'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('UDOO', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Adafruit', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('Fanstel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Microchip Technology', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth2.1'))
# (rdflib.term.Literal('Panasonic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Wurth Elektronik', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('ROBOTIS', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.0'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Taiyo Yuden', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('SparkFun', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.0'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('u-blox', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('Laird Connectivity', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.2'))
# (rdflib.term.Literal('STMicroelectronics', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Insight SiP', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.1'))
# (rdflib.term.Literal('IoTize', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))
# (rdflib.term.Literal('Silicon Labs', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth5.2'))
# (rdflib.term.Literal('Cypress Semiconductor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#Bluetooth4.1'))

# %% [markdown]
# # SHACL

# %% [markdown]
# ### Install dependencies for SHACL

# %%
# !pip install SPARQLWrapper
# !apt-get install netbase
# !pip install pyshacl
# Out:
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.7/dist-packages (1.8.5)
# Requirement already satisfied: rdflib>=4.0 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper) (5.0.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=4.0->SPARQLWrapper) (2.4.7)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=4.0->SPARQLWrapper) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rdflib>=4.0->SPARQLWrapper) (1.15.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# netbase is already the newest version (5.4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Requirement already satisfied: pyshacl in /usr/local/lib/python3.7/dist-packages (0.14.3)
# Requirement already satisfied: rdflib<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pyshacl) (5.0.0)
# Requirement already satisfied: owlrl<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pyshacl) (5.2.1)
# Requirement already satisfied: rdflib-jsonld<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from pyshacl) (0.5.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib<6.0.0,>=5.0.0->pyshacl) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rdflib<6.0.0,>=5.0.0->pyshacl) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib<6.0.0,>=5.0.0->pyshacl) (2.4.7)

# %%
shapes_file = '''
@prefix rdf:   <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix sh:    <http://www.w3.org/ns/shacl#> .
@prefix xsd:   <http://www.w3.org/2001/XMLSchema#> .
@prefix rdfs:  <http://www.w3.org/2000/01/rdf-schema#> .
@prefix owl:   <http://www.w3.org/2002/07/owl#> .
@prefix :   <https://ifmo.ru/etsilence/ontologies/2021/4/network-ontology#> .


:FrequencyRangeConstraints
    a sh:NodeShape ;
    sh:targetClass :FrequencyRange ; # Applies to all persons
    sh:property [              # _:b0
        sh:path :frequencyRangeLowerBound ;       # constrains the values of ex:ssn
        sh:lessThanOrEquals :frequencyRangeHigherBound ;
        sh:maxCount 1
    ] ;
    sh:property [              # _:b0
        sh:path :frequencyRangeHigherBound ;       # constrains the values of ex:ssn
        sh:maxCount 1
    ] ;
.

:NetworkDeviceConstraints
    a sh:NodeShape ;
    sh:targetClass :NetworkDevice ; # Applies to all persons
    sh:property [              # _:b0
        sh:path :deviceMinTemperature ;       # constrains the values of ex:ssn
        sh:lessThanOrEquals :deviceMaxTemperature ;
        sh:maxCount 1
    ] ;
    sh:property [              # _:b0
        sh:path :deviceMaxTemperature ;       # constrains the values of ex:ssn
        sh:maxCount 1
    ] ;
 .
 ###### add SHACL vocabulary ###### 

'''

shapes_file_format = 'turtle'

# %%
from pyshacl import validate

conforms, v_graph, v_text = validate(g,
                                     shacl_graph=shapes_file,
                                     target_graph_format='rdfxml',
                                     shacl_graph_format=shapes_file_format,
                                     inference='rdfs')
print(conforms)
# Out:
# Constraint Violation in LessThanOrEqualsConstraintComponent (http://www.w3.org/ns/shacl#LessThanOrEqualsConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:lessThanOrEquals :frequencyRangeHigherBound ; sh:maxCount Literal("1", datatype=xsd:integer) ; sh:path :frequencyRangeLowerBound ]
# 	Focus Node: :InvalidFrequencyRange
# 	Value Node: Literal("11.0", datatype=xsd:double)
# 	Result Path: :frequencyRangeLowerBound
# 	Message: Value of :InvalidFrequencyRange->:frequencyRangeHigherBound < Literal("11.0", datatype=xsd:double)
# False

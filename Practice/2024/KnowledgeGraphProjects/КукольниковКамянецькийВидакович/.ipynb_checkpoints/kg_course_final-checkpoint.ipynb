# %% [markdown]
# ---
# # Clustering and Classification using Knowledge Graph Embeddings
# ---
#
# In this tutorial we will explore how to use the knowledge embeddings generated by a graph of international football matches (since the 19th century) in clustering and classification tasks. Knowledge graph embeddings are typically used for missing link prediction and knowledge discovery, but they can also be used for entity clustering, entity disambiguation, and other downstream tasks. The embeddings are a form of representation learning that allow linear algebra and machine learning to be applied to knowledge graphs, which otherwise would be difficult to do.
#
#
# We will cover in this tutorial:
#
# 1. Creating the knowledge graph (i.e. triples) from a tabular dataset of football matches
# 2. Training the ComplEx embedding model on those triples
# 3. Evaluating the quality of the embeddings on a validation set
# 4. Clustering the embeddings, comparing to the natural clusters formed by the geographical continents
# 5. Applying the embeddings as features in classification task, to predict match results
# 6. Evaluating the predictive model on a out-of-time test set, comparing to a simple baseline
#
# We will show that knowledge embedding clusters manage to capture implicit geographical information from the graph and that they can be a useful feature source for a downstream machine learning classification task, significantly increasing accuracy from the baseline.
#
# ---

# %% [markdown]
# ## Requirements
#
# A Python environment with the AmpliGraph library installed. Please follow the [install guide](http://docs.ampligraph.org/en/latest/install.html).
#
# Some sanity check:

# %%
# !pip install tensorflow==2.9.0
# !pip install ampligraph
# Out:
# Collecting tensorflow==2.9.0
#   Downloading tensorflow-2.9.0-cp310-cp310-win_amd64.whl.metadata (3.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.9.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.9.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers<2,>=1.12 (from tensorflow==2.9.0)
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl.metadata (872 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.9.0)
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.9.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow==2.9.0)
#   Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.9.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.9.0)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.20 in c:\tools\python\lib\site-packages (from tensorflow==2.9.0) (2.1.2)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.9.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\tools\python\lib\site-packages (from tensorflow==2.9.0) (24.1)
# Collecting protobuf>=3.9.2 (from tensorflow==2.9.0)
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in c:\tools\python\lib\site-packages (from tensorflow==2.9.0) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\tools\python\lib\site-packages (from tensorflow==2.9.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.9.0)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\tools\python\lib\site-packages (from tensorflow==2.9.0) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow==2.9.0)
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.9.0)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.9.0)
#   Downloading grpcio-1.70.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.10,>=2.9 (from tensorflow==2.9.0)
#   Downloading tensorboard-2.9.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0 (from tensorflow==2.9.0)
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.10.0,>=2.9.0rc0 (from tensorflow==2.9.0)
#   Downloading keras-2.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.9.0)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.9.0)
#   Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl.metadata (806 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\tools\python\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.0) (2.32.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\tools\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\tools\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\tools\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\tools\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\tools\python\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.0) (3.0.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.0)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.9.0-cp310-cp310-win_amd64.whl (444.1 MB)
#    ---------------------------------------- 0.0/444.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/444.1 MB ? eta -:--:--
#    ---------------------------------------- 0.8/444.1 MB 3.0 MB/s eta 0:02:26
#    ---------------------------------------- 0.8/444.1 MB 3.0 MB/s eta 0:02:26
#    ---------------------------------------- 0.8/444.1 MB 3.0 MB/s eta 0:02:26
#    ---------------------------------------- 0.8/444.1 MB 3.0 MB/s eta 0:02:26
#    ---------------------------------------- 0.8/444.1 MB 3.0 MB/s eta 0:02:26
#    ---------------------------------------- 2.6/444.1 MB 1.9 MB/s eta 0:03:52
#    ---------------------------------------- 4.7/444.1 MB 3.1 MB/s eta 0:02:21
0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.70.0 h5py-3.12.1 keras-2.9.0 keras-preprocessing-1.1.2 libclang-18.1.1 markdown-3.7 oauthlib-3.2.2 opt-einsum-3.4.0 protobuf-3.19.6 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-oauthlib-2.0.0 rsa-4.9 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.0 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.5.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2
# Collecting ampligraph
#   Downloading ampligraph-2.1.0-py3-none-any.whl.metadata (932 bytes)
# Requirement already satisfied: numpy>=1.14.3 in c:\tools\python\lib\site-packages (from ampligraph) (2.1.2)
# Collecting pytest>=3.5.1 (from ampligraph)
#   Downloading pytest-8.3.4-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\tools\python\lib\site-packages (from ampligraph) (1.5.2)
# Collecting tqdm>=4.23.4 (from ampligraph)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: pandas>=0.23.1 in c:\tools\python\lib\site-packages (from ampligraph) (2.2.3)
# Collecting sphinx==5.0.2 (from ampligraph)
#   Downloading Sphinx-5.0.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting myst-parser==0.18.0 (from ampligraph)
#   Downloading myst_parser-0.18.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting docutils<0.18 (from ampligraph)
#   Downloading docutils-0.17.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting sphinx-rtd-theme==1.0.0 (from ampligraph)
#   Downloading sphinx_rtd_theme-1.0.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting sphinxcontrib-bibtex==2.4.2 (from ampligraph)
#   Downloading sphinxcontrib_bibtex-2.4.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting beautifultable>=0.7.0 (from ampligraph)
#   Downloading beautifultable-1.1.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml>=3.13 in c:\tools\python\lib\site-packages (from ampligraph) (6.0.2)
# Collecting rdflib>=4.2.2 (from ampligraph)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting scipy==1.10.0 (from ampligraph)
#   Downloading scipy-1.10.0-cp310-cp310-win_amd64.whl.metadata (58 kB)
# Collecting networkx>=2.3 (from ampligraph)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting flake8>=3.7.7 (from ampligraph)
#   Downloading flake8-7.1.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: setuptools>=36 in c:\tools\python\lib\site-packages (from ampligraph) (63.2.0)
# Requirement already satisfied: matplotlib>=3.7 in c:\tools\python\lib\site-packages (from ampligraph) (3.9.2)
# Collecting docopt==0.6.2 (from ampligraph)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting schema==0.7.5 (from ampligraph)
#   Downloading schema-0.7.5-py2.py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: jinja2 in c:\tools\python\lib\site-packages (from myst-parser==0.18.0->ampligraph) (3.1.4)
# Collecting markdown-it-py<3.0.0,>=1.0.0 (from myst-parser==0.18.0->ampligraph)
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting mdit-py-plugins~=0.3.0 (from myst-parser==0.18.0->ampligraph)
#   Downloading mdit_py_plugins-0.3.5-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in c:\tools\python\lib\site-packages (from myst-parser==0.18.0->ampligraph) (4.12.2)
# Collecting contextlib2>=0.5.5 (from schema==0.7.5->ampligraph)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting numpy>=1.14.3 (from ampligraph)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting sphinxcontrib-applehelp (from sphinx==5.0.2->ampligraph)
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx==5.0.2->ampligraph)
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx==5.0.2->ampligraph)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx==5.0.2->ampligraph)
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.5 (from sphinx==5.0.2->ampligraph)
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx==5.0.2->ampligraph)
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: Pygments>=2.0 in c:\tools\python\lib\site-packages (from sphinx==5.0.2->ampligraph) (2.18.0)
# Collecting snowballstemmer>=1.1 (from sphinx==5.0.2->ampligraph)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: babel>=1.3 in c:\tools\python\lib\site-packages (from sphinx==5.0.2->ampligraph) (2.16.0)
# Collecting alabaster<0.8,>=0.7 (from sphinx==5.0.2->ampligraph)
#   Downloading alabaster-0.7.16-py3-none-any.whl.metadata (2.9 kB)
# Collecting imagesize (from sphinx==5.0.2->ampligraph)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests>=2.5.0 in c:\tools\python\lib\site-packages (from sphinx==5.0.2->ampligraph) (2.32.3)
# Requirement already satisfied: packaging in c:\tools\python\lib\site-packages (from sphinx==5.0.2->ampligraph) (24.1)
# Requirement already satisfied: colorama>=0.3.5 in c:\tools\python\lib\site-packages (from sphinx==5.0.2->ampligraph) (0.4.6)
# Collecting pybtex>=0.24 (from sphinxcontrib-bibtex==2.4.2->ampligraph)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting pybtex-docutils>=1.0.0 (from sphinxcontrib-bibtex==2.4.2->ampligraph)
#   Downloading pybtex_docutils-1.0.3-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: wcwidth in c:\tools\python\lib\site-packages (from beautifultable>=0.7.0->ampligraph) (0.2.13)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8>=3.7.7->ampligraph)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.13.0,>=2.12.0 (from flake8>=3.7.7->ampligraph)
#   Downloading pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.3.0,>=3.2.0 (from flake8>=3.7.7->ampligraph)
#   Downloading pyflakes-3.2.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\tools\python\lib\site-packages (from matplotlib>=3.7->ampligraph) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\tools\python\lib\site-packages (from pandas>=0.23.1->ampligraph) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\tools\python\lib\site-packages (from pandas>=0.23.1->ampligraph) (2024.2)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\tools\python\lib\site-packages (from pytest>=3.5.1->ampligraph) (1.2.2)
# Collecting iniconfig (from pytest>=3.5.1->ampligraph)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2,>=1.5 (from pytest>=3.5.1->ampligraph)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: tomli>=1 in c:\tools\python\lib\site-packages (from pytest>=3.5.1->ampligraph) (2.0.2)
# Collecting isodate<1.0.0,>=0.7.2 (from rdflib>=4.2.2->ampligraph)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\tools\python\lib\site-packages (from scikit-learn>=0.19.1->ampligraph) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\tools\python\lib\site-packages (from scikit-learn>=0.19.1->ampligraph) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\tools\python\lib\site-packages (from jinja2->myst-parser==0.18.0->ampligraph) (3.0.2)
# Collecting mdurl~=0.1 (from markdown-it-py<3.0.0,>=1.0.0->myst-parser==0.18.0->ampligraph)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting latexcodec>=1.0.4 (from pybtex>=0.24->sphinxcontrib-bibtex==2.4.2->ampligraph)
#   Downloading latexcodec-3.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six in c:\tools\python\lib\site-packages (from pybtex>=0.24->sphinxcontrib-bibtex==2.4.2->ampligraph) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\tools\python\lib\site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\tools\python\lib\site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\tools\python\lib\site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\tools\python\lib\site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (2024.8.30)
# Downloading ampligraph-2.1.0-py3-none-any.whl (210 kB)
# Downloading myst_parser-0.18.0-py3-none-any.whl (57 kB)
# Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Downloading scipy-1.10.0-cp310-cp310-win_amd64.whl (42.5 MB)
#    ---------------------------------------- 0.0/42.5 MB ? eta -:--:--
#     --------------------------------------- 1.0/42.5 MB 7.2 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/42.5 MB 7.2 MB/s eta 0:00:06
#    --- ------------------------------------ 3.9/42.5 MB 7.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.8/42.5 MB 7.5 MB/s eta 0:00:05
#    ------- -------------------------------- 7.6/42.5 MB 7.7 MB/s eta 0:00:05
#    --------- ------------------------------ 9.7/42.5 MB 8.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.8/42.5 MB 8.6 MB/s eta 0:00:04
#    ------------- -------------------------- 14.2/42.5 MB 9.0 MB/s eta 0:00:04
#    --------------- ------------------------ 16.5/42.5 MB 9.2 MB/s eta 0:00:03
#    --------------- ------------------------ 16.8/42.5 MB 9.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 17.8/42.5 MB 8.1 MB/s eta 0:00:04
#    ------------------- -------------------- 20.2/42.5 MB 8.1 MB/s eta 0:00:03
#    --------------------- ------------------ 23.1/42.5 MB 8.6 MB/s eta 0:00:03
#    ------------------------ --------------- 26.5/42.5 MB 9.2 MB/s eta 0:00:02
#    --------------------------- ------------ 29.1/42.5 MB 9.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 31.2/42.5 MB 9.4 MB/s eta 0:00:02
#    ------------------------------- -------- 33.6/42.5 MB 9.6 MB/s eta 0:00:01
#    --------------------------------- ------ 35.7/42.5 MB 9.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 38.0/42.5 MB 9.7 MB/s eta 0:00:01
#    -------------------------------------- - 40.4/42.5 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  42.5/42.5 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  42.5/42.5 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 42.5/42.5 MB 9.3 MB/s eta 0:00:00
# Downloading Sphinx-5.0.2-py3-none-any.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------------------------------ --- 2.9/3.1 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 12.2 MB/s eta 0:00:00
# Downloading sphinx_rtd_theme-1.0.0-py2.py3-none-any.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --------------------------------- ------ 2.4/2.8 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 7.8 MB/s eta 0:00:00
# Downloading sphinxcontrib_bibtex-2.4.2-py3-none-any.whl (39 kB)
# Downloading beautifultable-1.1.0-py2.py3-none-any.whl (28 kB)
# Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#    ---------------------------------------- 0.0/575.5 kB ? eta -:--:--
#    ---------------------------------------- 575.5/575.5 kB 4.0 MB/s eta 0:00:00
# Downloading flake8-7.1.1-py2.py3-none-any.whl (57 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/15.8 MB 15.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.6/15.8 MB 15.5 MB/s eta 0:00:01
#    ------------------------ --------------- 9.7/15.8 MB 15.5 MB/s eta 0:00:01
#    -------------------------------- ------- 12.8/15.8 MB 15.8 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 8.7 MB/s eta 0:00:00
# Downloading pytest-8.3.4-py3-none-any.whl (343 kB)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ---------------------------------------- 0.0/564.9 kB ? eta -:--:--
#    ---------------------------------------- 564.9/564.9 kB 6.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading mdit_py_plugins-0.3.5-py3-none-any.whl (52 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#    ---------------------------------------- 0.0/561.4 kB ? eta -:--:--
#    ---------------------------------------- 561.4/561.4 kB 3.2 MB/s eta 0:00:00
# Downloading pybtex_docutils-1.0.3-py3-none-any.whl (6.4 kB)
# Downloading pycodestyle-2.12.1-py2.py3-none-any.whl (31 kB)
# Downloading pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
# Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13773 sha256=6ca06277a8c15bc62cfab920b8d4e681f4d5a5c82997de2d500c6efa5a68c147
#   Stored in directory: c:\users\kukol\appdata\local\pip\cache\wheels\fc\ab\d4\5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: snowballstemmer, docopt, tqdm, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, pyflakes, pycodestyle, pluggy, numpy, networkx, mdurl, mccabe, latexcodec, isodate, iniconfig, imagesize, docutils, contextlib2, beautifultable, alabaster, sphinx, scipy, schema, rdflib, pytest, pybtex, markdown-it-py, flake8, sphinx-rtd-theme, pybtex-docutils, mdit-py-plugins, sphinxcontrib-bibtex, myst-parser, ampligraph
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# Successfully installed alabaster-0.7.16 ampligraph-2.1.0 beautifultable-1.1.0 contextlib2-21.6.0 docopt-0.6.2 docutils-0.17.1 flake8-7.1.1 imagesize-1.4.1 iniconfig-2.0.0 isodate-0.7.2 latexcodec-3.0.0 markdown-it-py-2.2.0 mccabe-0.7.0 mdit-py-plugins-0.3.5 mdurl-0.1.2 myst-parser-0.18.0 networkx-3.4.2 numpy-1.26.4 pluggy-1.5.0 pybtex-0.24.0 pybtex-docutils-1.0.3 pycodestyle-2.12.1 pyflakes-3.2.0 pytest-8.3.4 rdflib-7.1.3 schema-0.7.5 scipy-1.10.0 snowballstemmer-2.2.0 sphinx-5.0.2 sphinx-rtd-theme-1.0.0 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-bibtex-2.4.2 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 tqdm-4.67.1

# %%
import numpy as np
import pandas as pd
import ampligraph
import tensorflow as tf

# %% [markdown]
# ## Dataset
#
# We will use the [International football results from 1872 to 2019](https://www.kaggle.com/martj42/international-football-results-from-1872-to-2017) available on Kaggle (public domain). It contains over 40 thousand international football matches. Each row contains the following information:
# 1. Match date
# 2. Home team name
# 3. Away team name
# 4. Home score (goals including extra time)
# 5. Away score (goals including extra time)
# 6. Tournament (whether it was a friendly match or part of a tournament)
# 7. City where match took place
# 8. Country where match took place
# 9. Whether match was on neutral grounds
#
# This dataset comes in a tabular format, therefore we will need to construct the knowledge graph ourselves.

# %%
excel_file = "final.xlsx"
df = pd.read_excel(excel_file).sort_values("Название").reset_index(drop=True)
df
# Out:
#                                                Название  \
# 0     Anti-Age Коллаген морской Эвалар 6000 мг пакет...
# 1     Herb apteka Спокойный малыш сироп детский успо...
# 2      L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт
# 3          Авелокс таблетки покрыт.плен.об. 400 мг 5 шт
# 4                          Аводарт капсулы 0,5 мг 90 шт
# ...                                                 ...
# 1457  Эффекс Силденафил таблетки покрыт.плен.об. 100...
# 1458  Эффекс Силденафил таблетки покрыт.плен.об. 50 ...
# 1459  Юнидокс Солютаб таблетки диспергируемые 100 мг...
# 1460  Юнидокс Солютаб таблетки диспергируемые 100 мг...
# 1461        Юперио таблетки покрыт.плен.об. 50 мг 28 шт
#
#        Действующее вещество  \
# 0                       NaN
# 1                       NaN
# 2       Левотироксин натрия
# 3            Моксифлоксацин
# 4                Дутастерид
# ...                     ...
# 1457             Силденафил
# 1458             Силденафил
# 1459            Доксициклин
# 1460            Доксициклин
# 1461  Валсартан, Сакубитрил
#
#                                Вспомогательные вещества  \
# 0                                                   NaN
# 1                                                   NaN
# 2     кальция гидрофосфата дигидрат, целлюлоза микро...
# 3     целлюлоза микрокристаллическая (Авицел)- 136,0...
# 4     Моно- и диглицериды каприловой/каприновой кисл...
# ...                                                 ...
# 1457  Целлюлоза микрокристаллическая, Кальция гидроф...
# 1458                                                NaN
# 1459  целлюлоза микрокристаллическая - 45 мг, сахари...
# 1460                                                NaN
# 1461  целлюлоза микрокристаллическая - 91,449 мг, ги...
#
#                                               Показания  \
# 0                                                   NaN
# 1         х лет - дополнительного источника витаминов с
# 2          гипотиреоидные состояния различной этиологии
# 3                                      по данным rxlist
# 4     лечение и профилактика прогрессирования доброк...
# ...                                                 ...
# 1457                                                NaN
# 1458                     лечение эректильной дисфункции
# 1459                                        остеомиелит
# 1460                         воспалительные заболевания
# 1461  сосудистой смертности и госпитализации по пово...
#
#                                        противопоказания  \
# 0            индивидуальная непереносимость компонентов
# 1            индивидуальная непереносимость компонентов
# 2                                 гиперчувствительность
# 3                               гиперчувствительность
# 4     гиперчувствительность к дутастериду или любому...
# ...                                                 ...
# 1457  повышенная чувствительность к силденафилу или ...
# 1458  повышенная чувствительность к силденафилу или ...
# 1459   гиперчувствительность к антибиотикам группы т...
# 1460              гиперчувствительность к тетрациклинам
# 1461  повышенная чувствительность к сакубитрилу или ...
#
#                                       побочные действия  \
# 0                                                   NaN
# 1                                                   NaN
# 2     тахикардия; нарушение сердечного ритма; боль з...
# 3                           тендинит и разрыв сухожилия
# 4                                                   NaN
# ...                                                 ...
# 1457  наиболее частыми побочными эффектами были голо...
# 1458  наиболее частыми побочными эффектами были голо...
# 1459  анорексия, тошнота, рвота, дисфагия, диарея, э...
# 1460  анорексия, тошнота, рвота, дисфагия, диарея; э...
# 1461  выявленные нежелательные явления   соответство...
#
#                                           форма выпуска  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                              таблетки
# 3                                              таблетки
# 4                                                   NaN
# ...                                                 ...
# 1457                                           таблетки
# 1458                                                NaN
# 1459                                                NaN
# 1460                                                NaN
# 1461  таблетки 50 мг   овальные двояковыпуклые таблетки
#
#                                        условия хранения Срок годности
# 0                                                   NaN           NaN
# 1     хранить при температуре от 0° до +25 и относит...    18 месяцев
# 2     хранить при температуре не выше 25. хранить в ...        2 года
# 3     при температуре не выше 25 . хранить в недосту...         5 лет
# 4     хранить в недоступном для детей месте при темп...        4 года
# ...                                                 ...           ...
# 1457  хранить при температуре не выше 25 . хранить в...        3 года
# 1458  хранить при температуре не выше 25 . хранить в...        3 года
# 1459                             при температуре 15–25          5 лет
# 1460  при температуре 15–25 . хранить в недоступном ...         5 лет
# 1461  при температуре не выше 25° с. хранить в недос...    30 месяцев
#
# [1462 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# Название                      0
# Действующее вещество          7
# Вспомогательные вещества    476
# Показания                    26
# противопоказания             17
# побочные действия           485
# форма выпуска               535
# условия хранения            141
# Срок годности               194
# dtype: int64

# %% [markdown]
# Dropping matches with unknown score:

# %%
df = df.dropna()
df
# Out:
#                                                Название  \
# 2      L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт
# 3          Авелокс таблетки покрыт.плен.об. 400 мг 5 шт
# 7                           Азафен таблетки 25 мг 50 шт
# 8     Азитромицин Форте-Алиум таблетки покрыт.плен.о...
# 17    Аквадетрим капли для приема внутрь 15000 ме/мл...
# ...                                                 ...
# 1447  Эторикоксиб-Тева таблетки покрыт.плен.об. 90 м...
# 1448  Эторикоксиб-Тева таблетки покрыт.плен.об. 90 м...
# 1451                   Эутирокс таблетки 125 мкг 100 шт
# 1453                    Эутирокс таблетки 50 мкг 100 шт
# 1461        Юперио таблетки покрыт.плен.об. 50 мг 28 шт
#
#        Действующее вещество  \
# 2       Левотироксин натрия
# 3            Моксифлоксацин
# 7                 Пипофезин
# 8               Азитромицин
# 17          Колекальциферол
# ...                     ...
# 1447            Эторикоксиб
# 1448            Эторикоксиб
# 1451    Левотироксин натрия
# 1453    Левотироксин натрия
# 1461  Валсартан, Сакубитрил
#
#                                Вспомогательные вещества  \
# 2     кальция гидрофосфата дигидрат, целлюлоза микро...
# 3     целлюлоза микрокристаллическая (Авицел)- 136,0...
# 7                           крахмал картофельный — 4 мг
# 8     [целлюлоза микрокристаллическая, натрия лаурил...
# 17    макрогола глицерилрицинолеат, сахaроза, натрия...
# ...                                                 ...
# 1447  кальция гидрофосфат (безводный) 38,20 мг/76,40...
# 1448                кальция гидрофосфат безводный - 114
# 1451  крахмал кукурузный - 25,00 мг, желатин - 5,00 ...
# 1453  крахмал кукурузный - 20,0 мг, желатин - 5,0 мг...
# 1461  целлюлоза микрокристаллическая - 91,449 мг, ги...
#
#                                               Показания  \
# 2          гипотиреоидные состояния различной этиологии
# 3                                      по данным rxlist
# 7     депрессивные эпизоды легкой и средней степени ...
# 8                                         по данным fda
# 17           профилактика и лечение дефицита витамина d
# ...                                                 ...
# 1447              симптоматическая терапия остеоартроза
# 1448              симптоматическая терапия остеоартроза
# 1451                                         гипотиреоз
# 1453                                         гипотиреоз
# 1461  сосудистой смертности и госпитализации по пово...
#
#                                        противопоказания  \
# 2                                 гиперчувствительность
# 3                               гиперчувствительность
# 7     гиперчувствительность к основному и/или вспомо...
# 8                  гиперчувствительность к азитромицину
# 17    повышенная чувствительность к компонентам преп...
# ...                                                 ...
# 1447  повышенная чувствительность к какому-либо комп...
# 1448  повышенная чувствительность к какому-либо комп...
# 1451  гиперчувствительность к левотироксину натрия и...
# 1453  гиперчувствительность к левотироксину натрия и...
# 1461  повышенная чувствительность к сакубитрилу или ...
#
#                                       побочные действия  \
# 2     тахикардия; нарушение сердечного ритма; боль з...
# 3                           тендинит и разрыв сухожилия
# 7     головная боль, головокружение, тошнота, рвота,...
# 8     в клинических испытаниях большинство побочных ...
# 17    повышенная чувствительность к компонентам преп...
# ...                                                 ...
# 1447  безопасность применения эторикоксиба оценивала...
# 1448  безопасность применения эторикоксиба оценивала...
# 1451  при правильном применении препарата эутирокс® ...
# 1453  при правильном применении препарата эутирокс® ...
# 1461  выявленные нежелательные явления   соответство...
#
#                                           форма выпуска  \
# 2                                              таблетки
# 3                                              таблетки
# 7                                     таблетки по 25 мг
# 8                                              таблетки
# 17                 капли для приема внутрь 15 000 ме/мл
# ...                                                 ...
# 1447                                           таблетки
# 1448                                           таблетки
# 1451                                        таблетки 25
# 1453                                           таблетки
# 1461  таблетки 50 мг   овальные двояковыпуклые таблетки
#
#                                        условия хранения Срок годности
# 2     хранить при температуре не выше 25. хранить в ...        2 года
# 3     при температуре не выше 25 . хранить в недосту...         5 лет
# 7     список б. хранить в сухом, защищенном от света...         5 лет
# 8     в сухом защищенном от света месте при температ...        3 года
# 17    хранить при температуре не выше 25 , в оригина...        3 года
# ...                                                 ...           ...
# 1447  хранить при температуре не выше 25. хранить в ...        3 года
# 1448  хранить при температуре не выше 25. хранить в ...        3 года
# 1451  в защищенном от света месте при температуре не...        3 года
# 1453  в защищенном от света месте, при температуре н...        3 года
# 1461  при температуре не выше 25° с. хранить в недос...    30 месяцев
#
# [363 rows x 9 columns]

# %% [markdown]
# The training set will be from 1872 to 2014, while the test set will be from 2014 to present date. Note that a temporal test set makes any machine learning task harder compared to a random shuffle.

# %%
df = df.assign(
    **{'Действующее вещество': df['Действующее вещество'].str.split(', ')}
).explode('Действующее вещество').reset_index(drop=True)

df = df.assign(
    **{'Вспомогательные вещества': df['Вспомогательные вещества'].str.split(', ')}
).explode('Вспомогательные вещества').reset_index(drop=True)

df = df.assign(
    **{'Показания': df['Показания'].str.split(', ')}
).explode('Показания').reset_index(drop=True)

df = df.assign(
    **{'противопоказания': df['противопоказания'].str.split(', ')}
).explode('противопоказания').reset_index(drop=True)

df = df.assign(
    **{'побочные действия': df['побочные действия'].str.split(', ')}
).explode('побочные действия').reset_index(drop=True)

df = df.assign(
    **{'побочные действия': df['побочные действия'].str.split('; ')}
).explode('побочные действия').reset_index(drop=True)

df
# Out:
#                                               Название Действующее вещество  \
# 0     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 1     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 2     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 3     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 4     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# ...                                                ...                  ...
# 8124       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8125       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8126       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8127       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8128       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
#
#                    Вспомогательные вещества  \
# 0             кальция гидрофосфата дигидрат
# 1             кальция гидрофосфата дигидрат
# 2             кальция гидрофосфата дигидрат
# 3             кальция гидрофосфата дигидрат
# 4             кальция гидрофосфата дигидрат
# ...                                     ...
# 8124              магния стеарат - 6,000 мг
# 8125                       тальк - 2,000 мг
# 8126                       тальк - 2,000 мг
# 8127  кремния диоксид коллоидный - 1,000 мг
# 8128  кремния диоксид коллоидный - 1,000 мг
#
#                                               Показания  \
# 0          гипотиреоидные состояния различной этиологии
# 1          гипотиреоидные состояния различной этиологии
# 2          гипотиреоидные состояния различной этиологии
# 3          гипотиреоидные состояния различной этиологии
# 4          гипотиреоидные состояния различной этиологии
# ...                                                 ...
# 8124  сосудистой смертности и госпитализации по пово...
# 8125  сосудистой смертности и госпитализации по пово...
# 8126  сосудистой смертности и госпитализации по пово...
# 8127  сосудистой смертности и госпитализации по пово...
# 8128  сосудистой смертности и госпитализации по пово...
#
#                                        противопоказания  \
# 0                                 гиперчувствительность
# 1                                 гиперчувствительность
# 2                                 гиперчувствительность
# 3                                 гиперчувствительность
# 4                                 гиперчувствительность
# ...                                                 ...
# 8124  повышенная чувствительность к сакубитрилу или ...
# 8125  повышенная чувствительность к сакубитрилу или ...
# 8126  повышенная чувствительность к сакубитрилу или ...
# 8127  повышенная чувствительность к сакубитрилу или ...
# 8128  повышенная чувствительность к сакубитрилу или ...
#
#                                       побочные действия  \
# 0                                            тахикардия
# 1                            нарушение сердечного ритма
# 2                                      боль за грудиной
# 3                                                тремор
# 4                                          беспокойство
# ...                                                 ...
# 8124                              имеющимся у пациентов
# 8125  выявленные нежелательные явления   соответство...
# 8126                              имеющимся у пациентов
# 8127  выявленные нежелательные явления   соответство...
# 8128                              имеющимся у пациентов
#
#                                           форма выпуска  \
# 0                                              таблетки
# 1                                              таблетки
# 2                                              таблетки
# 3                                              таблетки
# 4                                              таблетки
# ...                                                 ...
# 8124  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8125  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8126  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8127  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8128  таблетки 50 мг   овальные двояковыпуклые таблетки
#
#                                        условия хранения Срок годности
# 0     хранить при температуре не выше 25. хранить в ...        2 года
# 1     хранить при температуре не выше 25. хранить в ...        2 года
# 2     хранить при температуре не выше 25. хранить в ...        2 года
# 3     хранить при температуре не выше 25. хранить в ...        2 года
# 4     хранить при температуре не выше 25. хранить в ...        2 года
# ...                                                 ...           ...
# 8124  при температуре не выше 25° с. хранить в недос...    30 месяцев
# 8125  при температуре не выше 25° с. хранить в недос...    30 месяцев
# 8126  при температуре не выше 25° с. хранить в недос...    30 месяцев
# 8127  при температуре не выше 25° с. хранить в недос...    30 месяцев
# 8128  при температуре не выше 25° с. хранить в недос...    30 месяцев
#
# [8129 rows x 9 columns]

# %%
df["train"] = df.Название < "У"

df.train.value_counts()
# Out:
# train
# True     6168
# False    1961
# Name: count, dtype: int64

# %%
df
# Out:
#                                               Название Действующее вещество  \
# 0     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 1     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 2     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 3     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 4     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# ...                                                ...                  ...
# 8124       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8125       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8126       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8127       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8128       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
#
#                    Вспомогательные вещества  \
# 0             кальция гидрофосфата дигидрат
# 1             кальция гидрофосфата дигидрат
# 2             кальция гидрофосфата дигидрат
# 3             кальция гидрофосфата дигидрат
# 4             кальция гидрофосфата дигидрат
# ...                                     ...
# 8124              магния стеарат - 6,000 мг
# 8125                       тальк - 2,000 мг
# 8126                       тальк - 2,000 мг
# 8127  кремния диоксид коллоидный - 1,000 мг
# 8128  кремния диоксид коллоидный - 1,000 мг
#
#                                               Показания  \
# 0          гипотиреоидные состояния различной этиологии
# 1          гипотиреоидные состояния различной этиологии
# 2          гипотиреоидные состояния различной этиологии
# 3          гипотиреоидные состояния различной этиологии
# 4          гипотиреоидные состояния различной этиологии
# ...                                                 ...
# 8124  сосудистой смертности и госпитализации по пово...
# 8125  сосудистой смертности и госпитализации по пово...
# 8126  сосудистой смертности и госпитализации по пово...
# 8127  сосудистой смертности и госпитализации по пово...
# 8128  сосудистой смертности и госпитализации по пово...
#
#                                        противопоказания  \
# 0                                 гиперчувствительность
# 1                                 гиперчувствительность
# 2                                 гиперчувствительность
# 3                                 гиперчувствительность
# 4                                 гиперчувствительность
# ...                                                 ...
# 8124  повышенная чувствительность к сакубитрилу или ...
# 8125  повышенная чувствительность к сакубитрилу или ...
# 8126  повышенная чувствительность к сакубитрилу или ...
# 8127  повышенная чувствительность к сакубитрилу или ...
# 8128  повышенная чувствительность к сакубитрилу или ...
#
#                                       побочные действия  \
# 0                                            тахикардия
# 1                            нарушение сердечного ритма
# 2                                      боль за грудиной
# 3                                                тремор
# 4                                          беспокойство
# ...                                                 ...
# 8124                              имеющимся у пациентов
# 8125  выявленные нежелательные явления   соответство...
# 8126                              имеющимся у пациентов
# 8127  выявленные нежелательные явления   соответство...
# 8128                              имеющимся у пациентов
#
#                                           форма выпуска  \
# 0                                              таблетки
# 1                                              таблетки
# 2                                              таблетки
# 3                                              таблетки
# 4                                              таблетки
# ...                                                 ...
# 8124  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8125  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8126  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8127  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8128  таблетки 50 мг   овальные двояковыпуклые таблетки
#
#                                        условия хранения Срок годности  train
# 0     хранить при температуре не выше 25. хранить в ...        2 года   True
# 1     хранить при температуре не выше 25. хранить в ...        2 года   True
# 2     хранить при температуре не выше 25. хранить в ...        2 года   True
# 3     хранить при температуре не выше 25. хранить в ...        2 года   True
# 4     хранить при температуре не выше 25. хранить в ...        2 года   True
# ...                                                 ...           ...    ...
# 8124  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8125  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8126  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8127  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8128  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
#
# [8129 rows x 10 columns]

# %% [markdown]
# ## Knowledge graph creation
# We are going to create a knowledge graph from scratch based on the match information. The idea is that each match is an entity that will be connected to its participating teams, geography, characteristics, and results.
#
# The objective is to generate a new representation of the dataset where each data point is an triple in the form:
#
#     <subject, predicate, object>
#
# First we need to create the entities (subjects and objects) that will form the graph. We make sure teams and geographical information result in different entities (e.g. the Brazilian team and the corresponding country will be different).

# %%
from unidecode import unidecode

# %%
def create_uri(name):
    var = unidecode(name.replace(" ", "_"))
    var = var.replace(' ', '')
    var = var.replace('\'', '')
    var = var.replace('−', '')
    var = var.replace('.', '')
    var = var.replace('/', '')
    var = var.replace('\\', '')
    var = var.replace('\"', '')
    var = var.replace('<', '')
    var = var.replace('>', '')
    var = var.replace('-', '')
    var = var.replace(':', '')
    var = var.replace(';', '')
    var = var.replace('%', '')
    var = var.replace('-', '')
    return var

# %%
create_uri("Аквадетрим капли для приема внутрь 15000 ме/мл 15 мл 1 шт")
# Out:
# 'Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_15ml_1sht'

# %%
# Entities naming
df["medicine_id"] = df['Название'].apply(create_uri)
df["material_id"] =  "Material_" + df['Действующее вещество'].apply(create_uri)
df["propertie_id"] = "Propertie_" + df['Вспомогательные вещества'].apply(create_uri)
df["indication_id"] = "Indication_" + df['Показания'].apply(create_uri)
df["contraindication_id"] = "Contraindication_" + df['противопоказания'].apply(create_uri)
df["side_effect_id"] = "Side_effect_" + df['побочные действия'].apply(create_uri)
df["release_form_id"] = "Release_form_" + df['форма выпуска'].apply(create_uri)
df["storage_condition_id"] = "Storage_condition_" + df['условия хранения'].apply(create_uri)
df["expiration_date_id"] = "Expiration_date_" + df['Срок годности'].apply(create_uri)
df
# Out:
#                                               Название Действующее вещество  \
# 0     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 1     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 2     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 3     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# 4     L-Тироксин 75 Берлин-Хеми таблетки 75 мкг 100 шт  Левотироксин натрия
# ...                                                ...                  ...
# 8124       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8125       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8126       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8127       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
# 8128       Юперио таблетки покрыт.плен.об. 50 мг 28 шт           Сакубитрил
#
#                    Вспомогательные вещества  \
# 0             кальция гидрофосфата дигидрат
# 1             кальция гидрофосфата дигидрат
# 2             кальция гидрофосфата дигидрат
# 3             кальция гидрофосфата дигидрат
# 4             кальция гидрофосфата дигидрат
# ...                                     ...
# 8124              магния стеарат - 6,000 мг
# 8125                       тальк - 2,000 мг
# 8126                       тальк - 2,000 мг
# 8127  кремния диоксид коллоидный - 1,000 мг
# 8128  кремния диоксид коллоидный - 1,000 мг
#
#                                               Показания  \
# 0          гипотиреоидные состояния различной этиологии
# 1          гипотиреоидные состояния различной этиологии
# 2          гипотиреоидные состояния различной этиологии
# 3          гипотиреоидные состояния различной этиологии
# 4          гипотиреоидные состояния различной этиологии
# ...                                                 ...
# 8124  сосудистой смертности и госпитализации по пово...
# 8125  сосудистой смертности и госпитализации по пово...
# 8126  сосудистой смертности и госпитализации по пово...
# 8127  сосудистой смертности и госпитализации по пово...
# 8128  сосудистой смертности и госпитализации по пово...
#
#                                        противопоказания  \
# 0                                 гиперчувствительность
# 1                                 гиперчувствительность
# 2                                 гиперчувствительность
# 3                                 гиперчувствительность
# 4                                 гиперчувствительность
# ...                                                 ...
# 8124  повышенная чувствительность к сакубитрилу или ...
# 8125  повышенная чувствительность к сакубитрилу или ...
# 8126  повышенная чувствительность к сакубитрилу или ...
# 8127  повышенная чувствительность к сакубитрилу или ...
# 8128  повышенная чувствительность к сакубитрилу или ...
#
#                                       побочные действия  \
# 0                                            тахикардия
# 1                            нарушение сердечного ритма
# 2                                      боль за грудиной
# 3                                                тремор
# 4                                          беспокойство
# ...                                                 ...
# 8124                              имеющимся у пациентов
# 8125  выявленные нежелательные явления   соответство...
# 8126                              имеющимся у пациентов
# 8127  выявленные нежелательные явления   соответство...
# 8128                              имеющимся у пациентов
#
#                                           форма выпуска  \
# 0                                              таблетки
# 1                                              таблетки
# 2                                              таблетки
# 3                                              таблетки
# 4                                              таблетки
# ...                                                 ...
# 8124  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8125  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8126  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8127  таблетки 50 мг   овальные двояковыпуклые таблетки
# 8128  таблетки 50 мг   овальные двояковыпуклые таблетки
#
#                                        условия хранения Срок годности  train  \
# 0     хранить при температуре не выше 25. хранить в ...        2 года   True
# 1     хранить при температуре не выше 25. хранить в ...        2 года   True
# 2     хранить при температуре не выше 25. хранить в ...        2 года   True
# 3     хранить при температуре не выше 25. хранить в ...        2 года   True
# 4     хранить при температуре не выше 25. хранить в ...        2 года   True
# ...                                                 ...           ...    ...
# 8124  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8125  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8126  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8127  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
# 8128  при температуре не выше 25° с. хранить в недос...    30 месяцев  False
#
#                                          medicine_id  \
# 0     LTiroksin_75_BerlinKhemi_tabletki_75mkg_100sht
# 1     LTiroksin_75_BerlinKhemi_tabletki_75mkg_100sht
# 2     LTiroksin_75_BerlinKhemi_tabletki_75mkg_100sht
# 3     LTiroksin_75_BerlinKhemi_tabletki_75mkg_100sht
# 4     LTiroksin_75_BerlinKhemi_tabletki_75mkg_100sht
# ...                                              ...
# 8124        Iuperio_tabletki_pokrytplenob_50mg_28sht
# 8125        Iuperio_tabletki_pokrytplenob_50mg_28sht
# 8126        Iuperio_tabletki_pokrytplenob_50mg_28sht
# 8127        Iuperio_tabletki_pokrytplenob_50mg_28sht
# 8128        Iuperio_tabletki_pokrytplenob_50mg_28sht
#
#                         material_id  \
# 0     Material_Levotiroksin_natriia
# 1     Material_Levotiroksin_natriia
# 2     Material_Levotiroksin_natriia
# 3     Material_Levotiroksin_natriia
# 4     Material_Levotiroksin_natriia
# ...                             ...
# 8124            Material_Sakubitril
# 8125            Material_Sakubitril
# 8126            Material_Sakubitril
# 8127            Material_Sakubitril
# 8128            Material_Sakubitril
#
#                                          propertie_id  \
# 0            Propertie_kaltsiia_gidrofosfata_digidrat
# 1            Propertie_kaltsiia_gidrofosfata_digidrat
# 2            Propertie_kaltsiia_gidrofosfata_digidrat
# 3            Propertie_kaltsiia_gidrofosfata_digidrat
# 4            Propertie_kaltsiia_gidrofosfata_digidrat
# ...                                               ...
# 8124              Propertie_magniia_stearat__6,000_mg
# 8125                         Propertie_talk__2,000_mg
# 8126                         Propertie_talk__2,000_mg
# 8127  Propertie_kremniia_dioksid_kolloidnyi__1,000_mg
# 8128  Propertie_kremniia_dioksid_kolloidnyi__1,000_mg
#
#                                           indication_id  \
# 0     Indication_gipotireoidnye_sostoianiia_razlichn...
# 1     Indication_gipotireoidnye_sostoianiia_razlichn...
# 2     Indication_gipotireoidnye_sostoianiia_razlichn...
# 3     Indication_gipotireoidnye_sostoianiia_razlichn...
# 4     Indication_gipotireoidnye_sostoianiia_razlichn...
# ...                                                 ...
# 8124  Indication_sosudistoi_smertnosti_i_gospitaliza...
# 8125  Indication_sosudistoi_smertnosti_i_gospitaliza...
# 8126  Indication_sosudistoi_smertnosti_i_gospitaliza...
# 8127  Indication_sosudistoi_smertnosti_i_gospitaliza...
# 8128  Indication_sosudistoi_smertnosti_i_gospitaliza...
#
#                                     contraindication_id  \
# 0                 Contraindication_giperchuvstvitelnost
# 1                 Contraindication_giperchuvstvitelnost
# 2                 Contraindication_giperchuvstvitelnost
# 3                 Contraindication_giperchuvstvitelnost
# 4                 Contraindication_giperchuvstvitelnost
# ...                                                 ...
# 8124  Contraindication_povyshennaia_chuvstvitelnost_...
# 8125  Contraindication_povyshennaia_chuvstvitelnost_...
# 8126  Contraindication_povyshennaia_chuvstvitelnost_...
# 8127  Contraindication_povyshennaia_chuvstvitelnost_...
# 8128  Contraindication_povyshennaia_chuvstvitelnost_...
#
#                                          side_effect_id  \
# 0                              Side_effect_takhikardiia
# 1              Side_effect_narushenie_serdechnogo_ritma
# 2                           Side_effect_bol_za_grudinoi
# 3                                    Side_effect_tremor
# 4                              Side_effect_bespokoistvo
# ...                                                 ...
# 8124            Side_effect_imeiushchimsia_u_patsientov
# 8125  Side_effect_vyiavlennye_nezhelatelnye_iavlenii...
# 8126            Side_effect_imeiushchimsia_u_patsientov
# 8127  Side_effect_vyiavlennye_nezhelatelnye_iavlenii...
# 8128            Side_effect_imeiushchimsia_u_patsientov
#
#                                         release_form_id  \
# 0                                 Release_form_tabletki
# 1                                 Release_form_tabletki
# 2                                 Release_form_tabletki
# 3                                 Release_form_tabletki
# 4                                 Release_form_tabletki
# ...                                                 ...
# 8124  Release_form_tabletki_50_mg___ovalnye_dvoiakov...
# 8125  Release_form_tabletki_50_mg___ovalnye_dvoiakov...
# 8126  Release_form_tabletki_50_mg___ovalnye_dvoiakov...
# 8127  Release_form_tabletki_50_mg___ovalnye_dvoiakov...
# 8128  Release_form_tabletki_50_mg___ovalnye_dvoiakov...
#
#                                    storage_condition_id  \
# 0     Storage_condition_khranit_pri_temperature_ne_v...
# 1     Storage_condition_khranit_pri_temperature_ne_v...
# 2     Storage_condition_khranit_pri_temperature_ne_v...
# 3     Storage_condition_khranit_pri_temperature_ne_v...
# 4     Storage_condition_khranit_pri_temperature_ne_v...
# ...                                                 ...
# 8124  Storage_condition_pri_temperature_ne_vyshe_25d...
# 8125  Storage_condition_pri_temperature_ne_vyshe_25d...
# 8126  Storage_condition_pri_temperature_ne_vyshe_25d...
# 8127  Storage_condition_pri_temperature_ne_vyshe_25d...
# 8128  Storage_condition_pri_temperature_ne_vyshe_25d...
#
#                 expiration_date_id
# 0           Expiration_date_2_goda
# 1           Expiration_date_2_goda
# 2           Expiration_date_2_goda
# 3           Expiration_date_2_goda
# 4           Expiration_date_2_goda
# ...                            ...
# 8124  Expiration_date_30_mesiatsev
# 8125  Expiration_date_30_mesiatsev
# 8126  Expiration_date_30_mesiatsev
# 8127  Expiration_date_30_mesiatsev
# 8128  Expiration_date_30_mesiatsev
#
# [8129 rows x 19 columns]

# %% [markdown]
# Then, we create the actual triples based on the relationship between the entities. We do it only for the triples in the training set (before 2014).

# %%
triples = []
for _, row in df.iterrows():
    # Goal information
    material = (row["medicine_id"], "have_action_material", row["material_id"])
    propertie = (row["medicine_id"], "have_auxiliary_properties", row["propertie_id"])
    indication = (row["medicine_id"], "have_indications", row["indication_id"])
    contraindication = (row["medicine_id"], "have_contraindications", row["contraindication_id"])
    side_effect = (row["medicine_id"], "have_side_effects", row["side_effect_id"])
    release_form = (row["medicine_id"], "have_release_form", row["release_form_id"])
    storage_condition = (row["medicine_id"], "have_storage_conditions", row["storage_condition_id"])
    expiration_date = (row["medicine_id"], "have_expiration_date", row["expiration_date_id"])

    triples.extend((material, propertie, indication, contraindication, side_effect, release_form, storage_condition, expiration_date))

print(len(triples))
# Out:
# 65032

# %% [markdown]
# Note that we treat some literals (year, neutral match, home score, away score) as discrete entities and they will be part of the final knowledge graph used to generate the embeddings. We limit the number of score entities by clipping the score to be at most 5.

# %% [markdown]
# Below we can see visualise a subset of the graph related to the infamous [Maracanazo](https://en.wikipedia.org/wiki/Uruguay_v_Brazil_(1950_FIFA_World_Cup)):
#
# ![Football graph](https://github.com/Accenture/AmpliGraph/blob/main/docs/tutorials/img/FootballGraph.png?raw=1)

# %% [markdown]
# The whole graph related to this match can be summarised by the triples below:

# %%
# Преобразование троек в DataFrame
triples_df = pd.DataFrame(triples, columns=['subject', 'predicate', 'object'])
triples_df[(triples_df.subject=="Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_15ml_1sht")]
# Out:
#                                                subject  \
# 744  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 745  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 746  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 747  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 748  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# ..                                                 ...
# 851  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 852  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 853  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 854  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
# 855  Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...
#
#                      predicate  \
# 744       have_action_material
# 745  have_auxiliary_properties
# 746           have_indications
# 747     have_contraindications
# 748          have_side_effects
# ..                         ...
# 851     have_contraindications
# 852          have_side_effects
# 853          have_release_form
# 854    have_storage_conditions
# 855       have_expiration_date
#
#                                                 object
# 744                           Material_Kolekaltsiferol
# 745           Propertie_makrogola_glitserilritsinoleat
# 746  Indication_profilaktika_i_lechenie_defitsita_v...
# 747  Contraindication_povyshennaia_chuvstvitelnost_...
# 748  Side_effect_povyshennaia_chuvstvitelnost_k_kom...
# ..                                                 ...
# 851  Contraindication_povyshennaia_chuvstvitelnost_...
# 852                       Side_effect_gipervitaminoz_d
# 853   Release_form_kapli_dlia_priema_vnutr_15_000_meml
# 854  Storage_condition_khranit_pri_temperature_ne_v...
# 855                             Expiration_date_3_goda
#
# [112 rows x 3 columns]

# %% [markdown]
# #### Example [RML](https://rml.io/) mapping

# %%
# @prefix rr: <http://www.w3.org/ns/r2rml#>.
# @prefix rml: <http://semweb.mmlab.be/ns/rml#>.
# @prefix ql: <http://semweb.mmlab.be/ns/ql#>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
# @prefix ex: <http://example.com/ns#>.
# @prefix dbo: <http://dbpedia.org/ontology#/>.
# @prefix fno: <http://w3id.org/function/ontology#>.
# @prefix grel: <http://users.ugent.be/~bjdmeest/function/grel.ttl#>.

# <#Football_match>

#   rml:logicalSource [
#     rml:source "football_results.csv";
#     rml:referenceFormulation ql:CSV
#   ];


#   rr:subjectMap [
#     rr:template "http://ex.com/Team/Team{home_team}";
#     rr:class dbo:FootballTeam
#   ];

#   rr:subjectMap [
#     rr:template "http://ex.com/Team/Team{away_team}";
#     rr:class dbo:FootballTeam
#   ];

#   rr:subjectMap [
#     rr:template "http://ex.com/Match/{match_id}";
#     rr:class dbo:SportsEvent
#   ];


#   rr:predicateObjectMap [
#     rr:predicate ex:isHomeTeamIn;
#     rr:objectMap [
#       rml:reference "match_id"
#     ]
#   ];

#   rr:predicateObjectMap [
#     rr:predicate ex:isAwayTeamIn;
#     rr:objectMap [
#       rml:reference "match_id"
#     ]
#   ];

#   rr:predicateObjectMap [
#     rr:predicate ex:inTournament;
#     rr:objectMap [
#       rml:reference "tournament_id"
#     ]
#   ];

#   rr:predicateObjectMap [
#     rr:predicate ex:inCity;
#     rr:objectMap [
#       rml:reference "city_id"
#     ]
#   ].

# %% [markdown]
# #### Example output data

# %% [markdown]
# <http://ex.com/Team/TeamScotland> ex:isHomeTeamIn Match0.
#
# <http://ex.com/Team/TeamEngland> ex:isAwayTeamIn Match0.
#
# <http://ex.com/Match/Match0> ex:inTournament TournamentFriendly.
#
# <http://ex.com/Match/Match0> ex:inCity CityGlasgow.

# %% [markdown]
# ## Training knowledge graph embeddings
#
# We split our training dataset further into training and validation, where the new training set will be used to the knowledge embedding training and the validation set will be used in its evaluation. The test set will be used to evaluate the performance of the classification algorithm built on top of the embeddings.
#
# What differs from the standard method of randomly sampling N points to make up our validation set is that our data points are two entities linked by some relationship, and we need to take care to ensure that all entities are represented in train and validation sets by at least one triple.
#
# To accomplish this, AmpliGraph provides the [`train_test_split_no_unseen`](https://docs.ampligraph.org/en/latest/generated/ampligraph.evaluation.train_test_split_no_unseen.html#train-test-split-no-unseen) function.

# %%
from ampligraph.evaluation import train_test_split_no_unseen

X_train, X_valid = train_test_split_no_unseen(np.array(triples), test_size=9000)

# %%
print('Train set size: ', X_train.shape)
print('Test set size: ', X_valid.shape)
# Out:
# Train set size:  (56032, 3)
# Test set size:  (9000, 3)

# %%
pip show ampligraph
# Out:
# Name: ampligraphNote: you may need to restart the kernel to use updated packages.
#
# Version: 2.1.0
# Summary: A Python library for relational learning on knowledge graphs.
# Home-page: https://github.com/Accenture/AmpliGraph/
# Author: Accenture Dublin Labs
# Author-email: about@ampligraph.org
# License: Apache 2.0
# Location: c:\tools\python\lib\site-packages
# Requires: beautifultable, docopt, docutils, flake8, matplotlib, myst-parser, networkx, numpy, pandas, pytest, pyyaml, rdflib, schema, scikit-learn, scipy, setuptools, sphinx, sphinx-rtd-theme, sphinxcontrib-bibtex, tqdm
# Required-by:

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.9.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\tools\python\lib\site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, keras-preprocessing, libclang, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from ampligraph.latent_features import ScoringBasedEmbeddingModel
from ampligraph.latent_features.loss_functions import get as get_loss
from ampligraph.latent_features.regularizers import get as get_regularizer

model = ScoringBasedEmbeddingModel(k=50,
                                   eta=5,
                                   scoring_type='ComplEx',
                                   seed=0)

# Optimizer, loss and regularizer definition
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
loss = get_loss('multiclass_nll')
regularizer = get_regularizer('LP', {'p': 3, 'lambda': 1e-5})

# Compilation of the model
model.compile(optimizer=optimizer, loss=loss, entity_relation_regularizer=regularizer)

# %% [markdown]
# AmpliGraph has implemented [several Knowledge Graph Embedding models](https://docs.ampligraph.org/en/latest/ampligraph.latent_features.html#knowledge-graph-embedding-models) (TransE, ComplEx, DistMult, HolE), but to begin with we're just going to use the [ComplEx](https://docs.ampligraph.org/en/latest/generated/ampligraph.latent_features.ComplEx.html#ampligraph.latent_features.ComplEx) model, which is known to bring state-of-the-art predictive power.
#
# The hyper-parameter choice was based on the [best results](https://docs.ampligraph.org/en/latest/experiments.html) we have found so far for the ComplEx model applied to some benchmark datasets used in the knowledge graph embeddings community. This tutorial does not cover [hyper-parameter tuning](https://docs.ampligraph.org/en/latest/examples.html#model-selection).

# %% [markdown]
# Lets go through the parameters to understand what's going on:
#
# - **`k`**: the dimensionality of the embedding space.
# - **`eta`** ($\\eta$) : the number of negative, or false triples that must be generated at training runtime for each positive, or true triple.
# - **`scoring_type`**: type of model defined by spicific scoring function.
# - **`seed`** : random seed, used for reproducibility.
# - **`optimizer`** : the Adam optimizer, with a learning rate of 1e-4 set via the *optimizer_params* kwarg.
# - **`loss`** : pairwise loss, with a margin of 0.5 set via the *loss_params* kwarg.
# - **`regularizer`** : $L_p$ regularization with $p=3$, i.e. l3 regularization. $\\lambda$ = 1e-5, set via the *regularizer_params* kwarg.

# %% [markdown]
# Training should take around 10 minutes on a modern GPU:

# %%
model.fit(X_train,
          batch_size=int(X_train.shape[0] / 10),
          epochs=50, # Number of training epochs
          verbose=True # Displays a progress bar.
          )
# Out:
# Epoch 1/50
# 12/12 [==============================] - 5s 410ms/step - loss: 9125.7607
# Epoch 2/50
# 12/12 [==============================] - 2s 143ms/step - loss: 9125.0381
# Epoch 3/50
# 12/12 [==============================] - 1s 112ms/step - loss: 9124.3154
# Epoch 4/50
# 12/12 [==============================] - 1s 110ms/step - loss: 9123.5840
# Epoch 5/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9122.8330
# Epoch 6/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9122.0576
# Epoch 7/50
# 12/12 [==============================] - 1s 102ms/step - loss: 9121.2500
# Epoch 8/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9120.4053
# Epoch 9/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9119.5205
# Epoch 10/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9118.5889
# Epoch 11/50
# 12/12 [==============================] - 1s 108ms/step - loss: 9117.6035
# Epoch 12/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9116.5654
# Epoch 13/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9115.4600
# Epoch 14/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9114.2871
# Epoch 15/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9113.0420
# Epoch 16/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9111.7148
# Epoch 17/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9110.3066
# Epoch 18/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9108.8076
# Epoch 19/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9107.2168
# Epoch 20/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9105.5264
# Epoch 21/50
# 12/12 [==============================] - 1s 109ms/step - loss: 9103.7314
# Epoch 22/50
# 12/12 [==============================] - 1s 107ms/step - loss: 9101.8262
# Epoch 23/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9099.8047
# Epoch 24/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9097.6621
# Epoch 25/50
# 12/12 [==============================] - 1s 109ms/step - loss: 9095.3965
# Epoch 26/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9092.9971
# Epoch 27/50
# 12/12 [==============================] - 1s 108ms/step - loss: 9090.4639
# Epoch 28/50
# 12/12 [==============================] - 1s 106ms/step - loss: 9087.7891
# Epoch 29/50
# 12/12 [==============================] - 1s 106ms/step - loss: 9084.9639
# Epoch 30/50
# 12/12 [==============================] - 1s 106ms/step - loss: 9081.9883
# Epoch 31/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9078.8594
# Epoch 32/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9075.5635
# Epoch 33/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9072.1035
# Epoch 34/50
# 12/12 [==============================] - 1s 107ms/step - loss: 9068.4697
# Epoch 35/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9064.6582
# Epoch 36/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9060.6689
# Epoch 37/50
# 12/12 [==============================] - 1s 107ms/step - loss: 9056.4873
# Epoch 38/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9052.1191
# Epoch 39/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9047.5537
# Epoch 40/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9042.7881
# Epoch 41/50
# 12/12 [==============================] - 1s 111ms/step - loss: 9037.8174
# Epoch 42/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9032.6377
# Epoch 43/50
# 12/12 [==============================] - 1s 105ms/step - loss: 9027.2451
# Epoch 44/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9021.6357
# Epoch 45/50
# 12/12 [==============================] - 1s 107ms/step - loss: 9015.8037
# Epoch 46/50
# 12/12 [==============================] - 1s 104ms/step - loss: 9009.7451
# Epoch 47/50
# 12/12 [==============================] - 1s 103ms/step - loss: 9003.4541
# Epoch 48/50
# 12/12 [==============================] - 1s 106ms/step - loss: 8996.9297
# Epoch 49/50
# 12/12 [==============================] - 1s 112ms/step - loss: 8990.1748
# Epoch 50/50
# 12/12 [==============================] - 1s 105ms/step - loss: 8983.1748

# %% [markdown]
# ## Evaluating knowledge embeddings
#
# AmpliGraph aims to follow scikit-learn's ease-of-use design philosophy and simplify everything down to **`fit`**, **`evaluate`**, and **`predict`** functions.
#
# However, there are some knowledge graph specific steps we must take to ensure our model can be trained and evaluated correctly. The first of these is defining the filter that will be used to ensure that no negative statements generated by the corruption procedure are actually positives. This is simply can be done by concatenating our train and test sets. Now when negative triples are generated by the corruption strategy, we can check that they aren't actually true statements.

# %% [markdown]
# For this we'll use method `evaluate` of model object:
#
# - **`X_valid`** - the data to evaluate on. We're going to use our test set to evaluate.
# - **`use_filter`** - will filter out the false negatives generated by the corruption strategy.
# - **`corrupt_side`** - specifies approach for triple corruption. 's,o' option means t True, then subj and obj are corrupted separately during evaluation.
# - **`verbose`** - displays a progress bar.

# %%
ranks = model.evaluate(X_valid,
                      use_filter={'train': X_train,
                                  'test': X_valid},
                      corrupt_side='s,o',
                      verbose=True)
# Out:
# 901/901 [==============================] - 21s 23ms/step

# %% [markdown]
# We're going to use the mrr_score (mean reciprocal rank) and hits_at_n_score functions.
#
# - **mrr_score**: The function computes the mean of the reciprocal of elements of a vector of rankings ranks.
# - **hits_at_n_score**: The function computes how many elements of a vector of rankings ranks make it to the top n positions.

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

flat_ranks = ranks.flatten()
# Фильтрация одномерного массива, чтобы оставить только положительные значения (начиная с 1)
res_ranks = flat_ranks[flat_ranks > 0]

mr = mr_score(res_ranks)
mrr = mrr_score(res_ranks)

print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.23
# MR: 157.25
# Hits@10: 0.93
# Hits@3: 0.91
# Hits@1: 0.90

# %% [markdown]
# We can interpret these results by stating that the model will rank the correct entity within the top-3 possibilities 34% of the time.
#
# By themselves, these metrics are not enough to conclude the usefulness of the embeddings in a downstream task, but they suggest that the embeddings have learned a reasonable representation enough to consider using them in more tasks.

# %% [markdown]
# ## Clustering and embedding visualization

# %% [markdown]
# To evaluate the subjective quality of the embeddings, we can visualise the embeddings on 2D space and also cluster them on the original space. We can compare the clustered embeddings with natural clusters, in this case the continent where the team is from, so that we have a ground truth to evaluate the clustering quality both qualitatively and quantitatively.
#
# Requirements:
#
# * seaborn
# * adjustText
# * incf.countryutils
#
# For seaborn and adjustText, simply install them with `pip install seaborn adjustText`.
#
# For incf.countryutils, do the following steps:
# ```bash
# git clone https://github.com/wyldebeast-wunderliebe/incf.countryutils.git
# cd incf.countryutils
# pip install .```

# %%
# !git clone https://github.com/wyldebeast-wunderliebe/incf.countryutils.git
# !cd incf.countryutils && pip install .
# Out:
# Cloning into 'incf.countryutils'...
# Processing c:\users\kukol\desktop\uhfas\incf.countryutils
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools in c:\tools\python\lib\site-packages (from incf.countryutils==1.2) (63.2.0)
# Building wheels for collected packages: incf.countryutils
#   Building wheel for incf.countryutils (setup.py): started
#   Building wheel for incf.countryutils (setup.py): finished with status 'done'
#   Created wheel for incf.countryutils: filename=incf.countryutils-1.2-py3-none-any.whl size=21444 sha256=dc275d54c8cebdd0103ef1faa661be87c117124207974ee96c9a7ee166ec149a
#   Stored in directory: C:\Users\kukol\AppData\Local\Temp\pip-ephem-wheel-cache-86p93bno\wheels\61\21\4b\4d04a84c00a5a4a6b5babc375220d4df815d5bc271d425154b
# Successfully built incf.countryutils
# Installing collected packages: incf.countryutils
# Successfully installed incf.countryutils-1.2

# %%
# !pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in c:\tools\python\lib\site-packages (from adjustText) (1.26.4)
# Requirement already satisfied: matplotlib in c:\tools\python\lib\site-packages (from adjustText) (3.9.2)
# Requirement already satisfied: scipy in c:\tools\python\lib\site-packages (from adjustText) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (24.1)
# Requirement already satisfied: pillow>=8 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\tools\python\lib\site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\tools\python\lib\site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: adjustText
# Successfully installed adjustText-1.3.0

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from incf.countryutils import transformations
# %matplotlib inline

# %% [markdown]
# We create a map from the team ID (e.g. "TeamBrazil") to the team name (e.g. "Brazil") for visualization purposes.

# %%
id_to_name_map = {**dict(zip(df.medicine_id, df["Название"])),
                  **dict(zip(df.material_id, df.material_id))}

med_to_indication_map = {**dict(zip(df.medicine_id, df.indication_id))}

# %% [markdown]
# We now create a dictionary with the embeddings of all teams:

# %%
teams = pd.concat((df.medicine_id[df["train"]], df.material_id[df["train"]])).unique()
team_embeddings = dict(zip(teams, model.get_embeddings(teams)))
entities = df.medicine_id[df["train"]].unique()
entitie_embeddings = dict(zip(entities, model.get_embeddings(entities)))

# %% [markdown]
# We use PCA to project the embeddings from the 200 space into 2D space:

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in team_embeddings.values()]))

# %% [markdown]
# We will cluster the teams embeddings on its original 200-dimensional space using the `find_clusters` in our discovery API:

# %%
from ampligraph.discovery import find_clusters
from sklearn.cluster import KMeans

clustering_algorithm = KMeans(n_clusters=6, n_init=50, max_iter=500, random_state=0)
clusters = find_clusters(teams, model, clustering_algorithm, mode='e')

# %% [markdown]
# This helper function uses the `incf.countryutils` library to translate country names to their corresponding continents.

# %%
def mt_to_mat(material):
    try:
        return transformations.cn_to_ctn(id_to_name_map[material])
    except KeyError:
        return "unk"

# %% [markdown]
# This dataframe contains for each team their projected embeddings to 2D space via PCA, their continent and the KMeans cluster. This will be used alongisde Seaborn to make the visualizations.

# %%
plot_df = pd.DataFrame({"teams": teams,
                        "embedding1": embeddings_2d[:, 0],
                        "embedding2": embeddings_2d[:, 1],
                        "indication": pd.Series(entities).map(med_to_indication_map),
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})
plot_df = plot_df.dropna()
plot_df
# Out:
#                                                  teams  embedding1  \
# 0       LTiroksin_75_BerlinKhemi_tabletki_75mkg_100sht    0.434426
# 1             Aveloks_tabletki_pokrytplenob_400mg_5sht    0.126051
# 2                           Azafen_tabletki_25mg_50sht   -0.037590
# 3    Azitromitsin_ForteAlium_tabletki_pokrytplenob_...    0.228157
# 4    Akvadetrim_kapli_dlia_priema_vnutr_15000_meml_...    0.174494
# ..                                                 ...         ...
# 303                     Trikhopol_tabletki_250mg_20sht    0.247543
# 304  Trokserutin_Verteks_gel_dlia_naruzhnogo_primen...   -0.072574
# 305           Trokserutin_Verteks_kapsuly_300mg_100sht   -0.044976
# 306            Trokserutin_Verteks_kapsuly_300mg_50sht   -0.062947
# 307             Trokserutin_Vramed_kapsuly_300mg_50sht    0.054263
#
#      embedding2                                         indication   cluster
# 0     -0.201879  Indication_gipotireoidnye_sostoianiia_razlichn...  cluster2
# 1     -0.052333                        Indication_po_dannym_rxlist  cluster2
# 2     -0.060063  Indication_depressivnye_epizody_legkoi_i_sredn...  cluster4
# 3      0.125792                           Indication_po_dannym_fda  cluster5
# 4      0.124515  Indication_profilaktika_i_lechenie_defitsita_v...  cluster5
# ..          ...                                                ...       ...
# 303   -0.108478  Indication_trikhomoniaz_kishechnye_infektsii_i...  cluster2
# 304    0.002004              Indication_varikoznoe_rasshirenie_ven  cluster3
# 305    0.088094              Indication_varikoznoe_rasshirenie_ven  cluster3
# 306    0.027615              Indication_varikoznoe_rasshirenie_ven  cluster3
# 307   -0.042822  Indication_khronicheskaia_venoznaia_nedostatoc...  cluster3
#
# [308 rows x 5 columns]

# %% [markdown]
# We plot the results on a 2D scatter plot, coloring the teams by the continent or cluster and also displaying some individual team names.
#
# We always display the names of the top 20 teams (according to [FIFA rankings](https://en.wikipedia.org/wiki/FIFA_World_Rankings)) and a random subset of the rest.

# %%
koeff = 100

# %%
def plot_clusters(hue):
    np.random.seed(0)
    plt.figure(figsize=(12, 12))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df, x="embedding1", y="embedding2", hue=hue, legend=False)
    texts = []
    for i, point in plot_df.iterrows():
        if np.random.random() < 0.02:
            texts.append(plt.text(point['embedding1']+0.02, point['embedding2']+0.01, str(point["teams"])))
    adjust_text(texts)

# %% [markdown]
# The first visualisation of the 2D embeddings shows the natural geographical clusters (continents), which can be seen as a form of the ground truth:

# %%
plot_clusters("indication")

# %% [markdown]
# We can see above that the embeddings learned geographical similarities even though this information was not explicit on the original dataset.
#
# Now we plot the same 2D embeddings but with the clusters found by K-Means:

# %%
def plot_clusters(hue):
    np.random.seed(0)
    plt.figure(figsize=(12, 12))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df, x="embedding1", y="embedding2", hue=hue)
    texts = []
    for i, point in plot_df.iterrows():
        if np.random.random() < 0.02:
            texts.append(plt.text(point['embedding1']+0.02, point['embedding2']+0.01, str(point["teams"])))
    adjust_text(texts)

# %%
plot_clusters("cluster")

# %% [markdown]
# We can see that K-Means found very similar cluster to the natural geographical clusters by the continents. This shows that on the 200-dimensional embedding space, similar teams appear close together, which can be captured by a clustering algorithm.
#
# Our evaluation of the clusters can be more objective by using a metric such as the [adjusted Rand score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html), which varies from -1 to 1, where 0 is random labelling and 1 is a perfect match:

# %%
from sklearn import metrics
metrics.adjusted_rand_score(plot_df.indication, plot_df.cluster)*koeff
# Out:
# 0.7119781618187586

# %% [markdown]
# ## Classification
#
# We will use the knowledge embeddings to predict future matches as a classification problem.
#
# We can model it as a multiclass problem with three classes: home team wins, home team loses, draw.
#
# The embeddings are used directly as features to a XGBoost classifier.
#
# First we need to determine the target:

# %%
df["results"] = (df.home_score > df.away_score).astype(int) + \
                (df.home_score == df.away_score).astype(int)*2 + \
                (df.home_score < df.away_score).astype(int)*3 - 1

# %%
df.results.value_counts(normalize=True)
# Out:
# results
# 0    0.486473
# 2    0.282456
# 1    0.231071
# Name: proportion, dtype: float64

# %% [markdown]
# ### Original dataset

# %% [markdown]
# First install xgboost with `pip install xgboost`.

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.10.0)

# %%
new_df = df[["results", "neutral", "train"]].copy()
new_df
# Out:
#        results neutral  train
# 0            1   False   True
# 1            0   False   True
# 2            0   False   True
# 3            1   False   True
# 4            0   False   True
# ...        ...     ...    ...
# 40766        0    True  False
# 40767        1    True  False
# 40768        2    True  False
# 40769        0    True  False
# 40770        0    True  False
#
# [40771 rows x 3 columns]

# %%
new_df.neutral = new_df.neutral.astype(bool)

# %% [markdown]
# Split date:

# %%
new_df["year"] = df["date"].apply(lambda x: int(x[:4]))
new_df["month"] = df["date"].apply(lambda x: int(x[5:7]))
new_df["day"] = df["date"].apply(lambda x: int(x[8:]))

# %% [markdown]
# Apply one hot encoding:

# %%
encoded_cols = pd.get_dummies(df[["home_team", "away_team", "tournament", "city", "country"]])
encoded_cols
# Out:
#        home_team_Abkhazia  home_team_Afghanistan  home_team_Albania  \
# 0                   False                  False              False
# 1                   False                  False              False
# 2                   False                  False              False
# 3                   False                  False              False
# 4                   False                  False              False
# ...                   ...                    ...                ...
# 40766               False                  False              False
# 40767               False                  False              False
# 40768               False                  False              False
# 40769               False                  False              False
# 40770               False                  False              False
#
#        home_team_Alderney  home_team_Algeria  home_team_American Samoa  \
# 0                   False              False                     False
# 1                   False              False                     False
# 2                   False              False                     False
# 3                   False              False                     False
# 4                   False              False                     False
# ...                   ...                ...                       ...
# 40766               False              False                     False
# 40767               False              False                     False
# 40768               False              False                     False
# 40769               False               True                     False
# 40770               False              False                     False
#
#        home_team_Andalusia  home_team_Andorra  home_team_Angola  \
# 0                    False              False             False
# 1                    False              False             False
# 2                    False              False             False
# 3                    False              False             False
# 4                    False              False             False
# ...                    ...                ...               ...
# 40766                False              False             False
# 40767                False              False             False
# 40768                False              False             False
# 40769                False              False             False
# 40770                False              False             False
#
#        home_team_Anguilla  ...  country_Western Samoa  country_Yemen  \
# 0                   False  ...                  False          False
# 1                   False  ...                  False          False
# 2                   False  ...                  False          False
# 3                   False  ...                  False          False
# 4                   False  ...                  False          False
# ...                   ...  ...                    ...            ...
# 40766               False  ...                  False          False
# 40767               False  ...                  False          False
# 40768               False  ...                  False          False
# 40769               False  ...                  False          False
# 40770               False  ...                  False          False
#
#        country_Yemen AR  country_Yemen DPR  country_Yugoslavia  \
# 0                 False              False               False
# 1                 False              False               False
# 2                 False              False               False
# 3                 False              False               False
# 4                 False              False               False
# ...                 ...                ...                 ...
# 40766             False              False               False
# 40767             False              False               False
# 40768             False              False               False
# 40769             False              False               False
# 40770             False              False               False
#
#        country_Zambia  country_Zanzibar  country_Zaïre  country_Zimbabwe  \
# 0               False             False          False             False
# 1               False             False          False             False
# 2               False             False          False             False
# 3               False             False          False             False
# 4               False             False          False             False
# ...               ...               ...            ...               ...
# 40766           False             False          False             False
# 40767           False             False          False             False
# 40768           False             False          False             False
# 40769           False             False          False             False
# 40770           False             False          False             False
#
#        country_Éire
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 40766         False
# 40767         False
# 40768         False
# 40769         False
# 40770         False
#
# [40771 rows x 2946 columns]

# %%
new_df = new_df.join(encoded_cols)
new_df
# Out:
#        results  neutral  train  year  month  day  home_team_Abkhazia  \
# 0            1     True   True  1872     11   30               False
# 1            0     True   True  1873      3    8               False
# 2            0     True   True  1874      3    7               False
# 3            1     True   True  1875      3    6               False
# 4            0     True   True  1876      3    4               False
# ...        ...      ...    ...   ...    ...  ...                 ...
# 40766        0     True  False  2019      7   10               False
# 40767        1     True  False  2019      7   11               False
# 40768        2     True  False  2019      7   11               False
# 40769        0     True  False  2019      7   14               False
# 40770        0     True  False  2019      7   14               False
#
#        home_team_Afghanistan  home_team_Albania  home_team_Alderney  ...  \
# 0                      False              False               False  ...
# 1                      False              False               False  ...
# 2                      False              False               False  ...
# 3                      False              False               False  ...
# 4                      False              False               False  ...
# ...                      ...                ...                 ...  ...
# 40766                  False              False               False  ...
# 40767                  False              False               False  ...
# 40768                  False              False               False  ...
# 40769                  False              False               False  ...
# 40770                  False              False               False  ...
#
#        country_Western Samoa  country_Yemen  country_Yemen AR  \
# 0                      False          False             False
# 1                      False          False             False
# 2                      False          False             False
# 3                      False          False             False
# 4                      False          False             False
# ...                      ...            ...               ...
# 40766                  False          False             False
# 40767                  False          False             False
# 40768                  False          False             False
# 40769                  False          False             False
# 40770                  False          False             False
#
#        country_Yemen DPR  country_Yugoslavia  country_Zambia  \
# 0                  False               False           False
# 1                  False               False           False
# 2                  False               False           False
# 3                  False               False           False
# 4                  False               False           False
# ...                  ...                 ...             ...
# 40766              False               False           False
# 40767              False               False           False
# 40768              False               False           False
# 40769              False               False           False
# 40770              False               False           False
#
#        country_Zanzibar  country_Zaïre  country_Zimbabwe  country_Éire
# 0                 False          False             False         False
# 1                 False          False             False         False
# 2                 False          False             False         False
# 3                 False          False             False         False
# 4                 False          False             False         False
# ...                 ...            ...               ...           ...
# 40766             False          False             False         False
# 40767             False          False             False         False
# 40768             False          False             False         False
# 40769             False          False             False         False
# 40770             False          False             False         False
#
# [40771 rows x 2952 columns]

# %% [markdown]
# Create a multiclass model:

# %%
from xgboost import XGBClassifier

# %%
clf_model = XGBClassifier(n_estimators=500, max_depth=5, objective="multi:softmax")

# %%
X_train = new_df[df["train"]].drop(["results"], axis=1)
y_train = new_df[df["train"]].results
X_val = new_df[~df["train"]].drop(["results"], axis=1)
y_val = new_df[~df["train"]].results

# %%
clf_model.fit(X_train, y_train, verbose=1)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)

# %% [markdown]
# Result

# %%
from sklearn import metrics
metrics.accuracy_score(y_val, clf_model.predict(X_val))
# Out:
# 0.5283765078109551

# %% [markdown]
# ### Graph embedings

# %% [markdown]
# Now we create a function that extracts the features (knowledge embeddings for home and away teams) and the target for a particular subset of the dataset:

# %%
def get_features_target(mask):

    def get_embeddings(team):
        return team_embeddings.get(team, np.full(200, np.nan))

    X = np.hstack((np.vstack(df[mask].home_team_id.apply(get_embeddings).values),
                   np.vstack(df[mask].away_team_id.apply(get_embeddings).values)))
    y = df[mask].results.values
    return X, y

# %%
clf_X_train, y_train = get_features_target((df["train"]))
clf_X_test, y_test = get_features_target((~df["train"]))

# %%
clf_X_train.shape, clf_X_test.shape
# Out:
# ((35714, 400), (5057, 400))

# %% [markdown]
# Note that we have 200 features by team because the ComplEx model uses imaginary and real number for its embeddings, so we have twice as many parameters as defined by `k=100` in its model definition.
#
# We also have some missing information from the embeddings of the entities (i.e. teams) that only appear in the test set, which are unlikely to be correctly classified:

# %%
np.isnan(clf_X_test).sum()/clf_X_test.shape[1]
# Out:
# 105.0

# %% [markdown]
# Create a multiclass model with 500 estimators:

# %%
clf_model = XGBClassifier(n_estimators=500, max_depth=5, objective="multi:softmax")

# %% [markdown]
# Fit the model using all of the training samples:

# %%
clf_model.fit(clf_X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softmax', ...)

# %% [markdown]
# The baseline accuracy for this problem is 47%, as that is the frequency of the most frequent class (home team wins):

# %%
df[~df["train"]].results.value_counts(normalize=True)
# Out:
# results
# 0    0.471030
# 2    0.287325
# 1    0.241645
# Name: proportion, dtype: float64

# %%
metrics.accuracy_score(y_test, clf_model.predict(clf_X_test))
# Out:
# 0.527783270713862

# %% [markdown]
# In conclusion, while the baseline for this classification problem was 47%, with just the knowledge embeddings alone we were able to build a classifier that achieves **53%** accuracy.
#
# As future work, we could add more features to the model (not embeddings related) and tune the model hyper-parameters.

# %% [markdown]
# ## Link prediction

# %% [markdown]
# Link prediction allows us to infer missing links in a graph.
#
# In our case, we're going to predict match result.
# Choose match that exist in train dataset.

# %%
X_train, X_valid = train_test_split_no_unseen(np.array(triples), test_size=10000)

# %%
df = pd.DataFrame(X_train,columns = ['subject','predicate','object'])
matchSubject = "Match1324"
print(df[df.subject==matchSubject])
# Out:
#           subject     predicate              object
# 102407  Match1324    awayScores                   1
# 116179  Match1324     inCountry       CountryBrazil
# 126093  Match1324    homeScores                   4
# 158124  Match1324  inTournament  TournamentFriendly
# 172564  Match1324        inCity    CityRioDeJaneiro
# 266651  Match1324     isNeutral               False

# %% [markdown]
# Remove result for this match from train dataframe.

# %%
dfFiltered = np.array(df[(df.subject!=matchSubject) | ((df.subject==matchSubject) & ~df.predicate.isin(["homeScores","awayScores"]))])

# %% [markdown]
# Fit model on triples without results for current match.

# %%
model.fit(dfFiltered)
# Out:
# Epoch 1/100
# 384/384 [==============================] - 41s 108ms/step - loss: 5672.3242
# Epoch 2/100
# 384/384 [==============================] - 41s 106ms/step - loss: 5542.9214
# Epoch 3/100
# 384/384 [==============================] - 41s 106ms/step - loss: 5419.5327
# Epoch 4/100
# 384/384 [==============================] - 42s 111ms/step - loss: 5301.7891
# Epoch 5/100
# 384/384 [==============================] - 42s 111ms/step - loss: 5189.2979
# Epoch 6/100
# 384/384 [==============================] - 41s 108ms/step - loss: 5081.7212
# Epoch 7/100
# 384/384 [==============================] - 41s 106ms/step - loss: 4978.7417
# Epoch 8/100
# 384/384 [==============================] - 41s 107ms/step - loss: 4880.0381
# Epoch 9/100
# 384/384 [==============================] - 41s 106ms/step - loss: 4785.3955
# Epoch 10/100
# 384/384 [==============================] - 41s 106ms/step - loss: 4694.5400
# Epoch 11/100
# 384/384 [==============================] - 41s 107ms/step - loss: 4607.2554
# Epoch 12/100
# 384/384 [==============================] - 41s 107ms/step - loss: 4523.3296
# Epoch 13/100
# 384/384 [==============================] - 40s 105ms/step - loss: 4442.5845
# Epoch 14/100
# 384/384 [==============================] - 41s 106ms/step - loss: 4364.8257
# Epoch 15/100
# 384/384 [==============================] - 42s 110ms/step - loss: 4289.9062
# Epoch 16/100
# 384/384 [==============================] - 45s 117ms/step - loss: 4217.6509
# Epoch 17/100
# 384/384 [==============================] - 42s 108ms/step - loss: 4147.9448
# Epoch 18/100
# 384/384 [==============================] - 41s 107ms/step - loss: 4080.6362
# Epoch 19/100
# 384/384 [==============================] - 42s 109ms/step - loss: 4015.6162
# Epoch 20/100
# 384/384 [==============================] - 41s 107ms/step - loss: 3952.7656
# Epoch 94/100
# 384/384 [==============================] - 41s 105ms/step - loss: 1904.7622
# Epoch 95/100
# 384/384 [==============================] - 41s 107ms/step - loss: 1892.4604
# Epoch 96/100
# 384/384 [==============================] - 41s 107ms/step - loss: 1880.3397
# Epoch 97/100
# 384/384 [==============================] - 41s 107ms/step - loss: 1868.3950
# Epoch 98/100
# 384/384 [==============================] - 41s 106ms/step - loss: 1856.6204
# Epoch 99/100
# 384/384 [==============================] - 41s 106ms/step - loss: 1845.0166
# Epoch 100/100
# 384/384 [==============================] - 41s 108ms/step - loss: 1833.5797

# %% [markdown]
# We can create a few statements for this match result.

# %%
statements = np.array([
    [f'{matchSubject}', 'homeScores', '0'],
    [f'{matchSubject}', 'homeScores', '1'],
    [f'{matchSubject}', 'homeScores', '2'],
    [f'{matchSubject}', 'homeScores', '3'],
    [f'{matchSubject}', 'homeScores', '4'],
    [f'{matchSubject}', 'awayScores', '0'],
    [f'{matchSubject}', 'awayScores', '1'],
    [f'{matchSubject}', 'awayScores', '2'],
    [f'{matchSubject}', 'awayScores', '3'],
    [f'{matchSubject}', 'awayScores', '4']
])

# %% [markdown]
# Unite the triplets of the graph and the proposed statements.

# %%
statements_filter = np.array(list({tuple(i) for i in np.vstack((dfFiltered, statements))}))
statements_filter
# Out:
# array([['Match33087', 'isNeutral', 'False'],
#        ['TeamWales', 'isAwayTeamIn', 'Match5782'],
#        ['Match5992', 'awayScores', '5'],
#        ...,
#        ['Match14640', 'inCountry', 'CountryChad'],
#        ['Match21824', 'isNeutral', 'False'],
#        ['Match11653', 'homeScores', '1']], dtype='<U48')

# %%
ranks = model.evaluate(statements,
                      use_filter={'train': dfFiltered,
                                  'test': statements},
                      corrupt_side='s,o',
                      verbose=True)
# Out:
# 2/2 [==============================] - 2s 1s/step

# %%
scores = model.predict(statements)
scores
# Out:
# array([-0.5846524 ,  0.08066474, -0.48785803,  1.5089438 ,  5.684367  ,
#        -0.4420216 ,  2.5865698 ,  2.0160317 ,  1.2500255 , -0.39739496],
#       dtype=float32)

# %% [markdown]
# Present the result of predictions.

# %%
from scipy.special import expit
probs = expit(scores)

pd.DataFrame(list(zip([' '.join(x) for x in statements],
                      ranks,
                      np.squeeze(scores),
                      np.squeeze(probs))),
             columns=['statement', 'rank', 'score', 'prob']).sort_values("prob")
# Out:
#                 statement            rank     score      prob
# 0  Match1324 homeScores 0  [24323, 37191] -0.584652  0.357863
# 2  Match1324 homeScores 2  [25271, 36315] -0.487858  0.380398
# 5  Match1324 awayScores 0  [18691, 33323] -0.442022  0.391259
# 9  Match1324 awayScores 4  [32198, 31962] -0.397395  0.401938
# 1  Match1324 homeScores 1  [20895, 10848]  0.080665  0.520155
# 8  Match1324 awayScores 3     [23953, 86]  1.250026  0.777304
# 3  Match1324 homeScores 3     [22831, 67]  1.508944  0.818905
# 7  Match1324 awayScores 2     [17498, 22]  2.016032  0.882470
# 6  Match1324 awayScores 1      [12518, 6]  2.586570  0.929992
# 4  Match1324 homeScores 4      [16943, 1]  5.684367  0.996613

# %% [markdown]
# # Обработка текстовых данных

# %%
# !pip install wget
# !pip install ufal.udpipe
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)
# Requirement already satisfied: ufal.udpipe in /usr/local/lib/python3.10/dist-packages (1.3.1.1)

# %%
import rus_preprocessing_udpipe as UDPipe
from ufal.udpipe import Model, Pipeline

# загрузка модели UDPipe для предобработки
model2 = Model.load('/content/drive/MyDrive/EMO/model/russian-syntagrus-ud-2.0-170801.udpipe')
# Out:
# Loading the model...
# Processing input...

# %%
import pandas as pd

df = pd.read_csv('descs.csv', sep=';')

# %%
df
# Out:
#                                                  text    res_id
# 0   Tin Ore is a T3 resource. Harvesting this reso...    ORE_T3
# 1   Iron Ore is a T4 resource. Harvesting this res...    ORE_T4
# 2   Titanium Ore is a Tier 5 resource. Harvesting ...    ORE_T5
# 3   Chestnut Logs are a Tier 3 resource. They may ...   WOOD_T3
# 4   Pine Logs are a Tier 4 resource. They may be f...   WOOD_T4
# 5   Cedar Logs are a Tier 5 resource. They may be ...   WOOD_T5
# 6   yz near fort sterling like cairn cloatch or pe...    ORE_T5
# 7   for t5 ore i'd go farm somewhere around fort s...    ORE_T5
# 8   GO FARM T4 ORES AT PEN GARN OR PEN GENT, STOP ...    ORE_T4
# 9   Avalonian roads. You gonna be an ore slave if ...    ORE_T5
# 10  Yellow T5 - do cairn cloatch and do mists and ...    ORE_T5

# %%
from nltk.tokenize import RegexpTokenizer
from pymystem3 import Mystem
from nltk.corpus import stopwords

m = Mystem()

# Токенизация + лемматизация
df['token'] = df['text'].apply(lambda x: [word.lower() for word in RegexpTokenizer(r'[A-z]+').tokenize(x)])
df['lemma'] = df['token'].apply(lambda x: [word for word in m.lemmatize(' '.join(x)) if word.strip()])

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# Удаление стоп-слов
df['lemma_cor'] = df['lemma'].apply(lambda x: [word for word in x \
                                               if word not in stopwords.words('english')])

# %%
# извлечение морфологических признаков
df['morph'] = df['lemma_cor'].apply(lambda x: nltk.pos_tag([word for word in x]))

# %%
df
# Out:
#                                                  text    res_id  \
# 0   Tin Ore is a T3 resource. Harvesting this reso...    ORE_T3
# 1   Iron Ore is a T4 resource. Harvesting this res...    ORE_T4
# 2   Titanium Ore is a Tier 5 resource. Harvesting ...    ORE_T5
# 3   Chestnut Logs are a Tier 3 resource. They may ...   WOOD_T3
# 4   Pine Logs are a Tier 4 resource. They may be f...   WOOD_T4
# 5   Cedar Logs are a Tier 5 resource. They may be ...   WOOD_T5
# 6   yz near fort sterling like cairn cloatch or pe...    ORE_T5
# 7   for t5 ore i'd go farm somewhere around fort s...    ORE_T5
# 8   GO FARM T4 ORES AT PEN GARN OR PEN GENT, STOP ...    ORE_T4
# 9   Avalonian roads. You gonna be an ore slave if ...    ORE_T5
# 10  Yellow T5 - do cairn cloatch and do mists and ...    ORE_T5
#
#                                                 token  \
# 0   [tin, ore, is, a, t, resource, harvesting, thi...
# 1   [iron, ore, is, a, t, resource, harvesting, th...
# 2   [titanium, ore, is, a, tier, resource, harvest...
# 3   [chestnut, logs, are, a, tier, resource, they,...
# 4   [pine, logs, are, a, tier, resource, they, may...
# 5   [cedar, logs, are, a, tier, resource, they, ma...
# 6   [yz, near, fort, sterling, like, cairn, cloatc...
# 7   [for, t, ore, i, d, go, farm, somewhere, aroun...
# 8   [go, farm, t, ores, at, pen, garn, or, pen, ge...
# 9   [avalonian, roads, you, gonna, be, an, ore, sl...
# 10  [yellow, t, do, cairn, cloatch, and, do, mists...
#
#                                                 lemma  \
# 0   [tin, ore, is, a, t, resource, harvesting, thi...
# 1   [iron, ore, is, a, t, resource, harvesting, th...
# 2   [titanium, ore, is, a, tier, resource, harvest...
# 3   [chestnut, logs, are, a, tier, resource, they,...
# 4   [pine, logs, are, a, tier, resource, they, may...
# 5   [cedar, logs, are, a, tier, resource, they, ma...
# 6   [yz, near, fort, sterling, like, cairn, cloatc...
# 7   [for, t, ore, i, d, go, farm, somewhere, aroun...
# 8   [go, farm, t, ores, at, pen, garn, or, pen, ge...
# 9   [avalonian, roads, you, gonna, be, an, ore, sl...
# 10  [yellow, t, do, cairn, cloatch, and, do, mists...
#
#                                             lemma_cor  \
# 0   [tin, ore, resource, harvesting, resource, adv...
# 1   [iron, ore, resource, harvesting, resource, ad...
# 2   [titanium, ore, tier, resource, harvesting, re...
# 3   [chestnut, logs, tier, resource, may, found, f...
# 4   [pine, logs, tier, resource, may, found, follo...
# 5   [cedar, logs, tier, resource, may, found, foll...
# 6   [yz, near, fort, sterling, like, cairn, cloatc...
# 7   [ore, go, farm, somewhere, around, fort, sterl...
# 8   [go, farm, ores, pen, garn, pen, gent, stop, s...
# 9   [avalonian, roads, gonna, ore, slave, went, on...
# 10  [yellow, cairn, cloatch, mists, try, get, ore,...
#
#                                                 morph
# 0   [(tin, NN), (ore, RB), (resource, NN), (harves...
# 1   [(iron, NN), (ore, RB), (resource, JJ), (harve...
# 2   [(titanium, NN), (ore, RB), (tier, JJ), (resou...
# 3   [(chestnut, NN), (logs, NNS), (tier, JJR), (re...
# 4   [(pine, JJ), (logs, NNS), (tier, IN), (resourc...
# 5   [(cedar, NN), (logs, NNS), (tier, JJR), (resou...
# 6   [(yz, NN), (near, IN), (fort, NN), (sterling, ...
# 7   [(ore, RB), (go, VBP), (farm, NN), (somewhere,...
# 8   [(go, VB), (farm, NN), (ores, NNS), (pen, VBP)...
# 9   [(avalonian, JJ), (roads, NNS), (gonna, VBP), ...
# 10  [(yellow, JJ), (cairn, NN), (cloatch, NN), (mi...

# %%
from gensim.models import fasttext

# обучение модели на лемматизированных текстах корпуса
model1 = fasttext.FastText(sentences=df['lemma_cor'], vector_size=100, window=5, min_count=1, workers=4)

# %%
# векторизация слов и усреднение полученных векторов для каждого сообщения
df['fasttext1'] = df['lemma_cor'].apply(lambda x: \
                                        np.sum([model1.wv[word] for word in x], axis=0)/len(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8c33380ccb96> in <cell line: 2>()
#       1 # векторизация слов и усреднение полученных векторов для каждого сообщения
# ----> 2 df['fasttext1'] = df['lemma_cor'].apply(lambda x: \
#       3                                         np.sum([model1.wv[word] for word in x], axis=0)/len(x))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1074             else:
#    1075                 values = obj.astype(object)._values
# -> 1076                 mapped = lib.map_infer(
#    1077                     values,
#    1078                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-36-8c33380ccb96> in <lambda>(x)
#       1 # векторизация слов и усреднение полученных векторов для каждого сообщения
#       2 df['fasttext1'] = df['lemma_cor'].apply(lambda x: \
# ----> 3                                         np.sum([model1.wv[word] for word in x], axis=0)/len(x))
#
# NameError: name 'np' is not defined

# %%
# предобработка текстовых данных
process_pipeline = Pipeline(model2, 'tokenize', Pipeline.DEFAULT, Pipeline.DEFAULT, 'conllu')
#df['udpipe'] = df['text'].apply(lambda x: UDPipe.process(process_pipeline, text=x))

# %%
df['udpipe'] = df['text'].apply(lambda x: UDPipe.process(process_pipeline, text=x))

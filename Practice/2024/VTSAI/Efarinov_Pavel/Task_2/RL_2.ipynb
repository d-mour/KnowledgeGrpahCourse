# %% [markdown]
# ## Стратегии обучения RL
#
# В контексте обучения с подкреплением (Reinforcement Learning, RL), стратегии обучения модели определяют, каким образом агент исследует окружение и выбирает действия для максимизации награды. Эти стратегии разделяются на Exploration (исследование) и Exploitation (использование) и направлены на достижение баланса между изучением новых стратегий и максимизацией текущих знаний.
# В обучении с подкреплением присутствует баланс между Exploration и Exploitation. Exploration включает в себя стратегии, направленные на изучение новых действий или состояний, чтобы расширить базу знаний. Exploitation, наоборот, использует текущие знания для выбора оптимальных действий и максимизации награды. Нахождение оптимального баланса между Exploration и Exploitation - ключевой аспект в достижении успешных стратегий обучения с подкреплением.
# В данной работе мы рассмотрим различные стратегии и их влияние на обучение агента с использованием библиотек Gymnasium и Stable-Baseline3.

# %% [markdown]
# ### Подготовка среды и библиотек
#
# Установим необходимые библиотеки и создадим среду CartPole для экспериментов

# %%
# !pip install gymnasium[accept-rom-license]
# !pip install swig # требуется для сборки box2d
# !pip install gymnasium[box2d]
# !pip install gymnasium[mujoco]
# !pip install stable-baselines3
# !pip install PyVirtualDisplay
# !sudo apt-get install xvfb
# Out:
# Collecting gymnasium[accept-rom-license]
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[accept-rom-license])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (4.66.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 21.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2023.11.17)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=b37a16f4d6d1d61b650d4cde7d77271dce6519d8d3a8b30877c4301c57d7e0b5
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2 farama-notifications-0.0.4 gymnasium-0.29.1
# Collecting swig
#   Downloading swig-4.1.1.post1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.3 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1.post1
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.1.1.post1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373078 sha256=5ad63c78b9509399d5b39ff8ce0f416bb9bf099ef3877c32ebe50f5848d6b79b
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Collecting mujoco>=2.3.3 (from gymnasium[mujoco])
#   Downloading mujoco-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[mujoco]) (2.31.6)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (9.4.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (1.6.0)
# Collecting glfw (from mujoco>=2.3.3->gymnasium[mujoco])
#   Downloading glfw-2.6.4-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco>=2.3.3->gymnasium[mujoco]) (3.1.7)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (6.1.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=2.3.3->gymnasium[mujoco]) (3.17.0)
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.6.4 mujoco-3.1.1
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 655.3 kB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.2.1
# Collecting PyVirtualDisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: PyVirtualDisplay
# Successfully installed PyVirtualDisplay-3.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 29 not upgraded.
# Need to get 7,816 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.7 [28.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.7 [865 kB]
# Fetched 7,816 kB in 2s (3,399 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 9.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.7_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.7) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.7_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.7) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.7) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.7) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link

# %%
import gymnasium as gym
from stable_baselines3 import SAC,DDPG
import numpy as np
import matplotlib.pyplot as plt

# %%
# Создание окружения Pendulum-v1
env_name = "InvertedDoublePendulum-v4"
env = gym.make(env_name,)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Исследование различных стратегий
# Исследуем влияние различных стратегий исследования на процесс обучения агента.

# %% [markdown]
# #### Epsilon-Greedy
#
# Epsilon-Greedy - это одна из базовых стратегий исследования в обучении с подкреплением. Агент принимает решение о выборе действия с учетом двух возможных вариантов: с высокой вероятностью (1-epsilon) агент выбирает действие с максимальной оценкой (использование), а с низкой вероятностью (epsilon) - случайное действие (исследование). Это позволяет агенту совмещать использование текущих знаний с возможностью исследования новых стратегий.

# %%
def epsilon_greedy(Q_values, epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(len(Q_values))  # Исследование
    else:
        return np.argmax(Q_values)  # Использование

# %% [markdown]
# #### Softmax
# Стратегия Softmax представляет собой метод, который преобразует оценки ценности действий в вероятности их выбора. Эта стратегия учитывает "мягкость" выбора, регулируемую параметром температуры. При высокой температуре вероятности всех действий приближаются друг к другу, что способствует более случайному выбору (исследование), в то время как при низкой температуре выбирается действие с наибольшей оценкой (использованию).

# %%
def softmax(Q_values, temperature):
    exp_values = np.exp((Q_values - np.max(Q_values)) / temperature)
    probabilities = exp_values / exp_values.sum()
    return np.random.choice(len(Q_values), p=probabilities)

# %% [markdown]
# #### UCB1 (Upper Confidence Bound)
# Стратегия UCB1 основана на оценке верхней границы для ценности действий. Агент выбирает действие, которое имеет максимальную смешанную оценку ценности и уверенность в этой оценке. Параметр, который регулирует уровень исследования, зависит от логарифма общего числа выполненных шагов.

# %%
def ucb1(Q_values, counts, total_counts):
    ucb_values = Q_values + np.sqrt((2 * np.log(total_counts)) / counts)
    return np.argmax(ucb_values)

# %% [markdown]
# Каждая из этих стратегий нацелена обеспечивать баланс между исследованием (поиск новых стратегий) и эксплуатацией (использование текущих знаний) в процессе обучения с подкреплением. Выбор конкретной стратегии зависит от характеристик задачи и предпочтений, таких как уровень исследования, требуемый для успешного обучения агента.

# %% [markdown]
# ### Тестирование различных стратегий
# На этом шаге мы рассмотрим модели реализующие некоторые из этих стратегий

# %% [markdown]
# #### DDPG
# [DDPG](https://stable-baselines3.readthedocs.io/en/master/modules/ddpg.html) использует epsilon-greedy стратегию, добавляя шум к выбранному действию во время исследования.

# %%
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import os
from stable_baselines3.common.monitor import Monitor

n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

log_dir = "/tmp/gym/DDPG/"

os.makedirs(log_dir, exist_ok=True)
env = Monitor(env, log_dir)

model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=25000, log_interval=1)
model.save("ddpg_pendulum")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# |    actor_loss      | -19.1    |
# |    critic_loss     | 2.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 701      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.69     |
# |    ep_rew_mean     | 32.8     |
# | time/              |          |
# |    episodes        | 209      |
# |    fps             | 123      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 807      |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 2.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 705      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.68     |
# |    ep_rew_mean     | 32.7     |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 122      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 810      |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 3        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 709      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.67     |
# |    ep_rew_mean     | 32.6     |
# | time/              |          |
# |    episodes        | 211      |
# |    fps             | 122      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 813      |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 2.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 712      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.66     |
# |    ep_rew_mean     | 32.5     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 122      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 816      |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 2.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 715      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.67     |
# |    ep_rew_mean     | 32.6     |
# | time/              |          |
# |    episodes        | 213      |
# |    fps             | 122      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 820      |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 2.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 718      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.66     |
# |    ep_rew_mean     | 32.5     |
# | time/              |          |
# |    episodes        | 214      |
# |    fps             | 121      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 823      |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 2.79     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 722      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.66     |
# |    ep_rew_mean     | 32.5     |
# | time/              |          |
# |    episodes        | 215      |
# |    fps             | 121      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 827      |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 2.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 725      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 121      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 830      |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 2.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 729      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 217      |
# |    fps             | 121      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 834      |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 2.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 732      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 218      |
# |    fps             | 120      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 837      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 2.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 736      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 219      |
# |    fps             | 120      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 841      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 2.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 739      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 120      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 845      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 2.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 743      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 221      |
# |    fps             | 120      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 848      |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 2.22     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 747      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 222      |
# |    fps             | 120      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 851      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 2.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 750      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 223      |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 854      |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 2.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 753      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 858      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 2.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 756      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 225      |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 862      |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 2.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 760      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 226      |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 865      |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 2.45     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 764      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 227      |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 869      |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 2.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 767      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 119      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 873      |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 2.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 771      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 229      |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 877      |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 1.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 775      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 881      |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 3.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 779      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 231      |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 884      |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 2.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 783      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 888      |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 2.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 786      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 233      |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 892      |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 2.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 790      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 234      |
# |    fps             | 118      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 896      |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 1.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 794      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 235      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 1.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 798      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 904      |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 2.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 802      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 237      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 907      |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 1.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 806      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 238      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 911      |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 2.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 809      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 239      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 914      |
# | train/             |          |
# |    actor_loss      | -19.2    |
# |    critic_loss     | 2.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 813      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 917      |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 2.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 816      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 241      |
# |    fps             | 117      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 921      |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 2.68     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 819      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 242      |
# |    fps             | 116      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 924      |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 2.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 823      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 243      |
# |    fps             | 116      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 928      |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 2.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 826      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 116      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 932      |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 1.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 830      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 245      |
# |    fps             | 116      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 936      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 2.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 834      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 246      |
# |    fps             | 116      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 940      |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 2.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 838      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 247      |
# |    fps             | 116      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 944      |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 2.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 842      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.65     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 115      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 948      |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 2.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 846      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.4     |
# | time/              |          |
# |    episodes        | 249      |
# |    fps             | 115      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 951      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 2.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 850      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 115      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 954      |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 2.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 853      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 251      |
# |    fps             | 115      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 958      |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 2.52     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 856      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 115      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 962      |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 2.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 860      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 253      |
# |    fps             | 114      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 965      |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 2.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 864      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 254      |
# |    fps             | 114      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 969      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 2.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 867      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 255      |
# |    fps             | 114      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 973      |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 1.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 871      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 114      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 977      |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 2.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 875      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.64     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 257      |
# |    fps             | 114      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 981      |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 879      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 258      |
# |    fps             | 114      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 984      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 1.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 883      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 259      |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 987      |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 2.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 886      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 990      |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 2.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 889      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 261      |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 994      |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 2.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 892      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 262      |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 998      |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 2.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 896      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 263      |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1002     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 1.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 900      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1005     |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 2.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 904      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.6      |
# |    ep_rew_mean     | 32       |
# | time/              |          |
# |    episodes        | 265      |
# |    fps             | 112      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1008     |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 1.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 907      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 266      |
# |    fps             | 112      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1012     |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 2.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 910      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 267      |
# |    fps             | 112      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1015     |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 2.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 914      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 112      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1019     |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 2.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 917      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 269      |
# |    fps             | 112      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1023     |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 1.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 921      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.6      |
# |    ep_rew_mean     | 32       |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 112      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1026     |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 2.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 925      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.59     |
# |    ep_rew_mean     | 31.9     |
# | time/              |          |
# |    episodes        | 271      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1029     |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 1.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 928      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.58     |
# |    ep_rew_mean     | 31.8     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1032     |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 1.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 931      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.58     |
# |    ep_rew_mean     | 31.8     |
# | time/              |          |
# |    episodes        | 273      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1036     |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 1.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 934      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.58     |
# |    ep_rew_mean     | 31.8     |
# | time/              |          |
# |    episodes        | 274      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1040     |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 2.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 938      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.58     |
# |    ep_rew_mean     | 31.8     |
# | time/              |          |
# |    episodes        | 275      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1044     |
# | train/             |          |
# |    actor_loss      | -19.2    |
# |    critic_loss     | 3        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 942      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.59     |
# |    ep_rew_mean     | 31.9     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1048     |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 2.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 946      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.6      |
# |    ep_rew_mean     | 32       |
# | time/              |          |
# |    episodes        | 277      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1052     |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 2.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 950      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 278      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1056     |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 1.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 954      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 279      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1060     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 1.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 958      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1063     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 1.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 962      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 281      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1066     |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 965      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 282      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1070     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 1.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 968      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 283      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1073     |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 2.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 972      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1077     |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 1.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 975      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 285      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1081     |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 2.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 979      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 286      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1084     |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 1.85     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 983      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.6      |
# |    ep_rew_mean     | 32       |
# | time/              |          |
# |    episodes        | 287      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1087     |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 2.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 986      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1091     |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 1.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 989      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 289      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1095     |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 2.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 993      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1099     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 2.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 997      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 291      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1103     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 2.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1107     |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 1.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1005     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 293      |
# |    fps             | 111      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1110     |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 1.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1009     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 294      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1114     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 1.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1012     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 295      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1118     |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 1.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1016     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1121     |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 1.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1020     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 297      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1125     |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 2.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1023     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 298      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1128     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 1.82     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1027     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 299      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1132     |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 1.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1030     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61     |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1136     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1034     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.62     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 301      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1140     |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 1.7      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1038     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.63     |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 302      |
# |    fps             | 111      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1144     |
# ...
# |    actor_loss      | -199     |
# |    critic_loss     | 7.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7816     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.3     |
# |    ep_rew_mean     | 488      |
# | time/              |          |
# |    episodes        | 511      |
# |    fps             | 116      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 8122     |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 6.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7902     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.6     |
# |    ep_rew_mean     | 490      |
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 116      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 8172     |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 6.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8024     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.3     |
# |    ep_rew_mean     | 497      |
# | time/              |          |
# |    episodes        | 513      |
# |    fps             | 117      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 8295     |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 9.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8074     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.7     |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    episodes        | 514      |
# |    fps             | 116      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 8371     |
# | train/             |          |
# |    actor_loss      | -211     |
# |    critic_loss     | 7.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8197     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.5     |
# |    ep_rew_mean     | 508      |
# | time/              |          |
# |    episodes        | 515      |
# |    fps             | 117      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 8472     |
# | train/             |          |
# |    actor_loss      | -210     |
# |    critic_loss     | 6.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8273     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.1     |
# |    ep_rew_mean     | 551      |
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 121      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 8965     |
# | train/             |          |
# |    actor_loss      | -215     |
# |    critic_loss     | 6.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.9     |
# |    ep_rew_mean     | 559      |
# | time/              |          |
# |    episodes        | 517      |
# |    fps             | 117      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 9072     |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 6.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8867     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.7     |
# |    ep_rew_mean     | 613      |
# | time/              |          |
# |    episodes        | 518      |
# |    fps             | 122      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 9681     |
# | train/             |          |
# |    actor_loss      | -234     |
# |    critic_loss     | 6.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8974     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.8     |
# |    ep_rew_mean     | 632      |
# | time/              |          |
# |    episodes        | 519      |
# |    fps             | 119      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 9906     |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 7.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9583     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.3     |
# |    ep_rew_mean     | 721      |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 127      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 10906    |
# | train/             |          |
# |    actor_loss      | -253     |
# |    critic_loss     | 7.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.1     |
# |    ep_rew_mean     | 813      |
# | time/              |          |
# |    episodes        | 521      |
# |    fps             | 127      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 11906    |
# | train/             |          |
# |    actor_loss      | -274     |
# |    critic_loss     | 6.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10808    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.6     |
# |    ep_rew_mean     | 901      |
# | time/              |          |
# |    episodes        | 522      |
# |    fps             | 126      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 12906    |
# | train/             |          |
# |    actor_loss      | -306     |
# |    critic_loss     | 8.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11808    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 991      |
# | time/              |          |
# |    episodes        | 523      |
# |    fps             | 127      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 13906    |
# | train/             |          |
# |    actor_loss      | -339     |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12808    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 987      |
# | time/              |          |
# |    episodes        | 524      |
# |    fps             | 119      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 13932    |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13808    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 986      |
# | time/              |          |
# |    episodes        | 525      |
# |    fps             | 119      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 13964    |
# | train/             |          |
# |    actor_loss      | -385     |
# |    critic_loss     | 24.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13834    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | 981      |
# | time/              |          |
# |    episodes        | 526      |
# |    fps             | 119      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 13987    |
# | train/             |          |
# |    actor_loss      | -388     |
# |    critic_loss     | 16.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13866    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 527      |
# |    fps             | 123      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 14531    |
# | train/             |          |
# |    actor_loss      | -389     |
# |    critic_loss     | 115      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13889    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 1.12e+03 |
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 127      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 15531    |
# | train/             |          |
# |    actor_loss      | -401     |
# |    critic_loss     | 35.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14433    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 529      |
# |    fps             | 126      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 16531    |
# | train/             |          |
# |    actor_loss      | -423     |
# |    critic_loss     | 29       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15433    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | 1.27e+03 |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 125      |
# |    time_elapsed    | 137      |
# |    total_timesteps | 17276    |
# | train/             |          |
# |    actor_loss      | -452     |
# |    critic_loss     | 33.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16433    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 1.32e+03 |
# | time/              |          |
# |    episodes        | 531      |
# |    fps             | 123      |
# |    time_elapsed    | 144      |
# |    total_timesteps | 17836    |
# | train/             |          |
# |    actor_loss      | -479     |
# |    critic_loss     | 44       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17178    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | 1.36e+03 |
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 122      |
# |    time_elapsed    | 148      |
# |    total_timesteps | 18259    |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 46.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 533      |
# |    fps             | 126      |
# |    time_elapsed    | 152      |
# |    total_timesteps | 19259    |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 46.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | 1.53e+03 |
# | time/              |          |
# |    episodes        | 534      |
# |    fps             | 126      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 20259    |
# | train/             |          |
# |    actor_loss      | -528     |
# |    critic_loss     | 54.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 1.62e+03 |
# | time/              |          |
# |    episodes        | 535      |
# |    fps             | 125      |
# |    time_elapsed    | 168      |
# |    total_timesteps | 21259    |
# | train/             |          |
# |    actor_loss      | -554     |
# |    critic_loss     | 50.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 183      |
# |    ep_rew_mean     | 1.71e+03 |
# | time/              |          |
# |    episodes        | 536      |
# |    fps             | 126      |
# |    time_elapsed    | 176      |
# |    total_timesteps | 22259    |
# | train/             |          |
# |    actor_loss      | -578     |
# |    critic_loss     | 58.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 1.75e+03 |
# | time/              |          |
# |    episodes        | 537      |
# |    fps             | 122      |
# |    time_elapsed    | 184      |
# |    total_timesteps | 22709    |
# | train/             |          |
# |    actor_loss      | -602     |
# |    critic_loss     | 56.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 1.84e+03 |
# | time/              |          |
# |    episodes        | 538      |
# |    fps             | 125      |
# |    time_elapsed    | 188      |
# |    total_timesteps | 23709    |
# | train/             |          |
# |    actor_loss      | -617     |
# |    critic_loss     | 52.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22611    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 539      |
# |    fps             | 121      |
# |    time_elapsed    | 196      |
# |    total_timesteps | 23859    |
# | train/             |          |
# |    actor_loss      | -635     |
# |    critic_loss     | 56.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23611    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | 1.93e+03 |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 125      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 24859    |
# | train/             |          |
# |    actor_loss      | -649     |
# |    critic_loss     | 60.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23761    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 1.97e+03 |
# | time/              |          |
# |    episodes        | 541      |
# |    fps             | 123      |
# |    time_elapsed    | 205      |
# |    total_timesteps | 25322    |
# | train/             |          |
# |    actor_loss      | -663     |
# |    critic_loss     | 85.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24761    |
# ---------------------------------

# %%
import gymnasium as gym
from IPython import display
from pyvirtualdisplay import Display
from matplotlib import animation

# del model
timestamp = 250

model = DDPG.load("ddpg_pendulum")
ddpg_reward = []

d = Display()
d.start()

env = gym.make(env_name, render_mode="rgb_array")

obs, info = env.reset()

img = []
for i in range(timestamp):
    action, _states = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    ddpg_reward.append(reward)

    display.clear_output(wait=True)
    img.append(env.render())

    # if d:
        # env.reset()

dpi = 72
interval = 46 # ms

plt.figure(figsize=(img[0].shape[1]/dpi,img[0].shape[0]/dpi),dpi=dpi)
patch = plt.imshow(img[0])
plt.axis=('off')
animate = lambda i: patch.set_data(img[i])
ani = animation.FuncAnimation(plt.gcf(),animate,frames=len(img),interval=interval)
display.display(display.HTML(ani.to_jshtml()))
env.close()
ani.save('DDPG.gif', writer='imagemagick', fps=24)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img730bddae6d40464bb6818870b3a4ebc6">
#   <div class="anim-controls">
#     <input id="_anim_slider730bddae6d40464bb6818870b3a4ebc6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim730bddae6d40464bb6818870b3a4ebc6.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim730bddae6d40464bb6818870b3a4ebc6.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim730bddae6d40464bb6818870b3a4ebc6.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim730bddae6d40464bb6818870b3a4ebc6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim730bddae6d40464bb6818870b3a4ebc6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim730bddae6d40464bb6818870b3a4ebc6.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim730bddae6d40464bb6818870b3a4ebc6.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim730bddae6d40464bb6818870b3a4ebc6.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim730bddae6d40464bb6818870b3a4ebc6.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim730bddae6d40464bb6818870b3a4ebc6.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select730bddae6d40464bb6818870b3a4ebc6"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_730bddae6d40464bb6818870b3a4ebc6"
#              >
#       <label for="_anim_radio1_730bddae6d40464bb6818870b3a4ebc6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_730bddae6d40464bb6818870b3a4ebc6"
#              checked>
#       <label for="_anim_radio2_730bddae6d40464bb6818870b3a4ebc6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_730bddae6d40464bb6818870b3a4ebc6"
#              >
#       <label for="_anim_radio3_730bddae6d40464bb6818870b3a4ebc6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img730bddae6d40464bb6818870b3a4ebc6";
#     var slider_id = "_anim_slider730bddae6d40464bb6818870b3a4ebc6";
#     var loop_select_id = "_anim_loop_select730bddae6d40464bb6818870b3a4ebc6";
#     var frames = new Array(250);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAj50lE
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %% [markdown]
# #### SAC
# Стратегия исследования softmax применяется через термин энтропии в [SAC](https://stable-baselines3.readthedocs.io/en/master/modules/sac.html). Термин энтропия поощряет мягкое, вероятностное распределение действий, способствуя исследованию.

# %%
import gymnasium as gym
# Создание окружения Pendulum-v1
env = gym.make(env_name)

log_dir = "/tmp/gym/SAC/"

os.makedirs(log_dir, exist_ok=True)
env = Monitor(env, log_dir)

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=25000, log_interval=1)
model.save("sac_pendulum")
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 82.7     |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 835      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 9        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.5      |
# |    ep_rew_mean     | 68.3     |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 840      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 15       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.67     |
# |    ep_rew_mean     | 60.6     |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 756      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 20       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | 56.8     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 777      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 25       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 794      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 30       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 790      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 36       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 807      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 42       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | 52.2     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 801      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 46       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.56     |
# |    ep_rew_mean     | 50.4     |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 773      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 50       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.7      |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 788      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 57       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.82     |
# |    ep_rew_mean     | 52.7     |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 807      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.83     |
# |    ep_rew_mean     | 52.9     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 795      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 70       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.77     |
# |    ep_rew_mean     | 52.3     |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 800      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 75       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.71     |
# |    ep_rew_mean     | 51.8     |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 782      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 777      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 86       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | 52.2     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 786      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 92       |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Выходные данные были обрезаны до нескольких последних строк (5000).
# |    n_updates       | 350      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.81     |
# |    ep_rew_mean     | 52.7     |
# | time/              |          |
# |    episodes        | 79       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 459      |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 4.05     |
# |    ent_coef        | 0.899    |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 358      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.81     |
# |    ep_rew_mean     | 52.7     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 465      |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 3.56     |
# |    ent_coef        | 0.898    |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 364      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.81     |
# |    ep_rew_mean     | 52.7     |
# | time/              |          |
# |    episodes        | 81       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 471      |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 4.63     |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 370      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.8      |
# |    ep_rew_mean     | 52.6     |
# | time/              |          |
# |    episodes        | 82       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 476      |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 2.75     |
# |    ent_coef        | 0.895    |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 375      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.82     |
# |    ep_rew_mean     | 52.8     |
# | time/              |          |
# |    episodes        | 83       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 483      |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 4.64     |
# |    ent_coef        | 0.893    |
# |    ent_coef_loss   | -0.181   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 382      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.8      |
# |    ep_rew_mean     | 52.6     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 487      |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 4.03     |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | -0.187   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 386      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.82     |
# |    ep_rew_mean     | 52.8     |
# | time/              |          |
# |    episodes        | 85       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 495      |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 4.53     |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 394      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.8      |
# |    ep_rew_mean     | 52.6     |
# | time/              |          |
# |    episodes        | 86       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 499      |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 3.41     |
# |    ent_coef        | 0.889    |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 398      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.83     |
# |    ep_rew_mean     | 52.8     |
# | time/              |          |
# |    episodes        | 87       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 507      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.887    |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 406      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 518      |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 3.57     |
# |    ent_coef        | 0.884    |
# |    ent_coef_loss   | -0.199   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 417      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.87     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 89       |
# |    fps             | 74       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 522      |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 4.64     |
# |    ent_coef        | 0.883    |
# |    ent_coef_loss   | -0.196   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 421      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.87     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 528      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.881    |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 427      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.87     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 91       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 534      |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 3.87     |
# |    ent_coef        | 0.879    |
# |    ent_coef_loss   | -0.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 433      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.87     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 540      |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 4.91     |
# |    ent_coef        | 0.878    |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 439      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.94     |
# |    ep_rew_mean     | 53.8     |
# | time/              |          |
# |    episodes        | 93       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 552      |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.875    |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 451      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.91     |
# |    ep_rew_mean     | 53.7     |
# | time/              |          |
# |    episodes        | 94       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 556      |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.874    |
# |    ent_coef_loss   | -0.202   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 455      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.91     |
# |    ep_rew_mean     | 53.6     |
# | time/              |          |
# |    episodes        | 95       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 561      |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.873    |
# |    ent_coef_loss   | -0.217   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 460      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 565      |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 3.35     |
# |    ent_coef        | 0.872    |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 464      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 53.3     |
# | time/              |          |
# |    episodes        | 97       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 570      |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 4.58     |
# |    ent_coef        | 0.87     |
# |    ent_coef_loss   | -0.209   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 469      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.9      |
# |    ep_rew_mean     | 53.5     |
# | time/              |          |
# |    episodes        | 98       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 578      |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 4.33     |
# |    ent_coef        | 0.868    |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 477      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.9      |
# |    ep_rew_mean     | 53.5     |
# | time/              |          |
# |    episodes        | 99       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 584      |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 3.4      |
# |    ent_coef        | 0.867    |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.91     |
# |    ep_rew_mean     | 53.6     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 591      |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 3.28     |
# |    ent_coef        | 0.865    |
# |    ent_coef_loss   | -0.212   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 490      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 101      |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 595      |
# | train/             |          |
# |    actor_loss      | -21.2    |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.864    |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 102      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 601      |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.863    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 500      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 103      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 609      |
# | train/             |          |
# |    actor_loss      | -21      |
# |    critic_loss     | 4.06     |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 508      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 614      |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 4.74     |
# |    ent_coef        | 0.859    |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 513      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 105      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 619      |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 4.44     |
# |    ent_coef        | 0.858    |
# |    ent_coef_loss   | -0.212   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 518      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.87     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 106      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 623      |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 4.66     |
# |    ent_coef        | 0.857    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 522      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 53.3     |
# | time/              |          |
# |    episodes        | 107      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 630      |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 3.75     |
# |    ent_coef        | 0.856    |
# |    ent_coef_loss   | -0.224   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 529      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.9      |
# |    ep_rew_mean     | 53.5     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 636      |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 3.52     |
# |    ent_coef        | 0.854    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 535      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.92     |
# |    ep_rew_mean     | 53.7     |
# | time/              |          |
# |    episodes        | 109      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 642      |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 4.63     |
# |    ent_coef        | 0.853    |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 541      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.9      |
# |    ep_rew_mean     | 53.5     |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 647      |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 4.13     |
# |    ent_coef        | 0.852    |
# |    ent_coef_loss   | -0.217   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 546      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 111      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 653      |
# | train/             |          |
# |    actor_loss      | -21.8    |
# |    critic_loss     | 4.61     |
# |    ent_coef        | 0.85     |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 552      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 659      |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 4.08     |
# |    ent_coef        | 0.849    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 558      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 53.3     |
# | time/              |          |
# |    episodes        | 113      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 663      |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 2.98     |
# |    ent_coef        | 0.848    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 562      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 53.3     |
# | time/              |          |
# |    episodes        | 114      |
# |    fps             | 74       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 668      |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 3.91     |
# |    ent_coef        | 0.847    |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 567      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 115      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 672      |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 4.14     |
# |    ent_coef        | 0.846    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 571      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.85     |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 677      |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 4.36     |
# |    ent_coef        | 0.845    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 576      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.79     |
# |    ep_rew_mean     | 52.5     |
# | time/              |          |
# |    episodes        | 117      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 681      |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 3.14     |
# |    ent_coef        | 0.844    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 580      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.77     |
# |    ep_rew_mean     | 52.3     |
# | time/              |          |
# |    episodes        | 118      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 685      |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 4.56     |
# |    ent_coef        | 0.843    |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 584      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.76     |
# |    ep_rew_mean     | 52.2     |
# | time/              |          |
# |    episodes        | 119      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 691      |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.842    |
# |    ent_coef_loss   | -0.253   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 590      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.61     |
# |    ep_rew_mean     | 50.8     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 696      |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 4.1      |
# |    ent_coef        | 0.84     |
# |    ent_coef_loss   | -0.247   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 595      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.64     |
# |    ep_rew_mean     | 51.1     |
# | time/              |          |
# |    episodes        | 121      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 703      |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 3.02     |
# |    ent_coef        | 0.839    |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 602      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.66     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 122      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 710      |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 3.44     |
# |    ent_coef        | 0.837    |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 609      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.67     |
# |    ep_rew_mean     | 51.4     |
# | time/              |          |
# |    episodes        | 123      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 715      |
# | train/             |          |
# |    actor_loss      | -24.6    |
# |    critic_loss     | 4.56     |
# |    ent_coef        | 0.836    |
# |    ent_coef_loss   | -0.251   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 614      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.68     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 722      |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 4.65     |
# |    ent_coef        | 0.835    |
# |    ent_coef_loss   | -0.244   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 621      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.7      |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 125      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 729      |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 3.71     |
# |    ent_coef        | 0.833    |
# |    ent_coef_loss   | -0.218   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 628      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.66     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 126      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 734      |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 4.01     |
# |    ent_coef        | 0.832    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 633      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.66     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 127      |
# |    fps             | 74       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 742      |
# | train/             |          |
# |    actor_loss      | -25      |
# |    critic_loss     | 4.45     |
# |    ent_coef        | 0.83     |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 641      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.66     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 748      |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 3.69     |
# |    ent_coef        | 0.829    |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 647      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.68     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 129      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 756      |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 2.93     |
# |    ent_coef        | 0.827    |
# |    ent_coef_loss   | -0.226   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 655      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.7      |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 765      |
# | train/             |          |
# |    actor_loss      | -25.2    |
# |    critic_loss     | 3.88     |
# |    ent_coef        | 0.826    |
# |    ent_coef_loss   | -0.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 664      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.67     |
# |    ep_rew_mean     | 51.4     |
# | time/              |          |
# |    episodes        | 131      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 770      |
# | train/             |          |
# |    actor_loss      | -25.7    |
# |    critic_loss     | 4.44     |
# |    ent_coef        | 0.825    |
# |    ent_coef_loss   | -0.222   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 669      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.67     |
# |    ep_rew_mean     | 51.4     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 775      |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 3.82     |
# |    ent_coef        | 0.824    |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 674      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.7      |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 133      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 784      |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 4.01     |
# |    ent_coef        | 0.822    |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 683      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.74     |
# |    ep_rew_mean     | 52.1     |
# | time/              |          |
# |    episodes        | 134      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 793      |
# | train/             |          |
# |    actor_loss      | -25.8    |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.82     |
# |    ent_coef_loss   | -0.226   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 692      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.78     |
# |    ep_rew_mean     | 52.4     |
# | time/              |          |
# |    episodes        | 135      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 802      |
# | train/             |          |
# |    actor_loss      | -25.4    |
# |    critic_loss     | 6.61     |
# |    ent_coef        | 0.818    |
# |    ent_coef_loss   | -0.208   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 701      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.8      |
# |    ep_rew_mean     | 52.6     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 74       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 809      |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 5.15     |
# |    ent_coef        | 0.817    |
# |    ent_coef_loss   | -0.244   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 708      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.85     |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 137      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 818      |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 4.48     |
# |    ent_coef        | 0.815    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 717      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.95     |
# |    ep_rew_mean     | 54       |
# | time/              |          |
# |    episodes        | 138      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 833      |
# | train/             |          |
# |    actor_loss      | -26.8    |
# |    critic_loss     | 4.45     |
# |    ent_coef        | 0.812    |
# |    ent_coef_loss   | -0.227   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 732      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 139      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 839      |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 5.39     |
# |    ent_coef        | 0.811    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 738      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 846      |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 7.4      |
# |    ent_coef        | 0.81     |
# |    ent_coef_loss   | -0.233   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 745      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 141      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 851      |
# | train/             |          |
# |    actor_loss      | -26.6    |
# |    critic_loss     | 3.94     |
# |    ent_coef        | 0.809    |
# |    ent_coef_loss   | -0.235   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 750      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 142      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 857      |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 3.74     |
# |    ent_coef        | 0.808    |
# |    ent_coef_loss   | -0.283   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 756      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.03     |
# |    ep_rew_mean     | 54.8     |
# | time/              |          |
# |    episodes        | 143      |
# |    fps             | 74       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 864      |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.806    |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 763      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.07     |
# |    ep_rew_mean     | 55.1     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 73       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 873      |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 6.89     |
# |    ent_coef        | 0.805    |
# |    ent_coef_loss   | -0.227   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 772      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 55.4     |
# | time/              |          |
# |    episodes        | 145      |
# |    fps             | 73       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 880      |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 3.94     |
# |    ent_coef        | 0.803    |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 779      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 55.9     |
# | time/              |          |
# |    episodes        | 146      |
# |    fps             | 73       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 889      |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 4.87     |
# |    ent_coef        | 0.802    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 788      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 56.1     |
# | time/              |          |
# |    episodes        | 147      |
# |    fps             | 73       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 895      |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 5.72     |
# |    ent_coef        | 0.801    |
# |    ent_coef_loss   | -0.275   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 794      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.21     |
# |    ep_rew_mean     | 56.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 73       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 905      |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 4.88     |
# |    ent_coef        | 0.799    |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 804      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | 56.8     |
# | time/              |          |
# |    episodes        | 149      |
# |    fps             | 73       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 913      |
# | train/             |          |
# |    actor_loss      | -28.6    |
# |    critic_loss     | 7.73     |
# |    ent_coef        | 0.797    |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 812      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 57.3     |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 73       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 923      |
# | train/             |          |
# |    actor_loss      | -30.6    |
# |    critic_loss     | 4.67     |
# |    ent_coef        | 0.796    |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 822      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.34     |
# |    ep_rew_mean     | 57.6     |
# | time/              |          |
# |    episodes        | 151      |
# |    fps             | 73       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 937      |
# | train/             |          |
# |    actor_loss      | -29.5    |
# ...
# |    fps             | 71       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 7137     |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 5.47     |
# |    ent_coef        | 0.834    |
# |    ent_coef_loss   | 0.00678  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7036     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | 455      |
# | time/              |          |
# |    episodes        | 346      |
# |    fps             | 71       |
# |    time_elapsed    | 101      |
# |    total_timesteps | 7237     |
# | train/             |          |
# |    actor_loss      | -157     |
# |    critic_loss     | 7.81     |
# |    ent_coef        | 0.84     |
# |    ent_coef_loss   | 0.0113   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7136     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 462      |
# | time/              |          |
# |    episodes        | 347      |
# |    fps             | 71       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 7329     |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 8.27     |
# |    ent_coef        | 0.845    |
# |    ent_coef_loss   | 0.0218   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7228     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 465      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 71       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 7390     |
# | train/             |          |
# |    actor_loss      | -162     |
# |    critic_loss     | 9.94     |
# |    ent_coef        | 0.85     |
# |    ent_coef_loss   | 0.00515  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7289     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.6     |
# |    ep_rew_mean     | 480      |
# | time/              |          |
# |    episodes        | 349      |
# |    fps             | 71       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 7563     |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.852    |
# |    ent_coef_loss   | 0.0038   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7462     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.8     |
# |    ep_rew_mean     | 491      |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 71       |
# |    time_elapsed    | 107      |
# |    total_timesteps | 7704     |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 8.46     |
# |    ent_coef        | 0.862    |
# |    ent_coef_loss   | 0.00509  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7603     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.4     |
# |    ep_rew_mean     | 497      |
# | time/              |          |
# |    episodes        | 351      |
# |    fps             | 71       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 7775     |
# | train/             |          |
# |    actor_loss      | -176     |
# |    critic_loss     | 9.84     |
# |    ent_coef        | 0.866    |
# |    ent_coef_loss   | -0.00719 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7674     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55       |
# |    ep_rew_mean     | 513      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 71       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 7962     |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 6.74     |
# |    ent_coef        | 0.883    |
# |    ent_coef_loss   | 0.000904 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7861     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58       |
# |    ep_rew_mean     | 541      |
# | time/              |          |
# |    episodes        | 353      |
# |    fps             | 71       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 8286     |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.919    |
# |    ent_coef_loss   | 0.00809  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8185     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.1     |
# |    ep_rew_mean     | 551      |
# | time/              |          |
# |    episodes        | 354      |
# |    fps             | 71       |
# |    time_elapsed    | 116      |
# |    total_timesteps | 8413     |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.935    |
# |    ent_coef_loss   | 0.0047   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8312     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.9     |
# |    ep_rew_mean     | 567      |
# | time/              |          |
# |    episodes        | 355      |
# |    fps             | 71       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 8607     |
# | train/             |          |
# |    actor_loss      | -196     |
# |    critic_loss     | 6.56     |
# |    ent_coef        | 0.96     |
# |    ent_coef_loss   | 0.00097  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8506     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64       |
# |    ep_rew_mean     | 597      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 71       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 8944     |
# | train/             |          |
# |    actor_loss      | -202     |
# |    critic_loss     | 9.4      |
# |    ent_coef        | 1        |
# |    ent_coef_loss   | 0.000184 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8843     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | 688      |
# | time/              |          |
# |    episodes        | 357      |
# |    fps             | 71       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 9944     |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 9.36     |
# |    ent_coef        | 1.13     |
# |    ent_coef_loss   | -0.0191  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9843     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | 780      |
# | time/              |          |
# |    episodes        | 358      |
# |    fps             | 72       |
# |    time_elapsed    | 151      |
# |    total_timesteps | 10944    |
# | train/             |          |
# |    actor_loss      | -256     |
# |    critic_loss     | 9.37     |
# |    ent_coef        | 1.21     |
# |    ent_coef_loss   | -0.0187  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.2     |
# |    ep_rew_mean     | 870      |
# | time/              |          |
# |    episodes        | 359      |
# |    fps             | 72       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 11944    |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 1.23     |
# |    ent_coef_loss   | -0.0118  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 961      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 72       |
# |    time_elapsed    | 179      |
# |    total_timesteps | 12944    |
# | train/             |          |
# |    actor_loss      | -294     |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 1.24     |
# |    ent_coef_loss   | -0.0241  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | 1.05e+03 |
# | time/              |          |
# |    episodes        | 361      |
# |    fps             | 72       |
# |    time_elapsed    | 192      |
# |    total_timesteps | 13944    |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 7.69     |
# |    ent_coef        | 1.23     |
# |    ent_coef_loss   | 0.0188   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 362      |
# |    fps             | 72       |
# |    time_elapsed    | 206      |
# |    total_timesteps | 14944    |
# | train/             |          |
# |    actor_loss      | -335     |
# |    critic_loss     | 7.8      |
# |    ent_coef        | 1.2      |
# |    ent_coef_loss   | 0.0202   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 363      |
# |    fps             | 72       |
# |    time_elapsed    | 219      |
# |    total_timesteps | 15944    |
# | train/             |          |
# |    actor_loss      | -362     |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 1.12     |
# |    ent_coef_loss   | -0.00781 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 1.32e+03 |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 72       |
# |    time_elapsed    | 233      |
# |    total_timesteps | 16944    |
# | train/             |          |
# |    actor_loss      | -401     |
# |    critic_loss     | 32.1     |
# |    ent_coef        | 1.06     |
# |    ent_coef_loss   | 0.00356  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 1.42e+03 |
# | time/              |          |
# |    episodes        | 365      |
# |    fps             | 72       |
# |    time_elapsed    | 247      |
# |    total_timesteps | 17944    |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 1.03     |
# |    ent_coef_loss   | 0.00515  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 161      |
# |    ep_rew_mean     | 1.51e+03 |
# | time/              |          |
# |    episodes        | 366      |
# |    fps             | 72       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 18944    |
# | train/             |          |
# |    actor_loss      | -422     |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 1.01     |
# |    ent_coef_loss   | 0.000429 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 1.6e+03  |
# | time/              |          |
# |    episodes        | 367      |
# |    fps             | 72       |
# |    time_elapsed    | 274      |
# |    total_timesteps | 19944    |
# | train/             |          |
# |    actor_loss      | -425     |
# |    critic_loss     | 5.57     |
# |    ent_coef        | 0.965    |
# |    ent_coef_loss   | 0.000282 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | 1.69e+03 |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 72       |
# |    time_elapsed    | 288      |
# |    total_timesteps | 20944    |
# | train/             |          |
# |    actor_loss      | -448     |
# |    critic_loss     | 9.43     |
# |    ent_coef        | 0.959    |
# |    ent_coef_loss   | -0.00508 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | 1.78e+03 |
# | time/              |          |
# |    episodes        | 369      |
# |    fps             | 72       |
# |    time_elapsed    | 302      |
# |    total_timesteps | 21944    |
# | train/             |          |
# |    actor_loss      | -469     |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.00282 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 72       |
# |    time_elapsed    | 315      |
# |    total_timesteps | 22944    |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.887    |
# |    ent_coef_loss   | 0.000677 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 371      |
# |    fps             | 72       |
# |    time_elapsed    | 329      |
# |    total_timesteps | 23944    |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 23.8     |
# |    ent_coef        | 0.858    |
# |    ent_coef_loss   | -0.00801 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 220      |
# |    ep_rew_mean     | 2.05e+03 |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 72       |
# |    time_elapsed    | 342      |
# |    total_timesteps | 24944    |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 7.78     |
# |    ent_coef        | 0.851    |
# |    ent_coef_loss   | -0.0204  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24843    |
# ---------------------------------

# %%
import gymnasium as gym
del model

model = SAC.load("sac_pendulum")
sac_reward = []

d = Display()
d.start()

env = gym.make(env_name, render_mode='rgb_array')

obs, info = env.reset()

img = []
for i in range(timestamp):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    sac_reward.append(reward)

    display.clear_output(wait=True)
    img.append(env.render())

    # if d:
        # env.reset()

dpi = 72
interval = 46 # ms

plt.figure(figsize=(img[0].shape[1]/dpi,img[0].shape[0]/dpi),dpi=dpi)
patch = plt.imshow(img[0])
plt.axis=('off')
animate = lambda i: patch.set_data(img[i])
ani = animation.FuncAnimation(plt.gcf(),animate,frames=len(img),interval=interval)
display.display(display.HTML(ani.to_jshtml()))
env.close()
ani.save('SAC.gif', writer='imagemagick', fps=24)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb1ba880a4f914bad95cf44c20e7c43dc">
#   <div class="anim-controls">
#     <input id="_anim_sliderb1ba880a4f914bad95cf44c20e7c43dc" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb1ba880a4f914bad95cf44c20e7c43dc.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animb1ba880a4f914bad95cf44c20e7c43dc.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectb1ba880a4f914bad95cf44c20e7c43dc"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b1ba880a4f914bad95cf44c20e7c43dc"
#              >
#       <label for="_anim_radio1_b1ba880a4f914bad95cf44c20e7c43dc">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b1ba880a4f914bad95cf44c20e7c43dc"
#              checked>
#       <label for="_anim_radio2_b1ba880a4f914bad95cf44c20e7c43dc">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b1ba880a4f914bad95cf44c20e7c43dc"
#              >
#       <label for="_anim_radio3_b1ba880a4f914bad95cf44c20e7c43dc">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb1ba880a4f914bad95cf44c20e7c43dc";
#     var slider_id = "_anim_sliderb1ba880a4f914bad95cf44c20e7c43dc";
#     var loop_select_id = "_anim_loop_selectb1ba880a4f914bad95cf44c20e7c43dc";
#     var frames = new Array(250);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAg6klE
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %% [markdown]
# #### Сравнение
#
# Примеры выше демонстрируют возможность решить одну и ту же задачу с помощью двух моделей различных моделей, которые используют расмотренные ранее стратегии. Далее построим график, который отображает процесс обучения этих моделей.

# %%
from stable_baselines3.common.results_plotter import load_results, ts2xy

def plot_results(total = None):
    x, y = ts2xy(load_results("/tmp/gym/DDPG/"), "timesteps")
    # Truncate x
    if total is None:
      x = x[len(x) - len(y) :]
    else:
      filter_x = x < total
      x = x[filter_x]
      y = y[0:len(x)]
    plt.plot(x, y, label="DDPG")

    x, y = ts2xy(load_results("/tmp/gym/SAC/"), "timesteps")
    # Truncate x
    if total is None:
      x = x[len(x) - len(y) :]
    else:
      filter_x = x < total
      x = x[filter_x]
      y = y[0:len(x)]
    plt.plot(x, y, label="SAC")

    plt.xlabel("Number of Episodes")
    plt.ylabel("Rewards")
    plt.title("DDPG vs SAC")
    plt.legend()
    plt.show()
plot_results()
plot_results(total=3000)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Исследование влияния Learning Rate
#
# Learning Rate (LR) является одним из ключевых гиперпараметров алгоритмов обучения с подкреплением, включая алгоритм Soft Actor-Critic (SAC). Этот параметр оказывает значительное влияние на эффективность обучения и способность алгоритма адаптироваться к изменениям в окружающей среде.
#
# Learning Rate определяет размер шага, с которым модель обновляет свои веса в процессе градиентного спуска. В случае SAC, который является алгоритмом глубокого обучения, правильный выбор Learning Rate может определить успешность сходимости модели и её способность обучаться оптимальной стратегии.
#
# В данном блоке мы рассмотрим важность параметра Learning Rate для алгоритма SAC, исследуем, как различные значения этого параметра могут влиять на процесс обучения. Далее мы представим код, который демонстрирует обучение модели SAC при различных значениях Learning Rate, а также проанализируем графики, позволяющие визуально оценить влияние этого параметра.

# %%
import gymnasium as gym
# Создание среды Pendulum-1 из Gym

# Список learning rate, которые вы хотите проверить
learning_rates = [0.0001, 0.001, 0.01]
sac_reward = {0.0001:[],0.001:[],0.01:[]}

# Итерация по разным learning rates
for lr in learning_rates:
    env = gym.make(env_name)
    log_dir = f"/tmp/gym/SAC_LR/{lr}/"
    os.makedirs(log_dir, exist_ok=True)
    env = Monitor(env, log_dir)

    # Создание модели SAC с заданным learning rate
    model = SAC('MlpPolicy', env, learning_rate=lr, verbose=1)

    # Обучение модели
    model.learn(total_timesteps=10000)

    # Сохранение обученной модели
    model.save(f'sac_pendulum_lr_{lr}')
    obs, info = env.reset()
    for i in range(50):
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        sac_reward[lr].append(reward)
        if terminated or truncated:
            obs, info = env.reset()

    # Закрытие среды
    env.close()
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.25     |
# |    ep_rew_mean     | 66       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1798     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 29       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.88     |
# |    ep_rew_mean     | 62.5     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1661     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 55       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.08     |
# |    ep_rew_mean     | 64.6     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 1636     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 85       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.94     |
# |    ep_rew_mean     | 63.2     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 539      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 111      |
# | train/             |          |
# |    actor_loss      | -1.03    |
# |    critic_loss     | 85.5     |
# |    ent_coef        | 0.999    |
# |    ent_coef_loss   | -0.00152 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.6      |
# |    ep_rew_mean     | 60.1     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 258      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 74.4     |
# |    ent_coef        | 0.997    |
# |    ent_coef_loss   | -0.00504 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.58     |
# |    ep_rew_mean     | 60       |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 183      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 158      |
# | train/             |          |
# |    actor_loss      | -2.91    |
# |    critic_loss     | 59.1     |
# |    ent_coef        | 0.994    |
# |    ent_coef_loss   | -0.00942 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.54     |
# |    ep_rew_mean     | 59.5     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 154      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 183      |
# | train/             |          |
# |    actor_loss      | -4.45    |
# |    critic_loss     | 42.4     |
# |    ent_coef        | 0.992    |
# |    ent_coef_loss   | -0.0136  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 82       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.34     |
# |    ep_rew_mean     | 57.7     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 131      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 203      |
# | train/             |          |
# |    actor_loss      | -5.65    |
# |    critic_loss     | 37.2     |
# |    ent_coef        | 0.99     |
# |    ent_coef_loss   | -0.017   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 102      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.28     |
# |    ep_rew_mean     | 57.1     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 117      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 226      |
# | train/             |          |
# |    actor_loss      | -7.16    |
# |    critic_loss     | 31.3     |
# |    ent_coef        | 0.988    |
# |    ent_coef_loss   | -0.0209  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 125      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 59.4     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 103      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 261      |
# | train/             |          |
# |    actor_loss      | -8.45    |
# |    critic_loss     | 31.7     |
# |    ent_coef        | 0.984    |
# |    ent_coef_loss   | -0.0267  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 160      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.45     |
# |    ep_rew_mean     | 58.7     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 96       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 284      |
# | train/             |          |
# |    actor_loss      | -9.73    |
# |    critic_loss     | 28.6     |
# |    ent_coef        | 0.982    |
# |    ent_coef_loss   | -0.0305  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 183      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.46     |
# |    ep_rew_mean     | 58.8     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 91       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 310      |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 31.4     |
# |    ent_coef        | 0.979    |
# |    ent_coef_loss   | -0.0352  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 209      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.48     |
# |    ep_rew_mean     | 59       |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 87       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 337      |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 31.1     |
# |    ent_coef        | 0.977    |
# |    ent_coef_loss   | -0.0396  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 236      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.5      |
# |    ep_rew_mean     | 59.2     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 83       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 364      |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 32.8     |
# |    ent_coef        | 0.974    |
# |    ent_coef_loss   | -0.0443  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 263      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.52     |
# |    ep_rew_mean     | 59.3     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 81       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 391      |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 28.5     |
# |    ent_coef        | 0.972    |
# |    ent_coef_loss   | -0.0485  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 290      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.44     |
# |    ep_rew_mean     | 58.6     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 81       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 412      |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 28.5     |
# |    ent_coef        | 0.969    |
# |    ent_coef_loss   | -0.0523  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 311      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 58.1     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 80       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 434      |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 30.1     |
# |    ent_coef        | 0.967    |
# |    ent_coef_loss   | -0.0556  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 333      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 57.5     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 80       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 455      |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 27.2     |
# |    ent_coef        | 0.965    |
# |    ent_coef_loss   | -0.0598  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 354      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 57.4     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 80       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 480      |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 26.3     |
# |    ent_coef        | 0.963    |
# |    ent_coef_loss   | -0.0632  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 379      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | 56.8     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 79       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 500      |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 26.7     |
# |    ent_coef        | 0.961    |
# |    ent_coef_loss   | -0.0644  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 399      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 56.1     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 79       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 518      |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 24.1     |
# |    ent_coef        | 0.959    |
# |    ent_coef_loss   | -0.0679  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 417      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 55.5     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 79       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 537      |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 22       |
# |    ent_coef        | 0.958    |
# |    ent_coef_loss   | -0.0706  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 436      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.08     |
# |    ep_rew_mean     | 55.2     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 78       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 559      |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.956    |
# |    ent_coef_loss   | -0.0712  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 458      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 54.5     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 78       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.954    |
# |    ent_coef_loss   | -0.0736  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 475      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 78       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 597      |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 18.8     |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.0769  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 496      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 78       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 615      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 20.7     |
# |    ent_coef        | 0.951    |
# |    ent_coef_loss   | -0.079   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 514      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 78       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 641      |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 19.3     |
# |    ent_coef        | 0.948    |
# |    ent_coef_loss   | -0.076   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 540      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 78       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 658      |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 19.2     |
# |    ent_coef        | 0.947    |
# |    ent_coef_loss   | -0.0774  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 557      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.65     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 77       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 676      |
# | train/             |          |
# |    actor_loss      | -21.2    |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.945    |
# |    ent_coef_loss   | -0.0821  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 575      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.64     |
# |    ep_rew_mean     | 51.2     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 77       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 696      |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 18.1     |
# |    ent_coef        | 0.944    |
# |    ent_coef_loss   | -0.0865  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 595      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.62     |
# |    ep_rew_mean     | 51       |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 77       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.942    |
# |    ent_coef_loss   | -0.091   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 619      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.58     |
# |    ep_rew_mean     | 50.6     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 77       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 741      |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 18.4     |
# |    ent_coef        | 0.94     |
# |    ent_coef_loss   | -0.0964  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 640      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.57     |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 77       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 760      |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.0979  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 659      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.54     |
# |    ep_rew_mean     | 50.3     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 77       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 780      |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.936    |
# |    ent_coef_loss   | -0.0981  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 679      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.39     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 77       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.935    |
# |    ent_coef_loss   | -0.105   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.41     |
# |    ep_rew_mean     | 49.1     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 77       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 825      |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 724      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.35     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 77       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 845      |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.93     |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 744      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.29     |
# |    ep_rew_mean     | 47.9     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 77       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 866      |
# | train/             |          |
# |    actor_loss      | -25.5    |
# |    critic_loss     | 17.9     |
# |    ent_coef        | 0.928    |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 765      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.31     |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 77       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 895      |
# | train/             |          |
# |    actor_loss      | -26.6    |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.926    |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 794      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.32     |
# |    ep_rew_mean     | 48.2     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 77       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 923      |
# | train/             |          |
# |    actor_loss      | -25.7    |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.923    |
# |    ent_coef_loss   | -0.118   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 822      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.42     |
# |    ep_rew_mean     | 49.1     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 77       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 954      |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.921    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 853      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.48     |
# |    ep_rew_mean     | 49.7     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 77       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 982      |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.918    |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 881      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.5      |
# |    ep_rew_mean     | 49.9     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 77       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1005     |
# | train/             |          |
# |    actor_loss      | -28.2    |
# |    critic_loss     | 11       |
# |    ent_coef        | 0.916    |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 904      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.7      |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 77       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1050     |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 9        |
# |    ent_coef        | 0.913    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 949      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.82     |
# |    ep_rew_mean     | 52.9     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 76       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1082     |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.911    |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 981      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 54.3     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 76       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1115     |
# | train/             |          |
# |    actor_loss      | -30.8    |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.908    |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1014     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.06     |
# |    ep_rew_mean     | 55.1     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 76       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1143     |
# | train/             |          |
# |    actor_loss      | -30.5    |
# |    critic_loss     | 21.1     |
# |    ent_coef        | 0.907    |
# |    ent_coef_loss   | -0.0976  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1042     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.18     |
# |    ep_rew_mean     | 56.2     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 75       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1177     |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.905    |
# |    ent_coef_loss   | -0.0825  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1076     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.45     |
# |    ep_rew_mean     | 58.8     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 74       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1221     |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.902    |
# |    ent_coef_loss   | -0.0942  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1120     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.66     |
# |    ep_rew_mean     | 60.7     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 73       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1263     |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.9      |
# |    ent_coef_loss   | -0.085   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1162     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.9      |
# |    ep_rew_mean     | 63       |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 73       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1305     |
# | train/             |          |
# |    actor_loss      | -35.1    |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.898    |
# |    ent_coef_loss   | -0.0886  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1204     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.06     |
# |    ep_rew_mean     | 64.5     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 73       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1347     |
# | train/             |          |
# |    actor_loss      | -36.7    |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.895    |
# |    ent_coef_loss   | -0.0834  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1246     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.3      |
# |    ep_rew_mean     | 66.7     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 73       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1388     |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 16.7     |
# |    ent_coef        | 0.893    |
# |    ent_coef_loss   | -0.0717  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1287     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.48     |
# |    ep_rew_mean     | 68.4     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 73       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1424     |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | -0.0823  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1323     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.69     |
# |    ep_rew_mean     | 70.3     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 73       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1465     |
# | train/             |          |
# |    actor_loss      | -38.1    |
# |    critic_loss     | 17.9     |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1364     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.85     |
# |    ep_rew_mean     | 71.8     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 73       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1505     |
# | train/             |          |
# |    actor_loss      | -40.7    |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.0674  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1404     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.02     |
# |    ep_rew_mean     | 73.4     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 73       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1543     |
# | train/             |          |
# |    actor_loss      | -39.6    |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.886    |
# |    ent_coef_loss   | -0.0871  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1442     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.33     |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 73       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1593     |
# | train/             |          |
# |    actor_loss      | -41.5    |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.884    |
# |    ent_coef_loss   | -0.0791  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1492     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.56     |
# |    ep_rew_mean     | 78.5     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 73       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1636     |
# | train/             |          |
# |    actor_loss      | -43.3    |
# |    critic_loss     | 22.9     |
# |    ent_coef        | 0.882    |
# |    ent_coef_loss   | -0.0663  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1535     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.79     |
# |    ep_rew_mean     | 80.6     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 73       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1679     |
# | train/             |          |
# |    actor_loss      | -43.6    |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.88     |
# |    ent_coef_loss   | -0.0825  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1578     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 82.5     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 73       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1724     |
# | train/             |          |
# |    actor_loss      | -44.9    |
# |    critic_loss     | 22       |
# |    ent_coef        | 0.877    |
# |    ent_coef_loss   | -0.0937  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1623     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.21     |
# |    ep_rew_mean     | 84.5     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 73       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1766     |
# | train/             |          |
# |    actor_loss      | -45.3    |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.875    |
# |    ent_coef_loss   | -0.0848  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1665     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.42     |
# |    ep_rew_mean     | 86.5     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 73       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1808     |
# | train/             |          |
# |    actor_loss      | -45.6    |
# |    critic_loss     | 30.4     |
# |    ent_coef        | 0.874    |
# |    ent_coef_loss   | -0.0943  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1707     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.72     |
# |    ep_rew_mean     | 89.3     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 73       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1867     |
# | train/             |          |
# |    actor_loss      | -46.9    |
# |    critic_loss     | 21.5     |
# |    ent_coef        | 0.871    |
# |    ent_coef_loss   | -0.0766  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1766     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.86     |
# |    ep_rew_mean     | 90.6     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 73       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1909     |
# | train/             |          |
# |    actor_loss      | -48.7    |
# |    critic_loss     | 19.9     |
# |    ent_coef        | 0.869    |
# |    ent_coef_loss   | -0.0692  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.1     |
# |    ep_rew_mean     | 92.9     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 73       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1964     |
# | train/             |          |
# |    actor_loss      | -47.7    |
# |    critic_loss     | 28.3     |
# |    ent_coef        | 0.866    |
# |    ent_coef_loss   | -0.0705  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1863     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | 95.2     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 73       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2017     |
# | train/             |          |
# |    actor_loss      | -49.4    |
# |    critic_loss     | 30.1     |
# |    ent_coef        | 0.864    |
# |    ent_coef_loss   | -0.0735  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1916     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.8     |
# |    ep_rew_mean     | 99.6     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 73       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2086     |
# | train/             |          |
# |    actor_loss      | -52      |
# |    critic_loss     | 32.7     |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.0673  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1985     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 73       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 2146     |
# | train/             |          |
# |    actor_loss      | -52      |
# |    critic_loss     | 47.2     |
# |    ent_coef        | 0.859    |
# |    ent_coef_loss   | -0.092   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2045     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.3     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 72       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2213     |
# | train/             |          |
# |    actor_loss      | -54.5    |
# |    critic_loss     | 36.1     |
# |    ent_coef        | 0.856    |
# |    ent_coef_loss   | -0.0633  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2112     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.8     |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 71       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2297     |
# | train/             |          |
# |    actor_loss      | -55.8    |
# |    critic_loss     | 66.6     |
# |    ent_coef        | 0.853    |
# |    ent_coef_loss   | -0.0703  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2196     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.4     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 72       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2382     |
# | train/             |          |
# |    actor_loss      | -54      |
# |    critic_loss     | 66.3     |
# |    ent_coef        | 0.849    |
# |    ent_coef_loss   | -0.0613  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2281     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 72       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2473     |
# | train/             |          |
# |    actor_loss      | -55.1    |
# |    critic_loss     | 31.8     |
# |    ent_coef        | 0.846    |
# |    ent_coef_loss   | -0.0517  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2372     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.4     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 72       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 2563     |
# | train/             |          |
# |    actor_loss      | -57.4    |
# |    critic_loss     | 57.4     |
# |    ent_coef        | 0.843    |
# |    ent_coef_loss   | -0.0788  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2462     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.9     |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 72       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2657     |
# | train/             |          |
# |    actor_loss      | -60.9    |
# |    critic_loss     | 48.6     |
# |    ent_coef        | 0.84     |
# |    ent_coef_loss   | -0.0293  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2556     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.6     |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 72       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2769     |
# | train/             |          |
# |    actor_loss      | -60.4    |
# |    critic_loss     | 64.7     |
# |    ent_coef        | 0.836    |
# |    ent_coef_loss   | -0.0525  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2668     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.3     |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 72       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 2882     |
# | train/             |          |
# |    actor_loss      | -66.1    |
# |    critic_loss     | 56.7     |
# |    ent_coef        | 0.833    |
# |    ent_coef_loss   | -0.0597  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2781     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.9     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 72       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2977     |
# | train/             |          |
# |    actor_loss      | -68.2    |
# |    critic_loss     | 68.5     |
# |    ent_coef        | 0.831    |
# |    ent_coef_loss   | -0.0479  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2876     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.6     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 70       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 3088     |
# | train/             |          |
# |    actor_loss      | -70.5    |
# |    critic_loss     | 46       |
# |    ent_coef        | 0.828    |
# |    ent_coef_loss   | -0.0318  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2987     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.3     |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 68       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 3194     |
# | train/             |          |
# |    actor_loss      | -69.8    |
# |    critic_loss     | 51.2     |
# |    ent_coef        | 0.826    |
# |    ent_coef_loss   | -0.0381  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3093     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.7     |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 68       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 3273     |
# | train/             |          |
# |    actor_loss      | -69.6    |
# |    critic_loss     | 66.5     |
# |    ent_coef        | 0.824    |
# |    ent_coef_loss   | -0.0151  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3172     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.3     |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 69       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 3374     |
# | train/             |          |
# |    actor_loss      | -72.8    |
# |    critic_loss     | 84.6     |
# |    ent_coef        | 0.822    |
# |    ent_coef_loss   | -0.00733 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3273     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.8     |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 69       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 3474     |
# | train/             |          |
# |    actor_loss      | -78.4    |
# |    critic_loss     | 45.4     |
# |    ent_coef        | 0.821    |
# |    ent_coef_loss   | -0.00873 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3373     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | 180      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 69       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3579     |
# | train/             |          |
# |    actor_loss      | -77.4    |
# |    critic_loss     | 42.1     |
# |    ent_coef        | 0.82     |
# |    ent_coef_loss   | -0.0149  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3478     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# ...
# |    fps             | 78       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 978      |
# | train/             |          |
# |    actor_loss      | -35.7    |
# |    critic_loss     | 0.454    |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | -0.748   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 877      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.82     |
# |    ep_rew_mean     | 90.3     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 77       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1029     |
# | train/             |          |
# |    actor_loss      | -36.7    |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | 0.0155   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 928      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.1     |
# |    ep_rew_mean     | 92.6     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 75       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1092     |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 1.02     |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 991      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | 94.6     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 74       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1149     |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 1.38     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | 0.135    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1048     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.7     |
# |    ep_rew_mean     | 98.3     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 74       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1214     |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 0.491    |
# |    ent_coef        | 0.051    |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1113     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.1     |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 74       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1284     |
# | train/             |          |
# |    actor_loss      | -43.2    |
# |    critic_loss     | 0.603    |
# |    ent_coef        | 0.0563   |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1183     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.6     |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 74       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1365     |
# | train/             |          |
# |    actor_loss      | -45.1    |
# |    critic_loss     | 0.553    |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | 0.336    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1264     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.4     |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 74       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1469     |
# | train/             |          |
# |    actor_loss      | -44.3    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.083    |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1368     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.4     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 74       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1594     |
# | train/             |          |
# |    actor_loss      | -50.4    |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | 0.194    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1493     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.8     |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 75       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1759     |
# | train/             |          |
# |    actor_loss      | -56.6    |
# |    critic_loss     | 1.67     |
# |    ent_coef        | 0.133    |
# |    ent_coef_loss   | 0.109    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1658     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.8     |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 75       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1882     |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 2.93     |
# |    ent_coef        | 0.163    |
# |    ent_coef_loss   | 0.198    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1781     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.4     |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 73       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2080     |
# | train/             |          |
# |    actor_loss      | -62.6    |
# |    critic_loss     | 7.56     |
# |    ent_coef        | 0.197    |
# |    ent_coef_loss   | -0.2     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1979     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.9     |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 73       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2272     |
# | train/             |          |
# |    actor_loss      | -68.6    |
# |    critic_loss     | 2.69     |
# |    ent_coef        | 0.215    |
# |    ent_coef_loss   | 0.497    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2171     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 73       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2514     |
# | train/             |          |
# |    actor_loss      | -77.6    |
# |    critic_loss     | 2.35     |
# |    ent_coef        | 0.223    |
# |    ent_coef_loss   | 0.0375   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2413     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 73       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2749     |
# | train/             |          |
# |    actor_loss      | -80.1    |
# |    critic_loss     | 2.03     |
# |    ent_coef        | 0.244    |
# |    ent_coef_loss   | 0.135    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2648     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 72       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2999     |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.231    |
# |    ent_coef_loss   | 0.0212   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2898     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 72       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 3190     |
# | train/             |          |
# |    actor_loss      | -92.7    |
# |    critic_loss     | 2.75     |
# |    ent_coef        | 0.23     |
# |    ent_coef_loss   | -0.0165  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3089     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 72       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 3409     |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.228    |
# |    ent_coef_loss   | -0.0381  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3308     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.2     |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 73       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 3664     |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 6.85     |
# |    ent_coef        | 0.226    |
# |    ent_coef_loss   | -0.0951  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3563     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.1     |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 73       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 3804     |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 1.95     |
# |    ent_coef        | 0.278    |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3703     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.7     |
# |    ep_rew_mean     | 304      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 72       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 4011     |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 7.45     |
# |    ent_coef        | 0.237    |
# |    ent_coef_loss   | 0.011    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3910     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.3     |
# |    ep_rew_mean     | 319      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 72       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 4208     |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 1.64     |
# |    ent_coef        | 0.273    |
# |    ent_coef_loss   | 0.0209   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4107     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.2     |
# |    ep_rew_mean     | 336      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 72       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 4452     |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.226    |
# |    ent_coef_loss   | -0.148   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4351     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.1     |
# |    ep_rew_mean     | 355      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 72       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 4687     |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 3.81     |
# |    ent_coef        | 0.277    |
# |    ent_coef_loss   | -0.00884 |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4586     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.6     |
# |    ep_rew_mean     | 369      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 72       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 4888     |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 5.86     |
# |    ent_coef        | 0.235    |
# |    ent_coef_loss   | -0.00909 |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4787     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.7     |
# |    ep_rew_mean     | 388      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 72       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 5146     |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 7.19     |
# |    ent_coef        | 0.293    |
# |    ent_coef_loss   | -0.168   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5045     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | 416      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 72       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 5499     |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.487    |
# |    ent_coef_loss   | -0.202   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5398     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.2     |
# |    ep_rew_mean     | 552      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 72       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 7013     |
# | train/             |          |
# |    actor_loss      | -196     |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.0481  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6912     |
# ---------------------------------

# %% [markdown]
# Проанализировав логи обучения модели можно увидеть, что выбор параметра learning_rate влияет, например, на время обучения модели.
# Так же можно посчитать средний reward для различных значений learning_rate

# %%
print(sum(sac_reward[0.0001])/len(sac_reward[0.0001]))
print(sum(sac_reward[0.001])/len(sac_reward[0.001]))
print(sum(sac_reward[0.01])/len(sac_reward[0.01]))
# Out:
# 9.300001888906765
# 9.353651601887016
# 9.350747343708253

# %% [markdown]
# Представим результаты reward для моделей обученных с различным learning_rate на графике

# %%
def plot_lr_results(learing_rates):
    for lr in learning_rates:
      x, y = ts2xy(load_results(f"/tmp/gym/SAC_LR/{lr}"), "timesteps")
      # Truncate x
      x = x[len(x) - len(y) :]
      plt.plot(x, y, label=f"SAC, learning rate={lr}")
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title("Learning rates comparison")
    plt.legend()
    plt.show()

plot_lr_results(learning_rates)

# %% [markdown]
# Изменение параметра learning_rate при обучении алгоритма может существенно влиять на его производительность.
#
# #### Маленький learning rate:
#
# Обучение будет медленным, так как обновления весов модели будут небольшими.
# Может потребоваться больше времени для достижения сходимости.
# Существует риск застревания в локальных минимумах.
#
# #### Средний learning rate:
#
# Может оказаться хорошим компромиссом между скоростью обучения и стабильностью.
# Быстрее, чем маленький learning_rate, но может все еще требовать достаточно большое количество времени для сходимости. Требует аккуратного подбора значения.
#
# #### Большой learning rate:
# Обучение в среднем будет быстрее, так как веса модели обновляются с большими шагами.
# Может привести к нестабильному обучению, особенно если learning rate слишком велик.
# Существует риск "перепрыгивания" оптимальных значений, что может замедлить или прервать сходимость.
#
# #### Рекомендации
# Начинать с относительно небольшого learning rate и постепенно увеличивать его, наблюдая за производительностью алгоритма. Можно также попробовать методы настройки гиперпараметров, чтобы автоматически подобрать оптимальные значения learning rate.
#
# Помните, что результаты могут зависеть от конкретной задачи и структуры среды, поэтому рекомендуется проводить несколько экспериментов и внимательно анализировать результаты.

# %% [markdown]
# В данной лабораторной работе мы исследовали различные стратегии и влияние learning_rate на процесс обучения агента. Эксперименты позволяют нам понять, что различные стратегии и параметры лучше подходят для разных задач.
# В качестве самостоятельной работы вы может дополнительно провести свои эксперименты, изменяя параметры и используя различные стратегии, чтобы более глубоко понять их влияние на обучение модели. Например, попробовать использовать одну из используемых в данной работе моделей на другом окружении Gym.

# %%
# !pip install pykeen -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.3/739.3 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 35.4 MB/s eta 0:00:00

# %%
import pykeen
from pykeen.datasets import YAGO310
from pykeen.pipeline import pipeline
from pykeen.predict import predict_triples
import torch

# %%
dataset = YAGO310()

training_data = dataset.training.mapped_triples

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


pipeline_results = pipeline(
    model="TransE",  # TransE model for relation prediction
    dataset=dataset,  # Nations dataset
    training_kwargs=dict(num_epochs=20),  # Number of training epochs
    device=device
)

print(pipeline_results)
# Out:
# INFO:pykeen.datasets.base:Requesting dataset from https://github.com/TimDettmers/ConvE/raw/master/YAGO3-10.tar.gz
# INFO:pykeen.datasets.base:Extracted to /root/.data/pykeen/datasets/yago310.
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 18 entities and 0 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 18 from 5000 triples were filtered out
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 1474386446.
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 22 entities and 0 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 22 from 5000 triples were filtered out
# INFO:pykeen.pipeline.api:Using device: cuda
# Training epochs on cuda:0:   0%|          | 0/20 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/4215 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=256.
# Evaluating on cuda:0:   0%|          | 0.00/4.98k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 11.72s seconds
# PipelineResult(random_seed=1474386446, model=TransE(
#   (loss): MarginRankingLoss(
#     (margin_activation): ReLU()
#   )
#   (interaction): TransEInteraction()
#   (entity_representations): ModuleList(
#     (0): Embedding(
#       (_embeddings): Embedding(123143, 50)
#     )
#   )
#   (relation_representations): ModuleList(
#     (0): Embedding(
#       (_embeddings): Embedding(37, 50)
#     )
#   )
#   (weight_regularizers): ModuleList()
# ), training=TriplesFactory(num_entities=123143, num_relations=37, create_inverse_triples=False, num_triples=1079040, path="/root/.data/pykeen/datasets/yago310/train.txt"), training_loop=<pykeen.training.slcwa.SLCWATrainingLoop object at 0x7906664cb610>, losses=[0.6263329339055687, 0.2960702337934453, 0.2186450623267486, 0.18118191803866293, 0.15415094570297647, 0.13286300434212808, 0.11382227707057661, 0.0975008019260523, 0.08497310551159605, 0.07491116404913428, 0.06811459354110601, 0.06268899990499797, 0.05790910006347217, 0.054391318300246204, 0.051528299059431605, 0.048881314724047414, 0.04706479102408476, 0.0453575083771599, 0.044307273842862774, 0.042654583013195586], metric_results=<pykeen.evaluation.rank_based_evaluator.RankBasedMetricResults object at 0x79062fdb20e0>, train_seconds=517.4161772727966, evaluate_seconds=21.120870113372803, stopper=<pykeen.stoppers.stopper.NopStopper object at 0x7906664c95d0>, configuration={'dataset': 'yago310', 'dataset_kwargs': None, 'model': 'TransE', 'model_kwargs': {'random_seed': 1474386446, 'loss': MarginRankingLoss(
#   (margin_activation): ReLU()
# ), 'embedding_dim': 50, 'scoring_fct_norm': 1, 'entity_initializer': <function xavier_uniform_ at 0x790686339480>, 'entity_constrainer': <function normalize at 0x7906907e5f30>, 'relation_initializer': <pykeen.utils.compose object at 0x790686332200>, 'relation_constrainer': None, 'regularizer': None, 'regularizer_kwargs': None}, 'loss_kwargs': None, 'regularizer_kwargs': None, 'optimizer': 'Adam', 'optimizer_kwargs': {'lr': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None}, 'training_loop': 'SLCWATrainingLoop', 'training_loop_kwargs': {}, 'evaluator': 'RankBasedEvaluator', 'evaluator_kwargs': {}, 'num_epochs': 20, 'batch_size': 256, 'evaluation_kwargs': {'additional_filter_triples': {'training': {'sha512': '918a6388473487fe06f024abac78297d9aafe738d92f1185ffd861fdf6bea57c8b0f77c54ef6bad30523105c8549a20090f2c4764573572b0fa0f0a14c5de05e'}, 'validation': {'sha512': '5dfa0e3724f7b1e2aca058e41568340a8ed1c1e52b5d6f2ee98d1df5fd4f73afc7e9dce04e16e36263d19d902b1072c11add7ddc034634e4dfcb272be2634816'}}}}, metadata={}, version='1.10.1', git_hash='UNHASHED')

# %%
pack = predict_triples(model=pipeline_results.model, triples=dataset.validation)
df = pack.process(factory=pipeline_results.training).df

df.nlargest(n=10, columns="score")
# Out:
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
#       head_id                 head_label  relation_id  relation_label  \
# 1466    36670          Francesco_Carbone           21  isAffiliatedTo
# 3119    74600  Michael_Carr_(footballer)           21  isAffiliatedTo
# 3722    90202        Prvoslav_Mihajlović           21  isAffiliatedTo
# 1793    44591  Guilherme_de_Cássio_Alves           21  isAffiliatedTo
# 3664    88114              Phil_Gulliver           33        playsFor
# 4634   114530                    Vampeta           21  isAffiliatedTo
# 191      4708               Allan_Oviedo           21  isAffiliatedTo
# 2640    64484             Lassana_Diarra           21  isAffiliatedTo
# 3154    75315                Mick_Meagan           33        playsFor
# 3314    79539               Nathan_Abbey           21  isAffiliatedTo
#
#       tail_id                                  tail_label     score
# 1466      269                          A.S._Avellino_1912 -3.167139
# 3119   103818                       Stafford_Rangers_F.C. -3.373646
# 3722    34607                                   FK_Obilić -3.473298
# 1793    21577                      Clube_Atlético_Mineiro -3.622236
# 3664    99589                      Scunthorpe_United_F.C. -3.655143
# 4634   103475             Sport_Club_Corinthians_Paulista -3.687562
# 191     16407                              C.S._Herediano -3.714408
# 2640    36625               France_national_football_team -3.716438
# 3154    92798  Republic_of_Ireland_national_football_team -3.719418
# 3314    96521                     Rushden_&_Diamonds_F.C. -3.722638

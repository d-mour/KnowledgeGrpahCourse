# %% [markdown]
# # Лабораторная работа №5
# https://pykeen.readthedocs.io/en/stable/api/pykeen.datasets.Countries.html
#
# Работу выполнили:
#
# Расковалова Алёна, P4241
# Строкова Анастасия, P4240

# %% [markdown]
# ### Импорт зависимостей

# %%
# !pip install pykeen networkx matplotlib

# %%
import torch
import pykeen
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pykeen.pipeline import pipeline
from sklearn.neighbors import NearestNeighbors
from pykeen.evaluation import RankBasedEvaluator
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
# Out:
# INFO:pykeen.utils:Using opt_einsum

# %% [markdown]
# ### Создание датасета

# %%
from pykeen.datasets import Countries

# %%
dataset = Countries()
# Out:
# Downloading train.txt: 0.00B [00:00, ?B/s]
# Downloading test.txt: 0.00B [00:00, ?B/s]
# Downloading valid.txt: 0.00B [00:00, ?B/s]

# %% [markdown]
# ### Обучение модели

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
pipeline_results = pipeline(
    model="ComplEx",
    dataset=dataset,
    training_kwargs=dict(num_epochs=100),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 355207122.
# INFO:pykeen.pipeline.api:Using device: cpu
# Training epochs on cpu:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.14s seconds

# %%
model = pipeline_results.model

#plot loss
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %% [markdown]
# ### Оценка модели

# %%
# Создаем evaluator объект
evaluator = RankBasedEvaluator()

# Оценить работу модели
metrics = evaluator.evaluate(model, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.11s seconds
# Hits@1: 0.0
# Hits@3: 0.0
# Hits@5: 0.020833333333333332
# Hits@10: 0.041666666666666664
# Mean Reciprocal Rank: 0.021574536338448524

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

# Конвертируем матрицу весов в NumPy array
embedding_numpy = embedding_matrix.cpu().numpy()

# %%
#Созраняем названия сущностей в отдельной переменной
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    # Scatter plot
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    # Добавляем лейблы к точкаи на графике
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

#Количество точек которые необходимо отобразить на графике
number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
def diplay_matrix(similarity_matrix):
  # Визуализация матрицы близости
  plt.figure(figsize=(8, 8))
  plt.imshow(similarity_matrix, cmap='viridis', interpolation='nearest')
  plt.colorbar()
  plt.title('Node Similarity Matrix')
  plt.show()


# Рассчет близости между узлами
methods = [euclidean_distances,cosine_similarity,manhattan_distances]
#Узлы
nodes = [embedding_numpy[5],embedding_numpy[61],embedding_numpy[100],embedding_numpy[270]]
for method in methods:
  similarity_matrix = method(nodes)
  print(similarity_matrix)
  diplay_matrix(similarity_matrix)
# Out:
# [[ 0.       27.691042 28.678368 26.78373 ]
#  [27.691042  0.       28.227911 28.517677]
#  [28.678368 28.227911  0.       27.603205]
#  [26.78373  28.517677 27.603205  0.      ]]
# [[ 1.0000001   0.0555746  -0.03744566  0.103405  ]
#  [ 0.0555746   1.0000001  -0.03626093 -0.0478207 ]
#  [-0.03744566 -0.03626093  1.0000002  -0.00644671]
#  [ 0.103405   -0.0478207  -0.00644671  1.        ]]
# [[  0.         442.62286644 467.3479208  430.7470273 ]
#  [442.62286644   0.         450.9024394  455.76139656]
#  [467.3479208  450.9024394    0.         436.61865231]
#  [430.7470273  455.76139656 436.61865231   0.        ]]

# %%
# Выбираем случайный узел
random_node_index = 1
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       25.278864 25.342184 25.539833]]
# Индексы:[[  1   4 219 132]]
# Ближайшие соседи узла africa: ['africa', 'american_samoa', 'south_georgia', 'lithuania']
#
# Метрика:cosine
# Дистанции:[[1.7881393e-07 8.5042775e-01 8.7027204e-01 8.7534463e-01]]
# Индексы:[[  1   4 233 268]]
# Ближайшие соседи узла africa: ['africa', 'american_samoa', 'syria', 'zambia']
#
# Метрика:manhattan
# Дистанции:[[  0.         397.40863037 398.46673584 405.23632812]]
# Индексы:[[  1 219   4 233]]
# Ближайшие соседи узла africa: ['africa', 'south_georgia', 'american_samoa', 'syria']

# %%
# Еще один узел
random_node_index = 200
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       26.089764 26.091694 26.169386]]
# Индексы:[[200 107  60 145]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'indonesia', 'cyprus', 'mauritius']
#
# Метрика:cosine
# Дистанции:[[0.         0.86273885 0.8829131  0.89152586]]
# Индексы:[[200 261  60 145]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'vietnam', 'cyprus', 'mauritius']
#
# Метрика:manhattan
# Дистанции:[[  0.         414.73855591 415.18380737 418.16217041]]
# Индексы:[[200  60  11 107]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'cyprus', 'armenia', 'indonesia']

# %% [markdown]
# ### Меняем количество эпох обучения до 10

# %%
pipeline_results = pipeline(
    model="ComplEx",
    dataset=dataset,
    training_kwargs=dict(num_epochs=10),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 2975145870.
# INFO:pykeen.pipeline.api:Using device: cpu
# Training epochs on cpu:   0%|          | 0/10 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.12s seconds

# %%
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
# Создаем evaluator объект
evaluator = RankBasedEvaluator()

model2 = pipeline_results.model
# Оценить работу модели
metrics = evaluator.evaluate(model2, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.12s seconds
# Hits@1: 0.0
# Hits@3: 0.0
# Hits@5: 0.0
# Hits@10: 0.0
# Mean Reciprocal Rank: 0.015665657818317413

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

# Конвертируем матрицу весов в NumPy array
embedding_numpy = embedding_matrix.cpu().numpy()

# %%
#Созраняем названия сущностей в отдельной переменной
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    # Scatter plot
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    # Добавляем лейблы к точкаи на графике
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

#Количество точек которые необходимо отобразить на графике
number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
# Выбираем случайный узел
random_node_index = 1
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       25.81727  26.098598 26.121105]]
# Индексы:[[  1 138 129 118]]
# Ближайшие соседи узла africa: ['africa', 'malaysia', 'liberia', 'jordan']
#
# Метрика:cosine
# Дистанции:[[0.         0.84902817 0.8571751  0.8722935 ]]
# Индексы:[[  1 129 118   7]]
# Ближайшие соседи узла africa: ['africa', 'liberia', 'jordan', 'angola']
#
# Метрика:manhattan
# Дистанции:[[  0.         409.61593628 410.03390503 414.55099487]]
# Индексы:[[  1 138 134 226]]
# Ближайшие соседи узла africa: ['africa', 'malaysia', 'macau', 'sri_lanka']

# %%
# Еще один узел
random_node_index = 200
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       25.748686 25.915707 25.980019]]
# Индексы:[[200 180 217 134]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'palestine', 'south_africa', 'macau']
#
# Метрика:cosine
# Дистанции:[[0.         0.8276164  0.86080474 0.88127464]]
# Индексы:[[200 217 180 157]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'south_africa', 'palestine', 'mozambique']
#
# Метрика:manhattan
# Дистанции:[[  0.         407.3104248  409.88659668 410.04019165]]
# Индексы:[[200 180 264  24]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'palestine', 'western_asia', 'belize']

# %% [markdown]
# ### Меняем модель

# %%
pipeline_results = pipeline(
    model="HolE",
    dataset=dataset,
    training_kwargs=dict(num_epochs=50),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 88361564.
# INFO:pykeen.pipeline.api:Using device: cpu
# Training epochs on cpu:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.35s seconds

# %%
model3 = pipeline_results.model

#plot loss
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
# Создаем evaluator объект
evaluator = RankBasedEvaluator()
model3 = pipeline_results.model
# Оценить работу модели
metrics = evaluator.evaluate(model3, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.12s seconds
# Hits@1: 0.020833333333333332
# Hits@3: 0.08333333333333333
# Hits@5: 0.125
# Hits@10: 0.3333333333333333
# Mean Reciprocal Rank: 0.10945145040750504

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

# Конвертируем матрицу весов в NumPy array
embedding_numpy = embedding_matrix.cpu().numpy()

# %%
#Созраняем названия сущностей в отдельной переменной
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    # Scatter plot
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    # Добавляем лейблы к точкаи на графике
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

#Количество точек которые необходимо отобразить на графике
number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
# Выбираем случайный узел
random_node_index = 1
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.1310045 1.1917396 1.2206165]]
# Индексы:[[  1  67 263 229]]
# Ближайшие соседи узла africa: ['africa', 'eastern_africa', 'western_africa', 'svalbard_and_jan_mayen']
#
# Метрика:cosine
# Дистанции:[[0.         0.6395855  0.71012163 0.7449522 ]]
# Индексы:[[  1  67 263 229]]
# Ближайшие соседи узла africa: ['africa', 'eastern_africa', 'western_africa', 'svalbard_and_jan_mayen']
#
# Метрика:manhattan
# Дистанции:[[ 0.         12.90200615 13.8157196  14.03495502]]
# Индексы:[[  1  67 263 229]]
# Ближайшие соседи узла africa: ['africa', 'eastern_africa', 'western_africa', 'svalbard_and_jan_mayen']

# %%
# Еще один узел
random_node_index = 200
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.       1.136394 1.154473 1.189585]]
# Индексы:[[200 201 211 247]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'saint_pierre_and_miquelon', 'sint_maarten', 'turks_and_caicos_islands']
#
# Метрика:cosine
# Дистанции:[[5.9604645e-08 6.5256703e-01 6.7109323e-01 7.1510774e-01]]
# Индексы:[[200 201 211 247]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'saint_pierre_and_miquelon', 'sint_maarten', 'turks_and_caicos_islands']
#
# Метрика:manhattan
# Дистанции:[[ 0.         12.57125854 13.43739223 13.60910034]]
# Индексы:[[200 201 211 247]]
# Ближайшие соседи узла saint_martin: ['saint_martin', 'saint_pierre_and_miquelon', 'sint_maarten', 'turks_and_caicos_islands']

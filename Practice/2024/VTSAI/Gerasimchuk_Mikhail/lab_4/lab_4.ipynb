# %%
# !pip3 install pykeen
# Out:
# Collecting pykeen
#   Using cached pykeen-1.10.1-py3-none-any.whl (739 kB)
# Collecting dataclasses-json (from pykeen)
#   Using cached dataclasses_json-0.6.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy in /home/space/.local/lib/python3.8/site-packages (from pykeen) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /home/space/.local/lib/python3.8/site-packages (from pykeen) (1.9.1)
# Requirement already satisfied: click in /home/space/.local/lib/python3.8/site-packages (from pykeen) (8.1.6)
# Collecting click-default-group (from pykeen)
#   Using cached click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: scikit-learn in /home/space/.local/lib/python3.8/site-packages (from pykeen) (1.2.2)
# Requirement already satisfied: tqdm in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from pykeen) (4.66.1)
# Requirement already satisfied: requests in /home/space/.local/lib/python3.8/site-packages (from pykeen) (2.28.2)
# Collecting optuna>=2.0.0 (from pykeen)
#   Using cached optuna-3.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pandas>=1.0.0 in /home/space/.local/lib/python3.8/site-packages (from pykeen) (1.4.2)
# Requirement already satisfied: tabulate in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from pykeen) (0.9.0)
# Collecting more-click (from pykeen)
#   Using cached more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Collecting more-itertools (from pykeen)
#   Using cached more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting pystow>=0.4.3 (from pykeen)
#   Using cached pystow-0.5.2-py3-none-any.whl.metadata (8.9 kB)
# Collecting docdata (from pykeen)
#   Using cached docdata-0.0.3-py3-none-any.whl (5.8 kB)
# Collecting class-resolver>=0.3.10 (from pykeen)
#   Using cached class_resolver-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyyaml in /home/space/.local/lib/python3.8/site-packages (from pykeen) (6.0)
# Collecting rexmex>=0.1.3 (from pykeen)
#   Using cached rexmex-0.1.3-py3-none-any.whl
# Collecting torch-max-mem>=0.0.4 (from pykeen)
#   Using cached torch_max_mem-0.1.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting torch-ppr>=0.0.7 (from pykeen)
#   Using cached torch_ppr-0.0.8-py3-none-any.whl (12 kB)
# Requirement already satisfied: protobuf<4.0.0 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from pykeen) (3.20.3)
# Requirement already satisfied: typing-extensions in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from pykeen) (4.9.0)
# Requirement already satisfied: torch>=1.10 in /home/space/.local/lib/python3.8/site-packages (from pykeen) (1.13.1)
# Requirement already satisfied: importlib-metadata>3.6 in /home/space/.local/lib/python3.8/site-packages (from class-resolver>=0.3.10->pykeen) (6.0.0)
# Collecting alembic>=1.5.0 (from optuna>=2.0.0->pykeen)
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=2.0.0->pykeen)
#   Using cached colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /home/space/.local/lib/python3.8/site-packages (from optuna>=2.0.0->pykeen) (23.0)
# Collecting sqlalchemy>=1.3.0 (from optuna>=2.0.0->pykeen)
#   Using cached SQLAlchemy-2.0.25-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/space/.local/lib/python3.8/site-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/space/.local/lib/python3.8/site-packages (from pandas>=1.0.0->pykeen) (2023.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/space/.local/lib/python3.8/site-packages (from torch>=1.10->pykeen) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/space/.local/lib/python3.8/site-packages (from torch>=1.10->pykeen) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/space/.local/lib/python3.8/site-packages (from torch>=1.10->pykeen) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/space/.local/lib/python3.8/site-packages (from torch>=1.10->pykeen) (11.7.99)
# Requirement already satisfied: setuptools in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10->pykeen) (68.2.2)
# Requirement already satisfied: wheel in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10->pykeen) (0.41.2)
# Collecting torch>=1.10 (from pykeen)
#   Using cached torch-2.1.2-cp38-cp38-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting filelock (from torch>=1.10->pykeen)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: sympy in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from torch>=1.10->pykeen) (1.12)
# Requirement already satisfied: networkx in /home/space/.local/lib/python3.8/site-packages (from torch>=1.10->pykeen) (3.0)
# Collecting jinja2 (from torch>=1.10->pykeen)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch>=1.10->pykeen)
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10->pykeen)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from torch>=1.10->pykeen) (12.1.105)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10->pykeen)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10->pykeen)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10->pykeen)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from torch>=1.10->pykeen) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from torch>=1.10->pykeen) (10.3.2.106)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10->pykeen)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10->pykeen)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from torch>=1.10->pykeen) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from torch>=1.10->pykeen) (12.1.105)
# Collecting triton==2.1.0 (from torch>=1.10->pykeen)
#   Using cached triton-2.1.0-0-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10->pykeen) (12.3.101)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->pykeen)
#   Using cached marshmallow-3.20.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->pykeen)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/space/.local/lib/python3.8/site-packages (from requests->pykeen) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from requests->pykeen) (3.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/space/.local/lib/python3.8/site-packages (from requests->pykeen) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from requests->pykeen) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /home/space/.local/lib/python3.8/site-packages (from scikit-learn->pykeen) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/space/.local/lib/python3.8/site-packages (from scikit-learn->pykeen) (3.2.0)
# Collecting Mako (from alembic>=1.5.0->optuna>=2.0.0->pykeen)
#   Using cached Mako-1.3.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: importlib-resources in /home/space/.local/lib/python3.8/site-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (5.10.2)
# Requirement already satisfied: zipp>=0.5 in /home/space/.local/lib/python3.8/site-packages (from importlib-metadata>3.6->class-resolver>=0.3.10->pykeen) (3.13.0)
# Requirement already satisfied: six>=1.5 in /home/space/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->pykeen) (1.16.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna>=2.0.0->pykeen)
#   Using cached greenlet-3.0.3-cp38-cp38-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/space/.local/lib/python3.8/site-packages (from jinja2->torch>=1.10->pykeen) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/space/miniconda3/envs/know/lib/python3.8/site-packages (from sympy->torch>=1.10->pykeen) (1.3.0)
# Using cached optuna-3.5.0-py3-none-any.whl (413 kB)
# Using cached pystow-0.5.2-py3-none-any.whl (31 kB)
# Using cached torch_max_mem-0.1.3-py3-none-any.whl (10 kB)
# Using cached torch-2.1.2-cp38-cp38-manylinux1_x86_64.whl (670.2 MB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached triton-2.1.0-0-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
# Using cached click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Using cached dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Using cached marshmallow-3.20.2-py3-none-any.whl (49 kB)
# Using cached SQLAlchemy-2.0.25-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached colorlog-6.8.2-py3-none-any.whl (11 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached greenlet-3.0.3-cp38-cp38-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (622 kB)
# Using cached Mako-1.3.0-py3-none-any.whl (78 kB)
# Installing collected packages: nvidia-cusparse-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, more-itertools, more-click, marshmallow, Mako, jinja2, greenlet, fsspec, filelock, docdata, colorlog, click-default-group, typing-inspect, triton, sqlalchemy, pystow, nvidia-cusolver-cu12, nvidia-cudnn-cu12, class-resolver, torch, rexmex, dataclasses-json, alembic, torch-max-mem, optuna, torch-ppr, pykeen
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1 requires torch==1.13.1, but you have torch 2.1.2 which is incompatible.
# Successfully installed Mako-1.3.0 alembic-1.13.1 class-resolver-0.4.2 click-default-group-1.2.4 colorlog-6.8.2 dataclasses-json-0.6.3 docdata-0.0.3 filelock-3.13.1 fsspec-2023.12.2 greenlet-3.0.3 jinja2-3.1.3 marshmallow-3.20.2 more-click-0.1.2 more-itertools-10.2.0 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 optuna-3.5.0 pykeen-1.10.1 pystow-0.5.2 rexmex-0.1.3 sqlalchemy-2.0.25 torch-2.1.2 torch-max-mem-0.1.3 torch-ppr-0.0.8 triton-2.1.0 typing-inspect-0.9.0

# %%
import pykeen
from pykeen.datasets import Nations
from pykeen.pipeline import pipeline
from pykeen.predict import predict_triples
import torch

# %%
dataset = Nations()

training_data = dataset.training.mapped_triples

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


pipeline_results = pipeline(
    model="TransE",  # TransE model for relation prediction
    dataset=dataset,  # Nations dataset
    training_kwargs=dict(num_epochs=100),  # Number of training epochs
    device=device
)

print(pipeline_results)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 4062164729.
# INFO:pykeen.pipeline.api:Using device: cuda
# Training epochs on cuda:0: 100%|██████████| 100/100 [00:08<00:00, 12.22epoch/s, loss=0.769, prev_loss=0.737]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=201.
# Evaluating on cuda:0: 100%|██████████| 201/201 [00:00<00:00, 16.7ktriple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.02s seconds
# PipelineResult(random_seed=4062164729, model=TransE(
#   (loss): MarginRankingLoss(
#     (margin_activation): ReLU()
#   )
#   (interaction): TransEInteraction()
#   (entity_representations): ModuleList(
#     (0): Embedding(
#       (_embeddings): Embedding(14, 50)
#     )
#   )
#   (relation_representations): ModuleList(
#     (0): Embedding(
#       (_embeddings): Embedding(55, 50)
#     )
#   )
#   (weight_regularizers): ModuleList()
# ), training=TriplesFactory(num_entities=14, num_relations=55, create_inverse_triples=False, num_triples=1592, path="/home/space/miniconda3/envs/know/lib/python3.8/site-packages/pykeen/datasets/nations/train.txt"), training_loop=<pykeen.training.slcwa.SLCWATrainingLoop object at 0x7f64748d3970>, losses=[1.351236070905413, 1.4376486369541712, 1.3369601283754622, 1.306329607963562, 1.3350036484854562, 1.2912931782858712, 1.1927975927080428, 1.2286902495792933, 1.222324218068804, 1.2023182681628637, 1.2248401301247733, 1.2228398493358068, 1.2016646010535104, 1.2131702218736922, 1.1590517844472612, 1.1202581780297416, 1.1942727736064367, 1.153774653162275, 1.0910314576966422, 1.1106174162455968, 1.1117425646100725, 1.1201095921652657, 1.0531004496983118, 1.0495820386069161, 1.0296197959354945, 1.016633587224143, 1.0248871190207345, 1.0268702592168535, 1.0921458176204137, 1.0215847151620048, 1.021993679659707, 1.0459293723106384, 1.0170058693204607, 0.9845023921557835, 0.9930230123656136, 1.0070914370673043, 0.977169292313712, 0.9756727303777423, 0.9390380212238857, 0.9761840190206256, 0.9202412281717572, 0.9461821828569684, 0.9482340216636658, 0.9306889687265668, 0.9226113898413522, 0.8970957909311567, 0.9021155919347491, 0.8837702785219465, 0.8868184856006077, 0.862261848790305, 0.8969014542443412, 0.8645578282220023, 0.8795800464493888, 0.8777093120983669, 0.916914667401995, 0.8359669191496713, 0.8782282812254769, 0.8906563094684056, 0.8702044572149005, 0.8472713913236346, 0.8690325702939715, 0.7921841485159737, 0.915750971862248, 0.8595123887062073, 0.8559023312159947, 0.850568984236036, 0.8464682953698295, 0.8126446519579206, 0.8366954326629639, 0.8155372568539211, 0.8130360926900592, 0.818111641066415, 0.7949488248143878, 0.8346784540585109, 0.7980195028441293, 0.8241544791630336, 0.7765911136354718, 0.8014511040278843, 0.7623750397137233, 0.765561044216156, 0.7697973847389221, 0.7821576425007412, 0.8023008363587516, 0.8245014803750175, 0.7959209169660296, 0.7610703366143363, 0.8425080350467137, 0.794324244771685, 0.7543891242572239, 0.7866082617214748, 0.8083159668104989, 0.724900654384068, 0.7669747642108372, 0.7532770207950047, 0.7968311394963946, 0.7780630247933524, 0.7839151280266898, 0.7437556300844465, 0.7372730885233197, 0.7689572743007115], metric_results=<pykeen.evaluation.rank_based_evaluator.RankBasedMetricResults object at 0x7f646f372a90>, train_seconds=8.269601583480835, evaluate_seconds=0.17318391799926758, stopper=<pykeen.stoppers.stopper.NopStopper object at 0x7f64748d3460>, configuration={'dataset': 'nations', 'dataset_kwargs': None, 'model': 'TransE', 'model_kwargs': {'random_seed': 4062164729, 'loss': MarginRankingLoss(
#   (margin_activation): ReLU()
# )}, 'loss_kwargs': None, 'regularizer_kwargs': None, 'optimizer': 'Adam', 'optimizer_kwargs': {'lr': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None}, 'training_loop': 'SLCWATrainingLoop', 'training_loop_kwargs': {}, 'evaluator': 'RankBasedEvaluator', 'evaluator_kwargs': {}, 'num_epochs': 100, 'batch_size': 256, 'evaluation_kwargs': {'additional_filter_triples': {'training': {'sha512': '55186f67ee8112c8003519ea87c19bb6b9e110489e6b0a6abeb7a127f2dc9b7195a518f4829d773b82fd47632ac1fe09f6a256cef2469c7dc895210a10919bb4'}, 'validation': {'sha512': '171f020ddad54115ff23a5c7d7143aaf097472f5a76a47b55333ac7c5a522b045cf320b5c0e3842efe005bc017e3e3b1c412532a734195cb1102651babbf631f'}}}}, metadata={}, version='1.10.1', git_hash='UNHASHED')

# %%
pack = predict_triples(model=pipeline_results.model, triples=dataset.validation)
df = pack.process(factory=pipeline_results.training).df

df.nlargest(n=10, columns="score")
# Out:
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
#      head_id head_label  relation_id    relation_label  tail_id tail_label  \
# 175       12        usa           47           tourism        4      egypt
# 90         7     israel           13        eemigrants       12        usa
# 159       11         uk           40       relstudents       12        usa
# 176       12        usa           47           tourism       11         uk
# 35         2      china           26      negativecomm       12        usa
# 57         3       cuba           26      negativecomm       12        usa
# 170       12        usa           31         pprotests       10     poland
# 65         4      egypt           18          exports3       11         uk
# 139       10     poland           48          tourism3       13       ussr
# 93         7     israel           24  militaryalliance       12        usa
#
#         score
# 175 -7.054984
# 90  -7.078137
# 159 -7.179070
# 176 -7.525523
# 35  -7.539259
# 57  -7.689585
# 170 -7.815037
# 65  -7.880906
# 139 -8.030716
# 93  -8.072074

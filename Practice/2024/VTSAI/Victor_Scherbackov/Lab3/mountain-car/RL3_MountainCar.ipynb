# %% [markdown]
# ## Discount factor
# **Discount factor**  - это параметр, используемый в теории управления и обучении с подкреплением для оценки стоимости будущих вознаграждений. Он обозначается символом $\gamma$ (гамма).
#
# В контексте задачи обучения с подкреплением, такой как у **DQN** алгоритма, фактор дисконтирования применяется к будущим вознаграждениям, чтобы учесть уменьшение их значения с течением времени. Фактор дисконтирования позволяет агенту принимать во внимание не только мгновенные вознаграждения, но и будущие вознаграждения, приводя к более долгосрочной стратегии.
#
# **Формула для дисконтирования будущих вознаграждений** выглядит следующим образом:
#
#  $G_t$ = $R_{t+1}$ + $\gamma$ $R_{t+2}$ + $\gamma$^2 $R_{t+3}$ + $\ldots$ = $\sum_{k=0}^{\infty}$ $\gamma$^k $R_{t+k+1}$
#
# где:
# - $G_t$ - дисконтированная сумма вознаграждений (вознаграждение с учетом будущих шагов);
# - $R_{t+k+1}$ - вознаграждение, полученное на шаге $t+k+1$;
# - $\gamma$ - фактор дисконтирования,  $0 \leq \gamma \leq 1$.
#
# Фактор дисконтирования имеет важное значение при принятии решений в условиях неопределенности, где агенту нужно учитывать как мгновенные, так и будущие вознаграждения, с учетом их временного удаления. Выбор подходящего значения для фактора дисконтирования может влиять на стратегии обучения.

# %% [markdown]
# ## Long-term и Short-term стратегия
#
# Фактор дисконтирования оказывает сильное влияние на долгосрочность стратегии.
# В контексте обучения с подкреплением и стратегий агента, термины "краткосрочные" и "долгосрочные" относятся к временным характеристикам принятия решений агентом.
#
# **Краткосрочные стратегии**:
#
# > Агент, придерживающийся краткосрочной стратегии, ориентируется в основном на текущую информацию и мгновенные вознаграждения.
# Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам. Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам.
#
#
#
#
# **Долгосрочные стратегии**:
#
#
# > Агент, придерживающийся долгосрочной стратегии, учитывает будущие вознаграждения и последствия своих действий на протяжении более длительного времени.
# Такой агент может предпочесть действия, которые могут не приносить максимальное мгновенное вознаграждение, но могут способствовать достижению более высоких наград в будущем.
#
# Когда говорят о краткосрочных или долгосрочных стратегиях в контексте обучения с подкреплением, обычно имеется в виду, как агент принимает решения, оптимизируя сумму будущих вознаграждений. Фактор дисконтирования γ в уравнении обучения с подкреплением регулирует степень учета будущих вознаграждений, и, таким образом, влияет на то, насколько агент ориентирован на краткосрочные или долгосрочные перспективы.

# %% [markdown]
# ## Метрики для оценки модели
# В данной работе мы рассмотрим некоторые метрики, которые могут быть использованы для оценки обучения модели.
# Аналогично первой лабораторной работы мы будем решать задачу в окружении MountainCar-v0, а в качестве модели используем уже знакомый DQN. При этом мы обучим модель несколько разных с разным параметром Discount factor.
#
# Для оценки модели мы рассмотрим следущие метрики:
#
# *   Q-values, их поведение и сходимость.
# *   Средняя награда за эпизод.
# *   Время затрачиваемое на обучение модели.

# %% [markdown]
# ### Установка зависимостей
#
# На первом шаге мы начинаем с установки необходимых библиотек. Пакет [gymnasium](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет различные среды для обучения с подкреплением, в то время как [stable-baselines3](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет реализации различных алгоритмов обучения с подкреплением.

# %%
# !apt install -y swig
# !pip install 'shimmy>=0.2.1'
# Установка необходимых библиотек
# !pip install gymnasium stable-baselines3 gymnasium[box2d]
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,485 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting shimmy>=0.2.1
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy>=0.2.1) (1.23.5)
# Collecting gymnasium>=0.27.0 (from shimmy>=0.2.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.27.0->shimmy>=0.2.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, shimmy
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Collecting box2d-py==2.3.5 (from gymnasium)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.5.2)
# Collecting swig==4.* (from gymnasium)
#   Downloading swig-4.1.1.post1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349116 sha256=093350c82d28d39325d891e068064a0c68effbb8096da173d10a62c2286dbc2a
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py, stable-baselines3
# Successfully installed box2d-py-2.3.5 stable-baselines3-2.2.1 swig-4.1.1.post1

# %%
import torch as th
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import time

# %%
def q_values(model: DQN, obs: np.ndarray) -> np.ndarray:
  # Доступ к Q-network
  q_net = model.q_net

  # Конвертируем observation в PyTorch tensor
  obs_tensor = th.tensor(obs, dtype=th.float32)

  # Изменяем размерность
  obs_tensor = obs_tensor.unsqueeze(0)

  #Извлекаем Q-values
  q_values = model.q_net.forward(obs_tensor)

  return q_values.detach().numpy()[0]


def plot_q_values(q_values_list):
    # Построение графика
    plt.figure(figsize=(10, 6))
    for i in range(q_values_list.shape[1]):
        plt.plot(q_values_list[:, i], label=f'Q{i+1} Values')
    plt.xlabel('Time')
    plt.ylabel('Q-Values')
    plt.title('Convergence of Q-Values over Time')
    plt.legend()
    plt.show()

def mean_reward(discount_factor):
    # Создание окружения
    env = gym.make("MountainCar-v0")

    # Удаление обертки TimeLimit
    #env = env.unwrapped

    # Создание модели
    model = DQN("MlpPolicy", env, verbose=1, gamma=discount_factor)

    # Количество эпизодов для оценки модели
    n_eval_episodes = 250

    # Оценка модели до обучения
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes, deterministic=True)
    print(f"До обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

    # Засекаем начальное время
    start_time = time.time()

    # Обучение модели
    model.learn(total_timesteps=100000, log_interval=1000)

    # Засекаем время завершения
    end_time = time.time()

    # Оценка модели после обучения
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes, deterministic=True)
    print(f"После обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"dqn_MountainCar-v0_{discount_factor}")
    del model

    # Вычисляем время обучения
    learn_time = end_time - start_time
    return env, learn_time  # <-- Return both environment and learn_time


def q_values_calculation(discount_factor, env):
    # Загружаем созданную и сохраненную модель
    model = DQN.load(f"dqn_MountainCar-v0_{discount_factor}")

    # В MountainCar окружении возможны только 3 действия
    action_str = ['push left', 'no push', 'push right']
    q_values_list = []

    obs, info = env.reset()
    for _ in range(100):
        q_val = q_values(model, obs)
        q_values_list.append(q_val)
        action, _states = model.predict(obs, deterministic=True)

        print(f"Q-value состояния: {q_val}")
        print(f"Действие: {action_str[action]}")

        obs, reward, terminated, truncated, info = env.step(action)

    q_values_array = np.array(q_values_list)
    return q_values_array

discount_factors = [0.01, 0.5, 0.99]
environment, time_to_lrn = mean_reward(discount_factors[0])
obs = environment.reset()


q_vals = q_values_calculation(discount_factors[0], environment)
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[0]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()

environment, time_to_lrn = mean_reward(discount_factors[1])
q_vals = q_values_calculation(discount_factors[1], environment)
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[1]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()

environment, time_to_lrn = mean_reward(discount_factors[2])
q_vals = q_values_calculation(discount_factors[2], environment)
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[2]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.01, mean_reward:-200.00 +/- 0.00
# После обучения модели с discount_factor = 0.01, mean_reward:-200.00 +/- 0.00
# Q-value состояния: [-1.0101055 -1.0101207 -1.0101814]
# Действие: push left
# Q-value состояния: [-1.010108  -1.0101215 -1.0101857]
# Действие: push left
# Q-value состояния: [-1.0101115 -1.0101228 -1.01019  ]
# Действие: push left
# Q-value состояния: [-1.0101159 -1.0101249 -1.0101937]
# Действие: push left
# Q-value состояния: [-1.0101212 -1.0101277 -1.0101974]
# Действие: push left
# Q-value состояния: [-1.0101275 -1.0101311 -1.0102007]
# Действие: push left
# Q-value состояния: [-1.0101346 -1.010135  -1.0102036]
# Действие: push left
# Q-value состояния: [-1.0101426 -1.0101397 -1.0102062]
# Действие: no push
# Q-value состояния: [-1.0101497 -1.0101444 -1.0102056]
# Действие: no push
# Q-value состояния: [-1.0101568 -1.010149  -1.0102047]
# Действие: no push
# Q-value состояния: [-1.0101639 -1.0101539 -1.0102037]
# Действие: no push
# Q-value состояния: [-1.010171  -1.0101585 -1.0102023]
# Действие: no push
# Q-value состояния: [-1.0101708 -1.0101522 -1.0102   ]
# Действие: no push
# Q-value состояния: [-1.0101676 -1.0101213 -1.0101885]
# Действие: no push
# Q-value состояния: [-1.0101639 -1.0100912 -1.0101773]
# Действие: no push
# Q-value состояния: [-1.0101595 -1.010062  -1.0101664]
# Действие: no push
# Q-value состояния: [-1.0101547 -1.010034  -1.010156 ]
# Действие: no push
# Q-value состояния: [-1.0101494 -1.0100073 -1.0101464]
# Действие: no push
# Q-value состояния: [-1.0101436 -1.0099822 -1.0101377]
# Действие: no push
# Q-value состояния: [-1.0101373 -1.009959  -1.0101296]
# Действие: no push
# Q-value состояния: [-1.0101309 -1.0099376 -1.0101221]
# Действие: no push
# Q-value состояния: [-1.010124  -1.0099183 -1.0101156]
# Действие: no push
# Q-value состояния: [-1.0101169 -1.0099013 -1.0101103]
# Действие: no push
# Q-value состояния: [-1.0101094 -1.0098866 -1.0101056]
# Действие: no push
# Q-value состояния: [-1.010102  -1.0098745 -1.010102 ]
# Действие: no push
# Q-value состояния: [-1.0100993 -1.00986   -1.0100908]
# Действие: no push
# Q-value состояния: [-1.010096  -1.0098487 -1.0100818]
# Действие: no push
# Q-value состояния: [-1.0100876 -1.0098449 -1.0100826]
# Действие: no push
# Q-value состояния: [-1.0100744 -1.009849  -1.0100932]
# Действие: no push
# Q-value состояния: [-1.0100642 -1.0098525 -1.0100996]
# Действие: no push
# Q-value состояния: [-1.010057  -1.0098563 -1.0101023]
# Действие: no push
# Q-value состояния: [-1.0100498 -1.0098627 -1.0101058]
# Действие: no push
# Q-value состояния: [-1.010043  -1.0098715 -1.0101106]
# Действие: no push
# Q-value состояния: [-1.0100367 -1.0098832 -1.0101162]
# Действие: no push
# Q-value состояния: [-1.0100306 -1.0098972 -1.0101227]
# Действие: no push
# Q-value состояния: [-1.0100248 -1.0099134 -1.01013  ]
# Действие: no push
# Q-value состояния: [-1.0100197 -1.0099322 -1.0101384]
# Действие: no push
# Q-value состояния: [-1.010015  -1.0099529 -1.0101473]
# Действие: no push
# Q-value состояния: [-1.0100107 -1.0099758 -1.0101571]
# Действие: no push
# Q-value состояния: [-1.0100071 -1.0100003 -1.0101674]
# Действие: no push
# Q-value состояния: [-1.010004  -1.0100265 -1.0101781]
# Действие: push left
# Q-value состояния: [-1.0100095 -1.0100508 -1.0101867]
# Действие: push left
# Q-value состояния: [-1.0100155 -1.0100732 -1.0101947]
# Действие: push left
# Q-value состояния: [-1.0100218 -1.0100939 -1.0102016]
# Действие: push left
# Q-value состояния: [-1.0100284 -1.0101125 -1.0102079]
# Действие: push left
# Q-value состояния: [-1.0100353 -1.010129  -1.0102131]
# Действие: push left
# Q-value состояния: [-1.0100423 -1.010143  -1.0102177]
# Действие: push left
# Q-value состояния: [-1.0100496 -1.0101548 -1.010221 ]
# Действие: push left
# Q-value состояния: [-1.010057  -1.0101643 -1.0102236]
# Действие: push left
# Q-value состояния: [-1.0100644 -1.0101709 -1.010225 ]
# Действие: push left
# Q-value состояния: [-1.0100719 -1.0101752 -1.0102255]
# Действие: push left
# Q-value состояния: [-1.0100791 -1.0101768 -1.0102248]
# Действие: push left
# Q-value состояния: [-1.0100863 -1.0101758 -1.0102234]
# Действие: push left
# Q-value состояния: [-1.0100935 -1.0101721 -1.0102205]
# Действие: push left
# Q-value состояния: [-1.0101002 -1.0101659 -1.0102171]
# Действие: push left
# Q-value состояния: [-1.0101068 -1.010157  -1.0102124]
# Действие: push left
# Q-value состояния: [-1.0101131 -1.0101457 -1.0102069]
# Действие: push left
# Q-value состояния: [-1.010119  -1.010132  -1.0102006]
# Действие: push left
# Q-value состояния: [-1.0101246 -1.0101161 -1.0101936]
# Действие: no push
# Q-value состояния: [-1.0101215 -1.0101014 -1.0101881]
# Действие: no push
# Q-value состояния: [-1.0101184 -1.0100876 -1.0101833]
# Действие: no push
# Q-value состояния: [-1.0101148 -1.0100749 -1.0101788]
# Действие: no push
# Q-value состояния: [-1.0101111 -1.0100632 -1.0101748]
# Действие: no push
# Q-value состояния: [-1.0101073 -1.0100526 -1.0101713]
# Действие: no push
# Q-value состояния: [-1.0101033 -1.0100433 -1.0101683]
# Действие: no push
# Q-value состояния: [-1.0100992 -1.0100353 -1.0101658]
# Действие: no push
# Q-value состояния: [-1.010095  -1.0100287 -1.010164 ]
# Действие: no push
# Q-value состояния: [-1.0100907 -1.0100236 -1.0101625]
# Действие: no push
# Q-value состояния: [-1.0100867 -1.0100199 -1.0101619]
# Действие: no push
# Q-value состояния: [-1.0100822 -1.0100178 -1.0101619]
# Действие: no push
# Q-value состояния: [-1.010078  -1.0100172 -1.0101621]
# Действие: no push
# Q-value состояния: [-1.0100739 -1.0100179 -1.0101631]
# Действие: no push
# Q-value состояния: [-1.0100698 -1.0100203 -1.0101647]
# Действие: no push
# Q-value состояния: [-1.0100659 -1.010024  -1.0101669]
# Действие: no push
# Q-value состояния: [-1.0100621 -1.0100294 -1.0101695]
# Действие: no push
# Q-value состояния: [-1.0100586 -1.010036  -1.010173 ]
# Действие: no push
# Q-value состояния: [-1.0100552 -1.0100441 -1.0101767]
# Действие: no push
# Q-value состояния: [-1.0100521 -1.0100535 -1.0101808]
# Действие: push left
# Q-value состояния: [-1.0100572 -1.0100607 -1.0101829]
# Действие: push left
# Q-value состояния: [-1.0100625 -1.0100662 -1.0101839]
# Действие: push left
# Q-value состояния: [-1.0100677 -1.0100697 -1.0101846]
# Действие: push left
# Q-value состояния: [-1.0100728 -1.0100714 -1.0101844]
# Действие: no push
# Q-value состояния: [-1.01007   -1.0100747 -1.0101862]
# Действие: push left
# Q-value состояния: [-1.0100751 -1.0100758 -1.0101857]
# Действие: push left
# Q-value состояния: [-1.0100805 -1.010075  -1.0101845]
# Действие: no push
# Q-value состояния: [-1.0100774 -1.0100756 -1.0101854]
# Действие: no push
# Q-value состояния: [-1.0100745 -1.0100775 -1.0101863]
# Действие: push left
# Q-value состояния: [-1.0100797 -1.010077  -1.0101855]
# Действие: no push
# Q-value состояния: [-1.0100768 -1.010078  -1.0101862]
# Действие: push left
# Q-value состояния: [-1.0100819 -1.0100764 -1.0101849]
# Действие: no push
# Q-value состояния: [-1.0100788 -1.0100768 -1.0101855]
# Действие: no push
# Q-value состояния: [-1.0100759 -1.0100778 -1.0101864]
# Действие: push left
# Q-value состояния: [-1.0100812 -1.0100766 -1.010185 ]
# Действие: no push
# Q-value состояния: [-1.0100782 -1.0100771 -1.0101858]
# Действие: no push
# Q-value состояния: [-1.0100753 -1.0100785 -1.0101868]
# Действие: push left
# Q-value состояния: [-1.0100806 -1.0100777 -1.0101857]
# Действие: no push
# Q-value состояния: [-1.0100777 -1.0100784 -1.0101863]
# Действие: push left
# Q-value состояния: [-1.0100828 -1.0100766 -1.0101849]
# Действие: no push
# Q-value состояния: [-1.0100799 -1.0100764 -1.0101852]
# Действие: no push
# Q-value состояния: [-1.010077  -1.0100774 -1.0101861]
# Действие: push left
# Время обучения модели при discount_factor = 0.01 : 37.39062738418579 секунд.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.5, mean_reward:-200.00 +/- 0.00
# После обучения модели с discount_factor = 0.5, mean_reward:-200.00 +/- 0.00
# Q-value состояния: [-1.9480238 -1.9433903 -1.9459465]
# Действие: no push
# Q-value состояния: [-1.948025  -1.9433888 -1.9459472]
# Действие: no push
# Q-value состояния: [-1.9480261 -1.9433874 -1.9459484]
# Действие: no push
# Q-value состояния: [-1.9480269 -1.9433857 -1.9459491]
# Действие: no push
# Q-value состояния: [-1.9480275 -1.9433835 -1.9459498]
# Действие: no push
# Q-value состояния: [-1.9480281 -1.9433814 -1.945951 ]
# Действие: no push
# Q-value состояния: [-1.948028  -1.943379  -1.9459519]
# Действие: no push
# Q-value состояния: [-1.9480278 -1.9433767 -1.9459529]
# Действие: no push
# Q-value состояния: [-1.9480276 -1.9433739 -1.9459538]
# Действие: no push
# Q-value состояния: [-1.9480271 -1.9433712 -1.9459546]
# Действие: no push
# Q-value состояния: [-1.9480262 -1.9433683 -1.9459555]
# Действие: no push
# Q-value состояния: [-1.9480252 -1.9433656 -1.9459565]
# Действие: no push
# Q-value состояния: [-1.948024  -1.9433625 -1.9459574]
# Действие: no push
# Q-value состояния: [-1.9480226 -1.9433594 -1.9459581]
# Действие: no push
# Q-value состояния: [-1.948021  -1.9433566 -1.9459586]
# Действие: no push
# Q-value состояния: [-1.9480193 -1.9433533 -1.9459593]
# Действие: no push
# Q-value состояния: [-1.9480174 -1.9433506 -1.94596  ]
# Действие: no push
# Q-value состояния: [-1.9480152 -1.9433476 -1.9459605]
# Действие: no push
# Q-value состояния: [-1.948013  -1.9433448 -1.9459612]
# Действие: no push
# Q-value состояния: [-1.9480106 -1.9433421 -1.9459612]
# Действие: no push
# Q-value состояния: [-1.9480081 -1.9433392 -1.9459615]
# Действие: no push
# Q-value состояния: [-1.9480053 -1.943337  -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9480028 -1.9433347 -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9480002 -1.9433326 -1.9459622]
# Действие: no push
# Q-value состояния: [-1.9479973 -1.9433306 -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.947995  -1.9433287 -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.947992  -1.9433272 -1.9459617]
# Действие: no push
# Q-value состояния: [-1.9479895 -1.943326  -1.9459615]
# Действие: no push
# Q-value состояния: [-1.9479868 -1.9433249 -1.945961 ]
# Действие: no push
# Q-value состояния: [-1.9479842 -1.9433242 -1.9459608]
# Действие: no push
# Q-value состояния: [-1.9479817 -1.9433237 -1.9459603]
# Действие: no push
# Q-value состояния: [-1.9479795 -1.9433233 -1.9459596]
# Действие: no push
# Q-value состояния: [-1.9479774 -1.9433234 -1.9459589]
# Действие: no push
# Q-value состояния: [-1.9479754 -1.9433236 -1.9459581]
# Действие: no push
# Q-value состояния: [-1.9479735 -1.9433241 -1.9459574]
# Действие: no push
# Q-value состояния: [-1.9479718 -1.9433248 -1.9459567]
# Действие: no push
# Q-value состояния: [-1.9479703 -1.9433259 -1.945956 ]
# Действие: no push
# Q-value состояния: [-1.947969  -1.9433273 -1.945955 ]
# Действие: no push
# Q-value состояния: [-1.9479678 -1.9433287 -1.9459541]
# Действие: no push
# Q-value состояния: [-1.947967  -1.9433304 -1.9459531]
# Действие: no push
# Q-value состояния: [-1.9479662 -1.9433323 -1.9459522]
# Действие: no push
# Q-value состояния: [-1.9479659 -1.9433345 -1.9459512]
# Действие: no push
# Q-value состояния: [-1.9479656 -1.9433367 -1.9459505]
# Действие: no push
# Q-value состояния: [-1.9479656 -1.9433391 -1.9459493]
# Действие: no push
# Q-value состояния: [-1.947966  -1.9433417 -1.9459486]
# Действие: no push
# Q-value состояния: [-1.9479666 -1.9433445 -1.9459476]
# Действие: no push
# Q-value состояния: [-1.9479672 -1.9433473 -1.9459467]
# Действие: no push
# Q-value состояния: [-1.9479681 -1.9433502 -1.9459457]
# Действие: no push
# Q-value состояния: [-1.9479693 -1.9433532 -1.945945 ]
# Действие: no push
# Q-value состояния: [-1.9479706 -1.9433562 -1.9459441]
# Действие: no push
# Q-value состояния: [-1.9479723 -1.9433593 -1.9459434]
# Действие: no push
# Q-value состояния: [-1.947974  -1.9433621 -1.9459426]
# Действие: no push
# Q-value состояния: [-1.9479758 -1.9433651 -1.9459422]
# Действие: no push
# Q-value состояния: [-1.9479779 -1.9433682 -1.9459417]
# Действие: no push
# Q-value состояния: [-1.9479802 -1.943371  -1.9459412]
# Действие: no push
# Q-value состояния: [-1.9479825 -1.9433738 -1.9459407]
# Действие: no push
# Q-value состояния: [-1.9479849 -1.9433764 -1.9459407]
# Действие: no push
# Q-value состояния: [-1.9479874 -1.9433788 -1.9459403]
# Действие: no push
# Q-value состояния: [-1.9479902 -1.9433813 -1.94594  ]
# Действие: no push
# Q-value состояния: [-1.9479929 -1.9433833 -1.9459398]
# Действие: no push
# Q-value состояния: [-1.9479957 -1.9433856 -1.94594  ]
# Действие: no push
# Q-value состояния: [-1.9479984 -1.9433873 -1.94594  ]
# Действие: no push
# Q-value состояния: [-1.9480009 -1.9433888 -1.9459403]
# Действие: no push
# Q-value состояния: [-1.9480035 -1.9433903 -1.9459407]
# Действие: no push
# Q-value состояния: [-1.9480063 -1.9433912 -1.9459407]
# Действие: no push
# Q-value состояния: [-1.9480089 -1.9433922 -1.9459412]
# Действие: no push
# Q-value состояния: [-1.9480113 -1.9433926 -1.9459417]
# Действие: no push
# Q-value состояния: [-1.9480135 -1.9433931 -1.9459422]
# Действие: no push
# Q-value состояния: [-1.9480157 -1.9433931 -1.9459429]
# Действие: no push
# Q-value состояния: [-1.9480178 -1.943393  -1.9459436]
# Действие: no push
# Q-value состояния: [-1.9480199 -1.9433924 -1.9459443]
# Действие: no push
# Q-value состояния: [-1.9480215 -1.9433918 -1.945945 ]
# Действие: no push
# Q-value состояния: [-1.948023 -1.943391 -1.945946]
# Действие: no push
# Q-value состояния: [-1.9480244 -1.9433897 -1.9459467]
# Действие: no push
# Q-value состояния: [-1.9480256 -1.9433883 -1.9459476]
# Действие: no push
# Q-value состояния: [-1.9480265 -1.9433864 -1.9459488]
# Действие: no push
# Q-value состояния: [-1.9480274 -1.9433846 -1.9459493]
# Действие: no push
# Q-value состояния: [-1.9480278 -1.9433826 -1.9459505]
# Действие: no push
# Q-value состояния: [-1.948028  -1.9433805 -1.9459515]
# Действие: no push
# Q-value состояния: [-1.948028  -1.943378  -1.9459524]
# Действие: no push
# Q-value состояния: [-1.9480278 -1.9433753 -1.9459534]
# Действие: no push
# Q-value состояния: [-1.9480275 -1.9433728 -1.9459543]
# Действие: no push
# Q-value состояния: [-1.9480267 -1.94337   -1.9459553]
# Действие: no push
# Q-value состояния: [-1.9480258 -1.9433671 -1.945956 ]
# Действие: no push
# Q-value состояния: [-1.9480247 -1.9433639 -1.945957 ]
# Действие: no push
# Q-value состояния: [-1.9480234 -1.943361  -1.9459577]
# Действие: no push
# Q-value состояния: [-1.9480221 -1.9433581 -1.9459584]
# Действие: no push
# Q-value состояния: [-1.9480202 -1.9433551 -1.9459589]
# Действие: no push
# Q-value состояния: [-1.9480183 -1.9433519 -1.94596  ]
# Действие: no push
# Q-value состояния: [-1.9480163 -1.943349  -1.9459603]
# Действие: no push
# Q-value состояния: [-1.9480143 -1.9433463 -1.9459605]
# Действие: no push
# Q-value состояния: [-1.9480118 -1.9433434 -1.9459612]
# Действие: no push
# Q-value состояния: [-1.9480094 -1.9433409 -1.9459615]
# Действие: no push
# Q-value состояния: [-1.9480069 -1.9433382 -1.9459617]
# Действие: no push
# Q-value состояния: [-1.9480041 -1.943336  -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9480015 -1.9433335 -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9479989 -1.9433315 -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9479961 -1.9433297 -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9479934 -1.943328  -1.945962 ]
# Действие: no push
# Q-value состояния: [-1.9479907 -1.9433267 -1.9459617]
# Действие: no push
# Время обучения модели при discount_factor = 0.5 : 37.32334756851196 секунд.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.99, mean_reward:-200.00 +/- 0.00
# После обучения модели с discount_factor = 0.99, mean_reward:-200.00 +/- 0.00
# Q-value состояния: [-4.864693  -4.868975  -4.8654537]
# Действие: push left
# Q-value состояния: [-4.864457  -4.8687263 -4.8651786]
# Действие: push left
# Q-value состояния: [-4.8642025 -4.868447  -4.8648767]
# Действие: push left
# Q-value состояния: [-4.863931 -4.86814  -4.864549]
# Действие: push left
# Q-value состояния: [-4.863644  -4.867808  -4.8641996]
# Действие: push left
# Q-value состояния: [-4.8633447 -4.867453  -4.863829 ]
# Действие: push left
# Q-value состояния: [-4.863035  -4.8670774 -4.863442 ]
# Действие: push left
# Q-value состояния: [-4.8627167 -4.866685  -4.8630395]
# Действие: push left
# Q-value состояния: [-4.8623924 -4.8662767 -4.8626266]
# Действие: push left
# Q-value состояния: [-4.8620644 -4.865857  -4.8622046]
# Действие: push left
# Q-value состояния: [-4.8617353 -4.865429  -4.8617773]
# Действие: push left
# Q-value состояния: [-4.8614073 -4.8649955 -4.8613486]
# Действие: push right
# Q-value состояния: [-4.861721 -4.865233 -4.861664]
# Действие: push right
# Q-value состояния: [-4.8620915 -4.865552  -4.8620567]
# Действие: push right
# Q-value состояния: [-4.8625164 -4.86595   -4.8625245]
# Действие: push left
# Q-value состояния: [-4.862354  -4.865751  -4.8623204]
# Действие: push right
# Q-value состояния: [-4.862826  -4.866217  -4.8628535]
# Действие: push left
# Q-value состояния: [-4.862709 -4.866084 -4.862712]
# Действие: push left
# Q-value состояния: [-4.862586 -4.86594  -4.862561]
# Действие: push right
# Q-value состояния: [-4.8630953 -4.8664603 -4.863146 ]
# Действие: push left
# Q-value состояния: [-4.8630147 -4.86638   -4.863054 ]
# Действие: push left
# Q-value состояния: [-4.8629246 -4.866287  -4.86295  ]
# Действие: push left
# Q-value состояния: [-4.862828  -4.866182  -4.8628354]
# Действие: push left
# Q-value состояния: [-4.8627234 -4.866065  -4.8627105]
# Действие: push right
# Q-value состояния: [-4.863251 -4.866613 -4.86332 ]
# Действие: push left
# Q-value состояния: [-4.8631864 -4.8665566 -4.8632517]
# Действие: push left
# Q-value состояния: [-4.863112  -4.8664875 -4.86317  ]
# Действие: push left
# Q-value состояния: [-4.8630295 -4.866405  -4.863076 ]
# Действие: push left
# Q-value состояния: [-4.862938  -4.8663096 -4.8629704]
# Действие: push left
# Q-value состояния: [-4.8628387 -4.866202  -4.8628526]
# Действие: push left
# Q-value состояния: [-4.8627324 -4.866083  -4.8627257]
# Действие: push right
# Q-value состояния: [-4.8632574 -4.866627  -4.8633323]
# Действие: push left
# Q-value состояния: [-4.863191  -4.8665695 -4.863261 ]
# Действие: push left
# Q-value состояния: [-4.863115  -4.8664975 -4.863177 ]
# Действие: push left
# Q-value состояния: [-4.8630295 -4.8664117 -4.86308  ]
# Действие: push left
# Q-value состояния: [-4.862936  -4.8663135 -4.8629713]
# Действие: push left
# Q-value состояния: [-4.862834 -4.866203 -4.862851]
# Действие: push left
# Q-value состояния: [-4.862726 -4.866081 -4.862721]
# Действие: push right
# Q-value состояния: [-4.8632493 -4.866623  -4.8633246]
# Действие: push left
# Q-value состояния: [-4.86318   -4.866562  -4.8632507]
# Действие: push left
# Q-value состояния: [-4.8631024 -4.866487  -4.863164 ]
# Действие: push left
# Q-value состояния: [-4.8630147 -4.866399  -4.863064 ]
# Действие: push left
# Q-value состояния: [-4.8629193 -4.8662972 -4.8629527]
# Действие: push left
# Q-value состояния: [-4.8628163 -4.866184  -4.86283  ]
# Действие: push left
# Q-value состояния: [-4.8627067 -4.8660603 -4.862697 ]
# Действие: push right
# Q-value состояния: [-4.8632283 -4.866599  -4.8632994]
# Действие: push left
# Q-value состояния: [-4.863158 -4.866536 -4.863224]
# Действие: push left
# Q-value состояния: [-4.8630786 -4.8664594 -4.863135 ]
# Действие: push left
# Q-value состояния: [-4.8629913 -4.8663697 -4.8630342]
# Действие: push left
# Q-value состояния: [-4.8628945 -4.8662667 -4.862921 ]
# Действие: push left
# Q-value состояния: [-4.862791  -4.8661523 -4.8627973]
# Действие: push left
# Q-value состояния: [-4.8626804 -4.866027  -4.862664 ]
# Действие: push right
# Q-value состояния: [-4.8632026 -4.866565  -4.8632655]
# Действие: push left
# Q-value состояния: [-4.863132  -4.866502  -4.8631897]
# Действие: push left
# Q-value состояния: [-4.8630524 -4.8664246 -4.863101 ]
# Действие: push left
# Q-value состояния: [-4.862965  -4.8663344 -4.863    ]
# Действие: push left
# Q-value состояния: [-4.8628693 -4.866232  -4.862888 ]
# Действие: push left
# Q-value состояния: [-4.8627663 -4.8661184 -4.862765 ]
# Действие: push right
# Q-value состояния: [-4.8632946 -4.866667  -4.863376 ]
# Действие: push left
# Q-value состояния: [-4.8632307 -4.8666134 -4.863309 ]
# Действие: push left
# Q-value состояния: [-4.863157  -4.866545  -4.8632283]
# Действие: push left
# Q-value состояния: [-4.863074  -4.8664637 -4.863135 ]
# Действие: push left
# Q-value состояния: [-4.8629823 -4.8663692 -4.8630285]
# Действие: push left
# Q-value состояния: [-4.862882  -4.8662615 -4.8629107]
# Действие: push left
# Q-value состояния: [-4.8627753 -4.866142  -4.862783 ]
# Действие: push left
# Q-value состояния: [-4.862661  -4.8660116 -4.8626447]
# Действие: push right
# Q-value состояния: [-4.863179  -4.8665457 -4.8632417]
# Действие: push left
# Q-value состояния: [-4.8631063 -4.866477  -4.8631606]
# Действие: push left
# Q-value состояния: [-4.863024  -4.866396  -4.8630676]
# Действие: push left
# Q-value состояния: [-4.862933  -4.866301  -4.8629627]
# Действие: push left
# Q-value состояния: [-4.862835  -4.8661942 -4.862847 ]
# Действие: push left
# Q-value состояния: [-4.86273   -4.8660765 -4.8627205]
# Действие: push right
# Q-value состояния: [-4.8632565 -4.866623  -4.8633285]
# Действие: push left
# Q-value состояния: [-4.863191 -4.866566 -4.863259]
# Действие: push left
# Q-value состояния: [-4.8631153 -4.866495  -4.8631763]
# Действие: push left
# Q-value состояния: [-4.863031  -4.866411  -4.8630805]
# Действие: push left
# Q-value состояния: [-4.862939 -4.866314 -4.862973]
# Действие: push left
# Q-value состояния: [-4.8628383 -4.8662047 -4.8628545]
# Действие: push left
# Q-value состояния: [-4.8627305 -4.866084  -4.862725 ]
# Действие: push right
# Q-value состояния: [-4.863255  -4.866627  -4.8633304]
# Действие: push left
# Q-value состояния: [-4.863187  -4.8665676 -4.8632574]
# Действие: push left
# Q-value состояния: [-4.8631096 -4.866494  -4.863172 ]
# Действие: push left
# Q-value состояния: [-4.8630233 -4.866407  -4.8630733]
# Действие: push left
# Q-value состояния: [-4.862928  -4.866307  -4.8629627]
# Действие: push left
# Q-value состояния: [-4.862826  -4.8661947 -4.862841 ]
# Действие: push left
# Q-value состояния: [-4.862716  -4.866071  -4.8627095]
# Действие: push right
# Q-value состояния: [-4.863239  -4.866612  -4.8633127]
# Действие: push left
# Q-value состояния: [-4.863169  -4.8665495 -4.8632374]
# Действие: push left
# Q-value состояния: [-4.86309   -4.8664737 -4.8631487]
# Действие: push left
# Q-value состояния: [-4.8630023 -4.8663836 -4.863049 ]
# Действие: push left
# Q-value состояния: [-4.8629065 -4.8662815 -4.862936 ]
# Действие: push left
# Q-value состояния: [-4.8628025 -4.866167  -4.8628135]
# Действие: push left
# Q-value состояния: [-4.8626924 -4.8660426 -4.8626795]
# Действие: push right
# Q-value состояния: [-4.8632135 -4.8665805 -4.8632812]
# Действие: push left
# Q-value состояния: [-4.863144  -4.8665175 -4.863205 ]
# Действие: push left
# Q-value состояния: [-4.863064  -4.8664403 -4.8631163]
# Действие: push left
# Q-value состояния: [-4.862976 -4.86635  -4.863015]
# Действие: push left
# Q-value состояния: [-4.86288   -4.866247  -4.8629026]
# Действие: push left
# Q-value состояния: [-4.8627763 -4.866133  -4.8627787]
# Действие: push left
# Q-value состояния: [-4.8626666 -4.866008  -4.8626456]
# Действие: push right
# Время обучения модели при discount_factor = 0.99 : 37.16668462753296 секунд.

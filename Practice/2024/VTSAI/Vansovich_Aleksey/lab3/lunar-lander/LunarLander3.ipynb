# %% [markdown]
# ## Discount factor
# **Discount factor**  - это параметр, используемый в теории управления и обучении с подкреплением для оценки стоимости будущих вознаграждений. Он обозначается символом $\gamma$ (гамма).
#
# В контексте задачи обучения с подкреплением, такой как у **DQN** алгоритма, фактор дисконтирования применяется к будущим вознаграждениям, чтобы учесть уменьшение их значения с течением времени. Фактор дисконтирования позволяет агенту принимать во внимание не только мгновенные вознаграждения, но и будущие вознаграждения, приводя к более долгосрочной стратегии.
#
# **Формула для дисконтирования будущих вознаграждений** выглядит следующим образом:
#
#  $G_t$ = $R_{t+1}$ + $\gamma$ $R_{t+2}$ + $\gamma$^2 $R_{t+3}$ + $\ldots$ = $\sum_{k=0}^{\infty}$ $\gamma$^k $R_{t+k+1}$
#
# где:
# - $G_t$ - дисконтированная сумма вознаграждений (вознаграждение с учетом будущих шагов);
# - $R_{t+k+1}$ - вознаграждение, полученное на шаге $t+k+1$;
# - $\gamma$ - фактор дисконтирования,  $0 \leq \gamma \leq 1$.
#
# Фактор дисконтирования имеет важное значение при принятии решений в условиях неопределенности, где агенту нужно учитывать как мгновенные, так и будущие вознаграждения, с учетом их временного удаления. Выбор подходящего значения для фактора дисконтирования может влиять на стратегии обучения.

# %% [markdown]
# ## Long-term и Short-term стратегия
#
# Фактор дисконтирования оказывает сильное влияние на долгосрочность стратегии.
# В контексте обучения с подкреплением и стратегий агента, термины "краткосрочные" и "долгосрочные" относятся к временным характеристикам принятия решений агентом.
#
# **Краткосрочные стратегии**:
#
# > Агент, придерживающийся краткосрочной стратегии, ориентируется в основном на текущую информацию и мгновенные вознаграждения.
# Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам. Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам.
#
#
#
#
# **Долгосрочные стратегии**:
#
#
# > Агент, придерживающийся долгосрочной стратегии, учитывает будущие вознаграждения и последствия своих действий на протяжении более длительного времени.
# Такой агент может предпочесть действия, которые могут не приносить максимальное мгновенное вознаграждение, но могут способствовать достижению более высоких наград в будущем.
#
# Когда говорят о краткосрочных или долгосрочных стратегиях в контексте обучения с подкреплением, обычно имеется в виду, как агент принимает решения, оптимизируя сумму будущих вознаграждений. Фактор дисконтирования γ в уравнении обучения с подкреплением регулирует степень учета будущих вознаграждений, и, таким образом, влияет на то, насколько агент ориентирован на краткосрочные или долгосрочные перспективы.

# %% [markdown]
# ## Метрики для оценки модели
# В данной работе мы рассмотрим некоторые метрики, которые могут быть использованы для оценки обучения модели.
# Аналогично первой лабораторной работы мы будем решать задачу в окружении CartPole-v1, а в качестве модели используем уже знакомый DQN. При этом мы обучим модель несколько разных с разным параметром Discount factor.
#
# Для оценки модели мы рассмотрим следущие метрики:
#
# *   Q-values, их поведение и сходимость.
# *   Средняя награда за эпизод.
# *   Время затрачиваемое на обучение модели.

# %% [markdown]
# ### Установка зависимостей
#
# На первом шаге мы начинаем с установки необходимых библиотек. Пакет [gymnasium](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет различные среды для обучения с подкреплением, в то время как [stable-baselines3](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет реализации различных алгоритмов обучения с подкреплением.

# %%
# Установка необходимых библиотек
# !pip install gymnasium
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)

# %% [markdown]
# Импортируем пакет, которые будут использованы в данной работе

# %%
import torch as th
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import time

# %% [markdown]
# Q-значения (Q-values) представляют собой оценки или оценочные функции, используемые в контексте обучения с подкреплением для измерения ожидаемой полезности (ценности) принятия определенного действия в конкретном состоянии.
#
# Для получения значений для нашей модели реализуем функцию, которая их извлекает из q-сети.

# %%
def q_values(model: DQN, obs: np.ndarray) -> np.ndarray:
  # Доступ к Q-network
  q_net = model.q_net

  # Конвертируем observation в PyTorch tensor
  obs_tensor = th.tensor(obs, dtype=th.float32)

  # Изменяем размерность
  obs_tensor = obs_tensor.unsqueeze(0)

  #Извлекаем Q-values
  q_values = model.q_net.forward(obs_tensor)

  return q_values.detach().numpy()[0]

# %% [markdown]
# Для наглядности результатов Q-values необходимо создать функцию для составления графика по значениям.

# %%
def plot_q_values(q_values_list):
  # Извлечение отдельных списков для каждого Q-значения
  q1_values, q2_values, q3_values, q4_values = zip(*q_values_list)

  # Построение графика
  plt.figure(figsize=(10, 6))
  plt.plot(q1_values, label='Q1 Values')
  plt.plot(q2_values, label='Q2 Values')
  plt.plot(q3_values, label='Q3 Values')
  plt.plot(q4_values, label='Q4 Values')
  plt.xlabel('Time')
  plt.ylabel('Q-Values')
  plt.title('Convergence of Q-Values over Time')
  plt.legend()
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Следующий блок кода служит для следующих целей:
#
# *   Создание окружения
# *   Создание модели
# *   Обучение модели
# *   Оценка модели до обучения
# *   Оценка модели после обучения
# *   Измерение времени обучени

# %%
def mean_reward(discount_factor):
  #Создание окружения
  env = gym.make("LunarLander-v2")

  #Создание модели
  model = DQN("MlpPolicy", env, verbose=1, gamma=discount_factor)

  #Количество эпизодов для оценки модели
  n_eval_episodes = 1000

  #Оценка модели до обучения
  mean_reward, std_reward = evaluate_policy(model, gym.make("LunarLander-v2"), deterministic=True, n_eval_episodes=n_eval_episodes)
  print(f"До обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

  # Засекаем начальное время
  start_time = time.time()

  #Обучение модели
  model.learn(total_timesteps=1000000, log_interval=100)

  # Засекаем время завершения
  end_time = time.time()

  #Оценка модели после обучения
  mean_reward, std_reward = evaluate_policy(model, gym.make("LunarLander-v2"), deterministic=True, n_eval_episodes=n_eval_episodes)
  print(f"После обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
  model.save(f"dqn_cartpole_{discount_factor}")
  del model

  # Вычисляем время обучений
  learn_time = end_time - start_time
  return env, learn_time

# %% [markdown]
# Q-values необходимо вычислять для некоторого набора предсказаний модели, реализуем для этого функцию

# %%
def q_values_calculation(discount_factor, env):
  #Загружаем созданную и созраненную модель
  model = DQN.load(f"dqn_cartpole_{discount_factor}")

  #В CartPole окружении возможны только 2 действия
  action_str = ['do nothing','fire left orientation engine', 'fire main engine', 'fire right orientation engine']
  q_values_list = []

  obs, info = env.reset()
  for _ in range(100):
      q_val = q_values(model,obs)
      q_values_list.append(q_val)
      action, _states = model.predict(obs, deterministic=True)

      print(f"Q-value состояния do nothing={q_val[0]:.2f} fire left orientation engine={q_val[1]:.2f} fire main engine={q_val[2]:.2f} fire right orientation engine={q_val[3]:.2f}")
      print(f"Действие: {action_str[action]}")

      obs, reward, terminated, truncated, info = env.step(action)

  return q_values_list

# %% [markdown]
# Изменение значения discount factor (γ) в DQN может оказать существенное воздействие на обучение агента и его стратегию.
#
# Воздействие на краткосрочные или долгосрочные стратегии:
#
# *   При более высоком значении γ (ближе к 1) агент будет больше учитывать будущие вознаграждения, что может способствовать формированию более долгосрочных стратегий.
#
# *  При более низком значении γ (ближе к 0) агент будет более склонен к учету только мгновенных вознаграждений, что может привести к формированию краткосрочных стратегий.
#
#
# Влияние на стабильность обучения:
#
# *   Высокий γ может сделать обучение более стабильным, особенно в средах с большим количеством шума или случайности.
# *   Низкий γ может привести к более нестабильному обучению, так как агент будет менее чувствителен к долгосрочным последствиям своих действий.
#
#
# Влияние на временные рамки обучения:
#
#
# *   Различные значения γ могут потребовать различных временных рамок обучения для достижения оптимальных стратегий.
# *   Изменение γ может потребовать перенастройки гиперпараметров и количества шагов обучения.
#
#
# Адаптивность к задаче:
# *  Эффективное значение γ может зависеть от конкретной задачи. Например, в задачах с большой неопределенностью и случайностью, более высокий γ может быть полезен.
#
#
# Экспериментальные результаты:
# *  Чтобы определить оптимальное значение γ для вашей конкретной задачи, часто требуется провести эксперименты с различными значениями, а затем анализировать результаты.

# %% [markdown]
# Рассмотрим 3 значения discount factor

# %%
discount_factors = [0.01,0.5,0.99]

# %%
for i in range(len(discount_factors)):
  environment, time_to_lrn = mean_reward(discount_factors[i])
  q_vals = q_values_calculation(discount_factors[i], environment)
  plot_q_values(q_vals)
  print(f'Время обучения модели при discount_factor = {discount_factors[i]} : {time_to_lrn} секунд.')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.01, mean_reward:-583.14 +/- 165.10
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4028     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4776     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5040     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5228     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 37345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5320     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 46588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -234     |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2598     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 61834    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.773    |
# |    n_updates        | 2958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 396      |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1309     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 101479   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 12869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 318      |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 1073     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 133282   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.78     |
# |    n_updates        | 20820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 987      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 162063   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.98     |
# |    n_updates        | 28015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 313      |
# |    ep_rew_mean      | -62.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 928      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 193335   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.528    |
# |    n_updates        | 35833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 334      |
# |    ep_rew_mean      | -34.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 887      |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 226777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.747    |
# |    n_updates        | 44194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 326      |
# |    ep_rew_mean      | -25.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 858      |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 259359   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 52339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 323      |
# |    ep_rew_mean      | -61.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 840      |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 291661   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.34     |
# |    n_updates        | 60415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 337      |
# |    ep_rew_mean      | -9.77    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 824      |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 325375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.652    |
# |    n_updates        | 68843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 352      |
# |    ep_rew_mean      | -17.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 811      |
# |    time_elapsed     | 444      |
# |    total_timesteps  | 360607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.865    |
# |    n_updates        | 77651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 351      |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 804      |
# |    time_elapsed     | 491      |
# |    total_timesteps  | 395726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.336    |
# |    n_updates        | 86431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 357      |
# |    ep_rew_mean      | -28.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 795      |
# |    time_elapsed     | 542      |
# |    total_timesteps  | 431429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 95357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 352      |
# |    ep_rew_mean      | -23.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 789      |
# |    time_elapsed     | 591      |
# |    total_timesteps  | 466611   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.743    |
# |    n_updates        | 104152   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 358      |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 781      |
# |    time_elapsed     | 643      |
# |    total_timesteps  | 502439   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.524    |
# |    n_updates        | 113109   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 364      |
# |    ep_rew_mean      | -18.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 776      |
# |    time_elapsed     | 694      |
# |    total_timesteps  | 538819   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.284    |
# |    n_updates        | 122204   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 341      |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 774      |
# |    time_elapsed     | 739      |
# |    total_timesteps  | 572917   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.39     |
# |    n_updates        | 130729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 349      |
# |    ep_rew_mean      | -23.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 771      |
# |    time_elapsed     | 787      |
# |    total_timesteps  | 607775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.361    |
# |    n_updates        | 139443   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 374      |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2300     |
# |    fps              | 769      |
# |    time_elapsed     | 838      |
# |    total_timesteps  | 645154   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.36     |
# |    n_updates        | 148788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 347      |
# |    ep_rew_mean      | -4.14    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 767      |
# |    time_elapsed     | 885      |
# |    total_timesteps  | 679854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.567    |
# |    n_updates        | 157463   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 349      |
# |    ep_rew_mean      | -35.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 766      |
# |    time_elapsed     | 932      |
# |    total_timesteps  | 714738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.329    |
# |    n_updates        | 166184   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 765      |
# |    time_elapsed     | 972      |
# |    total_timesteps  | 744099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.939    |
# |    n_updates        | 173524   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 351      |
# |    ep_rew_mean      | -13.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 764      |
# |    time_elapsed     | 1019     |
# |    total_timesteps  | 779181   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 182295   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 362      |
# |    ep_rew_mean      | -12      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 762      |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 815353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.572    |
# |    n_updates        | 191338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 343      |
# |    ep_rew_mean      | -22.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 760      |
# |    time_elapsed     | 1116     |
# |    total_timesteps  | 849680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.952    |
# |    n_updates        | 199919   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 322      |
# |    ep_rew_mean      | -16.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 758      |
# |    time_elapsed     | 1162     |
# |    total_timesteps  | 881887   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.555    |
# |    n_updates        | 207971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 311      |
# |    ep_rew_mean      | -22.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3100     |
# |    fps              | 756      |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 913025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.373    |
# |    n_updates        | 215756   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 347      |
# |    ep_rew_mean      | -22.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3200     |
# |    fps              | 755      |
# |    time_elapsed     | 1255     |
# |    total_timesteps  | 947761   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.184    |
# |    n_updates        | 224440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 315      |
# |    ep_rew_mean      | -36.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3300     |
# |    fps              | 753      |
# |    time_elapsed     | 1299     |
# |    total_timesteps  | 979293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.58     |
# |    n_updates        | 232323   |
# ----------------------------------
# После обучения модели с discount_factor = 0.01, mean_reward:-40.95 +/- 160.68
# Q-value состояния do nothing=-1.31 fire left orientation engine=-2.43 fire main engine=-0.32 fire right orientation engine=-0.01
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.11 fire left orientation engine=-2.21 fire main engine=0.02 fire right orientation engine=0.16
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.93 fire left orientation engine=-2.01 fire main engine=0.36 fire right orientation engine=0.33
# Действие: fire main engine
# Q-value состояния do nothing=-1.05 fire left orientation engine=-2.15 fire main engine=-0.01 fire right orientation engine=0.23
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.84 fire left orientation engine=-1.92 fire main engine=0.36 fire right orientation engine=0.41
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.63 fire left orientation engine=-1.68 fire main engine=0.76 fire right orientation engine=0.61
# Действие: fire main engine
# Q-value состояния do nothing=-0.65 fire left orientation engine=-1.70 fire main engine=0.71 fire right orientation engine=0.59
# Действие: fire main engine
# Q-value состояния do nothing=-0.67 fire left orientation engine=-1.72 fire main engine=0.54 fire right orientation engine=0.59
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.47 fire left orientation engine=-1.49 fire main engine=0.94 fire right orientation engine=0.77
# Действие: fire main engine
# Q-value состояния do nothing=-0.48 fire left orientation engine=-1.49 fire main engine=0.87 fire right orientation engine=0.78
# Действие: fire main engine
# Q-value состояния do nothing=-0.58 fire left orientation engine=-1.62 fire main engine=0.57 fire right orientation engine=0.68
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.37 fire left orientation engine=-1.38 fire main engine=0.98 fire right orientation engine=0.87
# Действие: fire main engine
# Q-value состояния do nothing=-0.41 fire left orientation engine=-1.42 fire main engine=0.81 fire right orientation engine=0.85
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.16 fire left orientation engine=-1.14 fire main engine=1.27 fire right orientation engine=1.08
# Действие: fire main engine
# Q-value состояния do nothing=-0.28 fire left orientation engine=-1.28 fire main engine=0.97 fire right orientation engine=0.96
# Действие: fire main engine
# Q-value состояния do nothing=-0.36 fire left orientation engine=-1.38 fire main engine=0.74 fire right orientation engine=0.89
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.24 fire left orientation engine=-1.23 fire main engine=1.09 fire right orientation engine=0.97
# Действие: fire main engine
# Q-value состояния do nothing=-0.39 fire left orientation engine=-1.38 fire main engine=0.80 fire right orientation engine=0.81
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.50 fire left orientation engine=-1.43 fire main engine=0.86 fire right orientation engine=0.59
# Действие: fire main engine
# Q-value состояния do nothing=-0.74 fire left orientation engine=-1.68 fire main engine=0.48 fire right orientation engine=0.30
# Действие: fire main engine
# Q-value состояния do nothing=-1.06 fire left orientation engine=-2.01 fire main engine=-0.02 fire right orientation engine=-0.04
# Действие: fire main engine
# Q-value состояния do nothing=-1.02 fire left orientation engine=-1.92 fire main engine=-0.45 fire right orientation engine=-0.01
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.38 fire left orientation engine=-2.25 fire main engine=-0.31 fire right orientation engine=-0.45
# Действие: fire main engine
# Q-value состояния do nothing=-1.25 fire left orientation engine=-2.08 fire main engine=-0.18 fire right orientation engine=-0.33
# Действие: fire main engine
# Q-value состояния do nothing=-1.28 fire left orientation engine=-2.09 fire main engine=0.00 fire right orientation engine=-0.37
# Действие: fire main engine
# Q-value состояния do nothing=-1.10 fire left orientation engine=-1.88 fire main engine=-0.13 fire right orientation engine=-0.17
# Действие: fire main engine
# Q-value состояния do nothing=-1.23 fire left orientation engine=-2.00 fire main engine=-0.18 fire right orientation engine=-0.31
# Действие: fire main engine
# Q-value состояния do nothing=-1.30 fire left orientation engine=-2.06 fire main engine=-0.37 fire right orientation engine=-0.36
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.53 fire left orientation engine=-2.26 fire main engine=-0.39 fire right orientation engine=-0.66
# Действие: fire main engine
# Q-value состояния do nothing=-1.64 fire left orientation engine=-2.36 fire main engine=-0.45 fire right orientation engine=-0.77
# Действие: fire main engine
# Q-value состояния do nothing=-1.70 fire left orientation engine=-2.40 fire main engine=-0.44 fire right orientation engine=-0.83
# Действие: fire main engine
# Q-value состояния do nothing=-1.81 fire left orientation engine=-2.49 fire main engine=-0.47 fire right orientation engine=-0.95
# Действие: fire main engine
# Q-value состояния do nothing=-1.75 fire left orientation engine=-2.44 fire main engine=-0.44 fire right orientation engine=-0.87
# Действие: fire main engine
# Q-value состояния do nothing=-1.85 fire left orientation engine=-2.51 fire main engine=-0.49 fire right orientation engine=-0.96
# Действие: fire main engine
# Q-value состояния do nothing=-1.80 fire left orientation engine=-2.47 fire main engine=-0.40 fire right orientation engine=-0.91
# Действие: fire main engine
# Q-value состояния do nothing=-1.83 fire left orientation engine=-2.50 fire main engine=-0.44 fire right orientation engine=-0.94
# Действие: fire main engine
# Q-value состояния do nothing=-1.89 fire left orientation engine=-2.54 fire main engine=-0.43 fire right orientation engine=-1.01
# Действие: fire main engine
# Q-value состояния do nothing=-1.92 fire left orientation engine=-2.57 fire main engine=-0.43 fire right orientation engine=-1.04
# Действие: fire main engine
# Q-value состояния do nothing=-1.90 fire left orientation engine=-2.53 fire main engine=-0.61 fire right orientation engine=-0.98
# Действие: fire main engine
# Q-value состояния do nothing=-1.85 fire left orientation engine=-2.48 fire main engine=-0.76 fire right orientation engine=-0.90
# Действие: fire main engine
# Q-value состояния do nothing=-1.73 fire left orientation engine=-2.36 fire main engine=-0.67 fire right orientation engine=-0.73
# Действие: fire main engine
# Q-value состояния do nothing=-1.62 fire left orientation engine=-2.26 fire main engine=-0.61 fire right orientation engine=-0.58
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.85 fire left orientation engine=-2.46 fire main engine=-0.63 fire right orientation engine=-0.85
# Действие: fire main engine
# Q-value состояния do nothing=-1.66 fire left orientation engine=-2.28 fire main engine=-0.59 fire right orientation engine=-0.59
# Действие: fire main engine
# Q-value состояния do nothing=-1.64 fire left orientation engine=-2.28 fire main engine=-0.55 fire right orientation engine=-0.55
# Действие: fire main engine
# Q-value состояния do nothing=-1.66 fire left orientation engine=-2.31 fire main engine=-0.49 fire right orientation engine=-0.57
# Действие: fire main engine
# Q-value состояния do nothing=-1.54 fire left orientation engine=-2.21 fire main engine=-0.47 fire right orientation engine=-0.40
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.80 fire left orientation engine=-2.45 fire main engine=-0.49 fire right orientation engine=-0.76
# Действие: fire main engine
# Q-value состояния do nothing=-1.73 fire left orientation engine=-2.40 fire main engine=-0.36 fire right orientation engine=-0.67
# Действие: fire main engine
# Q-value состояния do nothing=-1.68 fire left orientation engine=-2.37 fire main engine=-0.20 fire right orientation engine=-0.62
# Действие: fire main engine
# Q-value состояния do nothing=-1.45 fire left orientation engine=-2.18 fire main engine=-0.27 fire right orientation engine=-0.31
# Действие: fire main engine
# Q-value состояния do nothing=-0.83 fire left orientation engine=-1.49 fire main engine=-0.57 fire right orientation engine=0.16
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.32 fire left orientation engine=-2.03 fire main engine=-0.30 fire right orientation engine=-0.31
# Действие: fire main engine
# Q-value состояния do nothing=-0.76 fire left orientation engine=-1.42 fire main engine=-0.64 fire right orientation engine=0.13
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.19 fire left orientation engine=-1.89 fire main engine=-0.31 fire right orientation engine=-0.31
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.76 fire left orientation engine=-2.52 fire main engine=0.08 fire right orientation engine=-0.80
# Действие: fire main engine
# Q-value состояния do nothing=-1.41 fire left orientation engine=-2.15 fire main engine=-0.10 fire right orientation engine=-0.56
# Действие: fire main engine
# Q-value состояния do nothing=-1.09 fire left orientation engine=-1.79 fire main engine=-0.29 fire right orientation engine=-0.35
# Действие: fire main engine
# Q-value состояния do nothing=-0.62 fire left orientation engine=-1.28 fire main engine=-0.91 fire right orientation engine=0.05
# Действие: fire right orientation engine
# Q-value состояния do nothing=-0.96 fire left orientation engine=-1.65 fire main engine=-0.65 fire right orientation engine=-0.34
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.44 fire left orientation engine=-2.17 fire main engine=-0.35 fire right orientation engine=-0.79
# Действие: fire main engine
# Q-value состояния do nothing=-0.81 fire left orientation engine=-1.46 fire main engine=-1.05 fire right orientation engine=-0.31
# Действие: fire right orientation engine
# Q-value состояния do nothing=-1.22 fire left orientation engine=-1.81 fire main engine=-0.68 fire right orientation engine=-0.78
# Действие: fire main engine
# Q-value состояния do nothing=-1.17 fire left orientation engine=-1.62 fire main engine=-0.80 fire right orientation engine=-0.92
# Действие: fire main engine
# Q-value состояния do nothing=-0.85 fire left orientation engine=-0.96 fire main engine=-2.43 fire right orientation engine=-0.96
# Действие: do nothing
# Q-value состояния do nothing=-1.42 fire left orientation engine=-1.46 fire main engine=-2.02 fire right orientation engine=-1.55
# Действие: do nothing
# Q-value состояния do nothing=-2.63 fire left orientation engine=-2.63 fire main engine=-1.52 fire right orientation engine=-2.66
# Действие: fire main engine
# Q-value состояния do nothing=-2.23 fire left orientation engine=-1.90 fire main engine=-2.83 fire right orientation engine=-2.70
# Действие: fire left orientation engine
# Q-value состояния do nothing=-3.53 fire left orientation engine=-3.34 fire main engine=-1.86 fire right orientation engine=-3.71
# Действие: fire main engine
# Q-value состояния do nothing=-1.90 fire left orientation engine=-0.77 fire main engine=-6.00 fire right orientation engine=-3.35
# Действие: fire left orientation engine
# Q-value состояния do nothing=-3.56 fire left orientation engine=-2.51 fire main engine=-5.03 fire right orientation engine=-4.81
# Действие: fire left orientation engine
# Q-value состояния do nothing=-4.13 fire left orientation engine=-3.24 fire main engine=-4.28 fire right orientation engine=-5.09
# Действие: fire left orientation engine
# Q-value состояния do nothing=-4.01 fire left orientation engine=-3.21 fire main engine=-3.52 fire right orientation engine=-4.90
# Действие: fire left orientation engine
# Q-value состояния do nothing=-3.94 fire left orientation engine=-3.20 fire main engine=-2.93 fire right orientation engine=-4.77
# Действие: fire main engine
# Q-value состояния do nothing=-3.04 fire left orientation engine=-1.97 fire main engine=-5.72 fire right orientation engine=-4.35
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.97 fire left orientation engine=-1.95 fire main engine=-5.18 fire right orientation engine=-4.25
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.87 fire left orientation engine=-1.88 fire main engine=-4.57 fire right orientation engine=-4.11
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.83 fire left orientation engine=-1.87 fire main engine=-4.06 fire right orientation engine=-4.03
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.75 fire left orientation engine=-1.82 fire main engine=-3.52 fire right orientation engine=-3.91
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.64 fire left orientation engine=-1.73 fire main engine=-2.87 fire right orientation engine=-3.78
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.45 fire left orientation engine=-1.55 fire main engine=-2.19 fire right orientation engine=-3.57
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.33 fire left orientation engine=-1.43 fire main engine=-1.59 fire right orientation engine=-3.43
# Действие: fire left orientation engine
# Q-value состояния do nothing=-2.10 fire left orientation engine=-1.19 fire main engine=-1.13 fire right orientation engine=-3.20
# Действие: fire main engine
# Q-value состояния do nothing=-1.93 fire left orientation engine=-0.99 fire main engine=-1.38 fire right orientation engine=-3.13
# Действие: fire left orientation engine
# Q-value состояния do nothing=-1.60 fire left orientation engine=-0.66 fire main engine=-0.82 fire right orientation engine=-2.80
# Действие: fire left orientation engine
# Q-value состояния do nothing=-1.30 fire left orientation engine=-0.36 fire main engine=-0.29 fire right orientation engine=-2.50
# Действие: fire main engine
# Q-value состояния do nothing=-1.24 fire left orientation engine=-0.28 fire main engine=-0.54 fire right orientation engine=-2.49
# Действие: fire left orientation engine
# Q-value состояния do nothing=-1.00 fire left orientation engine=-0.04 fire main engine=-0.05 fire right orientation engine=-2.23
# Действие: fire left orientation engine
# Q-value состояния do nothing=-0.77 fire left orientation engine=0.19 fire main engine=0.39 fire right orientation engine=-1.97
# Действие: fire main engine
# Q-value состояния do nothing=-0.67 fire left orientation engine=0.31 fire main engine=-0.22 fire right orientation engine=-1.99
# Действие: fire left orientation engine
# Q-value состояния do nothing=-0.49 fire left orientation engine=0.48 fire main engine=0.14 fire right orientation engine=-1.78
# Действие: fire left orientation engine
# Q-value состояния do nothing=-0.28 fire left orientation engine=0.68 fire main engine=0.57 fire right orientation engine=-1.55
# Действие: fire left orientation engine
# Q-value состояния do nothing=-0.04 fire left orientation engine=0.92 fire main engine=1.01 fire right orientation engine=-1.28
# Действие: fire main engine
# Q-value состояния do nothing=-0.01 fire left orientation engine=0.96 fire main engine=0.86 fire right orientation engine=-1.28
# Действие: fire left orientation engine
# Q-value состояния do nothing=0.18 fire left orientation engine=1.15 fire main engine=1.27 fire right orientation engine=-1.04
# Действие: fire main engine
# Q-value состояния do nothing=0.33 fire left orientation engine=1.32 fire main engine=0.95 fire right orientation engine=-0.99
# Действие: fire left orientation engine
# Q-value состояния do nothing=0.56 fire left orientation engine=1.54 fire main engine=1.47 fire right orientation engine=-0.69
# Действие: fire left orientation engine
# Q-value состояния do nothing=0.77 fire left orientation engine=1.76 fire main engine=1.93 fire right orientation engine=-0.43
# Действие: fire main engine
# Q-value состояния do nothing=0.76 fire left orientation engine=1.76 fire main engine=1.78 fire right orientation engine=-0.47
# Действие: fire main engine
# Q-value состояния do nothing=0.89 fire left orientation engine=1.91 fire main engine=1.70 fire right orientation engine=-0.39
# Действие: fire left orientation engine
# Время обучения модели при discount_factor = 0.01 : 1329.1180267333984 секунд.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.5, mean_reward:-494.70 +/- 151.65
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5691     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5710     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5109     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 27636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 4786     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 36869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 4969     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 46127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -255     |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2398     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 63259    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.558    |
# |    n_updates        | 3314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 315      |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1381     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 94791    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 11197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 584      |
# |    ep_rew_mean      | -12.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 972      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 153171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 25792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 483      |
# |    ep_rew_mean      | -95.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 890      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 201431   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.473    |
# |    n_updates        | 37857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 503      |
# |    ep_rew_mean      | -84.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 848      |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 251692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.408    |
# |    n_updates        | 50422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 513      |
# |    ep_rew_mean      | -80      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 822      |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 302975   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.495    |
# |    n_updates        | 63243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | -62.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 802      |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 345475   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 73868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 468      |
# |    ep_rew_mean      | 9.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 787      |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 392304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.433    |
# |    n_updates        | 85575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 4.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 778      |
# |    time_elapsed     | 559      |
# |    total_timesteps  | 435599   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 96399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 457      |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 770      |
# |    time_elapsed     | 624      |
# |    total_timesteps  | 481308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.468    |
# |    n_updates        | 107826   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 763      |
# |    time_elapsed     | 685      |
# |    total_timesteps  | 523638   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.559    |
# |    n_updates        | 118409   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | -10.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 759      |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 568619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.282    |
# |    n_updates        | 129654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 395      |
# |    ep_rew_mean      | -4.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 756      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 608101   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.408    |
# |    n_updates        | 139525   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 754      |
# |    time_elapsed     | 864      |
# |    total_timesteps  | 651587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.205    |
# |    n_updates        | 150396   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 387      |
# |    ep_rew_mean      | -24.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 751      |
# |    time_elapsed     | 918      |
# |    total_timesteps  | 690308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.511    |
# |    n_updates        | 160076   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 413      |
# |    ep_rew_mean      | 7.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 748      |
# |    time_elapsed     | 977      |
# |    total_timesteps  | 731638   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.56     |
# |    n_updates        | 170409   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 747      |
# |    time_elapsed     | 1035     |
# |    total_timesteps  | 774188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.275    |
# |    n_updates        | 181046   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 380      |
# |    ep_rew_mean      | -9.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2300     |
# |    fps              | 747      |
# |    time_elapsed     | 1087     |
# |    total_timesteps  | 812175   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.672    |
# |    n_updates        | 190543   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 352      |
# |    ep_rew_mean      | -26.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 746      |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 847337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.298    |
# |    n_updates        | 199334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 385      |
# |    ep_rew_mean      | -15.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 746      |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 885851   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.213    |
# |    n_updates        | 208962   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 377      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 745      |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 923600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.45     |
# |    n_updates        | 218399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 347      |
# |    ep_rew_mean      | -41.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 745      |
# |    time_elapsed     | 1284     |
# |    total_timesteps  | 958311   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.422    |
# |    n_updates        | 227077   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 369      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 744      |
# |    time_elapsed     | 1335     |
# |    total_timesteps  | 995253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.961    |
# |    n_updates        | 236313   |
# ----------------------------------
# После обучения модели с discount_factor = 0.5, mean_reward:-8.21 +/- 165.24
# ...
# |    total_timesteps  | 955523   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 226380   |
# ----------------------------------
# После обучения модели с discount_factor = 0.99, mean_reward:-41.33 +/- 21.52
# Q-value состояния do nothing=66.96 fire left orientation engine=67.87 fire main engine=67.10 fire right orientation engine=65.63
# Действие: fire left orientation engine
# Q-value состояния do nothing=67.91 fire left orientation engine=68.83 fire main engine=68.07 fire right orientation engine=66.61
# Действие: fire left orientation engine
# Q-value состояния do nothing=69.42 fire left orientation engine=70.23 fire main engine=69.56 fire right orientation engine=68.23
# Действие: fire left orientation engine
# Q-value состояния do nothing=71.12 fire left orientation engine=71.84 fire main engine=71.33 fire right orientation engine=70.04
# Действие: fire left orientation engine
# Q-value состояния do nothing=72.80 fire left orientation engine=73.39 fire main engine=73.07 fire right orientation engine=71.88
# Действие: fire left orientation engine
# Q-value состояния do nothing=74.16 fire left orientation engine=74.64 fire main engine=74.55 fire right orientation engine=73.41
# Действие: fire left orientation engine
# Q-value состояния do nothing=75.21 fire left orientation engine=75.55 fire main engine=75.71 fire right orientation engine=74.62
# Действие: fire main engine
# Q-value состояния do nothing=73.85 fire left orientation engine=74.20 fire main engine=74.27 fire right orientation engine=73.26
# Действие: fire main engine
# Q-value состояния do nothing=71.74 fire left orientation engine=72.11 fire main engine=72.00 fire right orientation engine=71.13
# Действие: fire left orientation engine
# Q-value состояния do nothing=72.22 fire left orientation engine=72.35 fire main engine=72.58 fire right orientation engine=71.86
# Действие: fire main engine
# Q-value состояния do nothing=69.04 fire left orientation engine=69.14 fire main engine=69.21 fire right orientation engine=68.71
# Действие: fire main engine
# Q-value состояния do nothing=68.46 fire left orientation engine=68.52 fire main engine=68.63 fire right orientation engine=68.20
# Действие: fire main engine
# Q-value состояния do nothing=64.42 fire left orientation engine=64.43 fire main engine=64.44 fire right orientation engine=64.20
# Действие: fire main engine
# Q-value состояния do nothing=63.13 fire left orientation engine=63.09 fire main engine=63.14 fire right orientation engine=62.97
# Действие: fire main engine
# Q-value состояния do nothing=59.00 fire left orientation engine=58.92 fire main engine=58.91 fire right orientation engine=58.89
# Действие: do nothing
# Q-value состояния do nothing=61.49 fire left orientation engine=61.34 fire main engine=61.52 fire right orientation engine=61.47
# Действие: fire main engine
# Q-value состояния do nothing=57.58 fire left orientation engine=57.39 fire main engine=57.50 fire right orientation engine=57.61
# Действие: fire right orientation engine
# Q-value состояния do nothing=61.97 fire left orientation engine=61.88 fire main engine=62.02 fire right orientation engine=61.92
# Действие: fire main engine
# Q-value состояния do nothing=60.80 fire left orientation engine=60.68 fire main engine=60.83 fire right orientation engine=60.79
# Действие: fire main engine
# Q-value состояния do nothing=58.49 fire left orientation engine=58.31 fire main engine=58.44 fire right orientation engine=58.53
# Действие: fire right orientation engine
# Q-value состояния do nothing=61.56 fire left orientation engine=61.46 fire main engine=61.67 fire right orientation engine=61.53
# Действие: fire main engine
# Q-value состояния do nothing=61.43 fire left orientation engine=61.30 fire main engine=61.57 fire right orientation engine=61.44
# Действие: fire main engine
# Q-value состояния do nothing=60.09 fire left orientation engine=59.92 fire main engine=60.20 fire right orientation engine=60.13
# Действие: fire main engine
# Q-value состояния do nothing=58.38 fire left orientation engine=58.17 fire main engine=58.43 fire right orientation engine=58.47
# Действие: fire right orientation engine
# Q-value состояния do nothing=61.18 fire left orientation engine=61.07 fire main engine=61.40 fire right orientation engine=61.17
# Действие: fire main engine
# Q-value состояния do nothing=57.88 fire left orientation engine=57.73 fire main engine=57.98 fire right orientation engine=57.91
# Действие: fire main engine
# Q-value состояния do nothing=54.49 fire left orientation engine=54.32 fire main engine=54.45 fire right orientation engine=54.54
# Действие: fire right orientation engine
# Q-value состояния do nothing=57.26 fire left orientation engine=57.27 fire main engine=57.42 fire right orientation engine=57.12
# Действие: fire main engine
# Q-value состояния do nothing=55.13 fire left orientation engine=55.12 fire main engine=55.19 fire right orientation engine=55.02
# Действие: fire main engine
# Q-value состояния do nothing=55.20 fire left orientation engine=55.18 fire main engine=55.27 fire right orientation engine=55.11
# Действие: fire main engine
# Q-value состояния do nothing=54.53 fire left orientation engine=54.48 fire main engine=54.57 fire right orientation engine=54.46
# Действие: fire main engine
# Q-value состояния do nothing=52.58 fire left orientation engine=52.50 fire main engine=52.52 fire right orientation engine=52.55
# Действие: do nothing
# Q-value состояния do nothing=54.67 fire left orientation engine=54.56 fire main engine=54.71 fire right orientation engine=54.67
# Действие: fire main engine
# Q-value состояния do nothing=51.32 fire left orientation engine=51.15 fire main engine=51.22 fire right orientation engine=51.37
# Действие: fire right orientation engine
# Q-value состояния do nothing=53.90 fire left orientation engine=53.87 fire main engine=53.95 fire right orientation engine=53.83
# Действие: fire main engine
# Q-value состояния do nothing=51.79 fire left orientation engine=51.74 fire main engine=51.77 fire right orientation engine=51.73
# Действие: do nothing
# Q-value состояния do nothing=53.82 fire left orientation engine=53.75 fire main engine=53.89 fire right orientation engine=53.79
# Действие: fire main engine
# Q-value состояния do nothing=53.43 fire left orientation engine=53.35 fire main engine=53.53 fire right orientation engine=53.39
# Действие: fire main engine
# Q-value состояния do nothing=50.19 fire left orientation engine=50.10 fire main engine=50.21 fire right orientation engine=50.16
# Действие: fire main engine
# Q-value состояния do nothing=49.73 fire left orientation engine=49.59 fire main engine=49.74 fire right orientation engine=49.73
# Действие: fire main engine
# Q-value состояния do nothing=48.33 fire left orientation engine=48.13 fire main engine=48.33 fire right orientation engine=48.38
# Действие: fire right orientation engine
# Q-value состояния do nothing=50.98 fire left orientation engine=50.97 fire main engine=51.10 fire right orientation engine=50.86
# Действие: fire main engine
# Q-value состояния do nothing=49.22 fire left orientation engine=49.20 fire main engine=49.31 fire right orientation engine=49.10
# Действие: fire main engine
# Q-value состояния do nothing=46.25 fire left orientation engine=46.13 fire main engine=46.27 fire right orientation engine=46.18
# Действие: fire main engine
# Q-value состояния do nothing=43.85 fire left orientation engine=43.64 fire main engine=43.81 fire right orientation engine=43.81
# Действие: do nothing
# Q-value состояния do nothing=45.64 fire left orientation engine=45.48 fire main engine=45.65 fire right orientation engine=45.58
# Действие: fire main engine
# Q-value состояния do nothing=43.09 fire left orientation engine=42.86 fire main engine=43.05 fire right orientation engine=43.08
# Действие: do nothing
# Q-value состояния do nothing=44.85 fire left orientation engine=44.66 fire main engine=44.86 fire right orientation engine=44.83
# Действие: fire main engine
# Q-value состояния do nothing=44.68 fire left orientation engine=44.47 fire main engine=44.69 fire right orientation engine=44.67
# Действие: fire main engine
# Q-value состояния do nothing=42.79 fire left orientation engine=42.53 fire main engine=42.76 fire right orientation engine=42.79
# Действие: do nothing
# Q-value состояния do nothing=44.54 fire left orientation engine=44.31 fire main engine=44.56 fire right orientation engine=44.53
# Действие: fire main engine
# Q-value состояния do nothing=41.62 fire left orientation engine=41.31 fire main engine=41.57 fire right orientation engine=41.64
# Действие: fire right orientation engine
# Q-value состояния do nothing=43.96 fire left orientation engine=43.79 fire main engine=44.00 fire right orientation engine=43.83
# Действие: fire main engine
# Q-value состояния do nothing=43.24 fire left orientation engine=43.07 fire main engine=43.28 fire right orientation engine=43.10
# Действие: fire main engine
# Q-value состояния do nothing=41.51 fire left orientation engine=41.30 fire main engine=41.50 fire right orientation engine=41.38
# Действие: do nothing
# Q-value состояния do nothing=43.15 fire left orientation engine=42.98 fire main engine=43.17 fire right orientation engine=43.00
# Действие: fire main engine
# Q-value состояния do nothing=41.67 fire left orientation engine=41.47 fire main engine=41.64 fire right orientation engine=41.53
# Действие: do nothing
# Q-value состояния do nothing=43.40 fire left orientation engine=43.24 fire main engine=43.40 fire right orientation engine=43.25
# Действие: fire main engine
# Q-value состояния do nothing=40.38 fire left orientation engine=40.18 fire main engine=40.35 fire right orientation engine=40.21
# Действие: do nothing
# Q-value состояния do nothing=42.05 fire left orientation engine=41.89 fire main engine=42.04 fire right orientation engine=41.87
# Действие: do nothing
# Q-value состояния do nothing=43.68 fire left orientation engine=43.55 fire main engine=43.70 fire right orientation engine=43.48
# Действие: fire main engine
# Q-value состояния do nothing=42.43 fire left orientation engine=42.29 fire main engine=42.40 fire right orientation engine=42.25
# Действие: do nothing
# Q-value состояния do nothing=44.09 fire left orientation engine=43.98 fire main engine=44.11 fire right orientation engine=43.89
# Действие: fire main engine
# Q-value состояния do nothing=42.48 fire left orientation engine=42.35 fire main engine=42.44 fire right orientation engine=42.30
# Действие: do nothing
# Q-value состояния do nothing=44.22 fire left orientation engine=44.12 fire main engine=44.23 fire right orientation engine=44.02
# Действие: fire main engine
# Q-value состояния do nothing=43.46 fire left orientation engine=43.35 fire main engine=43.41 fire right orientation engine=43.28
# Действие: do nothing
# Q-value состояния do nothing=45.23 fire left orientation engine=45.15 fire main engine=45.26 fire right orientation engine=45.05
# Действие: fire main engine
# Q-value состояния do nothing=42.34 fire left orientation engine=42.20 fire main engine=42.26 fire right orientation engine=42.19
# Действие: do nothing
# Q-value состояния do nothing=44.21 fire left orientation engine=44.11 fire main engine=44.18 fire right orientation engine=44.05
# Действие: do nothing
# Q-value состояния do nothing=46.13 fire left orientation engine=46.02 fire main engine=46.17 fire right orientation engine=45.98
# Действие: fire main engine
# Q-value состояния do nothing=43.23 fire left orientation engine=43.08 fire main engine=43.18 fire right orientation engine=43.11
# Действие: do nothing
# Q-value состояния do nothing=45.35 fire left orientation engine=45.20 fire main engine=45.34 fire right orientation engine=45.24
# Действие: do nothing
# Q-value состояния do nothing=47.39 fire left orientation engine=47.22 fire main engine=47.47 fire right orientation engine=47.31
# Действие: fire main engine
# Q-value состояния do nothing=45.31 fire left orientation engine=45.15 fire main engine=45.37 fire right orientation engine=45.20
# Действие: fire main engine
# Q-value состояния do nothing=42.99 fire left orientation engine=42.83 fire main engine=43.05 fire right orientation engine=42.84
# Действие: fire main engine
# Q-value состояния do nothing=42.09 fire left orientation engine=41.91 fire main engine=42.14 fire right orientation engine=41.94
# Действие: fire main engine
# Q-value состояния do nothing=40.14 fire left orientation engine=39.94 fire main engine=40.18 fire right orientation engine=39.99
# Действие: fire main engine
# Q-value состояния do nothing=38.86 fire left orientation engine=38.63 fire main engine=38.86 fire right orientation engine=38.72
# Действие: do nothing
# Q-value состояния do nothing=40.53 fire left orientation engine=40.33 fire main engine=40.56 fire right orientation engine=40.39
# Действие: fire main engine
# Q-value состояния do nothing=38.23 fire left orientation engine=38.00 fire main engine=38.25 fire right orientation engine=38.06
# Действие: fire main engine
# Q-value состояния do nothing=37.43 fire left orientation engine=37.20 fire main engine=37.43 fire right orientation engine=37.29
# Действие: do nothing
# Q-value состояния do nothing=39.11 fire left orientation engine=38.90 fire main engine=39.13 fire right orientation engine=38.95
# Действие: fire main engine
# Q-value состояния do nothing=36.63 fire left orientation engine=36.39 fire main engine=36.61 fire right orientation engine=36.48
# Действие: do nothing
# Q-value состояния do nothing=38.31 fire left orientation engine=38.10 fire main engine=38.32 fire right orientation engine=38.14
# Действие: fire main engine
# Q-value состояния do nothing=37.66 fire left orientation engine=37.43 fire main engine=37.63 fire right orientation engine=37.53
# Действие: do nothing
# Q-value состояния do nothing=39.36 fire left orientation engine=39.17 fire main engine=39.37 fire right orientation engine=39.22
# Действие: fire main engine
# Q-value состояния do nothing=37.88 fire left orientation engine=37.67 fire main engine=37.88 fire right orientation engine=37.73
# Действие: fire main engine
# Q-value состояния do nothing=38.05 fire left orientation engine=37.88 fire main engine=38.04 fire right orientation engine=37.84
# Действие: do nothing
# Q-value состояния do nothing=39.83 fire left orientation engine=39.71 fire main engine=39.81 fire right orientation engine=39.57
# Действие: do nothing
# Q-value состояния do nothing=41.75 fire left orientation engine=41.67 fire main engine=41.76 fire right orientation engine=41.44
# Действие: fire main engine
# Q-value состояния do nothing=38.64 fire left orientation engine=38.52 fire main engine=38.58 fire right orientation engine=38.39
# Действие: do nothing
# Q-value состояния do nothing=40.53 fire left orientation engine=40.45 fire main engine=40.49 fire right orientation engine=40.23
# Действие: do nothing
# Q-value состояния do nothing=42.57 fire left orientation engine=42.54 fire main engine=42.58 fire right orientation engine=42.22
# Действие: fire main engine
# Q-value состояния do nothing=39.47 fire left orientation engine=39.40 fire main engine=39.40 fire right orientation engine=39.17
# Действие: do nothing
# Q-value состояния do nothing=41.58 fire left orientation engine=41.56 fire main engine=41.55 fire right orientation engine=41.22
# Действие: do nothing
# Q-value состояния do nothing=43.84 fire left orientation engine=43.85 fire main engine=43.86 fire right orientation engine=43.45
# Действие: fire main engine
# Q-value состояния do nothing=43.36 fire left orientation engine=43.38 fire main engine=43.37 fire right orientation engine=42.97
# Действие: fire left orientation engine
# Q-value состояния do nothing=45.95 fire left orientation engine=45.74 fire main engine=45.82 fire right orientation engine=45.77
# Действие: do nothing
# Q-value состояния do nothing=48.49 fire left orientation engine=48.28 fire main engine=48.42 fire right orientation engine=48.30
# Действие: do nothing
# Q-value состояния do nothing=50.98 fire left orientation engine=50.77 fire main engine=50.99 fire right orientation engine=50.79
# Действие: fire main engine
# Время обучения модели при discount_factor = 0.99 : 1319.0728478431702 секунд.

# %% [markdown]
# #### Закрытие среды после тестирования
# По завершении тестирования мы закрываем среду с помощью env.close().

# %%
# Закрытие среды
environment.close()

# %% [markdown]
# ## Reinforcement Learning (RL)
#
#
# Reinforcement Learning (Обучение с подкреплением) — это класс машинного обучения, в котором агент обучается принимать решения путем взаимодействия с окружающей средой. Агент принимает действия, получает обратную связь в виде вознаграждения или штрафа, и стремится максимизировать кумулятивное вознаграждение.
#
# ## Q-learning
# [Q-learning](https://en.wikipedia.org/wiki/Q-learning) — это один из методов обучения с подкреплением, используемый для обучения агента принимать оптимальные действия в конкретной среде. Агент стремится выучить функцию Q, которая оценивает ожидаемую награду для каждой пары состояние-действие.
#
# ## Тестирование и Валидация
#
# В контексте RL, тестирование и валидация играют важную роль. После обучения модели агента необходимо оценить ее производительность (тестирование) и убедиться в ее способности обобщения к различным ситуациям (валидация).
#
# Тестирование в RL включает в себя запуск обученной модели в реальной среде и измерение ее производительности на основе определенных метрик. Валидация, с другой стороны, может включать в себя проверку способности модели адаптироваться к новым условиям или изменениям в среде.

# %% [markdown]
# ### Установка зависимостей
#
# На первом шаге мы начинаем с установки необходимых библиотек. Пакет [gymnasium](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет различные среды для обучения с подкреплением, в то время как [stable-baselines3](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет реализации различных алгоритмов обучения с подкреплением.
#
#
# Эти пакеты будут использованы в дальнейшем коде для создания среды и реализации алгоритма обучения с подкреплением.

# %%
# Установка необходимых библиотек

# !pip install -q swig
# !pip install gym[box2d]
# !pip install stable-baselines3
# !pip install PyVirtualDisplay
# !sudo apt-get install xvfb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (4.1.1.post1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373129 sha256=2d0f88881fe12352f8bb59be596d31891c8b98ec2e14c6b5c479212053d1683a
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed box2d-py-2.3.5 pygame-2.1.0
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 3.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable-baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable-baselines3-2.2.1
# Collecting PyVirtualDisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: PyVirtualDisplay
# Successfully installed PyVirtualDisplay-3.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 24 not upgraded.
# Need to get 7,813 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.5 [28.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.5 [863 kB]
# Fetched 7,813 kB in 1s (7,834 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 9.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 121654 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.5_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.5) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.5_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.5) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.5) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link

# %% [markdown]
# После установки мы импортируем два основных модуля: gym и [DQN](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) из stable_baselines3. gym предоставляет инструменты для создания и использования различных сред для обучения агента, в то время как DQN (Deep Q-Network) представляет собой алгоритм Q-learning с использованием нейронных сетей для оценки функции Q.

# %%
# Импорт необходимых пакетов
import gymnasium as gym
from stable_baselines3 import DQN

# %% [markdown]
# ### Выбор среды
# Давайте определим задачу, которую мы будем решать, используя алгоритм Q-learning и библиотеки gym и stable-baselines3. В данной работе мы будем использовать среду LunarLander, предоставляемую Gym.

# %%
# Создание среды
env = gym.make("LunarLander-v2")

# %% [markdown]
# #### Описание задачи
# Мы сохраняем информацию о пространстве наблюдений (observation_space) и пространстве действий (action_space). observation_space представляет собой пространство всех возможных состояний в задаче, а action_space - пространство всех возможных действий, которые агент может предпринять.

# %%
# Описание задачи
observation_space = env.observation_space
action_space = env.action_space

# %% [markdown]
# Эти шаги предварительно готовят нас к использованию выбранной среды для обучения и тестирования агента с использованием алгоритма Q-learning.

# %% [markdown]
# ### Решение задачи
# На этом шаге мы используем алгоритм Q-learning, представленный в stable-baselines3. Давайте разберем каждый этап.

# %% [markdown]
# #### Инициализация модели DQN
# Мы создаем экземпляр модели Deep Q-Network (DQN) с использованием DQN("MlpPolicy", env, verbose=1). Здесь "MlpPolicy" означает полносвязную нейронную сеть в качестве политики. env - это среда LunarLander, а verbose=1 добавляет вывод для отслеживания прогресса обучения.

# %%
# Инициализация модели DQN
model = DQN("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Обучение модели
# Мы вызываем метод learn() для обучения модели на 3000000 временных шагах (total_timesteps=2000000).

# %%
# Обучение модели
timestamp=2000000
model.learn(total_timesteps=timestamp, log_interval=4)
model.save("dqn_cartpole")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 280677   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 400      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2356     |
# |    fps              | 886      |
# |    time_elapsed     | 1324     |
# |    total_timesteps  | 1174129  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.895    |
# |    n_updates        | 281032   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 402      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2360     |
# |    fps              | 886      |
# |    time_elapsed     | 1326     |
# |    total_timesteps  | 1175799  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 281449   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2364     |
# |    fps              | 886      |
# |    time_elapsed     | 1328     |
# |    total_timesteps  | 1177466  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.342    |
# |    n_updates        | 281866   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 408      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2368     |
# |    fps              | 886      |
# |    time_elapsed     | 1330     |
# |    total_timesteps  | 1179074  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.213    |
# |    n_updates        | 282268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 411      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2372     |
# |    fps              | 886      |
# |    time_elapsed     | 1332     |
# |    total_timesteps  | 1181167  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.147    |
# |    n_updates        | 282791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2376     |
# |    fps              | 886      |
# |    time_elapsed     | 1334     |
# |    total_timesteps  | 1183041  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.241    |
# |    n_updates        | 283260   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 410      |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2380     |
# |    fps              | 886      |
# |    time_elapsed     | 1336     |
# |    total_timesteps  | 1184600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 283649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 409      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2384     |
# |    fps              | 886      |
# |    time_elapsed     | 1338     |
# |    total_timesteps  | 1186029  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 284007   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 409      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2388     |
# |    fps              | 886      |
# |    time_elapsed     | 1340     |
# |    total_timesteps  | 1187600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.267    |
# |    n_updates        | 284399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 410      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2392     |
# |    fps              | 886      |
# |    time_elapsed     | 1341     |
# |    total_timesteps  | 1189278  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.252    |
# |    n_updates        | 284819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2396     |
# |    fps              | 886      |
# |    time_elapsed     | 1344     |
# |    total_timesteps  | 1191347  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 285336   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 886      |
# |    time_elapsed     | 1346     |
# |    total_timesteps  | 1193375  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.324    |
# |    n_updates        | 285843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2404     |
# |    fps              | 885      |
# |    time_elapsed     | 1349     |
# |    total_timesteps  | 1195540  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.272    |
# |    n_updates        | 286384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2408     |
# |    fps              | 885      |
# |    time_elapsed     | 1351     |
# |    total_timesteps  | 1197052  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 286762   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2412     |
# |    fps              | 886      |
# |    time_elapsed     | 1353     |
# |    total_timesteps  | 1198887  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 287221   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 428      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2416     |
# |    fps              | 886      |
# |    time_elapsed     | 1355     |
# |    total_timesteps  | 1200991  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 287747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2420     |
# |    fps              | 886      |
# |    time_elapsed     | 1358     |
# |    total_timesteps  | 1203419  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.557    |
# |    n_updates        | 288354   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2424     |
# |    fps              | 885      |
# |    time_elapsed     | 1360     |
# |    total_timesteps  | 1205266  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 288816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 436      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2428     |
# |    fps              | 885      |
# |    time_elapsed     | 1362     |
# |    total_timesteps  | 1206996  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 289248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2432     |
# |    fps              | 885      |
# |    time_elapsed     | 1365     |
# |    total_timesteps  | 1209378  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.212    |
# |    n_updates        | 289844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2436     |
# |    fps              | 885      |
# |    time_elapsed     | 1368     |
# |    total_timesteps  | 1211713  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19     |
# |    n_updates        | 290428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2440     |
# |    fps              | 885      |
# |    time_elapsed     | 1369     |
# |    total_timesteps  | 1213083  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 290770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2444     |
# |    fps              | 885      |
# |    time_elapsed     | 1372     |
# |    total_timesteps  | 1215630  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.559    |
# |    n_updates        | 291407   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2448     |
# |    fps              | 885      |
# |    time_elapsed     | 1376     |
# |    total_timesteps  | 1218941  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 292235   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 485      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2452     |
# |    fps              | 885      |
# |    time_elapsed     | 1379     |
# |    total_timesteps  | 1221250  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 292812   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 488      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2456     |
# |    fps              | 885      |
# |    time_elapsed     | 1381     |
# |    total_timesteps  | 1222948  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.159    |
# |    n_updates        | 293236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 494      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2460     |
# |    fps              | 885      |
# |    time_elapsed     | 1383     |
# |    total_timesteps  | 1225165  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.19     |
# |    n_updates        | 293791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2464     |
# |    fps              | 885      |
# |    time_elapsed     | 1385     |
# |    total_timesteps  | 1227208  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 294301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2468     |
# |    fps              | 885      |
# |    time_elapsed     | 1388     |
# |    total_timesteps  | 1229567  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.2      |
# |    n_updates        | 294891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2472     |
# |    fps              | 885      |
# |    time_elapsed     | 1390     |
# |    total_timesteps  | 1231125  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.158    |
# |    n_updates        | 295281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2476     |
# |    fps              | 885      |
# |    time_elapsed     | 1393     |
# |    total_timesteps  | 1233562  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98     |
# |    n_updates        | 295890   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 510      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2480     |
# |    fps              | 885      |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 1235612  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 296402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 519      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2484     |
# |    fps              | 885      |
# |    time_elapsed     | 1397     |
# |    total_timesteps  | 1237936  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.167    |
# |    n_updates        | 296983   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 520      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2488     |
# |    fps              | 885      |
# |    time_elapsed     | 1400     |
# |    total_timesteps  | 1239616  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0991   |
# |    n_updates        | 297403   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2492     |
# |    fps              | 885      |
# |    time_elapsed     | 1402     |
# |    total_timesteps  | 1241732  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 297932   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2496     |
# |    fps              | 885      |
# |    time_elapsed     | 1405     |
# |    total_timesteps  | 1244038  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.346    |
# |    n_updates        | 298509   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 528      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 885      |
# |    time_elapsed     | 1407     |
# |    total_timesteps  | 1246165  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.133    |
# |    n_updates        | 299041   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 532      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2504     |
# |    fps              | 885      |
# |    time_elapsed     | 1410     |
# |    total_timesteps  | 1248751  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7      |
# |    n_updates        | 299687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 534      |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2508     |
# |    fps              | 885      |
# |    time_elapsed     | 1412     |
# |    total_timesteps  | 1250495  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 300123   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2512     |
# |    fps              | 885      |
# |    time_elapsed     | 1414     |
# |    total_timesteps  | 1252194  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.45     |
# |    n_updates        | 300548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2516     |
# |    fps              | 885      |
# |    time_elapsed     | 1416     |
# |    total_timesteps  | 1254289  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.349    |
# |    n_updates        | 301072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2520     |
# |    fps              | 885      |
# |    time_elapsed     | 1419     |
# |    total_timesteps  | 1256740  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 301684   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2524     |
# |    fps              | 885      |
# |    time_elapsed     | 1421     |
# |    total_timesteps  | 1258577  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.212    |
# |    n_updates        | 302144   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 540      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2528     |
# |    fps              | 885      |
# |    time_elapsed     | 1424     |
# |    total_timesteps  | 1261009  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 302752   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 539      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2532     |
# |    fps              | 884      |
# |    time_elapsed     | 1427     |
# |    total_timesteps  | 1263234  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.126    |
# |    n_updates        | 303308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2536     |
# |    fps              | 884      |
# |    time_elapsed     | 1430     |
# |    total_timesteps  | 1265482  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 303870   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 551      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2540     |
# |    fps              | 884      |
# |    time_elapsed     | 1433     |
# |    total_timesteps  | 1268211  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.182    |
# |    n_updates        | 304552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 551      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2544     |
# |    fps              | 884      |
# |    time_elapsed     | 1436     |
# |    total_timesteps  | 1270713  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.15     |
# |    n_updates        | 305178   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2548     |
# |    fps              | 884      |
# |    time_elapsed     | 1438     |
# |    total_timesteps  | 1272408  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.233    |
# |    n_updates        | 305601   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 536      |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2552     |
# |    fps              | 884      |
# |    time_elapsed     | 1441     |
# |    total_timesteps  | 1274848  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.255    |
# |    n_updates        | 306211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 539      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2556     |
# |    fps              | 884      |
# |    time_elapsed     | 1443     |
# |    total_timesteps  | 1276822  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 306705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2560     |
# |    fps              | 884      |
# |    time_elapsed     | 1445     |
# |    total_timesteps  | 1278701  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.549    |
# |    n_updates        | 307175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 534      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2564     |
# |    fps              | 884      |
# |    time_elapsed     | 1447     |
# |    total_timesteps  | 1280562  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.472    |
# |    n_updates        | 307640   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 526      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2568     |
# |    fps              | 884      |
# |    time_elapsed     | 1449     |
# |    total_timesteps  | 1282145  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 308036   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 531      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2572     |
# |    fps              | 884      |
# |    time_elapsed     | 1451     |
# |    total_timesteps  | 1284210  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.194    |
# |    n_updates        | 308552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 523      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2576     |
# |    fps              | 884      |
# |    time_elapsed     | 1454     |
# |    total_timesteps  | 1285821  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.229    |
# |    n_updates        | 308955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2580     |
# |    fps              | 884      |
# |    time_elapsed     | 1456     |
# |    total_timesteps  | 1288066  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.07     |
# |    n_updates        | 309516   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 531      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2584     |
# |    fps              | 884      |
# |    time_elapsed     | 1459     |
# |    total_timesteps  | 1291029  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.205    |
# |    n_updates        | 310257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 197      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2588     |
# |    fps              | 884      |
# |    time_elapsed     | 1462     |
# |    total_timesteps  | 1293420  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.231    |
# |    n_updates        | 310854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 546      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2592     |
# |    fps              | 884      |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 1296305  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.232    |
# |    n_updates        | 311576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 544      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2596     |
# |    fps              | 884      |
# |    time_elapsed     | 1468     |
# |    total_timesteps  | 1298455  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 312113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 549      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 884      |
# |    time_elapsed     | 1471     |
# |    total_timesteps  | 1301020  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 312754   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 553      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2604     |
# |    fps              | 884      |
# |    time_elapsed     | 1474     |
# |    total_timesteps  | 1304005  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 313501   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 555      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2608     |
# |    fps              | 884      |
# |    time_elapsed     | 1476     |
# |    total_timesteps  | 1305988  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.213    |
# |    n_updates        | 313996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 568      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2612     |
# |    fps              | 884      |
# |    time_elapsed     | 1480     |
# |    total_timesteps  | 1308996  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.19     |
# |    n_updates        | 314748   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 576      |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2616     |
# |    fps              | 884      |
# |    time_elapsed     | 1483     |
# |    total_timesteps  | 1311907  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.354    |
# |    n_updates        | 315476   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 570      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2620     |
# |    fps              | 884      |
# |    time_elapsed     | 1486     |
# |    total_timesteps  | 1313703  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.381    |
# |    n_updates        | 315925   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 574      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2624     |
# |    fps              | 883      |
# |    time_elapsed     | 1488     |
# |    total_timesteps  | 1316021  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.192    |
# |    n_updates        | 316505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 579      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2628     |
# |    fps              | 883      |
# |    time_elapsed     | 1492     |
# |    total_timesteps  | 1318955  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.832    |
# |    n_updates        | 317238   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2632     |
# |    fps              | 883      |
# |    time_elapsed     | 1495     |
# |    total_timesteps  | 1321707  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.188    |
# |    n_updates        | 317926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 591      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2636     |
# |    fps              | 883      |
# |    time_elapsed     | 1498     |
# |    total_timesteps  | 1324624  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.611    |
# |    n_updates        | 318655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 597      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2640     |
# |    fps              | 883      |
# |    time_elapsed     | 1502     |
# |    total_timesteps  | 1327865  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.218    |
# |    n_updates        | 319466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2644     |
# |    fps              | 883      |
# |    time_elapsed     | 1506     |
# |    total_timesteps  | 1330696  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.174    |
# |    n_updates        | 320173   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 610      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2648     |
# |    fps              | 883      |
# |    time_elapsed     | 1509     |
# |    total_timesteps  | 1333428  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 320856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 612      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2652     |
# |    fps              | 883      |
# |    time_elapsed     | 1512     |
# |    total_timesteps  | 1336089  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.16     |
# |    n_updates        | 321522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 624      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2656     |
# |    fps              | 883      |
# |    time_elapsed     | 1515     |
# |    total_timesteps  | 1339197  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.331    |
# |    n_updates        | 322299   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 644      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2660     |
# |    fps              | 883      |
# |    time_elapsed     | 1520     |
# |    total_timesteps  | 1343060  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 323264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 664      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2664     |
# |    fps              | 883      |
# |    time_elapsed     | 1525     |
# |    total_timesteps  | 1346974  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 324243   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 686      |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2668     |
# |    fps              | 883      |
# |    time_elapsed     | 1529     |
# |    total_timesteps  | 1350783  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.187    |
# |    n_updates        | 325195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2672     |
# |    fps              | 882      |
# |    time_elapsed     | 1532     |
# |    total_timesteps  | 1353225  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 325806   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 703      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 882      |
# |    time_elapsed     | 1536     |
# |    total_timesteps  | 1356120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.339    |
# |    n_updates        | 326529   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 709      |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 882      |
# |    time_elapsed     | 1539     |
# |    total_timesteps  | 1358956  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 327238   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 700      |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 882      |
# |    time_elapsed     | 1541     |
# |    total_timesteps  | 1361013  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 327753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 707      |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 882      |
# |    time_elapsed     | 1545     |
# |    total_timesteps  | 1364146  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.303    |
# |    n_updates        | 328536   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 710      |
# |    ep_rew_mean      | 122      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 882      |
# |    time_elapsed     | 1549     |
# |    total_timesteps  | 1367255  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.07     |
# |    n_updates        | 329313   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 712      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 882      |
# |    time_elapsed     | 1551     |
# |    total_timesteps  | 1369670  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 329917   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 717      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 882      |
# |    time_elapsed     | 1555     |
# |    total_timesteps  | 1372733  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.02     |
# |    n_updates        | 330683   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 882      |
# |    time_elapsed     | 1558     |
# |    total_timesteps  | 1375152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.169    |
# |    n_updates        | 331287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 123      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 882      |
# |    time_elapsed     | 1561     |
# |    total_timesteps  | 1377317  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 331829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 882      |
# |    time_elapsed     | 1563     |
# |    total_timesteps  | 1379790  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.24     |
# |    n_updates        | 332447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 707      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 882      |
# |    time_elapsed     | 1566     |
# |    total_timesteps  | 1382631  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.262    |
# |    n_updates        | 333157   |
# ...
# |    time_elapsed     | 2243     |
# |    total_timesteps  | 1944247  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.063    |
# |    n_updates        | 473561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 529      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3568     |
# |    fps              | 866      |
# |    time_elapsed     | 2245     |
# |    total_timesteps  | 1946402  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 474100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 523      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3572     |
# |    fps              | 866      |
# |    time_elapsed     | 2247     |
# |    total_timesteps  | 1948216  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0599   |
# |    n_updates        | 474553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3576     |
# |    fps              | 866      |
# |    time_elapsed     | 2251     |
# |    total_timesteps  | 1950683  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 475170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 531      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3580     |
# |    fps              | 866      |
# |    time_elapsed     | 2254     |
# |    total_timesteps  | 1953134  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 475783   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3584     |
# |    fps              | 866      |
# |    time_elapsed     | 2256     |
# |    total_timesteps  | 1955184  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 476295   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 526      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3588     |
# |    fps              | 866      |
# |    time_elapsed     | 2257     |
# |    total_timesteps  | 1956604  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 476650   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3592     |
# |    fps              | 866      |
# |    time_elapsed     | 2260     |
# |    total_timesteps  | 1958965  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 477241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 522      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3596     |
# |    fps              | 866      |
# |    time_elapsed     | 2262     |
# |    total_timesteps  | 1960386  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14     |
# |    n_updates        | 477596   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 515      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3600     |
# |    fps              | 866      |
# |    time_elapsed     | 2264     |
# |    total_timesteps  | 1962036  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.202    |
# |    n_updates        | 478008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 510      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3604     |
# |    fps              | 866      |
# |    time_elapsed     | 2266     |
# |    total_timesteps  | 1964021  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 478505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 498      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3608     |
# |    fps              | 866      |
# |    time_elapsed     | 2268     |
# |    total_timesteps  | 1965662  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0588   |
# |    n_updates        | 478915   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 494      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3612     |
# |    fps              | 866      |
# |    time_elapsed     | 2270     |
# |    total_timesteps  | 1967151  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 479287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 495      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3616     |
# |    fps              | 866      |
# |    time_elapsed     | 2272     |
# |    total_timesteps  | 1969116  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0657   |
# |    n_updates        | 479778   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 492      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3620     |
# |    fps              | 866      |
# |    time_elapsed     | 2275     |
# |    total_timesteps  | 1971284  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 480320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 482      |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3624     |
# |    fps              | 866      |
# |    time_elapsed     | 2277     |
# |    total_timesteps  | 1973103  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0571   |
# |    n_updates        | 480775   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 482      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3628     |
# |    fps              | 866      |
# |    time_elapsed     | 2279     |
# |    total_timesteps  | 1975048  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 481261   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 475      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3632     |
# |    fps              | 866      |
# |    time_elapsed     | 2281     |
# |    total_timesteps  | 1976760  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0715   |
# |    n_updates        | 481689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3636     |
# |    fps              | 866      |
# |    time_elapsed     | 2283     |
# |    total_timesteps  | 1978333  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 482083   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3640     |
# |    fps              | 866      |
# |    time_elapsed     | 2284     |
# |    total_timesteps  | 1979717  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 482429   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 469      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3644     |
# |    fps              | 866      |
# |    time_elapsed     | 2287     |
# |    total_timesteps  | 1981681  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0781   |
# |    n_updates        | 482920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3648     |
# |    fps              | 866      |
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 1983448  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.28     |
# |    n_updates        | 483361   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3652     |
# |    fps              | 866      |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 1985378  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0954   |
# |    n_updates        | 483844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3656     |
# |    fps              | 866      |
# |    time_elapsed     | 2293     |
# |    total_timesteps  | 1986833  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0721   |
# |    n_updates        | 484208   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 457      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3660     |
# |    fps              | 866      |
# |    time_elapsed     | 2294     |
# |    total_timesteps  | 1988219  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 484554   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3664     |
# |    fps              | 866      |
# |    time_elapsed     | 2295     |
# |    total_timesteps  | 1989433  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0979   |
# |    n_updates        | 484858   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 444      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3668     |
# |    fps              | 866      |
# |    time_elapsed     | 2297     |
# |    total_timesteps  | 1990842  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.114    |
# |    n_updates        | 485210   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3672     |
# |    fps              | 866      |
# |    time_elapsed     | 2300     |
# |    total_timesteps  | 1993032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0757   |
# |    n_updates        | 485757   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 446      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3676     |
# |    fps              | 866      |
# |    time_elapsed     | 2303     |
# |    total_timesteps  | 1995249  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.228    |
# |    n_updates        | 486312   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3680     |
# |    fps              | 866      |
# |    time_elapsed     | 2306     |
# |    total_timesteps  | 1997590  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 486897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 438      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3684     |
# |    fps              | 866      |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 1998999  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.01     |
# |    n_updates        | 487249   |
# ----------------------------------

# %% [markdown]
# #### Тестирование модели
# Мы тестируем обученную модель, используя цикл, в котором агент принимает решения в соответствии с обученной политикой на каждом временном шаге. Мы используем метод render(), чтобы визуализировать среду в реальном времени.

# %%
# !sudo apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.5).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
import gym
from IPython import display
from pyvirtualdisplay import Display
import matplotlib.pyplot as plt
from matplotlib import animation


d = Display()
d.start()

env = gym.make("LunarLander-v2")

obs = env.reset()

img = []
for _ in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated = env.step(action)
    img.append(env.render('rgb_array'))

dpi = 72
interval = 50 # ms

plt.figure(figsize=(img[0].shape[1]/dpi,img[0].shape[0]/dpi),dpi=dpi)
patch = plt.imshow(img[0])
plt.axis=('off')
animate = lambda i: patch.set_data(img[i])
ani = animation.FuncAnimation(plt.gcf(),animate,frames=len(img),interval=interval)
display.HTML(ani.to_jshtml())

# %% [markdown]
# #### Закрытие среды после тестирования
# По завершении тестирования мы закрываем среду с помощью env.close().

# %%
# Закрытие среды после тестирования
env.close()

# %% [markdown]
# В рамках самостоятельной работы попробуйте обучить и протестировать модель на другой среды доступной в gymnasium.

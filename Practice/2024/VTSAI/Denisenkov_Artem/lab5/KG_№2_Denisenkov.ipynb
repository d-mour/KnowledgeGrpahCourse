# %% [markdown]
# # Лабораторная работа 5

# %% [markdown]
# ### Импорт зависимостей

# %%
# Установка Pykeen
# !pip install pykeen
# Out:
# Collecting pykeen
#   Using cached pykeen-1.10.1-py3-none-any.whl (739 kB)
# Collecting dataclasses-json (from pykeen)
#   Using cached dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.11.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from pykeen) (8.1.7)
# Collecting click-default-group (from pykeen)
#   Using cached click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.31.0)
# Collecting optuna>=2.0.0 (from pykeen)
#   Using cached optuna-3.5.0-py3-none-any.whl (413 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.5.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.9.0)
# Collecting more-click (from pykeen)
#   Using cached more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from pykeen) (10.1.0)
# Collecting pystow>=0.4.3 (from pykeen)
#   Using cached pystow-0.5.2-py3-none-any.whl (31 kB)
# Collecting docdata (from pykeen)
#   Using cached docdata-0.0.3-py3-none-any.whl (5.8 kB)
# Collecting class-resolver>=0.3.10 (from pykeen)
#   Using cached class_resolver-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from pykeen) (6.0.1)
# Collecting rexmex>=0.1.3 (from pykeen)
#   Using cached rexmex-0.1.3.tar.gz (21 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting torch-max-mem>=0.0.4 (from pykeen)
#   Downloading torch_max_mem-0.1.3-py3-none-any.whl (10 kB)
# Collecting torch-ppr>=0.0.7 (from pykeen)
#   Downloading torch_ppr-0.0.8-py3-none-any.whl (12 kB)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (3.20.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.5.0)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.1.0+cu121)
# Collecting alembic>=1.5.0 (from optuna>=2.0.0->pykeen)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 6.0 MB/s eta 0:00:00
# Collecting colorlog (from optuna>=2.0.0->pykeen)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (2.0.24)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2023.3.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen) (2.1.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->pykeen)
#   Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->pykeen)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen) (3.2.0)
# Collecting Mako (from alembic>=1.5.0->optuna>=2.0.0->pykeen)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->pykeen) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=2.0.0->pykeen) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10->pykeen) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10->pykeen) (1.3.0)
# Building wheels for collected packages: rexmex
#   Building wheel for rexmex (pyproject.toml) ... done
#   Created wheel for rexmex: filename=rexmex-0.1.3-py3-none-any.whl size=19952 sha256=e8d4da44ad76ec3cb97e626edf4093872670c5b09d8bdad9b75f6c41b9a7c7e7
#   Stored in directory: /root/.cache/pip/wheels/13/31/9d/51fb64454e6012bc88dd72b57609646432e478ba35772736d6
# Successfully built rexmex
# Installing collected packages: mypy-extensions, more-click, marshmallow, Mako, docdata, colorlog, click-default-group, class-resolver, typing-inspect, pystow, alembic, torch-max-mem, rexmex, optuna, dataclasses-json, torch-ppr, pykeen
# Successfully installed Mako-1.3.0 alembic-1.13.1 class-resolver-0.4.2 click-default-group-1.2.4 colorlog-6.8.0 dataclasses-json-0.6.3 docdata-0.0.3 marshmallow-3.20.2 more-click-0.1.2 mypy-extensions-1.0.0 optuna-3.5.0 pykeen-1.10.1 pystow-0.5.2 rexmex-0.1.3 torch-max-mem-0.1.3 torch-ppr-0.0.8 typing-inspect-0.9.0

# %%
import torch
import pykeen
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pykeen.pipeline import pipeline
from sklearn.neighbors import NearestNeighbors
from pykeen.evaluation import RankBasedEvaluator
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
# Out:
# INFO:pykeen.utils:Using opt_einsum

# %% [markdown]
# ### Создание датасета

# %%
from pykeen.datasets import Countries

# %%
dataset = Countries()
# Out:
# Downloading train.txt: 0.00B [00:00, ?B/s]
# Downloading test.txt: 0.00B [00:00, ?B/s]
# Downloading valid.txt: 0.00B [00:00, ?B/s]

# %% [markdown]
# ### Обучение модели

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
pipeline_results = pipeline(
    model="ComplEx",
    dataset=dataset,
    training_kwargs=dict(num_epochs=100),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 4017259965.
# INFO:pykeen.pipeline.api:Using device: cpu
# Training epochs on cpu:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.11s seconds

# %%
model = pipeline_results.model

#plot loss
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %% [markdown]
# ### Оценка модели

# %%
# Создаем evaluator объект
evaluator = RankBasedEvaluator()

# Оценить работу модели
metrics = evaluator.evaluate(model, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.10s seconds
# Hits@1: 0.0
# Hits@3: 0.0
# Hits@5: 0.0
# Hits@10: 0.0
# Mean Reciprocal Rank: 0.01712476834654808

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

# Конвертируем матрицу весов в NumPy array
embedding_numpy = embedding_matrix.cpu().numpy()

# %%
#Созраняем названия сущностей в отдельной переменной
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    # Scatter plot
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    # Добавляем лейблы к точкаи на графике
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

#Количество точек которые необходимо отобразить на графике
number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
id_to_lable[0]
# Out:
# 'afghanistan'

# %%
def diplay_matrix(similarity_matrix):
  # Визуализация матрицы близости
  plt.figure(figsize=(8, 8))
  plt.imshow(similarity_matrix, cmap='viridis', interpolation='nearest')
  plt.colorbar()
  plt.title('Node Similarity Matrix')
  plt.show()


# Рассчет близости между узлами
methods = [euclidean_distances,cosine_similarity,manhattan_distances]
#Узлы
nodes = [embedding_numpy[0],embedding_numpy[1],embedding_numpy[2],embedding_numpy[3]]
for method in methods:
  similarity_matrix = method(nodes)
  print(similarity_matrix)
  diplay_matrix(similarity_matrix)
# Out:
# [[ 0.       28.354933 28.285715 27.58924 ]
#  [28.354933  0.       27.778439 27.701145]
#  [28.285715 27.778439  0.       27.444645]
#  [27.58924  27.701145 27.444645  0.      ]]
# [[ 1.0000001e+00 -7.1226068e-02 -2.1149389e-02 -3.2808658e-02]
#  [-7.1226068e-02  1.0000000e+00 -6.1680181e-03 -6.5177351e-02]
#  [-2.1149389e-02 -6.1680181e-03  9.9999976e-01  2.0912476e-04]
#  [-3.2808658e-02 -6.5177351e-02  2.0912476e-04  9.9999964e-01]]
# [[  0.         447.14397909 449.38399203 439.50113564]
#  [447.14397909   0.         444.68951245 448.28836906]
#  [449.38399203 444.68951245   0.         426.23586985]
#  [439.50113564 448.28836906 426.23586985   0.        ]]

# %%
# Выбираем случайный узел
random_node_index = 0
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       25.465418 25.48008  25.883297]]
# Индексы:[[  0  61  82 134]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'czechia', 'france', 'macau']
#
# Метрика:cosine
# Дистанции:[[1.1920929e-07 8.8349229e-01 8.8544226e-01 8.8572097e-01]]
# Индексы:[[  0  82  33 164]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'france', 'british_virgin_islands', 'new_zealand']
#
# Метрика:manhattan
# Дистанции:[[  0.         401.7532959  410.90847778 411.76745605]]
# Индексы:[[  0 187 263 265]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'poland', 'western_africa', 'western_europe']

# %%
# Еще один узел
random_node_index = 207
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       26.620956 26.66417  26.674654]]
# Индексы:[[207 190 270 183]]
# Ближайшие соседи узла serbia: ['serbia', 'puerto_rico', 'Åland_islands', 'paraguay']
#
# Метрика:cosine
# Дистанции:[[1.1920929e-07 8.5513079e-01 8.7757623e-01 8.8300288e-01]]
# Индексы:[[207  70 270 252]]
# Ближайшие соседи узла serbia: ['serbia', 'ecuador', 'Åland_islands', 'united_kingdom']
#
# Метрика:manhattan
# Дистанции:[[  0.         427.18490601 427.37533569 427.65164185]]
# Индексы:[[207  39 270 137]]
# Ближайшие соседи узла serbia: ['serbia', 'cameroon', 'Åland_islands', 'malawi']

# %% [markdown]
# ### Меняем количество эпох обучения до 10

# %%
pipeline_results = pipeline(
    model="ComplEx",
    dataset=dataset,
    training_kwargs=dict(num_epochs=10),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 3611508331.
# INFO:pykeen.pipeline.api:Using device: cpu
# Training epochs on cpu:   0%|          | 0/10 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.10s seconds

# %%
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
# Создаем evaluator объект
evaluator = RankBasedEvaluator()

model2 = pipeline_results.model
# Оценить работу модели
metrics = evaluator.evaluate(model2, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.10s seconds
# Hits@1: 0.020833333333333332
# Hits@3: 0.041666666666666664
# Hits@5: 0.08333333333333333
# Hits@10: 0.125
# Mean Reciprocal Rank: 0.05065644904971123

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

# Конвертируем матрицу весов в NumPy array
embedding_numpy = embedding_matrix.cpu().numpy()

# %%
#Созраняем названия сущностей в отдельной переменной
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    # Scatter plot
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    # Добавляем лейблы к точкаи на графике
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

#Количество точек которые необходимо отобразить на графике
number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
# Выбираем случайный узел
random_node_index = 0
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       26.248966 26.585375 26.620447]]
# Индексы:[[  0 163  73 149]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'new_caledonia', 'equatorial_guinea', 'micronesia']
#
# Метрика:cosine
# Дистанции:[[1.1920929e-07 8.6282074e-01 8.8637954e-01 8.9061970e-01]]
# Индексы:[[  0 163 124 149]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'new_caledonia', 'kyrgyzstan', 'micronesia']
#
# Метрика:manhattan
# Дистанции:[[  0.         423.61053467 423.97372437 424.78207397]]
# Индексы:[[  0 163 216  59]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'new_caledonia', 'south-eastern_asia', 'curaçao']

# %%
# Еще один узел
random_node_index = 207
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       24.860117 25.691628 25.888052]]
# Индексы:[[207 176  15 251]]
# Ближайшие соседи узла serbia: ['serbia', 'oceania', 'australia_and_new_zealand', 'united_arab_emirates']
#
# Метрика:cosine
# Дистанции:[[0.         0.85229313 0.8767495  0.88753855]]
# Индексы:[[207 176  80 185]]
# Ближайшие соседи узла serbia: ['serbia', 'oceania', 'fiji', 'philippines']
#
# Метрика:manhattan
# Дистанции:[[  0.         392.75018311 409.74099731 411.8520813 ]]
# Индексы:[[207 176 263  73]]
# Ближайшие соседи узла serbia: ['serbia', 'oceania', 'western_africa', 'equatorial_guinea']

# %% [markdown]
# ### Меняем модель

# %%
pipeline_results = pipeline(
    model="TransE",
    dataset=dataset,
    training_kwargs=dict(num_epochs=100),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 2305395179.
# INFO:pykeen.pipeline.api:Using device: cpu
# Training epochs on cpu:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.15s seconds

# %%
model3 = pipeline_results.model

#plot loss
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
# Создаем evaluator объект
evaluator = RankBasedEvaluator()
model3 = pipeline_results.model
# Оценить работу модели
metrics = evaluator.evaluate(model3, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.11s seconds
# Hits@1: 0.08333333333333333
# Hits@3: 0.2916666666666667
# Hits@5: 0.4166666666666667
# Hits@10: 0.5416666666666666
# Mean Reciprocal Rank: 0.23904938995838165

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

# Конвертируем матрицу весов в NumPy array
embedding_numpy = embedding_matrix.cpu().numpy()

# %%
#Сохраняем названия сущностей в отдельной переменной
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    # Scatter plot
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    # Добавляем лейблы к точкаи на графике
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

#Количество точек которые необходимо отобразить на графике
number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
# Выбираем случайный узел
random_node_index = 0
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.0642153 1.0732827 1.1101607]]
# Индексы:[[  0 174 178 246]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'northern_mariana_islands', 'pakistan', 'turkmenistan']
#
# Метрика:cosine
# Дистанции:[[5.9604645e-08 5.6627709e-01 5.7596785e-01 6.1622846e-01]]
# Индексы:[[  0 174 178 246]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'northern_mariana_islands', 'pakistan', 'turkmenistan']
#
# Метрика:manhattan
# Дистанции:[[0.         5.74292278 6.07917547 6.19829607]]
# Индексы:[[  0 108 178 174]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'iran', 'pakistan', 'northern_mariana_islands']

# %%
# Еще один узел
random_node_index = 207
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  # Визуализация ближайших соседей
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.0322791 1.0536146 1.078461 ]]
# Индексы:[[207  29  35 122]]
# Ближайшие соседи узла serbia: ['serbia', 'bosnia_and_herzegovina', 'bulgaria', 'kosovo']
#
# Метрика:cosine
# Дистанции:[[0.        0.5328001 0.5550519 0.5815391]]
# Индексы:[[207  29  35 122]]
# Ближайшие соседи узла serbia: ['serbia', 'bosnia_and_herzegovina', 'bulgaria', 'kosovo']
#
# Метрика:manhattan
# Дистанции:[[0.         5.77604818 5.78388214 5.87364292]]
# Индексы:[[207  57  29  35]]
# Ближайшие соседи узла serbia: ['serbia', 'croatia', 'bosnia_and_herzegovina', 'bulgaria']

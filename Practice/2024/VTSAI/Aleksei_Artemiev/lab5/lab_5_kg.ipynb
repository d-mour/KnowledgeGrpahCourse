# %%
# !nvidia-smi
# Out:
# Fri Jan 26 00:50:48 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              50W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install pykeen networkx matplotlib -q

# %%
import torch
import pykeen
import numpy as np
import matplotlib.pyplot as plt
from pykeen.pipeline import pipeline
from pykeen.evaluation import RankBasedEvaluator
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
from pykeen.datasets import DBpedia50
from sklearn.neighbors import NearestNeighbors
# Out:
# INFO:pykeen.utils:Using opt_einsum

# %%
# Function for visualizing node embeddings
def visualize_embeddings(embeddings, labels):
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)
    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)
    plt.title('Scatter Plot of Embeddings')
    plt.show()


# Function for visualizing the similarity matrix
def display_matrix(similarity_matrix, title='Node Similarity Matrix'):
    plt.figure(figsize=(8, 8))
    plt.imshow(similarity_matrix, cmap='viridis', interpolation='nearest')
    plt.colorbar()
    plt.title(title)
    plt.show()

# %%
# Loading the graph dataset DBpedia50
dbpedia_dataset = DBpedia50()
entity_labels = list(dbpedia_dataset.testing.entity_id_to_label.values())

# Parameters for research
num_epochs_list = [10, 50, 100]
models = ["HolE", "DistMult"]
node_indices = [1324, 12240, 15386, 17242]  # Example node indices for analysis

for model_name in models:
    for num_epochs in num_epochs_list:
        # Model training
        pipeline_results = pipeline(
            model=model_name,
            dataset=dbpedia_dataset,
            training_kwargs=dict(num_epochs=num_epochs, batch_size=128),
            evaluation_kwargs=dict(batch_size=64),
            device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),

        )

        # Obtaining node embeddings
        node_embeddings = pipeline_results.model.entity_representations[0]._embeddings.weight.data.cpu().numpy()

        # Visualizing nodes
        visualize_embeddings(node_embeddings[:25], entity_labels[:25])

        # Measuring Node Similarity for selected nodes
        nodes = node_embeddings[node_indices]
        for method in [euclidean_distances, cosine_similarity, manhattan_distances]:
            similarity_matrix = method(nodes)
            display_matrix(similarity_matrix, title=f'{model_name} - {num_epochs} epochs')

        # Searching for neighbors for random nodes
        nn_model = NearestNeighbors(n_neighbors=5, metric='euclidean')
        nn_model.fit(node_embeddings)
        for node_index in node_indices:
            distances, indices = nn_model.kneighbors([node_embeddings[node_index]])
            neighbor_labels = [entity_labels[i] for i in indices.flatten()]
            print(f"Closest neighbors of node {entity_labels[node_index]}: {neighbor_labels}")
# Out:
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 11247 entities and 22 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 8871 from 10969 triples were filtered out
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 553961247.
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 332 entities and 1 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 276 from 399 triples were filtered out
# INFO:pykeen.pipeline.api:Using device: cuda
# Training epochs on cuda:0:   0%|          | 0/10 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.10k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.10s seconds
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 3910464834.
# INFO:pykeen.pipeline.api:Using device: cuda
# Closest neighbors of node Alphonse_J._Jackson: ['Alphonse_J._Jackson', 'Enoch_T._Nix', 'Guy_Sockrider', 'Thornton_F._Bell', "George_Hamilton_D'Oyly_Lyon"]
# Closest neighbors of node LaPlace,_Louisiana: ['LaPlace,_Louisiana', 'Ted_Baillieu', 'Wong_Tin-lam', 'Michigan_Radio', 'Loyola_University_New_Orleans_College_of_Law']
# Closest neighbors of node Nevio_Passaro: ['Nevio_Passaro', 'Saltatio_Mortis', 'Wise_Guys_(band)', 'Da_Hool', 'Night_Sun']
# Closest neighbors of node Princes_Risborough_to_Aylesbury_Line: ['Princes_Risborough_to_Aylesbury_Line', 'Marlow_Branch_Line', 'Waterloo_to_Reading_Line', 'Cherwell_Valley_Line', 'Steve_Doszpot']
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.10k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.09s seconds
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 4066062158.
# INFO:pykeen.pipeline.api:Using device: cuda
# Closest neighbors of node Alphonse_J._Jackson: ['Alphonse_J._Jackson', 'Neil_Riser', 'James_Monroe_Smith', 'K.D._Kilpatrick', 'James_C._Gardner']
# Closest neighbors of node LaPlace,_Louisiana: ['LaPlace,_Louisiana', 'La_Salle_Parish,_Louisiana', 'Red_River_of_the_South', 'Sabine_Parish,_Louisiana', 'Winnsboro,_Louisiana']
# Closest neighbors of node Nevio_Passaro: ['Nevio_Passaro', 'Craig_Nicholls', 'Kluster', 'Too_Hot_to_Handle_(1960_film)', 'Time_Flies_(Vaya_Con_Dios_album)']
# Closest neighbors of node Princes_Risborough_to_Aylesbury_Line: ['Princes_Risborough_to_Aylesbury_Line', 'Marlow_Branch_Line', '2004_British_Grand_Prix', 'Brassolini', 'Piet_Sielck']
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.10k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.09s seconds
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 689003247.
# INFO:pykeen.pipeline.api:Using device: cuda
# Closest neighbors of node Alphonse_J._Jackson: ['Alphonse_J._Jackson', 'Danny_Martiny', 'James_C._Gardner', 'Ben_Earl_Looney', 'The_Color_of_Death']
# Closest neighbors of node LaPlace,_Louisiana: ['LaPlace,_Louisiana', 'Louisiana_State_University_in_Shreveport', 'Louisiana_State_University', 'Red_River_Parish,_Louisiana', 'Jon_Connor']
# Closest neighbors of node Nevio_Passaro: ['Nevio_Passaro', 'Jon_Connor', 'Tokyo_Ghetto_Pussy', 'Aurora_Sutra', 'Necrophagist']
# Closest neighbors of node Princes_Risborough_to_Aylesbury_Line: ['Princes_Risborough_to_Aylesbury_Line', 'Marlow_Branch_Line', 'Saetheria', 'Chesham_branch', '2004_British_Grand_Prix']
# Training epochs on cuda:0:   0%|          | 0/10 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.10k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.40s seconds
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 3583397020.
# INFO:pykeen.pipeline.api:Using device: cuda
# Closest neighbors of node Alphonse_J._Jackson: ['Alphonse_J._Jackson', 'Alexander_the_Great_(1956_film)', 'Swammerdamia', 'Ehsan_Danish', 'Friday_Night_with_Jonathan_Ross']
# Closest neighbors of node LaPlace,_Louisiana: ['LaPlace,_Louisiana', 'FC_Zaria_Bălți', 'Gabriel_Lippmann', 'Jeff_Martin_(writer)', 'Daniel_Gimeno-Traver']
# Closest neighbors of node Nevio_Passaro: ['Nevio_Passaro', 'Edmund_Herring', 'Foje', 'Andriy_Sokolenko', 'Kirsten_Storms']
# Closest neighbors of node Princes_Risborough_to_Aylesbury_Line: ['Princes_Risborough_to_Aylesbury_Line', 'Chumpol_Silpa-archa', 'White_bread', 'Marlow_Branch_Line', 'The_23rd_Psalm']
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.10k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.40s seconds
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 328778085.
# INFO:pykeen.pipeline.api:Using device: cuda
# Closest neighbors of node Alphonse_J._Jackson: ['Alphonse_J._Jackson', 'Danny_Martiny', 'Walter_Lee_(Louisiana_politician)', 'Andrew_Jackson_Sevier', 'George_Eustis,_Sr.']
# Closest neighbors of node LaPlace,_Louisiana: ['LaPlace,_Louisiana', 'Louisiana_State_University_in_Shreveport', 'Loyola_University_New_Orleans_College_of_Law', 'Patterson,_Louisiana', 'Winnsboro,_Louisiana']
# Closest neighbors of node Nevio_Passaro: ['Nevio_Passaro', 'Night_Sun', 'Brainstorm_(German_band)', 'Sinnflut_(band)', 'Blank_&_Jones']
# Closest neighbors of node Princes_Risborough_to_Aylesbury_Line: ['Princes_Risborough_to_Aylesbury_Line', 'Marlow_Branch_Line', 'Cherwell_Valley_Line', 'Bristol_to_Exeter_Line', 'Waterloo_to_Reading_Line']
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/252 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.10k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.40s seconds
# Closest neighbors of node Alphonse_J._Jackson: ['Alphonse_J._Jackson', 'George_Eustis,_Sr.', 'Thornton_F._Bell', 'Andrew_Jackson_Sevier', 'Enoch_T._Nix']
# Closest neighbors of node LaPlace,_Louisiana: ['LaPlace,_Louisiana', 'Lafourche_Parish,_Louisiana', 'Red_River_of_the_South', 'Winnsboro,_Louisiana', 'Sabine_Parish,_Louisiana']
# Closest neighbors of node Nevio_Passaro: ['Nevio_Passaro', 'Night_Sun', 'Saltatio_Mortis', 'Aurora_Sutra', 'Die_Apokalyptischen_Reiter']
# Closest neighbors of node Princes_Risborough_to_Aylesbury_Line: ['Princes_Risborough_to_Aylesbury_Line', 'Cherwell_Valley_Line', '2004_British_Grand_Prix', 'Borderlands_Line', 'Bristol_to_Exeter_Line']

# %%
# !pip install pykeen networkx matplotlib

# %%
import torch
import pykeen
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pykeen.pipeline import pipeline
from sklearn.neighbors import NearestNeighbors
from pykeen.evaluation import RankBasedEvaluator
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
# Out:
# INFO:pykeen.utils:Using opt_einsum

# %%
from pykeen.datasets import Countries

# %%
dataset = Countries()

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
pipeline_results = pipeline(
    model="ComplEx",
    dataset=dataset,
    training_kwargs=dict(num_epochs=100),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 2957213907.
# INFO:pykeen.pipeline.api:Using device: cuda
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=24.
# Evaluating on cuda:0:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.10s seconds

# %%
model = pipeline_results.model

pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
evaluator = RankBasedEvaluator()

metrics = evaluator.evaluate(model, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=24.
# Evaluating on cuda:0:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.09s seconds
# Hits@1: 0.0
# Hits@3: 0.0
# Hits@5: 0.0
# Hits@10: 0.020833333333333332
# Mean Reciprocal Rank: 0.015319667756557463

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

embedding_numpy = embedding_matrix.cpu().numpy()

# %%
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
id_to_lable[0]
# Out:
# 'afghanistan'

# %%
def diplay_matrix(similarity_matrix):
  plt.figure(figsize=(8, 8))
  plt.imshow(similarity_matrix, cmap='viridis', interpolation='nearest')
  plt.colorbar()
  plt.title('Node Similarity Matrix')
  plt.show()


methods = [euclidean_distances,cosine_similarity,manhattan_distances]
nodes = [embedding_numpy[0],embedding_numpy[1],embedding_numpy[2],embedding_numpy[3]]
for method in methods:
  similarity_matrix = method(nodes)
  print(similarity_matrix)
  diplay_matrix(similarity_matrix)
# Out:
# [[ 0.       27.966908 28.634787 29.83702 ]
#  [27.966908  0.       26.597975 27.848888]
#  [28.634787 26.597975  0.       27.790476]
#  [29.83702  27.848888 27.790476  0.      ]]
# [[ 1.0000002  -0.01231679 -0.02150496 -0.05058394]
#  [-0.01231679  0.9999998  -0.02068716 -0.05148298]
#  [-0.02150496 -0.02068716  1.0000002  -0.00585999]
#  [-0.05058394 -0.05148298 -0.00585999  1.        ]]
# [[  0.         449.84445495 444.44988976 484.4605644 ]
#  [449.84445495   0.         422.70232427 439.90162407]
#  [444.44988976 422.70232427   0.         450.50310451]
#  [484.4605644  439.90162407 450.50310451   0.        ]]

# %%
random_node_index = 0
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       26.38373  26.409346 26.894909]]
# Индексы:[[  0 228 121 118]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'suriname', 'kiribati', 'jordan']
#
# Метрика:cosine
# Дистанции:[[0.        0.8599751 0.8646089 0.8707335]]
# Индексы:[[  0 226 228 121]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'sri_lanka', 'suriname', 'kiribati']
#
# Метрика:manhattan
# Дистанции:[[  0.         424.20202637 426.940979   427.44430542]]
# Индексы:[[  0 121  19  22]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'kiribati', 'bahrain', 'belarus']

# %%
random_node_index = 207
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[ 0.       24.952068 25.019783 25.341501]]
# Индексы:[[207   5  73 188]]
# Ближайшие соседи узла serbia: ['serbia', 'americas', 'equatorial_guinea', 'polynesia']
#
# Метрика:cosine
# Дистанции:[[1.1920929e-07 8.5882974e-01 8.8710743e-01 8.9658022e-01]]
# Индексы:[[207   5  35  97]]
# Ближайшие соседи узла serbia: ['serbia', 'americas', 'bulgaria', 'guernsey']
#
# Метрика:manhattan
# Дистанции:[[  0.         389.83377075 394.03405762 399.51998901]]
# Индексы:[[207   5  73 188]]
# Ближайшие соседи узла serbia: ['serbia', 'americas', 'equatorial_guinea', 'polynesia']

# %%
pipeline_results = pipeline(
    model="HolE",
    dataset=dataset,
    training_kwargs=dict(num_epochs=50),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 2820394987.
# INFO:pykeen.pipeline.api:Using device: cuda
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=24.
# Evaluating on cuda:0:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.09s seconds

# %%
pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
evaluator = RankBasedEvaluator()

model2 = pipeline_results.model
metrics = evaluator.evaluate(model2, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=24.
# Evaluating on cuda:0:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.13s seconds
# Hits@1: 0.0625
# Hits@3: 0.25
# Hits@5: 0.4166666666666667
# Hits@10: 0.625
# Mean Reciprocal Rank: 0.21909065544605258

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

embedding_numpy = embedding_matrix.cpu().numpy()

# %%
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
random_node_index = 0
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.0438597 1.0555675 1.1325064]]
# Индексы:[[  0  27 178 124]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'bhutan', 'pakistan', 'kyrgyzstan']
#
# Метрика:cosine
# Дистанции:[[0.        0.5451007 0.5611075 0.6412853]]
# Индексы:[[  0  27 178 124]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'bhutan', 'pakistan', 'kyrgyzstan']
#
# Метрика:manhattan
# Дистанции:[[ 0.         11.37917805 12.07828045 12.7797718 ]]
# Индексы:[[  0  27 178 124]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'bhutan', 'pakistan', 'kyrgyzstan']

# %%
random_node_index = 207
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.1324377 1.1545826 1.1990563]]
# Индексы:[[207   2  91  57]]
# Ближайшие соседи узла serbia: ['serbia', 'albania', 'greece', 'croatia']
#
# Метрика:cosine
# Дистанции:[[0.         0.64151263 0.6668476  0.7192099 ]]
# Индексы:[[207   2  91  57]]
# Ближайшие соседи узла serbia: ['serbia', 'albania', 'greece', 'croatia']
#
# Метрика:manhattan
# Дистанции:[[ 0.         13.20380688 13.22449493 13.6006813 ]]
# Индексы:[[207  91   2 213]]
# Ближайшие соседи узла serbia: ['serbia', 'greece', 'albania', 'slovenia']

# %%
pipeline_results = pipeline(
    model="TransE",
    dataset=dataset,
    training_kwargs=dict(num_epochs=100),
    device=device
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 1626989193.
# INFO:pykeen.pipeline.api:Using device: cuda
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/5 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=24.
# Evaluating on cuda:0:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.10s seconds

# %%
model3 = pipeline_results.model

pipeline_results.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
evaluator = RankBasedEvaluator()
model3 = pipeline_results.model
metrics = evaluator.evaluate(model3, dataset.testing.mapped_triples,
                             additional_filter_triples=[dataset.training.mapped_triples,
                                                        dataset.validation.mapped_triples])

print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=24.
# Evaluating on cuda:0:   0%|          | 0.00/24.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.10s seconds
# Hits@1: 0.020833333333333332
# Hits@3: 0.10416666666666667
# Hits@5: 0.20833333333333334
# Hits@10: 0.3333333333333333
# Mean Reciprocal Rank: 0.11460412293672563

# %%
node_embeddings = pipeline_results.model.entity_representations

embedding_matrix = node_embeddings[0]._embeddings.weight.data

embedding_numpy = embedding_matrix.cpu().numpy()

# %%
id_to_lable = list(dataset.testing.entity_id_to_label.values())

def visualize_embeddings(embeddings, labels):
    plt.figure(figsize=(10, 8))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], c=np.arange(len(labels)), cmap='viridis', s=25)

    for i, label in enumerate(labels):
        plt.annotate(label, (embeddings[i, 0], embeddings[i, 1]), alpha=1)

    plt.title('Точечная диаграмма представлений')
    plt.show()

number = 25

visualize_embeddings(embedding_numpy[:number], id_to_lable[:number])

# %%
random_node_index = 0
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.0316727 1.0389694 1.0713704]]
# Индексы:[[  0 140 108  50]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'mali', 'iran', 'china']
#
# Метрика:cosine
# Дистанции:[[0.         0.5321742  0.5397287  0.57391727]]
# Индексы:[[  0 140 108  50]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'mali', 'iran', 'china']
#
# Метрика:manhattan
# Дистанции:[[0.         5.43871641 5.6296854  6.01579905]]
# Индексы:[[  0 108 140 257]]
# Ближайшие соседи узла afghanistan: ['afghanistan', 'iran', 'mali', 'uzbekistan']

# %%
random_node_index = 207
methods = ['nan_euclidean','cosine','manhattan']
def nearest_nodes(method):
  nn_model = NearestNeighbors(n_neighbors=4, metric=method)
  nn_model.fit(embedding_numpy)
  distances, indices = nn_model.kneighbors([embedding_numpy[random_node_index]])
  print('Метрика:'+method )
  print(f'Дистанции:{distances}' )
  print(f'Индексы:{indices}' )
  neighbors_labels = [id_to_lable[i] for i in indices.flatten()]
  print(f"Ближайшие соседи узла {id_to_lable[random_node_index]}: {neighbors_labels} \n")

for method in methods: nearest_nodes(method)
# Out:
# Метрика:nan_euclidean
# Дистанции:[[0.        1.0771941 1.1129793 1.11963  ]]
# Индексы:[[207 122  35 104]]
# Ближайшие соседи узла serbia: ['serbia', 'kosovo', 'bulgaria', 'hungary']
#
# Метрика:cosine
# Дистанции:[[0.         0.5801736  0.6193614  0.62678564]]
# Индексы:[[207 122  35 104]]
# Ближайшие соседи узла serbia: ['serbia', 'kosovo', 'bulgaria', 'hungary']
#
# Метрика:manhattan
# Дистанции:[[0.         5.81584597 5.87100172 5.880476  ]]
# Индексы:[[207 122 154  57]]
# Ближайшие соседи узла serbia: ['serbia', 'kosovo', 'montenegro', 'croatia']

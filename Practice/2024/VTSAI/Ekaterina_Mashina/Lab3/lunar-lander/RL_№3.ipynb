# %% [markdown]
# ## Discount factor
# **Discount factor**  - это параметр, используемый в теории управления и обучении с подкреплением для оценки стоимости будущих вознаграждений. Он обозначается символом $\gamma$ (гамма).
#
# В контексте задачи обучения с подкреплением, такой как у **DQN** алгоритма, фактор дисконтирования применяется к будущим вознаграждениям, чтобы учесть уменьшение их значения с течением времени. Фактор дисконтирования позволяет агенту принимать во внимание не только мгновенные вознаграждения, но и будущие вознаграждения, приводя к более долгосрочной стратегии.
#
# **Формула для дисконтирования будущих вознаграждений** выглядит следующим образом:
#
#  $G_t$ = $R_{t+1}$ + $\gamma$ $R_{t+2}$ + $\gamma$^2 $R_{t+3}$ + $\ldots$ = $\sum_{k=0}^{\infty}$ $\gamma$^k $R_{t+k+1}$
#
# где:
# - $G_t$ - дисконтированная сумма вознаграждений (вознаграждение с учетом будущих шагов);
# - $R_{t+k+1}$ - вознаграждение, полученное на шаге $t+k+1$;
# - $\gamma$ - фактор дисконтирования,  $0 \leq \gamma \leq 1$.
#
# Фактор дисконтирования имеет важное значение при принятии решений в условиях неопределенности, где агенту нужно учитывать как мгновенные, так и будущие вознаграждения, с учетом их временного удаления. Выбор подходящего значения для фактора дисконтирования может влиять на стратегии обучения.

# %% [markdown]
# ## Long-term и Short-term стратегия
#
# Фактор дисконтирования оказывает сильное влияние на долгосрочность стратегии.
# В контексте обучения с подкреплением и стратегий агента, термины "краткосрочные" и "долгосрочные" относятся к временным характеристикам принятия решений агентом.
#
# **Краткосрочные стратегии**:
#
# > Агент, придерживающийся краткосрочной стратегии, ориентируется в основном на текущую информацию и мгновенные вознаграждения.
# Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам. Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам.
#
#
#
#
# **Долгосрочные стратегии**:
#
#
# > Агент, придерживающийся долгосрочной стратегии, учитывает будущие вознаграждения и последствия своих действий на протяжении более длительного времени.
# Такой агент может предпочесть действия, которые могут не приносить максимальное мгновенное вознаграждение, но могут способствовать достижению более высоких наград в будущем.
#
# Когда говорят о краткосрочных или долгосрочных стратегиях в контексте обучения с подкреплением, обычно имеется в виду, как агент принимает решения, оптимизируя сумму будущих вознаграждений. Фактор дисконтирования γ в уравнении обучения с подкреплением регулирует степень учета будущих вознаграждений, и, таким образом, влияет на то, насколько агент ориентирован на краткосрочные или долгосрочные перспективы.

# %% [markdown]
# ## Метрики для оценки модели
# В данной работе мы рассмотрим некоторые метрики, которые могут быть использованы для оценки обучения модели.
# Аналогично первой лабораторной работы мы будем решать задачу в окружении MountainCar-v0, а в качестве модели используем уже знакомый DQN. При этом мы обучим модель несколько разных с разным параметром Discount factor.
#
# Для оценки модели мы рассмотрим следущие метрики:
#
# *   Q-values, их поведение и сходимость.
# *   Средняя награда за эпизод.
# *   Время затрачиваемое на обучение модели.

# %% [markdown]
# ### Установка зависимостей
#
# На первом шаге мы начинаем с установки необходимых библиотек. Пакет [gymnasium](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет различные среды для обучения с подкреплением, в то время как [stable-baselines3](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет реализации различных алгоритмов обучения с подкреплением.

# %%
# Установка необходимых библиотек
# !pip install gym
# !pip install stable-baselines3
import torch as th
import numpy as np
import gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import time
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 2.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable-baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable-baselines3-2.2.1

# %%
# !apt install -y swig
# !pip install gymnasium[box2d]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (2,860 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.5.2)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.1.1.post1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.5 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349112 sha256=3fafc299d4a693f4abbd420d067082a534f52c22b9f89f722cbf738682fa73d4
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py
# Successfully installed box2d-py-2.3.5 swig-4.1.1.post1

# %%
# !pip install 'shimmy>=0.2.1'
# Out:
# Collecting shimmy>=0.2.1
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy>=0.2.1) (1.23.5)
# Requirement already satisfied: gymnasium>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from shimmy>=0.2.1) (0.29.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (0.0.4)
# Installing collected packages: shimmy
# Successfully installed shimmy-1.3.0

# %%
# Установка необходимых библиотек
# !pip install gymnasium
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)

# %%
import torch as th
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import time

# %%
def q_values(model: DQN, obs: np.ndarray) -> np.ndarray:
  # Доступ к Q-network
  q_net = model.q_net

  # Конвертируем observation в PyTorch tensor
  obs_tensor = th.tensor(obs, dtype=th.float32)

  # Изменяем размерность
  obs_tensor = obs_tensor.unsqueeze(0)

  #Извлекаем Q-values
  q_values = model.q_net.forward(obs_tensor)

  return q_values.detach().numpy()[0]


def plot_q_values(q_values_list):
    # Построение графика
    plt.figure(figsize=(10, 6))
    for i in range(q_values_list.shape[1]):
        plt.plot(q_values_list[:, i], label=f'Q{i+1} Values')
    plt.xlabel('Time')
    plt.ylabel('Q-Values')
    plt.title('Convergence of Q-Values over Time')
    plt.legend()
    plt.show()

def mean_reward(discount_factor):
    # Создание окружения
    env = gym.make("LunarLander-v2")

    # Удаление обертки TimeLimit
    env = env.unwrapped

    # Создание модели
    model = DQN("MlpPolicy", env, verbose=1, gamma=discount_factor)

    # Количество эпизодов для оценки модели
    n_eval_episodes = 250

    # Оценка модели до обучения
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes, deterministic=True)
    print(f"До обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

    # Засекаем начальное время
    start_time = time.time()

    # Обучение модели
    model.learn(total_timesteps=10000, log_interval=100)

    # Засекаем время завершения
    end_time = time.time()

    # Оценка модели после обучения
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes, deterministic=True)
    print(f"После обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"dqn_lunarlander_{discount_factor}")
    del model

    # Вычисляем время обучения
    learn_time = end_time - start_time
    return env, learn_time  # <-- Return both environment and learn_time


def q_values_calculation(discount_factor, env):
    # Загружаем созданную и сохраненную модель
    model = DQN.load(f"dqn_lunarlander_{discount_factor}")

    # В LunarLander окружении возможны только 4 действия
    action_str = ['do nothing', 'fire engine', 'left engine', 'right engine']
    q_values_list = []

    obs = env.reset()
    for _ in range(100):
        obs, _ = environment.reset()
        q_val = q_values(model, obs)
        q_values_list.append(q_val)
        action, _states = model.predict(obs, deterministic=True)

        print(f"Q-value состояния: {q_val}")
        print(f"Действие: {action_str[action]}")

        obs, reward, terminated, truncated, info = env.step(action)

    q_values_array = np.array(q_values_list)
    return q_values_array

# %%
discount_factors = [0.01, 0.5, 0.99]
environment, time_to_lrn = mean_reward(discount_factors[0])
obs = environment.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# До обучения модели с discount_factor = 0.01, mean_reward:-528.50 +/- 297.33
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4530     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8964     |
# ----------------------------------
# После обучения модели с discount_factor = 0.01, mean_reward:-629.44 +/- 1330.75

# %%
q_vals = q_values_calculation(discount_factors[0], environment)
# Out:
# Q-value состояния: [-0.08961897 -0.02323748 -0.00378557 -0.0327539 ]
# Действие: left engine
# Q-value состояния: [-0.10211606 -0.01307776  0.00489206 -0.03880066]
# Действие: left engine
# Q-value состояния: [-0.08759739 -0.03438226 -0.01133233 -0.02526321]
# Действие: left engine
# Q-value состояния: [-0.09247895 -0.02935794 -0.00085304 -0.02797345]
# Действие: left engine
# Q-value состояния: [-0.08337314 -0.03035746 -0.01692188 -0.03442453]
# Действие: left engine
# Q-value состояния: [-0.12391216 -0.01649838  0.01645359 -0.03823441]
# Действие: left engine
# Q-value состояния: [-0.06972429 -0.03336535 -0.03850327 -0.02436177]
# Действие: right engine
# Q-value состояния: [-0.06058184 -0.02908614 -0.05819706 -0.02071526]
# Действие: right engine
# Q-value состояния: [-0.12246981 -0.0152321   0.01785044 -0.03567449]
# Действие: left engine
# Q-value состояния: [-0.10379702 -0.02914777  0.00595139 -0.03193393]
# Действие: left engine
# Q-value состояния: [-0.10383409 -0.02826579  0.00510646 -0.03098238]
# Действие: left engine
# Q-value состояния: [-0.0857323  -0.02792923 -0.01273795 -0.03396092]
# Действие: left engine
# Q-value состояния: [-0.08360185 -0.03652548 -0.01887889 -0.02395992]
# Действие: left engine
# Q-value состояния: [-0.08419622 -0.03443772 -0.01533798 -0.03090845]
# Действие: left engine
# Q-value состояния: [-0.0635186  -0.03289922 -0.05675777 -0.02119615]
# Действие: right engine
# Q-value состояния: [-0.07551151 -0.03831773 -0.03493925 -0.02632126]
# Действие: right engine
# Q-value состояния: [-0.09996898 -0.03193319  0.00271319 -0.03129234]
# Действие: left engine
# Q-value состояния: [-0.07186065 -0.03203887 -0.03772908 -0.03711775]
# Действие: fire engine
# Q-value состояния: [-0.05702453 -0.03060934 -0.06519774 -0.02556597]
# Действие: right engine
# Q-value состояния: [-0.10263035 -0.01779734  0.01334403 -0.03110465]
# Действие: left engine
# Q-value состояния: [-0.09755474 -0.01672109 -0.00084526 -0.039011  ]
# Действие: left engine
# Q-value состояния: [-0.0865837  -0.03586697 -0.00716648 -0.02438301]
# Действие: left engine
# Q-value состояния: [-0.07701959 -0.03527708 -0.0171589  -0.0285266 ]
# Действие: left engine
# Q-value состояния: [-0.08316715 -0.03002345 -0.0177144  -0.03478346]
# Действие: left engine
# Q-value состояния: [-0.10548253 -0.02130178  0.01179586 -0.03086977]
# Действие: left engine
# Q-value состояния: [-0.09325657 -0.02356865  0.0027711  -0.03122324]
# Действие: left engine
# Q-value состояния: [-0.10876035 -0.02404999  0.00981702 -0.03088138]
# Действие: left engine
# Q-value состояния: [-0.07389186 -0.03545055 -0.03332254 -0.02538008]
# Действие: right engine
# Q-value состояния: [-0.12485395 -0.01006556  0.01964678 -0.03767947]
# Действие: left engine
# Q-value состояния: [-0.10168809 -0.01407075  0.00573867 -0.03721698]
# Действие: left engine
# Q-value состояния: [-0.10355286 -0.01122971  0.00727249 -0.0405487 ]
# Действие: left engine
# Q-value состояния: [-0.07036339 -0.03710015 -0.0451953  -0.02625188]
# Действие: right engine
# Q-value состояния: [-0.09994453 -0.01487905  0.00217227 -0.0386235 ]
# Действие: left engine
# Q-value состояния: [-0.09630821 -0.01873497  0.00661144 -0.03216002]
# Действие: left engine
# Q-value состояния: [-0.08773789 -0.03443116 -0.01090301 -0.02564064]
# Действие: left engine
# Q-value состояния: [-0.11717914 -0.02324043  0.01703428 -0.03829312]
# Действие: left engine
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Q-value состояния: [-0.09492417 -0.0359124  -0.00252183 -0.02765537]
# Действие: left engine
# Q-value состояния: [-0.09381913 -0.0238702   0.00341181 -0.03094584]
# Действие: left engine
# Q-value состояния: [-0.10795248 -0.02138047  0.0123607  -0.03116361]
# Действие: left engine
# Q-value состояния: [-0.08131419 -0.03522666 -0.02056616 -0.03212404]
# Действие: left engine
# Q-value состояния: [-0.06904115 -0.03281663 -0.03855106 -0.02433176]
# Действие: right engine
# Q-value состояния: [-0.07783263 -0.03656301 -0.02845449 -0.02498174]
# Действие: right engine
# Q-value состояния: [-0.05717806 -0.0296245  -0.06505099 -0.02965468]
# Действие: fire engine
# Q-value состояния: [-0.11464902 -0.00923171  0.01926717 -0.0367427 ]
# Действие: left engine
# Q-value состояния: [-0.07697628 -0.03863731 -0.03248932 -0.02656344]
# Действие: right engine
# Q-value состояния: [-0.11256457 -0.00986202  0.01557352 -0.03765951]
# Действие: left engine
# Q-value состояния: [-0.11483605 -0.02028397  0.01524468 -0.03227465]
# Действие: left engine
# Q-value состояния: [-0.10661077 -0.02885552  0.0094597  -0.03395407]
# Действие: left engine
# Q-value состояния: [-0.09949784 -0.0163583   0.00861072 -0.03334837]
# Действие: left engine
# Q-value состояния: [-0.10799399 -0.01300462  0.01756649 -0.03302442]
# Действие: left engine
# Q-value состояния: [-0.06173224 -0.03278973 -0.0583525  -0.02361994]
# Действие: right engine
# Q-value состояния: [-0.10365545 -0.01100827  0.00804692 -0.04099326]
# Действие: left engine
# Q-value состояния: [-0.06160745 -0.03067857 -0.05682317 -0.02137963]
# Действие: right engine
# Q-value состояния: [-0.06978045 -0.033763   -0.04071917 -0.03607851]
# Действие: fire engine
# Q-value состояния: [-0.11769029 -0.01264409  0.0216332  -0.03441072]
# Действие: left engine
# Q-value состояния: [-0.06713071 -0.03166787 -0.04727161 -0.03614257]
# Действие: fire engine
# Q-value состояния: [-0.09071444 -0.03355496 -0.00747775 -0.02606076]
# Действие: left engine
# Q-value состояния: [-0.10641547 -0.02269797  0.01064899 -0.03067743]
# Действие: left engine
# Q-value состояния: [-0.05614005 -0.03013402 -0.06653322 -0.02427375]
# Действие: right engine
# Q-value состояния: [-0.12123989 -0.01916023  0.01679718 -0.03826989]
# Действие: left engine
# Q-value состояния: [-0.11209578 -0.01023354  0.01602855 -0.0370375 ]
# Действие: left engine
# Q-value состояния: [-0.06396665 -0.03388253 -0.05189011 -0.03079741]
# Действие: right engine
# Q-value состояния: [-0.10943869 -0.00960828  0.01181673 -0.03938816]
# Действие: left engine
# Q-value состояния: [-0.08784477 -0.03616246 -0.00889793 -0.02447882]
# Действие: left engine
# Q-value состояния: [-0.10459519 -0.02675441  0.00578156 -0.03026984]
# Действие: left engine
# Q-value состояния: [-0.11864235 -0.01929556  0.01692455 -0.03319913]
# Действие: left engine
# Q-value состояния: [-0.07958651 -0.03473745 -0.02407677 -0.03494418]
# Действие: left engine
# Q-value состояния: [-0.07807378 -0.02914402 -0.02858178 -0.03719527]
# Действие: left engine
# Q-value состояния: [-0.06492281 -0.03246662 -0.05056362 -0.03386372]
# Действие: fire engine
# Q-value состояния: [-0.07698284 -0.03709198 -0.02944823 -0.03352576]
# Действие: left engine
# Q-value состояния: [-0.07360475 -0.03453791 -0.0299436  -0.02598058]
# Действие: right engine
# Q-value состояния: [-0.09595627 -0.02479843  0.00524197 -0.02929869]
# Действие: left engine
# Q-value состояния: [-0.11208682 -0.01334546  0.02122083 -0.03333247]
# Действие: left engine
# Q-value состояния: [-0.10224135 -0.02766444  0.00389108 -0.02961563]
# Действие: left engine
# Q-value состояния: [-0.07628961 -0.03840917 -0.03359864 -0.02638613]
# Действие: right engine
# Q-value состояния: [-0.07520791 -0.03516213 -0.0268533  -0.02621572]
# Действие: right engine
# Q-value состояния: [-0.11047547 -0.0271422   0.01268513 -0.03561248]
# Действие: left engine
# Q-value состояния: [-0.07498399 -0.03834009 -0.03675665 -0.0262742 ]
# Действие: right engine
# Q-value состояния: [-0.07406604 -0.03699132 -0.03521037 -0.03200039]
# Действие: right engine
# Q-value состояния: [-0.08947939 -0.03634951 -0.00715765 -0.02516976]
# Действие: left engine
# Q-value состояния: [-0.10672343 -0.01334905  0.01542436 -0.03331318]
# Действие: left engine
# Q-value состояния: [-0.08743598 -0.03484079 -0.01137345 -0.02791024]
# Действие: left engine
# Q-value состояния: [-0.06931586 -0.03673638 -0.04800287 -0.02440593]
# Действие: right engine
# Q-value состояния: [-0.11260991 -0.02213944  0.01281647 -0.03158585]
# Действие: left engine
# Q-value состояния: [-0.0947641  -0.031478   -0.0037206  -0.02715079]
# Действие: left engine
# Q-value состояния: [-0.08857936 -0.02373488 -0.00687521 -0.03362802]
# Действие: left engine
# Q-value состояния: [-0.1052615  -0.00964186  0.00958829 -0.04105587]
# Действие: left engine
# Q-value состояния: [-0.11134558 -0.0113769   0.01955318 -0.03440608]
# Действие: left engine
# Q-value состояния: [-0.07637459 -0.03589753 -0.02598473 -0.02616125]
# Действие: left engine
# Q-value состояния: [-0.06009115 -0.03052778 -0.06080923 -0.02085251]
# Действие: right engine
# Q-value состояния: [-0.05854461 -0.02868748 -0.06170846 -0.02061595]
# Действие: right engine
# Q-value состояния: [-0.07210378 -0.03535226 -0.03993301 -0.02423719]
# Действие: right engine
# Q-value состояния: [-0.10284694 -0.02302228  0.00939691 -0.03015564]
# Действие: left engine
# Q-value состояния: [-0.11109348 -0.01095078  0.01660874 -0.03593726]
# Действие: left engine
# Q-value состояния: [-0.11808264 -0.00843202  0.02266464 -0.03612496]
# Действие: left engine
# Q-value состояния: [-0.12843409 -0.0088326   0.01794616 -0.03943449]
# Действие: left engine
# Q-value состояния: [-0.09315284 -0.02801654  0.00095346 -0.02910483]
# Действие: left engine
# Q-value состояния: [-0.07159857 -0.03561783 -0.03720817 -0.03532566]
# Действие: right engine
# Q-value состояния: [-0.08788708 -0.03408564 -0.01083106 -0.02520494]
# Действие: left engine
# Q-value состояния: [-0.06176094 -0.03334416 -0.05695009 -0.02716109]
# Действие: right engine

# %%
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[0]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()
# Out:
# Время обучения модели при discount_factor = 0.01 : 2.3061370849609375 секунд.

# %%
environment, time_to_lrn = mean_reward(discount_factors[1])
q_vals = q_values_calculation(discount_factors[1], environment)
plot_q_values(q_vals)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.5, mean_reward:-132.72 +/- 41.55
# После обучения модели с discount_factor = 0.5, mean_reward:-128.78 +/- 42.06
# Q-value состояния: [-0.00723747 -0.12606862 -0.08557779 -0.16524595]
# Действие: do nothing
# Q-value состояния: [ 0.00281937 -0.12001491 -0.11121664 -0.18786423]
# Действие: do nothing
# Q-value состояния: [-0.00465579 -0.12683338 -0.08459739 -0.16861542]
# Действие: do nothing
# Q-value состояния: [-0.01193096 -0.10798132 -0.09455694 -0.1153817 ]
# Действие: do nothing
# Q-value состояния: [-0.01390122 -0.13549654 -0.11622912 -0.14086348]
# Действие: do nothing
# Q-value состояния: [-0.01077426 -0.12949717 -0.09732373 -0.15390582]
# Действие: do nothing
# Q-value состояния: [-0.00218343 -0.125005   -0.07905288 -0.16500594]
# Действие: do nothing
# Q-value состояния: [-0.01381475 -0.13666141 -0.1314291  -0.15111174]
# Действие: do nothing
# Q-value состояния: [-0.01033665 -0.13018863 -0.10317282 -0.14991269]
# Действие: do nothing
# Q-value состояния: [-0.01312318 -0.13848434 -0.15450627 -0.16387685]
# Действие: do nothing
# Q-value состояния: [-0.01271589 -0.13781723 -0.15603802 -0.16599527]
# Действие: do nothing
# Q-value состояния: [ 0.00212032 -0.12711921 -0.07690272 -0.17049064]
# Действие: do nothing
# Q-value состояния: [-0.00529287 -0.12797344 -0.11748082 -0.16529496]
# Действие: do nothing
# Q-value состояния: [-0.01366504 -0.12296478 -0.09129506 -0.14464414]
# Действие: do nothing
# Q-value состояния: [-0.0151901  -0.1427632  -0.16941367 -0.1649918 ]
# Действие: do nothing
# Q-value состояния: [-0.00851436 -0.12990002 -0.1079258  -0.15255472]
# Действие: do nothing
# Q-value состояния: [ 0.00271996 -0.12813233 -0.07720163 -0.1728479 ]
# Действие: do nothing
# Q-value состояния: [-0.01547515 -0.1430704  -0.1563317  -0.15704471]
# Действие: do nothing
# Q-value состояния: [-0.01401551 -0.14027429 -0.15592594 -0.16165274]
# Действие: do nothing
# Q-value состояния: [-0.01853155 -0.12112889 -0.09910321 -0.11980191]
# Действие: do nothing
# Q-value состояния: [-0.00306023 -0.12742084 -0.08393583 -0.17082372]
# Действие: do nothing
# Q-value состояния: [-0.01784579 -0.11940661 -0.09566216 -0.12150168]
# Действие: do nothing
# Q-value состояния: [-0.00477977 -0.12729892 -0.08301622 -0.1677958 ]
# Действие: do nothing
# Q-value состояния: [-0.01221567 -0.13342167 -0.11721937 -0.147645  ]
# Действие: do nothing
# Q-value состояния: [ 0.00948401 -0.11753757 -0.0965701  -0.19450584]
# Действие: do nothing
# Q-value состояния: [-0.0180405  -0.12450594 -0.10023281 -0.12411537]
# Действие: do nothing
# Q-value состояния: [ 0.0069194  -0.12203389 -0.08806822 -0.18411627]
# Действие: do nothing
# Q-value состояния: [-0.0058042  -0.11110373 -0.07992259 -0.14084344]
# Действие: do nothing
# Q-value состояния: [ 0.00587878 -0.11915383 -0.10184962 -0.1866327 ]
# Действие: do nothing
# Q-value состояния: [-0.01684822 -0.12870872 -0.10360719 -0.12900475]
# Действие: do nothing
# Q-value состояния: [-0.00163605 -0.12263673 -0.09724904 -0.17029846]
# Действие: do nothing
# Q-value состояния: [-0.01384193 -0.1238491  -0.09252746 -0.14442547]
# Действие: do nothing
# Q-value состояния: [-0.00730545 -0.11864033 -0.08278667 -0.14550447]
# Действие: do nothing
# Q-value состояния: [ 0.00403947 -0.11886399 -0.11374705 -0.19295117]
# Действие: do nothing
# Q-value состояния: [-0.00305722 -0.12244128 -0.13119873 -0.18696697]
# Действие: do nothing
# Q-value состояния: [-0.00544525 -0.12593107 -0.09127454 -0.16649032]
# Действие: do nothing
# Q-value состояния: [-0.01850737 -0.12119858 -0.09817145 -0.12059663]
# Действие: do nothing
# Q-value состояния: [ 0.00694757 -0.11798102 -0.10524315 -0.19300279]
# Действие: do nothing
# Q-value состояния: [ 0.00094363 -0.11891708 -0.12965658 -0.19485587]
# Действие: do nothing
# Q-value состояния: [ 0.00516975 -0.11920507 -0.10636525 -0.18893088]
# Действие: do nothing
# Q-value состояния: [ 0.01406708 -0.11536157 -0.09532356 -0.20532402]
# Действие: do nothing
# Q-value состояния: [-0.0114697  -0.12735127 -0.09327634 -0.15558088]
# Действие: do nothing
# Q-value состояния: [ 0.00534474 -0.11802169 -0.11233827 -0.19533548]
# Действие: do nothing
# Q-value состояния: [ 0.00905129 -0.11617599 -0.10493505 -0.1977136 ]
# Действие: do nothing
# Q-value состояния: [-0.01580562 -0.11573983 -0.09009059 -0.1246139 ]
# Действие: do nothing
# Q-value состояния: [-0.01683623 -0.11603474 -0.09150377 -0.12230805]
# Действие: do nothing
# Q-value состояния: [-0.01467396 -0.14024636 -0.14630479 -0.15466008]
# Действие: do nothing
# Q-value состояния: [-0.0135917  -0.12064551 -0.08986946 -0.1385881 ]
# Действие: do nothing
# Q-value состояния: [ 0.00034181 -0.10353952 -0.0746329  -0.15387319]
# Действие: do nothing
# Q-value состояния: [ 0.0022433  -0.12080885 -0.10569794 -0.17953297]
# Действие: do nothing
# Q-value состояния: [-0.0147148  -0.1225667  -0.0938528  -0.13268584]
# Действие: do nothing
# Q-value состояния: [-0.01009521 -0.10624421 -0.09177013 -0.11758459]
# Действие: do nothing
# Q-value состояния: [ 0.00651467 -0.11796406 -0.10717279 -0.19382161]
# Действие: do nothing
# Q-value состояния: [-0.01391358 -0.13964121 -0.14986898 -0.1589794 ]
# Действие: do nothing
# Q-value состояния: [ 0.00521289 -0.11569943 -0.12615645 -0.20244794]
# Действие: do nothing
# Q-value состояния: [ 0.00546227 -0.10652338 -0.07784411 -0.17239735]
# Действие: do nothing
# Q-value состояния: [ 0.00692531 -0.11570535 -0.11731594 -0.2014738 ]
# Действие: do nothing
# Q-value состояния: [-0.01252833 -0.12379393 -0.09032792 -0.1517735 ]
# Действие: do nothing
# Q-value состояния: [-0.00998911 -0.11897632 -0.08605982 -0.14012057]
# Действие: do nothing
# Q-value состояния: [ 0.00366058 -0.11906253 -0.1143875  -0.19238618]
# Действие: do nothing
# Q-value состояния: [ 0.00257857 -0.11574131 -0.07649717 -0.16208802]
# Действие: do nothing
# Q-value состояния: [-0.0011731  -0.12170685 -0.12041458 -0.18472522]
# Действие: do nothing
# Q-value состояния: [ 0.00780372 -0.1182703  -0.0987574  -0.19113344]
# Действие: do nothing
# Q-value состояния: [ 0.00659115 -0.1187536  -0.1020295  -0.18863288]
# Действие: do nothing
# Q-value состояния: [-0.00659023 -0.1286197  -0.1250402  -0.16912115]
# Действие: do nothing
# Q-value состояния: [-0.00079837 -0.10724044 -0.07575535 -0.15285555]
# Действие: do nothing
# Q-value состояния: [ 0.00308551 -0.12213961 -0.09309916 -0.17748529]
# Действие: do nothing
# Q-value состояния: [-0.01458104 -0.1413202  -0.15553895 -0.15959193]
# Действие: do nothing
# Q-value состояния: [-0.00399528 -0.12655194 -0.11524002 -0.16756889]
# Действие: do nothing
# Q-value состояния: [-0.01612762 -0.12880886 -0.10204045 -0.13213967]
# Действие: do nothing
# Q-value состояния: [-0.00097486 -0.11960436 -0.13492543 -0.19439386]
# Действие: do nothing
# Q-value состояния: [ 0.00693189 -0.12022984 -0.09189128 -0.1850172 ]
# Действие: do nothing
# Q-value состояния: [-0.01272318 -0.13362867 -0.11356474 -0.14377272]
# Действие: do nothing
# Q-value состояния: [-0.01026796 -0.12342425 -0.08628865 -0.15731667]
# Действие: do nothing
# Q-value состояния: [ 0.00630607 -0.11722045 -0.11217733 -0.19734724]
# Действие: do nothing
# Q-value состояния: [-0.00148698 -0.12328261 -0.1101502  -0.1726477 ]
# Действие: do nothing
# Q-value состояния: [ 0.00366756 -0.11591091 -0.13248277 -0.2038205 ]
# Действие: do nothing
# Q-value состояния: [-0.01050993 -0.13226938 -0.12154195 -0.15515342]
# Действие: do nothing
# Q-value состояния: [ 0.00613403 -0.11704707 -0.11446893 -0.19798514]
# Действие: do nothing
# Q-value состояния: [-0.01292551 -0.1234286  -0.09044946 -0.14982367]
# Действие: do nothing
# Q-value состояния: [-0.00633623 -0.12494287 -0.08247026 -0.16239941]
# Действие: do nothing
# Q-value состояния: [-0.00203974 -0.12376656 -0.11244248 -0.17331958]
# Действие: do nothing
# Q-value состояния: [ 0.00035205 -0.13013037 -0.08276866 -0.17600444]
# Действие: do nothing
# Q-value состояния: [-0.00399168 -0.12386531 -0.09706646 -0.16668445]
# Действие: do nothing
# Q-value состояния: [-0.01096636 -0.12395243 -0.0882048  -0.1575443 ]
# Действие: do nothing
# Q-value состояния: [-0.00650302 -0.12408106 -0.08231791 -0.16075277]
# Действие: do nothing
# Q-value состояния: [-0.01005761 -0.12985456 -0.10277185 -0.15105668]
# Действие: do nothing
# Q-value состояния: [ 0.00702698 -0.11903446 -0.095522   -0.18763599]
# Действие: do nothing
# Q-value состояния: [-0.00961158 -0.12889756 -0.09864996 -0.15584889]
# Действие: do nothing
# Q-value состояния: [-0.00037416 -0.10303238 -0.07514321 -0.15120617]
# Действие: do nothing
# Q-value состояния: [-0.00236043 -0.12406443 -0.10726153 -0.16810524]
# Действие: do nothing
# Q-value состояния: [-0.00255087 -0.1226535  -0.12590452 -0.18467328]
# Действие: do nothing
# Q-value состояния: [-0.00801741 -0.13027525 -0.11977675 -0.15971473]
# Действие: do nothing
# Q-value состояния: [-0.01425258 -0.12625816 -0.09590293 -0.14354359]
# Действие: do nothing
# Q-value состояния: [-0.00499336 -0.12710604 -0.08306828 -0.16737029]
# Действие: do nothing
# Q-value состояния: [-0.0075192  -0.10402589 -0.08451587 -0.12401038]
# Действие: do nothing
# Q-value состояния: [-0.01646968 -0.12997326 -0.10493927 -0.13006838]
# Действие: do nothing
# Q-value состояния: [-0.00560495 -0.11739281 -0.08073159 -0.14833266]
# Действие: do nothing
# Q-value состояния: [-0.01424166 -0.11002852 -0.09421062 -0.11580354]
# Действие: do nothing
# Q-value состояния: [-0.00450246 -0.12364373 -0.08035164 -0.16149795]
# Действие: do nothing

# %%
print(f'Время обучения модели при discount_factor = {discount_factors[1]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()
# Out:
# Время обучения модели при discount_factor = 0.5 : 6.275145053863525 секунд.

# %%
environment, time_to_lrn = mean_reward(discount_factors[2])
q_vals = q_values_calculation(discount_factors[2], environment)
plot_q_values(q_vals)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.99, mean_reward:-158.92 +/- 76.40
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5910     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9616     |
# ----------------------------------
# После обучения модели с discount_factor = 0.99, mean_reward:-156.85 +/- 62.39
# Q-value состояния: [ 0.2453593   0.13405016 -0.01739242  0.10645966]
# Действие: do nothing
# Q-value состояния: [ 0.23381221  0.14500065 -0.00833444  0.11379519]
# Действие: do nothing
# Q-value состояния: [0.23560217 0.14677218 0.0035315  0.11337157]
# Действие: do nothing
# Q-value состояния: [ 0.22973451  0.1745781  -0.00476371  0.10070574]
# Действие: do nothing
# Q-value состояния: [ 0.26167563  0.13650438 -0.04136235  0.0914737 ]
# Действие: do nothing
# Q-value состояния: [ 0.23894003  0.13815373 -0.01818447  0.10703218]
# Действие: do nothing
# Q-value состояния: [ 0.25936773  0.1374189  -0.03788025  0.09313408]
# Действие: do nothing
# Q-value состояния: [ 0.23657079  0.13767782 -0.00153483  0.11373715]
# Действие: do nothing
# Q-value состояния: [ 0.2344134   0.1443374  -0.02182597  0.11162409]
# Действие: do nothing
# Q-value состояния: [ 0.23857385  0.13927437 -0.02566321  0.10810332]
# Действие: do nothing
# Q-value состояния: [0.23565319 0.1511294  0.00668951 0.11026354]
# Действие: do nothing
# Q-value состояния: [ 0.23933914  0.13874573 -0.02130479  0.10812054]
# Действие: do nothing
# Q-value состояния: [ 0.26396042  0.13509645 -0.04520418  0.08987755]
# Действие: do nothing
# Q-value состояния: [ 0.23682743  0.14084725 -0.02828301  0.1087263 ]
# Действие: do nothing
# Q-value состояния: [ 0.24219832  0.13644807 -0.03022288  0.10390601]
# Действие: do nothing
# Q-value состояния: [ 0.23410156  0.14471097 -0.00795988  0.11415097]
# Действие: do nothing
# Q-value состояния: [ 0.2634312   0.13417345 -0.04818338  0.09076291]
# Действие: do nothing
# Q-value состояния: [ 0.23575425  0.13599038 -0.00808068  0.11309432]
# Действие: do nothing
# Q-value состояния: [0.2350364  0.16208684 0.00237773 0.10522471]
# Действие: do nothing
# Q-value состояния: [ 0.23236723  0.16839927 -0.00193946  0.10344726]
# Действие: do nothing
# Q-value состояния: [0.2359702  0.15276113 0.00696658 0.10955964]
# Действие: do nothing
# Q-value состояния: [ 0.2716604   0.12973727 -0.05631337  0.08447766]
# Действие: do nothing
# Q-value состояния: [ 0.2293202   0.16801018 -0.00482017  0.10343635]
# Действие: do nothing
# Q-value состояния: [0.23702332 0.14635304 0.00394444 0.11067973]
# Действие: do nothing
# Q-value состояния: [ 0.23578873  0.1405869  -0.0099349   0.11358006]
# Действие: do nothing
# Q-value состояния: [ 0.23284547  0.1619419  -0.00085691  0.10814194]
# Действие: do nothing
# Q-value состояния: [0.23849905 0.14168814 0.00046346 0.11181558]
# Действие: do nothing
# Q-value состояния: [0.23980793 0.1444752  0.0003341  0.11116783]
# Действие: do nothing
# Q-value состояния: [ 0.26551896  0.13415772 -0.04988077  0.08874605]
# Действие: do nothing
# Q-value состояния: [ 0.2525225   0.13057135 -0.05209728  0.09294526]
# Действие: do nothing
# Q-value состояния: [ 0.22949839  0.16871747 -0.00469087  0.10290304]
# Действие: do nothing
# Q-value состояния: [0.23539683 0.16018656 0.00408842 0.10596377]
# Действие: do nothing
# Q-value состояния: [ 0.24447325  0.1368894  -0.00945389  0.10949729]
# Действие: do nothing
# Q-value состояния: [ 0.23314767  0.14642444 -0.01024624  0.1123413 ]
# Действие: do nothing
# Q-value состояния: [ 0.24273588  0.13602991 -0.03045743  0.10337784]
# Действие: do nothing
# Q-value состояния: [ 0.2544816   0.133808   -0.04038675  0.09609225]
# Действие: do nothing
# Q-value состояния: [0.23334622 0.14885761 0.00035463 0.11382183]
# Действие: do nothing
# Q-value состояния: [0.23437005 0.16177133 0.00145628 0.10704899]
# Действие: do nothing
# Q-value состояния: [ 0.22900708  0.16460821 -0.00395569  0.10664937]
# Действие: do nothing
# Q-value состояния: [ 0.26064643  0.13402466 -0.04515238  0.09291618]
# Действие: do nothing
# Q-value состояния: [0.235234   0.14896385 0.00387231 0.11326409]
# Действие: do nothing
# Q-value состояния: [ 0.2607842   0.13653402 -0.04104963  0.09217218]
# Действие: do nothing
# Q-value состояния: [0.23563145 0.16138098 0.00696094 0.10332389]
# Действие: do nothing
# Q-value состояния: [ 0.25977463  0.13188061 -0.05268838  0.09136294]
# Действие: do nothing
# Q-value состояния: [0.23451142 0.16176787 0.00163075 0.10685131]
# Действие: do nothing
# Q-value состояния: [ 0.24458669  0.13390356 -0.03499456  0.10087886]
# Действие: do nothing
# Q-value состояния: [0.23470002 0.1631556  0.00152665 0.10497174]
# Действие: do nothing
# Q-value состояния: [0.2348295  0.16105235 0.002597   0.10666156]
# Действие: do nothing
# Q-value состояния: [0.23618829 0.14604932 0.00458863 0.11251193]
# Действие: do nothing
# Q-value состояния: [ 0.25934485  0.13399269 -0.04377832  0.09383603]
# Действие: do nothing
# Q-value состояния: [ 2.3340094e-01  1.6914707e-01 -1.9642711e-04  1.0187633e-01]
# Действие: do nothing
# Q-value состояния: [0.23494974 0.15018088 0.00393632 0.11319325]
# Действие: do nothing
# Q-value состояния: [0.23319432 0.15593207 0.01052837 0.10880084]
# Действие: do nothing
# Q-value состояния: [ 0.24049267  0.13444245 -0.01363647  0.10951846]
# Действие: do nothing
# Q-value состояния: [ 0.23689787  0.14031188 -0.01402114  0.11087839]
# Действие: do nothing
# Q-value состояния: [0.2356911  0.1600104  0.00854801 0.10497373]
# Действие: do nothing
# Q-value состояния: [ 0.2317803   0.15449953 -0.00122143  0.11266059]
# Действие: do nothing
# Q-value состояния: [ 0.23140937  0.14924823 -0.0116383   0.11102964]
# Действие: do nothing
# Q-value состояния: [0.22875682 0.1709722  0.01659906 0.10747334]
# Действие: do nothing
# Q-value состояния: [ 0.23420118  0.14477853 -0.01952516  0.11229555]
# Действие: do nothing
# Q-value состояния: [0.23585987 0.15557766 0.00538968 0.10851194]
# Действие: do nothing
# Q-value состояния: [ 0.24232352  0.13634405 -0.02767782  0.10436329]
# Действие: do nothing
# Q-value состояния: [ 0.23267798  0.16066043 -0.00107215  0.1089549 ]
# Действие: do nothing
# Q-value состояния: [0.23522864 0.1565951  0.01080007 0.10773024]
# Действие: do nothing
# Q-value состояния: [ 0.24589832  0.13458309 -0.02005261  0.10504134]
# Действие: do nothing
# Q-value состояния: [ 0.2438716   0.13458109 -0.03366994  0.10171748]
# Действие: do nothing
# Q-value состояния: [0.23475821 0.14975554 0.00321157 0.11357605]
# Действие: do nothing
# Q-value состояния: [ 0.26543933  0.13377598 -0.04646674  0.08883057]
# Действие: do nothing
# Q-value состояния: [0.23398906 0.1467179  0.0005874  0.11421595]
# Действие: do nothing
# Q-value состояния: [ 0.23149128  0.14932004 -0.00414708  0.11401933]
# Действие: do nothing
# Q-value состояния: [0.2318035  0.17367175 0.0075937  0.10228213]
# Действие: do nothing
# Q-value состояния: [ 0.2575865   0.13115476 -0.05550487  0.0908417 ]
# Действие: do nothing
# Q-value состояния: [ 0.23573926  0.13570012 -0.00705177  0.11359549]
# Действие: do nothing
# Q-value состояния: [ 0.2659912   0.13409282 -0.0493602   0.08846727]
# Действие: do nothing
# Q-value состояния: [0.23466098 0.14994799 0.00297894 0.11358234]
# Действие: do nothing
# Q-value состояния: [ 0.22804534  0.173329   -0.00534904  0.10046047]
# Действие: do nothing
# Q-value состояния: [ 0.23574011  0.1429034  -0.01267321  0.1124556 ]
# Действие: do nothing
# Q-value состояния: [ 0.25770894  0.13739124 -0.03508075  0.09453816]
# Действие: do nothing
# Q-value состояния: [ 0.24835254  0.1344974  -0.01735333  0.1060242 ]
# Действие: do nothing
# Q-value состояния: [ 0.25594348  0.13254559 -0.04557227  0.09434499]
# Действие: do nothing
# Q-value состояния: [0.2307209  0.16261199 0.01419673 0.10898399]
# Действие: do nothing
# Q-value состояния: [ 0.22652385  0.17773782 -0.00505292  0.09863542]
# Действие: do nothing
# Q-value состояния: [ 0.24063262  0.13718645 -0.04035787  0.10371713]
# Действие: do nothing
# Q-value состояния: [ 0.23100361  0.17444053 -0.00303856  0.10033488]
# Действие: do nothing
# Q-value состояния: [0.23736241 0.14717692 0.00395951 0.11054008]
# Действие: do nothing
# Q-value состояния: [0.22708875 0.17681104 0.01861972 0.10743155]
# Действие: do nothing
# Q-value состояния: [ 0.25616175  0.1314796  -0.05011962  0.09290959]
# Действие: do nothing
# Q-value состояния: [0.2354925  0.15705794 0.0044143  0.10823053]
# Действие: do nothing
# Q-value состояния: [ 0.23968868  0.13440387 -0.01232682  0.11034694]
# Действие: do nothing
# Q-value состояния: [0.23582992 0.14345284 0.00223462 0.11398885]
# Действие: do nothing
# Q-value состояния: [0.23609002 0.15968382 0.00559692 0.10462509]
# Действие: do nothing
# Q-value состояния: [ 0.22791046  0.16302982 -0.00419936  0.10910926]
# Действие: do nothing
# Q-value состояния: [ 0.22978027  0.16106331 -0.00300747  0.10894671]
# Действие: do nothing
# Q-value состояния: [ 0.23499143  0.14094914 -0.00604529  0.11570039]
# Действие: do nothing
# Q-value состояния: [ 0.25907326  0.13751379 -0.03718923  0.09336459]
# Действие: do nothing
# Q-value состояния: [ 0.23104948  0.15361112 -0.00157269  0.113199  ]
# Действие: do nothing
# Q-value состояния: [ 0.25565636  0.13102677 -0.05335167  0.09192838]
# Действие: do nothing
# Q-value состояния: [ 0.22639358  0.17696267 -0.00539982  0.09857199]
# Действие: do nothing
# Q-value состояния: [ 0.23581758  0.14283    -0.01776832  0.11174967]
# Действие: do nothing
# Q-value состояния: [ 0.23148245  0.14872815 -0.00559438  0.11359601]
# Действие: do nothing

# %%
print(f'Время обучения модели при discount_factor = {discount_factors[2]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()
# Out:
# Время обучения модели при discount_factor = 0.99 : 1.7161436080932617 секунд.

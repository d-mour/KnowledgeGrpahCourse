# %% [markdown]
# ## Discount factor
# **Discount factor**  - это параметр, используемый в теории управления и обучении с подкреплением для оценки стоимости будущих вознаграждений. Он обозначается символом $\gamma$ (гамма).
#
# В контексте задачи обучения с подкреплением, такой как у **DQN** алгоритма, фактор дисконтирования применяется к будущим вознаграждениям, чтобы учесть уменьшение их значения с течением времени. Фактор дисконтирования позволяет агенту принимать во внимание не только мгновенные вознаграждения, но и будущие вознаграждения, приводя к более долгосрочной стратегии.
#
# **Формула для дисконтирования будущих вознаграждений** выглядит следующим образом:
#
#  $G_t$ = $R_{t+1}$ + $\gamma$ $R_{t+2}$ + $\gamma$^2 $R_{t+3}$ + $\ldots$ = $\sum_{k=0}^{\infty}$ $\gamma$^k $R_{t+k+1}$
#
# где:
# - $G_t$ - дисконтированная сумма вознаграждений (вознаграждение с учетом будущих шагов);
# - $R_{t+k+1}$ - вознаграждение, полученное на шаге $t+k+1$;
# - $\gamma$ - фактор дисконтирования,  $0 \leq \gamma \leq 1$.
#
# Фактор дисконтирования имеет важное значение при принятии решений в условиях неопределенности, где агенту нужно учитывать как мгновенные, так и будущие вознаграждения, с учетом их временного удаления. Выбор подходящего значения для фактора дисконтирования может влиять на стратегии обучения.

# %% [markdown]
# ## Long-term и Short-term стратегия
#
# Фактор дисконтирования оказывает сильное влияние на долгосрочность стратегии.
# В контексте обучения с подкреплением и стратегий агента, термины "краткосрочные" и "долгосрочные" относятся к временным характеристикам принятия решений агентом.
#
# **Краткосрочные стратегии**:
#
# > Агент, придерживающийся краткосрочной стратегии, ориентируется в основном на текущую информацию и мгновенные вознаграждения.
# Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам. Такой агент может принимать решения, которые приносят максимальное мгновенное вознаграждение, не уделяя большого внимания будущим шагам.
#
#
#
#
# **Долгосрочные стратегии**:
#
#
# > Агент, придерживающийся долгосрочной стратегии, учитывает будущие вознаграждения и последствия своих действий на протяжении более длительного времени.
# Такой агент может предпочесть действия, которые могут не приносить максимальное мгновенное вознаграждение, но могут способствовать достижению более высоких наград в будущем.
#
# Когда говорят о краткосрочных или долгосрочных стратегиях в контексте обучения с подкреплением, обычно имеется в виду, как агент принимает решения, оптимизируя сумму будущих вознаграждений. Фактор дисконтирования γ в уравнении обучения с подкреплением регулирует степень учета будущих вознаграждений, и, таким образом, влияет на то, насколько агент ориентирован на краткосрочные или долгосрочные перспективы.

# %% [markdown]
# ## Метрики для оценки модели
# В данной работе мы рассмотрим некоторые метрики, которые могут быть использованы для оценки обучения модели.
# Аналогично первой лабораторной работы мы будем решать задачу в окружении MountainCar-v0, а в качестве модели используем уже знакомый DQN. При этом мы обучим модель несколько разных с разным параметром Discount factor.
#
# Для оценки модели мы рассмотрим следущие метрики:
#
# *   Q-values, их поведение и сходимость.
# *   Средняя награда за эпизод.
# *   Время затрачиваемое на обучение модели.

# %% [markdown]
# ### Установка зависимостей
#
# На первом шаге мы начинаем с установки необходимых библиотек. Пакет [gymnasium](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет различные среды для обучения с подкреплением, в то время как [stable-baselines3](https://en.wikipedia.org/wiki/Q-learning#Deep_Q-learning) предоставляет реализации различных алгоритмов обучения с подкреплением.

# %%
# !apt install -y swig
# !pip install 'shimmy>=0.2.1'
# Установка необходимых библиотек
# !pip install gymnasium stable-baselines3 gymnasium[box2d]
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,485 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting shimmy>=0.2.1
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy>=0.2.1) (1.23.5)
# Collecting gymnasium>=0.27.0 (from shimmy>=0.2.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.27.0->shimmy>=0.2.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, shimmy
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Collecting box2d-py==2.3.5 (from gymnasium)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.5.2)
# Collecting swig==4.* (from gymnasium)
#   Downloading swig-4.1.1.post1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349116 sha256=093350c82d28d39325d891e068064a0c68effbb8096da173d10a62c2286dbc2a
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py, stable-baselines3
# Successfully installed box2d-py-2.3.5 stable-baselines3-2.2.1 swig-4.1.1.post1

# %%
import torch as th
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import time

# %%
def q_values(model: DQN, obs: np.ndarray) -> np.ndarray:
  # Доступ к Q-network
  q_net = model.q_net

  # Конвертируем observation в PyTorch tensor
  obs_tensor = th.tensor(obs, dtype=th.float32)

  # Изменяем размерность
  obs_tensor = obs_tensor.unsqueeze(0)

  #Извлекаем Q-values
  q_values = model.q_net.forward(obs_tensor)

  return q_values.detach().numpy()[0]


def plot_q_values(q_values_list):
    # Построение графика
    plt.figure(figsize=(10, 6))
    for i in range(q_values_list.shape[1]):
        plt.plot(q_values_list[:, i], label=f'Q{i+1} Values')
    plt.xlabel('Time')
    plt.ylabel('Q-Values')
    plt.title('Convergence of Q-Values over Time')
    plt.legend()
    plt.show()

def mean_reward(discount_factor):
    # Создание окружения
    env = gym.make("LunarLander-v2")

    # Удаление обертки TimeLimit
    env = env.unwrapped

    # Создание модели
    model = DQN("MlpPolicy", env, verbose=1, gamma=discount_factor)

    # Количество эпизодов для оценки модели
    n_eval_episodes = 250

    # Оценка модели до обучения
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes, deterministic=True)
    print(f"До обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

    # Засекаем начальное время
    start_time = time.time()

    # Обучение модели
    model.learn(total_timesteps=10000, log_interval=100)

    # Засекаем время завершения
    end_time = time.time()

    # Оценка модели после обучения
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_eval_episodes, deterministic=True)
    print(f"После обучения модели с discount_factor = {discount_factor}, mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"dqn_lunarlander_{discount_factor}")
    del model

    # Вычисляем время обучения
    learn_time = end_time - start_time
    return env, learn_time  # <-- Return both environment and learn_time


def q_values_calculation(discount_factor, env):
    # Загружаем созданную и сохраненную модель
    model = DQN.load(f"dqn_lunarlander_{discount_factor}")

    # В LunarLander окружении возможны только 4 действия
    action_str = ['do nothing', 'fire engine', 'left engine', 'right engine']
    q_values_list = []

    obs, info = env.reset()
    for _ in range(100):
        q_val = q_values(model, obs)
        q_values_list.append(q_val)
        action, _states = model.predict(obs, deterministic=True)

        print(f"Q-value состояния: {q_val}")
        print(f"Действие: {action_str[action]}")

        obs, reward, terminated, truncated, info = env.step(action)

    q_values_array = np.array(q_values_list)
    return q_values_array

discount_factors = [0.01, 0.5, 0.99]
environment, time_to_lrn = mean_reward(discount_factors[0])
obs = environment.reset()


q_vals = q_values_calculation(discount_factors[0], environment)
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[0]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()

environment, time_to_lrn = mean_reward(discount_factors[1])
q_vals = q_values_calculation(discount_factors[1], environment)
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[1]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()

environment, time_to_lrn = mean_reward(discount_factors[2])
q_vals = q_values_calculation(discount_factors[2], environment)
plot_q_values(q_vals)
print(f'Время обучения модели при discount_factor = {discount_factors[2]} : {time_to_lrn} секунд.')
# Закрытие среды
environment.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.01, mean_reward:-586.47 +/- 173.36
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4292     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9190     |
# ----------------------------------
# После обучения модели с discount_factor = 0.01, mean_reward:-559.44 +/- 151.59
# Q-value состояния: [-0.06339852  0.2062128  -0.01979361  0.02794937]
# Действие: fire engine
# Q-value состояния: [-0.06184511  0.20902148 -0.01961562  0.0296567 ]
# Действие: fire engine
# Q-value состояния: [-0.05967814  0.21224037 -0.01956013  0.03210116]
# Действие: fire engine
# Q-value состояния: [-0.05744613  0.21535818 -0.01955734  0.03460574]
# Действие: fire engine
# Q-value состояния: [-0.05539555  0.21815099 -0.01956926  0.03686637]
# Действие: fire engine
# Q-value состояния: [-0.05340925  0.22083347 -0.01953573  0.03894964]
# Действие: fire engine
# Q-value состояния: [-0.05111894  0.22401121 -0.01921391  0.04114806]
# Действие: fire engine
# Q-value состояния: [-0.04932665  0.22709751 -0.01843711  0.04277426]
# Действие: fire engine
# Q-value состояния: [-0.04793233  0.230832   -0.01819199  0.04589055]
# Действие: fire engine
# Q-value состояния: [-0.0464308   0.2338207  -0.01818144  0.04858677]
# Действие: fire engine
# Q-value состояния: [-0.0442998   0.2372483  -0.01835633  0.05222699]
# Действие: fire engine
# Q-value состояния: [-0.04275345  0.23975946 -0.0185428   0.05480503]
# Действие: fire engine
# Q-value состояния: [-0.04130235  0.24185449 -0.01848856  0.05689306]
# Действие: fire engine
# Q-value состояния: [-0.0402748   0.24412055 -0.01819298  0.0595137 ]
# Действие: fire engine
# Q-value состояния: [-0.03965916  0.2467185  -0.01798225  0.06198337]
# Действие: fire engine
# Q-value состояния: [-0.03900795  0.2492185  -0.01778117  0.06532221]
# Действие: fire engine
# Q-value состояния: [-0.03858475  0.25140655 -0.01738072  0.06902022]
# Действие: fire engine
# Q-value состояния: [-0.03859498  0.25420266 -0.01660168  0.07222926]
# Действие: fire engine
# Q-value состояния: [-0.04022026  0.25778648 -0.01648837  0.0757308 ]
# Действие: fire engine
# Q-value состояния: [-0.04193465  0.26079    -0.01735018  0.07948616]
# Действие: fire engine
# Q-value состояния: [-0.04363815  0.26364988 -0.01825448  0.08301997]
# Действие: fire engine
# Q-value состояния: [-0.04530205  0.2665079  -0.01917486  0.08582263]
# Действие: fire engine
# Q-value состояния: [-0.04627585  0.26878488 -0.02039089  0.08837715]
# Действие: fire engine
# Q-value состояния: [-0.0482069   0.2716727  -0.02244366  0.090254  ]
# Действие: fire engine
# Q-value состояния: [-0.05022463  0.27455837 -0.02463732  0.09208308]
# Действие: fire engine
# Q-value состояния: [-0.05211674  0.27693588 -0.02757072  0.09347858]
# Действие: fire engine
# Q-value состояния: [-0.05427994  0.27893126 -0.03109507  0.09500239]
# Действие: fire engine
# Q-value состояния: [-0.05662716  0.2811818  -0.03499868  0.09693174]
# Действие: fire engine
# Q-value состояния: [-0.05889259  0.28324836 -0.03904803  0.09889706]
# Действие: fire engine
# Q-value состояния: [-0.06096979  0.2845865  -0.04258763  0.10033285]
# Действие: fire engine
# Q-value состояния: [-0.06309637  0.28593472 -0.04623461  0.10181807]
# Действие: fire engine
# Q-value состояния: [-0.06542155  0.28755575 -0.05004914  0.1038271 ]
# Действие: fire engine
# Q-value состояния: [-0.0677361   0.28954566 -0.05419815  0.10600808]
# Действие: fire engine
# Q-value состояния: [-0.06991923  0.2920614  -0.05876504  0.10826048]
# Действие: fire engine
# Q-value состояния: [-0.07191703  0.2949533  -0.06456345  0.11107437]
# Действие: fire engine
# Q-value состояния: [-0.07325534  0.2980477  -0.07100627  0.11443685]
# Действие: fire engine
# Q-value состояния: [-0.07334864  0.29983187 -0.07832856  0.11726372]
# Действие: fire engine
# Q-value состояния: [-0.07395917  0.30183363 -0.08577539  0.12020312]
# Действие: fire engine
# Q-value состояния: [-0.07506451  0.30687973 -0.09242538  0.12366541]
# Действие: fire engine
# Q-value состояния: [-0.07605039  0.31195647 -0.0992638   0.12712564]
# Действие: fire engine
# Q-value состояния: [-0.07715881  0.31718805 -0.10633402  0.13070723]
# Действие: fire engine
# Q-value состояния: [-0.07807787  0.32238933 -0.11358367  0.134166  ]
# Действие: fire engine
# Q-value состояния: [-0.07902349  0.32769844 -0.12103587  0.13772376]
# Действие: fire engine
# Q-value состояния: [-0.07975481  0.33274388 -0.12850031  0.14162974]
# Действие: fire engine
# Q-value состояния: [-0.07986933  0.33702648 -0.13568372  0.14639927]
# Действие: fire engine
# Q-value состояния: [-0.07952996  0.3411141  -0.14296512  0.15094474]
# Действие: fire engine
# Q-value состояния: [-0.07941803  0.3453241  -0.15052587  0.15572783]
# Действие: fire engine
# Q-value состояния: [-0.07812178  0.34940842 -0.15856205  0.16037916]
# Действие: fire engine
# Q-value состояния: [-0.07659518  0.35341159 -0.16672501  0.16497152]
# Действие: fire engine
# Q-value состояния: [-0.07529567  0.3575472  -0.17504832  0.16976419]
# Действие: fire engine
# Q-value состояния: [-0.07373017  0.36161423 -0.18350302  0.17452933]
# Действие: fire engine
# Q-value состояния: [-0.07186125  0.36487746 -0.19211888  0.17992532]
# Действие: fire engine
# Q-value состояния: [-0.07065812  0.36786267 -0.20095895  0.18581353]
# Действие: fire engine
# Q-value состояния: [-0.06949198  0.37093237 -0.21026854  0.190415  ]
# Действие: fire engine
# Q-value состояния: [-0.06842913  0.37405688 -0.21966237  0.19516629]
# Действие: fire engine
# Q-value состояния: [-0.06895448  0.37839437 -0.22925903  0.19836572]
# Действие: fire engine
# Q-value состояния: [-0.06969061  0.3828725  -0.23894198  0.20163023]
# Действие: fire engine
# Q-value состояния: [-0.07060262  0.3874359  -0.24869207  0.20516022]
# Действие: fire engine
# Q-value состояния: [-0.0715545   0.39209956 -0.25857735  0.20881563]
# Действие: fire engine
# Q-value состояния: [-0.08320878  0.200486   -0.3087654   0.0420894 ]
# Действие: fire engine
# Q-value состояния: [-0.07748912  0.22709626 -0.28899765  0.05101815]
# Действие: fire engine
# Q-value состояния: [-0.07606578  0.23287678 -0.28357542  0.05335683]
# Действие: fire engine
# Q-value состояния: [-0.0763795   0.22961038 -0.2844302   0.05255822]
# Действие: fire engine
# Q-value состояния: [-0.07677184  0.22588173 -0.2853771   0.05150943]
# Действие: fire engine
# Q-value состояния: [-0.07687941  0.2230828  -0.28544527  0.05106699]
# Действие: fire engine
# Q-value состояния: [-0.07698847  0.22011024 -0.28546548  0.05058449]
# Действие: fire engine
# Q-value состояния: [-0.07707722  0.2171635  -0.2853086   0.05007268]
# Действие: fire engine
# Q-value состояния: [-0.07716168  0.21410105 -0.28506255  0.0495206 ]
# Действие: fire engine
# Q-value состояния: [-0.07726844  0.21066995 -0.28487217  0.04890761]
# Действие: fire engine
# Q-value состояния: [-0.07736741  0.20713425 -0.28455436  0.04824518]
# Действие: fire engine
# Q-value состояния: [-0.07755791  0.20332405 -0.2841189   0.047418  ]
# Действие: fire engine
# Q-value состояния: [-0.07791577  0.19920906 -0.28349996  0.04632501]
# Действие: fire engine
# Q-value состояния: [-0.07829484  0.19483285 -0.28280556  0.04515037]
# Действие: fire engine
# Q-value состояния: [-0.07872265  0.19013087 -0.2821502   0.04376982]
# Действие: fire engine
# Q-value состояния: [-0.07913702  0.185486   -0.28132433  0.04225201]
# Действие: fire engine
# Q-value состояния: [-0.07952627  0.18138322 -0.28075415  0.04028238]
# Действие: fire engine
# Q-value состояния: [-0.07995713  0.17705515 -0.28013337  0.03814955]
# Действие: fire engine
# Q-value состояния: [-0.08092175  0.17250794 -0.27943283  0.03691674]
# Действие: fire engine
# Q-value состояния: [-0.08233712  0.16689488 -0.27853006  0.03566312]
# Действие: fire engine
# Q-value состояния: [-0.08369182  0.16121642 -0.27729583  0.03452975]
# Действие: fire engine
# Q-value состояния: [-0.06753945  0.22126555 -0.23126687  0.05659625]
# Действие: fire engine
# Q-value состояния: [-0.06734823  0.22118267 -0.23132436  0.05698241]
# Действие: fire engine
# Q-value состояния: [-0.06719218  0.22118884 -0.23128833  0.05715391]
# Действие: fire engine
# Q-value состояния: [-0.06703021  0.22118627 -0.23125663  0.05734599]
# Действие: fire engine
# Q-value состояния: [-0.06684648  0.22114038 -0.23126005  0.05764067]
# Действие: fire engine
# Q-value состояния: [-0.06666858  0.2211175  -0.23124029  0.05788497]
# Действие: fire engine
# Q-value состояния: [-0.06647059  0.2210572  -0.23125087  0.05821962]
# Действие: fire engine
# Q-value состояния: [-0.06627741  0.2210195  -0.23123918  0.05850634]
# Действие: fire engine
# Q-value состояния: [-0.06608149  0.22098535 -0.23122227  0.05878881]
# Действие: fire engine
# Q-value состояния: [-0.06587665  0.22094052 -0.23121278  0.05910036]
# Действие: fire engine
# Q-value состояния: [-0.06567436  0.2209123  -0.23118694  0.05937788]
# Действие: fire engine
# Q-value состояния: [-0.06546515  0.22087766 -0.23116507  0.05967457]
# Действие: fire engine
# Q-value состояния: [-0.06526455  0.22087255 -0.23111574  0.05990689]
# Действие: fire engine
# Q-value состояния: [-0.06506678  0.22088128 -0.23105308  0.06011011]
# Действие: fire engine
# Q-value состояния: [-0.06486204  0.22088037 -0.23099785  0.06033879]
# Действие: fire engine
# Q-value состояния: [-0.06464598  0.2208612  -0.23095754  0.06061358]
# Действие: fire engine
# Q-value состояния: [-0.06442944  0.22085005 -0.23090893  0.06087399]
# Действие: fire engine
# Q-value состояния: [-0.0642063   0.22083247 -0.23086478  0.06115339]
# Действие: fire engine
# Q-value состояния: [-0.06399667  0.22085457 -0.23078465  0.06134447]
# Действие: fire engine
# Q-value состояния: [-0.06376796  0.22083908 -0.23073669  0.06162611]
# Действие: fire engine
# Время обучения модели при discount_factor = 0.01 : 2.291562795639038 секунд.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.5, mean_reward:-247.97 +/- 42.49
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6506     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9111     |
# ----------------------------------
# После обучения модели с discount_factor = 0.5, mean_reward:-244.20 +/- 41.34
# Q-value состояния: [-0.02595709  0.01399517  0.00817952  0.10663154]
# Действие: right engine
# Q-value состояния: [-0.02785871  0.01962289  0.0045654   0.10536461]
# Действие: right engine
# Q-value состояния: [-0.02970638  0.02449359  0.00162081  0.10414704]
# Действие: right engine
# Q-value состояния: [-0.03146226  0.02881394 -0.00058652  0.10282908]
# Действие: right engine
# Q-value состояния: [-0.03246302  0.03341021 -0.00290312  0.1016833 ]
# Действие: right engine
# Q-value состояния: [-0.03341059  0.03752052 -0.00495844  0.10061345]
# Действие: right engine
# Q-value состояния: [-0.03412005  0.04160999 -0.00718462  0.10017221]
# Действие: right engine
# Q-value состояния: [-0.03535527  0.04534824 -0.00886616  0.10033238]
# Действие: right engine
# Q-value состояния: [-0.0369347   0.04922215 -0.01055661  0.10063776]
# Действие: right engine
# Q-value состояния: [-0.03862082  0.05325526 -0.01239429  0.10091832]
# Действие: right engine
# Q-value состояния: [-0.04101656  0.05727017 -0.01445957  0.10085002]
# Действие: right engine
# Q-value состояния: [-0.04324634  0.06040171 -0.01628339  0.10037487]
# Действие: right engine
# Q-value состояния: [-0.04590631  0.06404884 -0.01834684  0.09927714]
# Действие: right engine
# Q-value состояния: [-0.04853014  0.0675965  -0.02042676  0.09808348]
# Действие: right engine
# Q-value состояния: [-0.05121854  0.07123649 -0.02261774  0.09683254]
# Действие: right engine
# Q-value состояния: [-0.05320015  0.07469343 -0.02476818  0.09570119]
# Действие: right engine
# Q-value состояния: [-0.05400888  0.07707933 -0.02583573  0.09558006]
# Действие: right engine
# Q-value состояния: [-0.05401863  0.07869829 -0.02648295  0.09515785]
# Действие: right engine
# Q-value состояния: [-0.05401271  0.08246776 -0.02673719  0.09328496]
# Действие: right engine
# Q-value состояния: [-0.05397477  0.08594558 -0.0273517   0.0912815 ]
# Действие: right engine
# Q-value состояния: [-0.05343836  0.08904874 -0.02796294  0.08918919]
# Действие: right engine
# Q-value состояния: [-0.0530535   0.09277418 -0.0286175   0.08689081]
# Действие: fire engine
# Q-value состояния: [-0.05110149  0.09120831 -0.02927155  0.08650861]
# Действие: fire engine
# Q-value состояния: [-0.04913153  0.08999856 -0.03003919  0.08618972]
# Действие: fire engine
# Q-value состояния: [-0.04714362  0.08862002 -0.03072233  0.08588693]
# Действие: fire engine
# Q-value состояния: [-0.04519323  0.08608428 -0.03131029  0.08583195]
# Действие: fire engine
# Q-value состояния: [-0.04368595  0.0836449  -0.03158871  0.08543122]
# Действие: right engine
# Q-value состояния: [-0.04411586  0.087569   -0.03247804  0.08290824]
# Действие: fire engine
# Q-value состояния: [-0.04308583  0.08428267 -0.03217104  0.08161461]
# Действие: fire engine
# Q-value состояния: [-0.04203051  0.08088598 -0.03133265  0.07901219]
# Действие: fire engine
# Q-value состояния: [-0.04260494  0.07878512 -0.03091834  0.07683149]
# Действие: fire engine
# Q-value состояния: [-0.04430642  0.0765779  -0.03102445  0.07476771]
# Действие: fire engine
# Q-value состояния: [-0.04562083  0.07433204 -0.0317586   0.0730864 ]
# Действие: fire engine
# Q-value состояния: [-0.04689394  0.07146823 -0.0319588   0.07161418]
# Действие: right engine
# Q-value состояния: [-0.04702397  0.07616404 -0.03336728  0.0695575 ]
# Действие: fire engine
# Q-value состояния: [-0.04812879  0.07395627 -0.0336094   0.06797222]
# Действие: fire engine
# Q-value состояния: [-0.0494944   0.07120796 -0.03325125  0.06701225]
# Действие: fire engine
# Q-value состояния: [-0.05091822  0.06863631 -0.03252514  0.06631815]
# Действие: fire engine
# Q-value состояния: [-0.05234261  0.0651097  -0.0314654   0.06580701]
# Действие: right engine
# Q-value состояния: [-0.05205522  0.06910385 -0.0329243   0.06377408]
# Действие: fire engine
# Q-value состояния: [-0.05353074  0.06695038 -0.03257979  0.06319448]
# Действие: fire engine
# Q-value состояния: [-0.05560014  0.06522903 -0.03274846  0.06337076]
# Действие: fire engine
# Q-value состояния: [-0.05784152  0.06309846 -0.03281627  0.06387861]
# Действие: right engine
# Q-value состояния: [-0.05725636  0.06668872 -0.03398888  0.06200902]
# Действие: fire engine
# Q-value состояния: [-0.05945829  0.0660526  -0.03436575  0.06198745]
# Действие: fire engine
# Q-value состояния: [-0.06199905  0.06483862 -0.03464389  0.06246705]
# Действие: fire engine
# Q-value состояния: [-0.06391869  0.0636798  -0.03486362  0.06293222]
# Действие: fire engine
# Q-value состояния: [-0.0662934   0.06218098 -0.03465506  0.06266715]
# Действие: right engine
# Q-value состояния: [-0.06633258  0.06482901 -0.03545987  0.06086609]
# Действие: fire engine
# Q-value состояния: [-0.06856143  0.06324401 -0.0354424   0.06059107]
# Действие: fire engine
# Q-value состояния: [-0.07051838  0.06136303 -0.03550677  0.06066732]
# Действие: fire engine
# Q-value состояния: [-0.07221953  0.05928537 -0.03522026  0.06051406]
# Действие: right engine
# Q-value состояния: [-0.0718589   0.06336667 -0.03628653  0.05849965]
# Действие: fire engine
# Q-value состояния: [-0.07373128  0.06214717 -0.03642283  0.05854797]
# Действие: fire engine
# Q-value состояния: [-0.0752972   0.06125112 -0.03670054  0.05872959]
# Действие: fire engine
# Q-value состояния: [-0.07692496  0.05962546 -0.03673507  0.05924028]
# Действие: fire engine
# Q-value состояния: [-0.07776344  0.05756623 -0.03672156  0.06000227]
# Действие: right engine
# Q-value состояния: [-0.07682586  0.06063306 -0.03836311  0.06013967]
# Действие: fire engine
# Q-value состояния: [-0.07784742  0.05817395 -0.03825849  0.06089754]
# Действие: right engine
# Q-value состояния: [-0.07637814  0.06083165 -0.03897297  0.06259163]
# Действие: right engine
# Q-value состояния: [-0.07444216  0.0648647  -0.03973514  0.06522872]
# Действие: right engine
# Q-value состояния: [-0.07308792  0.06799917 -0.0404008   0.06750287]
# Действие: fire engine
# Q-value состояния: [-0.0748489   0.06563303 -0.0401382   0.06823619]
# Действие: right engine
# Q-value состояния: [-0.07434873  0.06896785 -0.04082706  0.0694285 ]
# Действие: right engine
# Q-value состояния: [-0.07378125  0.07237633 -0.04149298  0.07036491]
# Действие: fire engine
# Q-value состояния: [-0.07525645  0.07126606 -0.04177174  0.07097881]
# Действие: fire engine
# Q-value состояния: [-0.07719519  0.06911384 -0.04195104  0.07173368]
# Действие: right engine
# Q-value состояния: [-0.076256    0.07098371 -0.0414694   0.07247069]
# Действие: right engine
# Q-value состояния: [-0.07580525  0.07219945 -0.04093626  0.07315131]
# Действие: right engine
# Q-value состояния: [-0.07556937  0.07311969 -0.03985249  0.07355942]
# Действие: right engine
# Q-value состояния: [-0.07497292  0.07480769 -0.03824758  0.07346876]
# Действие: fire engine
# Q-value состояния: [-0.07713653  0.0727897  -0.03712926  0.07423314]
# Действие: right engine
# Q-value состояния: [-0.07702368  0.07427156 -0.03440954  0.07465722]
# Действие: right engine
# Q-value состояния: [-0.07669272  0.07622184 -0.0319126   0.07490871]
# Действие: fire engine
# Q-value состояния: [-0.07926381  0.07464656 -0.03071446  0.07579214]
# Действие: right engine
# Q-value состояния: [-0.07929748  0.07605661 -0.02851546  0.07614774]
# Действие: right engine
# Q-value состояния: [-0.07953085  0.07763383 -0.02644114  0.07635231]
# Действие: fire engine
# Q-value состояния: [-0.0829121   0.07547332 -0.02506985  0.0772398 ]
# Действие: right engine
# Q-value состояния: [-0.08363314  0.07680093 -0.02235249  0.07760079]
# Действие: right engine
# Q-value состояния: [-0.08431055  0.07903758 -0.0195562   0.07755685]
# Действие: fire engine
# Q-value состояния: [-0.08705574  0.07762186 -0.01829164  0.07912011]
# Действие: right engine
# Q-value состояния: [-0.08707485  0.08016935 -0.01647641  0.08017224]
# Действие: right engine
# Q-value состояния: [-0.08708493  0.08213134 -0.0157363   0.08097096]
# Действие: fire engine
# Q-value состояния: [-0.08989616  0.08047605 -0.01334397  0.08310896]
# Действие: right engine
# Q-value состояния: [-0.09003227  0.08181125 -0.01212293  0.08337259]
# Действие: right engine
# Q-value состояния: [-0.09018955  0.08344506 -0.01088295  0.08286989]
# Действие: fire engine
# Q-value состояния: [-0.09706824  0.09628972 -0.01145992  0.1152865 ]
# Действие: right engine
# Q-value состояния: [-0.16783537  0.24407789 -0.05166321  0.05492154]
# Действие: fire engine
# Q-value состояния: [-0.1416065   0.21686897 -0.04728354  0.05490536]
# Действие: fire engine
# Q-value состояния: [-0.12953126  0.21179545 -0.05227616  0.05384691]
# Действие: fire engine
# Q-value состояния: [-0.03295739  0.03771244 -0.01640354  0.08316471]
# Действие: right engine
# Q-value состояния: [-0.03571213  0.0451328  -0.01821629  0.0849864 ]
# Действие: right engine
# Q-value состояния: [-0.05834516  0.02337298 -0.00720871  0.08304545]
# Действие: right engine
# Q-value состояния: [-0.03671451  0.05494738 -0.02030535  0.08493502]
# Действие: right engine
# Q-value состояния: [-0.06138787  0.02842825 -0.00505766  0.08195086]
# Действие: right engine
# Q-value состояния: [-0.07863622  0.05757776 -0.01504884  0.08483322]
# Действие: right engine
# Q-value состояния: [-0.08026628  0.06021339 -0.01259039  0.08552666]
# Действие: right engine
# Q-value состояния: [-0.08292374  0.0628912  -0.01016082  0.08580466]
# Действие: right engine
# Q-value состояния: [-0.08499364  0.06482002 -0.00754897  0.08647421]
# Действие: right engine
# Q-value состояния: [-0.08720916  0.06768489 -0.00477633  0.08701202]
# Действие: right engine
# Время обучения модели при discount_factor = 0.5 : 1.5382938385009766 секунд.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# До обучения модели с discount_factor = 0.99, mean_reward:-256.95 +/- 57.69
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4375     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9290     |
# ----------------------------------
# После обучения модели с discount_factor = 0.99, mean_reward:-247.78 +/- 68.02
# Q-value состояния: [-0.0176212  -0.1429171  -0.12962565  0.00433785]
# Действие: right engine
# Q-value состояния: [-0.01647119 -0.14197983 -0.13263038  0.00415263]
# Действие: right engine
# Q-value состояния: [-0.0151318  -0.14093924 -0.13595071  0.00385305]
# Действие: right engine
# Q-value состояния: [-0.0135351  -0.13995148 -0.13914806  0.00324998]
# Действие: right engine
# Q-value состояния: [-0.01224087 -0.13927951 -0.14207092  0.00226242]
# Действие: right engine
# Q-value состояния: [-0.01113075 -0.13837498 -0.14467782  0.00142907]
# Действие: right engine
# Q-value состояния: [-0.01079812 -0.13752949 -0.14708015  0.00075027]
# Действие: right engine
# Q-value состояния: [-0.01037955 -0.13712391 -0.14959787  0.00036901]
# Действие: right engine
# Q-value состояния: [-0.00988703 -0.13704303 -0.15226707  0.00058042]
# Действие: right engine
# Q-value состояния: [-0.00811091 -0.13733482 -0.1554454   0.0009249 ]
# Действие: right engine
# Q-value состояния: [-0.00752576 -0.13767074 -0.15718979  0.00136601]
# Действие: right engine
# Q-value состояния: [-0.00703752 -0.13824776 -0.15832756  0.00182289]
# Действие: right engine
# Q-value состояния: [-0.00643456 -0.13967416 -0.15946336  0.00152136]
# Действие: right engine
# Q-value состояния: [-0.00621546 -0.14064893 -0.16087872  0.00090548]
# Действие: right engine
# Q-value состояния: [-6.6604540e-03 -1.4096911e-01 -1.6267489e-01 -5.3987838e-05]
# Действие: right engine
# Q-value состояния: [-0.00714559 -0.14256062 -0.16512334 -0.00204117]
# Действие: right engine
# Q-value состояния: [-0.00781202 -0.14365855 -0.16642772 -0.00438462]
# Действие: right engine
# Q-value состояния: [-0.00875341 -0.14516799 -0.16781968 -0.00743337]
# Действие: right engine
# Q-value состояния: [-0.00977598 -0.1467243  -0.16929354 -0.01018874]
# Действие: do nothing
# Q-value состояния: [-0.00976517 -0.14521196 -0.16948172 -0.01217049]
# Действие: do nothing
# Q-value состояния: [-0.01006536 -0.14372608 -0.16952857 -0.01416861]
# Действие: do nothing
# Q-value состояния: [-0.01044689 -0.1423289  -0.16926545 -0.01608119]
# Действие: do nothing
# Q-value состояния: [-0.01073786 -0.1408216  -0.168538   -0.01783147]
# Действие: do nothing
# Q-value состояния: [-0.01104441 -0.13925871 -0.16780846 -0.01956942]
# Действие: do nothing
# Q-value состояния: [-0.01140235 -0.13790254 -0.16701198 -0.02123046]
# Действие: do nothing
# Q-value состояния: [-0.01244954 -0.13779834 -0.16563031 -0.02245691]
# Действие: do nothing
# Q-value состояния: [-0.01353158 -0.1377151  -0.16419372 -0.02363077]
# Действие: do nothing
# Q-value состояния: [-0.01463509 -0.13759048 -0.16274881 -0.02478784]
# Действие: do nothing
# Q-value состояния: [-0.01558357 -0.13749942 -0.16119863 -0.02603676]
# Действие: do nothing
# Q-value состояния: [-0.01597411 -0.13776213 -0.15921572 -0.02769647]
# Действие: do nothing
# Q-value состояния: [-0.01641553 -0.13808164 -0.15716243 -0.02917191]
# Действие: do nothing
# Q-value состояния: [-0.01699689 -0.1381303  -0.15496725 -0.03059506]
# Действие: do nothing
# Q-value состояния: [-0.01758217 -0.13814667 -0.15275607 -0.03200667]
# Действие: do nothing
# Q-value состояния: [-0.01823905 -0.13840295 -0.15076503 -0.03369154]
# Действие: do nothing
# Q-value состояния: [-0.01890716 -0.13865617 -0.1487834  -0.03539549]
# Действие: do nothing
# Q-value состояния: [-0.0195797  -0.1388793  -0.14678773 -0.03709026]
# Действие: do nothing
# Q-value состояния: [-0.02025666 -0.13907227 -0.14477804 -0.03877587]
# Действие: do nothing
# Q-value состояния: [-0.02093255 -0.13931738 -0.1428227  -0.04049357]
# Действие: do nothing
# Q-value состояния: [-0.02160331 -0.13967383 -0.14097083 -0.04227316]
# Действие: do nothing
# Q-value состояния: [-0.02227951 -0.1403885  -0.13938746 -0.04371588]
# Действие: do nothing
# Q-value состояния: [-0.02287802 -0.14114004 -0.1383915  -0.04506235]
# Действие: do nothing
# Q-value состояния: [-0.02401112 -0.14210942 -0.1360595  -0.04560214]
# Действие: do nothing
# Q-value состояния: [-0.02541627 -0.14324453 -0.13319945 -0.04640803]
# Действие: do nothing
# Q-value состояния: [-0.02682812 -0.1443531  -0.13032226 -0.0471979 ]
# Действие: do nothing
# Q-value состояния: [-0.02853642 -0.1456627  -0.12741789 -0.048578  ]
# Действие: do nothing
# Q-value состояния: [-0.03027566 -0.14664136 -0.12430239 -0.05047804]
# Действие: do nothing
# Q-value состояния: [-0.03195186 -0.14723718 -0.12099208 -0.05266856]
# Действие: do nothing
# Q-value состояния: [-0.03263376 -0.14720534 -0.11796223 -0.05505981]
# Действие: do nothing
# Q-value состояния: [-0.03283267 -0.14686015 -0.1153612  -0.05728178]
# Действие: do nothing
# Q-value состояния: [-0.0330157  -0.14646898 -0.11275516 -0.05950418]
# Действие: do nothing
# Q-value состояния: [-0.03319356 -0.14603765 -0.11013211 -0.0617328 ]
# Действие: do nothing
# Q-value состояния: [-0.03352582 -0.14601937 -0.10762442 -0.06367442]
# Действие: do nothing
# Q-value состояния: [-0.03395198 -0.14615011 -0.1050837  -0.06553864]
# Действие: do nothing
# Q-value состояния: [-0.05742444 -0.14197546 -0.07474582 -0.03039939]
# Действие: right engine
# Q-value состояния: [ 0.02730466 -0.02939498 -0.13807556 -0.07898812]
# Действие: do nothing
# Q-value состояния: [ 0.09187759 -0.04989266 -0.16782042 -0.0816703 ]
# Действие: do nothing
# Q-value состояния: [ 0.09224631 -0.05142695 -0.16793872 -0.08489218]
# Действие: do nothing
# Q-value состояния: [ 0.09087916 -0.03998177 -0.18385503 -0.13407417]
# Действие: do nothing
# Q-value состояния: [ 0.09013404 -0.05327998 -0.16526203 -0.09102084]
# Действие: do nothing
# Q-value состояния: [ 0.08805415 -0.04497772 -0.18013632 -0.13890566]
# Действие: do nothing
# Q-value состояния: [ 0.08710621 -0.04810463 -0.17832863 -0.14136323]
# Действие: do nothing
# Q-value состояния: [ 0.0861164  -0.05170591 -0.17667648 -0.14339475]
# Действие: do nothing
# Q-value состояния: [ 0.0859367  -0.05452974 -0.1754754  -0.14598633]
# Действие: do nothing
# Q-value состояния: [ 0.08547494 -0.05767504 -0.17396706 -0.14850254]
# Действие: do nothing
# Q-value состояния: [ 0.08461748 -0.0611764  -0.17215586 -0.15089345]
# Действие: do nothing
# Q-value состояния: [ 0.08587041 -0.06461167 -0.17219841 -0.15319686]
# Действие: do nothing
# Q-value состояния: [ 0.08498597 -0.06815477 -0.17034468 -0.15566476]
# Действие: do nothing
# Q-value состояния: [ 0.08683906 -0.07211983 -0.1710102  -0.15769945]
# Действие: do nothing
# Q-value состояния: [ 0.08593917 -0.0757826  -0.16908722 -0.16031669]
# Действие: do nothing
# Q-value состояния: [ 0.08499838 -0.07942096 -0.16713928 -0.16295414]
# Действие: do nothing
# Q-value состояния: [ 0.08873974 -0.08443217 -0.1696423  -0.16443756]
# Действие: do nothing
# Q-value состояния: [ 0.08910225 -0.08879012 -0.1687956  -0.16703862]
# Действие: do nothing
# Q-value состояния: [ 0.08817209 -0.09280482 -0.16668105 -0.17007889]
# Действие: do nothing
# Q-value состояния: [ 0.08970337 -0.09772022 -0.16695699 -0.17240028]
# Действие: do nothing
# Q-value состояния: [ 0.08844371 -0.10184541 -0.16482551 -0.17582956]
# Действие: do nothing
# Q-value состояния: [ 0.08700699 -0.10592514 -0.16270459 -0.17936234]
# Действие: do nothing
# Q-value состояния: [ 0.0855325  -0.10997966 -0.16055566 -0.1829134 ]
# Действие: do nothing
# Q-value состояния: [ 0.03486149 -0.10713296 -0.1190234  -0.21374424]
# Действие: do nothing
# Q-value состояния: [ 0.03472425 -0.10726199 -0.11907397 -0.21396859]
# Действие: do nothing
# Q-value состояния: [ 0.03438672 -0.10741481 -0.11922069 -0.21389543]
# Действие: do nothing
# Q-value состояния: [ 0.03404782 -0.10756451 -0.11936891 -0.21381804]
# Действие: do nothing
# Q-value состояния: [ 0.03370487 -0.10771427 -0.11951931 -0.2137342 ]
# Действие: do nothing
# Q-value состояния: [ 0.03337328 -0.10784552 -0.11968879 -0.2136416 ]
# Действие: do nothing
# Q-value состояния: [ 0.03304768 -0.1079614  -0.11987616 -0.21353602]
# Действие: do nothing
# Q-value состояния: [ 0.03272189 -0.10807732 -0.12006363 -0.21343042]
# Действие: do nothing
# Q-value состояния: [ 0.03239591 -0.10819334 -0.12025124 -0.21332474]
# Действие: do nothing
# Q-value состояния: [ 0.03206968 -0.10830942 -0.12043893 -0.21321899]
# Действие: do nothing
# Q-value состояния: [ 0.03174324 -0.10842559 -0.12062673 -0.21311313]
# Действие: do nothing
# Q-value состояния: [ 0.03141664 -0.10854182 -0.12081468 -0.21300721]
# Действие: do nothing
# Q-value состояния: [ 0.03108986 -0.10865809 -0.1210027  -0.21290126]
# Действие: do nothing
# Q-value состояния: [ 0.03076287 -0.10877445 -0.12119088 -0.2127952 ]
# Действие: do nothing
# Q-value состояния: [ 0.03043568 -0.10889089 -0.12137915 -0.21268913]
# Действие: do nothing
# Q-value состояния: [ 0.03008243 -0.10902038 -0.12153596 -0.212563  ]
# Действие: do nothing
# Q-value состояния: [ 0.02975543 -0.10913575 -0.12172382 -0.21245937]
# Действие: do nothing
# Q-value состояния: [ 0.02942817 -0.1092512  -0.12191182 -0.21235569]
# Действие: do nothing
# Q-value состояния: [ 0.03090624 -0.10961233 -0.12291573 -0.21233104]
# Действие: do nothing
# Q-value состояния: [ 0.0341097  -0.11030027 -0.12464432 -0.2124054 ]
# Действие: do nothing
# Q-value состояния: [ 0.0384644  -0.11133006 -0.1267851  -0.21259518]
# Действие: do nothing
# Q-value состояния: [ 0.04277825 -0.11279434 -0.12903516 -0.21291298]
# Действие: do nothing
# Q-value состояния: [ 0.04704043 -0.1145353  -0.13119362 -0.2132998 ]
# Действие: do nothing
# Время обучения модели при discount_factor = 0.99 : 2.27221941947937 секунд.

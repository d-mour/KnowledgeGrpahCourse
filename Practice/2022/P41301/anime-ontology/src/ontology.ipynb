# %%
import requests
import json
import rdflib
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
import networkx as nx
import matplotlib.pyplot as plt
import urllib
from rdflib import URIRef, BNode, Literal, Namespace, Graph
from rdflib.namespace import Namespace, NamespaceManager
from rdflib.plugins import sparql
from rdflib.namespace import RDF, RDFS, XSD
from rdflib.serializer import Serializer

# %%
from re import sub
def snake_case(s):
  return urllib.parse.quote(
    '_'.join(
    sub('([A-Z][a-z]+)', r' \1',
    sub('([A-Z]+)', r' \1',
    s.replace('-', ' '))).split()).lower().replace(":", "_").replace("#", "_").replace("\"", "_").replace("'", "_").replace("/", "_")
    )

# %%
url = 'ontology/animeowl.owl'
g = rdflib.Graph()
result = g.parse(url, format='turtle')

# %%
def make_object_property(name, domain, range):
    object_property = URIRef(f"{default_schema}#op_{name}")
    g.add((object_property, RDF.type, URIRef(f"{owl_schema}#ObjectProperty")))
    g.add((object_property, URIRef(f"{rdfs_schema}#domain"), domain))
    g.add((object_property, URIRef(f"{rdfs_schema}#range"), range))
    #print(object_property)
    return object_property

# %%
def make_data_property(name, domain):
    data_property = URIRef(f"{default_schema}#dp_{name}")
    g.add((data_property, RDF.type, URIRef(f"{owl_schema}#DatatypeProperty")))
    g.add((data_property, URIRef(f"{rdfs_schema}#domain"), domain))
    return data_property

# %%
def link(a, a_rel_type_b, b_rel_type_a, b, is_symmetrical=True):
    g.add((a, a_rel_type_b, b))
    if is_symmetrical:
        g.add((b, b_rel_type_a, a))

# %%
#schemas
default_schema = "http://ani.me"
rdfs_schema = "http://www.w3.org/2000/01/rdf-schema"
owl_schema = "http://www.w3.org/2002/07/owl"

# classes
anime_class = URIRef(f"{default_schema}#Anime")
character_class = URIRef(f"{default_schema}#Character")
genre_class = URIRef(f"{default_schema}#Genre")
studio_class = URIRef(f"{default_schema}#Studio")

#object properties
anime_has_character = make_object_property("anime_has_character", anime_class, character_class)
anime_has_genre = make_object_property("anime_has_genre", anime_class, genre_class)
anime_has_studio = make_object_property("anime_has_studio", anime_class, studio_class)
character_has_anime = make_object_property("character_has_anime", character_class, anime_class)
genre_has_anime = make_object_property("genre_has_anime", genre_class, anime_class)
studio_has_anime = make_object_property("studio_has_anime", studio_class, anime_class)

# %%
def make_genre_field(individual, field, value, lang=""):
    data_property = make_data_property(snake_case(field), genre_class)
    g.add((individual, data_property, Literal(value, lang=lang)))

def make_genre_individual(genre_model):
    genre_name = snake_case(genre_model["name"])
    individual = URIRef(f"{default_schema}#genre_{genre_name}")
    g.add((individual, RDF.type, URIRef(f"{owl_schema}#NamedIndividual")))
    g.add((individual, RDF.type, genre_class))
    make_genre_field(individual, "name", genre_model["name"])
    make_genre_field(individual, "name", genre_model["russian"], lang="ru")
    make_genre_field(individual, "shiki_id", genre_model["id"])
    make_genre_field(individual, "kind", genre_model["kind"])
    #print(individual)
    return individual

# %%
def make_studio_field(individual, field, value, lang=""):
    data_property = make_data_property(snake_case(field), studio_class)
    g.add((individual, data_property, Literal(value, lang=lang)))

def make_studio_individual(studio_model):
    studio_name = snake_case(studio_model["name"])
    individual = URIRef(f"{default_schema}#studio_{studio_name}")
    g.add((individual, RDF.type, URIRef(f"{owl_schema}#NamedIndividual")))
    g.add((individual, RDF.type, studio_class))
    make_studio_field(individual, "name", studio_model["name"])
    make_studio_field(individual, "filtered_name", studio_model["filtered_name"])
    make_studio_field(individual, "shiki_id", studio_model["id"])
    make_studio_field(individual, "real", studio_model["real"])
    make_studio_field(individual, "image", studio_model["image"])
    #print(individual)
    return individual

# %%
def make_character_field(individual, field, value, lang=""):
    data_property = make_data_property(snake_case(field), character_class)
    g.add((individual, data_property, Literal(value, lang=lang)))

def relate(character, type, relation):
    linked_character = make_character_individual({"id":relation["id"], "entity": relation["entity"]})
    relation_type = make_object_property(snake_case(f"relation_{type}"), character_class, character_class)
    relation_knows = make_object_property(snake_case(f"relation_knows"), character_class, character_class)
    link(character, relation_knows, relation_knows, linked_character)
    link(character, relation_type, relation_type, linked_character, is_symmetrical=False)

def make_character_individual(character_model):

    ignore_fields = [
        "info",
        "anime",
        "relations",
        "characteristics"
    ]

    character_id = character_model["id"]
    individual = URIRef(f"{default_schema}#character_anidbch{character_id}")
    g.add((individual, RDF.type, URIRef(f"{owl_schema}#NamedIndividual")))
    g.add((individual, RDF.type, character_class))

    for field, value in character_model.items():
        if field not in ignore_fields:
            make_character_field(individual, field, value)
        if field == "info":
            for key, anime in value["anime"].items():
                linked_anime = make_anime_individual(anime)
                link(individual, character_has_anime, anime_has_character, linked_anime)
            for type, relations in value["relations"].items():
                for relation in relations:
                    relate(individual, type, relation)
            for characteristic, val in value["characteristics"].items():
                if isinstance(val, list):
                    for item in value:
                        make_character_field(individual, characteristic, item)
                else:
                    make_character_field(individual, characteristic, val)
    return individual

# %%
def make_anime_field(individual, field, value, lang=""):
    data_property = make_data_property(snake_case(field), anime_class)
    g.add((individual, data_property, Literal(value, lang=lang)))

def make_anime_individual(anime_model):

    ignore_fields = [
        "image", 
        "russian",
        "english",
        "japanese", 
        "synonyms",
        "fandubbers",
        "fansubbers",
        "licensors",
        "rates_scores_stats",
        "rates_statuses_stats",
        "genres",
        "studios",
        "videos",
        "screenshots"
    ]

    if "name" in anime_model:
        anime_name = snake_case(anime_model["name"])
        individual = URIRef(f"{default_schema}#anime_{anime_name}")
        g.add((individual, RDF.type, URIRef(f"{owl_schema}#NamedIndividual")))
        g.add((individual, RDF.type, anime_class))

        for field, value in anime_model.items():
            if field not in ignore_fields:
                make_anime_field(individual, field, value)
            if field == "english":
                make_anime_field(individual, 'name', value[0], "en")
            if field == "japanese":
                make_anime_field(individual, 'name', value[0], "jp")
            if field == "russian":
                make_anime_field(individual, 'name', value, "ru")
            if field == "synonyms":
                for synonym in value:
                    make_anime_field(individual, 'name', synonym)
            if field == "fansubbers":
                for fansubber in value:
                    make_anime_field(individual, 'fansubber', fansubber)
            if field == "fandubbers":
                for fundubber in value:
                    make_anime_field(individual, 'fundubber', fundubber)
            if field == "licensors":
                for licensor in value:
                    make_anime_field(individual, 'licensor', licensor)
            if field == "genres":
                for genre in value:
                    linked_genre = make_genre_individual(genre)
                    link(individual, anime_has_genre, genre_has_anime, linked_genre)
            if field == "studios":
                for studio in value:
                    linked_studio = make_studio_individual(studio)
                    link(individual, anime_has_studio, studio_has_anime, linked_studio)
        #print(individual)
        return individual
    else:
        print(f"ERROR: {anime_model}")

# %%
# with open("../jsons/raw/shiki_anime_raw.json", "r") as file:
#      make_anime_individual(json.load(file)["Dragon Ball Z: Fukkatsu no \"F\""])

# %%
with open("../jsons/processed/data_json.json", "r") as file:
    for character in json.load(file):
        make_character_individual(character)

# %%
knows_query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX ani: <http://ani.me#>
SELECT ?name ?knows_name
WHERE
{
  # ?character a ani:Character .
  # ?character ani:op_relation_knows ?relation .
  # ?character ani:dp_name ?name .
  # ?relation ani:dp_name ?knows_name
}  
"""

qres = g.query(knows_query)
for row in qres:
    #print(row)
    print(f"{row.name} knows {row.knows_name}")
# Out:
# A-drei knows Cain
# Cain knows A-drei
# Ai knows Mai
# Ai knows Mea
# Mai knows Ai
# Mai knows Mea
# Mea knows Ai
# Mea knows Mai
# Ai knows Mako
# Ai knows Pao
# Mako knows Ai
# Mako knows Pao
# Pao knows Ai
# Pao knows Mako
# Ai knows Mai
# Mai knows Ai
# Alfred Izuruha knows Chay
# Chay knows Alfred Izuruha
# Alphonse Elric knows Cray
# Cray knows Alphonse Elric
# An knows Ail
# Ail knows An
# An knows Ema
# Ema knows An
# A-ko knows Sae
# Sae knows A-ko
# Abo knows Cado
# Cado knows Abo
# Add knows Gray
# Gray knows Add
# Age knows Kaho
# Ajo knows Kajo
# Kajo knows Ajo
# Aki knows Ryouhei
# Ryouhei knows Aki
# Aki knows Haru
# Aki knows Miltank (Aki)
# Haru knows Aki
# Miltank (Aki) knows Aki
# Aki knows Nao
# Nao knows Aki
# Aki knows Mako
# Mako knows Aki
# Ame knows Hana
# Hana knows Ame
# Ame knows Hare
# Hare knows Ame
# Hare knows Rita
# Hare knows Mari
# Ami knows Ani
# Ani knows Ami
# Amy knows Alex
# Alex knows Amy
# Ani knows Aria
# Ani knows Kaho
# Aria knows Ani
# Aria knows Kaho
# Kaho knows Ani
# Kaho knows Aria
# Ani knows Mina
# Mina knows Ani
# Ani knows Mako
# Ani knows Airi
# Mako knows Ani
# Mako knows Airi
# Mako knows Ruha
# Airi knows Ani
# Airi knows Mako
# Airi knows Ruha
# Ann knows Safu
# Safu knows Ann
# Ans knows Diga
# Diga knows Ans
# Takahashi Aoi knows Suzuki Yua
# Suzuki Yua knows Takahashi Aoi
# APE knows Nana
# Nana knows APE
# Ash knows Ian
# Ian knows Ash
# Aya knows Kyou
# Kyou knows Aya
# Aya knows Airi
# Aya knows Airi
# Airi knows Aya
# Airi knows Aya
# Bay knows Jiyuu Wakusei Doumei
# Jiyuu Wakusei Doumei knows Bay
# Jiyuu Wakusei Doumei knows Chan
# Jiyuu Wakusei Doumei knows Lao
# Cal Shekal knows Aryabhata
# Aryabhata knows Cal Shekal
# CaS knows Aine
# CaS knows Rika
# Aine knows CaS
# Rika knows CaS
# Central Intelligence Agency (Conan) knows Central Intelligence Agency
# Central Intelligence Agency knows Central Intelligence Agency (Conan)
# Dao knows Nami
# Nami knows Dao
# Ema knows Luna
# Luna knows Ema
# Ena knows Gail
# Gail knows Ena
# Eva knows Myne
# Myne knows Eva
# Fai knows May
# May knows Fai
# Fai knows Maou
# Fai knows Mao
# Maou knows Fai
# Maou knows Mao
# Mao knows Fai
# Mao knows Maou
# Chan knows Jiyuu Wakusei Doumei
# Lao knows Jiyuu Wakusei Doumei
# Gia knows Alex
# Gia knows Opal
# Alex knows Gia
# Opal knows Gia
# Hau knows Hala
# Hala knows Hau
# Iva knows Nai
# Nai knows Iva
# Jan knows Alan
# Alan knows Jan
# Joe knows Hina
# Hina knows Joe
# Shan Bruce knows Rin Bruce
# Rin Bruce knows Shan Bruce
# Kai knows Fang
# Fang knows Kai
# Kai knows J.D.
# J.D. knows Kai
# Kai knows Carl
# Kai knows Nina
# Carl knows Kai
# Carl knows Nina
# Nina knows Kai
# Nina knows Carl
# Kai knows Mera
# Mera knows Kai
# Lan knows Vox Rympha
# Vox Rympha knows Lan
# Lao knows Lana
# Lana knows Lao
# Lua knows Luca
# Luca knows Lua
# Mac knows Max
# Max knows Mac
# Mai knows Kana
# Kana knows Mai
# Haruka knows Hikari
# Haruka knows Masato
# Hikari knows Haruka
# Hikari knows Iino Kane
# Hikari knows Kotone
# Masato knows Haruka
# Mao knows Kaki
# Mao knows Suiren
# Kaki knows Mao
# Kaki knows Suiren
# Suiren knows Mao
# Suiren knows Kaki
# Mia knows Luca
# Luca knows Mia
# Moa knows Cyan
# Cyan knows Moa
# Nam knows Anri
# Anri knows Nam
# Nao knows Kaamu
# Kaamu knows Nao
# Kikuchi Akane knows Kujou Hisui
# Kikuchi Akane knows Tanaka Nozomu
# Kikuchi Akane knows Maho
# Kujou Hisui knows Kikuchi Akane
# Kujou Hisui knows Tanaka Nozomu
# Tanaka Nozomu knows Kikuchi Akane
# Tanaka Nozomu knows Kujou Hisui
# Maho knows Kikuchi Akane
# Pan knows Chichi
# Pan knows Mr. Satan
# Chichi knows Pan
# Chichi knows Bulma
# Mr. Satan knows Pan
# Mr. Satan knows Pan
# Pan knows Chichi
# Pan knows Mr. Satan
# Chichi knows Pan
# Pia knows Lufa
# Lufa knows Pia
# Ran knows Lum
# Lum knows Ran
# Ran knows Kuja
# Kuja knows Ran
# Rei knows Airi
# Rei knows Raou
# Rei knows Yuda
# Airi knows Rei
# Raou knows Rei
# Raou knows Gaia
# Yuda knows Rei
# Ray knows Emma
# Ray knows Isabella
# Emma knows Ray
# Isabella knows Ray
# Sae knows Nina
# Nina knows Sae
# Sae knows Hata
# Hata knows Sae
# Sai knows Kira
# Kira knows Sai
# San knows Flan
# Flan knows San
# Flan knows Asta
# Tae knows Outa
# Outa knows Tae
# Tea knows Airi
# Airi knows Tea
# Tia knows Maou
# Maou knows Tia
# Upa knows Bora
# Bora knows Upa
# Val knows Eiha
# Eiha knows Val
# Wal knows Nina
# Nina knows Wal
# Ikezawa Masaomi knows Nagino Satoshi
# Nagino Satoshi knows Ikezawa Masaomi
# Yua knows Nami
# Yua knows Rena
# Nami knows Yua
# Nami knows Rena
# Rena knows Yua
# Rena knows Nami
# Aban knows Boan
# Aban knows Layn
# Boan knows Aban
# Boan knows Layn
# Layn knows Aban
# Layn knows Boan
# Abel knows Cain
# Cain knows Abel
# ACCA knows Rail
# Rail knows ACCA
# ACDC knows Cars
# Cars knows ACDC
# Jubstacheit von Einzbern knows Illyasviel von Einzbern
# Jubstacheit von Einzbern knows Irisviel von Einzbern
# Illyasviel von Einzbern knows Jubstacheit von Einzbern
# Illyasviel von Einzbern knows Irisviel von Einzbern
# Irisviel von Einzbern knows Jubstacheit von Einzbern
# Irisviel von Einzbern knows Illyasviel von Einzbern
# Adan knows Maou
# Maou knows Adan
# Adel knows Faye
# Faye knows Adel
# Ados knows Maya
# Maya knows Ados
# Ainz knows Aura
# Ainz knows Mare
# Aura knows Ainz
# Mare knows Ainz
# Airi knows Rana
# Rana knows Airi
# Ruha knows Airi
# Ruha knows Mako
# Aisa knows Laki
# Laki knows Aisa
# Alma knows Opal
# Opal knows Alma
# Ange knows Luva
# Luva knows Ange
# Ange knows Oujo Charlotte
# Oujo Charlotte knows Ange
# Anko knows Dabu
# Anko knows Dora
# Dabu knows Anko
# Dabu knows Dora
# Dora knows Anko
# Dora knows Dabu
# Anna knows Hans
# Hans knows Anna
# Anne knows Grea
# Grea knows Anne
# Anti knows Anti
# Anti knows Anti
# Anzu knows Hina
# Hina knows Anzu
# Aqua knows Hans
# Hans knows Aqua
# Aria knows Lisa
# Lisa knows Aria
# Artemis knows Jeda
# Jeda knows Artemis
# Asta knows Flan
# Atui knows Haku
# Haku knows Atui
# Aura knows Kuroki Kaze
# Kuroki Kaze knows Aura
# Azan knows Guts
# Guts knows Azan
# Guts knows Luca
# Baba knows Ouya
# Baba knows Kira
# Ouya knows Baba
# Ouya knows Ouya
# Kira knows Baba
# Bado knows Lena
# Lena knows Bado
# Badr knows Esra
# Esra knows Badr
# Bari knows Lala
# Lala knows Bari
# Nyorotono (Nabi) knows Nabi
# Nabi knows Nyorotono (Nabi)
# Bima knows Jima
# Jima knows Bima
# Cana knows Lina
# Lina knows Cana
# Iino Kane knows Hikari
# Caro knows Fina
# Fina knows Caro
# Sado Yasutora knows Noba
# Sado Yasutora knows Noba
# Noba knows Sado Yasutora
# Noba knows Sado Yasutora
# Dall knows Reca
# Reca knows Dall
# Reca knows Mani
# Kotone knows Hikari
# Dita knows Jima
# Jima knows Dita
# Kuni knows Isao
# Isao knows Kuni
# Elsa knows Rein
# Rein knows Elsa
# Emma knows Hans
# Hans knows Emma
# Isora knows Nami
# Nami knows Isora
# Fana knows Mars
# Mars knows Fana
# Faru knows Jiisuri
# Jiisuri knows Faru
# Fusa knows Saki
# Saki knows Fusa
# Gagi knows Naki
# Gagi knows Naki
# Naki knows Gagi
# Naki knows Gagi
# Naki knows Goat
# Gaia knows Raou
# Gaku knows Haru
# Haru knows Gaku
# Luca knows Guts
# Luca knows Nina
# Gera knows Mace
# Mace knows Gera
# Goat knows Naki
# Hack knows Sabo
# Sabo knows Hack
# Haha knows Jack
# Jack knows Haha
# Rita knows Hare
# Iona knows Mayu
# Mayu knows Iona
# Jack knows Kana
# Kana knows Jack
# Jagi knows Raou
# Raou knows Jagi
# JAXA knows Uchuu Koukuu Kenkyuukaihatsu Kikou
# Uchuu Koukuu Kenkyuukaihatsu Kikou knows JAXA
# Kaho knows Age
# Kako knows Maco
# Maco knows Kako
# Kame knows Bulma
# Bulma knows Kame
# Bulma knows Chichi
# Bulma knows Puar
# Kate knows Mary
# Mary knows Kate
# Yagami Light knows Near
# Near knows Yagami Light
# Lana knows Mija
# Mija knows Lana
# Lara knows Leira
# Leira knows Lara
# Puar knows Bulma
# Tower Tycoon Lila knows Masa
# Masa knows Tower Tycoon Lila
# Lizardon (Sieg) knows Sieg
# Sieg knows Lizardon (Sieg)
# Lola knows Nami
# Nami knows Lola
# Luca knows Pace
# Pace knows Luca
# Nina knows Luca
# Luna knows Riza
# Riza knows Luna
# Mama knows Papa
# Papa knows Mama
# Mama knows Papa
# Papa knows Mama
# Mama knows Papa
# Papa knows Mama
# Tarou no Okaasan knows Tarou no Chichioya
# Tarou no Chichioya knows Tarou no Okaasan
# Mama knows Mari
# Mari knows Mama
# Mama knows Papa
# Mama knows Mika
# Mika knows Mama
# Mika knows Papa
# Mama knows Papa
# Papa knows Mama
# Mama knows Rita
# Rita knows Mama
# Rita knows Papa
# Mani knows Reca
# Shiki Granbell knows Ziggy
# Ziggy knows Shiki Granbell
# Marg knows Mars
# Mars knows Marg
# Mari knows Hare
# Nidoran (Emily) knows Nidorina (Emily)
# Nidorina (Emily) knows Nidoran (Emily)
# Masa knows Misa
# Misa knows Masa
# Maya knows Saga
# Saga knows Maya
# Mayu knows Nana
# Nana knows Mayu
# Mayu knows Miwa
# Miwa knows Mayu
# Maza knows Rika
# Rika knows Maza
# Papa knows Mika
# Mina knows Riza
# Riza knows Mina
# Misa knows Nana
# Nana knows Misa
# Nabu knows Nabu
# Nabu knows Nabu
# Nami knows Rena
# Rena knows Nami
# National Aeronautics and Space Administration knows NASA
# NASA knows National Aeronautics and Space Administration
# Onna knows Onna
# Onna knows Onna
# Ouya knows Ouya
# Papa knows Mama
# Papa knows Rita

# %%
# G = rdflib_to_networkx_multidigraph(result)
# plt.rcParams['figure.figsize'] = [40, 40] # for square canvas
# # Plot Networkx instance of RDF Graph
# pos = nx.spring_layout(G, scale=1)
# edge_labels = nx.get_edge_attributes(G, 'r')
# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
# nx.draw(G, with_labels=True)

# #if not in interactive mode for 
# plt.show()

# %%
import io
import pydotplus
from IPython.display import display, Image
from rdflib.tools.rdf2dot import rdf2dot

def visualize(g):
    stream = io.StringIO()
    rdf2dot(g, stream, opts = {display})
    dg = pydotplus.graph_from_dot_data(stream.getvalue())
    png = dg.create_png()
    display(Image(png))

#visualize(g)

# %%
g.serialize(destination="test.owl", format="n3")
# Out:
# <Graph identifier=N324fdd1ee6c041039051b4816e1acf2d (<class 'rdflib.graph.Graph'>)>

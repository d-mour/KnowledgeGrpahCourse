# %%
import pandas as pd
from bs4 import BeautifulSoup
from dataclasses import dataclass
import aiohttp 
import asyncio

# %%
@dataclass(frozen=True)
class Job:
    artist_name: str
    composition_name: str
    url: str
        
    @property
    def full_name(self):
        return f"{self.composition_name} by {self.artist_name}"
    
    @property
    def key(self):
        return self.url

# %%
def get_url(path):
    return "https://www.hooktheory.com" + path

async with aiohttp.ClientSession() as session:
    async with session.get(get_url("/theorytab/charts/chart/top")) as resp:
        soup = BeautifulSoup(await resp.text())
        top_songs_a_tags = soup.select("ul.grid2468 > li.grid-item > a")

print(f"{len(top_songs_a_tags)} initial song(s).")
# Out:
# 49 initial song(s).

# %%
def top_song_a_tag_to_job(a):
    href = a.attrs["href"]
    artist_name = a.select_one("tr span.span-song").text[len("by "):]
    composition_name = a.select_one("tr b").text
    return Job(artist_name, composition_name, href)
    
for a in top_songs_a_tags[:10]:
    print(top_song_a_tag_to_job(a))
job = top_song_a_tag_to_job(top_songs_a_tags[10])
# Out:
# Job(artist_name='Queen', composition_name='Bohemian Rhapsody', url='/theorytab/view/queen/bohemian-rhapsody')
# Job(artist_name='Daft Punk', composition_name='Get Lucky', url='/theorytab/view/daft-punk/get-lucky')
# Job(artist_name='Knife Party', composition_name='Baghdad', url='/theorytab/view/knife-party/baghdad')
# Job(artist_name='Celine Dion', composition_name='My Heart Will Go On', url='/theorytab/view/celine-dion/my-heart-will-go-on')
# Job(artist_name='Taylor Swift', composition_name='Shake It Off', url='/theorytab/view/taylor-swift/shake-it-off')
# Job(artist_name='Green Day', composition_name='Boulevard of Broken Dreams', url='/theorytab/view/green-day/boulevard-of-broken-dreams')
# Job(artist_name='Tristam and Braken', composition_name='Frame of Mind', url='/theorytab/view/tristam-and-braken/frame-of-mind')
# Job(artist_name='Nintendo', composition_name='The Legend of Zelda Main Theme', url='/theorytab/view/nintendo/legend-of-zelda-main-theme')
# Job(artist_name='Deadmau5', composition_name='Some Chords', url='/theorytab/view/deadmau5/some-chords')
# Job(artist_name='Johann Pachelbel', composition_name='Canon in D Major', url='/theorytab/view/johann-pachelbel/canon-in-d-major')

# %%
# SEARCH_AUTH_KEY = input("Search Auth Key: ").strip()
SEARCH_AUTH_KEY = "YHXUiQCa6024e2a88cb48f226a94d16db0c20d993e0a424cfde7834b697445bdf280ce88"

# %%
def name_to_dashed_lowercase(name: str):
    return "-".join(e.lower() for e in name.split())
name_to_dashed_lowercase(job.artist_name)
# Out:
# 'bob-dylan'

# %%
def song_ytlist_a_tag_to_job(a):
    table = a.find_next_sibling()
    return Job(
        artist_name=table.select_one("p.artist").text[len("by "):],
        composition_name=table.select_one("p.song").text, 
        url=a.attrs["href"],
    )

async def process_job(session, job):
    """ :returns (result, new_jobs) """
    payload = {"q": f"{job.artist_name} {job.composition_name}"}
    async with session.post("https://search.hooktheory.com/indexes/theorytabs/search", json=payload) as resp:
        hits = (await resp.json())["hits"]
    
    if not hits:
        return None, []
    
    result = max(hits, key=lambda e: (
        e["song"].lower() == job.composition_name.lower(), 
        e["artist"].lower() == job.artist_name.lower(), 
        len(e["chordAbs"]) + len(e["chordRel"]),
    ))

    artist_in_url = name_to_dashed_lowercase(result["artist"])
    song_in_url = name_to_dashed_lowercase(result["song"])
    url = get_url(f"/theorytab/view/{artist_in_url}/{song_in_url}")
    async with session.get(url) as resp:
        soup = BeautifulSoup(await resp.text())
    
    new_jobs = [
        song_ytlist_a_tag_to_job(a) for a in soup.select("div.col-md-4 > h3 + ul.yt-list a") 
        if a.attrs.get("href", "").startswith("/theorytab/view/")
    ]
    
    return result, new_jobs
    
async with aiohttp.ClientSession(headers={"Authorization": f"Bearer {SEARCH_AUTH_KEY}"}) as session:
    result, new_jobs = await process_job(session, top_song_a_tag_to_job(top_songs_a_tags[12]))
    print(result)
    print(new_jobs)
# Out:
# {'song': 'Four Chord Songs', 'artist': 'The Axis Of Awesome', 'chordAbs': 'qqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqqEqqBqqC#mqqAqq', 'chordRel': 'qqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqqIqqVqqwjqqIVqq', 'SInD': 'qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq1qq5qq6qq4qq', 'key': 'E major', 'id': 1341, 'ytid': 'oOlDewpCfZQ'}
# [Job(artist_name='Tim Minchin', composition_name='15 Minutes', url='/theorytab/view/tim-minchin/15-minutes'), Job(artist_name='Tim and Eric', composition_name='Come Over', url='/theorytab/view/tim-and-eric/come-over'), Job(artist_name='Paul and Storm', composition_name='Here Come The Dinosaurs', url='/theorytab/view/paul-and-storm/here-come-the-dinosaurs'), Job(artist_name='Tim Minchin', composition_name='Not Perfect', url='/theorytab/view/tim-minchin/not-perfect'), Job(artist_name='Paul and Storm', composition_name='Opening Band', url='/theorytab/view/paul-and-storm/opening-band'), Job(artist_name='Tim Minchin', composition_name='Ten Foot Cock And A Few Hundred Virgins', url='/theorytab/view/tim-minchin/ten-foot-cock-and-a-few-hundred-virgins'), Job(artist_name='Tom Lehrer', composition_name="We'll All Go Together When We Go", url='/theorytab/view/tom-lehrer/well-all-go-together-when-we-go'), Job(artist_name='Pedro Capo', composition_name='Calma', url='/theorytab/view/pedro-capo/calma'), Job(artist_name='Camilo', composition_name='Tutu (feat Pedro Capo)', url='/theorytab/view/camilo/tutu-%28feat-pedro-capo%29'), Job(artist_name='Jessi', composition_name='What Type of X', url='/theorytab/view/jessi/what-type-of-x'), Job(artist_name='INXS', composition_name='Need You Tonight', url='/theorytab/view/inxs/need-you-tonight'), Job(artist_name='Sky Ferreira', composition_name='Love In Stereo', url='/theorytab/view/sky-ferreira/love-in-stereo'), Job(artist_name='Don Blackman', composition_name="Heart's Desire", url='/theorytab/view/don-blackman/hearts-desire'), Job(artist_name='Shura', composition_name='Tongue Tied', url='/theorytab/view/shura/tongue-tied'), Job(artist_name='Mobb Deep', composition_name='Shook Ones Pt II', url='/theorytab/view/mobb-deep/shook-ones-pt-ii'), Job(artist_name='Rae Morris', composition_name='Someone Out There', url='/theorytab/view/rae-morris/someone-out-there'), Job(artist_name='Korn', composition_name='Freak On A Leash', url='/theorytab/view/korn/freak-on-a-leash'), Job(artist_name='Mother Mother', composition_name='Biting On A Rose', url='/theorytab/view/mother-mother/biting-on-a-rose'), Job(artist_name='Sigrid', composition_name="Don't Feel Like Crying", url='/theorytab/view/sigrid/dont-feel-like-crying'), Job(artist_name='ABBA', composition_name='Does Your Mother Know', url='/theorytab/view/abba/does-your-mother-know'), Job(artist_name='Aerosmith', composition_name='Dream On', url='/theorytab/view/aerosmith/dream-on'), Job(artist_name='The Stone Roses', composition_name='Love Spreads', url='/theorytab/view/the-stone-roses/love-spreads'), Job(artist_name='Genesis', composition_name='Land Of Confusion', url='/theorytab/view/genesis/land-of-confusion'), Job(artist_name='Motoi Sakuraba', composition_name='Battle (Saturos)', url='/theorytab/view/motoi-sakuraba/battle-%28saturos%29'), Job(artist_name='Papa Roach', composition_name='Last Resort', url='/theorytab/view/papa-roach/last-resort'), Job(artist_name='Dorian Electra', composition_name='Flamboyant', url='/theorytab/view/dorian-electra/flamboyant'), Job(artist_name='Florence and the Machine', composition_name='Drumming Song', url='/theorytab/view/florence-and-the-machine/drumming-song'), Job(artist_name='Carly Pearce', composition_name='Never Wanted To Be That Girl', url='/theorytab/view/carly-pearce/never-wanted-to-be-that-girl'), Job(artist_name='Mother Mother', composition_name='Good At Loving You', url='/theorytab/view/mother-mother/good-at-loving-you'), Job(artist_name='Information Society', composition_name="What's On Your Mind (Pure Energy)", url='/theorytab/view/information-society/whats-on-your-mind-%28pure-energy%29'), Job(artist_name='Kesha', composition_name='Gold Trans Am', url='/theorytab/view/kesha/gold-trans-am'), Job(artist_name='Mother Mother', composition_name='So Down', url='/theorytab/view/mother-mother/so-down'), Job(artist_name='Eve', composition_name='Let Me Blow Ya Mind (ft Gwen Stefani)', url='/theorytab/view/eve/let-me-blow-y ...

# %%
queue = asyncio.Queue()
for a in top_songs_a_tags:
    queue.put_nowait(top_song_a_tag_to_job(a))
print(f"Initial queue size: {queue.qsize()}")    

results = {}
seen = set()
seen_lock = asyncio.Lock()
queued = set()
queued_lock = asyncio.Lock()
# Out:
# Initial queue size: 49

# %%
counter_lock = asyncio.Lock()
counter = 10000
n_workers = 100

async def worker(n):
    global counter
    async with aiohttp.ClientSession(headers={"Authorization": f"Bearer {SEARCH_AUTH_KEY}"}) as session: 
        while counter > n_workers:
            job = await queue.get()
            
            async with seen_lock:
                if job.key in seen:
                    continue
                seen.add(job.key)

            try:
                result, new_jobs = await process_job(session, job)
            except Exception as e:
                print(f"{e.__class__.__name__}: {e} for {job}")
                result, new_jobs = None, []

            added_jobs = 0
            async with queued_lock:
                for new_job in new_jobs:
                    if new_job.key not in queued:
                        added_jobs += 1
                        queued.add(new_job.key)
                        queue.put_nowait(new_job)
            
            result["link"] = job.url
            results[job.key] = result

            async with counter_lock:
                counter -= 1
                print(f"{counter:4}\t+{added_jobs}\t{len(new_jobs) - added_jobs:3} skipped\t"
                      f"{len(results):3} total\t{queue.qsize():3} queued\t{job.artist_name}, {job.composition_name}.")
            
            queue.task_done()

workers = [worker(i) for i in range(n_workers)]

import time
start_time = time.time()

# try: 
await asyncio.gather(*workers)
# finally:
#     duration = time.time() - start_time
#     print(f"Done in {duration:.2f} s.")
# Out:
# 9999	+0	 48 skipped	10044 total	343 queued	Haken, Cockroach King.
# 9998	+0	 40 skipped	10045 total	342 queued	Hem, The Seed.
# 9997	+1	 43 skipped	10046 total	342 queued	C2C, The Beat.
# 9996	+1	 51 skipped	10047 total	342 queued	AZEDIA, Something.
# 9995	+0	 41 skipped	10048 total	341 queued	Stupeflip, Stupeflip Vite.
# 9994	+0	  0 skipped	10049 total	340 queued	Girl's Day, Don't Forget Me.
# 9993	+0	 51 skipped	10050 total	339 queued	Jon Bellion, Fashion.
# 9992	+11	 57 skipped	10051 total	349 queued	Leessang, Leessang Blues.
# 9991	+0	 41 skipped	10052 total	348 queued	Stupeflip, Crou Anthem.
# 9990	+0	 67 skipped	10053 total	347 queued	The Cure, Lovesong.
# 9989	+0	 43 skipped	10054 total	346 queued	ShockOne, Light Cycles.
# 9988	+0	 67 skipped	10055 total	345 queued	The Cure, The Figurehead.
# 9987	+0	 67 skipped	10056 total	344 queued	The Cure, Pictures Of You.
# 9986	+0	 44 skipped	10057 total	343 queued	C2C, Down The Road.
# 9985	+0	 40 skipped	10058 total	342 queued	The Correspondents, Who Knew.
# 9984	+0	 58 skipped	10059 total	341 queued	Les Miserables, On My Own.
# 9983	+0	 81 skipped	10060 total	340 queued	Aphex Twin, Fingerbib.
# 9982	+0	 44 skipped	10061 total	339 queued	Die Prinzen, Deutschland.
# 9981	+1	 43 skipped	10062 total	339 queued	Pachanga Boys, Time.
# 9980	+0	 51 skipped	10063 total	338 queued	Jon Bellion, All Time Low.
# 9979	+0	 69 skipped	10064 total	337 queued	Rob Gasser, Ecstasy - feat Nitro Fun.
# 9978	+0	  0 skipped	10065 total	336 queued	The Cure, Boys Don't Cry.
# 9977	+0	 81 skipped	10066 total	335 queued	Aphex Twin, Flim.
# 9976	+0	 43 skipped	10067 total	334 queued	Eluveitie, Inis Mona.
# 9975	+0	 69 skipped	10068 total	333 queued	Rob Gasser, Ricochet.
# 9974	+0	 41 skipped	10069 total	332 queued	JAHKOY, California Heaven - Medasin Remix.
# 9973	+1	 41 skipped	10070 total	332 queued	Evidence, The Epilogue.
# 9972	+0	 67 skipped	10071 total	331 queued	The Cure, Just Like Heaven.
# 9971	+0	 81 skipped	10072 total	330 queued	Aphex Twin, Iz-us.
# 9970	+0	  0 skipped	10073 total	329 queued	Moulin Rouge, One Day I'll Fly Away.
# 9969	+0	 42 skipped	10074 total	328 queued	Squarepusher, Iambic 5 Poetry.
# 9968	+0	  0 skipped	10075 total	327 queued	Girl's Day, Darling.
# 9967	+1	348 skipped	10076 total	327 queued	Lin-Manuel Miranda, Stay Alive.
# 9966	+0	 81 skipped	10077 total	326 queued	Aphex Twin, 4.
# 9965	+0	  0 skipped	10078 total	325 queued	Blackhawk, Like There Ain't No Yesterday.
# 9964	+0	349 skipped	10079 total	324 queued	Lin-Manuel Miranda, Hurricane.
# 9963	+0	 49 skipped	10080 total	323 queued	Dustin Kensrue, Rejoice.
# 9962	+0	 44 skipped	10081 total	322 queued	Lucio Dalla, Caruso.
# 9961	+0	 47 skipped	10082 total	321 queued	Ashley Parker Angel, Let U Go.
# 9960	+0	 81 skipped	10083 total	320 queued	Aphex Twin, Vordhosbn.
# 9959	+0	  0 skipped	10084 total	319 queued	Ma Rainey, Don't Fish In My Sea.
# 9958	+0	 49 skipped	10085 total	318 queued	Dustin Kensrue, It Is Finished.
# 9957	+0	  0 skipped	10086 total	317 queued	Broadcast, Come On Let's Go.
# 9956	+0	 81 skipped	10087 total	316 queued	Aphex Twin, Heliosphan.
# 9955	+0	 48 skipped	10088 total	315 queued	Haken, Celestial Elixir.
# 9954	+0	 41 skipped	10089 total	314 queued	T-ARA, Sugar Free.
# 9953	+0	 81 skipped	10090 total	313 queued	Aphex Twin, Windowlicker.
# 9952	+0	 42 skipped	10091 total	312 queued	Casting Crowns, Joy to the World - Christmas.
# 9951	+0	 53 skipped	10092 total	311 queued	BIGBANG, Loser.
# 9950	+0	 81 skipped	10093 total	310 queued	Aphex Twin, Bucephalus Bouncing Ball.
# 9949	+0	  0 skipped	10094 total	309 queued	Franco Battiato, Centro Di Gravita' Permanente.
# 9948	+0	 42 skipped	10095 total	308 queued	Squarepusher, Plug Me In.
# 9947	+2	 41 skipped	10096 total	309 queued	Unknown Brain, Superhero feat Chris Linton.
# 9946	+0	 40 skipped	10097 total	308 queued	Parov Stelar, The Mojo Radio Gang.
# 9945	+0	 81 skipped	10098 total	307 queued	Aphex Twin, Ageispolis.
# 9944	+1	213 skipped	10099 total	307 queued	The Aston Shuffle, No Place Like Home.
# 9943	+0	349 skipped	10100 total	306 queued	Lin-Manuel Miranda, What Else Can I Do.
# 9942	+1	 43 skipped	10101 total	306 queued	Bobby Shmurda, Hot N-gga.
# 9941	+0	 40 skipped	10102 total	305 queued	Dizzy Wright, God Bless America.
# 9940	+0	 42 skipped	10103 total	304 queued	Casting Crowns, O Come All Ye Faithful - Christmas.
# 9939	+1	 83 skipped	10104 total	304 queued	Perfume, Cosmic Explorer.
# 9938	+0	 41 skipped	10105 total	303 queued	Astor Piazzolla, Libertango.
# 9937	+1	 49 skipped	10106 total	303 queued	JJ Lin, Always Online.
# 9936	+0	 81 skipped	10107 total	302 queued	Aphex Twin, Xtal.
# 9935	+0	 81 skipped	10108 total	301 queued	Aphex Twin, Avril 14th.
# 9934	+0	 84 skipped	10109 total	300 queued	Perfume, Chocolate Disco.
# 9933	+1	 49 skipped	10110 total	300 queued	Broadcast, Papercuts.
# 9932	+0	 40 skipped	10111 total	299 queued	Kate Wolf, Give Yourself to Love.
# 9931	+0	 42 skipped	10112 total	298 queued	David Lee Murphy, Dust On The Bottle.
# 9930	+0	  0 skipped	10113 total	297 queued	Yann Tiersen, Comptine d'un autre ete L'apres midi.
# 9929	+0	  0 skipped	10114 total	296 queued	Leessang, Can't Breakup Girl Can't Breakaway Boy.
# 9928	+0	 84 skipped	10115 total	295 queued	Perfume, Computer City.
# 9927	+0	  0 skipped	10116 total	294 queued	Girl's Day, White Day.
# 9926	+0	  0 skipped	10117 total	293 queued	Nicola Conte , Jet Sounds - Thievery Corporation Remix.
# 9925	+0	349 skipped	10118 total	292 queued	Lin-Manuel Miranda, My Shot.
# 9924	+0	  0 skipped	10119 total	291 queued	Girl's Day, Hello Bubble.
# 9923	+0	 81 skipped	10120 total	290 queued	Aphex Twin, Alberto Balsam.
# 9922	+0	349 skipped	10121 total	289 queued	Lin-Manuel Miranda, The Family Madrigal.
# 9921	+0	 41 skipped	10122 total	288 queued	Francesca Battistelli, This Is The Stuff.
# 9920	+0	 67 skipped	10123 total	287 queued	The Cure, A Forest.
# 9919	+0	  0 skipped	10124 total	286 queued	Yann Tiersen, La Valse D'Amelie.
# 9918	+0	 41 skipped	10125 total	285 queued	Asuka Ninomiya - Hajime Fujiwara - Karen Hojo, Mikansei no Rekishi.
# 9917	+0	 69 skipped	10126 total	284 queued	Rob Gasser, Until Next Time feat Auvic.
# 9916	+0	  0 skipped	10127 total	283 queued	The Cure, Friday I'm In Love.
# 9915	+0	 40 skipped	10128 total	282 queued	Brian Crain, Leaves On The Water.
# 9914	+0	 41 skipped	10129 total	281 queued	Pyramid, Wolf.
# 9913	+0	 84 skipped	10130 total	280 queued	Perfume, Butterfly.
# 9912	+0	 81 skipped	10131 total	279 queued	Aphex Twin, Minipops 67.
# 9911	+0	 40 skipped	10132 total	278 queued	Hideki Naganuma, Grace and Glory (B-B-H-M-Mix).
# 9910	+0	  0 skipped	10133 total	277 queued	Yann Tiersen, J'y suis jamais alle.
# 9909	+0	 81 skipped	10134 total	276 queued	Aphex Twin, PAPAT4.
# 9908	+0	 69 skipped	10135 total	275 queued	Rob Gasser, Full Force.
# 9907	+0	 41 skipped	10136 total	274 queued	T-ara, I Go Crazy Because of You.
# 9906	+0	 69 skipped	10137 total	273 queued	Rob Gasser, Wrong Answer.
# 9905	+0	 44 skipped	10138 total	272 queued	Franco Battiato, Voglio Vederti Danzare.
# 9904	+0	  0 skipped	10139 total	271 queued	Lin-Manuel Miranda, You'll Be Back.
# 9903	+0	 69 skipped	10140 total	270 queued	Rob Gasser, Move.
# 9902	+0	  0 skipped	10141 total	269 queued	Girl's Day, Nothing Lasts Forever.
# 9901	+0	 40 skipped	10142 total	268 queued	Herbert Gronemeyer, Lache Wenn Es Nicht Zum Weinen Reicht.
# 9900	+0	 84 skipped	10143 total	267 queued	Perfume, Hold Your Hand.
# 9899	+0	 42 skipped	10144 total	266 queued	Squarepusher, Beep Street.
# 9898	+0	 58 skipped	10145 total	265 queued	Les Miserables, Do You Hear The People Sing.
# 9897	+0	 81 skipped	10146 total	264 queued	Aphex Twin, Rhubarb.
# 9896	+0	349 skipped	10147 total	263 queued	Lin-Manuel Miranda, Wait For It - Hamilton.
# 9895	+0	  0 skipped	10148 total	262 queued	Girl's Day, Let's Go.
# 9894	+0	 44 skipped	10149 total	261 queued	Franco Battiato, Bandiera Bianca.
# 9893	+0	349 skipped	10150 total	260 queued	Lin-Manuel Miranda, Satisfied.
# 9892	+0	 84 skipped	10151 total	259 queued	Perfume, Oishii Recipe.
# 9891	+0	 46 skipped	10152 total	258 queued	Gabriel Rios, Baby Lone Star.
# 9890	+0	 81 skipped	10153 total	257 queued	Bent Van Looy, Flowers and Balloons.
# 9889	+0	 84 skipped	10154 total	256 queued	Perfume, Sweet Donuts.
# 9888	+1	 40 skipped	10155 total	256 queued	Robert Wyatt, Sea Song.
# 9887	+1	 48 skipped	10156 total	256 queued	Bellini, Samba De Janeiro.
# 9886	+0	 44 skipped	10157 total	255 queued	Asaf Avidan, One Day.
# 9885	+0	349 skipped	10158 total	254 queued	Lin-Manuel Miranda, Waiting On a Miracle.
# 9884	+0	 81 skipped	10159 total	253 queued	Bent Van Looy, Shadow of a Man.
# 9883	+3	 40 skipped	10160 total	255 queued	Kato, Celebrate Life - Stafford Brothers Remix.
# 9882	+0	 41 skipped	10161 total	254 queued	Geographer, Kites.
# 9881	+0	 84 skipped	10162 total	253 queued	Perfume, Polyrhythm.
# 9880	+10	 42 skipped	10163 total	262 queued	Shakey Graves, Dearly Departed.
# 9879	+1	 64 skipped	10164 total	262 queued	Walk off the Earth, Lightning Bolt.
# 9878	+0	 84 skipped	10165 total	261 queued	Perfume, Magic of Love.
# 9877	+0	 84 skipped	10166 total	260 queued	Perfume, Sweet Refrain.
# 9876	+0	 84 skipped	10167 total	259 queued	Perfume, Omajinai Perori.
# 9875	+0	 84 skipped	10168 total	258 queued	Perfume, GLITTER.
# 9874	+0	 84 skipped	10169 total	257 queued	Perfume, Spice.
# 9873	+0	349 skipped	10170 total	256 queued	Lin-Manuel Miranda, We Know - Hamilton.
# 9872	+0	 42 skipped	10171 total	255 queued	K Camp, Cut Her Off.
# 9871	+0	 81 skipped	10172 total	254 queued	Bent Van Looy, Words.
# 9870	+2	 46 skipped	10173 total	255 queued	Animaniacs, Magna Carta Song.
# 9869	+0	  0 skipped	10174 total	254 queued	L'Imperatrice, Tako Tsubo.
# 9868	+0	 48 skipped	10175 total	253 queued	Animaniacs, Reboot It.
# 9867	+0	 52 skipped	10176 total	252 queued	Jerry Paper, All Clowns.
# 9866	+0	  0 skipped	10177 total	251 queued	Red Vox, Atom Bomb.
# 9865	+0	  0 skipped	10178 total	250 queued	Ariel Pink, Put Your Number In My Phone.
# 9864	+1	 49 skipped	10179 total	250 queued	Crumb, Bones.
# 9863	+0	  0 skipped	10180 total	249 queued	DAGames, You're Mine.
# 9862	+0	  0 skipped	10181 total	248 queued	Ariel Pink, Mature Themes.
# 9861	+0	 40 skipped	10182 total	247 queued	The Dear Hunter, Crow and Cackle.
# 9860	+0	 60 skipped	10183 total	246 queued	Lupe Fiasco, Alan Forever.
# 9859	+0	 52 skipped	10184 total	245 queued	Jerry Paper, Zoom Out.
# 9858	+0	 51 skipped	10185 total	244 queued	This Town Needs Guns, Lemur.
# 9857	+0	 52 skipped	10186 total	243 queued	Red Vox, Reno.
# 9856	+0	 43 skipped	10187 total	242 queued	Ghost, Kiss The Go-Goat.
# 9855	+0	 64 skipped	10188 total	241 queued	Bladee, Hotel Breakfast.
# 9854	+3	 48 skipped	10189 total	243 queued	Crusher-P, ECHO.
# 9853	+0	 64 skipped	10190 total	242 queued	Bladee, Be Nice 2 Me.
# 9852	+0	 51 skipped	10191 total	241 queued	This Town Needs Guns, Baboon.
# 9851	+15	 83 skipped	10192 total	255 queued	Sweet Trip, Darkness.
# 9850	+0	 98 skipped	10193 total	254 queued	Sweet Trip, Dsco.
# 9849	+0	 98 skipped	10194 total	253 queued	Sweet Trip, Milk.
# 9848	+0	 51 skipped	10195 total	252 queued	This Town Needs Guns, Nice Riff Clichard.
# 9847	+0	 40 skipped	10196 total	251 queued	Evol Intent, Middle Of The Night - Jorts Remix.
# 9846	+0	107 skipped	10197 total	250 queued	DAGames, Build Our Machine.
# 9845	+0	 51 skipped	10198 total	249 queued	This Town Needs Guns, Badger.
# 9844	+0	  0 skipped	10199 total	248 queued	This Town Needs Guns, If I Sit Still Maybe I'll Get Out Of Here.
# 9843	+2	 90 skipped	10200 total	249 queued	MitiS, Vulnerability.
# 9842	+0	 42 skipped	10201 total	248 queued	Blue Stahli, Shotgun Senorita.
# 9841	+5	 52 skipped	10202 total	252 queued	Moe Shop, You Look So Good.
# 9840	+0	 98 skipped	10203 total	251 queued	Sweet Trip, In Sound We Found Each Other.
# 9839	+0	 43 skipped	10204 total	250 queued	Ghost, Square Hammer.
# 9838	+0	 92 skipped	10205 total	249 queued	Mitis, Living Color.
# 9837	+0	 92 skipped	10206 total	248 queued	MitiS, Innocent Discretion.
# 9836	+0	 98 skipped	10207 total	247 queued	Sweet Trip, International.
# 9835	+0	 98 skipped	10208 total	246 queued	Sweet Trip, Surviving a Smile.
# 9834	+0	 98 skipped	10209 total	245 queued	Sweet Trip, To All the Dancers of the World.
# 9833	+0	 69 skipped	10210 total	244 queued	Lena Raine, First Steps - Celeste.
# 9832	+0	 51 skipped	10211 total	243 queued	This Town Needs Guns, Rabbit.
# 9831	+0	 98 skipped	10212 total	242 queued	Sweet Trip, Chocolate Matter.
# 9830	+1	 40 skipped	10213 total	242 queued	Harpo, Movie Star.
# 9829	+1	 43 skipped	10214 total	242 queued	Mew, Am I Wry No.
# 9828	+0	 51 skipped	10215 total	241 queued	This Town Needs Guns, Gibbon.
# 9827	+0	 44 skipped	10216 total	240 queued	Amy Grant, Every Heartbeat.
# 9826	+22	 51 skipped	10217 total	261 queued	George Gershwin, Swanee.
# 9825	+0	 51 skipped	10218 total	260 queued	Mac Miller, Good News.
# 9824	+0	 51 skipped	10219 total	259 queued	Mac Miller, Best Day Ever.
# 9823	+0	 46 skipped	10220 total	258 queued	Ecco2k, Pollen.
# 9822	+0	 51 skipped	10221 total	257 queued	This Town Needs Guns, 13 0 0 0 1.
# 9821	+0	 43 skipped	10222 total	256 queued	Ghost, He Is.
# 9820	+0	 51 skipped	10223 total	255 queued	This Town Needs Guns, Zebra.
# 9819	+0	 74 skipped	10224 total	254 queued	Ahrix, Nova.
# 9818	+0	 44 skipped	10225 total	253 queued	Amy Grant, Baby Baby.
# 9817	+0	 53 skipped	10226 total	252 queued	Candy Claws, Pangaea Girls - Magic Feeling.
# 9816	+0	 98 skipped	10227 total	251 queued	Sweet Trip, Velocity.
# 9815	+4	 45 skipped	10228 total	254 queued	Flobots, Handlebars.
# 9814	+0	 92 skipped	10229 total	253 queued	MitiS, WildFlower.
# 9813	+0	 42 skipped	10230 total	252 queued	Machine Gun Kelly, At My Best - ft Hailee Steinfeld.
# 9812	+0	 80 skipped	10231 total	251 queued	Jackson 5, Blame It On The Boogie.
# 9811	+0	 44 skipped	10232 total	250 queued	The Ditty Bops, The Weeds Are Winning.
# 9810	+0	 40 skipped	10233 total	249 queued	Team Me, Riding My Bicycle (From Feddersensgate).
# 9809	+0	 51 skipped	10234 total	248 queued	Mac Miller, Small Worlds.
# 9808	+0	118 skipped	10235 total	247 queued	Jelly Roll Morton, Milenburg Joys.
# 9807	+0	 42 skipped	10236 total	246 queued	Machine Gun Kelly, Bad Things.
# 9806	+0	 51 skipped	10237 total	245 queued	This Town Needs Guns, Crocodile.
# 9805	+0	 44 skipped	10238 total	244 queued	Mew, Comforting Sounds.
# 9804	+0	 69 skipped	10239 total	243 queued	Lena Raine, Resurrections - Celeste.
# 9803	+0	 48 skipped	10240 total	242 queued	meganeko, Discovery.
# 9802	+0	 53 skipped	10241 total	241 queued	Candy Claws, White Seal - Shell and Spine.
# 9801	+0	 69 skipped	10242 total	240 queued	Lena Raine, Scattered And Lost - Celeste.
# 9800	+0	 40 skipped	10243 total	239 queued	Manuel, No Control.
# 9799	+0	 62 skipped	10244 total	238 queued	Globus, Amazing Grace.
# 9798	+0	 69 skipped	10245 total	237 queued	Lena Raine, otherside.
# 9797	+0	 62 skipped	10246 total	236 queued	Globus, Europa.
# 9796	+0	 53 skipped	10247 total	235 queued	Candy Claws, Fell In Love - At The Water.
# 9795	+0	 73 skipped	10248 total	234 queued	George Gershwin, Summertime.
# 9794	+0	 51 skipped	10249 total	233 queued	This Town Needs Guns, Havoc In The Forum.
# 9793	+0	131 skipped	10250 total	232 queued	Deakin, Golden Chords.
# 9792	+0	 92 skipped	10251 total	231 queued	MitiS, Life.
# 9791	+0	 48 skipped	10252 total	230 queued	meganeko, Computer Blues.
# 9790	+0	 51 skipped	10253 total	229 queued	This Town Needs Guns, Dog.
# 9789	+0	 51 skipped	10254 total	228 queued	This Town Needs Guns, Chinchilla.
# 9788	+0	  0 skipped	10255 total	227 queued	Mew, The Zookeeper's Boy.
# 9787	+0	 41 skipped	10256 total	226 queued	Booka Shade, Love Inc.
# 9786	+0	 92 skipped	10257 total	225 queued	MitiS, Born.
# 9785	+0	 47 skipped	10258 total	224 queued	Jonathan Young, Best Band in the Universe feat Ninja Brian.
# 9784	+0	 40 skipped	10259 total	223 queued	NayutalieN, Alien Alien.
# 9783	+0	 57 skipped	10260 total	222 queued	Miles Davis, So What.
# 9782	+1	 48 skipped	10261 total	222 queued	The Streets, Blinded By The Lights.
# 9781	+0	 50 skipped	10262 total	221 queued	Ariel Pink, Lipstick.
# 9780	+0	 60 skipped	10263 total	220 queued	Lupe Fiasco, The Show Goes On.
# 9779	+1	 44 skipped	10264 total	220 queued	Hefner, The Day That Thatcher Dies.
# 9778	+0	  0 skipped	10265 total	219 queued	Fiction Family, When She's Near.
# 9777	+0	 43 skipped	10266 total	218 queued	Ghost, Cirice.
# 9776	+0	 42 skipped	10267 total	217 queued	Hieroglyphics, Make Your Move - 9th Wonder Remix.
# 9775	+0	 51 skipped	10268 total	216 queued	This Town Needs Guns, Triptych.
# 9774	+0	  0 skipped	10269 total	215 queued	Red Vox, Why Can't This Be Easy.
# 9773	+0	  0 skipped	10270 total	214 queued	Souls of Mischief, 93 'Til Infinity.
# 9772	+0	 53 skipped	10271 total	213 queued	Candy Claws, Into The Deep Time - One Sun.
# 9771	+0	 80 skipped	10272 total	212 queued	Jackson 5, I Wanna Be Where You Are.
# 9770	+2	 43 skipped	10273 total	213 queued	White Town, Your Woman.
# 9769	+0	 45 skipped	10274 total	212 queued	White Town, Once I Flew.
# 9768	+0	 80 skipped	10275 total	211 queued	Jackson 5, Rockin Robin.
# 9767	+0	 80 skipped	10276 total	210 queued	Jackson 5, I Want You Back.
# 9766	+0	 43 skipped	10277 total	209 queued	Dave Brubeck, Take Five.
# 9765	+0	  0 skipped	10278 total	208 queued	Yasunori Nishiki, H'aanit the Hunter - Octopath Traveler.
# 9764	+0	 61 skipped	10279 total	207 queued	Gnarls Barkley, Crazy.
# 9763	+1	 54 skipped	10280 total	207 queued	Leprous, From The Flame.
# 9762	+0	 50 skipped	10281 total	206 queued	Yasunori Nishiki, Beneath The Surface.
# 9761	+0	  0 skipped	10282 total	205 queued	Nataly Dawn, How I Knew Her.
# 9760	+0	  0 skipped	10283 total	204 queued	Pomplamoose, Don't Stop Lovin Me.
# 9759	+0	 55 skipped	10284 total	203 queued	Leprous, Rewind.
# 9758	+0	 50 skipped	10285 total	202 queued	Yasunori Nishiki, Oasis in the Sparkling Sands.
# 9757	+0	 55 skipped	10286 total	201 queued	Leprous, Painful Detour.
# 9756	+0	 55 skipped	10287 total	200 queued	Leprous, Collapse.
# 9755	+4	 87 skipped	10288 total	203 queued	Pomplamoose, Beat the Horse.
# 9754	+0	 50 skipped	10289 total	202 queued	Yasunori Nishiki, Flamesgrace Guiding Light - Octopath Traveler.
# 9753	+0	 91 skipped	10290 total	201 queued	Pomplamoose, I'm the ****.
# 9752	+0	109 skipped	10291 total	200 queued	ConcernedApe, The Stardrop Saloon.
# 9751	+0	 91 skipped	10292 total	199 queued	Pomplamoose, Hail Mary.
# 9750	+0	 89 skipped	10293 total	198 queued	Nataly Dawn, Coffee Baby.
# 9749	+0	 40 skipped	10294 total	197 queued	Kevin Penkin, Made in Abyss OST - Hanezeve Caradhina.
# 9748	+0	 50 skipped	10295 total	196 queued	Yasunori Nishiki, Daughter of the Dark God - Octopath Traveler.
# 9747	+0	 42 skipped	10296 total	195 queued	Plastic Tree, Mizuiro Girlfriend.
# 9746	+0	 91 skipped	10297 total	194 queued	Pomplamoose, River Shiver.
# 9745	+0	 41 skipped	10298 total	193 queued	Frankie Knuckles, The Whistle Song.
# 9744	+0	 45 skipped	10299 total	192 queued	JJAMZ, Heartbeat.
# 9743	+0	 91 skipped	10300 total	191 queued	Pomplamoose, Single Ladies (Put a Ring on It).
# 9742	+0	 42 skipped	10301 total	190 queued	Maxo, Honeybell.
# 9741	+0	 61 skipped	10302 total	189 queued	dj-Jo, Leaving Without.
# 9740	+0	  0 skipped	10303 total	188 queued	808 State, Pacific State - JUSTIN STRAUSS' 212 MIX.
# 9739	+0	 41 skipped	10304 total	187 queued	LilDeuceDeuce, Mine Turtle.
# 9738	+0	 91 skipped	10305 total	186 queued	Pomplamoose, Uptown Funk.
# 9737	+0	 42 skipped	10306 total	185 queued	Maxo, Sunset BB.
# 9736	+0	 42 skipped	10307 total	184 queued	Plastic Tree, Thirteenth Friday.
# 9735	+0	 41 skipped	10308 total	183 queued	Doss, Strawberry.
# 9734	+0	 91 skipped	10309 total	182 queued	Pomplamoose, Fight Back.
# 9733	+0	 42 skipped	10310 total	181 queued	Plastic Tree, Kuuchuu Buranko.
# 9732	+0	 55 skipped	10311 total	180 queued	Fusq, Perfume.
# 9731	+0	  0 skipped	10312 total	179 queued	Nataly Dawn, Please Don't Scream.
# 9730	+0	 50 skipped	10313 total	178 queued	Yasunori Nishiki, Decisive Battle II - Octopath Traveler.
# 9729	+0	 79 skipped	10314 total	177 queued	thenewno2, Interception.
# 9728	+0	 91 skipped	10315 total	176 queued	Pomplamoose, Believe.
# 9727	+0	109 skipped	10316 total	175 queued	ConcernedApe, In The Deep Woods.
# 9726	+0	 40 skipped	10317 total	174 queued	Fever the Ghost, SOURCE.
# 9725	+0	 67 skipped	10318 total	173 queued	Rob Cantor, Nobody Else Quite Like You.
# 9724	+0	  0 skipped	10319 total	172 queued	Da Vinci's Notebook, Enormous Penis.
# 9723	+1	 58 skipped	10320 total	172 queued	Julee Cruise, Floating.
# 9722	+0	  0 skipped	10321 total	171 queued	LilDeuceDeuce, Anderson Cooper's Secret.
# 9721	+0	 41 skipped	10322 total	170 queued	Four Year Strong, Go Down In History.
# 9720	+0	 91 skipped	10323 total	169 queued	Pomplamoose, Bust Your Knee Caps.
# 9719	+0	 91 skipped	10324 total	168 queued	Pomplamoose, Get That Body Back.
# 9718	+0	 91 skipped	10325 total	167 queued	Pomplamoose, Centrifuge.
# 9717	+0	 91 skipped	10326 total	166 queued	Pomplamoose, 30 Rock.
# 9716	+0	 89 skipped	10327 total	165 queued	Nataly Dawn, Counting Down.
# 9715	+0	 91 skipped	10328 total	164 queued	Pomplamoose, Expiration Date.
# 9714	+0	 41 skipped	10329 total	163 queued	Animals as Leaders, David.
# 9713	+0	 89 skipped	10330 total	162 queued	Nataly Dawn, Dying To Live.
# 9712	+0	 91 skipped	10331 total	161 queued	Pomplamoose, If You Think You Need Some Lovin.
# 9711	+0	 50 skipped	10332 total	160 queued	Yasunori Nishiki, Battle I - Octopath Traveler.
# 9710	+0	 50 skipped	10333 total	159 queued	Yasunori Nishiki, Tressa the Merchant - Octopath Traveler.
# 9709	+0	 41 skipped	10334 total	158 queued	Celia Cruz, La Vida Es Un Carnaval.
# 9708	+0	 50 skipped	10335 total	157 queued	Yasunori Nishiki, Olberic the Warrior - Octopath Traveler.
# 9707	+0	 48 skipped	10336 total	156 queued	Garoad, Karmotrine Dream.
# 9706	+2	101 skipped	10337 total	157 queued	She, Supersonic.
# 9705	+1	 47 skipped	10338 total	157 queued	ABSRDST, Skin Contest.
# 9704	+0	 42 skipped	10339 total	156 queued	Maxo, Grow Wings.
# 9703	+0	103 skipped	10340 total	155 queued	She, Make Me Real.
# 9702	+0	 91 skipped	10341 total	154 queued	Pomplamoose, Telephone.
# 9701	+0	 41 skipped	10342 total	153 queued	Animals As Leaders, Air Chrysalis.
# 9700	+0	 91 skipped	10343 total	152 queued	Pomplamoose, Le Commun des Mortels.
# 9699	+0	103 skipped	10344 total	151 queued	She, Break the Silence.
# 9698	+0	103 skipped	10345 total	150 queued	she, Axiom.
# 9697	+6	185 skipped	10346 total	155 queued	Skylar Spence, Fiona Coyne.
# 9696	+0	 91 skipped	10347 total	154 queued	Pomplamoose, Jungle Animal.
# 9695	+0	 50 skipped	10348 total	153 queued	Yasunori Nishiki, Battle II - Octopath Traveler.
# 9694	+0	 91 skipped	10349 total	152 queued	Pomplamoose, Red Hot Chili Smashup.
# 9693	+0	 59 skipped	10350 total	151 queued	Julee Cruise, Into The Night.
# 9692	+0	 53 skipped	10351 total	150 queued	Jeremy Blake, Heaven And Hell.
# 9691	+0	 50 skipped	10352 total	149 queued	Yasunori Nishiki, Battle III - Octopath Traveler.
# 9690	+0	 91 skipped	10353 total	148 queued	Pomplamoose, Twice as Nice.
# 9689	+19	115 skipped	10354 total	166 queued	bo en, Spintered Sweets In The Castle.
# 9688	+0	134 skipped	10355 total	165 queued	bo en, Friend.
# 9687	+1	 40 skipped	10356 total	165 queued	Detektivbyran, Nattoppet.
# 9686	+3	 49 skipped	10357 total	167 queued	Michel Legrand, Chanson Des Jumelles.
# 9685	+0	 91 skipped	10358 total	166 queued	Pomplamoose, Pay Attention.
# 9684	+0	 91 skipped	10359 total	165 queued	Pomplamoose, Walking on Sunshine.
# 9683	+0	 89 skipped	10360 total	164 queued	Nataly Dawn, We Still Got Us.
# 9682	+0	 91 skipped	10361 total	163 queued	Pomplamoose, Prioritise-moi.
# 9681	+0	 91 skipped	10362 total	162 queued	Pomplamoose, Little Things.
# 9680	+2	 42 skipped	10363 total	163 queued	Stateless, Bloodstream.
# 9679	+0	 91 skipped	10364 total	162 queued	Pomplamoose, Morning Waterbug.
# 9678	+0	 41 skipped	10365 total	161 queued	Epic Mountain, Alien Scale.
# 9677	+1	 46 skipped	10366 total	161 queued	Trio, Da Da Da.
# 9676	+0	 41 skipped	10367 total	160 queued	Epic Mountain, What happened before history.
# 9675	+0	134 skipped	10368 total	159 queued	bo en, My Time.
# 9674	+0	 91 skipped	10369 total	158 queued	Pomplamoose, Wake Me Up Before You Go-Go.
# 9673	+0	 48 skipped	10370 total	157 queued	Garoad, HOPES AND DREAMS - VA-11 HALL-A.
# 9672	+0	 67 skipped	10371 total	156 queued	Rob Cantor, Perfect.
# 9671	+0	 67 skipped	10372 total	155 queued	Rob Cantor, Old Bike.
# 9670	+0	 46 skipped	10373 total	154 queued	Explosions In The Sky, Your Hand In Mine.
# 9669	+0	 67 skipped	10374 total	153 queued	Rob Cantor, Shia LaBeouf.
# 9668	+0	 49 skipped	10375 total	152 queued	Yves Tumor, Romanticist.
# 9667	+0	 41 skipped	10376 total	151 queued	idk, This Is For Music Class Lol 2.
# 9666	+0	  0 skipped	10377 total	150 queued	Die Antwoord, Baby's On Fire.
# 9665	+0	 43 skipped	10378 total	149 queued	God is an Astronaut, No Return.
# 9664	+0	 42 skipped	10379 total	148 queued	Lomelda, Hannah Sun.
# 9663	+0	 49 skipped	10380 total	147 queued	SWMRS, April In Houston.
# 9662	+0	  0 skipped	10381 total	146 queued	65Daysofstatic, Debutante - No Man's Sky Trailer.
# 9661	+2	 44 skipped	10382 total	147 queued	IDLES, Danny Nedelko.
# 9660	+0	 50 skipped	10383 total	146 queued	Mike Krol, Like a Star.
# 9659	+0	 59 skipped	10384 total	145 queued	Injury Reserve, Superman That.
# 9658	+0	 46 skipped	10385 total	144 queued	IDLES, Model Village.
# 9657	+0	 49 skipped	10386 total	143 queued	Yves Tumor, Kerosene.
# 9656	+0	 49 skipped	10387 total	142 queued	Yves Tumor, Licking an Orchid.
# 9655	+0	 54 skipped	10388 total	141 queued	Chloe Moriondo, Ghost Adventure Spirit Orb.
# 9654	+0	 40 skipped	10389 total	140 queued	Jockstrap, Acid.
# 9653	+0	 40 skipped	10390 total	139 queued	SIAMES, Mr Fear.
# 9652	+0	 48 skipped	10391 total	138 queued	Thomas Bergersen, Dragonland.
# 9651	+0	  0 skipped	10392 total	137 queued	Snail's House, Snailchan Adventure.
# 9650	+0	 44 skipped	10393 total	136 queued	The Wonders, That Thing You Do.
# 9649	+1	 51 skipped	10394 total	136 queued	Julieta Venegas, A Donde Sea.
# 9648	+0	 49 skipped	10395 total	135 queued	SWMRS, Palm Trees.
# 9647	+0	 52 skipped	10396 total	134 queued	Julieta Venegas, Bien o Mal.
# 9646	+0	  0 skipped	10397 total	133 queued	Snail's House, Hot Milk.
# 9645	+3	 52 skipped	10398 total	135 queued	Wu-Tang Clan, CREAM.
# 9644	+0	 40 skipped	10399 total	134 queued	Sons of Kemet, My Queen is Anna Julia Cooper.
# 9643	+0	  0 skipped	10400 total	133 queued	Jake Kaufman, Shantae Risky's Revenge - File Select.
# 9642	+0	  0 skipped	10401 total	132 queued	Snail's House, ra-mu-ne.
# 9641	+1	 92 skipped	10402 total	132 queued	Gareth Coker, ARK Survival Evolved - Main Theme.
# 9640	+0	 41 skipped	10403 total	131 queued	Really Slow Motion, Endlessness.
# 9639	+0	  0 skipped	10404 total	130 queued	Snail's House, Lullaby.
# 9638	+0	 49 skipped	10405 total	129 queued	Sheck Wes, Mo Bamba.
# 9637	+0	 41 skipped	10406 total	128 queued	idk, This Is For Music Class Lol.
# 9636	+0	  0 skipped	10407 total	127 queued	65Daysofstatic, Escape Velocity - No Man's Sky.
# 9635	+0	 50 skipped	10408 total	126 queued	Jake Kaufman, Shovel Knight - In the Halls of the Usurper.
# 9634	+0	 42 skipped	10409 total	125 queued	Gesu no Kiwami Otome, Watashi Igai Watashi ja Nai no.
# 9633	+0	 50 skipped	10410 total	124 queued	Jake Kaufman, Loli Fishing Next 20000 Leagues.
# 9632	+0	 42 skipped	10411 total	123 queued	Mike Morasky, I Am Not A Moron.
# 9631	+0	 50 skipped	10412 total	122 queued	Jake Kaufman, Shovel Knight - Main Theme.
# 9630	+0	 42 skipped	10413 total	121 queued	Mike Morasky, Turret Wife Serenade.
# 9629	+0	 52 skipped	10414 total	120 queued	Julieta Venegas, Dulce Compania.
# 9628	+0	 42 skipped	10415 total	119 queued	Mike Morasky, Bombs For Throwing At You.
# 9627	+0	  0 skipped	10416 total	118 queued	Underscores, Everybody's Dead.
# 9626	+0	 52 skipped	10417 total	117 queued	Julieta Venegas, No Sere.
# 9625	+0	 46 skipped	10418 total	116 queued	cupcakKe, Deepthroat.
# 9624	+0	 52 skipped	10419 total	115 queued	Julieta Venegas, Primer Dia.
# 9623	+0	 41 skipped	10420 total	114 queued	Zoe, Deja te Conecto.
# 9622	+0	 50 skipped	10421 total	113 queued	Jake Kaufman, Shovel Knight - La Danse Macabre.
# 9621	+0	 52 skipped	10422 total	112 queued	Julieta Venegas, Me Voy.
# 9620	+0	 50 skipped	10423 total	111 queued	Jake Kaufman, Shovel Knight - Of Devious Machinations.
# 9619	+0	 52 skipped	10424 total	110 queued	Julieta Venegas, Limon Y Sal.
# 9618	+0	  0 skipped	10425 total	109 queued	Snail's House, Pixel Galaxy.
# 9617	+6	 64 skipped	10426 total	114 queued	Kozilek, The Nuclear Throne.
# 9616	+0	 40 skipped	10427 total	113 queued	Puppet, Answers.
# 9615	+3	 42 skipped	10428 total	115 queued	Waterflame, Glorious Morning.
# 9614	+0	 50 skipped	10429 total	114 queued	Jake Kaufman, FX 4 - Incident Zero.
# 9613	+0	 40 skipped	10430 total	113 queued	Valve, DJ Sandman - Dota 2 Reborn DNB Mix.
# 9612	+0	 50 skipped	10431 total	112 queued	Jake Kaufman, Strike The Earth.
# 9611	+0	 40 skipped	10432 total	111 queued	Howard Drossin, Feed My Disease - Comix Zone.
# 9610	+0	 50 skipped	10433 total	110 queued	Jake Kaufman, Shovel Knight - An Underlying Problem.
# 9609	+0	 50 skipped	10434 total	109 queued	Jake Kaufman, BloodRayne Betrayal - Betrayal.
# 9608	+0	 52 skipped	10435 total	108 queued	Julieta Venegas, Eres Para Mi.
# 9607	+0	 50 skipped	10436 total	107 queued	Jake Kaufman, Singularity.
# 9606	+0	 40 skipped	10437 total	106 queued	Ken Hirai, Ring.
# 9605	+0	 42 skipped	10438 total	105 queued	Gesu no Kiwami Otome, Otonatic.
# 9604	+0	 42 skipped	10439 total	104 queued	Gesu no Kiwami Otome, Ryoseibai.
# 9603	+0	 50 skipped	10440 total	103 queued	Jake Kaufman, Shovel Knight - The Defender.
# 9602	+0	 50 skipped	10441 total	102 queued	Jake Kaufman, Mighty Switch Force - Level Select.
# 9601	+0	 40 skipped	10442 total	101 queued	vistlip, -OZONE-.
# 9600	+2	 59 skipped	10443 total	102 queued	StaySolidRocky, Party Girl.
# 9599	+0	 50 skipped	10444 total	101 queued	Jake Kaufman, FX 2 - Option.
# 9598	+0	 44 skipped	10445 total	100 queued	Gym Class Heroes, Ass Back Home.
# 9597	+0	 50 skipped	10446 total	 99 queued	Jake Kaufman, Shovel Knight - The Fateful Return.
# 9596	+0	 45 skipped	10447 total	 98 queued	Waterflame, Hexagon Force - from Geometry Dash.
# 9595	+0	 46 skipped	10448 total	 97 queued	Meaghan Smith, It Snowed.
# 9594	+0	 40 skipped	10449 total	 96 queued	Remioromen, Sangatsu kokonoka.
# 9593	+0	108 skipped	10450 total	 95 queued	Sungazer, Bird on the Wing.
# 9592	+2	 97 skipped	10451 total	 96 queued	Reks, Stages.
# 9591	+0	 40 skipped	10452 total	 95 queued	Former Hero, Eyelids (Acloudyskye Remix).
# 9590	+0	108 skipped	10453 total	 94 queued	Sungazer, Drunk.
# 9589	+0	 56 skipped	10454 total	 93 queued	The Bamboos, The Wilhelm Scream.
# 9588	+0	 52 skipped	10455 total	 92 queued	Julieta Venegas, Lento.
# 9587	+0	 50 skipped	10456 total	 91 queued	Mike Krol, Fifteen Minutes.
# 9586	+0	 52 skipped	10457 total	 90 queued	Julieta Venegas, Alguien.
# 9585	+0	 41 skipped	10458 total	 89 queued	Zoe, No me Destruyas.
# 9584	+0	 48 skipped	10459 total	 88 queued	Thomas Bergersen, Immortal.
# 9583	+0	  0 skipped	10460 total	 87 queued	Snail's House, SUPERGIRL.
# 9582	+0	 50 skipped	10461 total	 86 queued	Jake Kaufman, Mighty Switch Force 2 - Final Level.
# 9581	+0	 48 skipped	10462 total	 85 queued	The Partridge Family, I Think I Love You.
# 9580	+0	 52 skipped	10463 total	 84 queued	Julieta Venegas, Algo Esta Cambiando.
# 9579	+0	  0 skipped	10464 total	 83 queued	Jake Kaufman, Mighty Switch Force - Whoa I'm In Space Cuba.
# 9578	+0	 50 skipped	10465 total	 82 queued	Jake Kaufman, Moon Theme - Remastered Version.
# 9577	+0	 52 skipped	10466 total	 81 queued	Julieta Venegas, Canciones de Amor.
# 9576	+0	  0 skipped	10467 total	 80 queued	Waterflame, Blast Processing.
# 9575	+0	 52 skipped	10468 total	 79 queued	Julieta Venegas, Andar Conmigo.
# 9574	+0	 42 skipped	10469 total	 78 queued	Brad Mehldau, When It Rains.
# 9573	+1	 48 skipped	10470 total	 78 queued	Yellow Magic Orchestra, Behind the Mask.
# 9572	+0	 42 skipped	10471 total	 77 queued	Brad Mehldau, The Garden.
# 9571	+0	 46 skipped	10472 total	 76 queued	Telex, Euro-Vision.
# 9570	+0	 46 skipped	10473 total	 75 queued	Telex, Moskow Diskow.
# 9569	+0	  0 skipped	10474 total	 74 queued	Girls' Generation, Oh.
# 9568	+0	 49 skipped	10475 total	 73 queued	Yellow Magic Orchestra, Rydeen.
# 9567	+0	  0 skipped	10476 total	 72 queued	Yellow Magic Orchestra, Cosmic Surfin'.
# 9566	+0	  0 skipped	10477 total	 71 queued	Leon Ware, Rockin' You Eternally.
# 9565	+0	  0 skipped	10478 total	 70 queued	Hocus Pocus, Mr Tout Le Monde.
# 9564	+0	  0 skipped	10479 total	 69 queued	Girls' Generation, Paparazzi.
# 9563	+0	  0 skipped	10480 total	 68 queued	Girls' Generation, I Got a Boy.
# 9562	+0	 41 skipped	10481 total	 67 queued	YUKI, Dramatic.
# 9561	+0	  0 skipped	10482 total	 66 queued	Girls' Generation, Run Devil Run.
# 9560	+0	  0 skipped	10483 total	 65 queued	Girls' Generation, Lion Heart.
# 9559	+0	 41 skipped	10484 total	 64 queued	Emilie Autumn, What If.
# 9558	+0	  0 skipped	10485 total	 63 queued	Girls' Generation, Into The New World.
# 9557	+0	 44 skipped	10486 total	 62 queued	Phillip Phillips, Home.
# 9556	+0	  0 skipped	10487 total	 61 queued	EXO, Call Me Baby.
# 9555	+0	 46 skipped	10488 total	 60 queued	Lights, Quiet.
# 9554	+2	 41 skipped	10489 total	 61 queued	Tokyo Machine, BUBBLES.
# 9553	+0	 49 skipped	10490 total	 60 queued	Yellow Magic Orchestra, Tong Poo.
# 9552	+0	 49 skipped	10491 total	 59 queued	Yellow Magic Orchestra, Technopolis.
# 9551	+0	 50 skipped	10492 total	 58 queued	Grey, Wings Clipped.
# 9550	+0	 47 skipped	10493 total	 57 queued	Mild High Club, Homage.
# 9549	+0	 50 skipped	10494 total	 56 queued	Ichiko Aoba, Kokoro No Sekai.
# 9548	+0	 62 skipped	10495 total	 55 queued	Vulfpeck, 1612.
# 9547	+1	 45 skipped	10496 total	 55 queued	Christie, Yellow River.
# 9546	+0	  0 skipped	10497 total	 54 queued	Girls' Generation, Genie.
# 9545	+0	 62 skipped	10498 total	 53 queued	Vulfpeck, Smile Meditation.
# 9544	+1	114 skipped	10499 total	 53 queued	The Muppets, Mah Na Mah Na.
# 9543	+0	  0 skipped	10500 total	 52 queued	PinocchioP, Because You're Here.
# 9542	+0	 62 skipped	10501 total	 51 queued	Vulfpeck, Darwin Derby.
# 9541	+0	 43 skipped	10502 total	 50 queued	MORTEN, Look Closer.
# 9540	+0	115 skipped	10503 total	 49 queued	The Muppets, Rainbow Connection.
# 9539	+0	 50 skipped	10504 total	 48 queued	Ichiko Aoba, Terifuriame.
# 9538	+0	 41 skipped	10505 total	 47 queued	HOME, Resonance.
# 9537	+2	 49 skipped	10506 total	 48 queued	Dan Croll, Work.
# 9536	+0	 62 skipped	10507 total	 47 queued	Vulfpeck, My First Car.
# 9535	+0	 43 skipped	10508 total	 46 queued	Tokyo Machine, SPOOKY.
# 9534	+0	 85 skipped	10509 total	 45 queued	Future Islands, Seasons (Waiting On You).
# 9533	+0	 62 skipped	10510 total	 44 queued	Vulfpeck, Grandma.
# 9532	+0	 40 skipped	10511 total	 43 queued	Clarian, Castaway - Henry Saiz Remix.
# 9531	+0	 55 skipped	10512 total	 42 queued	Flying Lotus, Massage Situation.
# 9530	+0	 50 skipped	10513 total	 41 queued	Ichiko Aoba, Yusagi.
# 9529	+1	 42 skipped	10514 total	 41 queued	Bougenvilla, Homeless.
# 9528	+0	 40 skipped	10515 total	 40 queued	Darren Criss, Granger Danger.
# 9527	+0	 53 skipped	10516 total	 39 queued	Zendaya, Replay.
# 9526	+0	 42 skipped	10517 total	 38 queued	PinocchioP, Motivation Is Dead.
# 9525	+0	 55 skipped	10518 total	 37 queued	Flying Lotus, Never Catch Me (feat Kendrick Lamar).
# 9524	+0	 44 skipped	10519 total	 36 queued	Morten Hampenberg, Kiss Me.
# 9523	+0	 40 skipped	10520 total	 35 queued	Jeff Lorber, Watching the Sun Set.
# 9522	+0	 80 skipped	10521 total	 34 queued	Women, Heat Distraction.
# 9521	+0	 62 skipped	10522 total	 33 queued	VULFPECK, Animal Spirits.
# 9520	+0	 62 skipped	10523 total	 32 queued	Vulfpeck, Wait For The Moment.
# 9519	+0	 42 skipped	10524 total	 31 queued	The United States of America, The American Metaphysical Circus.
# 9518	+1	 44 skipped	10525 total	 31 queued	EXO, Love Me Right.
# 9517	+0	 41 skipped	10526 total	 30 queued	Method Man and Redman, Dis Iz 4 All My Smokers.
# 9516	+0	  0 skipped	10527 total	 29 queued	Girls' Generation, Gee.
# 9515	+0	 62 skipped	10528 total	 28 queued	Vulfpeck, Outro.
# 9514	+0	 43 skipped	10529 total	 27 queued	MORTEN, Beautiful Heartbeat - Avicii Remix.
# 9513	+0	 42 skipped	10530 total	 26 queued	Nell, Good Night.
# 9512	+0	 41 skipped	10531 total	 25 queued	deadmau5 and Kaskade, I Remember.
# 9511	+0	 62 skipped	10532 total	 24 queued	Vulfpeck, Game Winner.
# 9510	+0	 64 skipped	10533 total	 23 queued	Kaoma, Lambada.
# 9509	+0	 50 skipped	10534 total	 22 queued	Ichiko Aoba, Kikaijikake No Ucyuu.
# 9508	+0	 40 skipped	10535 total	 21 queued	Mort Garson, Plantasia.
# 9507	+0	 42 skipped	10536 total	 20 queued	PinocchioP, Nice To Meet You Mr Earthling.
# 9506	+0	 42 skipped	10537 total	 19 queued	Mili, world-execute-me.
# 9505	+0	 50 skipped	10538 total	 18 queued	Ichiko Aoba, Easter Lily.
# 9504	+0	 50 skipped	10539 total	 17 queued	Ichiko Aoba, Haru Natsu Aki Fuyu.
# 9503	+0	 42 skipped	10540 total	 16 queued	Mili, Rightfully.
# 9502	+0	 50 skipped	10541 total	 15 queued	Ichiko Aoba, Minashigo No Ame.
# 9501	+1	 82 skipped	10542 total	 15 queued	Crywolf, Stomach It - ft EDEN.
# 9500	+0	 50 skipped	10543 total	 14 queued	Ichiko Aoba, Porcelain.
# 9499	+0	 50 skipped	10544 total	 13 queued	Ichiko Aoba, Dawn in the Adan.
# 9498	+0	 50 skipped	10545 total	 12 queued	Ichiko Aoba, Uta no Kehai.
# 9497	+0	 69 skipped	10546 total	 11 queued	Scott Joplin, Gladiolus Rag.
# 9496	+0	 50 skipped	10547 total	 10 queued	Ichiko Aoba, Hitsuji no Anthony.
# 9495	+0	 50 skipped	10548 total	  9 queued	Ichiko Aoba, Tsuki no Oka.
# 9494	+0	 50 skipped	10549 total	  8 queued	Ichiko Aoba, Ikinokori Bokura.
# 9493	+0	 83 skipped	10550 total	  7 queued	Crywolf, Weight.
# 9492	+0	  0 skipped	10551 total	  6 queued	Carissa's Wierd, So You Wanna Be A Superhero.
# 9491	+0	349 skipped	10552 total	  5 queued	sodagreen, Wu yu lun bi de mei li.
# 9490	+0	 42 skipped	10553 total	  4 queued	Mili, Salt Pepper Birds and the Thought Police.
# 9489	+0	 50 skipped	10554 total	  3 queued	Ichiko Aoba, Parfum de Etoiles.
# 9488	+0	  0 skipped	10555 total	  2 queued	Home, We're Finally Landing.
# 9487	+0	 50 skipped	10556 total	  1 queued	Ichiko Aoba, iam POD 0.
# 9486	+0	 69 skipped	10557 total	  0 queued	Scott Joplin, Magnetic Rag.
# 9485	+0	 69 skipped	10558 total	  0 queued	Scott Joplin, Elite Syncopations.
# 9484	+0	 69 skipped	10559 total	  0 queued	Scott Joplin, A Breeze From Alabama.
# 9483	+0	 69 skipped	10560 total	  0 queued	Scott Joplin, Bethena.
# 9482	+0	 69 skipped	10561 total	  0 queued	Scott Joplin, Pineapple Rag.
# 9481	+0	 69 skipped	10562 total	  0 queued	Scott Joplin, Peacherine Rag.
# 9480	+0	 69 skipped	10563 total	  0 queued	Scott Joplin, Something Doing.
# 9479	+0	 69 skipped	10564 total	  0 queued	Scott Joplin, Paragon Rag.
# 9478	+0	 69 skipped	10565 total	  0 queued	Scott Joplin, Maple Leaf Rag.
# 9477	+0	 69 skipped	10566 total	  0 queued	Scott Joplin, Fig Leaf Rag.
# 9476	+0	 69 skipped	10567 total	  0 queued	Scott Joplin, Searchlight Rag.
# 9475	+0	103 skipped	10568 total	  0 queued	She, Computer Music.
# 9474	+0	 49 skipped	10569 total	  0 queued	Fort Minor, Kenji.
# 9473	+0	  0 skipped	10570 total	  0 queued	Scott Joplin, Treemonisha - Act 1 no 4 - We're Goin Around.
# 9472	+0	 47 skipped	10571 total	  0 queued	Lake Street Dive, Bad Self Portraits.
# 9471	+0	 52 skipped	10572 total	  0 queued	Caesars, Jerk It Out.
# 9470	+0	 69 skipped	10573 total	  0 queued	Scott Joplin, The Entertainer.
# 9469	+0	 49 skipped	10574 total	  0 queued	Fort Minor, Remember The Name.
# 9468	+0	 47 skipped	10575 total	  0 queued	Lake Street Dive, Sarah.
# 9467	+0	 86 skipped	10576 total	  0 queued	Life Without Buildings, The Leanover.
# 9466	+0	 69 skipped	10577 total	  0 queued	Scott Joplin, Weeping Willow.
# 9465	+0	 49 skipped	10578 total	  0 queued	Fort Minor, Welcome.
# 9464	+0	 69 skipped	10579 total	  0 queued	Scott Joplin, The Cascades.
# 9463	+1	 44 skipped	10580 total	  1 queued	Wyclef Jean, Divine Sorrow.
# 9462	+0	 69 skipped	10581 total	  0 queued	Scott Joplin, The Ragtime Dance.
# 9461	+0	 46 skipped	10582 total	  0 queued	Tom Cochrane, Life is a Highway.
# 9460	+0	 69 skipped	10583 total	  0 queued	Scott Joplin, The Easy Winners.
# 9459	+0	  0 skipped	10584 total	  0 queued	Fort Minor, Where'd You Go.
# 9458	+0	 47 skipped	10585 total	  0 queued	We Were Evergreen, Best Thing.
# 9457	+0	142 skipped	10586 total	  0 queued	Gorillaz, Slow Country.
# 9456	+0	 42 skipped	10587 total	  0 queued	Kasbo, Kaleidoscope.
# 9455	+0	 47 skipped	10588 total	  0 queued	Lake Street Dive, Rabid Animal.
# 9454	+1	 49 skipped	10589 total	  1 queued	Dover, King George.
# 9453	+0	 46 skipped	10590 total	  0 queued	Bonobo, Kong.
# 9452	+0	 46 skipped	10591 total	  0 queued	2pac, Changes.
# 9451	+0	142 skipped	10592 total	  0 queued	Gorillaz, 19-2000 - Soulchild Remix.
# 9450	+0	  0 skipped	10593 total	  0 queued	Confidence Man, Does It Make You Feel Good.
# 9449	+0	  0 skipped	10594 total	  0 queued	Miss Li, I Can't Get You Off My Mind.
# 9448	+0	 46 skipped	10595 total	  0 queued	Bonobo, Flutter.
# 9447	+0	 69 skipped	10596 total	  0 queued	Scott Joplin, Sunflower Slow Drag.
# 9446	+0	142 skipped	10597 total	  0 queued	Gorillaz, Feel Good Inc.
# 9445	+0	142 skipped	10598 total	  0 queued	Gorillaz, Tomorrow Comes Today.
# 9444	+0	 46 skipped	10599 total	  0 queued	Bonobo, Nothing Owed.
# 9443	+0	 41 skipped	10600 total	  0 queued	Jaron, before i fall.
# 9442	+0	142 skipped	10601 total	  0 queued	Gorillaz, El Manana.
# 9441	+0	 40 skipped	10602 total	  0 queued	Fearofdark, Gastly.
# 9440	+0	 40 skipped	10603 total	  0 queued	Klaus Doldinger, Petit Pierre Au Pays Des Reves.
# 9439	+0	 52 skipped	10604 total	  0 queued	The Kid Laroi, Go.
# 9438	+0	 46 skipped	10605 total	  0 queued	2Pac, 2 of Amerikaz Most Wanted.
# 9437	+0	 44 skipped	10606 total	  0 queued	Native Construct, Chromatic Aberration.
# 9436	+0	 52 skipped	10607 total	  0 queued	The Kid LAROI, Without You.
# 9435	+0	 47 skipped	10608 total	  0 queued	Lake Street Dive, Stop Your Crying.
# 9434	+0	 89 skipped	10609 total	  0 queued	Dax Johnson, A Moment In The Life Of Me.
# 9433	+0	 69 skipped	10610 total	  0 queued	Scott Joplin, Treemonisha - Act 3 no 27 - A Real Slow Drag.
# 9432	+0	 46 skipped	10611 total	  0 queued	Bonobo, Noctuary.
# 9431	+0	 43 skipped	10612 total	  0 queued	Ashes Remain, Right Here.
# 9430	+0	 69 skipped	10613 total	  0 queued	Scott Joplin, Treemonisha - Aunt Dinah Has Blowed The Horn.
# 9429	+0	 40 skipped	10614 total	  0 queued	Danny Howard, Apex.
# 9428	+18	 60 skipped	10615 total	 18 queued	Chris Christodoulou, Coalescence.
# 9427	+0	 46 skipped	10616 total	 17 queued	Bonobo, All In Forms.
# 9426	+0	  0 skipped	10617 total	 16 queued	2Pac, I Ain't Mad At Cha.
# 9425	+0	142 skipped	10618 total	 15 queued	Gorillaz, The Apprentice.
# 9424	+0	 42 skipped	10619 total	 14 queued	Marcus Warner, Liberation.
# 9423	+0	142 skipped	10620 total	  0 queued	Gorillaz, Empire Ants.
# 9422	+0	142 skipped	10621 total	  0 queued	Gorillaz, Souk Eye.
# 9421	+0	 41 skipped	10622 total	  0 queued	JJ Project, Bounce.
# 9420	+0	239 skipped	10623 total	  0 queued	Christopher Tin, Baba Yetu.
# 9419	+0	239 skipped	10624 total	  0 queued	Christopher Tin, Sogno Di Volare.
# 9418	+0	142 skipped	10625 total	  0 queued	Gorillaz, PAC-MAN (feat ScHoolboy Q).
# 9417	+0	101 skipped	10626 total	  0 queued	Akiko Yano, Water Ways Flow Backward Again.
# 9416	+0	 41 skipped	10627 total	  0 queued	Jaron, escape.
# 9415	+0	 41 skipped	10628 total	  0 queued	Necro, Nirvana.
# 9414	+2	 46 skipped	10629 total	  2 queued	Carpenter Brut, Paradise Warfare.
# 9413	+0	 48 skipped	10630 total	  1 queued	Carpenter Brut, Inferno Galore.
# 9412	+0	 44 skipped	10631 total	  0 queued	Pinegrove, Angelina.
# 9411	+0	142 skipped	10632 total	  0 queued	Gorillaz, Clint Eastwood.
# 9410	+0	142 skipped	10633 total	  0 queued	Gorillaz, Broken.
# 9409	+0	142 skipped	10634 total	  0 queued	Gorillaz, Aries (feat Peter Hook and Georgia).
# 9408	+1	 46 skipped	10635 total	  1 queued	Dschinghis Khan, Moskau.
# 9407	+0	  0 skipped	10636 total	  0 queued	Gorillaz, She's My Collar feat Kali Uchis.
# 9406	+0	 42 skipped	10637 total	  0 queued	Aleks Syntek, Te Sone.
# 9405	+0	 41 skipped	10638 total	  0 queued	Necro, I Have A Dream.
# 9404	+0	 47 skipped	10639 total	  0 queued	We Were Evergreen, Baby Blue.
# 9403	+0	106 skipped	10640 total	  0 queued	Paul Mauriat, Love is Blue.
# 9402	+0	239 skipped	10641 total	  0 queued	Christopher Tin, Mado Kara Mieru.
# 9401	+0	 48 skipped	10642 total	  0 queued	Carpenter Brut, Roller Mobster.
# 9400	+0	142 skipped	10643 total	  0 queued	Gorillaz, Rhinestone Eyes.
# 9399	+0	142 skipped	10644 total	  0 queued	Gorillaz, Rock The House.
# 9398	+0	 48 skipped	10645 total	  0 queued	Carpenter Brut, Turbo Killer.
# 9397	+0	 89 skipped	10646 total	  0 queued	Dax Johnson, The Random And The Purpose.
# 9396	+0	142 skipped	10647 total	  0 queued	Gorillaz, Melancholy Hill.
# 9395	+0	 47 skipped	10648 total	  0 queued	Los Lobos, Cancion Del Mariachi.
# 9394	+0	142 skipped	10649 total	  0 queued	Gorillaz, Saturnz Barz.
# 9393	+0	 48 skipped	10650 total	  0 queued	Carpenter Brut, Le Perv.
# 9392	+0	106 skipped	10651 total	  0 queued	Paul Mauriat, Minuetto.
# 9391	+0	 46 skipped	10652 total	  0 queued	Bonobo, El Toro.
# 9390	+0	142 skipped	10653 total	  0 queued	Gorillaz, DoYaThing.
# 9389	+0	142 skipped	10654 total	  0 queued	Gorillaz, DARE.
# 9388	+0	 40 skipped	10655 total	  0 queued	Daniel Boone, Beautiful Sunday.
# 9387	+0	113 skipped	10656 total	  0 queued	Limahl, Never Ending Story.
# 9386	+0	  0 skipped	10657 total	  0 queued	Shogo Sakai, Gentle Rain.
# 9385	+0	 54 skipped	10658 total	  0 queued	Bobby Caldwell, My Flame.
# 9384	+1	 55 skipped	10659 total	  1 queued	bignic, Domina - Mire.
# 9383	+0	 56 skipped	10660 total	  0 queued	bignic, Domina - Boom.
# 9382	+0	 58 skipped	10661 total	  0 queued	FloRida, Right Round feat Kesha.
# 9381	+0	  0 skipped	10662 total	  0 queued	Shogo Sakai, Mind Of A Thief.
# 9380	+0	  0 skipped	10663 total	  0 queued	Shogo Sakai, Master Porky's Theme - Mother 3.
# 9379	+0	 46 skipped	10664 total	  0 queued	Mitch Murder, Megamagic Theme.
# 9378	+2	 45 skipped	10665 total	  2 queued	Fancy, Flames Of Love.
# 9377	+0	 46 skipped	10666 total	  1 queued	Mitch Murder, Communication Device.
# 9376	+0	 50 skipped	10667 total	  0 queued	Shogo Sakai, LOG-O-TYPE.
# 9375	+0	 50 skipped	10668 total	  0 queued	Shogo Sakai, Stormy Area.
# 9374	+0	 50 skipped	10669 total	  0 queued	Shogo Sakai, Tragic Reconstruction.
# 9373	+0	 50 skipped	10670 total	  0 queued	Shogo Sakai, Letter From You My Sweet.
# 9372	+0	 50 skipped	10671 total	  0 queued	Shogo Sakai, Kirby and the Rainbow Curse - Rest Area.
# 9371	+0	 50 skipped	10672 total	  0 queued	Shogo Sakai, Natural Killer Cyborg.
# 9370	+0	 50 skipped	10673 total	  0 queued	Shogo Sakai, Long Shadow.
# 9369	+0	 50 skipped	10674 total	  0 queued	Shogo Sakai, Unfounded Revenge.
# 9368	+0	 50 skipped	10675 total	  0 queued	Shogo Sakai, MOTHER 3 Going Alone.
# 9367	+0	 50 skipped	10676 total	  0 queued	Shogo Sakai, Hard Rain.
# 9366	+0	 50 skipped	10677 total	  0 queued	Shogo Sakai, Fun Naming.
# 9365	+0	 50 skipped	10678 total	  0 queued	Shogo Sakai, Fate.
# 9364	+1	 56 skipped	10679 total	  1 queued	Desireless, Voyage Voyage.
# 9363	+0	 40 skipped	10680 total	  0 queued	Simon Viklund, Breach 2015.
# 9362	+0	 40 skipped	10681 total	  0 queued	Savage, Only You.
# 9361	+0	 50 skipped	10682 total	  0 queued	Shogo Sakai, Strong One (Masked Man).
# 9360	+0	 47 skipped	10683 total	  0 queued	Black, Wonderful Life.
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-17-84b4892af2bf> in async-def-wrapper()
#      47 # finally:
#      48 #     duration = time.time() - start_time
# ---> 49 #     print(f"Done in {duration:.2f} s.")
#
# CancelledError:

# %%
from operator import itemgetter 

df = pd.DataFrame([e for e in results.values() if e])
df = df.drop(["SInD", "id", "ytid"], axis=1)

def map_chords_rel(chords_str):
    result = [e for e in chords_str.replace("slash", "/").replace("w", "v").replace("j", "i").split("qq") if e]
    result = [e.strip() for e in result]
    return result

def map_chords_abs(chords_str):
    result = [e for e in chords_str.replace("slash", "/").split("qq") if e]
    result = [e.strip() for e in result]
    return result

df.chordAbs = df.chordAbs.apply(map_chords_abs)
df.chordRel = df.chordRel.apply(map_chords_rel)
df.key = df.key.str.split()
df["keyTonic"] = df.key.apply(itemgetter(0))
df["keyScale"] = df.key.apply(itemgetter(1))
df = df.drop("key", axis=1)
df = df.set_index(["artist", "song"]).sort_index()
df = df[~df.index.duplicated(keep="first")]
df = df.reset_index()
df
# Out:
#                   artist                      song  \
# 0           'Til Tuesday              Voices Carry
# 1              070 Shake         Guilty Conscience
# 2               100 gecs  Hand Crushed By A Mallet
# 3               100 gecs             Money Machine
# 4                   10cc           I'm Not In Love
# ...                  ...                       ...
# 10484  twenty one pilots                  My Blood
# 10485  twenty one pilots       Nico And The Niners
# 10486  twenty one pilots               Pet Cheetah
# 10487            vistlip                   -OZONE-
# 10488               zedd                  Spectrum
#
#                                                 chordAbs  \
# 0      [G, G/D, G, G/D, G, G/D, G, Bb, Bb/F, Bb, Bb/F...
# 1                               [G, Em7, Cmaj9, Am11, D]
# 2                   [C#m, F#m, A, G#m, C#m, F#m, A, G#m]
# 3      [D#m, B, F#, A#m, D#m, B, F#, A#m, D#m, B, F#,...
# 4      [A, Am, G#m, G#/B#, C#m, C#m/B, A, B, E, A/E, ...
# ...                                                  ...
# 10484  [Bbm, Ab, Db, Fm, Eb, Ab, Bbm, Ab, Db, Fm, Eb,...
# 10485  [Dm, Dm, Dm, Dm, Am, Am, Am, Am, G, G, F, F, D...
# 10486                     [Eb, Gm, F, Dm, Eb, Gm, F, Dm]
# 10487  [Dbmaj7, Dbmaj7, Dbmaj7, Eb7/Db, Ab, Eb7/G, Fm...
# 10488  [Ab(add9), Abmaj7, Ab(add9), Cm/Bb, Cm7, Eb, F...
#
#                                                 chordRel  \
# 0      [I, I64, I, I64, I, I64, I, IV, IV64, IV, IV64...
# 1                                 [I, vi7, IV9, ii11, V]
# 2                           [i, iv, VI, v, i, iv, VI, v]
# 3      [vi, IV, I, iii, vi, IV, I, iii, vi, IV, I, ii...
# 4      [IV, iv, iii, V6, vi, vi42, IV, V, I, IV64, i7...
# ...                                                  ...
# 10484  [iv, III, VI, i, VII, III, iv, III, VI, i, VII...
# 10485  [iv, iv, iv, iv, i, i, i, i, VII, VII, VI, VI,...
# 10486                     [VI, i, VII, v, VI, i, VII, v]
# 10487  [IV7, IV7, IV7, V42, I, V65, vi7, Vsus4, Isus4...
# 10488  [VI(add9), VI7, VI(add9), i42, i7, III, iv7, V...
#
#                                                     link keyTonic    keyScale
# 0               /theorytab/view/til-tuesday/voices-carry        G  mixolydian
# 1            /theorytab/view/070-shake/guilty-conscience        G       major
# 2      /theorytab/view/100-gecs/hand-crushed-by-a-mallet       C#       minor
# 3                 /theorytab/view/100-gecs/money-machine       F#       major
# 4                    /theorytab/view/10cc/im-not-in-love        E       major
# ...                                                  ...      ...         ...
# 10484         /theorytab/view/twenty-one-pilots/my-blood        F       minor
# 10485  /theorytab/view/twenty-one-pilots/nico-and-the...        A       minor
# 10486      /theorytab/view/twenty-one-pilots/pet-cheetah        G       minor
# 10487                    /theorytab/view/vistlip/-ozone-       Ab       major
# 10488                      /theorytab/view/zedd/spectrum        C       minor
#
# [10489 rows x 7 columns]

# %%
# df.to_csv("test4-songs.csv", index=False)

# %%
from shared import *
read_songs("test4-songs.csv")
# Out:
#                   artist                      song  \
# 0           'Til Tuesday              Voices Carry
# 1              070 Shake         Guilty Conscience
# 2               100 gecs  Hand Crushed By A Mallet
# 3               100 gecs             Money Machine
# 4                   10cc           I'm Not In Love
# ...                  ...                       ...
# 10484  twenty one pilots                  My Blood
# 10485  twenty one pilots       Nico And The Niners
# 10486  twenty one pilots               Pet Cheetah
# 10487            vistlip                   -OZONE-
# 10488               zedd                  Spectrum
#
#                                                 chordAbs  \
# 0      [G, G/D, G, G/D, G, G/D, G, Bb, Bb/F, Bb, Bb/F...
# 1                               [G, Em7, Cmai9, Am11, D]
# 2                   [C#m, F#m, A, G#m, C#m, F#m, A, G#m]
# 3      [D#m, B, F#, A#m, D#m, B, F#, A#m, D#m, B, F#,...
# 4      [A, Am, G#m, G#/B#, C#m, C#m/B, A, B, E, A/E, ...
# ...                                                  ...
# 10484  [Bbm, Ab, Db, Fm, Eb, Ab, Bbm, Ab, Db, Fm, Eb,...
# 10485  [Dm, Dm, Dm, Dm, Am, Am, Am, Am, G, G, F, F, D...
# 10486                     [Eb, Gm, F, Dm, Eb, Gm, F, Dm]
# 10487  [Dbmai7, Dbmai7, Dbmai7, Eb7/Db, Ab, Eb7/G, Fm...
# 10488  [Ab(add9), Abmai7, Ab(add9), Cm/Bb, Cm7, Eb, F...
#
#                                                 chordRel  \
# 0      [I, I64, I, I64, I, I64, I, IV, IV64, IV, IV64...
# 1                                 [I, vi7, IV9, ii11, V]
# 2                           [i, iv, VI, v, i, iv, VI, v]
# 3      [vi, IV, I, iii, vi, IV, I, iii, vi, IV, I, ii...
# 4      [IV, iv, iii, V6, vi, vi42, IV, V, I, IV64, i7...
# ...                                                  ...
# 10484  [iv, III, VI, i, VII, III, iv, III, VI, i, VII...
# 10485  [iv, iv, iv, iv, i, i, i, i, VII, VII, VI, VI,...
# 10486                     [VI, i, VII, v, VI, i, VII, v]
# 10487  [IV7, IV7, IV7, V42, I, V65, vi7, Vsus4, Isus4...
# 10488  [VI(add9), VI7, VI(add9), i42, i7, III, iv7, V...
#
#                                                     link keyTonic    keyScale
# 0               /theorytab/view/til-tuesday/voices-carry        G  mixolydian
# 1            /theorytab/view/070-shake/guilty-conscience        G       major
# 2      /theorytab/view/100-gecs/hand-crushed-by-a-mallet       C#       minor
# 3                 /theorytab/view/100-gecs/money-machine       F#       major
# 4                    /theorytab/view/10cc/im-not-in-love        E       major
# ...                                                  ...      ...         ...
# 10484         /theorytab/view/twenty-one-pilots/my-blood        F       minor
# 10485  /theorytab/view/twenty-one-pilots/nico-and-the...        A       minor
# 10486      /theorytab/view/twenty-one-pilots/pet-cheetah        G       minor
# 10487                    /theorytab/view/vistlip/-ozone-       Ab       major
# 10488                      /theorytab/view/zedd/spectrum        C       minor
#
# [10489 rows x 7 columns]

# %%
df[df.keyScale=="major"].chordRel.explode().value_counts().head(10)
# Out:
# I      27230
# V      19163
# IV     18939
# vi     11219
# ii      4727
# V7      4156
# iii     4001
# ii7     2779
# IV7     2723
# vi7     2614
# Name: chordRel, dtype: int64

# %%
df[df.chordRel.apply(lambda x: " ".join(x).startswith("i "))]
# Out:
#                   artist                                song  \
# 2               100 gecs            Hand Crushed By A Mallet
# 5                   10cc             The Wall Street Shuffle
# 8            2 Unlimited                            No Limit
# 12              24kGoldn                           Valentino
# 13                  2Pac           2 of Amerikaz Most Wanted
# ...                  ...                                 ...
# 10462             miss A                            Only You
# 10473          rammstein                   Mein Hertz Brennt
# 10474           scarlxrd                        HEART ATTACK
# 10476                sia  The Church Of What's Happening Now
# 10481  twenty one pilots                      Heavydirtysoul
#
#                                                 chordAbs  \
# 2                   [C#m, F#m, A, G#m, C#m, F#m, A, G#m]
# 5      [Dm, Bb, C, Dm, G, G, G, Dm, Bb, C, Dm, Dm, Bb...
# 8           [Bbm, Bbm, Bbm, Eb, F, Bbm, Bbm, Bbm, Eb, F]
# 12                                      [Am, Dm, Em, Am]
# 13     [D#m, D#m, D#m, D#m, B, D#m, D#m, D#m, D#m, B,...
# ...                                                  ...
# 10462  [Dm, Am, Bb, F, F/E, Dm, Am, Bb, C, C#o, Dm, A...
# 10473  [Dm, Gm, Bb, C, Dm, Gm, Bb, C, Cm, Cm, Cm, Cm,...
# 10474                                           [Bm, Bm]
# 10476                     [Em, A, D, G, Em, A, D, C, Bm]
# 10481  [Dm, Bb, Gm, Dm, C, Bb, Gm, Dm, C, Bb, Gm, Dm,...
#
#                                                 chordRel  \
# 2                           [i, iv, VI, v, i, iv, VI, v]
# 5      [i, VI, VII, i, IV, IV, IV, i, VI, VII, i, i, ...
# 8                       [i, i, i, IV, V, i, i, i, IV, V]
# 12                                         [i, iv, v, i]
# 13     [i, i, i, i, VI, i, i, i, i, VI, i, i, i, i, V...
# ...                                                  ...
# 10462  [i, v, VI, III, III42, i, v, VI, VII, viio, i,...
# 10473  [i, iv, VI, VII, i, iv, VI, VII, i, i, i, i, i...
# 10474                                             [i, i]
# 10476              [i, IV, VII, III, i, IV, VII, bVI, v]
# 10481  [i, VI, iv, i, VII, VI, iv, i, VII, VI, iv, i,...
#
#                                                     link keyTonic keyScale
# 2      /theorytab/view/100-gecs/hand-crushed-by-a-mallet       C#    minor
# 5           /theorytab/view/10cc/the-wall-street-shuffle        D    minor
# 8                   /theorytab/view/2-unlimited/no-limit       Bb    minor
# 12                    /theorytab/view/24kgoldn/valentino        A    minor
# 13        /theorytab/view/2pac/2-of-amerikaz-most-wanted       D#    minor
# ...                                                  ...      ...      ...
# 10462                    /theorytab/view/miss-a/only-you        D    minor
# 10473        /theorytab/view/rammstein/mein-hertz-brennt        D    minor
# 10474              /theorytab/view/scarlxrd/heart-attack        B    minor
# 10476  /theorytab/view/sia/the-church-of-whats-happen...        E   dorian
# 10481   /theorytab/view/twenty-one-pilots/heavydirtysoul        D    minor
#
# [2559 rows x 7 columns]

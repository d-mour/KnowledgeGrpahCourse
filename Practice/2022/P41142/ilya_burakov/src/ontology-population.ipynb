# %%
from shared import *
import pandas as pd
from rdflib import Graph, Literal, BNode, Namespace, URIRef
from rdflib.namespace import RDF, OWL, RDFS
from urllib.parse import quote_plus
from pathlib import Path

# %%
df = read_songs("../source-data/hooktheory-songs.csv")
df
# Out:
#                   artist                      song  \
# 0           'Til Tuesday              Voices Carry
# 1              070 Shake         Guilty Conscience
# 2               100 gecs  Hand Crushed By A Mallet
# 3               100 gecs             Money Machine
# 4                   10cc           I'm Not In Love
# ...                  ...                       ...
# 10484  twenty one pilots                  My Blood
# 10485  twenty one pilots       Nico And The Niners
# 10486  twenty one pilots               Pet Cheetah
# 10487            vistlip                   -OZONE-
# 10488               zedd                  Spectrum
#
#                                                 chordAbs  \
# 0      [G, G/D, G, G/D, G, G/D, G, Bb, Bb/F, Bb, Bb/F...
# 1                               [G, Em7, Cmaj9, Am11, D]
# 2                   [C#m, F#m, A, G#m, C#m, F#m, A, G#m]
# 3      [D#m, B, F#, A#m, D#m, B, F#, A#m, D#m, B, F#,...
# 4      [A, Am, G#m, G#/B#, C#m, C#m/B, A, B, E, A/E, ...
# ...                                                  ...
# 10484  [Bbm, Ab, Db, Fm, Eb, Ab, Bbm, Ab, Db, Fm, Eb,...
# 10485  [Dm, Dm, Dm, Dm, Am, Am, Am, Am, G, G, F, F, D...
# 10486                     [Eb, Gm, F, Dm, Eb, Gm, F, Dm]
# 10487  [Dbmaj7, Dbmaj7, Dbmaj7, Eb7/Db, Ab, Eb7/G, Fm...
# 10488  [Ab(add9), Abmaj7, Ab(add9), Cm/Bb, Cm7, Eb, F...
#
#                                                 chordRel  \
# 0      [I, I64, I, I64, I, I64, I, IV, IV64, IV, IV64...
# 1                                 [I, vi7, IV9, ii11, V]
# 2                           [i, iv, VI, v, i, iv, VI, v]
# 3      [vi, IV, I, iii, vi, IV, I, iii, vi, IV, I, ii...
# 4      [IV, iv, iii, V6, vi, vi42, IV, V, I, IV64, i7...
# ...                                                  ...
# 10484  [iv, III, VI, i, VII, III, iv, III, VI, i, VII...
# 10485  [iv, iv, iv, iv, i, i, i, i, VII, VII, VI, VI,...
# 10486                     [VI, i, VII, v, VI, i, VII, v]
# 10487  [IV7, IV7, IV7, V42, I, V65, vi7, Vsus4, Isus4...
# 10488  [VI(add9), VI7, VI(add9), i42, i7, III, iv7, V...
#
#                                                     link keyTonic    keyScale
# 0               /theorytab/view/til-tuesday/voices-carry        G  mixolydian
# 1            /theorytab/view/070-shake/guilty-conscience        G       major
# 2      /theorytab/view/100-gecs/hand-crushed-by-a-mallet       C#       minor
# 3                 /theorytab/view/100-gecs/money-machine       F#       major
# 4                    /theorytab/view/10cc/im-not-in-love        E       major
# ...                                                  ...      ...         ...
# 10484         /theorytab/view/twenty-one-pilots/my-blood        F       minor
# 10485  /theorytab/view/twenty-one-pilots/nico-and-the...        A       minor
# 10486      /theorytab/view/twenty-one-pilots/pet-cheetah        G       minor
# 10487                    /theorytab/view/vistlip/-ozone-       Ab       major
# 10488                      /theorytab/view/zedd/spectrum        C       minor
#
# [10489 rows x 7 columns]

# %%
df[df.artist == "Edith Piaf"]
# Out:
#           artist                     song  \
# 2578  Edith Piaf           La vie en rose
# 2579  Edith Piaf                   Milord
# 2580  Edith Piaf  Non Je ne regrette rien
# 2581  Edith Piaf              Padam Padam
# 2582  Edith Piaf    Sous Le Ciel De Paris
#
#                                                chordAbs  \
# 2578  [G, Bm, Em7, Am, D7/A, Am7, D7, E7sus2, D7, Eo...
# 2579                     [D, G, D, E, A, D, G, D, E, A]
# 2580  [G, D7/F#, G, C, C+, Am/C, D9, D7(b9), D7, Bm,...
# 2581  [Bbm, Bbm/Db, Bbm, Bbm/Db, Bbm, Bbm/Db, F, F/C...
# 2582  [Am, Dm, E, Am, Dm, Am, Am, Dm, E, Am, Dm, G, ...
#
#                                                chordRel  \
# 2578  [I, iii, vi7, ii, V43, ii7, V7, vi7sus2, V7, v...
# 2579                   [I, IV, I, V, V, I, IV, I, V, V]
# 2580  [I, V65, I, IV, IV+(#5), ii6, V9, V7(b9), V7, ...
# 2581  [i, i6, i, i6, i, i6, V, V64, V, V64, V, V64, ...
# 2582  [vi, ii, V, vi, ii, vi, vi, ii, V, vi, ii, V, ...
#
#                                                    link keyTonic keyScale
# 2578          /theorytab/view/edith-piaf/la-vie-en-rose        G    major
# 2579                  /theorytab/view/edith-piaf/milord        D    major
# 2580  /theorytab/view/edith-piaf/non-je-ne-regrette-...        G    major
# 2581             /theorytab/view/edith-piaf/padam-padam       Bb    minor
# 2582   /theorytab/view/edith-piaf/sous-le-ciel-de-paris        C    major

# %%
from unidecode import unidecode

# %%
unidecode("Такунович in café")
# Out:
# 'Takunovich in cafe'

# %%
def name_to_iri_name(name) -> str:
    return "_".join(
        unidecode(name.replace("(", " ").replace(")", " ").replace('"', "").replace("^", "")).split()
    )

# %%
g = Graph()
g.parse("../ontologies/chord_progressions.owl", format="turtle")
# Out:
# <Graph identifier=Nbc3e2961b71d44819e9291bfadf8a660 (<class 'rdflib.graph.Graph'>)>

# %%
g.bind("chp", chp)

# %%
def artist_name_to_node(g, artist_name):
    author = URIRef(chp[name_to_iri_name(artist_name)])
    g.add((author, RDF.type, chp.Artist))
    g.add((author, RDF.type, OWL.NamedIndividual))
    g.add((author, chp.hasName, Literal(artist_name)))
    return author

def get_song_name(artist_name, song_name):
    return name_to_iri_name(artist_name + "_" + song_name)

def song_name_to_node(g, author, song_iri_frag, song_raw_name):
    song = URIRef(chp[song_iri_frag])
    g.add((song, RDF.type, chp.Composition))
    g.add((song, RDF.type, OWL.NamedIndividual))
    g.add((song, chp.hasAuthor, author))
    g.add((song, chp.hasName, Literal(song_raw_name)))
    return song

# %%
total_artists = len(df.artist.unique())
for i, (artist, songs) in enumerate(df.sort_values(["artist", "song"]).groupby("artist")):
    if i % 100 == 0:
        print(f"{i}/{total_artists}")
#     if i > 20:
#         break
        
    author = artist_name_to_node(g, artist)
    
    for row in songs.itertuples():
        tonic_name = row.keyTonic.replace("#", "s")
        scale_name = row.keyScale
        song_name = get_song_name(artist, row.song)
        
        tonic_note = URIRef(chp[tonic_name])
        g.add((tonic_note, RDF.type, chp.Note))
        g.add((tonic_note, RDF.type, OWL.NamedIndividual))
        g.add((tonic_note, RDFS.label, Literal(row.keyTonic)))
        
        scale = URIRef(chp[scale_name])
        g.add((scale, RDF.type, chp.Scale))
        g.add((scale, RDF.type, OWL.NamedIndividual))
        g.add((scale, RDFS.label, Literal(row.keyScale)))
        
        key = URIRef(chp[tonic_name + "_" + scale_name])
        g.add((key, RDF.type, chp.Key))
        g.add((key, RDF.type, OWL.NamedIndividual))
        g.add((key, chp.hasTonicNote, tonic_note))
        g.add((key, chp.hasScale, scale))
        
        song = song_name_to_node(g, author, song_name, row.song)
        g.add((song, chp.hasKey, key))
        
        progression_name = f"{song_name}_Progression1"
        last_entry = None
        for i, (chord_abs_str, chord_rel_str) in enumerate(zip(row.chordAbs, row.chordRel)):
            n = i + 1
            entry = URIRef(chp[f"{progression_name}_{n}"])
            g.add((entry, RDF.type, chp.ChordProgressionEntry))
            g.add((entry, RDF.type, OWL.NamedIndividual))
            g.add((entry, chp.hasProgressionPosition, Literal(n)))
            
            g.add((song, chp.hasChordProgression, entry))
            
            chord_abs = URIRef(chp[quote_plus(chord_abs_str)])
            g.add((chord_abs, RDF.type, chp.AbsoluteChord))
            g.add((chord_abs, RDF.type, OWL.NamedIndividual))
            g.add((chord_abs, chp.hasHookTheoryRepresentation, Literal(chord_abs_str)))
            g.add((chord_abs, RDFS.label, Literal(chord_abs_str)))
            g.add((entry, chp.hasAbsoluteChord, chord_abs))
            
            chord_rel = URIRef(chp[quote_plus(chord_rel_str)])
            g.add((chord_rel, RDF.type, chp.RelativeChord))
            g.add((chord_rel, RDF.type, OWL.NamedIndividual))
            g.add((chord_rel, chp.hasHookTheoryRepresentation, Literal(chord_rel_str)))
            g.add((chord_rel, RDFS.label, Literal(chord_rel_str)))
            g.add((entry, chp.hasRelativeChord, chord_rel))
            
            if last_entry:
                g.add((last_entry, chp.hasNextEntry, entry))
            last_entry = entry
# Out:
# 0/2944
# 100/2944
# 200/2944
# 300/2944
# 400/2944
# 500/2944
# 600/2944
# 700/2944
# 800/2944
# 900/2944
# 1000/2944
# 1100/2944
# 1200/2944
# 1300/2944
# 1400/2944
# 1500/2944
# 1600/2944
# 1700/2944
# 1800/2944
# 1900/2944
# 2000/2944
# 2100/2944
# 2200/2944
# 2300/2944
# 2400/2944
# 2500/2944
# 2600/2944
# 2700/2944
# 2800/2944
# 2900/2944

# %%
len(g)
# Out:
# 2176852

# %%
POPULATED_OWL_FILENAME = "../ontologies/chord-progressions-populated-ht-full.owl"
g.serialize(destination=POPULATED_OWL_FILENAME, format="turtle")
# Out:
# <Graph identifier=Nbc3e2961b71d44819e9291bfadf8a660 (<class 'rdflib.graph.Graph'>)>

# %%
# rg = Graph(store="Oxigraph")
# rg.parse(POPULATED_OWL_FILENAME, format="ttl")
# len(rg)
# Out:
# 7192

# %%
# def do_sparql_query(graph, query):
#     if isinstance(query, Path):
#         with query.open("r") as f:
#             q_str = f.read()
#     else:
#         q_str = str(query)
#         
#     res = graph.query(q_str)
#     
#     def map_value(v):
#         if isinstance(v, URIRef):
#             vs = str(v) 
#             return vs[vs.rfind("#") + 1:]
#         
#         return v.toPython()
#     
#     return pd.DataFrame([
#         {str(var): map_value(getattr(row, str(var))) for var in res.vars}
#         for row in res
#     ])/

# %%
# do_sparql_query(rg, Path("queries/1.sparql"))
# Out:
#   abs_chord_repr                     composition
# 0              D  38_Special_If_I'd_Been_the_One
# 1              D                    2pac_Changes
# 2              D     070_Shake_Guilty_Conscience

# %% [markdown]
# ### Querying Wikidata

# %%
from qwikidata.sparql import return_sparql_query_results

wdfn = "../source-data/wikidata-songs.csv"

def sparql_results_to_df(res):
    return pd.DataFrame({cname: value["value"] for cname, value in row.items()} for row in res["results"]["bindings"])

def get_artist_songs_from_wikidata(artist):
    return sparql_results_to_df(return_sparql_query_results("""
    SELECT DISTINCT ?song ?songLabel ?artistLabel ?genreLabel ?publicationDate WHERE {
    #   FILTER (?song = wd:Q21172725)
      # ?artist rdfs:label "<$ARTIST_LABEL$>"@en.
      # we need either composer (classical music, for example) or performer (pop) and it's hard to tell what exactly, so include both.
      {?song wdt:P175 ?artist.} UNION {?song wdt:P86 ?artist.}
      # ?song p:P31/ps:P31/(p:P279|ps:P279)* wd:Q105543609.
      OPTIONAL { ?song wdt:P577 ?publicationDate }
      OPTIONAL { ?song wdt:P136 ?genre }
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """.replace("<$ARTIST_LABEL$>", artist)))

get_artist_songs_from_wikidata("Adele").head(5)
# Out:
#                                        song            songLabel artistLabel  \
# 0    http://www.wikidata.org/entity/Q326790              Skyfall       Adele
# 1  http://www.wikidata.org/entity/Q57786072        Best For Last       Adele
# 2   http://www.wikidata.org/entity/Q1107851        Cold Shoulder       Adele
# 3  http://www.wikidata.org/entity/Q57797127           First Love       Adele
# 4    http://www.wikidata.org/entity/Q170165  Rolling in the Deep       Adele
#
#        genreLabel       publicationDate
# 0  orchestral pop                   NaN
# 1             NaN                   NaN
# 2      soul music  2008-04-21T00:00:00Z
# 3             NaN                   NaN
# 4     power metal  2011-01-01T00:00:00Z

# %%
from concurrent.futures import ThreadPoolExecutor
from threading import Lock
import time

done = {"value": 0}
cl = Lock()
artists = df.artist.unique()

def job(artist):
    print(f"Done {done['value']} / {len(artists)}, doing {artist}")
    result = None
    while result is None:
        try:
            result = get_artist_songs_from_wikidata(artist)
        except Exception as e:
            print(f"{e.__class__.__name__}: {e} @ {artist}, retrying...")
        time.sleep(5)
    with cl:
        done["value"] += 1
    return result

with ThreadPoolExecutor(4) as tp:
    wdf = pd.concat(tp.map(job, artists))
# Out:
# Done 0 / 2944, doing 'Til Tuesday
# Done 0 / 2944, doing 070 Shake
# Done 0 / 2944, doing 100 gecs
# Done 0 / 2944, doing 10cc
# Done 1 / 2944, doing 112
# Done 2 / 2944, doing 2 UnlimitedDone 3 / 2944, doing 20syl
#
# Done 4 / 2944, doing 24kGoldn
# Done 5 / 2944, doing 2Pac
# Done 6 / 2944, doing 2pac
# Done 7 / 2944, doing 3 Doors Down
# Done 8 / 2944, doing 30 Seconds To Mars
# Done 9 / 2944, doing 311
# Done 10 / 2944, doing 38 Special
# Done 11 / 2944, doing 3LAU
# Done 12 / 2944, doing 4 Non Blondes
# Done 13 / 2944, doing 4 Strings
# Done 14 / 2944, doing 4minute
# Done 15 / 2944, doing 5 Seconds Of Summer
# Done 16 / 2944, doing 50 Cent
# Done 17 / 2944, doing 65Daysofstatic
# Done 18 / 2944, doing 808 State
# Done 19 / 2944, doing 98 Degrees
# Done 20 / 2944, doing 9th Wonder
# Done 21 / 2944, doing A Boogie Wit Da Hoodie
# Done 22 / 2944, doing A Great Big World
# Done 23 / 2944, doing A Perfect Circle
# Done 24 / 2944, doing A Sunny Day in Glasgow
# Done 25 / 2944, doing A Tribe Called Quest
# Done 26 / 2944, doing A-ha
# Done 27 / 2944, doing ABBA
# Done 28 / 2944, doing ABSRDST
# Done 29 / 2944, doing AFI
# Done 30 / 2944, doing AJR
# Done 31 / 2944, doing AKB48
# Done 32 / 2944, doing AOA
# Done 33 / 2944, doing ARCHIVE
# Done 34 / 2944, doing ATB
# Done 35 / 2944, doing ATC
# Done 36 / 2944, doing AZEDIA
# Done 37 / 2944, doing AaRON
# Done 38 / 2944, doing Aaliyah
# Done 39 / 2944, doing Aaron Carter
# Done 40 / 2944, doing Ab-Soul
# Done 41 / 2944, doing Abel Korzeniowski
# Done 42 / 2944, doing Absynthe Minded
# Done 43 / 2944, doing Ace Of Base
# Done 44 / 2944, doing Ace of Base
# Done 45 / 2944, doing Adam Lambert
# Done 46 / 2944, doing Adam Sandler
# Done 47 / 2944, doing Adel Tawil
# Done 48 / 2944, doing Adele
# Done 49 / 2944, doing Adrian Lux
# Done 50 / 2944, doing Adriana Calcanhotto
# Done 51 / 2944, doing Adrianne Lenker
# Done 52 / 2944, doing Adventure Club
# Done 53 / 2944, doing Adventure Time
# Done 54 / 2944, doing Adventures
# Done 55 / 2944, doing Aerosmith
# Done 56 / 2944, doing Afrojack
# Done 57 / 2944, doing Afroman
# Done 58 / 2944, doing Agnes
# Done 59 / 2944, doing Ahrix
# Done 60 / 2944, doing Ai Otsuka
# Done 61 / 2944, doing Aimee Mann
# Done 62 / 2944, doing Air
# Done 63 / 2944, doing Air Supply
# Done 64 / 2944, doing Airwave
# Done 65 / 2944, doing Aitana
# Done 66 / 2944, doing Akcent
# Done 67 / 2944, doing Akiko Yano
# Done 68 / 2944, doing Akira Yamaoka
# Done 69 / 2944, doing Akon
# Done 70 / 2944, doing Al Green
# Done 71 / 2944, doing Al Jarreau
# Done 72 / 2944, doing Alabama Shakes
# Done 73 / 2944, doing Alan Menken
# Done 74 / 2944, doing Alan Silvestri
# Done 75 / 2944, doing Alan Walker
# Done 76 / 2944, doing Alanis Morissette
# Done 77 / 2944, doing Aleks Syntek
# Done 78 / 2944, doing Alela Diane
# Done 79 / 2944, doing Alessia Cara
# Done 80 / 2944, doing Alesso
# Done 81 / 2944, doing Alestorm
# Done 82 / 2944, doing Alex Clare
# Done 83 / 2944, doing Alex G
# Done 84 / 2944, doing Alex Gaudino
# Done 85 / 2944, doing Alex LloydDone 86 / 2944, doing Alexander Brandon
#
# Done 87 / 2944, doing Alexander Courage
# Done 88 / 2944, doing Alexander Rybak
# Done 89 / 2944, doing Alexandra Stan
# Done 90 / 2944, doing Alexandre Desplat
# Done 91 / 2944, doing Alexi Murdoch
# Done 92 / 2944, doing Alice Cooper
# Done 93 / 2944, doing Alice In Chains
# Done 94 / 2944, doing Alice in Chains
# Done 95 / 2944, doing Alicia Keys
# Done 96 / 2944, doing Alien Ant Farm
# Done 97 / 2944, doing Alison Krauss
# Done 98 / 2944, doing Alizee
# Done 99 / 2944, doing Alkaline Trio
# Done 100 / 2944, doing Allemaal Door Jou
# Done 101 / 2944, doing Allen Stone
# Done 102 / 2944, doing Allie X
# Done 103 / 2944, doing Allstar Weekend
# Done 104 / 2944, doing Aloe Blacc
# Done 105 / 2944, doing Alpha 9
# Done 106 / 2944, doing Alphabeat
# Done 107 / 2944, doing Alphaville
# Done 108 / 2944, doing Alt-J
# Done 109 / 2944, doing Alter Bridge
# Done 110 / 2944, doing AlunaGeorge
# Done 111 / 2944, doing Alvvays
# Done 112 / 2944, doing Amaral
# Done 113 / 2944, doing Amber Run
# Done 114 / 2944, doing America
# Done 115 / 2944, doing American Authors
# Done 116 / 2944, doing American Football
# Done 117 / 2944, doing Amerie
# Done 118 / 2944, doing Amy Grant
# Done 119 / 2944, doing Amy Lee
# Done 120 / 2944, doing Amy Winehouse
# Done 121 / 2944, doing Anamanaguchi
# Done 122 / 2944, doing And One
# Done 123 / 2944, doing Andain
# Done 124 / 2944, doing Andrea True Connection
# Done 125 / 2944, doing Andrew Bird
# Done 126 / 2944, doing Andrew Huang
# Done 127 / 2944, doing Andrew Lloyd Webber
# Done 128 / 2944, doing Andy Gibb
# Done 129 / 2944, doing Andy Grammer
# Done 130 / 2944, doing Andy Williams
# Done 131 / 2944, doing Ane Brun
# Done 132 / 2944, doing Angel Olsen
# Done 133 / 2944, doing Angela Bofill
# Done 134 / 2944, doing Angelo Badalamenti
# Done 135 / 2944, doing Animal Collective
# Done 136 / 2944, doing Animals As Leaders
# Done 137 / 2944, doing Animals as Leaders
# Done 138 / 2944, doing Animaniacs
# Done 139 / 2944, doing Anita Baker
# Done 140 / 2944, doing Anne Murray
# Done 141 / 2944, doing Anne-Marie
# Done 142 / 2944, doing Annie
# Done 143 / 2944, doing Annie Lennox
# Done 144 / 2944, doing Anoraak
# Done 145 / 2944, doing Anouk
# Done 146 / 2944, doing Antonio Vivaldi
# Done 147 / 2944, doing Aphex Twin
# Done 148 / 2944, doing Apollo
# Done 149 / 2944, doing Approaching Nirvana
# Done 150 / 2944, doing Aqua
# Done 151 / 2944, doing Aqualung
# Done 152 / 2944, doing Arash
# Done 153 / 2944, doing Arca
# Done 154 / 2944, doing Arcade Fire
# Done 155 / 2944, doing Archie
# Done 156 / 2944, doing Architecture in Helsinki
# Done 157 / 2944, doing Arctic Monkeys
# Done 158 / 2944, doing Area 11
# Done 159 / 2944, doing Aretha Franklin
# Done 160 / 2944, doing Ari Lennox
# Done 161 / 2944, doing Ariana Grande
# Done 162 / 2944, doing Ariel Pink
# Done 163 / 2944, doing Ark Patrol
# Done 164 / 2944, doing Armin Van Buuren
# Done 165 / 2944, doing Armin van Buuren
# Done 166 / 2944, doing Art Garfunkel
# Done 167 / 2944, doing Art of Noise
# Done 168 / 2944, doing Arthur Russell
# Done 169 / 2944, doing Arty
# Done 170 / 2944, doing Arvo Part
# Done 171 / 2944, doing Asaf Avidan
# Done 172 / 2944, doing Asgeir
# Done 173 / 2944, doing Ash
# Done 174 / 2944, doing Ashanti
# Done 175 / 2944, doing Asher Roth
# Done 176 / 2944, doing Ashes Remain
# Done 177 / 2944, doing Ashlee Simpson
# Done 178 / 2944, doing Ashley Parker Angel
# Done 179 / 2944, doing Ashmute
# Done 180 / 2944, doing Asia
# Done 181 / 2944, doing Astor Piazzolla
# Done 182 / 2944, doing Astrid S
# Done 183 / 2944, doing Astronaut
# Done 184 / 2944, doing Asuka Ninomiya - Hajime Fujiwara - Karen Hojo
# Done 185 / 2944, doing At The Drive-In
# Done 186 / 2944, doing At the Drive-In
# Done 187 / 2944, doing Atlas Genius
# Done 188 / 2944, doing Atomic Kitten
# Done 189 / 2944, doing Atoms For Peace
# Done 190 / 2944, doing Au5
# Done 191 / 2944, doing Audien
# Done 192 / 2944, doing Audiomachine
# Done 193 / 2944, doing Audioslave
# Done 194 / 2944, doing Augustana
# Done 195 / 2944, doing Augustines
# Done 196 / 2944, doing Aura Dione
# Done 197 / 2944, doing Austin Mahone
# Done 198 / 2944, doing Austra
# Done 199 / 2944, doing Australian Crawl
# Done 200 / 2944, doing Autolaser
# Done 201 / 2944, doing Ava Max
# Done 202 / 2944, doing Avenged Sevenfold
# Done 203 / 2944, doing Avey Tare
# Done 204 / 2944, doing Avicii
# Done 205 / 2944, doing Avril Lavigne
# Done 206 / 2944, doing Awolnation
# Done 207 / 2944, doing Axwell
# Done 208 / 2944, doing Aya Hirano
# Done 209 / 2944, doing Ayreon
# Done 210 / 2944, doing Azealia Banks
# Done 211 / 2944, doing Azymuth
# Done 212 / 2944, doing BADBADNOTGOOD
# Done 213 / 2944, doing BBC National Orchestra of Wales
# Done 214 / 2944, doing BENEE
# Done 215 / 2944, doing BIGBANG
# Done 216 / 2944, doing BOY
# Done 217 / 2944, doing BROCKHAMPTON
# Done 218 / 2944, doing BT
# Done 219 / 2944, doing BTS
# Done 220 / 2944, doing Baauer
# Done 221 / 2944, doing Baby Bash
# Done 222 / 2944, doing Babymetal
# Done 223 / 2944, doing Bachman-Turner Overdrive
# Done 224 / 2944, doing Backstreet Boys
# Done 225 / 2944, doing Bad Lip Reading
# Done 226 / 2944, doing Bad Religion
# Done 227 / 2944, doing Bad Suns
# Done 228 / 2944, doing Badfinger
# Done 229 / 2944, doing Bag Raiders
# Done 230 / 2944, doing Bahamas
# Done 231 / 2944, doing Bakermat
# Done 232 / 2944, doing Bali Bandits
# Done 233 / 2944, doing Balthazar
# Done 234 / 2944, doing Bambee
# Done 235 / 2944, doing Bananarama
# Done 236 / 2944, doing Band of Skulls
# Done 237 / 2944, doing Banks
# Done 238 / 2944, doing Barbra Streisand
# Done 239 / 2944, doing Barenaked Ladies
# Done 240 / 2944, doing Barry Manilow
# Done 241 / 2944, doing Basement Jaxx
# Done 242 / 2944, doing Basshunter
# Done 243 / 2944, doing Bastille
# Done 244 / 2944, doing Basto
# Done 245 / 2944, doing Bat For Lashes
# Done 246 / 2944, doing Baths
# Done 247 / 2944, doing Bayside
# Done 248 / 2944, doing Beach Bunny
# Done 249 / 2944, doing Beach Fossils
# Done 250 / 2944, doing Beach House
# Done 251 / 2944, doing Bear McCreary
# Done 252 / 2944, doing Beast
# Done 253 / 2944, doing Bebe Rexha
# Done 254 / 2944, doing Beck
# Done 255 / 2944, doing Becky G
# Done 256 / 2944, doing Bee Gees
# Done 257 / 2944, doing Bela Bartok
# Done 258 / 2944, doing Belchior
# Done 259 / 2944, doing Belinda Carlisle
# Done 260 / 2944, doing Bellini
# Done 261 / 2944, doing Ben Folds
# Done 262 / 2944, doing Ben Folds Five
# Done 263 / 2944, doing Ben Harper
# Done 264 / 2944, doing Ben Lee
# Done 265 / 2944, doing Ben Prunty
# Done 266 / 2944, doing Ben Rector
# Done 267 / 2944, doing Benny Benassi
# Done 268 / 2944, doing Benny Blanco
# Done 269 / 2944, doing Benny Sings
# Done 270 / 2944, doing Bent Van Looy
# Done 271 / 2944, doing Berlin
# Done 272 / 2944, doing Bernard Herrmann
# Done 273 / 2944, doing Bessie Smith
# Done 274 / 2944, doing Bethany Joy Lenz
# Done 275 / 2944, doing Bette Midler
# Done 276 / 2944, doing Betty Who
# Done 277 / 2944, doing Beyonce
# Done 278 / 2944, doing Beyonce
# Done 279 / 2944, doing Bic Runga
# Done 280 / 2944, doing Biffy Clyro
# Done 281 / 2944, doing Big Data
# Done 282 / 2944, doing Big Star
# Done 283 / 2944, doing Big Wild
# Done 284 / 2944, doing Bill Brown
# Done 285 / 2944, doing Bill Withers
# Done 286 / 2944, doing Bill Wurtz
# Done 287 / 2944, doing Billie Eilish
# Done 288 / 2944, doing Billie Piper
# Done 289 / 2944, doing Billy Currington
# Done 290 / 2944, doing Billy Joel
# Done 291 / 2944, doing Billy Ocean
# Done 292 / 2944, doing Billy Squier
# Done 293 / 2944, doing Billy Talent
# Done 294 / 2944, doing Binary Finary
# Done 295 / 2944, doing Bing Crosby
# Done 296 / 2944, doing Bingo Players
# Done 297 / 2944, doing Birds of Tokyo
# Done 298 / 2944, doing Birdy
# Done 299 / 2944, doing Bis
# Done 300 / 2944, doing Biz Markie
# Done 301 / 2944, doing Bjork
# Done 302 / 2944, doing Black
# Done 303 / 2944, doing Black Dresses
# Done 304 / 2944, doing Black Milk
# Done 305 / 2944, doing Black Moth Super Rainbow
# Done 306 / 2944, doing Black Sabbath
# Done 307 / 2944, doing Blackhawk
# Done 308 / 2944, doing Blackpink
# Done 309 / 2944, doing Bladee
# Done 310 / 2944, doing Blake Shelton
# Done 311 / 2944, doing Blank Banshee
# Done 312 / 2944, doing Blaque
# Done 313 / 2944, doing Bleachers
# Done 314 / 2944, doing Blende
# Done 315 / 2944, doing Blind Guardian
# Done 316 / 2944, doing Blind Melon
# Done 317 / 2944, doing Blind Pilot
# Done 318 / 2944, doing Blink-182
# Done 319 / 2944, doing Bloc Party
# Done 320 / 2944, doing Block B
# Done 321 / 2944, doing Blonde Redhead
# Done 322 / 2944, doing Blondie
# Done 323 / 2944, doing Blood Orange
# Done 324 / 2944, doing Bloodhound Gang
# Done 325 / 2944, doing Blu Cantrell
# Done 326 / 2944, doing Blue Oyster Cult
# Done 327 / 2944, doing Blue Stahli
# Done 328 / 2944, doing Blue Swede
# Done 329 / 2944, doing Blues Traveler
# Done 330 / 2944, doing Blumchen
# Done 331 / 2944, doing Blur
# Done 332 / 2944, doing Bo Burnham
# Done 333 / 2944, doing BoA
# Done 334 / 2944, doing Boards Of Canada
# Done 335 / 2944, doing Boards of Canada
# Done 336 / 2944, doing Bob Dylan
# Done 337 / 2944, doing Bob Evans
# Done 338 / 2944, doing Bob Marley
# Done 339 / 2944, doing Bob Mould
# Done 340 / 2944, doing Bob Seger
# Done 341 / 2944, doing Bobby Caldwell
# Done 342 / 2944, doing Bobby Darin
# Done 343 / 2944, doing Bobby Shmurda
# Done 344 / 2944, doing Bombay Bicycle Club
# Done 345 / 2944, doing Bomfunk MC's
# Done 346 / 2944, doing Bon Iver
# Done 347 / 2944, doing Bon Jovi
# Done 348 / 2944, doing Bonnie Raitt
# Done 349 / 2944, doing Bonnie Tyler
# Done 350 / 2944, doing Bonobo
# Done 351 / 2944, doing Booka Shade
# Done 352 / 2944, doing Boom Boom Satellites
# Done 353 / 2944, doing Boom Jinx
# Done 354 / 2944, doing Booty Luv
# Done 355 / 2944, doing Boston
# Done 356 / 2944, doing Bougenvilla
# Done 357 / 2944, doing Bowling For Soup
# Done 358 / 2944, doing Bowling for Soup
# Done 359 / 2944, doing Boy Pablo
# Done 360 / 2944, doing Boys Like Girls
# Done 361 / 2944, doing Boys Noize
# Done 362 / 2944, doing Boyz II Men
# Done 363 / 2944, doing Boyzone
# Done 364 / 2944, doing Brad Mehldau
# Done 365 / 2944, doing Brad Paisley
# Done 366 / 2944, doing Braken
# Done 367 / 2944, doing Brand New
# Done 368 / 2944, doing Brandi Carlile
# Done 369 / 2944, doing Brandon Flowers
# Done 370 / 2944, doing Brandy
# Done 371 / 2944, doing Bread
# Done 372 / 2944, doing Breakbot
# Done 373 / 2944, doing Breaking Benjamin
# Done 374 / 2944, doing Breathe Carolina
# Done 375 / 2944, doing Brenda Lee
# Done 376 / 2944, doing Brenda Russell
# Done 377 / 2944, doing Brent Faiyaz
# Done 378 / 2944, doing Brentalfloss
# Done 379 / 2944, doing Brett Eldredge
# Done 380 / 2944, doing Brian Crain
# Done 381 / 2944, doing Brian Eno
# Done 382 / 2944, doing Brian Fallon
# Done 383 / 2944, doing Brian May
# Done 384 / 2944, doing Brian Tyler
# Done 385 / 2944, doing Bright Eyes
# Done 386 / 2944, doing Britney Spears
# Done 387 / 2944, doing Britt Nicole
# Done 388 / 2944, doing Broadcast
# Done 389 / 2944, doing Broken Bells
# Done 390 / 2944, doing Broken Social Scene
# Done 391 / 2944, doing Brown Eyed Girls
# Done 392 / 2944, doing Bruce Broughton
# Done 393 / 2944, doing Bruce Dickinson
# Done 394 / 2944, doing Bruce Hornsby
# Done 395 / 2944, doing Bruce Springsteen
# Done 396 / 2944, doing Bruno Mars
# Done 397 / 2944, doing Bryan Adams
# Done 398 / 2944, doing BtoB
# Done 399 / 2944, doing Buddy Holly
# Done 400 / 2944, doing Buffalo Springfield
# Done 401 / 2944, doing Built To Spill
# Done 402 / 2944, doing Built to Spill
# Done 403 / 2944, doing Bullet For My Valentine
# Done 404 / 2944, doing Bush
# Done 405 / 2944, doing Buzzcocks
# Done 406 / 2944, doing C2C
# Done 407 / 2944, doing C418
# Done 408 / 2944, doing CG5
# Done 409 / 2944, doing CHIC
# Done 410 / 2944, doing CHVRCHES
# Done 411 / 2944, doing CKY
# Done 412 / 2944, doing CRO
# Done 413 / 2944, doing Cady Groves
# Done 414 / 2944, doing Caesars
# Done 415 / 2944, doing Cake
# Done 416 / 2944, doing Cal Tjader
# Done 417 / 2944, doing Calum Bowen
# Done 418 / 2944, doing Calum Scott
# Done 419 / 2944, doing Calvin Harris Alesso
# Done 420 / 2944, doing Camel
# Done 421 / 2944, doing Cameo
# Done 422 / 2944, doing Camera Obscura
# Done 423 / 2944, doing Camila Cabello
# Done 424 / 2944, doing Camille
# Done 425 / 2944, doing Camille Saint-Saens
# Done 426 / 2944, doing Camilo Sesto
# Done 427 / 2944, doing Can
# Done 428 / 2944, doing Canaan Smith
# Done 429 / 2944, doing Candy Claws
# Done 430 / 2944, doing Canned Heat
# Done 431 / 2944, doing Cannibal Corpse
# Done 432 / 2944, doing Capital Cities
# Done 433 / 2944, doing Capital Kings
# Done 434 / 2944, doing Capsule
# Done 435 / 2944, doing Captain Hollywood Project
# Done 436 / 2944, doing Car Seat Headrest
# Done 437 / 2944, doing Caramell
# Done 438 / 2944, doing Caravan Palace
# Done 439 / 2944, doing Cardi B
# Done 440 / 2944, doing Caribou
# Done 441 / 2944, doing Carissa's Wierd
# Done 442 / 2944, doing Carl Espen
# Done 443 / 2944, doing Carlos Gardel
# Done 444 / 2944, doing Carlos Santana
# Done 445 / 2944, doing Carly Pearce
# Done 446 / 2944, doing Carly Rae Jepsen
# Done 447 / 2944, doing Carly Simon
# Done 448 / 2944, doing Carole King
# Done 449 / 2944, doing Carolina Liar
# Done 450 / 2944, doing Caroline Polachek
# Done 451 / 2944, doing Carpenter Brut
# Done 452 / 2944, doing Carrie Underwood
# Done 453 / 2944, doing Carter Burwell
# Done 454 / 2944, doing Cascada
# Done 455 / 2944, doing Cash Cash
# Done 456 / 2944, doing Cashmere Cat
# Done 457 / 2944, doing Cassia Eller
# Done 458 / 2944, doing Cassius
# Done 459 / 2944, doing Casting Crowns
# Done 460 / 2944, doing Cat Power
# Done 461 / 2944, doing Cat Stevens
# Done 462 / 2944, doing Catch 22
# Done 463 / 2944, doing Caught A Ghost
# Done 464 / 2944, doing Cavetown
# Done 465 / 2944, doing Cazuza
# Done 466 / 2944, doing Celia Cruz
# Done 467 / 2944, doing Celine Dion
# Done 468 / 2944, doing Chad Valley
# Done 469 / 2944, doing Chairlift
# Done 470 / 2944, doing Chaka Khan
# Done 471 / 2944, doing Chamillionaire
# Done 472 / 2944, doing Chance the Rapper
# Done 473 / 2944, doing Change
# Done 474 / 2944, doing Charles Gounod
# Done 475 / 2944, doing Charles Wright - The Watts 103rd Street Rhythm Ban
# Done 476 / 2944, doing Charles-Valentin Alkan
# Done 477 / 2944, doing Charley Patton
# Done 478 / 2944, doing Charli XCX
# Done 479 / 2944, doing Charlie Parker
# Done 480 / 2944, doing Charlie Puth
# Done 481 / 2944, doing Charlotte Day Wilson
# Done 482 / 2944, doing Charlotte Gainsbourg
# Done 483 / 2944, doing Charly Bliss
# Done 484 / 2944, doing Chase Rice
# Done 485 / 2944, doing Cheap Trick
# Done 486 / 2944, doing Chef'Special
# Done 487 / 2944, doing Cher
# Done 488 / 2944, doing Cher Lloyd
# Done 489 / 2944, doing Cheryl Cole
# Done 490 / 2944, doing Chester See
# Done 491 / 2944, doing Chet Faker
# Done 492 / 2944, doing Chevelle
# Done 493 / 2944, doing Chic
# Done 494 / 2944, doing Chicago
# Done 495 / 2944, doing Chico Buarque
# Done 496 / 2944, doing Chiddy Bang
# Done 497 / 2944, doing Chief Keef
# Done 498 / 2944, doing Childish Gambino
# Done 499 / 2944, doing Chipzel
# Done 500 / 2944, doing Chloe Moriondo
# Done 501 / 2944, doing Chloe x Halle
# Done 502 / 2944, doing Chris Brown
# Done 503 / 2944, doing Chris Christodoulou
# Done 504 / 2944, doing Chris Cornell
# Done 505 / 2944, doing Chris Isaak
# Done 506 / 2944, doing Chris Lane
# Done 507 / 2944, doing Chris Tomlin
# Done 508 / 2944, doing Christie
# Done 509 / 2944, doing Christina Aguilera
# Done 510 / 2944, doing Christina Grimmie
# Done 511 / 2944, doing Christina Perri
# Done 512 / 2944, doing Christopher Cross
# Done 513 / 2944, doing Christopher Larkin
# Done 514 / 2944, doing Christopher Tin
# Done 515 / 2944, doing Chrome Sparks
# Done 516 / 2944, doing Chromeo
# Done 517 / 2944, doing Chubby Checker
# Done 518 / 2944, doing Chuck Berry
# Done 519 / 2944, doing Chumbawamba
# Done 520 / 2944, doing Chung HaDone 521 / 2944, doing Ciara
#
# Done 522 / 2944, doing Cicero
# Done 523 / 2944, doing Circa Waves
# Done 524 / 2944, doing Citizen King
# Done 525 / 2944, doing Citizens
# Done 526 / 2944, doing City Girls
# Done 527 / 2944, doing Clairo
# Done 528 / 2944, doing ClariS
# Done 529 / 2944, doing Clarian
# Done 530 / 2944, doing Claude Debussy
# Done 531 / 2944, doing Claude-Michel Schonberg
# Done 532 / 2944, doing Clay Aiken
# Done 533 / 2944, doing Clean Bandit
# Done 534 / 2944, doing Clint Mansell
# Done 535 / 2944, doing Cloud Nothings
# Done 536 / 2944, doing Cobra Starship
# Done 537 / 2944, doing Cocoon
# Done 538 / 2944, doing Cocteau Twins
# Done 539 / 2944, doing Codeko
# Done 540 / 2944, doing Colbie Caillat
# Done 541 / 2944, doing Cold Chisel
# Done 542 / 2944, doing Cold War Kids
# Done 543 / 2944, doing Coldplay
# Done 544 / 2944, doing Cole Porter
# Done 545 / 2944, doing Collective Soul
# Done 546 / 2944, doing Com Truise
# Done 547 / 2944, doing Commodores
# Done 548 / 2944, doing Common
# Done 549 / 2944, doing Conan Gray
# Done 550 / 2944, doing ConcernedApe
# Done 551 / 2944, doing Confidence Man
# Done 552 / 2944, doing Connan Mockasin
# Done 553 / 2944, doing Conor Maynard
# Done 554 / 2944, doing Converge
# Done 555 / 2944, doing Coolio
# Done 556 / 2944, doing Coralie Clement
# Done 557 / 2944, doing Corinne Bailey Rae
# Done 558 / 2944, doing Cornershop
# Done 559 / 2944, doing Corona
# Done 560 / 2944, doing Cosmo's Midnight
# Done 561 / 2944, doing Count Basie
# Done 562 / 2944, doing Counting Crows
# Done 563 / 2944, doing Courtney Barnett
# Done 564 / 2944, doing Coyote Kisses
# Done 565 / 2944, doing Craig David
# Done 566 / 2944, doing Crash Kings
# Done 567 / 2944, doing Crash Test Dummies
# Done 568 / 2944, doing Crazy Ex-Girlfriend Cast
# Done 569 / 2944, doing Crazy Town
# Done 570 / 2944, doing Cream
# Done 571 / 2944, doing Creed
# Done 572 / 2944, doing Creedence Clearwater Revival
# Done 573 / 2944, doing Cro
# Done 574 / 2944, doing Crowded House
# Done 575 / 2944, doing Crumb
# Done 576 / 2944, doing Crush 40
# Done 577 / 2944, doing Crusher-P
# Done 578 / 2944, doing Crystal Castles
# Done 579 / 2944, doing Crystal Waters
# Done 580 / 2944, doing Crywolf
# Done 581 / 2944, doing Cuco
# Done 582 / 2944, doing Cults
# Done 583 / 2944, doing Culture Club
# Done 584 / 2944, doing Culture Shock
# Done 585 / 2944, doing Curbi
# Done 586 / 2944, doing Current Joys
# Done 587 / 2944, doing Curtis Harding
# Done 588 / 2944, doing Cut CopyDone 589 / 2944, doing Cutting Crew
#
# Done 590 / 2944, doing Cyndi Lauper
# Done 591 / 2944, doing D'Angelo
# Done 592 / 2944, doing DAGames
# Done 593 / 2944, doing DATA
# Done 594 / 2944, doing DC Talk
# Done 595 / 2944, doing DEV
# Done 596 / 2944, doing DEVO
# Done 597 / 2944, doing DIIV
# Done 598 / 2944, doing DJ Khaled
# Done 599 / 2944, doing DJ Mehdi
# Done 600 / 2944, doing DJ Shadow
# Done 601 / 2944, doing DJ Snake
# Done 602 / 2944, doing DNCE
# Done 603 / 2944, doing DVDA
# Done 604 / 2944, doing Da Tweekaz
# Done 605 / 2944, doing Da Vinci's Notebook
# Done 606 / 2944, doing DaBaby
# Done 607 / 2944, doing Daddy Yankee
# Done 608 / 2944, doing Daddy's Groove
# Done 609 / 2944, doing Daft Punk
# Done 610 / 2944, doing Daisuke Ishiwatari
# Done 611 / 2944, doing Dallas Smith
# Done 612 / 2944, doing Dan Croll
# Done 613 / 2944, doing Dan Fogelberg
# Done 614 / 2944, doing Dan Salvato
# Done 615 / 2944, doing Daniel Adams-Ray
# Done 616 / 2944, doing Daniel Boone
# Done 617 / 2944, doing Daniel Caesar
# Done 618 / 2944, doing Daniel Johnston
# Done 619 / 2944, doing Daniel Powter
# Done 620 / 2944, doing Daniela Andrade
# Done 621 / 2944, doing Danny Baranowsky
# Done 622 / 2944, doing Danny Brown
# Done 623 / 2944, doing Danny Elfman
# Done 624 / 2944, doing Danny Howard
# Done 625 / 2944, doing Danny L Harle
# Done 626 / 2944, doing Danny Ocean
# Done 627 / 2944, doing Dario Marianelli
# Done 628 / 2944, doing Darius
# Done 629 / 2944, doing Darren Criss
# Done 630 / 2944, doing Darren Korb
# Done 631 / 2944, doing Darren Styles
# Done 632 / 2944, doing Darude
# Done 633 / 2944, doing Darwin Deez
# Done 634 / 2944, doing Dash Berlin
# Done 635 / 2944, doing Datarock
# Done 636 / 2944, doing Daughter
# Done 637 / 2944, doing Daughtry
# Done 638 / 2944, doing Dave Matthews Band
# Done 639 / 2944, doing Dave Rodgers
# Done 640 / 2944, doing David Archuleta
# Done 641 / 2944, doing David Bowie
# Done 642 / 2944, doing David Gilmour
# Done 643 / 2944, doing David Guetta
# Done 644 / 2944, doing David Lanz
# Done 645 / 2944, doing David Lee Murphy
# Done 646 / 2944, doing David Wise
# Done 647 / 2944, doing Dax Johnson
# Done 648 / 2944, doing Daya
# Done 649 / 2944, doing Days Of The New
# Done 650 / 2944, doing Daze
# Done 651 / 2944, doing De Hofnar
# Done 652 / 2944, doing De Jeugd Van Tegenwoordig
# Done 653 / 2944, doing De La Soul
# Done 654 / 2944, doing De Staat
# Done 655 / 2944, doing Dead Kennedys
# Done 656 / 2944, doing Dead Or Alive
# Done 657 / 2944, doing Deadmau5
# Done 658 / 2944, doing Deadmau5 and Kaskade
# Done 659 / 2944, doing Deafheaven
# Done 660 / 2944, doing Deakin
# Done 661 / 2944, doing Dean Blunt
# Done 662 / 2944, doing Death Cab For Cutie
# Done 663 / 2944, doing Death Cab for Cutie
# Done 664 / 2944, doing Death Grips
# Done 665 / 2944, doing Debbie Gibson
# Done 666 / 2944, doing Declan McKenna
# Done 667 / 2944, doing Deee-Lite
# Done 668 / 2944, doing Deep Blue Something
# Done 669 / 2944, doing Deep Purple
# Done 670 / 2944, doing Deerhunter
# Done 671 / 2944, doing Def Leppard
# Done 672 / 2944, doing Deftones
# Done 673 / 2944, doing Deitrick Haddon
# Done 674 / 2944, doing Del Amitri
# Done 675 / 2944, doing Delain
# Done 676 / 2944, doing Delphic
# Done 677 / 2944, doing Delta Heavy
# Done 678 / 2944, doing Delta Rae
# Done 679 / 2944, doing Demi Lovato
# Done 680 / 2944, doing Denzel Curry
# Done 681 / 2944, doing Deorro
# Done 682 / 2944, doing Depeche Mode
# Done 683 / 2944, doing Derek And The Dominos
# Done 684 / 2944, doing Desireless
# Done 685 / 2944, doing Destiny's Child
# Done 686 / 2944, doing Destroyer
# Done 687 / 2944, doing Detektivbyran
# Done 688 / 2944, doing Dethklok
# Done 689 / 2944, doing Deuce
# Done 690 / 2944, doing Devin Townsend
# Done 691 / 2944, doing Dexys Midnight Runners
# Done 692 / 2944, doing Diana Ross
# Done 693 / 2944, doing Dick Dale
# Done 694 / 2944, doing Diddy
# Done 695 / 2944, doing Dido
# Done 696 / 2944, doing Die Antwoord
# Done 697 / 2944, doing Die Prinzen
# Done 698 / 2944, doing Digitalism
# Done 699 / 2944, doing Dilated Peoples
# Done 700 / 2944, doing Dillon Francis
# Done 701 / 2944, doing Dinka
# Done 702 / 2944, doing Dio
# Done 703 / 2944, doing Dionne Warwick
# Done 704 / 2944, doing Dire Straits
# Done 705 / 2944, doing Dirty Loops
# Done 706 / 2944, doing Dirty Projectors
# Done 707 / 2944, doing Dirty South
# Done 708 / 2944, doing Dirtyloud
# Done 709 / 2944, doing Disasterpeace
# Done 710 / 2944, doing Disclosure
# Done 711 / 2944, doing Dispatch
# Done 712 / 2944, doing Disturbed
# Done 713 / 2944, doing Divine
# Done 714 / 2944, doing Dixie Chicks
# Done 715 / 2944, doing Dizzy Wright
# Done 716 / 2944, doing Dj Sammy
# Done 717 / 2944, doing Django Django
# Done 718 / 2944, doing Dmitri Shostakovich
# Done 719 / 2944, doing Doja Cat
# Done 720 / 2944, doing Dolly Parton
# Done 721 / 2944, doing Dominic Fike
# Done 722 / 2944, doing Don Diablo
# Done 723 / 2944, doing Don Henley
# Done 724 / 2944, doing Don McLean
# Done 725 / 2944, doing Donna Lewis
# Done 726 / 2944, doing Donna Summer
# Done 727 / 2944, doing Donovan
# Done 728 / 2944, doing Doss
# Done 729 / 2944, doing Dover
# Done 730 / 2944, doing Doves
# Done 731 / 2944, doing Dragonette
# Done 732 / 2944, doing Dragonforce
# Done 733 / 2944, doing Drake
# Done 734 / 2944, doing Drake Bell
# Done 735 / 2944, doing Draper
# Done 736 / 2944, doing Drax Project
# Done 737 / 2944, doing Dream
# Done 738 / 2944, doing Dream Theater
# Done 739 / 2944, doing Driftless Pony Club
# Done 740 / 2944, doing Drowning Pool
# Done 741 / 2944, doing Dschinghis Khan
# Done 742 / 2944, doing Dua Lipa
# Done 743 / 2944, doing Dubvision
# Done 744 / 2944, doing Duck Sauce
# Done 745 / 2944, doing Duffy
# Done 746 / 2944, doing Duke Dumont
# Done 747 / 2944, doing Duke Ellington
# Done 748 / 2944, doing Dungen
# Done 749 / 2944, doing Duran Duran
# Done 750 / 2944, doing Dusky
# Done 751 / 2944, doing Duster
# Done 752 / 2944, doing Dustin Kensrue
# Done 753 / 2944, doing Dusty Springfield
# Done 754 / 2944, doing Dwele
# Done 755 / 2944, doing Dylan Scott
# Done 756 / 2944, doing Dzeko and Torres
# Done 757 / 2944, doing E-Type
# Done 758 / 2944, doing EDX
# Done 759 / 2944, doing EGOIST
# Done 760 / 2944, doing EMF
# Done 761 / 2944, doing ERA
# Done 762 / 2944, doing EXO
# Done 763 / 2944, doing Eagles
# Done 764 / 2944, doing Earth
# Done 765 / 2944, doing Ecco2k
# Done 766 / 2944, doing Echosmith
# Done 767 / 2944, doing Ed Sheeran
# Done 768 / 2944, doing Eddie Money
# Done 769 / 2944, doing Edith Piaf
# Done 770 / 2944, doing Editors
# Done 771 / 2944, doing Edvard Grieg
# Done 772 / 2944, doing Edward Maya
# Done 773 / 2944, doing Edward Sharpe and the Magnetic Zeros
# Done 774 / 2944, doing Edwyn Collins
# Done 775 / 2944, doing Eir Aoi
# Done 776 / 2944, doing Eisley
# Done 777 / 2944, doing Elastica
# Done 778 / 2944, doing Electric Guest
# Done 779 / 2944, doing Electric Light Orchestra
# Done 780 / 2944, doing Elektronomia
# Done 781 / 2944, doing Eletric Light Orchestra
# Done 782 / 2944, doing Elis Regina
# Done 783 / 2944, doing Ella Eyre
# Done 784 / 2944, doing Ella Fitzgerald
# Done 785 / 2944, doing Ella Henderson
# Done 786 / 2944, doing Ella Mai
# Done 787 / 2944, doing Ellie Goulding
# Done 788 / 2944, doing Elliott Smith
# Done 789 / 2944, doing Elliphant
# Done 790 / 2944, doing Elmer Bernstein
# Done 791 / 2944, doing Elton John
# Done 792 / 2944, doing Eluveitie
# Done 793 / 2944, doing Elvis Costello
# Done 794 / 2944, doing Elvis Presley
# Done 795 / 2944, doing Emancipator
# Done 796 / 2944, doing Emblem3
# Done 797 / 2944, doing Emeli Sande
# Done 798 / 2944, doing Emiliana Torrini
# Done 799 / 2944, doing Emilie Autumn
# Done 800 / 2944, doing Eminem
# Done 801 / 2944, doing Emma Blackery
# Done 802 / 2944, doing Emma Hewitt
# Done 803 / 2944, doing Empire Of The Sun
# Done 804 / 2944, doing Empire of the Sun
# Done 805 / 2944, doing Empress Of
# Done 806 / 2944, doing En Vogue
# Done 807 / 2944, doing Enigma
# Done 808 / 2944, doing Ennio Morricone
# Done 809 / 2944, doing Enrique Iglesias
# Done 810 / 2944, doing Ensiferum
# Done 811 / 2944, doing Enya
# Done 812 / 2944, doing Epic Mountain
# Done 813 / 2944, doing Epica
# Done 814 / 2944, doing Erasure
# Done 815 / 2944, doing Eric Church
# Done 816 / 2944, doing Eric Clapton
# Done 817 / 2944, doing Eric Hutchinson
# Done 818 / 2944, doing Eric Johnson
# Done 819 / 2944, doing Eric Prydz
# Done 820 / 2944, doing Eric Saade
# Done 821 / 2944, doing Eric Serra
# Done 822 / 2944, doing Eric Whitacre
# Done 823 / 2944, doing Erich Wolfgang Korngold
# Done 824 / 2944, doing Erik Satie
# Done 825 / 2944, doing Erykah Badu
# Done 826 / 2944, doing Esperanza Spalding
# Done 827 / 2944, doing Estelle
# Done 828 / 2944, doing Europe
# Done 829 / 2944, doing Eurythmics
# Done 830 / 2944, doing Eva Cassidy
# Done 831 / 2944, doing Eva Simons
# Done 832 / 2944, doing Evanescence
# Done 833 / 2944, doing Evanescence
# Done 834 / 2944, doing Eve 6
# Done 835 / 2944, doing Evermore
# Done 836 / 2944, doing Everything But The Girl
# Done 837 / 2944, doing Everything But the Girl
# Done 838 / 2944, doing Everything Everything
# Done 839 / 2944, doing Evidence
# Done 840 / 2944, doing Evol Intent
# Done 841 / 2944, doing Excision
# Done 842 / 2944, doing Explosions In The Sky
# Done 843 / 2944, doing Extreme
# Done 844 / 2944, doing FIDLAR
# Done 845 / 2944, doing FKA Twigs
# Done 846 / 2944, doing FKA twigs
# Done 847 / 2944, doing FLOW
# Done 848 / 2944, doing FRENSHIP
# Done 849 / 2944, doing Fabian Mazur
# Done 850 / 2944, doing Face to Face
# Done 851 / 2944, doing Faith Hill
# Done 852 / 2944, doing Faith No More
# Done 853 / 2944, doing Faithless
# Done 854 / 2944, doing Fake Problems
# Done 855 / 2944, doing Falco
# Done 856 / 2944, doing Fall Out Boy
# Done 857 / 2944, doing Falling In Reverse
# Done 858 / 2944, doing Family of the Year
# Done 859 / 2944, doing Fancy
# Done 860 / 2944, doing Fanfarlo
# Done 861 / 2944, doing Far East Movement
# Done 862 / 2944, doing Far Too Loud
# Done 863 / 2944, doing Farruko
# Done 864 / 2944, doing Fast Distance
# Done 865 / 2944, doing Fastball
# Done 866 / 2944, doing Fatboy Slim
# Done 867 / 2944, doing Father John Misty
# Done 868 / 2944, doing Fearofdark
# Done 869 / 2944, doing Feeder
# Done 870 / 2944, doing Feint
# Done 871 / 2944, doing Feist
# Done 872 / 2944, doing Felix Mendelssohn
# Done 873 / 2944, doing Fergie
# Done 874 / 2944, doing Ferry Corsten
# Done 875 / 2944, doing Fever Ray
# Done 876 / 2944, doing Fever the Ghost
# Done 877 / 2944, doing Fiction Family
# Done 878 / 2944, doing FictionJunction YUUKA
# Done 879 / 2944, doing Fifth Harmony
# Done 880 / 2944, doing Filter
# Done 881 / 2944, doing Fine Young Cannibals
# Done 882 / 2944, doing Fiona Apple
# Done 883 / 2944, doing Fitz and The Tantrums
# Done 884 / 2944, doing Fitz and the Tantrums
# Done 885 / 2944, doing Five
# Done 886 / 2944, doing Five For Fighting
# Done 887 / 2944, doing Fkj
# Done 888 / 2944, doing Fleet Foxes
# Done 889 / 2944, doing Fleetwood Mac
# Done 890 / 2944, doing Flight Facilities
# Done 891 / 2944, doing Flo Milli
# Done 892 / 2944, doing Flo Rida
# Done 893 / 2944, doing FloRida
# Done 894 / 2944, doing Flobots
# Done 895 / 2944, doing Florence And The Machine
# Done 896 / 2944, doing Florence and The Machine
# Done 897 / 2944, doing Florence and the Machine
# Done 898 / 2944, doing Florian Picasso
# Done 899 / 2944, doing Florida Georgia Line
# Done 900 / 2944, doing Florrie
# Done 901 / 2944, doing Flume
# Done 902 / 2944, doing Flux Pavilion
# Done 903 / 2944, doing Flying Colors
# Done 904 / 2944, doing Flying Lotus
# Done 905 / 2944, doing Flyleaf
# Done 906 / 2944, doing Foals
# Done 907 / 2944, doing Focus
# Done 908 / 2944, doing Foo Fighters
# Done 909 / 2944, doing Foreigner
# Done 910 / 2944, doing Forever The Sickest Kids
# Done 911 / 2944, doing Former Hero
# Done 912 / 2944, doing Fort Minor
# Done 913 / 2944, doing Foster The People
# Done 914 / 2944, doing Foster the People
# Done 915 / 2944, doing Fountains Of Wayne
# Done 916 / 2944, doing Fountains of Wayne
# Done 917 / 2944, doing Four Tops
# Done 918 / 2944, doing Four Year Strong
# Done 919 / 2944, doing Fox Stevenson
# Done 920 / 2944, doing Foxes
# Done 921 / 2944, doing Foxygen
# Done 922 / 2944, doing Fractal
# Done 923 / 2944, doing Francesca Battistelli
# Done 924 / 2944, doing Francis and the Lights
# Done 925 / 2944, doing Franco Battiato
# Done 926 / 2944, doing Francoise Hardy
# Done 927 / 2944, doing Frank Klepacki
# Done 928 / 2944, doing Frank Ocean
# Done 929 / 2944, doing Frank Sinatra
# Done 930 / 2944, doing Frank Zappa
# Done 931 / 2944, doing FrankJavCee
# Done 932 / 2944, doing Frankie Goes to Hollywood
# Done 933 / 2944, doing Frankie Knuckles
# Done 934 / 2944, doing Frankie Valli
# Done 935 / 2944, doing Franz Ferdinand
# Done 936 / 2944, doing Franz Liszt
# Done 937 / 2944, doing Franz Schubert
# Done 938 / 2944, doing Freddie Hubbard
# Done 939 / 2944, doing Frederic Chopin
# Done 940 / 2944, doing Free
# Done 941 / 2944, doing Freezepop
# Done 942 / 2944, doing French Montana
# Done 943 / 2944, doing Friendly Fires
# Done 944 / 2944, doing Frou Frou
# Done 945 / 2944, doing Fuel
# Done 946 / 2944, doing Fun
# Done 947 / 2944, doing Fusq
# Done 948 / 2944, doing Future
# Done 949 / 2944, doing Future Islands
# Done 950 / 2944, doing G-Eazy
# Done 951 / 2944, doing GLOC-9
# Done 952 / 2944, doing Gabbie Hanna
# Done 953 / 2944, doing Gabby Barrett
# Done 954 / 2944, doing Gabriel Faure
# Done 955 / 2944, doing Gabriel Rios
# Done 956 / 2944, doing Gabriel Yared
# Done 957 / 2944, doing Gabrielle Aplin
# Done 958 / 2944, doing Gackt
# Done 959 / 2944, doing Gal Costa
# Done 960 / 2944, doing Galantis
# Done 961 / 2944, doing Galavant
# Done 962 / 2944, doing Galaxie 500
# Done 963 / 2944, doing Game Freak
# Done 964 / 2944, doing Gamma ray
# Done 965 / 2944, doing Gammer
# Done 966 / 2944, doing Garbage
# Done 967 / 2944, doing Gareth Coker
# Done 968 / 2944, doing Gareth Emery
# Done 969 / 2944, doing Garmiani and Salvatore Ganacci
# Done 970 / 2944, doing Garoad
# Done 971 / 2944, doing Gary Allan
# Done 972 / 2944, doing Gary Moore
# Done 973 / 2944, doing Gary Numan
# Done 974 / 2944, doing Gary Wright
# Done 975 / 2944, doing Gavin DeGraw
# Done 976 / 2944, doing Gemini
# Done 977 / 2944, doing Gene Clark
# Done 978 / 2944, doing Genesis
# Done 979 / 2944, doing Genix
# Done 980 / 2944, doing Geographer
# Done 981 / 2944, doing George Benson
# Done 982 / 2944, doing George Duke
# Done 983 / 2944, doing George Ezra
# Done 984 / 2944, doing George Gershwin
# Done 985 / 2944, doing George Harrison
# Done 986 / 2944, doing George Michael
# Done 987 / 2944, doing George Strait
# Done 988 / 2944, doing Georges Bizet
# Done 989 / 2944, doing Georges Brassens
# Done 990 / 2944, doing Gerry Rafferty
# Done 991 / 2944, doing Gesu no Kiwami Otome
# Done 992 / 2944, doing Ghost
# Done 993 / 2944, doing Gigi D'Agostino
# Done 994 / 2944, doing Gilbert O'Sullivan
# Done 995 / 2944, doing Gilberto Gil
# Done 996 / 2944, doing Gin Blossoms
# Done 997 / 2944, doing Ginuwine
# Done 998 / 2944, doing Gioachino Rossini
# Done 999 / 2944, doing Giorgio Moroder
# Done 1000 / 2944, doing Girl's Day
# Done 1001 / 2944, doing Girls
# Done 1002 / 2944, doing Girls Aloud
# Done 1003 / 2944, doing Girls' Generation
# Done 1004 / 2944, doing Giuseppe Verdi
# Done 1005 / 2944, doing Giveon
# Done 1006 / 2944, doing Glass Animals
# Done 1007 / 2944, doing Glassjaw
# Done 1008 / 2944, doing Glen Campbell
# Done 1009 / 2944, doing Glenn Frey
# Done 1010 / 2944, doing Global Communication
# Done 1011 / 2944, doing Globus
# Done 1012 / 2944, doing Gloria Gaynor
# Done 1013 / 2944, doing Gnarls Barkley
# Done 1014 / 2944, doing Gnash
# Done 1015 / 2944, doing Go West
# Done 1016 / 2944, doing Goblin
# Done 1017 / 2944, doing God is an Astronaut
# Done 1018 / 2944, doing Gold Motel
# Done 1019 / 2944, doing GoldLink
# Done 1020 / 2944, doing Goldfinger
# Done 1021 / 2944, doing Goldfrapp
# Done 1022 / 2944, doing Goldmund
# Done 1023 / 2944, doing Goo Goo Dolls
# Done 1024 / 2944, doing Good Charlotte
# Done 1025 / 2944, doing Gordon Lightfoot
# Done 1026 / 2944, doing Gorgon City
# Done 1027 / 2944, doing Gorillaz
# Done 1028 / 2944, doing Gossip
# Done 1029 / 2944, doing Gotye
# Done 1030 / 2944, doing Graffiti6
# Done 1031 / 2944, doing Gramatik
# Done 1032 / 2944, doing Grandaddy
# Done 1033 / 2944, doing Grant Kirkhope
# Done 1034 / 2944, doing Grateful Dead
# Done 1035 / 2944, doing Green Day
# Done 1036 / 2944, doing Greg Edmonson
# Done 1037 / 2944, doing Greg Laswell
# Done 1038 / 2944, doing Gregory Alan Isakov
# Done 1039 / 2944, doing Grey
# Done 1040 / 2944, doing Grimes
# Done 1041 / 2944, doing Grizzly Bear
# Done 1042 / 2944, doing Groove Armada
# Done 1043 / 2944, doing Grouplove
# Done 1044 / 2944, doing Grum
# Done 1045 / 2944, doing Gryffin
# Done 1046 / 2944, doing Gucci Mane
# Done 1047 / 2944, doing Guided By Voices
# Done 1048 / 2944, doing Guillemots
# Done 1049 / 2944, doing Guns N' Roses
# Done 1050 / 2944, doing Gustav Holst
# Done 1051 / 2944, doing Gustavo Santaolalla
# Done 1052 / 2944, doing Guster
# Done 1053 / 2944, doing Gwen Stefani
# Done 1054 / 2944, doing Gyllene Tider
# Done 1055 / 2944, doing Gym Class Heroes
# Done 1056 / 2944, doing HARDY
# Done 1057 / 2944, doing HOME
# Done 1058 / 2944, doing Haddaway
# Done 1059 / 2944, doing Haim
# Done 1060 / 2944, doing Haken
# Done 1061 / 2944, doing Halsey
# Done 1062 / 2944, doing Hammock
# Done 1063 / 2944, doing Hank Green
# Done 1064 / 2944, doing Hank Williams Sr
# Done 1065 / 2944, doing Hannah Diamond
# Done 1066 / 2944, doing Hans Zimmer
# Done 1067 / 2944, doing Hanson
# Done 1068 / 2944, doing Hardwell
# Done 1069 / 2944, doing Harpo
# Done 1070 / 2944, doing Harry Chapin
# Done 1071 / 2944, doing Harry Gregson-Williams
# Done 1072 / 2944, doing Harry Nilsson
# Done 1073 / 2944, doing Harry Styles
# Done 1074 / 2944, doing Harvey Danger
# Done 1075 / 2944, doing Have a Nice Life
# Done 1076 / 2944, doing Hayden James
# Done 1077 / 2944, doing Haywyre
# Done 1078 / 2944, doing Headhunterz
# Done 1079 / 2944, doing Heart
# Done 1080 / 2944, doing Heatbeat
# Done 1081 / 2944, doing Heaven 17
# Done 1082 / 2944, doing Hefner
# Done 1083 / 2944, doing Hellberg
# Done 1084 / 2944, doing Helloween
# Done 1085 / 2944, doing Hem
# Done 1086 / 2944, doing Henry Jackman
# Done 1087 / 2944, doing Henry Mancini
# Done 1088 / 2944, doing Henry Purcell
# Done 1089 / 2944, doing Herbert Gronemeyer
# Done 1090 / 2944, doing Herbie Hancock
# Done 1091 / 2944, doing Herman's Hermits
# Done 1092 / 2944, doing Hey Violet
# Done 1093 / 2944, doing Hiatus Kaiyote
# Done 1094 / 2944, doing Hideki Naganuma
# Done 1095 / 2944, doing Hieroglyphics
# Done 1096 / 2944, doing High School Musical
# Done 1097 / 2944, doing Hilary Duff
# Done 1098 / 2944, doing Hinder
# Done 1099 / 2944, doing Hinds
# Done 1100 / 2944, doing Hitoshi Sakimoto
# Done 1101 / 2944, doing Hixxy
# Done 1102 / 2944, doing Hoagy Carmichael
# Done 1103 / 2944, doing Hocus Pocus
# Done 1104 / 2944, doing Hoku
# Done 1105 / 2944, doing Hole
# Done 1106 / 2944, doing Holly Herndon
# Done 1107 / 2944, doing Hollywood Undead
# Done 1108 / 2944, doing Home
# Done 1109 / 2944, doing Homestuck
# Done 1110 / 2944, doing Hoobastank
# Done 1111 / 2944, doing Hoodie Allen
# Done 1112 / 2944, doing Hook n Sling
# Done 1113 / 2944, doing Hop Along
# Done 1114 / 2944, doing Hot Chelle Rae
# Done 1115 / 2944, doing Hot Chip
# Done 1116 / 2944, doing Hot Sugar
# Done 1117 / 2944, doing Houndmouth
# Done 1118 / 2944, doing Howard Drossin
# Done 1119 / 2944, doing Howard Shore
# Done 1120 / 2944, doing Hozier
# Done 1121 / 2944, doing Hudson Mohawke
# Done 1122 / 2944, doing Hunter Hayes
# Done 1123 / 2944, doing Hurts
# Done 1124 / 2944, doing Hyper Potions
# Done 1125 / 2944, doing I Am Oak
# Done 1126 / 2944, doing I DONT KNOW HOW BUT THEY FOUND ME
# Done 1127 / 2944, doing IDA
# Done 1128 / 2944, doing IDLES
# Done 1129 / 2944, doing INXS
# Done 1130 / 2944, doing IOSYS
# Done 1131 / 2944, doing IQ
# Done 1132 / 2944, doing ITZY
# Done 1133 / 2944, doing IU
# Done 1134 / 2944, doing Ian van Dahl
# Done 1135 / 2944, doing Ice Cube
# Done 1136 / 2944, doing Ichiko Aoba
# Done 1137 / 2944, doing Icon for Hire
# Done 1138 / 2944, doing Icona Pop
# Done 1139 / 2944, doing Ida Maria
# Done 1140 / 2944, doing Idina Menzel
# Done 1141 / 2944, doing Iggy Azalea
# Done 1142 / 2944, doing Iggy Pop
# Done 1143 / 2944, doing Igor Stravinsky
# Done 1144 / 2944, doing Ikimono-gakari
# Done 1145 / 2944, doing Ilan Eshkeri
# Done 1146 / 2944, doing Illenium
# Done 1147 / 2944, doing Imagine Dragons
# Done 1148 / 2944, doing Imogen Heap
# Done 1149 / 2944, doing In Flames
# Done 1150 / 2944, doing In This Moment
# Done 1151 / 2944, doing Incubus
# Done 1152 / 2944, doing Indigo Girls
# Done 1153 / 2944, doing Infected Mushroom
# Done 1154 / 2944, doing Ingrid Michaelson
# Done 1155 / 2944, doing Injury Reserve
# Done 1156 / 2944, doing Inkyz
# Done 1157 / 2944, doing Inna
# Done 1158 / 2944, doing Inner City
# Done 1159 / 2944, doing Inon Zur
# Done 1160 / 2944, doing Insan3Lik3
# Done 1161 / 2944, doing Interpol
# Done 1162 / 2944, doing Irene Cara
# Done 1163 / 2944, doing Iron Butterfly
# Done 1164 / 2944, doing Iron Maiden
# Done 1165 / 2944, doing ItaloBrothers
# Done 1166 / 2944, doing Ivy
# Done 1167 / 2944, doing Iyaz
# Done 1168 / 2944, doing J Alvarez
# Done 1169 / 2944, doing J Balvin
# Done 1170 / 2944, doing J Dilla
# Done 1171 / 2944, doing JAHKOY
# Done 1172 / 2944, doing JAM Project
# Done 1173 / 2944, doing JJ Lin
# Done 1174 / 2944, doing JJ Project
# Done 1175 / 2944, doing JJAMZ
# Done 1176 / 2944, doing JP Cooper
# Done 1177 / 2944, doing JT Music
# Done 1178 / 2944, doing Jace Everett
# Done 1179 / 2944, doing Jack Conte
# Done 1180 / 2944, doing Jack Garratt
# Done 1181 / 2944, doing Jack Harlow
# Done 1182 / 2944, doing Jack Johnson
# Done 1183 / 2944, doing Jack Stauber
# Done 1184 / 2944, doing Jack U
# Done 1185 / 2944, doing Jack Wall
# Done 1186 / 2944, doing Jack White
# Done 1187 / 2944, doing JackLNDN
# Done 1188 / 2944, doing Jackson 5
# Done 1189 / 2944, doing Jackson Browne
# Done 1190 / 2944, doing Jai Paul
# Done 1191 / 2944, doing Jain
# Done 1192 / 2944, doing Jake Bugg
# Done 1193 / 2944, doing Jake Kaufman
# Done 1194 / 2944, doing Jakob Liedholm
# Done 1195 / 2944, doing James Arthur
# Done 1196 / 2944, doing James Bay
# Done 1197 / 2944, doing James Blake
# Done 1198 / 2944, doing James Blunt
# Done 1199 / 2944, doing James Brown
# Done 1200 / 2944, doing James Egbert
# Done 1201 / 2944, doing James Gang
# Done 1202 / 2944, doing James Horner
# Done 1203 / 2944, doing James Ingram
# Done 1204 / 2944, doing James Newton Howard
# Done 1205 / 2944, doing James Taylor
# Done 1206 / 2944, doing Jamie Cullum
# Done 1207 / 2944, doing Jamie Lynn Spears
# Done 1208 / 2944, doing Jamie Woon
# Done 1209 / 2944, doing Jamie xx
# Done 1210 / 2944, doing Jamiroquai
# Done 1211 / 2944, doing Jan Hammer
# Done 1212 / 2944, doing Jane's Addiction
# Done 1213 / 2944, doing Janelle Monae
# Done 1214 / 2944, doing Janet Jackson
# Done 1215 / 2944, doing Janis Ian
# Done 1216 / 2944, doing Janis Joplin
# Done 1217 / 2944, doing Japanese Breakfast
# Done 1218 / 2944, doing Jaron
# Done 1219 / 2944, doing Jars Of Clay
# Done 1220 / 2944, doing Jason Aldean
# Done 1221 / 2944, doing Jason Becker
# Done 1222 / 2944, doing Jason Derulo
# Done 1223 / 2944, doing Jason Mraz
# Done 1224 / 2944, doing Jason Robert Brown
# Done 1225 / 2944, doing Jax Jones
# Done 1226 / 2944, doing Jay Chou
# Done 1227 / 2944, doing Jay Electronica
# Done 1228 / 2944, doing Jay Hardway
# Done 1229 / 2944, doing Jay Sean
# Done 1230 / 2944, doing Jay-Z
# Done 1231 / 2944, doing Jaymes Young
# Done 1232 / 2944, doing Jaytech
# Done 1233 / 2944, doing Jazmine Sullivan
# Done 1234 / 2944, doing Jean Elan
# Done 1235 / 2944, doing Jean Grae
# Done 1236 / 2944, doing Jean Sibelius
# Done 1237 / 2944, doing Jebediah
# Done 1238 / 2944, doing Jeff Buckley
# Done 1239 / 2944, doing Jeff Lorber
# Done 1240 / 2944, doing Jefferson Airplane
# Done 1241 / 2944, doing Jelly Roll Morton
# Done 1242 / 2944, doing Jennifer Lopez
# Done 1243 / 2944, doing Jenny Owen Youngs
# Done 1244 / 2944, doing Jens Lekman
# Done 1245 / 2944, doing Jeremih
# Done 1246 / 2944, doing Jeremy Blake
# Done 1247 / 2944, doing Jeremy Soule
# Done 1248 / 2944, doing Jerome Isma-Ae
# Done 1249 / 2944, doing Jerry Goldsmith
# Done 1250 / 2944, doing Jerry Lee Lewis
# Done 1251 / 2944, doing Jerry Paper
# Done 1252 / 2944, doing Jerry Wallace
# Done 1253 / 2944, doing Jess Glynne
# Done 1254 / 2944, doing Jesse McCartney
# Done 1255 / 2944, doing Jessica Lea Mayfield
# Done 1256 / 2944, doing Jessica Pratt
# Done 1257 / 2944, doing Jessica Simpson
# Done 1258 / 2944, doing Jessie J
# Done 1259 / 2944, doing Jessie Ware
# Done 1260 / 2944, doing Jet
# Done 1261 / 2944, doing Jethro Tull
# Done 1262 / 2944, doing Jewel
# Done 1263 / 2944, doing Jill Scott
# Done 1264 / 2944, doing Jim Croce
# Done 1265 / 2944, doing Jimi Hendrix
# Done 1266 / 2944, doing Jimmie Allen
# Done 1267 / 2944, doing Jimmy Barnes
# Done 1268 / 2944, doing Jimmy Buffett
# Done 1269 / 2944, doing Jimmy Eat World
# Done 1270 / 2944, doing Jo Dee Messina
# Done 1271 / 2944, doing Joan Baez
# Done 1272 / 2944, doing Joan Jett
# Done 1273 / 2944, doing Joan Osborne
# Done 1274 / 2944, doing Joanna Newsom
# Done 1275 / 2944, doing Jockstrap
# Done 1276 / 2944, doing Joe Cocker
# Done 1277 / 2944, doing Joe Hisaishi
# Done 1278 / 2944, doing Joe Jackson
# Done 1279 / 2944, doing Joe Satriani
# Done 1280 / 2944, doing Johann Pachelbel
# Done 1281 / 2944, doing Johann Sebastian Bach
# Done 1282 / 2944, doing Johann Strauss II
# Done 1283 / 2944, doing Johannes Brahms
# Done 1284 / 2944, doing John Barry
# Done 1285 / 2944, doing John Cage
# Done 1286 / 2944, doing John Cale
# Done 1287 / 2944, doing John Carpenter
# Done 1288 / 2944, doing John Coltrane
# Done 1289 / 2944, doing John Dahlback
# Done 1290 / 2944, doing John Denver
# Done 1291 / 2944, doing John Farnham
# Done 1292 / 2944, doing John Frusciante
# Done 1293 / 2944, doing John Grant
# Done 1294 / 2944, doing John Hiatt
# Done 1295 / 2944, doing John Legend
# Done 1296 / 2944, doing John Lennon
# Done 1297 / 2944, doing John Martin
# Done 1298 / 2944, doing John Maus
# Done 1299 / 2944, doing John Mayer
# Done 1300 / 2944, doing John Mellencamp
# Done 1301 / 2944, doing John Michael Montgomery
# Done 1302 / 2944, doing John Murphy
# Done 1303 / 2944, doing John Newman
# Done 1304 / 2944, doing John Powell
# Done 1305 / 2944, doing John Williams
# Done 1306 / 2944, doing Johnny Cash
# Done 1307 / 2944, doing Johnny Hates Jazz
# Done 1308 / 2944, doing Joji
# Done 1309 / 2944, doing Jojo
# Done 1310 / 2944, doing Jon Bellion
# Done 1311 / 2944, doing Jon Brion
# Done 1312 / 2944, doing Jon Foreman
# Done 1313 / 2944, doing Jon Hopkins
# Done 1314 / 2944, doing Jon Lajoie
# Done 1315 / 2944, doing Jon Schmidt
# Done 1316 / 2944, doing Jonas Blue
# Done 1317 / 2944, doing Jonas Brothers
# Done 1318 / 2944, doing Jonathan Coulton
# Done 1319 / 2944, doing Jonathan Larson
# Done 1320 / 2944, doing Jonathan Young
# Done 1321 / 2944, doing Joni Mitchell
# Done 1322 / 2944, doing Jonny Greenwood
# Done 1323 / 2944, doing Jordan Davis
# Done 1324 / 2944, doing Jordan Rakei
# Done 1325 / 2944, doing Jordan Rudess
# Done 1326 / 2944, doing Jordin Sparks
# Done 1327 / 2944, doing Jorge Ben
# Done 1328 / 2944, doing Jorja Smith
# Done 1329 / 2944, doing Jorn Van Deynhoven
# Done 1330 / 2944, doing Jose James
# Done 1331 / 2944, doing Josh Groban
# Done 1332 / 2944, doing Josh Pyke
# Done 1333 / 2944, doing Joshua Redman
# Done 1334 / 2944, doing Journey
# Done 1335 / 2944, doing Joy Division
# Done 1336 / 2944, doing Juanes
# Done 1337 / 2944, doing Judas Priest
# Done 1338 / 2944, doing Judee Sill
# Done 1339 / 2944, doing Judy Garland
# Done 1340 / 2944, doing Judy and Mary
# Done 1341 / 2944, doing Juice WRLD
# Done 1342 / 2944, doing Jukebox the Ghost
# Done 1343 / 2944, doing Jukio Kallio
# Done 1344 / 2944, doing Julee Cruise
# Done 1345 / 2944, doing Julia Holter
# Done 1346 / 2944, doing Julia Michaels
# Done 1347 / 2944, doing Julian Casablancas
# Done 1348 / 2944, doing Julie Andrews
# Done 1349 / 2944, doing Julieta Venegas
# Done 1350 / 2944, doing Jump5
# Done 1351 / 2944, doing Jun Senoue
# Done 1352 / 2944, doing Jungle
# Done 1353 / 2944, doing Junior Boys
# Done 1354 / 2944, doing Junior Senior
# Done 1355 / 2944, doing Justice
# Done 1356 / 2944, doing Justin Bieber
# Done 1357 / 2944, doing Justin Moore
# Done 1358 / 2944, doing Justin Quiles
# Done 1359 / 2944, doing Justin Timberlake
# ...
# Done 2504 / 2944, doing The Cinematics
# Done 2505 / 2944, doing The Clash
# Done 2506 / 2944, doing The Connells
# Done 2507 / 2944, doing The Contours
# Done 2508 / 2944, doing The Coral
# Done 2509 / 2944, doing The Correspondents
# Done 2510 / 2944, doing The Cranberries
# Done 2511 / 2944, doing The Cribs
# Done 2512 / 2944, doing The Crystal Method
# Done 2513 / 2944, doing The Cure
# Done 2514 / 2944, doing The Darkness
# Done 2515 / 2944, doing The Dave Brubeck Quartet
# Done 2516 / 2944, doing The Dear Hunter
# Done 2517 / 2944, doing The Decemberists
# Done 2518 / 2944, doing The Dismemberment Plan
# Done 2519 / 2944, doing The Ditty Bops
# Done 2520 / 2944, doing The Divine Comedy
# Done 2521 / 2944, doing The Doobie Brothers
# Done 2522 / 2944, doing The Doors
# Done 2523 / 2944, doing The Downtown Fiction
# Done 2524 / 2944, doing The Drifters
# Done 2525 / 2944, doing The Drums
# Done 2526 / 2944, doing The Dubliners
# Done 2527 / 2944, doing The Durutti Column
# Done 2528 / 2944, doing The Emotions
# Done 2529 / 2944, doing The Flaming Lips
# Done 2530 / 2944, doing The Flower Kings
# Done 2531 / 2944, doing The Foundations
# Done 2532 / 2944, doing The Four Seasons
# Done 2533 / 2944, doing The Fratellis
# Done 2534 / 2944, doing The Fray
# Done 2535 / 2944, doing The Front Bottoms
# Done 2536 / 2944, doing The Gap Band
# Done 2537 / 2944, doing The Gaslight Anthem
# Done 2538 / 2944, doing The Glitch Mob
# Done 2539 / 2944, doing The Go-Go's
# Done 2540 / 2944, doing The Gregory Brothers
# Done 2541 / 2944, doing The Griswolds
# Done 2542 / 2944, doing The Guess Who
# Done 2543 / 2944, doing The Head and The Heart
# Done 2544 / 2944, doing The Heavy
# Done 2545 / 2944, doing The Hollies
# Done 2546 / 2944, doing The Honeysticks
# Done 2547 / 2944, doing The Horrible Crowes
# Done 2548 / 2944, doing The Hotelier
# Done 2549 / 2944, doing The Human League
# Done 2550 / 2944, doing The Hush Sound
# Done 2551 / 2944, doing The Ink Spots
# Done 2552 / 2944, doing The Internet
# Done 2553 / 2944, doing The Isley Brothers
# Done 2554 / 2944, doing The Jam
# Done 2555 / 2944, doing The Japanese House
# Done 2556 / 2944, doing The Kid LAROI
# Done 2557 / 2944, doing The Kid Laroi
# Done 2558 / 2944, doing The Killers
# Done 2559 / 2944, doing The Kills
# Done 2560 / 2944, doing The Kinks
# Done 2561 / 2944, doing The Knack
# Done 2562 / 2944, doing The Knife
# Done 2563 / 2944, doing The Kooks
# Done 2564 / 2944, doing The La's
# Done 2565 / 2944, doing The Last Shadow Puppets
# Done 2566 / 2944, doing The Libertines
# Done 2567 / 2944, doing The Living End
# Done 2568 / 2944, doing The Living Tombstone
# Done 2569 / 2944, doing The Lonely Island
# Done 2570 / 2944, doing The Lovin' Spoonful
# Done 2571 / 2944, doing The Lumineers
# Done 2572 / 2944, doing The Lumineers
# Done 2573 / 2944, doing The M Machine
# Done 2574 / 2944, doing The Maccabees
# Done 2575 / 2944, doing The Magnetic Fields
# Done 2576 / 2944, doing The Matches
# Done 2577 / 2944, doing The Meters
# Done 2578 / 2944, doing The Microphones
# Done 2579 / 2944, doing The Middle East
# Done 2580 / 2944, doing The Mighty Mighty Bosstones
# Done 2581 / 2944, doing The Modern Lovers
# Done 2582 / 2944, doing The Moldy Peaches
# Done 2583 / 2944, doing The Monkees
# Done 2584 / 2944, doing The Moody Blues
# Done 2585 / 2944, doing The Move
# Done 2586 / 2944, doing The Mowgli's
# Done 2587 / 2944, doing The Muffs
# Done 2588 / 2944, doing The Muppets
# Done 2589 / 2944, doing The Naked And Famous
# Done 2590 / 2944, doing The Naked and Famous
# Done 2591 / 2944, doing The National
# Done 2592 / 2944, doing The Neighbourhood
# Done 2593 / 2944, doing The New Pornographers
# Done 2594 / 2944, doing The Offspring
# Done 2595 / 2944, doing The Oh Hellos
# Done 2596 / 2944, doing The Original Caste
# Done 2597 / 2944, doing The Outfield
# Done 2598 / 2944, doing The Paper Kites
# Done 2599 / 2944, doing The Partridge Family
# Done 2600 / 2944, doing The Penguins
# Done 2601 / 2944, doing The Platters
# Done 2602 / 2944, doing The Pogues
# Done 2603 / 2944, doing The Pointer Sisters
# Done 2604 / 2944, doing The Police
# Done 2605 / 2944, doing The Polyphonic Spree
# Done 2606 / 2944, doing The Postal Service
# Done 2607 / 2944, doing The Presets
# Done 2608 / 2944, doing The Pretty Reckless
# Done 2609 / 2944, doing The Proclaimers
# Done 2610 / 2944, doing The Prodigy
# Done 2611 / 2944, doing The Protomen
# Done 2612 / 2944, doing The Psychedelic Furs
# Done 2613 / 2944, doing The Raconteurs
# Done 2614 / 2944, doing The Rasmus
# Done 2615 / 2944, doing The Replacements
# Done 2616 / 2944, doing The Rolling Stones
# Done 2617 / 2944, doing The Ronettes
# Done 2618 / 2944, doing The Roots
# Done 2619 / 2944, doing The Royal Concept
# Done 2620 / 2944, doing The Script
# Done 2621 / 2944, doing The Seatbelts
# Done 2622 / 2944, doing The Shangri-Las
# Done 2623 / 2944, doing The Shins
# Done 2624 / 2944, doing The Smashing Pumpkins
# Done 2625 / 2944, doing The Smiths
# Done 2626 / 2944, doing The Spill Canvas
# Done 2627 / 2944, doing The Spinners
# Done 2628 / 2944, doing The Stone Roses
# Done 2629 / 2944, doing The Stooges
# Done 2630 / 2944, doing The Stranglers
# Done 2631 / 2944, doing The Streets
# Done 2632 / 2944, doing The Strokes
# Done 2633 / 2944, doing The Stylistics
# Done 2634 / 2944, doing The Sundays
# Done 2635 / 2944, doing The Supremes
# Done 2636 / 2944, doing The Tallest Man On Earth
# Done 2637 / 2944, doing The Tallest Man on Earth
# Done 2638 / 2944, doing The Temper Trap
# Done 2639 / 2944, doing The Temptations
# Done 2640 / 2944, doing The The
# Done 2641 / 2944, doing The Trammps
# Done 2642 / 2944, doing The Troggs
# Done 2643 / 2944, doing The Turtles
# Done 2644 / 2944, doing The United States of America
# Done 2645 / 2944, doing The Velvet Underground
# Done 2646 / 2944, doing The Veronicas
# Done 2647 / 2944, doing The Verve
# Done 2648 / 2944, doing The Vines
# Done 2649 / 2944, doing The Voidz
# Done 2650 / 2944, doing The Waifs
# Done 2651 / 2944, doing The Wailers
# Done 2652 / 2944, doing The Wallflowers
# Done 2653 / 2944, doing The Wanted
# Done 2654 / 2944, doing The Weather Girls
# Done 2655 / 2944, doing The Weeknd
# Done 2656 / 2944, doing The Weepies
# Done 2657 / 2944, doing The White Stripes
# Done 2658 / 2944, doing The Whitest Boy Alive
# Done 2659 / 2944, doing The Who
# Done 2660 / 2944, doing The Wombats
# Done 2661 / 2944, doing The Wonders
# Done 2662 / 2944, doing The Wreckers
# Done 2663 / 2944, doing The Zombies
# Done 2664 / 2944, doing The verve
# Done 2665 / 2944, doing The xx
# Done 2666 / 2944, doing TheFatRat
# Done 2667 / 2944, doing Theatre of Tragedy
# Done 2668 / 2944, doing Thee Oh Sees
# Done 2669 / 2944, doing Theory of a Deadman
# Done 2670 / 2944, doing These New Puritans
# Done 2671 / 2944, doing They Might Be Giants
# Done 2672 / 2944, doing Third Eye Blind
# Done 2673 / 2944, doing This Town Needs Guns
# Done 2674 / 2944, doing Thom Yorke
# Done 2675 / 2944, doing Thomas Bangalter
# Done 2676 / 2944, doing Thomas Bergersen
# Done 2677 / 2944, doing Thomas Newman
# Done 2678 / 2944, doing Thomas Newson
# Done 2679 / 2944, doing Thomas Rhett
# Done 2680 / 2944, doing Thompson Square
# Done 2681 / 2944, doing Thousand Foot Krutch
# Done 2682 / 2944, doing Three Days Grace
# Done 2683 / 2944, doing Three Dog Night
# Done 2684 / 2944, doing Thrice
# Done 2685 / 2944, doing Thundercat
# Done 2686 / 2944, doing Thursday
# Done 2687 / 2944, doing Tiesto
# Done 2688 / 2944, doing Tiffany
# Done 2689 / 2944, doing Tiga
# Done 2690 / 2944, doing Tiggy
# Done 2691 / 2944, doing Tim Berg
# Done 2692 / 2944, doing Tim McGraw
# Done 2693 / 2944, doing Tim Minchin
# Done 2694 / 2944, doing Tim and Eric
# Done 2695 / 2944, doing Timbaland
# Done 2696 / 2944, doing Timeflies
# Done 2697 / 2944, doing Tina Turner
# Done 2698 / 2944, doing Tinashe
# Done 2699 / 2944, doing Tindersticks
# Done 2700 / 2944, doing Tiny Moving Parts
# Done 2701 / 2944, doing Titas
# Done 2702 / 2944, doing Tkay Maidza
# Done 2703 / 2944, doing Toad the Wet Sprocket
# Done 2704 / 2944, doing Tobi Lou
# Done 2705 / 2944, doing Tobu
# Done 2706 / 2944, doing Toby Keith
# Done 2707 / 2944, doing Todd Rundgren
# Done 2708 / 2944, doing Todd Terje
# Done 2709 / 2944, doing Tokyo Machine
# Done 2710 / 2944, doing Tokyo Police Club
# Done 2711 / 2944, doing Tom Cochrane
# Done 2712 / 2944, doing Tom Fall
# Done 2713 / 2944, doing Tom Jones
# Done 2714 / 2944, doing Tom Lehrer
# Done 2715 / 2944, doing Tom Misch
# Done 2716 / 2944, doing Tom Odell
# Done 2717 / 2944, doing Tom Petty
# Done 2718 / 2944, doing Tom Petty And The Heartbreakers
# Done 2719 / 2944, doing Tom Petty and the Heartbreakers
# Done 2720 / 2944, doing Tom Swoon
# Done 2721 / 2944, doing Tom Tom Club
# Done 2722 / 2944, doing Tom Waits
# Done 2723 / 2944, doing Tommy Roe
# Done 2724 / 2944, doing Tommy Sparks
# Done 2725 / 2944, doing Tones And I
# Done 2726 / 2944, doing Toni Basil
# Done 2727 / 2944, doing Toni Braxton
# Done 2728 / 2944, doing Tool
# Done 2729 / 2944, doing Tori Kelly
# Done 2730 / 2944, doing Toro Y Moi
# Done 2731 / 2944, doing Toro y Moi
# Done 2732 / 2944, doing Toto
# Done 2733 / 2944, doing Tove Lo
# Done 2734 / 2944, doing Traffic
# Done 2735 / 2944, doing Train
# Done 2736 / 2944, doing Transatlantic
# Done 2737 / 2944, doing Traveling Wilburys
# Done 2738 / 2944, doing Travie McCoy
# Done 2739 / 2944, doing Travis
# Done 2740 / 2944, doing Travis Scott
# Done 2741 / 2944, doing Trio
# Done 2742 / 2944, doing Trippie Redd
# Done 2743 / 2944, doing Tristam
# Done 2744 / 2944, doing Tristam and Braken
# Done 2745 / 2944, doing Tritonal
# Done 2746 / 2944, doing Troye Sivan
# Done 2747 / 2944, doing Trust
# Done 2748 / 2944, doing Tubeway Army
# Done 2749 / 2944, doing Tuxedomoon
# Done 2750 / 2944, doing Twenty One Pilots
# Done 2751 / 2944, doing Twin Atlantic
# Done 2752 / 2944, doing Twisted Sister
# Done 2753 / 2944, doing Two Door CInema Club
# Done 2754 / 2944, doing Two Door Cinema Club
# Done 2755 / 2944, doing Two Feet
# Done 2756 / 2944, doing Two Steps From Hell
# Done 2757 / 2944, doing Two Steps from Hell
# Done 2758 / 2944, doing TwoThirds
# Done 2759 / 2944, doing TyDi
# Done 2760 / 2944, doing Tycho
# Done 2761 / 2944, doing Tyler Bates
# Done 2762 / 2944, doing Tyler Shaw
# Done 2763 / 2944, doing Tyr
# Done 2764 / 2944, doing U2
# Done 2765 / 2944, doing UB40
# Done 2766 / 2944, doing UFO
# Done 2767 / 2944, doing UNKLE
# Done 2768 / 2944, doing Uffie
# Done 2769 / 2944, doing Ultravox
# Done 2770 / 2944, doing Underscores
# Done 2771 / 2944, doing Underworld
# Done 2772 / 2944, doing Unknown Brain
# Done 2773 / 2944, doing Unknown Mortal Orchestra
# Done 2774 / 2944, doing Unwound
# Done 2775 / 2944, doing Unwritten Law
# Done 2776 / 2944, doing Usher
# Done 2777 / 2944, doing VULFPECK
# Done 2778 / 2944, doing Valve
# Done 2779 / 2944, doing Vampire Weekend
# Done 2780 / 2944, doing Van Halen
# Done 2781 / 2944, doing Van Morrison
# Done 2782 / 2944, doing Vance Joy
# Done 2783 / 2944, doing Vanessa Carlton
# Done 2784 / 2944, doing Vanessa Hudgens
# Done 2785 / 2944, doing Vangelis
# Done 2786 / 2944, doing Vanguart
# Done 2787 / 2944, doing Varien
# Done 2788 / 2944, doing Vashti Bunyan
# Done 2789 / 2944, doing Vaya Con Dios
# Done 2790 / 2944, doing Vengaboys
# Done 2791 / 2944, doing Veronica Maggio
# Done 2792 / 2944, doing Vertical Horizon
# Done 2793 / 2944, doing Vicetone
# Done 2794 / 2944, doing Victoria Justice
# Done 2795 / 2944, doing Vienna Teng
# Done 2796 / 2944, doing Village People
# Done 2797 / 2944, doing Villagers
# Done 2798 / 2944, doing Violent Soho
# Done 2799 / 2944, doing Virtual Riot
# Done 2800 / 2944, doing Vitamin C
# Done 2801 / 2944, doing Voltaire
# Done 2802 / 2944, doing Vulfpeck
# Done 2803 / 2944, doing WALK THE MOON
# Done 2804 / 2944, doing WRLD
# Done 2805 / 2944, doing Waka Flocka Flame
# Done 2806 / 2944, doing Walden
# Done 2807 / 2944, doing Wale
# Done 2808 / 2944, doing Walk The Moon
# Done 2809 / 2944, doing Walk off the Earth
# Done 2810 / 2944, doing Walker Hayes
# Done 2811 / 2944, doing Wang Chung
# Done 2812 / 2944, doing Warpaint
# Done 2813 / 2944, doing Warrant
# Done 2814 / 2944, doing Warren Zevon
# Done 2815 / 2944, doing Washed Out
# Done 2816 / 2944, doing Waterflame
# Done 2817 / 2944, doing Wave Racer
# Done 2818 / 2944, doing Wavves
# Done 2819 / 2944, doing We Are Scientists
# Done 2820 / 2944, doing We Were Evergreen
# Done 2821 / 2944, doing We the Kings
# Done 2822 / 2944, doing Weather Report
# Done 2823 / 2944, doing Ween
# Done 2824 / 2944, doing Weezer
# Done 2825 / 2944, doing Weird Al Yankovic
# Done 2826 / 2944, doing Westlife
# Done 2827 / 2944, doing Weyes Blood
# Done 2828 / 2944, doing What A Day
# Done 2829 / 2944, doing Wheatus
# Done 2830 / 2944, doing White Town
# Done 2831 / 2944, doing Whitesnake
# Done 2832 / 2944, doing Whitney Houston
# Done 2833 / 2944, doing Wilbur
# Done 2834 / 2944, doing Wilbur Soot
# Done 2835 / 2944, doing Wilco
# Done 2836 / 2944, doing Wild Nothing
# Done 2837 / 2944, doing Will Young
# Done 2838 / 2944, doing Willie Nelson
# Done 2839 / 2944, doing Wilson Phillips
# Done 2840 / 2944, doing Wings
# Done 2841 / 2944, doing Wire
# Done 2842 / 2944, doing Wise Guys
# Done 2843 / 2944, doing Within Temptation
# Done 2844 / 2944, doing Wiz Khalifa
# Done 2845 / 2944, doing Wolf Alice
# Done 2846 / 2944, doing Wolfgang Amadeus Mozart
# Done 2847 / 2944, doing Wolfgang Gartner
# Done 2848 / 2944, doing Women
# Done 2849 / 2944, doing Woody Guthrie
# Done 2850 / 2944, doing Wretch 32
# Done 2851 / 2944, doing Wu-Tang Clan
# Done 2852 / 2944, doing Wyclef Jean
# Done 2853 / 2944, doing X Ambassadors
# Done 2854 / 2944, doing XTC
# Done 2855 / 2944, doing XXXTENTACION
# Done 2856 / 2944, doing Xilent
# Done 2857 / 2944, doing YNW Melly
# Done 2858 / 2944, doing YUKI
# Done 2859 / 2944, doing Yael Naim
# Done 2860 / 2944, doing Yandel
# Done 2861 / 2944, doing Yann Tiersen
# Done 2862 / 2944, doing Yanni
# Done 2863 / 2944, doing Yasunori Mitsuda
# Done 2864 / 2944, doing Yasunori Nishiki
# Done 2865 / 2944, doing Yeah Yeah Yeahs
# Done 2866 / 2944, doing Yeasayer
# Done 2867 / 2944, doing Yelle
# Done 2868 / 2944, doing Yellow Magic Orchestra
# Done 2869 / 2944, doing Yellowcard
# Done 2870 / 2944, doing Yes
# Done 2871 / 2944, doing Yeule
# Done 2872 / 2944, doing Yevgueni
# Done 2873 / 2944, doing Yiruma
# Done 2874 / 2944, doing Ylvis
# Done 2875 / 2944, doing Yo La Tengo
# Done 2876 / 2944, doing Yoko Kanno
# Done 2877 / 2944, doing Yoko Shimomura
# Done 2878 / 2944, doing Yolanda Adams
# Done 2879 / 2944, doing Yoshida Brothers
# Done 2880 / 2944, doing You Am I
# Done 2881 / 2944, doing Young the Giant
# Done 2882 / 2944, doing Youngblood Hawke
# Done 2883 / 2944, doing Youth Group
# Done 2884 / 2944, doing Yui
# Done 2885 / 2944, doing Yuki Kajiura
# Done 2886 / 2944, doing Yung Lean
# Done 2887 / 2944, doing Yves Tumor
# Done 2888 / 2944, doing ZAYN
# Done 2889 / 2944, doing ZHU
# Done 2890 / 2944, doing ZUN
# Done 2891 / 2944, doing ZZ Top
# Done 2892 / 2944, doing Zara Larsson
# Done 2893 / 2944, doing Zayn
# Done 2894 / 2944, doing Zbigniew Preisner
# Done 2895 / 2944, doing Zebrahead
# Done 2896 / 2944, doing Zedd
# Done 2897 / 2944, doing Zeds Dead
# Done 2898 / 2944, doing Zella Day
# Done 2899 / 2944, doing Zendaya
# Done 2900 / 2944, doing Zero 7
# Done 2901 / 2944, doing Ziggy Marley
# Done 2902 / 2944, doing Zoe
# Done 2903 / 2944, doing Zomboy
# Done 2904 / 2944, doing alt-J
# Done 2905 / 2944, doing beabadoobee
# Done 2906 / 2944, doing bignic
# Done 2907 / 2944, doing bill wurtz
# Done 2908 / 2944, doing black midi
# Done 2909 / 2944, doing blink-182
# Done 2910 / 2944, doing bo en
# Done 2911 / 2944, doing c418
# Done 2912 / 2944, doing cupcakKe
# Done 2913 / 2944, doing deadmau5
# Done 2914 / 2944, doing deadmau5 and Kaskade
# Done 2915 / 2944, doing dj-Jo
# Done 2916 / 2944, doing dodie
# Done 2917 / 2944, doing fIREHOSE
# Done 2918 / 2944, doing fripSide
# Done 2919 / 2944, doing girl in red
# Done 2920 / 2944, doing glue70
# Done 2921 / 2944, doing iamamiwhoami
# Done 2922 / 2944, doing idk
# Done 2923 / 2944, doing ilan Bluestone
# Done 2924 / 2944, doing meganeko
# Done 2925 / 2944, doing miss A
# Done 2926 / 2944, doing mxmtoon
# Done 2927 / 2944, doing nanobii
# Done 2928 / 2944, doing nao
# Done 2929 / 2944, doing nelward
# Done 2930 / 2944, doing rammstein
# Done 2931 / 2944, doing scarlxrd
# Done 2932 / 2944, doing she
# Done 2933 / 2944, doing sia
# Done 2934 / 2944, doing sodagreen
# Done 2935 / 2944, doing supercell
# Done 2936 / 2944, doing the caretaker
# Done 2937 / 2944, doing thenewno2
# Done 2938 / 2944, doing twenty one pilots
# Done 2939 / 2944, doing vistlip
# Done 2940 / 2944, doing zedd

# %%
wdf
# Out:
#                                          song       publicationDate  \
# 0    http://www.wikidata.org/entity/Q99126904  2019-05-29T00:00:00Z
# 1    http://www.wikidata.org/entity/Q93160306  2020-02-24T00:00:00Z
# 0     http://www.wikidata.org/entity/Q2525537                   NaN
# 1     http://www.wikidata.org/entity/Q1823414                   NaN
# 2    http://www.wikidata.org/entity/Q14942376                   NaN
# ..                                        ...                   ...
# 13   http://www.wikidata.org/entity/Q25212174  2016-05-27T00:00:00Z
# 0    http://www.wikidata.org/entity/Q86742896  2020-02-26T00:00:00Z
# 1    http://www.wikidata.org/entity/Q86742896  2020-02-26T00:00:00Z
# 0    http://www.wikidata.org/entity/Q85814726  2018-11-21T00:00:00Z
# 1   http://www.wikidata.org/entity/Q108739714                   NaN
#
#                      songLabel  artistLabel  genreLabel
# 0                money machine     100 gecs         NaN
# 1             Ringtone (Remix)     100 gecs  glitch hop
# 0   From Rochdale to Ocho Rios         10cc  rock music
# 1                  Flying Junk         10cc         NaN
# 2        Rock 'n' Roll Lullaby         10cc  rock music
# ..                         ...          ...         ...
# 13                    Snowcone     deadmau5         NaN
# 0                    Q86742896     fripSide       J-pop
# 1                    Q86742896     fripSide     anisong
# 0   We Fell in Love in October  girl in red         NaN
# 1                    Serotonin  girl in red  indie rock
#
# [25967 rows x 5 columns]

# %%
# wdf.to_csv(wdfn, index=False)

# %%
wdf = pd.read_csv(wdfn)
wdf
# Out:
#                                             song       publicationDate  \
# 0       http://www.wikidata.org/entity/Q99126904  2019-05-29T00:00:00Z
# 1       http://www.wikidata.org/entity/Q93160306  2020-02-24T00:00:00Z
# 2        http://www.wikidata.org/entity/Q2525537                   NaN
# 3        http://www.wikidata.org/entity/Q1823414                   NaN
# 4       http://www.wikidata.org/entity/Q14942376                   NaN
# ...                                          ...                   ...
# 25962   http://www.wikidata.org/entity/Q25212174  2016-05-27T00:00:00Z
# 25963   http://www.wikidata.org/entity/Q86742896  2020-02-26T00:00:00Z
# 25964   http://www.wikidata.org/entity/Q86742896  2020-02-26T00:00:00Z
# 25965   http://www.wikidata.org/entity/Q85814726  2018-11-21T00:00:00Z
# 25966  http://www.wikidata.org/entity/Q108739714                   NaN
#
#                         songLabel  artistLabel  genreLabel
# 0                   money machine     100 gecs         NaN
# 1                Ringtone (Remix)     100 gecs  glitch hop
# 2      From Rochdale to Ocho Rios         10cc  rock music
# 3                     Flying Junk         10cc         NaN
# 4           Rock 'n' Roll Lullaby         10cc  rock music
# ...                           ...          ...         ...
# 25962                    Snowcone     deadmau5         NaN
# 25963                   Q86742896     fripSide       J-pop
# 25964                   Q86742896     fripSide     anisong
# 25965  We Fell in Love in October  girl in red         NaN
# 25966                   Serotonin  girl in red  indie rock
#
# [25967 rows x 5 columns]

# %%
def map_genres(tdf):
    lst = tdf.unique().tolist()
    return None if pd.isna(lst[0]) else lst
    
awdf = wdf.groupby("song").aggregate({
    "songLabel": "first",
    "artistLabel": "first",
    "genreLabel": map_genres,
    "publicationDate": "first",
})
awdf = awdf.reset_index()
# filter songs without valid label
awdf = awdf[~awdf.apply(lambda row: row.song.endswith(row.songLabel), axis=1)]
awdf.publicationDate = pd.to_datetime(awdf.publicationDate, errors="coerce")
awdf
# Out:
#                                             song  \
# 0        http://www.wikidata.org/entity/Q1001245
# 1        http://www.wikidata.org/entity/Q1001441
# 2      http://www.wikidata.org/entity/Q100144704
# 3        http://www.wikidata.org/entity/Q1001904
# 4        http://www.wikidata.org/entity/Q1001928
# ...                                          ...
# 22804   http://www.wikidata.org/entity/Q99947370
# 22805   http://www.wikidata.org/entity/Q99954395
# 22806     http://www.wikidata.org/entity/Q999593
# 22807   http://www.wikidata.org/entity/Q99980407
# 22808   http://www.wikidata.org/entity/Q99982130
#
#                               songLabel              artistLabel  \
# 0                 Fight from the Inside                    Queen
# 1      Serenade no. 3 in D, "Andretter"  Wolfgang Amadeus Mozart
# 2                              Lazy Day                John Cale
# 3                               Flaming               Pink Floyd
# 4                                 Flash                Brian May
# ...                                 ...                      ...
# 22804                     Bet You Wanna                Blackpink
# 22805                Der traurige Mönch              Franz Liszt
# 22806                         Unwritten      Natasha Bedingfield
# 22807                         FRANCHISE             Travis Scott
# 22808                       Puerto Rico            Vaya Con Dios
#
#                genreLabel           publicationDate
# 0                    None 1977-01-01 00:00:00+00:00
# 1                    None 1773-07-01 00:00:00+00:00
# 2                    None 2020-10-06 00:00:00+00:00
# 3      [psychedelic rock] 1967-08-04 00:00:00+00:00
# 4            [rock music] 1980-11-24 00:00:00+00:00
# ...                   ...                       ...
# 22804        [rap, K-pop] 2020-10-02 00:00:00+00:00
# 22805                None                       NaT
# 22806         [pop music] 2004-11-29 00:00:00+00:00
# 22807                None 2020-09-25 00:00:00+00:00
# 22808                None                       NaT
#
# [21362 rows x 5 columns]

# %%
awdf.describe()
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                                            song       songLabel  \
# count                                     21362           21362
# unique                                    21362           19193
# top     http://www.wikidata.org/entity/Q7063774  Symphony No. 1
# freq                                          1              16
# first                                       NaN             NaN
# last                                        NaN             NaN
#
#                   artistLabel    genreLabel            publicationDate
# count                   21362         11619                      14651
# unique                   1675          1076                       3905
# top     Johann Sebastian Bach  [rock music]  1967-01-01 00:00:00+00:00
# freq                      555          1234                        260
# first                     NaN           NaN  1683-01-01 00:00:00+00:00
# last                      NaN           NaN  2030-12-05 00:00:00+00:00

# %%
awdf.genreLabel.explode().value_counts().head(50)
# Out:
# rock music                1287
# pop music                 1158
# country music              537
# pop rock                   433
# alternative rock           391
# hip hop music              343
# hard rock                  343
# synth-pop                  292
# folk rock                  287
# progressive rock           259
# contemporary R&B           232
# dance-pop                  202
# popular music              188
# rock and roll              177
# heavy metal                173
# soul music                 171
# rhythm and blues           159
# soft rock                  154
# psychedelic rock           153
# jazz                       151
# electropop                 123
# new wave                   120
# blues rock                 117
# protest song               112
# indie rock                  89
# opera                       87
# art rock                    86
# progressive metal           80
# bebop                       78
# blues                       78
# country rock                78
# grunge                      78
# house music                 77
# funk                        73
# electronic music            73
# electronic dance music      72
# punk rock                   69
# traditional folk music      66
# disco                       65
# J-pop                       62
# country pop                 61
# thrash metal                58
# pop punk                    58
# folk music                  58
# indie pop                   57
# post-punk                   55
# alternative metal           52
# dance music                 49
# ragtime                     48
# baroque pop                 47
# Name: genreLabel, dtype: int64

# %%
# analyze matching with Hooktheory dataset
def match_sets(s1: set, s2: set, s1name: str = "s1", s2name: str = "s2"):
    return pd.Series({
        f"{s1name}": len(s1),
        f"{s2name}": len(s2),
        f"{s1name} & {s2name}": len(s1 & s2),
        f"{s1name} - {s2name}": len(s1 - s2),
        f"{s2name} - {s1name}": len(s2 - s1),
    })
    
ht_artists = set(map(name_to_iri_name, df.artist.unique()))
wd_artists = set(map(name_to_iri_name, wdf.artistLabel.unique()))
match_sets(ht_artists, wd_artists, "ht", "wd")
# Out:
# ht         2939
# wd         1705
# ht & wd    1705
# ht - wd    1234
# wd - ht       0
# dtype: int64

# %%
wg = Graph()
wg.parse("../ontologies/chord_progressions.owl", format="turtle")
wg.bind("chp", chp)

# %%
for i, (artist, songs) in enumerate(awdf.sort_values(["artistLabel", "song"]).groupby("artistLabel")):
    author = artist_name_to_node(wg, artist)
    for row in songs.itertuples():
        song = song_name_to_node(wg, author, get_song_name(artist, quote_plus(row.songLabel)), row.songLabel)
        if not pd.isna(row.publicationDate):
            wg.add((song, chp.hasPublicationDate, Literal(row.publicationDate)))
        if row.genreLabel:
            for genre in row.genreLabel:    
                wg.add((song, chp.hasGenre, Literal(genre)))

# %%
len(wg)
# Out:
# 117001

# %%
wg.serialize(destination="../ontologies/chord-progressions-populated-wikidata.owl", format="turtle")
# Out:
# <Graph identifier=N0c186de8bee546bf8f2836f88662cfa8 (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib.void import generateVoID

# %%
vfn = "../ontologies/chord-progressions-populated-full.owl"
vg = Graph()

# vg.parse(vfn, format="turtle")
vg = g | wg 

vg.bind("chp", chp)
vg.bind("chpv", chpv)

# %%
ovg = generateVoID(vg, dataset=chpv.Dataset)[0]

# %%
ovfn = vfn[:-4] + "-void.owl"
ovg.bind("chp", chp)
ovg.bind("chpv", chpv)
ovg.serialize(ovfn, format="turtle")
# Out:
# <Graph identifier=N720a864091854082a6fc6273caafd917 (<class 'rdflib.graph.Graph'>)>

# %%
vg.serialize(vfn, format="turtle")
# Out:
# <Graph identifier=N7f8ffedebb3a4124821e37ec008a2d50 (<class 'rdflib.graph.Graph'>)>

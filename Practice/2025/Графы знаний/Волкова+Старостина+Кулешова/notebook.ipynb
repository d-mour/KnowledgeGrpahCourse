# %%
# !pip install pykeen
# Out:
# Collecting pykeen
#   Downloading pykeen-1.11.1-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 4.6 MB/s eta 0:00:00
# Collecting dataclasses-json (from pykeen)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pykeen) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from pykeen) (1.16.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from pykeen) (8.3.1)
# Collecting click_default_group (from pykeen)
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pykeen) (1.6.1)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from pykeen) (2.9.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pykeen) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pykeen) (2.32.4)
# Collecting optuna>=2.0.0 (from pykeen)
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pykeen) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from pykeen) (0.9.0)
# Collecting more_click (from pykeen)
#   Downloading more_click-0.1.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from pykeen) (10.8.0)
# Collecting pystow>=0.4.3 (from pykeen)
#   Downloading pystow-0.7.12-py3-none-any.whl.metadata (17 kB)
# Collecting docdata>=0.0.5 (from pykeen)
#   Downloading docdata-0.0.5-py3-none-any.whl.metadata (13 kB)
# Collecting class_resolver>=0.6.0 (from pykeen)
#   Downloading class_resolver-0.7.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pykeen) (6.0.3)
# Collecting torch_max_mem>=0.1.4 (from pykeen)
#   Downloading torch_max_mem-0.1.4-py3-none-any.whl.metadata (12 kB)
# Collecting torch-ppr>=0.0.7 (from pykeen)
#   Downloading torch_ppr-0.0.8-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pykeen) (4.15.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=2.0.0->pykeen) (1.17.2)
# Collecting colorlog (from optuna>=2.0.0->pykeen)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=2.0.0->pykeen) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=2.0.0->pykeen) (2.0.44)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->pykeen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->pykeen) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->pykeen) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pykeen) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pykeen) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pykeen) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pykeen) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pykeen) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->pykeen) (2025.3.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->pykeen)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->pykeen)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pykeen) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pykeen) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pykeen) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pykeen) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pykeen) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pykeen) (3.6.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->pykeen) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->pykeen) (3.0.3)
# Downloading pykeen-1.11.1-py3-none-any.whl (730 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.3/730.3 kB 28.4 MB/s eta 0:00:00
# Downloading class_resolver-0.7.1-py3-none-any.whl (31 kB)
# Downloading docdata-0.0.5-py3-none-any.whl (9.2 kB)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 20.0 MB/s eta 0:00:00
# Downloading pystow-0.7.12-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.9 MB/s eta 0:00:00
# Downloading torch_max_mem-0.1.4-py3-none-any.whl (13 kB)
# Downloading torch_ppr-0.0.8-py3-none-any.whl (12 kB)
# Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading more_click-0.1.3-py3-none-any.whl (12 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.9 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: mypy-extensions, more_click, marshmallow, docdata, colorlog, click_default_group, class_resolver, typing-inspect, pystow, torch_max_mem, optuna, dataclasses-json, torch-ppr, pykeen
# Successfully installed class_resolver-0.7.1 click_default_group-1.2.4 colorlog-6.10.1 dataclasses-json-0.6.7 docdata-0.0.5 marshmallow-3.26.1 more_click-0.1.3 mypy-extensions-1.1.0 optuna-4.6.0 pykeen-1.11.1 pystow-0.7.12 torch-ppr-0.0.8 torch_max_mem-0.1.4 typing-inspect-0.9.0

# %%
# !pip install rdflib pandas scikit-learn matplotlib seaborn
# Out:
# Collecting rdflib
#   Downloading rdflib-7.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib) (3.2.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading rdflib-7.5.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.2/587.2 kB 14.8 MB/s eta 0:00:00
# Installing collected packages: rdflib
# Successfully installed rdflib-7.5.0

# %%
# !pip install xgboost
# !pip install unidecode
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.28.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 9.7 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0

# %%
# %%writefile harrypotter_kg_ru.py
from __future__ import annotations

import argparse
import re
import time
import html
import urllib.parse
import requests
import logging
from pathlib import Path
from bs4 import BeautifulSoup
from unidecode import unidecode
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, OWL
from typing import Optional, Callable

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
)
logger = logging.getLogger("hp-kg")


BASE_IRI = "http://www.semanticweb.org/ekaterinakulesova/ontologies/2025/0/harry_potter#"
BASE = "https://harrypotter.fandom.com/ru/wiki/"
API_ENDPOINT = "https://harrypotter.fandom.com/ru/api.php"

REQUEST_DELAY = 0.2
RELATION_DELAY = 0.05

OUT_FILE = "harrypotter_kg_ru.ttl"
CHECKPOINT_EVERY = 120
_save_counter = 0

g = Graph()
HP = Namespace(BASE_IRI)
HPO = Namespace(BASE_IRI)
g.bind("hp", HP)
g.bind("hpo", HPO)
g.bind("rdfs", RDFS)
g.bind("owl", OWL)

def qn(term) -> str:
    try:
        if isinstance(term, URIRef) and str(term).startswith(BASE_IRI):
            return str(term).replace(BASE_IRI, "hpo:")
        return g.namespace_manager.normalizeUri(term)
    except Exception:
        return str(term)


def load_existing_graph(path: str):
    if not path:
        return
    file_path = Path(path)
    if not file_path.exists():
        logger.info("Файл %s не найден, создаём новый граф", file_path)
        return
    try:
        g.parse(file_path, format="turtle")
        logger.info("Загружено %s триплетов из %s", len(g), file_path)
    except Exception as exc:
        logger.warning("Не удалось загрузить %s: %s", file_path, exc)

classes = {
    "Thing": HPO.Thing,
    "Artifact": HPO.Artifact,
    "Character": HPO.Character,
    "Human": HPO.Human,
    "Muggle": HPO.Muggle,
    "Squib": HPO.Squib,
    "Wizard": HPO.Wizard,
    "Magical_creature": HPO.Magical_creature,
    "Centaur": HPO.Centaur,
    "Ghost": HPO.Ghost,
    "Giant": HPO.Giant,
    "Giant_spider": HPO.Giant_spider,
    "House": HPO.House,
    "House_elf": HPO.House_elf,
    "Mermaid": HPO.Mermaid,
    "Event": HPO.Event,
    "Big": HPO.Big,
    "Small": HPO.Small,
    "Location": HPO.Location,
    "Organization": HPO.Organization,
    "Potion": HPO.Potion,
    "Role": HPO.Role,
    "Spell": HPO.Spell,
}
for c, p in [
    (classes["Artifact"], classes["Thing"]),
    (classes["Character"], classes["Thing"]),
    (classes["Human"], classes["Character"]),
    (classes["Muggle"], classes["Human"]),
    (classes["Squib"], classes["Human"]),
    (classes["Wizard"], classes["Human"]),
    (classes["Magical_creature"], classes["Character"]),
    (classes["Centaur"], classes["Magical_creature"]),
    (classes["Ghost"], classes["Magical_creature"]),
    (classes["Giant"], classes["Magical_creature"]),
    (classes["Giant_spider"], classes["Magical_creature"]),
    (classes["House_elf"], classes["Magical_creature"]),
    (classes["Mermaid"], classes["Magical_creature"]),
    (classes["Event"], classes["Thing"]),
    (classes["Big"], classes["Event"]),
    (classes["Small"], classes["Event"]),
    (classes["House"], classes["Thing"]),
    (classes["Location"], classes["Thing"]),
    (classes["Organization"], classes["Thing"]),
    (classes["Potion"], classes["Thing"]),
    (classes["Role"], classes["Thing"]),
    (classes["Spell"], classes["Thing"]),
]:
    g.add((c, RDF.type, OWL.Class))
    g.add((c, RDFS.subClassOf, p))

obj_props = {
    "activeAt": HPO.activeAt,
    "artifactInvolvedIn": HPO.artifactInvolvedIn,
    "hasOwner": HPO.hasOwner,
    "hasCreator": HPO.hasCreator,
    "hasManufacturer": HPO.hasManufacturer,
    "friendWith": HPO.friendWith,
    "hasRole": HPO.hasRole,
    "memberOf": HPO.memberOf,
    "participatedIn": HPO.participatedIn,
    "relativeOf": HPO.relativeOf,
    "hasFather": HPO.hasFather,
    "hasMother": HPO.hasMother,
    "marriedWith": HPO.marriedWith,
    "romanceWith": HPO.romanceWith,
    "studiedAt": HPO.studiedAt,
    "takePartInEvent": HPO.takePartInEvent,
    "tookPlaceAt": HPO.tookPlaceAt,
    "hasSibling": HPO.hasSibling,
    "hasBrother": HPO.hasBrother,
    "hasSister": HPO.hasSister,
    "hasChild": HPO.hasChild,
    "hasSon": HPO.hasSon,
    "hasDaughter": HPO.hasDaughter,
    "hasUncle": HPO.hasUncle,
    "hasAunt": HPO.hasAunt,
    "hasNephew": HPO.hasNephew,
    "hasNiece": HPO.hasNiece,
    "hasGrandparent": HPO.hasGrandparent,
    "hasGrandchild": HPO.hasGrandchild,

    "siblingOf": HPO.siblingOf,
    "brotherOf": HPO.brotherOf,
    "sisterOf": HPO.sisterOf,
    "childOf": HPO.childOf,
    "sonOf": HPO.sonOf,
    "daughterOf": HPO.daughterOf,

    "godfatherOf": HPO.godfatherOf,
    "godsonOf": HPO.godsonOf,
    "cousinOf": HPO.cousinOf,
    "nephewOf": HPO.nephewOf,
    "nieceOf": HPO.nieceOf,
}

data_props = {
    "hasWand": HPO.hasWand,
    "hasPatronus": HPO.hasPatronus,
    "purpose": HPO.purpose,
    "hasType": HPO.hasType,
    "formula": HPO.formula,
    "effect": HPO.effect,
}

for p in data_props.values():
    g.add((p, RDF.type, OWL.DatatypeProperty))
for p in obj_props.values():
    g.add((p, RDF.type, OWL.ObjectProperty))
for p in ["godfatherOf", "godsonOf", "cousinOf", "nephewOf", "nieceOf", "hasManufacturer"]:
    g.add((obj_props[p], RDF.type, OWL.ObjectProperty))


session = requests.Session()
retry = Retry(
    total=4, backoff_factor=0.5,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"], raise_on_status=False,
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)

def http_get(url: str) -> BeautifulSoup | None:
    try:
        r = session.get(url, headers={"User-Agent": "hp-kg-populator/1.0"}, timeout=20)
        if r.status_code == 200:
            return BeautifulSoup(r.text, "html.parser")
        logger.warning("HTTP %s: %s", r.status_code, url)
    except requests.RequestException as e:
        logger.warning("Ошибка запроса %s: %s", url, e)
    return None


def save_checkpoint(force=False):
    global _save_counter
    if not force and _save_counter < CHECKPOINT_EVERY:
        return
    g.serialize(destination=OUT_FILE, format="turtle")
    logger.info("Сохранено в %s (триплетов: %s)", OUT_FILE, len(g))
    _save_counter = 0

def bump_counter(n=1):
    global _save_counter
    _save_counter += n
    save_checkpoint(False)

SKIP_TITLE_PATTERNS = [
    r"\(персонажи\)$", r"\(персонаж\)$", r"\(персонажи фильма\)$",
    r"^Список($|[ \t])", r"^Персонажи($|[ \t])", r"^Категория:",
]
def should_skip_title(title: str) -> bool:
    if not title:
        return True
    t = title.strip()
    for pat in SKIP_TITLE_PATTERNS:
        if re.search(pat, t, flags=re.IGNORECASE):
            return True
    return False

def slugify(label: str) -> str:
    txt = html.unescape(label).strip()
    ascii_txt = unidecode(txt)
    ascii_txt = re.sub(r"[\s/]+", "_", ascii_txt)
    ascii_txt = re.sub(r"[^A-Za-z0-9_\-]", "", ascii_txt)
    return ascii_txt or "entity"

def hp_entity(s: str) -> URIRef:
    return HP[s]

def add_labeled_instance(uri: URIRef, label_ru: str, rdf_type: URIRef):
    already = (uri, RDF.type, None) in g
    g.add((uri, RDF.type, rdf_type))
    g.add((uri, RDFS.label, Literal(label_ru, lang="ru")))
    if not already:
        logger.info("%s ← %s (%s)", qn(rdf_type), label_ru, qn(uri))
        bump_counter()

def fandom_url(title_ru: str) -> str:
    return urllib.parse.urljoin(BASE, urllib.parse.quote(title_ru.replace(" ", "_")))

def parse_categories(soup: BeautifulSoup) -> set[str]:
    cats = set()
    for a in soup.select('.page-header__categories a.category[href^="/ru/wiki/Категория:"]'):
        t = (a.get("title") or a.get_text(strip=True) or "").strip()
        if t.startswith("Категория:"):
            cats.add(t.replace("Категория:", "").strip())
    for a in soup.select('#articleCategories a[href^="/ru/wiki/Категория:"]'):
        t = (a.get("title") or a.get_text(strip=True) or "").strip()
        if t.startswith("Категория:"):
            cats.add(t.replace("Категория:", "").strip())
    return cats

def parse_infobox(soup: BeautifulSoup) -> dict:
    data = {}
    box = soup.select_one(".portable-infobox")
    if not box:
        return data
    for row in box.select(".pi-data"):
        label = row.select_one(".pi-data-label")
        value = row.select_one(".pi-data-value")
        if not label or not value:
            continue
        key = label.get_text(separator=" ", strip=True)
        text = value.get_text(separator=" ", strip=True)
        links = []
        for a in value.select("a[href]"):
            href = a.get("href") or ""
            title = a.get("title") or a.get_text(strip=True)
            if href.startswith("/ru/wiki/") and title and "/Категория:" not in href:
                links.append(title)
        data[key] = {"text": text, "links": links}
    return data

def ensure_entity(title_ru: str, rdf_type: URIRef):
    uri = hp_entity(slugify(title_ru))
    add_labeled_instance(uri, title_ru, rdf_type)
    return uri

def link_by_titles(subject_uri: URIRef, prop: URIRef, titles: list[str], fallback_type: URIRef):
    for t in titles:
        if should_skip_title(t):
            continue
        obj = hp_entity(slugify(t))
        if (obj, RDF.type, None) not in g:
            add_labeled_instance(obj, t, fallback_type)
        g.add((subject_uri, prop, obj))


detect_type_cache: dict[str, Optional[URIRef]] = {}

def determine_type_for_title(title_ru: str) -> Optional[URIRef]:
    """
    Если в графе уже есть тип — возвращаем его.
    Иначе пробуем запросить страницу персонажа и вычислить тип через type_from_sources.
    Кешируем результаты в detect_type_cache, чтобы не делать лишних запросов.
    Возвращаем найденный класс или None, если не удалось определить.
    """
    if not title_ru:
        return None
    if title_ru in detect_type_cache:
        return detect_type_cache[title_ru]
    obj = hp_entity(slugify(title_ru))
    for _, _, t in g.triples((obj, RDF.type, None)):
        if isinstance(t, URIRef):
            detect_type_cache[title_ru] = t
            return t

    url = fandom_url(title_ru)
    soup = http_get(url)
    if not soup:
        detect_type_cache[title_ru] = None
        return None
    if not soup.select_one(".portable-infobox"):
        detect_type_cache[title_ru] = None
        return None
    info = parse_infobox(soup)
    cats = parse_categories(soup)
    page_text = " ".join(soup.stripped_strings)
    rdf_type = type_from_sources(info, cats, page_text)
    detect_type_cache[title_ru] = rdf_type
    return rdf_type


def link_people_analyze(subject_uri: URIRef, prop: URIRef, titles: list[str], fallback_type: URIRef):
    for t in titles:
        if should_skip_title(t):
            continue
        detected_type = determine_type_for_title(t)
        use_type = detected_type or fallback_type
        obj = hp_entity(slugify(t))
        if (obj, RDF.type, None) not in g:
            add_labeled_instance(obj, t, use_type)
        g.add((subject_uri, prop, obj))


FIELD_MAP = {
    "Дом": ("memberOf", classes["House"]),
    "Организация": ("memberOf", classes["Organization"]),
    "Принадлежность": ("memberOf", classes["Organization"]),

    "Место обучения": ("studiedAt", classes["Location"]),
    "Обучался в": ("studiedAt", classes["Location"]),
    "Школа": ("studiedAt", classes["Location"]),
    "Учился в": ("studiedAt", classes["Location"]),

    "Род занятий": ("hasRole", classes["Role"]),
    "Профессия": ("hasRole", classes["Role"]),
    "Должность": ("hasRole", classes["Role"]),
    "Специальность": ("hasRole", classes["Role"]),

    "Супруг": ("marriedWith", classes["Character"]),
    "Супруга": ("marriedWith", classes["Character"]),
    "Супруг(а)": ("marriedWith", classes["Character"]),
    "Отец": ("hasFather", classes["Character"]),
    "Мать": ("hasMother", classes["Character"]),
    "Родители": ("hasParent", classes["Character"]),
    "Друзья": ("friendWith", classes["Character"]),
    "Любовный интерес": ("romanceWith", classes["Character"]),
    "Романтические отношения": ("romanceWith", classes["Character"]),

    "Семья": ("family_from_infobox", classes["Character"]),
    "Брат": ("hasBrother", classes["Character"]),
    "Сестра": ("hasSister", classes["Character"]),
    "Братья": ("hasSibling", classes["Character"]),
    "Сёстры": ("hasSibling", classes["Character"]),
    "Братья и сёстры": ("hasSibling", classes["Character"]),
    "Дети": ("hasChild", classes["Character"]),
    "Сын": ("hasSon", classes["Character"]),
    "Дочь": ("hasDaughter", classes["Character"]),
    "Сыновья": ("hasChild", classes["Character"]),
    "Дочери": ("hasChild", classes["Character"]),
    "Дядя": ("hasUncle", classes["Character"]),
    "Тётя": ("hasAunt", classes["Character"]),
    "Племянник": ("hasNephew", classes["Character"]),
    "Племянница": ("hasNiece", classes["Character"]),
    "Дедушка": ("hasGrandparent", classes["Character"]),
    "Бабушка": ("hasGrandparent", classes["Character"]),
    "Внук": ("hasGrandchild", classes["Character"]),
    "Внучка": ("hasGrandchild", classes["Character"]),

    "Вид": ("type_hint", None),
    "Вид(ы)": ("type_hint", None),
    "Раса": ("type_hint", None),
    "Раса/вид": ("type_hint", None),
    "Принадлежность к виду": ("type_hint", None),
    "Пол": ("sex_hint", None),

    "Чистота крови": ("blood_status_hint", None),
}

CATEGORY_TO_CLASS = {
    "Люди": classes["Human"],
    "Маги": classes["Wizard"],
    "Маги по алфавиту": classes["Wizard"],
    "Магглы": classes["Muggle"],
    "Сквибы": classes["Squib"],
    "Маглорождённые волшебники": classes["Wizard"],
    "Чистокровные волшебники": classes["Wizard"],
    "Полукровки": classes["Wizard"],
    "Домовые эльфы": classes["House_elf"],
    "Привидения": classes["Ghost"],
    "Кентавры": classes["Centaur"],
    "Акромантулы": classes["Giant_spider"],
    "Великаны": classes["Giant"],
    "Русалки": classes["Mermaid"],
}

CREATURE_KEYWORDS = {
    "кентавр": classes["Centaur"],
    "привидение": classes["Ghost"],
    "гигант": classes["Giant"],
    "акромантул": classes["Giant_spider"],
    "домовой эльф": classes["House_elf"],
    "русалк": classes["Mermaid"],
}

def has_word(txt: str, pattern: str) -> bool:
    try:
        return re.search(rf"(?iu)\b{pattern}\w*\b", txt) is not None
    except re.error:
        patt = re.escape(pattern)
        return re.search(rf"(?iu)\b{patt}\w*\b", txt) is not None

def choose_most_specific(types: list[URIRef]) -> URIRef:
    priority = [
        classes["Centaur"], classes["Ghost"], classes["Giant"], classes["Giant_spider"],
        classes["House_elf"], classes["Mermaid"],
        classes["Wizard"], classes["Muggle"], classes["Squib"],
        classes["Human"], classes["Character"],
    ]
    for cls in priority:
        if cls in types:
            return cls
    return classes["Character"]


def type_from_sources(info: dict, cats: set[str], page_text: str) -> URIRef:
    """
    Определение типа сущности по инфобоксу, категориям и тексту.
    Приоритет:
      1. Явные указания вида (кентавр, призрак и т.д.)
      2. Поле «Чистота крови» (даже для не-людей!)
      3. Поле «Вид» → человек/маг/существо
      4. Категории (особенно «Магглы», «Сквибы»)
      5. Контекст (осторожно: «Хогвартс» у магглов — не делает их волшебниками)
    """

    def classify_by_purity() -> Optional[URIRef]:
        purity = (info.get("Чистота крови", {}) or {}).get("text", "")
        purity = purity.lower().strip()
        if not purity:
            return None
        if has_word(purity, "сквиб"):
            return classes["Squib"]
        if has_word(purity, "маглорожд") or has_word(purity, "полукров"):
            return classes["Wizard"]
        if has_word(purity, "магл") and not has_word(purity, "маглорожд"):
            return classes["Muggle"]
        if any(has_word(purity, s) for s in ["чистокровный", "грязнокров", "кровь"]):
            return classes["Wizard"]
        return None

    raw_kind = ""
    for k in ("Вид", "Вид(ы)", "Раса", "Раса/вид", "Принадлежность к виду"):
        if k in info:
            raw_kind = info[k]["text"].lower().strip()
            break

    if raw_kind:
        for key, cls in CREATURE_KEYWORDS.items():
            if key in raw_kind:
                return cls
        if "привидение" in raw_kind or "призрак" in raw_kind:
            return classes["Ghost"]
        if "великан" in raw_kind:
            return classes["Giant"]
        if "акромантул" in raw_kind:
            return classes["Giant_spider"]
        if "домовой эльф" in raw_kind or ("домовой" in raw_kind and "эльф" in raw_kind):
            return classes["House_elf"]
        if "русалк" in raw_kind:
            return classes["Mermaid"]
        if "волшебник" in raw_kind or "маг" in raw_kind:
            return classes["Wizard"]
        if "человек" in raw_kind:
            by_purity = classify_by_purity()
            if by_purity:
                return by_purity
            if "Дом" in info:
                house = info["Дом"]["text"].lower()
                if any(h in house for h in ["гриффиндор", "слизерин", "когтевран", "пуффендуй"]):
                    return classes["Wizard"]
            if "обучался" in page_text.lower() or "хогвартс" in page_text.lower() and "учился" in page_text.lower():
                return classes["Wizard"]
            return classes["Human"]

    by_purity = classify_by_purity()
    if by_purity:
        return by_purity
    for c in cats:
        if c in CATEGORY_TO_CLASS:
            return CATEGORY_TO_CLASS[c]
        if "сквиб" in c.lower():
            return classes["Squib"]
        if "маггл" in c.lower() or "мугл" in c.lower():
            return classes["Muggle"]
        if any(x in c.lower() for x in ["хогвартс", "маг", "волшебник", "ученик", "профессор"]):
            pass

    txt = page_text.lower()

    muggle_phrases = [
        "не маг", "немаг", "маггл", "мугл", "muggle", "non-mag",
        "не волшебник", "обычный человек", "простой человек",
        "не имеет магических способностей", "не обучался в хогвартсе",
        "не владеет магией"
    ]
    for phrase in muggle_phrases:
        if phrase in txt:
            if "сквиб" in txt:
                return classes["Squib"]
            return classes["Muggle"]

    if ("хогвартс" in txt and ("учился" in txt or "посещал" in txt or "выпускник" in txt)) \
       or "палочка" in txt \
       or "заклин" in txt \
       or "волшебник" in txt \
       or "маги" in txt \
       or "чары" in txt:
        return classes["Wizard"]

    for key, cls in CREATURE_KEYWORDS.items():
        if has_word(txt, key):
            return cls

    return classes["Human"]

def extract_family_relations_from_text(soup: BeautifulSoup, subject_title: str) -> list[tuple[str, str]]:

    relations = []

    content = soup.select_one(".mw-parser-output")
    if not content:
        return relations

    text_blocks = []
    for elem in content.children:
        if elem.name in {"p", "ul", "ol", "h2", "h3"}:
            text_blocks.append(elem.get_text(separator=" ", strip=True))

    full_text = " ".join(text_blocks)

    patterns = [
        ("hasBrother", r"(?:брат(?:а|у|ом)?|брат\s+его|его\s+брат)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
        ("hasSister", r"(?:сестр(?:а|ы|у|ой)?|сестра\s+его|его\s+сестра)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
        ("hasSon", r"(?:сын(?:а|у|ом)?|его\s+сын)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
        ("hasDaughter", r"(?:дочь|дочер(?:и|ью)?|его\s+дочь)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
        ("hasFather", r"(?:отец|его\s+отец)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
        ("hasMother", r"(?:мать|его\s+мать)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
        ("marriedWith", r"(?:супруг(?:а|и)?|муж|жена|женат\s+на|замужем\s+за)\s+—?\s*([А-ЯЁ][а-яё\s\-]+?(?:\s[А-ЯЁ]\.)?)"),
    ]

    for rel_type, pattern in patterns:
        for match in re.finditer(pattern, full_text, flags=re.IGNORECASE | re.UNICODE):
            name_candidate = match.group(1).strip()
            name_candidate = re.sub(r"[,\.!\?;:]+$", "", name_candidate)
            name_candidate = re.sub(r"\s+(?:и|или|также|ранее|позже)\s+.*$", "", name_candidate)
            if name_candidate and not should_skip_title(name_candidate):
                if len(name_candidate.split()) >= 2 and re.match(r"^[А-ЯЁ][а-яё]+(?:\s+[А-ЯЁ][а-яё]+)+$", name_candidate):
                    relations.append((rel_type, name_candidate))


    return relations


def parse_family_section(soup: BeautifulSoup) -> list[tuple[str, str]]:
    relations = []

    family_header = None
    for h2 in soup.select("h2"):
        if "семья" in h2.get_text(strip=True).lower():
            family_header = h2
            break

    if not family_header:
        return relations

    next_elem = family_header.find_next_sibling()
    family_text = ""
    while next_elem and next_elem.name != "h2":
        if next_elem.name in {"p", "ul", "ol"}:
            family_text += " " + next_elem.get_text(separator=" ", strip=True)
        next_elem = next_elem.find_next_sibling()

    if not family_text.strip():
        return relations

    items = [item.strip() for item in re.split(r"[,;]", family_text)]

    role_map = {
        "отец": "hasFather",
        "мать": "hasMother",
        "брат": "hasBrother",
        "сестра": "hasSister",
        "сын": "hasSon",
        "дочь": "hasDaughter",
        "дядя": "hasUncle",
        "тётя": "hasAunt",
        "племянник": "hasNephew",
        "племянница": "hasNiece",
        "дедушка": "hasGrandparent",
        "бабушка": "hasGrandparent",
        "внук": "hasGrandchild",
        "внучка": "hasGrandchild",
        "кузина": "cousinOf",
        "кузен": "cousinOf",
        "двоюродная племянница": "nieceOf",
        "двоюродный племянник": "nephewOf",
        "троюродный племянник": "nephewOf",
        "крестник": "godsonOf",
        "крёстный отец": "godfatherOf",
    }

    for item in items:
        item = re.sub(r"[†*«»\"]", "", item).strip()
        if not item:
            continue

        match = re.match(r"([А-ЯЁ][а-яё\s\-]+?)\s*\(([^)]+)\)", item)
        if not match:
            continue

        name = match.group(1).strip()
        role_desc = match.group(2).strip().lower()

        for role_name, prop_key in role_map.items():
            if role_name in role_desc:
                relations.append((prop_key, name))
                break

    return relations


def parse_family_field_from_infobox(family_text: str) -> list[tuple[str, str]]:

    logger.debug("🔍 Разбор поля 'Семья': %r", family_text[:200])
    relations = []

    cleaned_text = re.sub(r"[\†*«»\"]|\[\s*\d+\s*\]", "", family_text).strip()
    if not cleaned_text:
        return relations

    role_map = {
        "отец": "hasFather", "свёкор": "hasFather", "тесть": "hasFather",
        "мать": "hasMother", "свекровь": "hasMother", "тёща": "hasMother",
        "брат": "hasBrother", "деверь": "hasBrother", "шурин": "hasBrother",
        "сестра": "hasSister", "золовка": "hasSister",
        "сын": "hasSon",
        "дочь": "hasDaughter",
        "дядя": "hasUncle",
        "тётя": "hasAunt",
        "племянник": "hasNephew", "внучатый племянник": "hasNephew",
        "племянница": "hasNiece",
        "дед": "hasGrandparent", "дедушка": "hasGrandparent",
        "бабушка": "hasGrandparent",
        "внук": "hasGrandchild",
        "внучка": "hasGrandchild",
        "жена": "marriedWith", "супруга": "marriedWith",
        "муж": "marriedWith", "супруг": "marriedWith",
        "кузина": "cousinOf", "двоюродная сестра": "cousinOf",
        "кузен": "cousinOf", "двоюродный брат": "cousinOf",
        "крестник": "godsonOf",
        "крёстный отец": "godfatherOf",
        "зять": "sonOf",
        "невестка": "daughterOf",
        "предок": "relativeOf",
        "потомок": "relativeOf",
    }

    pattern = re.compile(r"([А-ЯЁ][^()]+?)\s*\(([^)]+)\)")

    for match in pattern.finditer(cleaned_text):
        name = match.group(1).strip()
        role_desc = match.group(2).strip().lower()

        if len(name) < 2 or should_skip_title(name):
            continue

        found_role = False
        sorted_roles = sorted(role_map.keys(), key=len, reverse=True)
        for role_name in sorted_roles:
            if re.search(rf"\b{re.escape(role_name)}\b", role_desc):
                prop_key = role_map[role_name]
                relations.append((prop_key, name))
                found_role = True
                break

        if not found_role:
            for role_name, prop_key in role_map.items():
                if role_name in role_desc:
                    relations.append((prop_key, name))
                    break

    return relations


def scrape_character(title_ru: str):
    if should_skip_title(title_ru):
        return
    url = fandom_url(title_ru)
    soup = http_get(url)
    if not soup:
        logger.warning("Пропуск (нет доступа): %s", title_ru)
        return

    if not soup.select_one(".portable-infobox"):
        logger.debug("Пропуск (нет инфобокса): %s", title_ru)
        return

    info = parse_infobox(soup)
    cats = parse_categories(soup)
    rdf_type = type_from_sources(info, cats, soup.get_text(separator=" ", strip=True))
    subj = ensure_entity(title_ru, rdf_type)

    if "Пол" in info:
        g.add((subj, RDFS.comment, Literal(f"Пол: {info['Пол']['text']}", lang="ru")))

    direct_fields_map = {
        "Факультет": ("facultet", obj_props["memberOf"], "object"),
        "Палочка": ("wand", data_props["hasWand"], "data"),
        "Патронус": ("patronus", data_props["hasPatronus"], "data"),
        "Работа": ("job", obj_props["hasRole"], "role"),
    }

    for info_key, (log_key, prop_uri, prop_type) in direct_fields_map.items():
        if info_key in info:
            value_text = info[info_key].get("text", "").strip()
            if not value_text:
                continue

            if info_key == "Факультет" and rdf_type != classes["Wizard"]:
                continue

            if prop_type == "data":
                g.add((subj, prop_uri, Literal(value_text, lang="ru")))
            elif prop_type == "object":
                if value_text in HOUSES:
                    obj_uri = ensure_entity(value_text, classes["House"])
                    g.add((subj, prop_uri, obj_uri))
                else:
                    continue
            elif prop_type == "role":
                obj_uri = ensure_entity(value_text, classes["Role"])
                g.add((subj, prop_uri, obj_uri))

            logger.info(f"hpo:{log_key} {title_ru} -> {value_text}")
            bump_counter()

    logger.debug("Инфобокс для %s: %s", title_ru, list(info.keys()))
    for key, val in info.items():
        if key not in FIELD_MAP:
            continue
        prop_key, fallback_cls = FIELD_MAP[key]

        if prop_key == "family_from_infobox":
            if val["text"]:
                family_rels = parse_family_field_from_infobox(val["text"])
                for rel_type, person_title in family_rels:
                    if rel_type in obj_props:
                        prop_uri = obj_props[rel_type]
                        detected_type = determine_type_for_title(person_title)
                        use_type = detected_type or classes["Character"]
                        obj = ensure_entity(person_title, use_type)
                        g.add((subj, prop_uri, obj))
                        logger.info("👨‍👩‍👧‍👦 Инфобокс-Семья: %s --%s--> %s", title_ru, rel_type, person_title)
                        bump_counter()
            continue

        if prop_key in ("type_hint", "sex_hint", "blood_status_hint") or prop_key not in obj_props:
            continue
        prop_uri = obj_props[prop_key]

        PERSON_RELATIONS = {"marriedWith", "hasFather", "hasMother", "friendWith",
                            "romanceWith", "relativeOf", "hasParent"}
        if prop_key in PERSON_RELATIONS:
            if prop_key == "hasParent" and val["links"]:
                for link_title in val["links"]:
                    if any(link_title.endswith(end) for end in ["а", "я", "ия", "ина", "ьна", "на"]):
                        g.add((subj, obj_props["hasMother"], hp_entity(slugify(link_title))))
                    else:
                        g.add((subj, obj_props["hasFather"], hp_entity(slugify(link_title))))
                    detected = determine_type_for_title(link_title)
                    use_type = detected or classes["Character"]
                    ensure_entity(link_title, use_type)
                    logger.info("👨‍👦 Родитель: %s --%s--> %s", title_ru,
                                "hasMother" if "а" in link_title[-1] else "hasFather", link_title)
                continue
            if val["links"]:
                link_people_analyze(subj, prop_uri, val["links"], fallback_cls)
            else:
                v = val["text"]
                if not v or should_skip_title(v):
                    continue
                detected = determine_type_for_title(v)
                use_type = detected or fallback_cls
                obj = ensure_entity(v, use_type)
                g.add((subj, prop_uri, obj))
            continue

        if val["links"]:
            link_by_titles(subj, prop_uri, val["links"], fallback_cls)
        else:
            v = val["text"]
            if not v or should_skip_title(v):
                continue
            obj = ensure_entity(v, fallback_cls)
            g.add((subj, prop_uri, obj))

    family_section_rels = parse_family_section(soup)
    for prop_key, person_title in family_section_rels:
        if prop_key in obj_props:
            prop_uri = obj_props[prop_key]
            detected_type = determine_type_for_title(person_title)
            use_type = detected_type or classes["Character"]
            obj = ensure_entity(person_title, use_type)
            g.add((subj, prop_uri, obj))
            if prop_key == "hasFather":
                g.add((obj, obj_props["childOf"], subj))
            elif prop_key == "hasMother":
                g.add((obj, obj_props["childOf"], subj))
            elif prop_key == "hasBrother":
                g.add((obj, obj_props["brotherOf"], subj))
            elif prop_key == "hasSister":
                g.add((obj, obj_props["sisterOf"], subj))
            elif prop_key == "cousinOf":
                g.add((obj, obj_props["cousinOf"], subj))
            elif prop_key == "godsonOf":
                g.add((obj, obj_props["godfatherOf"], subj))
            elif prop_key == "godfatherOf":
                g.add((obj, obj_props["godsonOf"], subj))
            logger.info("Семья: %s --%s--> %s", title_ru, prop_key, person_title)
            bump_counter()

    family_rels = extract_family_relations_from_text(soup, title_ru)
    for rel_type, person_title in family_rels:
        if rel_type in obj_props:
            prop_uri = obj_props[rel_type]
            detected_type = determine_type_for_title(person_title)
            use_type = detected_type or classes["Character"]
            obj = hp_entity(slugify(person_title))
            if (obj, RDF.type, None) not in g:
                add_labeled_instance(obj, person_title, use_type)
            g.add((subj, prop_uri, obj))
            logger.info("🔗 Текст: %s --%s--> %s", title_ru, rel_type, person_title)
            bump_counter()


ARTIFACT_FIELD_MAP = {
    "Владелец": ("hasOwner", classes["Thing"]),
    "Владельцы": ("hasOwner", classes["Thing"]),
    "Хозяин": ("hasOwner", classes["Thing"]),
    "Создатель": ("hasCreator", classes["Thing"]),
    "Создатели": ("hasCreator", classes["Thing"]),
    "Изобретатель": ("hasCreator", classes["Thing"]),
    "Изобретатели": ("hasCreator", classes["Thing"]),
    "Производитель": ("hasManufacturer", classes["Thing"]),
    "Производители": ("hasManufacturer", classes["Thing"]),
    "Изготовитель": ("hasManufacturer", classes["Thing"]),
    "Изготовители": ("hasManufacturer", classes["Thing"]),
    "Назначение": ("purpose", None),
    "Предназначение": ("purpose", None),
    "Использование": ("purpose", None),
}


def scrape_artifact(title_ru: str) -> bool:
    if should_skip_title(title_ru):
        return False
    subj = ensure_entity(title_ru, classes["Artifact"])
    url = fandom_url(title_ru)
    soup = http_get(url)
    if not soup:
        logger.warning("Пропуск артефакта (нет доступа): %s", title_ru)
        return True
    info = parse_infobox(soup)
    if not info:
        return True

    for key, val in info.items():
        if key not in ARTIFACT_FIELD_MAP:
            continue
        prop_key, fallback_cls = ARTIFACT_FIELD_MAP[key]
        if prop_key == "purpose":
            text = val.get("text", "").strip()
            if text:
                g.add((subj, data_props["purpose"], Literal(text, lang="ru")))
                logger.info("🎯 Назначение: %s -> %s", title_ru, text)
                bump_counter()
            continue
        if prop_key not in obj_props:
            continue
        prop_uri = obj_props[prop_key]
        fallback = fallback_cls or classes["Thing"]
        added = False
        if val["links"]:
            link_by_titles(subj, prop_uri, val["links"], fallback)
            added = True
        else:
            text = val.get("text", "").strip()
            if text and not should_skip_title(text):
                obj = ensure_entity(text, fallback)
                g.add((subj, prop_uri, obj))
                added = True
        if added:
            logger.info("🔧 Артефакт: %s --%s--> %s", title_ru, prop_key, val.get("text", ""))
            bump_counter()
    return True


SPELL_FIELD_MAP = {
    "Тип": "hasType",
    "Вид": "hasType",
    "Вид магии": "hasType",
    "Ветвь магии": "hasType",
    "Категория": "hasType",
    "Инкарнация": "formula",
    "Формула": "formula",
    "Слова": "formula",
    "Эффект": "effect",
    "Воздействие": "effect",
    "Описание": "effect",
}


POTION_FIELD_MAP = {
    "Создатель": "hasCreator",
    "Создатели": "hasCreator",
    "Изобретатель": "hasCreator",
    "Изобретательница": "hasCreator",
    "Изобретатели": "hasCreator",
    "Производитель": "hasManufacturer",
    "Производители": "hasManufacturer",
    "Изготовитель": "hasManufacturer",
    "Изготовители": "hasManufacturer",
    "Эффект": "effect",
    "Воздействие": "effect",
    "Описание": "effect",
}


def scrape_spell(title_ru: str) -> bool:
    if should_skip_title(title_ru):
        return False
    subj = ensure_entity(title_ru, classes["Spell"])
    url = fandom_url(title_ru)
    soup = http_get(url)
    if not soup:
        logger.warning("Пропуск заклинания (нет доступа): %s", title_ru)
        return True
    info = parse_infobox(soup)
    if not info:
        return True

    for key, val in info.items():
        prop_key = SPELL_FIELD_MAP.get(key)
        if not prop_key or prop_key not in data_props:
            continue
        text_parts = []
        if val.get("links"):
            text_parts.extend([t.strip() for t in val["links"] if t and not should_skip_title(t)])
        raw_text = val.get("text", "").strip()
        if raw_text:
            text_parts.append(raw_text)
        text_parts = [t for t in text_parts if t]
        if not text_parts:
            continue
        literal_text = "; ".join(dict.fromkeys(text_parts))
        g.add((subj, data_props[prop_key], Literal(literal_text, lang="ru")))
        logger.info("✨ Заклинание: %s --%s--> %s", title_ru, prop_key, literal_text)
        bump_counter()
    return True


def scrape_potion(title_ru: str) -> bool:
    if should_skip_title(title_ru):
        return False
    subj = ensure_entity(title_ru, classes["Potion"])
    url = fandom_url(title_ru)
    soup = http_get(url)
    if not soup:
        logger.warning("Пропуск зелья (нет доступа): %s", title_ru)
        return True
    info = parse_infobox(soup)
    if not info:
        return True

    for key, val in info.items():
        prop_key = POTION_FIELD_MAP.get(key)
        if not prop_key:
            continue
        if prop_key in obj_props:
            fallback = classes["Thing"]
            added = False
            if val.get("links"):
                link_by_titles(subj, obj_props[prop_key], val["links"], fallback)
                added = True
            else:
                text = val.get("text", "").strip()
                if text and not should_skip_title(text):
                    obj = ensure_entity(text, fallback)
                    g.add((subj, obj_props[prop_key], obj))
                    added = True
            if added:
                logger.info("🧪 Зелье (obj): %s --%s--> %s", title_ru, prop_key, val.get("text", ""))
                bump_counter()
        elif prop_key in data_props:
            text = val.get("text", "").strip()
            if text:
                g.add((subj, data_props[prop_key], Literal(text, lang="ru")))
                logger.info("🧪 Зелье: %s --%s--> %s", title_ru, prop_key, text)
                bump_counter()
    return True


def scrape_single_page_as(label_ru: str, rdf_type: URIRef):
    if should_skip_title(label_ru):
        return
    ensure_entity(label_ru, rdf_type)

category_prefix_cache: dict[str, list[str]] = {}


def fetch_categories_by_prefix(prefix: str, limit: int = 20) -> list[str]:
    """
    Возвращает список существующих категорий, начинающихся с указанного префикса.
    """
    if not prefix:
        return []
    prefix = prefix.strip()
    if not prefix:
        return []
    if prefix in category_prefix_cache:
        return category_prefix_cache[prefix]

    params = {
        "action": "query",
        "format": "json",
        "list": "allcategories",
        "acprefix": prefix,
        "aclimit": limit,
        "acprop": "size",
    }
    try:
        resp = session.get(API_ENDPOINT, params=params, timeout=20)
        if resp.status_code != 200:
            logger.debug("Не удалось получить категории с префиксом %s (HTTP %s)", prefix, resp.status_code)
            category_prefix_cache[prefix] = []
            return []
        data = resp.json()
        cats = [c.get("*") for c in data.get("query", {}).get("allcategories", []) if c.get("*")]
        category_prefix_cache[prefix] = cats
        return cats
    except (requests.RequestException, ValueError) as exc:
        logger.debug("Ошибка получения категорий по префиксу %s: %s", prefix, exc)
        category_prefix_cache[prefix] = []
        return []


def _iter_category_members_api(category_title_ru: str, cap: int | None = None, include_subcategories: bool = False):
    seen_titles: set[str] = set()
    seen_categories: set[str] = set()
    queue = [_cleanup_category_title(category_title_ru)]
    total = 0

    headers = {"User-Agent": "hp-kg-populator/1.0"}

    while queue:
        current_cat = queue.pop(0)
        if not current_cat or current_cat in seen_categories:
            continue
        seen_categories.add(current_cat)

        cmcontinue = None
        while True:
            params = {
                "action": "query",
                "format": "json",
                "list": "categorymembers",
                "cmlimit": 500,
                "cmtitle": f"Категория:{current_cat}",
                "cmprop": "title|type|ids",
                "cmnamespace": "0|14",
            }
            if cmcontinue:
                params["cmcontinue"] = cmcontinue
            try:
                resp = session.get(API_ENDPOINT, params=params, headers=headers, timeout=20)
                if resp.status_code != 200:
                    logger.warning("Категория API HTTP %s: %s", resp.status_code, current_cat)
                    return
                data = resp.json()
            except (requests.RequestException, ValueError) as exc:
                logger.warning("Ошибка API категории %s: %s", current_cat, exc)
                return

            members = data.get("query", {}).get("categorymembers", [])
            for member in members:
                title = (member.get("title") or "").strip()
                if not title:
                    continue
                ns = member.get("ns")
                if ns == 14:
                    if include_subcategories:
                        sub_title = _cleanup_category_title(title)
                        if sub_title and sub_title not in seen_categories:
                            queue.append(sub_title)
                    continue
                if should_skip_title(title) or title in seen_titles:
                    continue
                seen_titles.add(title)
                yield title
                total += 1
                if cap and total >= cap:
                    return

            cmcontinue = data.get("continue", {}).get("cmcontinue")
            if not cmcontinue:
                break


def _cleanup_category_title(title: str | None) -> str:
    if not title:
        return ""
    cleaned = title.strip()
    for prefix in ("Категория:", "Category:"):
        if cleaned.startswith(prefix):
            cleaned = cleaned[len(prefix):]
    return cleaned.strip()


def _extract_category_name(href: str, fallback: str | None = None) -> Optional[str]:
    candidate = urllib.parse.unquote(href or "")
    marker_pos = -1
    for marker in ("/Категория:", "/Category:"):
        marker_pos = candidate.find(marker)
        if marker_pos != -1:
            candidate = candidate[marker_pos + len(marker):]
            break
    else:
        candidate = fallback or ""
    candidate = candidate.replace("_", " ")
    candidate = _cleanup_category_title(candidate)
    return candidate or None
def _iter_category_members_html(category_title_ru: str, cap: int | None = None, include_subcategories: bool = False):
    seen_titles: set[str] = set()
    seen_categories: set[str] = set()
    queue = [_cleanup_category_title(category_title_ru)]
    total = 0

    while queue:
        current_cat = queue.pop(0)
        if not current_cat:
            continue
        if current_cat in seen_categories:
            continue
        seen_categories.add(current_cat)

        url = fandom_url("Категория:" + current_cat)
        while url:
            soup = http_get(url)
            if not soup:
                break
            for a in soup.select("a.category-page__member-link"):
                href = a.get("href") or ""
                title = (a.get("title") or a.get_text(strip=True) or "").strip()
                if not title:
                    continue
                if "/Категория:" in href or "/Category:" in href:
                    if include_subcategories:
                        sub_title = _extract_category_name(href, title)
                        if sub_title and sub_title not in seen_categories:
                            queue.append(sub_title)
                    continue
                if should_skip_title(title) or title in seen_titles:
                    continue
                seen_titles.add(title)
                yield title
                total += 1
                if cap and total >= cap:
                    return
            next_a = soup.select_one('a.category-page__pagination-next')
            url = next_a["href"] if (next_a and next_a.get("href")) else None
            if url and url.startswith("/"):
                url = urllib.parse.urljoin(BASE, url)


def iter_category_members(category_title_ru: str, cap: int | None = None, include_subcategories: bool = False):
    yielded_any = False
    for title in _iter_category_members_api(category_title_ru, cap=cap, include_subcategories=include_subcategories):
        yielded_any = True
        yield title
    if yielded_any:
        return
    logger.info("API не вернул элементы категории %s, резервный HTML-парсинг", category_title_ru)
    for title in _iter_category_members_html(category_title_ru, cap=cap, include_subcategories=include_subcategories):
        yield title

def scrape_category_characters(category_title_ru: str, cap: int, delay: float = 0.2):
    logger.info("Категория персонажей: %s (cap=%s)", category_title_ru, cap)
    for title in iter_category_members(category_title_ru, cap=cap):
        scrape_character(title)
        ##time.sleep(delay)

def scrape_category_entities(
    category_title_ru: str,
    rdf_type: URIRef,
    cap: int,
    delay: float = 0.1,
    include_subcategories: bool = False,
) -> int:
    logger.info(
        "Категория сущностей: %s → %s (cap=%s, subcats=%s)",
        category_title_ru,
        qn(rdf_type),
        cap,
        include_subcategories,
    )
    produced = 0
    handler = ENTITY_TYPE_HANDLERS.get(rdf_type)
    for title in iter_category_members(
        category_title_ru, cap=cap, include_subcategories=include_subcategories
    ):
        if handler:
            if handler(title):
                produced += 1
        else:
            ensure_entity(title, rdf_type)
            produced += 1
        ##time.sleep(delay)
    return produced

CHAR_SEED = [
    "Гарри Поттер","Гермиона Грейнджер","Рон Уизли","Альбус Дамблдор","Северус Снегг",
    "Драко Малфой","Рубеус Хагрид","Минерва Макгонагалл","Сириус Блэк","Лорд Волан-де-Морт",
]
MUGGLE_SEED = [
    "Вернон Дурсль", "Петуния Дурсль", "Дадли Дурсль",
    "Мардж Дурсль",  "Флетчер", "Франк Брайт",
    "Том Реддл (старший)", "Мэри Реддл"]
SQUIB_SEED = [
    "Аргус Филч",
    "Арабелла Фигг",
]
HOUSES = ["Гриффиндор", "Слизерин", "Когтевран", "Пуффендуй"]
ORGS = ["Орден Феникса", "Пожиратели смерти", "Министерство магии"]
LOCATIONS = ["Хогвартс", "Косой переулок", "Хогсмид", "Азкабан"]

PERSON_CATS = [
    "Персонажи", "Люди", "Маги", "Ученики Хогвартса", "Преподаватели Хогвартса",
    "Домовые эльфы", "Привидения", "Кентавры", "Акромантулы", "Великаны", "Русалки",
]

ENTITY_CATS = [
    {
        "names": ["Локации", "Места", "Локации (Гарри Поттер)"],
        "type": classes["Location"],
        "include_subcategories": True,
        "keywords": ["Локаци", "Места", "Город", "Село"],
    },
    {
        "names": ["Организации"],
        "type": classes["Organization"],
        "include_subcategories": False,
    },
    {
        "names": ["Артефакты", "Предметы", "Магические предметы", "Волшебные предметы", "Магические артефакты"],
        "type": classes["Artifact"],
        "include_subcategories": True,
        "keywords": ["Артефакт", "Предмет", "Магические предметы", "Волшебные предметы", "Магические артефакты"],
    },
    {
        "names": ["Должности"],
        "type": classes["Role"],
        "include_subcategories": False,
    },
]

ENTITY_TYPE_HANDLERS: dict[URIRef, callable] = {
    classes["Artifact"]: scrape_artifact,
    classes["Spell"]: scrape_spell,
    classes["Potion"]: scrape_potion,
}

def parse_cli_args():
    parser = argparse.ArgumentParser(
        description="Скрапит ru.fandom и наполняет RDF-онтологию по Гарри Поттеру."
    )
    parser.add_argument(
        "--output",
        default=OUT_FILE,
        help="Путь к TTL-файлу для сохранения (по умолчанию %(default)s)",
    )
    parser.add_argument(
        "--load",
        default=None,
        help="TTL-файл для предварительной загрузки. "
             "Если не задан и --fresh не указан, будет использоваться --output (если существует).",
    )
    parser.add_argument(
        "--fresh",
        action="store_true",
        help="Игнорировать существующий файл и строить граф с нуля.",
    )
    parser.add_argument(
        "--spell-cap",
        type=int,
        default=200,
        help="Максимальное количество заклинаний из категорий (по умолчанию %(default)s).",
    )
    parser.add_argument(
        "--potion-cap",
        type=int,
        default=200,
        help="Максимальное количество зелий из категорий (по умолчанию %(default)s).",
    )
    return parser.parse_args()


def main():
    args = parse_cli_args()
    global OUT_FILE
    OUT_FILE = args.output

    load_path = None
    if args.load:
        load_path = args.load
    elif not args.fresh:
        candidate = Path(args.output)
        if candidate.exists():
            load_path = args.output
    if load_path:
        load_existing_graph(load_path)

    for h in HOUSES: scrape_single_page_as(h, classes["House"])
    for o in ORGS:   scrape_single_page_as(o, classes["Organization"])
    for l in LOCATIONS: scrape_single_page_as(l, classes["Location"])

    for name in CHAR_SEED:
        scrape_character(name)
        # time.sleep(0.4)
    for name in MUGGLE_SEED:
        scrape_character(name)
    for name in SQUIB_SEED:
        scrape_character(name)

    for cat in PERSON_CATS:
        cap = 500 if cat in ("Люди", "Персонажи") else 200
        scrape_category_characters(cat, cap=cap, delay=0.15)

    for cfg in ENTITY_CATS:
        names = cfg["names"]
        rdf_type = cfg["type"]
        include_subcats = cfg.get("include_subcategories", False)
        cap = cfg.get("cap", 300)
        if isinstance(names, str):
            names = [names]

        candidate_names: list[str] = []
        seen_names: set[str] = set()
        for n in names:
            cleaned = _cleanup_category_title(n)
            if cleaned and cleaned not in seen_names:
                candidate_names.append(cleaned)
                seen_names.add(cleaned)

        for keyword in cfg.get("keywords", []) or []:
            for suggested in fetch_categories_by_prefix(keyword):
                cleaned = _cleanup_category_title(suggested)
                if cleaned and cleaned not in seen_names:
                    candidate_names.append(cleaned)
                    seen_names.add(cleaned)

        scraped = False
        for cat_name in candidate_names:
            produced = scrape_category_entities(
                cat_name,
                rdf_type,
                cap=cap,
                delay=0.1,
                include_subcategories=include_subcats,
            )
            if produced:
                scraped = True
                break
        if not scraped:
            logger.warning(
                "Не удалось извлечь сущности для категорий %s → %s",
                ", ".join(candidate_names) or "(нет кандидатов)",
                qn(rdf_type),
            )

    scrape_category_entities(
        "Заклинания",
        classes["Spell"],
        cap=args.spell_cap,
        delay=0.1,
        include_subcategories=True,
    )
    scrape_category_entities(
        "Зелья",
        classes["Potion"],
        cap=args.potion_cap,
        delay=0.1,
        include_subcategories=True,
    )

    save_checkpoint(force=True)
    logger.info("Готово. Триплетов в графе: %s", len(g))

if __name__ == "__main__":
    import sys
    sys.argv = ['harrypotter_kg_ru.py', '--fresh']
    main()
# Out:
# Overwriting harrypotter_kg_ru.py

# %%
# !python harrypotter_kg_ru.py
# Out:
# 2025-12-17 08:51:07,235 [INFO] hpo:House ← Гриффиндор (hpo:Griffindor)
# 2025-12-17 08:51:07,235 [INFO] hpo:House ← Слизерин (hpo:Slizerin)
# 2025-12-17 08:51:07,235 [INFO] hpo:House ← Когтевран (hpo:Kogtevran)
# 2025-12-17 08:51:07,236 [INFO] hpo:House ← Пуффендуй (hpo:Puffendui)
# 2025-12-17 08:51:07,236 [INFO] hpo:Organization ← Орден Феникса (hpo:Orden_Feniksa)
# 2025-12-17 08:51:07,236 [INFO] hpo:Organization ← Пожиратели смерти (hpo:Pozhirateli_smerti)
# 2025-12-17 08:51:07,236 [INFO] hpo:Organization ← Министерство магии (hpo:Ministerstvo_magii)
# 2025-12-17 08:51:07,236 [INFO] hpo:Location ← Хогвартс (hpo:Khogvarts)
# 2025-12-17 08:51:07,236 [INFO] hpo:Location ← Косой переулок (hpo:Kosoi_pereulok)
# 2025-12-17 08:51:07,237 [INFO] hpo:Location ← Хогсмид (hpo:Khogsmid)
# 2025-12-17 08:51:07,237 [INFO] hpo:Location ← Азкабан (hpo:Azkaban)
# 2025-12-17 08:51:07,609 [INFO] hpo:Wizard ← Гарри Поттер (hpo:Garri_Potter)
# 2025-12-17 08:51:07,610 [INFO] hpo:facultet Гарри Поттер -> Гриффиндор
# 2025-12-17 08:51:07,610 [INFO] hpo:wand Гарри Поттер -> Oстролист, перо феникса, 11 дюймов Терновник, неизвестная сердцевина, 10 дюймов (временно) Боярышник, волос единорога, 10 дюймов (временно) Бузина, волос фестрала, 15 дюймов (временно)
# 2025-12-17 08:51:07,610 [INFO] hpo:patronus Гарри Поттер -> Олень
# 2025-12-17 08:51:07,610 [INFO] hpo:Role ← Мракоборец Глава Управления мракоборцев Несколько лекций в году по ЗОТИ в Хогвартсе Глава Отдела магического правопорядка (hpo:Mrakoborets_Glava_Upravleniia_mrakobortsev_Neskolko_lektsii_v_godu_po_ZOTI_v_Khogvartse_Glava_Otdela_magicheskogo_pravoporiadka)
# 2025-12-17 08:51:07,610 [INFO] hpo:job Гарри Поттер -> Мракоборец Глава Управления мракоборцев Несколько лекций в году по ЗОТИ в Хогвартсе Глава Отдела магического правопорядка
# 2025-12-17 08:51:07,790 [INFO] hpo:Human ← Джинни Уизли (hpo:Dzhinni_Uizli)
# 2025-12-17 08:51:08,011 [INFO] hpo:Wizard ← Игнотус Певерелл (hpo:Ignotus_Peverell)
# 2025-12-17 08:51:08,011 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --relativeOf--> Игнотус Певерелл
# 2025-12-17 08:51:08,232 [INFO] hpo:Human ← Линфред Стинчкомбский (hpo:Linfred_Stinchkombskii)
# 2025-12-17 08:51:08,232 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --relativeOf--> Линфред Стинчкомбский
# 2025-12-17 08:51:08,440 [INFO] hpo:Wizard ← Флимонт Поттер (hpo:Flimont_Potter)
# 2025-12-17 08:51:08,440 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasGrandparent--> Флимонт Поттер
# 2025-12-17 08:51:08,713 [INFO] hpo:Human ← Юфимия Поттер (hpo:Iufimiia_Potter)
# 2025-12-17 08:51:08,714 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasGrandparent--> Юфимия Поттер
# 2025-12-17 08:51:08,999 [INFO] hpo:Wizard ← Джеймс Поттер (hpo:Dzheims_Potter)
# 2025-12-17 08:51:08,999 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasFather--> Джеймс Поттер
# 2025-12-17 08:51:09,320 [INFO] hpo:Wizard ← Лили Поттер (hpo:Lili_Potter)
# 2025-12-17 08:51:09,320 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasMother--> Лили Поттер
# 2025-12-17 08:51:09,630 [INFO] hpo:Muggle ← Петуния Дурсль (hpo:Petuniia_Dursl)
# 2025-12-17 08:51:09,631 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasAunt--> Петуния Дурсль
# 2025-12-17 08:51:09,948 [INFO] hpo:Muggle ← Вернон Дурсль (hpo:Vernon_Dursl)
# 2025-12-17 08:51:09,948 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasUncle--> Вернон Дурсль
# 2025-12-17 08:51:10,217 [INFO] hpo:Muggle ← Дадли Дурсль (hpo:Dadli_Dursl)
# 2025-12-17 08:51:10,218 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --cousinOf--> Дадли Дурсль
# 2025-12-17 08:51:10,503 [INFO] hpo:Wizard ← Артур Уизли (hpo:Artur_Uizli)
# 2025-12-17 08:51:10,503 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasFather--> Артур Уизли
# 2025-12-17 08:51:10,691 [INFO] hpo:Human ← Молли Уизли (hpo:Molli_Uizli)
# 2025-12-17 08:51:10,691 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasMother--> Молли Уизли
# 2025-12-17 08:51:10,691 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --marriedWith--> Джинни Уизли
# 2025-12-17 08:51:10,830 [INFO] hpo:Wizard ← Джеймс Сириус Поттер (hpo:Dzheims_Sirius_Potter)
# 2025-12-17 08:51:10,830 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasSon--> Джеймс Сириус Поттер
# 2025-12-17 08:51:11,052 [INFO] hpo:Wizard ← Альбус Северус Поттер (hpo:Albus_Severus_Potter)
# 2025-12-17 08:51:11,052 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasSon--> Альбус Северус Поттер
# 2025-12-17 08:51:11,190 [INFO] hpo:Wizard ← Лили Полумна Поттер (hpo:Lili_Polumna_Potter)
# 2025-12-17 08:51:11,190 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --hasDaughter--> Лили Полумна Поттер
# 2025-12-17 08:51:11,322 [INFO] hpo:Wizard ← Тедди Люпин (hpo:Teddi_Liupin)
# 2025-12-17 08:51:11,323 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гарри Поттер --godsonOf--> Тедди Люпин
# 2025-12-17 08:51:11,641 [INFO] hpo:Wizard ← Гермиона Грейнджер (hpo:Germiona_Greindzher)
# 2025-12-17 08:51:11,641 [INFO] hpo:facultet Гермиона Грейнджер -> Гриффиндор
# 2025-12-17 08:51:11,641 [INFO] hpo:wand Гермиона Грейнджер -> Виноградная лоза, сердечная жила дракона, 10¾ дюймов Грецкий орех, сердечная жила дракона, 12¾ дюймов (временно)
# 2025-12-17 08:51:11,641 [INFO] hpo:patronus Гермиона Грейнджер -> Выдра
# 2025-12-17 08:51:11,642 [INFO] hpo:Role ← Отдел регулирования магических популяций и контроля над ними Заместитель руководителя Отдела магического правопорядка Министр магии Профессор Защиты от Тёмных искусств (альтернативная реальность) (hpo:Otdel_regulirovaniia_magicheskikh_populiatsii_i_kontrolia_nad_nimi_Zamestitel_rukovoditelia_Otdela_magicheskogo_pravoporiadka_Ministr_magii_Professor_Zashchity_ot_Tiomnykh_iskusstv_alternativnaia_realnost)
# 2025-12-17 08:51:11,642 [INFO] hpo:job Гермиона Грейнджер -> Отдел регулирования магических популяций и контроля над ними Заместитель руководителя Отдела магического правопорядка Министр магии Профессор Защиты от Тёмных искусств (альтернативная реальность)
# 2025-12-17 08:51:12,002 [INFO] hpo:Wizard ← Рон Уизли (hpo:Ron_Uizli)
# 2025-12-17 08:51:12,123 [INFO] hpo:Muggle ← Мистер Грейнджер (hpo:Mister_Greindzher)
# 2025-12-17 08:51:12,123 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasFather--> Мистер Грейнджер
# 2025-12-17 08:51:12,246 [INFO] hpo:Muggle ← Миссис Грейнджер (hpo:Missis_Greindzher)
# 2025-12-17 08:51:12,246 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasMother--> Миссис Грейнджер
# 2025-12-17 08:51:12,246 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasFather--> Артур Уизли
# 2025-12-17 08:51:12,246 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasMother--> Молли Уизли
# 2025-12-17 08:51:12,246 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --marriedWith--> Рон Уизли
# 2025-12-17 08:51:12,390 [INFO] hpo:Wizard ← Роза Грейнджер-Уизли (hpo:Roza_Greindzher-Uizli)
# 2025-12-17 08:51:12,390 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasDaughter--> Роза Грейнджер-Уизли
# 2025-12-17 08:51:12,520 [INFO] hpo:Wizard ← Хьюго Грейнджер-Уизли (hpo:Khiugo_Greindzher-Uizli)
# 2025-12-17 08:51:12,520 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasSon--> Хьюго Грейнджер-Уизли
# 2025-12-17 08:51:12,796 [INFO] hpo:Human ← Джинни Поттер (hpo:Dzhinni_Potter)
# 2025-12-17 08:51:12,796 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasSister--> Джинни Поттер
# 2025-12-17 08:51:12,796 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --sonOf--> Гарри Поттер
# 2025-12-17 08:51:12,796 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNephew--> Альбус Северус Поттер
# 2025-12-17 08:51:12,796 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNephew--> Джеймс Сириус Поттер
# 2025-12-17 08:51:12,796 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNiece--> Лили Полумна Поттер
# 2025-12-17 08:51:12,955 [INFO] hpo:Wizard ← Билл Уизли (hpo:Bill_Uizli)
# 2025-12-17 08:51:12,955 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasBrother--> Билл Уизли
# 2025-12-17 08:51:13,110 [INFO] hpo:Human ← Флёр Делакур (hpo:Flior_Delakur)
# 2025-12-17 08:51:13,110 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --daughterOf--> Флёр Делакур
# 2025-12-17 08:51:13,239 [INFO] hpo:Wizard ← Мари-Виктуар Уизли (hpo:Mari-Viktuar_Uizli)
# 2025-12-17 08:51:13,239 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNiece--> Мари-Виктуар Уизли
# 2025-12-17 08:51:13,363 [INFO] hpo:Human ← Доминик Уизли (hpo:Dominik_Uizli)
# 2025-12-17 08:51:13,363 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNiece--> Доминик Уизли
# 2025-12-17 08:51:13,556 [INFO] hpo:Human ← Луи Уизли (hpo:Lui_Uizli)
# 2025-12-17 08:51:13,556 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNephew--> Луи Уизли
# 2025-12-17 08:51:13,718 [INFO] hpo:Wizard ← Чарли Уизли (hpo:Charli_Uizli)
# 2025-12-17 08:51:13,718 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasBrother--> Чарли Уизли
# 2025-12-17 08:51:13,923 [INFO] hpo:Wizard ← Перси Уизли (hpo:Persi_Uizli)
# 2025-12-17 08:51:13,923 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasBrother--> Перси Уизли
# 2025-12-17 08:51:14,043 [INFO] hpo:Human ← Одри Уизли (hpo:Odri_Uizli)
# 2025-12-17 08:51:14,044 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --daughterOf--> Одри Уизли
# 2025-12-17 08:51:14,054 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%9C%D0%BE%D0%BB%D0%BB%D0%B8_%D0%A3%D0%B8%D0%B7%D0%BB%D0%B8-%D0%BC%D0%BB%D0%B0%D0%B4%D1%88%D0%B0%D1%8F
# 2025-12-17 08:51:14,055 [INFO] hpo:Character ← Молли Уизли-младшая (hpo:Molli_Uizli-mladshaia)
# 2025-12-17 08:51:14,055 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNiece--> Молли Уизли-младшая
# 2025-12-17 08:51:14,172 [INFO] hpo:Squib ← Люси Уизли (hpo:Liusi_Uizli)
# 2025-12-17 08:51:14,172 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNiece--> Люси Уизли
# 2025-12-17 08:51:14,504 [INFO] hpo:Wizard ← Фред Уизли (hpo:Fred_Uizli)
# 2025-12-17 08:51:14,504 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasBrother--> Фред Уизли
# 2025-12-17 08:51:14,690 [INFO] hpo:Wizard ← Джордж Уизли (hpo:Dzhordzh_Uizli)
# 2025-12-17 08:51:14,691 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasBrother--> Джордж Уизли
# 2025-12-17 08:51:14,866 [INFO] hpo:Human ← Анджелина Джонсон (hpo:Andzhelina_Dzhonson)
# 2025-12-17 08:51:14,866 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --daughterOf--> Анджелина Джонсон
# 2025-12-17 08:51:14,876 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%A4%D1%80%D0%B5%D0%B4_%D0%A3%D0%B8%D0%B7%D0%BB%D0%B8-%D0%BC%D0%BB%D0%B0%D0%B4%D1%88%D0%B8%D0%B9
# 2025-12-17 08:51:14,876 [INFO] hpo:Character ← Фред Уизли-младший (hpo:Fred_Uizli-mladshii)
# 2025-12-17 08:51:14,876 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNephew--> Фред Уизли-младший
# 2025-12-17 08:51:14,993 [INFO] hpo:Wizard ← Роксана Уизли (hpo:Roksana_Uizli)
# 2025-12-17 08:51:14,993 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Гермиона Грейнджер --hasNiece--> Роксана Уизли
# 2025-12-17 08:51:15,389 [INFO] hpo:facultet Рон Уизли -> Гриффиндор
# 2025-12-17 08:51:15,390 [INFO] hpo:wand Рон Уизли -> Ясень, волос единорога, 12 дюймов Ива, волос единорога, 14 дюймов Каштан, сердечная жила дракона, 9¼ дюйма
# 2025-12-17 08:51:15,390 [INFO] hpo:patronus Рон Уизли -> Джек-рассел-терьер
# 2025-12-17 08:51:15,390 [INFO] hpo:Role ← Мракоборец (ранее) Совладелец магазина « Всевозможные волшебные вредилки » (hpo:Mrakoborets_ranee_Sovladelets_magazina__Vsevozmozhnye_volshebnye_vredilki_)
# 2025-12-17 08:51:15,390 [INFO] hpo:job Рон Уизли -> Мракоборец (ранее) Совладелец магазина « Всевозможные волшебные вредилки »
# 2025-12-17 08:51:15,515 [INFO] hpo:Wizard ← Септимус Уизли (hpo:Septimus_Uizli)
# 2025-12-17 08:51:15,515 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasGrandparent--> Септимус Уизли
# 2025-12-17 08:51:15,524 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%A1%D0%B5%D0%B4%D1%80%D0%B5%D0%BB%D0%BB%D0%B0_%D0%A3%D0%B8%D0%B7%D0%BB%D0%B8
# 2025-12-17 08:51:15,525 [INFO] hpo:Character ← Седрелла Уизли (hpo:Sedrella_Uizli)
# 2025-12-17 08:51:15,525 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasGrandparent--> Седрелла Уизли
# 2025-12-17 08:51:15,642 [INFO] hpo:Wizard ← Мистер Пруэтт (hpo:Mister_Pruett)
# 2025-12-17 08:51:15,642 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasGrandparent--> Мистер Пруэтт
# 2025-12-17 08:51:15,758 [INFO] hpo:Wizard ← Миссис Пруэтт (hpo:Missis_Pruett)
# 2025-12-17 08:51:15,759 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasGrandparent--> Миссис Пруэтт
# 2025-12-17 08:51:15,904 [INFO] hpo:Wizard ← Тётушка Мюриэль (hpo:Tiotushka_Miuriel)
# 2025-12-17 08:51:15,905 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasGrandparent--> Тётушка Мюриэль
# 2025-12-17 08:51:16,078 [INFO] hpo:Wizard ← Ланселот (hpo:Lanselot)
# 2025-12-17 08:51:16,078 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasGrandparent--> Ланселот
# 2025-12-17 08:51:16,088 [INFO] Сохранено в harrypotter_kg_ru.ttl (триплетов: 273)
# 2025-12-17 08:51:16,098 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%94%D1%8F%D0%B4%D0%B8_%D0%BF%D0%BE_%D0%BE%D1%82%D1%86%D1%83_%D0%91%D0%B8%D0%BB%D0%B8%D1%83%D1%81
# 2025-12-17 08:51:16,098 [INFO] hpo:Character ← Дяди по отцу Билиус (hpo:Diadi_po_ottsu_Bilius)
# 2025-12-17 08:51:16,099 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasUncle--> Дяди по отцу Билиус
# 2025-12-17 08:51:16,099 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasFather--> Артур Уизли
# 2025-12-17 08:51:16,099 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasMother--> Молли Уизли
# 2025-12-17 08:51:16,231 [INFO] hpo:Wizard ← Фабиан Пруэтт (hpo:Fabian_Pruett)
# 2025-12-17 08:51:16,231 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasUncle--> Фабиан Пруэтт
# 2025-12-17 08:51:16,366 [INFO] hpo:Wizard ← Гидеон Пруэтт (hpo:Gideon_Pruett)
# 2025-12-17 08:51:16,366 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasUncle--> Гидеон Пруэтт
# 2025-12-17 08:51:16,367 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasBrother--> Билл Уизли
# 2025-12-17 08:51:16,367 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --daughterOf--> Флёр Делакур
# 2025-12-17 08:51:16,367 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNiece--> Мари-Виктуар Уизли
# 2025-12-17 08:51:16,367 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNiece--> Доминик Уизли
# 2025-12-17 08:51:16,367 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNephew--> Луи Уизли
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasBrother--> Чарли Уизли
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasBrother--> Перси Уизли
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --daughterOf--> Одри Уизли
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNiece--> Молли Уизли-младшая
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNiece--> Люси Уизли
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasBrother--> Фред Уизли
# 2025-12-17 08:51:16,368 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasBrother--> Джордж Уизли
# 2025-12-17 08:51:16,369 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --daughterOf--> Анджелина Джонсон
# 2025-12-17 08:51:16,369 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNephew--> Фред Уизли-младший
# 2025-12-17 08:51:16,369 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNiece--> Роксана Уизли
# 2025-12-17 08:51:16,369 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasSister--> Джинни Поттер
# 2025-12-17 08:51:16,370 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --sonOf--> Гарри Поттер
# 2025-12-17 08:51:16,370 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasFather--> Мистер Грейнджер
# 2025-12-17 08:51:16,370 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasMother--> Миссис Грейнджер
# 2025-12-17 08:51:16,380 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%93%D0%B5%D1%80%D0%BC%D0%B8%D0%BE%D0%BD%D0%B0_%D0%A3%D0%B8%D0%B7%D0%BB%D0%B8
# 2025-12-17 08:51:16,380 [INFO] hpo:Character ← Гермиона Уизли (hpo:Germiona_Uizli)
# 2025-12-17 08:51:16,381 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --marriedWith--> Гермиона Уизли
# 2025-12-17 08:51:16,381 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasDaughter--> Роза Грейнджер-Уизли
# 2025-12-17 08:51:16,381 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasSon--> Хьюго Грейнджер-Уизли
# 2025-12-17 08:51:16,381 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNephew--> Альбус Северус Поттер
# 2025-12-17 08:51:16,382 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNephew--> Джеймс Сириус Поттер
# 2025-12-17 08:51:16,382 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasNiece--> Лили Полумна Поттер
# 2025-12-17 08:51:16,527 [INFO] hpo:Wizard ← Падма Патил (hpo:Padma_Patil)
# 2025-12-17 08:51:16,528 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --marriedWith--> Падма Патил
# 2025-12-17 08:51:16,619 [INFO] hpo:Character ← Панжу Уизли (hpo:Panzhu_Uizli)
# 2025-12-17 08:51:16,619 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рон Уизли --hasSon--> Панжу Уизли
# 2025-12-17 08:51:17,033 [INFO] hpo:Wizard ← Альбус Дамблдор (hpo:Albus_Dambldor)
# 2025-12-17 08:51:17,034 [INFO] hpo:facultet Альбус Дамблдор -> Гриффиндор
# 2025-12-17 08:51:17,034 [INFO] hpo:wand Альбус Дамблдор -> Первая палочка Альбуса Дамблдора Бузинная палочка
# 2025-12-17 08:51:17,034 [INFO] hpo:patronus Альбус Дамблдор -> Феникс [ 1 ] [ 2 ]
# 2025-12-17 08:51:17,034 [INFO] hpo:Role ← Профессор трансфигурации (до 1955 ) Директор Хогвартса (до 1955 — 1997 ) (hpo:Professor_transfiguratsii_do_1955__Direktor_Khogvartsa_do_1955_--_1997_)
# 2025-12-17 08:51:17,035 [INFO] hpo:job Альбус Дамблдор -> Профессор трансфигурации (до 1955 ) Директор Хогвартса (до 1955 — 1997 )
# 2025-12-17 08:51:17,045 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%9F%D1%80%D0%B0%D0%BF%D1%80%D0%B0%D0%B4%D0%B5%D0%B4_%D0%9F%D0%B5%D1%80%D1%81%D0%B8%D0%B2%D0%B0%D0%BB%D1%8C_%D0%94%D0%B0%D0%BC%D0%B1%D0%BB%D0%B4%D0%BE%D1%80
# 2025-12-17 08:51:17,046 [INFO] hpo:Character ← Прапрадед Персиваль Дамблдор (hpo:Prapraded_Persival_Dambldor)
# 2025-12-17 08:51:17,046 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Альбус Дамблдор --hasFather--> Прапрадед Персиваль Дамблдор
# 2025-12-17 08:51:17,165 [INFO] hpo:Wizard ← Кендра Дамблдор (hpo:Kendra_Dambldor)
# 2025-12-17 08:51:17,165 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Альбус Дамблдор --hasMother--> Кендра Дамблдор
# 2025-12-17 08:51:17,324 [INFO] hpo:Wizard ← Аберфорт Дамблдор (hpo:Aberfort_Dambldor)
# 2025-12-17 08:51:17,324 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Альбус Дамблдор --hasBrother--> Аберфорт Дамблдор
# 2025-12-17 08:51:17,456 [INFO] hpo:Wizard ← Ариана Дамблдор (hpo:Ariana_Dambldor)
# 2025-12-17 08:51:17,456 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Альбус Дамблдор --hasSister--> Ариана Дамблдор
# 2025-12-17 08:51:17,611 [INFO] hpo:Wizard ← Аурелиус Дамблдор (hpo:Aurelius_Dambldor)
# 2025-12-17 08:51:17,611 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Альбус Дамблдор --hasNephew--> Аурелиус Дамблдор
# 2025-12-17 08:51:17,724 [INFO] hpo:Human ← Гонория (hpo:Gonoriia)
# 2025-12-17 08:51:17,724 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Альбус Дамблдор --hasAunt--> Гонория
# 2025-12-17 08:51:18,116 [INFO] hpo:Wizard ← Северус Снегг (hpo:Severus_Snegg)
# 2025-12-17 08:51:18,116 [INFO] hpo:facultet Северус Снегг -> Слизерин
# 2025-12-17 08:51:18,116 [INFO] hpo:wand Северус Снегг -> Палочка Северуса Снегга
# 2025-12-17 08:51:18,116 [INFO] hpo:patronus Северус Снегг -> Лань
# 2025-12-17 08:51:18,117 [INFO] hpo:Role ← Мастер зелий (до 1996 года ) Декан факультета Слизерин ( 1981 — 1996 гг.) Капитан Дуэльного клуба ( 1992 — 1993 гг.) Преподаватель зельеварения ( 1981 — 1996 гг.) Преподаватель ЗоТИ ( 1996 — 1997 гг.) Директор Школа Чародейства и Волшебства Хогвартс ( 1997 — 1998 гг.) ( 1981 - 1998 (hpo:Master_zelii_do_1996_goda__Dekan_fakulteta_Slizerin__1981_--_1996_gg_Kapitan_Duelnogo_kluba__1992_--_1993_gg_Prepodavatel_zelevareniia__1981_--_1996_gg_Prepodavatel_ZoTI__1996_--_1997_gg_Direktor_Shkola_Charodeistva_i_Volshebstva_Khogvarts__1997_--_1998_gg__1981_-_1998)
# 2025-12-17 08:51:18,117 [INFO] hpo:job Северус Снегг -> Мастер зелий (до 1996 года ) Декан факультета Слизерин ( 1981 — 1996 гг.) Капитан Дуэльного клуба ( 1992 — 1993 гг.) Преподаватель зельеварения ( 1981 — 1996 гг.) Преподаватель ЗоТИ ( 1996 — 1997 гг.) Директор Школа Чародейства и Волшебства Хогвартс ( 1997 — 1998 гг.) ( 1981 - 1998
# 2025-12-17 08:51:18,234 [INFO] hpo:Muggle ← Тобиас Снегг (hpo:Tobias_Snegg)
# 2025-12-17 08:51:18,234 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Северус Снегг --hasFather--> Тобиас Снегг
# 2025-12-17 08:51:18,355 [INFO] hpo:Human ← Эйлин Принц (hpo:Eilin_Prints)
# 2025-12-17 08:51:18,355 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Северус Снегг --hasMother--> Эйлин Принц
# 2025-12-17 08:51:18,625 [INFO] hpo:Wizard ← Драко Малфой (hpo:Drako_Malfoi)
# 2025-12-17 08:51:18,625 [INFO] hpo:facultet Драко Малфой -> Слизерин
# 2025-12-17 08:51:18,625 [INFO] hpo:wand Драко Малфой -> 24 см (10"), боярышник и шерсть единорога, упругая Вяз, 18", сердечная жила дракона (временно) Бузина, 15", волос фестрала (временно) Палочка Нарциссы Малфой
# 2025-12-17 08:51:18,819 [INFO] hpo:Wizard ← Астория Гринграсс (hpo:Astoriia_Gringrass)
# 2025-12-17 08:51:18,946 [INFO] hpo:Wizard ← Арманд Малфой (hpo:Armand_Malfoi)
# 2025-12-17 08:51:18,946 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --relativeOf--> Арманд Малфой
# 2025-12-17 08:51:19,067 [INFO] hpo:Wizard ← Николас Малфой (hpo:Nikolas_Malfoi)
# 2025-12-17 08:51:19,068 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --relativeOf--> Николас Малфой
# 2025-12-17 08:51:19,181 [INFO] hpo:Wizard ← Люциус Малфой I (hpo:Liutsius_Malfoi_I)
# 2025-12-17 08:51:19,181 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --relativeOf--> Люциус Малфой I
# 2025-12-17 08:51:19,298 [INFO] hpo:Wizard ← Брутус Малфой (hpo:Brutus_Malfoi)
# 2025-12-17 08:51:19,299 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --relativeOf--> Брутус Малфой
# 2025-12-17 08:51:19,439 [INFO] hpo:Wizard ← Септимус Малфой (hpo:Septimus_Malfoi)
# 2025-12-17 08:51:19,440 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --relativeOf--> Септимус Малфой
# 2025-12-17 08:51:19,640 [INFO] hpo:Wizard ← Абраксас Малфой (hpo:Abraksas_Malfoi)
# 2025-12-17 08:51:19,640 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasGrandparent--> Абраксас Малфой
# 2025-12-17 08:51:19,849 [INFO] hpo:Wizard ← Люциус Малфой (hpo:Liutsius_Malfoi)
# 2025-12-17 08:51:19,849 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasFather--> Люциус Малфой
# 2025-12-17 08:51:20,022 [INFO] hpo:Human ← Нарцисса Малфой (hpo:Nartsissa_Malfoi)
# 2025-12-17 08:51:20,022 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasMother--> Нарцисса Малфой
# 2025-12-17 08:51:20,204 [INFO] hpo:Human ← Беллатриса Лестрейндж (hpo:Bellatrisa_Lestreindzh)
# 2025-12-17 08:51:20,205 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasAunt--> Беллатриса Лестрейндж
# 2025-12-17 08:51:20,421 [INFO] hpo:Wizard ← Родольфус Лестрейндж (hpo:Rodolfus_Lestreindzh)
# 2025-12-17 08:51:20,421 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasUncle--> Родольфус Лестрейндж
# 2025-12-17 08:51:20,678 [INFO] hpo:Human ← Андромеда Тонкс (hpo:Andromeda_Tonks)
# 2025-12-17 08:51:20,678 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasAunt--> Андромеда Тонкс
# 2025-12-17 08:51:20,904 [INFO] hpo:Wizard ← Тед Тонкс (hpo:Ted_Tonks)
# 2025-12-17 08:51:20,904 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasUncle--> Тед Тонкс
# 2025-12-17 08:51:21,135 [INFO] hpo:Wizard ← Дельфи (hpo:Delfi)
# 2025-12-17 08:51:21,135 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --cousinOf--> Дельфи
# 2025-12-17 08:51:21,136 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --marriedWith--> Астория Гринграсс
# 2025-12-17 08:51:21,350 [INFO] hpo:Wizard ← Скорпиус Малфой (hpo:Skorpius_Malfoi)
# 2025-12-17 08:51:21,350 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --hasSon--> Скорпиус Малфой
# 2025-12-17 08:51:21,761 [INFO] hpo:Wizard ← Нимфадора Тонкс (hpo:Nimfadora_Tonks)
# 2025-12-17 08:51:21,762 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Драко Малфой --cousinOf--> Нимфадора Тонкс
# 2025-12-17 08:51:22,153 [INFO] hpo:Giant ← Рубеус Хагрид (hpo:Rubeus_Khagrid)
# 2025-12-17 08:51:22,153 [INFO] hpo:wand Рубеус Хагрид -> Дуб, 16 дюймов [ 1 ]
# 2025-12-17 08:51:22,153 [INFO] hpo:patronus Рубеус Хагрид -> Нет
# 2025-12-17 08:51:22,153 [INFO] hpo:Role ← Привратник Хогвартса Преподаватель Ухода за магическими существами Лесничий Специальный посланник (hpo:Privratnik_Khogvartsa_Prepodavatel_Ukhoda_za_magicheskimi_sushchestvami_Lesnichii_Spetsialnyi_poslannik)
# 2025-12-17 08:51:22,153 [INFO] hpo:job Рубеус Хагрид -> Привратник Хогвартса Преподаватель Ухода за магическими существами Лесничий Специальный посланник
# 2025-12-17 08:51:22,354 [INFO] hpo:Wizard ← Мистер Хагрид (hpo:Mister_Khagrid)
# 2025-12-17 08:51:22,354 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рубеус Хагрид --hasFather--> Мистер Хагрид
# 2025-12-17 08:51:22,541 [INFO] hpo:Giant ← Фридвульфа (hpo:Fridvulfa)
# 2025-12-17 08:51:22,541 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рубеус Хагрид --hasMother--> Фридвульфа
# 2025-12-17 08:51:22,774 [INFO] hpo:Giant ← Грохх (hpo:Grokhkh)
# 2025-12-17 08:51:22,774 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Рубеус Хагрид --hasBrother--> Грохх
# 2025-12-17 08:51:24,052 [INFO] hpo:Wizard ← Минерва Макгонагалл (hpo:Minerva_Makgonagall)
# 2025-12-17 08:51:24,052 [INFO] hpo:wand Минерва Макгонагалл -> Пихта и сердечная жила дракона, 9,5 дюймов, жесткая [ 1 ]
# 2025-12-17 08:51:24,052 [INFO] hpo:patronus Минерва Макгонагалл -> Кошка
# 2025-12-17 08:51:24,052 [INFO] hpo:Role ← Сотрудница Отдела магического правопорядка ( 1954 — 1956 ) Профессор трансфигурации в Хогвартсе ( 1956 — 1998 ) Декан факультета Гриффиндор [ 3 ] (19??— 1998 ) Заместитель директора (19??— 1998 ) [ 3 ] Директор Хогвартса ( 1998 — 2010 / 2017 ) (hpo:Sotrudnitsa_Otdela_magicheskogo_pravoporiadka__1954_--_1956__Professor_transfiguratsii_v_Khogvartse__1956_--_1998__Dekan_fakulteta_Griffindor__3__19--_1998__Zamestitel_direktora_19--_1998___3__Direktor_Khogvartsa__1998_--_2010_2017_)
# 2025-12-17 08:51:24,053 [INFO] hpo:job Минерва Макгонагалл -> Сотрудница Отдела магического правопорядка ( 1954 — 1956 ) Профессор трансфигурации в Хогвартсе ( 1956 — 1998 ) Декан факультета Гриффиндор [ 3 ] (19??— 1998 ) Заместитель директора (19??— 1998 ) [ 3 ] Директор Хогвартса ( 1998 — 2010 / 2017 )
# 2025-12-17 08:51:24,191 [INFO] hpo:Wizard ← Элфинстоун Урхарт (hpo:Elfinstoun_Urkhart)
# 2025-12-17 08:51:24,340 [INFO] hpo:Wizard ← Изабель Росс (hpo:Izabel_Ross)
# 2025-12-17 08:51:24,340 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Минерва Макгонагалл --hasMother--> Изабель Росс
# 2025-12-17 08:51:24,357 [INFO] Сохранено в harrypotter_kg_ru.ttl (триплетов: 443)
# 2025-12-17 08:51:24,489 [INFO] hpo:Muggle ← Роберт Макгонагалл (hpo:Robert_Makgonagall)
# 2025-12-17 08:51:24,489 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Минерва Макгонагалл --hasFather--> Роберт Макгонагалл
# 2025-12-17 08:51:24,608 [INFO] hpo:Wizard ← Малькольм Макгонагалл (hpo:Malkolm_Makgonagall)
# 2025-12-17 08:51:24,608 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Минерва Макгонагалл --hasBrother--> Малькольм Макгонагалл
# 2025-12-17 08:51:24,620 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%A0%D0%BE%D0%B1%D0%B5%D1%80%D1%82_%D0%9C%D0%B0%D0%BA%D0%B3%D0%BE%D0%BD%D0%B0%D0%B3%D0%B0%D0%BB%D0%BB_%D0%BC%D0%BB.
# 2025-12-17 08:51:24,620 [INFO] hpo:Character ← Роберт Макгонагалл мл. (hpo:Robert_Makgonagall_ml)
# 2025-12-17 08:51:24,620 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Минерва Макгонагалл --hasBrother--> Роберт Макгонагалл мл.
# 2025-12-17 08:51:24,921 [INFO] hpo:Wizard ← Сириус Блэк (hpo:Sirius_Blek)
# 2025-12-17 08:51:24,922 [INFO] hpo:facultet Сириус Блэк -> Гриффиндор
# 2025-12-17 08:51:24,922 [INFO] hpo:wand Сириус Блэк -> Палочка Сириуса Блэка
# 2025-12-17 08:51:25,049 [INFO] hpo:Wizard ← Орион Блэк (hpo:Orion_Blek)
# 2025-12-17 08:51:25,050 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --hasFather--> Орион Блэк
# 2025-12-17 08:51:25,174 [INFO] hpo:Human ← Вальбурга Блэк (hpo:Valburga_Blek)
# 2025-12-17 08:51:25,175 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --hasMother--> Вальбурга Блэк
# 2025-12-17 08:51:25,334 [INFO] hpo:Wizard ← Регулус Блэк (hpo:Regulus_Blek)
# 2025-12-17 08:51:25,334 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --hasBrother--> Регулус Блэк
# 2025-12-17 08:51:25,334 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --cousinOf--> Беллатриса Лестрейндж
# 2025-12-17 08:51:25,334 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --cousinOf--> Андромеда Тонкс
# 2025-12-17 08:51:25,334 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --cousinOf--> Нарцисса Малфой
# 2025-12-17 08:51:25,334 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --hasNiece--> Нимфадора Тонкс
# 2025-12-17 08:51:25,335 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --hasNephew--> Тедди Люпин
# 2025-12-17 08:51:25,335 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --hasNephew--> Артур Уизли
# 2025-12-17 08:51:25,335 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Сириус Блэк --godsonOf--> Гарри Поттер
# 2025-12-17 08:51:25,617 [INFO] hpo:Wizard ← Лорд Волан-де-Морт (hpo:Lord_Volan-de-Mort)
# 2025-12-17 08:51:25,617 [INFO] hpo:facultet Лорд Волан-де-Морт -> Слизерин
# 2025-12-17 08:51:25,618 [INFO] hpo:wand Лорд Волан-де-Морт -> тис, перо феникса, 13½ дюйма вяз, сердечная жила дракона, 18 дюймов бузина, волос фестрала, 15 дюймов
# 2025-12-17 08:51:25,618 [INFO] hpo:patronus Лорд Волан-де-Морт -> Нет
# 2025-12-17 08:51:25,618 [INFO] hpo:Role ← « Горбин и Бэркес » (прибл. до конца 40-х годов XX века ) (hpo:_Gorbin_i_Berkes__pribl_do_kontsa_40-kh_godov_XX_veka_)
# 2025-12-17 08:51:25,618 [INFO] hpo:job Лорд Волан-де-Морт -> « Горбин и Бэркес » (прибл. до конца 40-х годов XX века )
# 2025-12-17 08:51:25,851 [INFO] hpo:Wizard ← Салазар Слизерин (hpo:Salazar_Slizerin)
# 2025-12-17 08:51:25,851 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --relativeOf--> Салазар Слизерин
# 2025-12-17 08:51:25,980 [INFO] hpo:Wizard ← Кадм Певерелл (hpo:Kadm_Peverell)
# 2025-12-17 08:51:25,980 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --relativeOf--> Кадм Певерелл
# 2025-12-17 08:51:26,100 [INFO] hpo:Wizard ← Корвин Мракс (hpo:Korvin_Mraks)
# 2025-12-17 08:51:26,101 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --relativeOf--> Корвин Мракс
# 2025-12-17 08:51:26,237 [INFO] hpo:Wizard ← Марволо Мракс (hpo:Marvolo_Mraks)
# 2025-12-17 08:51:26,237 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --hasGrandparent--> Марволо Мракс
# 2025-12-17 08:51:26,248 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%91%D0%B0%D0%B1%D1%83%D1%88%D0%BA%D0%B0_%D0%BF%D0%BE_%D0%BC%D0%B0%D0%BC%D0%B5_%D0%9C%D0%BE%D1%80%D1%84%D0%B8%D0%BD_%D0%9C%D1%80%D0%B0%D0%BA%D1%81
# 2025-12-17 08:51:26,248 [INFO] hpo:Character ← Бабушка по маме Морфин Мракс (hpo:Babushka_po_mame_Morfin_Mraks)
# 2025-12-17 08:51:26,248 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --hasUncle--> Бабушка по маме Морфин Мракс
# 2025-12-17 08:51:26,394 [INFO] hpo:Human ← Меропа Мракс (hpo:Meropa_Mraks)
# 2025-12-17 08:51:26,394 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --hasMother--> Меропа Мракс
# 2025-12-17 08:51:26,590 [INFO] hpo:Muggle ← Томас Реддл (hpo:Tomas_Reddl)
# 2025-12-17 08:51:26,590 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --hasGrandparent--> Томас Реддл
# 2025-12-17 08:51:26,716 [INFO] hpo:Muggle ← Мэри Реддл (hpo:Meri_Reddl)
# 2025-12-17 08:51:26,716 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --hasGrandparent--> Мэри Реддл
# 2025-12-17 08:51:26,716 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Лорд Волан-де-Морт --hasDaughter--> Дельфи
# 2025-12-17 08:51:26,897 [INFO] hpo:Role ← Директор фирмы « Граннингс » (hpo:Direktor_firmy__Grannings_)
# 2025-12-17 08:51:26,897 [INFO] hpo:job Вернон Дурсль -> Директор фирмы « Граннингс »
# 2025-12-17 08:51:27,028 [INFO] hpo:Muggle ← Марджори Дурсль (hpo:Mardzhori_Dursl)
# 2025-12-17 08:51:27,028 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasSister--> Марджори Дурсль
# 2025-12-17 08:51:27,028 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --marriedWith--> Петуния Дурсль
# 2025-12-17 08:51:27,028 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasSon--> Дадли Дурсль
# 2025-12-17 08:51:27,029 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasNephew--> Гарри Поттер
# 2025-12-17 08:51:27,029 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasNephew--> Джеймс Сириус Поттер
# 2025-12-17 08:51:27,029 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasNephew--> Альбус Северус Поттер
# 2025-12-17 08:51:27,029 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasNiece--> Лили Полумна Поттер
# 2025-12-17 08:51:27,416 [INFO] hpo:Muggle ← Мистер Эванс (hpo:Mister_Evans)
# 2025-12-17 08:51:27,416 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasFather--> Мистер Эванс
# 2025-12-17 08:51:27,793 [INFO] hpo:Muggle ← Миссис Эванс (hpo:Missis_Evans)
# 2025-12-17 08:51:27,793 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasMother--> Миссис Эванс
# 2025-12-17 08:51:27,803 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%96%D0%B5%D0%BD%D0%B0_%D0%94%D0%B0%D0%B4%D0%BB%D0%B8
# 2025-12-17 08:51:27,804 [INFO] hpo:Character ← Жена Дадли (hpo:Zhena_Dadli)
# 2025-12-17 08:51:27,804 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --daughterOf--> Жена Дадли
# 2025-12-17 08:51:27,813 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%94%D0%B5%D1%82%D0%B8_%D0%94%D0%B0%D0%B4%D0%BB%D0%B8
# 2025-12-17 08:51:27,813 [INFO] hpo:Character ← Дети Дадли (hpo:Deti_Dadli)
# 2025-12-17 08:51:27,814 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Вернон Дурсль --hasGrandchild--> Дети Дадли
# 2025-12-17 08:51:28,106 [INFO] hpo:Role ← Работница фирмы Граннингс (ранее) [ 2 ] (hpo:Rabotnitsa_firmy_Grannings_ranee__2_)
# 2025-12-17 08:51:28,106 [INFO] hpo:job Петуния Дурсль -> Работница фирмы Граннингс (ранее) [ 2 ]
# 2025-12-17 08:51:28,107 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasFather--> Мистер Эванс
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasMother--> Миссис Эванс
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasSister--> Лили Поттер
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --sonOf--> Джеймс Поттер
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasNephew--> Гарри Поттер
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --marriedWith--> Вернон Дурсль
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasSon--> Дадли Дурсль
# 2025-12-17 08:51:28,108 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasSister--> Марджори Дурсль
# 2025-12-17 08:51:28,109 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --daughterOf--> Жена Дадли
# 2025-12-17 08:51:28,109 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Петуния Дурсль --hasGrandchild--> Дети Дадли
# 2025-12-17 08:51:28,403 [INFO] hpo:Muggle ← Жена Дадли Дурсля (hpo:Zhena_Dadli_Durslia)
# 2025-12-17 08:51:28,405 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasGrandparent--> Мистер Эванс
# 2025-12-17 08:51:28,405 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasGrandparent--> Миссис Эванс
# 2025-12-17 08:51:28,405 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasFather--> Вернон Дурсль
# 2025-12-17 08:51:28,406 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasMother--> Петуния Дурсль
# 2025-12-17 08:51:28,406 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasAunt--> Марджори Дурсль
# 2025-12-17 08:51:28,407 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --cousinOf--> Гарри Поттер
# 2025-12-17 08:51:28,407 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasAunt--> Лили Поттер
# 2025-12-17 08:51:28,407 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasUncle--> Джеймс Поттер
# 2025-12-17 08:51:28,419 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%94%D0%B2%D0%BE%D0%B5_%D0%B4%D0%B5%D1%82%D0%B5%D0%B9_%D0%94%D0%B6%D0%B5%D0%B9%D0%BC%D1%81_%D0%A1%D0%B8%D1%80%D0%B8%D1%83%D1%81_%D0%9F%D0%BE%D1%82%D1%82%D0%B5%D1%80
# 2025-12-17 08:51:28,420 [INFO] hpo:Character ← Двое детей Джеймс Сириус Поттер (hpo:Dvoe_detei_Dzheims_Sirius_Potter)
# 2025-12-17 08:51:28,420 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasNephew--> Двое детей Джеймс Сириус Поттер
# 2025-12-17 08:51:28,420 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasNephew--> Альбус Северус Поттер
# 2025-12-17 08:51:28,420 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Дадли Дурсль --hasNiece--> Лили Полумна Поттер
# 2025-12-17 08:51:28,458 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%9C%D0%B0%D1%80%D0%B4%D0%B6_%D0%94%D1%83%D1%80%D1%81%D0%BB%D1%8C
# 2025-12-17 08:51:28,458 [WARNING] Пропуск (нет доступа): Мардж Дурсль
# 2025-12-17 08:51:28,468 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%A4%D0%BB%D0%B5%D1%82%D1%87%D0%B5%D1%80
# 2025-12-17 08:51:28,468 [WARNING] Пропуск (нет доступа): Флетчер
# 2025-12-17 08:51:28,479 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%A4%D1%80%D0%B0%D0%BD%D0%BA_%D0%91%D1%80%D0%B0%D0%B9%D1%82
# 2025-12-17 08:51:28,479 [WARNING] Пропуск (нет доступа): Франк Брайт
# 2025-12-17 08:51:28,609 [INFO] hpo:Muggle ← Том Реддл (старший) (hpo:Tom_Reddl_starshii)
# 2025-12-17 08:51:28,610 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --hasFather--> Томас Реддл
# 2025-12-17 08:51:28,610 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --hasMother--> Мэри Реддл
# 2025-12-17 08:51:28,610 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --hasFather--> Марволо Мракс
# 2025-12-17 08:51:28,750 [INFO] hpo:Wizard ← Морфин Мракс (hpo:Morfin_Mraks)
# 2025-12-17 08:51:28,750 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --hasBrother--> Морфин Мракс
# 2025-12-17 08:51:28,750 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --marriedWith--> Меропа Мракс
# 2025-12-17 08:51:29,083 [INFO] hpo:Wizard ← Волан-де-Морт (hpo:Volan-de-Mort)
# 2025-12-17 08:51:29,083 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --hasSon--> Волан-де-Морт
# 2025-12-17 08:51:29,083 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Том Реддл (старший) --hasGrandchild--> Дельфи
# 2025-12-17 08:51:29,216 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Мэри Реддл --hasSon--> Том Реддл старший
# 2025-12-17 08:51:29,216 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Мэри Реддл --daughterOf--> Меропа Мракс
# 2025-12-17 08:51:29,225 [WARNING] HTTP 404: https://harrypotter.fandom.com/ru/wiki/%D0%A2%D0%BE%D0%BC_%D0%A0%D0%B5%D0%B4%D0%B4%D0%BB_%D0%BC%D0%BB.
# 2025-12-17 08:51:29,226 [INFO] hpo:Character ← Том Реддл мл. (hpo:Tom_Reddl_ml)
# 2025-12-17 08:51:29,226 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Мэри Реддл --hasGrandchild--> Том Реддл мл.
# 2025-12-17 08:51:29,446 [INFO] hpo:Squib ← Аргус Филч (hpo:Argus_Filch)
# 2025-12-17 08:51:29,446 [INFO] hpo:Role ← Завхоз Хогвартса (hpo:Zavkhoz_Khogvartsa)
# 2025-12-17 08:51:29,446 [INFO] hpo:job Аргус Филч -> Завхоз Хогвартса
# 2025-12-17 08:51:29,651 [INFO] hpo:Squib ← Арабелла Фигг (hpo:Arabella_Figg)
# 2025-12-17 08:51:29,651 [INFO] hpo:Role ← Дилер скрещенных кошек и жмыров (hpo:Diler_skreshchennykh_koshek_i_zhmyrov)
# 2025-12-17 08:51:29,651 [INFO] hpo:job Арабелла Фигг -> Дилер скрещенных кошек и жмыров
# 2025-12-17 08:51:29,665 [INFO] Категория персонажей: Персонажи (cap=500)
# 2025-12-17 08:51:29,814 [INFO] API не вернул элементы категории Персонажи, резервный HTML-парсинг
# 2025-12-17 08:51:29,933 [INFO] Категория персонажей: Люди (cap=500)
# 2025-12-17 08:51:30,333 [INFO] hpo:Human ← Омар Абаси (hpo:Omar_Abasi)
# 2025-12-17 08:51:30,333 [INFO] hpo:Role ← Целитель (hpo:Tselitel)
# 2025-12-17 08:51:30,333 [INFO] hpo:job Омар Абаси -> Целитель
# 2025-12-17 08:51:30,522 [INFO] hpo:Wizard ← Ханна Аббот (hpo:Khanna_Abbot)
# 2025-12-17 08:51:30,522 [INFO] hpo:facultet Ханна Аббот -> Пуффендуй
# 2025-12-17 08:51:30,522 [INFO] hpo:wand Ханна Аббот -> Неизвестная длина, древесина и сердцевина
# 2025-12-17 08:51:30,522 [INFO] hpo:patronus Ханна Аббот -> Бестелесный [ 4 ]
# 2025-12-17 08:51:30,522 [INFO] hpo:Role ← Хозяйка бара « Дырявый котёл » (hpo:Khoziaika_bara__Dyriavyi_kotiol_)
# 2025-12-17 08:51:30,522 [INFO] hpo:job Ханна Аббот -> Хозяйка бара « Дырявый котёл »
# 2025-12-17 08:51:30,757 [INFO] hpo:Wizard ← Невилл Долгопупс (hpo:Nevill_Dolgopups)
# 2025-12-17 08:51:30,912 [INFO] hpo:Wizard ← Фрэнк Долгопупс (hpo:Frenk_Dolgopups)
# 2025-12-17 08:51:30,913 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Ханна Аббот --hasFather--> Фрэнк Долгопупс
# 2025-12-17 08:51:30,929 [INFO] Сохранено в harrypotter_kg_ru.ttl (триплетов: 618)
# 2025-12-17 08:51:31,081 [INFO] hpo:Human ← Алиса Долгопупс (hpo:Alisa_Dolgopups)
# 2025-12-17 08:51:31,081 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Ханна Аббот --hasMother--> Алиса Долгопупс
# 2025-12-17 08:51:31,297 [INFO] hpo:Wizard ← Джиффорд Аббот (hpo:Dzhifford_Abbot)
# 2025-12-17 08:51:31,297 [INFO] hpo:facultet Джиффорд Аббот -> Пуффендуй
# 2025-12-17 08:51:31,297 [INFO] hpo:Role ← Директор Школы Чародейства и Волшебства Хогвартс (hpo:Direktor_Shkoly_Charodeistva_i_Volshebstva_Khogvarts)
# 2025-12-17 08:51:31,297 [INFO] hpo:job Джиффорд Аббот -> Директор Школы Чародейства и Волшебства Хогвартс
# 2025-12-17 08:51:31,548 [INFO] hpo:Human ← Теофил Аббот (hpo:Teofil_Abbot)
# 2025-12-17 08:51:31,549 [INFO] hpo:Role ← Историк Писатель (hpo:Istorik_Pisatel)
# 2025-12-17 08:51:31,549 [INFO] hpo:job Теофил Аббот -> Историк Писатель
# 2025-12-17 08:51:31,676 [INFO] hpo:Human ← Юан Аберкромби (hpo:Iuan_Aberkrombi)
# 2025-12-17 08:51:31,817 [INFO] hpo:Human ← Абернэти (hpo:Aberneti)
# 2025-12-17 08:51:31,818 [INFO] hpo:Role ← Сотрудник МАКУСА (hpo:Sotrudnik_MAKUSA)
# 2025-12-17 08:51:31,818 [INFO] hpo:job Абернэти -> Сотрудник МАКУСА
# 2025-12-17 08:51:31,949 [INFO] hpo:Human ← Агнес (hpo:Agnes)
# 2025-12-17 08:51:32,078 [INFO] hpo:Human ← Сын Агнес (hpo:Syn_Agnes)
# 2025-12-17 08:51:32,299 [INFO] hpo:Human ← Корнелиус Агриппа (hpo:Kornelius_Agrippa)
# 2025-12-17 08:51:32,299 [INFO] hpo:Role ← Автор работ по нумерологии, писатель, врач, философ, астролог, адвокат (hpo:Avtor_rabot_po_numerologii_pisatel_vrach_filosof_astrolog_advokat)
# 2025-12-17 08:51:32,299 [INFO] hpo:job Корнелиус Агриппа -> Автор работ по нумерологии, писатель, врач, философ, астролог, адвокат
# 2025-12-17 08:51:32,433 [INFO] hpo:Human ← Адриан (hpo:Adrian)
# 2025-12-17 08:51:32,433 [INFO] hpo:Role ← Фотограф (hpo:Fotograf)
# 2025-12-17 08:51:32,433 [INFO] hpo:job Адриан -> Фотограф
# 2025-12-17 08:51:32,590 [INFO] hpo:Human ← Эрни Азан (hpo:Erni_Azan)
# 2025-12-17 08:51:32,717 [INFO] hpo:Human ← Косме Акажёр (hpo:Kosme_Akazhior)
# 2025-12-17 08:51:32,718 [INFO] hpo:Role ← Изготовитель волшебных палочек (hpo:Izgotovitel_volshebnykh_palochek)
# 2025-12-17 08:51:32,718 [INFO] hpo:job Косме Акажёр -> Изготовитель волшебных палочек
# 2025-12-17 08:51:32,849 [INFO] hpo:Wizard ← Стюарт Акерли (hpo:Stiuart_Akerli)
# 2025-12-17 08:51:32,850 [INFO] hpo:facultet Стюарт Акерли -> Когтевран
# 2025-12-17 08:51:32,977 [INFO] hpo:Human ← Учи Акимбо (hpo:Uchi_Akimbo)
# 2025-12-17 08:51:33,108 [INFO] hpo:Human ← Аланнис (hpo:Alannis)
# 2025-12-17 08:51:33,420 [INFO] hpo:Muggle ← Албанский крестьянин (hpo:Albanskii_krestianin)
# 2025-12-17 08:51:33,619 [INFO] hpo:Human ← Аланза Алвес (hpo:Alanza_Alves)
# 2025-12-17 08:51:33,995 [INFO] hpo:Human ← Арчибальд Алдертон (hpo:Archibald_Alderton)
# 2025-12-17 08:51:33,996 [INFO] hpo:Role ← Повар (hpo:Povar)
# 2025-12-17 08:51:33,996 [INFO] hpo:job Арчибальд Алдертон -> Повар
# 2025-12-17 08:51:34,189 [INFO] hpo:Human ← Александра Уокер (hpo:Aleksandra_Uoker)
# 2025-12-17 08:51:34,387 [INFO] hpo:Human ← Сиприен Алеси (hpo:Siprien_Alesi)
# 2025-12-17 08:51:34,388 [INFO] hpo:Role ← Судья в квиддиче (hpo:Sudia_v_kviddiche)
# 2025-12-17 08:51:34,388 [INFO] hpo:job Сиприен Алеси -> Судья в квиддиче
# 2025-12-17 08:51:34,681 [INFO] hpo:Wizard ← Бадия Али (hpo:Badiia_Ali)
# 2025-12-17 08:51:34,681 [INFO] hpo:facultet Бадия Али -> Когтевран
# 2025-12-17 08:51:34,916 [INFO] hpo:Human ← Рауль Алмейда (hpo:Raul_Almeida)
# 2025-12-17 08:51:34,916 [INFO] hpo:Role ← Вратарь Сборной Бразилии по квиддичу (hpo:Vratar_Sbornoi_Brazilii_po_kviddichu)
# 2025-12-17 08:51:34,916 [INFO] hpo:job Рауль Алмейда -> Вратарь Сборной Бразилии по квиддичу
# 2025-12-17 08:51:35,133 [INFO] hpo:Human ← Алехандра Алонсо (hpo:Alekhandra_Alonso)
# 2025-12-17 08:51:35,134 [INFO] hpo:Role ← Профессиональный игрок в квиддич (hpo:Professionalnyi_igrok_v_kviddich)
# 2025-12-17 08:51:35,134 [INFO] hpo:job Алехандра Алонсо -> Профессиональный игрок в квиддич
# 2025-12-17 08:51:35,343 [INFO] hpo:Human ← Фатима Аль-Эрьяни (hpo:Fatima_Al-Eriani)
# 2025-12-17 08:51:35,552 [INFO] hpo:Human ← Альма (hpo:Alma)
# 2025-12-17 08:51:35,743 [INFO] hpo:Human ← Альтеда (hpo:Alteda)
# 2025-12-17 08:51:35,882 [INFO] hpo:Human ← Орион Амари (hpo:Orion_Amari)
# 2025-12-17 08:51:36,081 [INFO] hpo:Human ← Амата (hpo:Amata)
# 2025-12-17 08:51:36,199 [INFO] hpo:Muggle ← Сэр Невезучий (hpo:Ser_Nevezuchii)
# 2025-12-17 08:51:36,324 [INFO] hpo:Squib ← Брат Долорес Амбридж (hpo:Brat_Dolores_Ambridzh)
# 2025-12-17 08:51:36,460 [INFO] hpo:Wizard ← Орфорд Амбридж (hpo:Orford_Ambridzh)
# 2025-12-17 08:51:36,461 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Брат Долорес Амбридж --hasFather--> Орфорд Амбридж
# 2025-12-17 08:51:36,573 [INFO] hpo:Muggle ← Эллен Кракнелл (hpo:Ellen_Kraknell)
# 2025-12-17 08:51:36,573 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Брат Долорес Амбридж --hasMother--> Эллен Кракнелл
# 2025-12-17 08:51:36,923 [INFO] hpo:Wizard ← Долорес Амбридж (hpo:Dolores_Ambridzh)
# 2025-12-17 08:51:36,923 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Брат Долорес Амбридж --hasSister--> Долорес Амбридж
# 2025-12-17 08:51:37,071 [INFO] hpo:Role ← Поломойщик в Отделе магического хозяйства (hpo:Polomoishchik_v_Otdele_magicheskogo_khoziaistva)
# 2025-12-17 08:51:37,072 [INFO] hpo:job Орфорд Амбридж -> Поломойщик в Отделе магического хозяйства
# 2025-12-17 08:51:37,072 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Орфорд Амбридж --hasDaughter--> Долорес Амбридж
# 2025-12-17 08:51:37,372 [INFO] hpo:wand Долорес Амбридж -> Берёза, сердечная жила дракона, длина 8 дюймов, очень гибкая
# 2025-12-17 08:51:37,372 [INFO] hpo:patronus Долорес Амбридж -> Белый персидский кот
# 2025-12-17 08:51:37,372 [INFO] hpo:Role ← Министерство магии Глава Сектора борьбы с неправомерным использованием магии [ 4 ] Глава Отдела магического правопорядка [ 4 ] Старший заместитель министра магии (до 1998 ) Судья Визенгамота (до 1998 ) Председатель комиссии по учёту магловских выродков ( 1997 - 1998 ) Школа Чародейства и Волшебства Хогвартс Профессор ЗОТИ ( 1995 - 1996 ) Генеральный инспектор Хогвартса ( 1995 - 1996 ) Директор Хогвартса ( 1996 ) (hpo:Ministerstvo_magii_Glava_Sektora_borby_s_nepravomernym_ispolzovaniem_magii__4__Glava_Otdela_magicheskogo_pravoporiadka__4__Starshii_zamestitel_ministra_magii_do_1998__Sudia_Vizengamota_do_1998__Predsedatel_komissii_po_uchiotu_maglovskikh_vyrodkov__1997_-_1998__Shkola_Charodeistva_i_Volshebstva_Khogvarts_Professor_ZOTI__1995_-_1996__Generalnyi_inspektor_Khogvartsa__1995_-_1996__Direktor_Khogvartsa__1996_)
# 2025-12-17 08:51:37,372 [INFO] hpo:job Долорес Амбридж -> Министерство магии Глава Сектора борьбы с неправомерным использованием магии [ 4 ] Глава Отдела магического правопорядка [ 4 ] Старший заместитель министра магии (до 1998 ) Судья Визенгамота (до 1998 ) Председатель комиссии по учёту магловских выродков ( 1997 - 1998 ) Школа Чародейства и Волшебства Хогвартс Профессор ЗОТИ ( 1995 - 1996 ) Генеральный инспектор Хогвартса ( 1995 - 1996 ) Директор Хогвартса ( 1996 )
# 2025-12-17 08:51:37,373 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Долорес Амбридж --hasFather--> Орфорд Амбридж
# 2025-12-17 08:51:37,373 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Долорес Амбридж --hasMother--> Эллен Кракнелл
# 2025-12-17 08:51:37,623 [INFO] hpo:Human ← Ангус (hpo:Angus)
# 2025-12-17 08:51:37,858 [INFO] hpo:Wizard ← Файверли Андерклифф (hpo:Faiverli_Anderkliff)
# 2025-12-17 08:51:37,858 [INFO] hpo:Role ← Директор (hpo:Direktor)
# 2025-12-17 08:51:37,859 [INFO] hpo:job Файверли Андерклифф -> Директор
# 2025-12-17 08:51:37,983 [INFO] hpo:Human ← Олаф Андерсен (hpo:Olaf_Andersen)
# 2025-12-17 08:51:38,108 [INFO] hpo:Muggle ← Андерсон (hpo:Anderson)
# 2025-12-17 08:51:38,108 [INFO] hpo:Role ← Полицейский (hpo:Politseiskii)
# 2025-12-17 08:51:38,108 [INFO] hpo:job Андерсон -> Полицейский
# 2025-12-17 08:51:38,233 [INFO] hpo:Human ← Билли Андерсон (hpo:Billi_Anderson)
# 2025-12-17 08:51:38,370 [INFO] hpo:Wizard ← Уолтер Арагон (hpo:Uolter_Aragon)
# 2025-12-17 08:51:38,370 [INFO] hpo:job Уолтер Арагон -> Директор
# 2025-12-17 08:51:38,502 [INFO] hpo:Human ← Аркус (hpo:Arkus)
# 2025-12-17 08:51:38,503 [INFO] hpo:wand Аркус -> Бузинная палочка (возможно)
# 2025-12-17 08:51:38,792 [INFO] hpo:Human ← Адам Артериус (hpo:Adam_Arterius)
# 2025-12-17 08:51:38,939 [INFO] hpo:Muggle ← Король Артур (hpo:Korol_Artur)
# 2025-12-17 08:51:39,070 [INFO] hpo:Wizard ← Малодора Гримм (hpo:Malodora_Grimm)
# 2025-12-17 08:51:39,212 [INFO] hpo:Human ← Моргана Ле Фэй (hpo:Morgana_Le_Fei)
# 2025-12-17 08:51:39,212 [INFO] 👨‍👩‍👧‍👦 Инфобокс-Семья: Король Артур --hasSister--> Моргана Ле Фэй
# 2025-12-17 08:51:39,343 [INFO] hpo:Human ← Архитектор Хогвартса (hpo:Arkhitektor_Khogvartsa)
# 2025-12-17 08:51:39,343 [INFO] hpo:Role ← Архитектор (hpo:Arkhitektor)
# 2025-12-17 08:51:39,343 [INFO] hpo:job Архитектор Хогвартса -> Архитектор
# 2025-12-17 08:51:39,473 [INFO] hpo:Human ← Сильвио Астольфи (hpo:Silvio_Astolfi)
# ...
# 2025-12-17 08:55:09,700 [INFO] hpo:Potion ← Огнезащитное зелье (hpo:Ognezashchitnoe_zele)
# 2025-12-17 08:55:09,887 [INFO] 🧪 Зелье: Огнезащитное зелье --effect--> Защищает от огня
# 2025-12-17 08:55:09,887 [INFO] hpo:Potion ← Ослабляющее зелье (hpo:Oslabliaiushchee_zele)
# 2025-12-17 08:55:10,112 [INFO] hpo:Potion ← Охранное зелье (hpo:Okhrannoe_zele)
# 2025-12-17 08:55:10,238 [INFO] 🧪 Зелье: Охранное зелье --effect--> Придаёт сил
# 2025-12-17 08:55:10,238 [INFO] hpo:Potion ← Паста для удаления ушибов (hpo:Pasta_dlia_udaleniia_ushibov)
# 2025-12-17 08:55:10,461 [INFO] 🧪 Зелье: Паста для удаления ушибов --effect--> Удаляет ушибы и синяки
# 2025-12-17 08:55:10,462 [INFO] hpo:Potion ← Первый любовный соблазнитель (hpo:Pervyi_liubovnyi_soblaznitel)
# 2025-12-17 08:55:10,569 [INFO] 🧪 Зелье: Первый любовный соблазнитель --effect--> Заставляет пьющего влюбиться в того, кто даёт зелье
# 2025-12-17 08:55:10,570 [INFO] 🧪 Зелье (obj): Первый любовный соблазнитель --hasCreator--> Фред и Джордж Уизли
# 2025-12-17 08:55:10,570 [INFO] hpo:Potion ← Подави стыд (hpo:Podavi_styd)
# 2025-12-17 08:55:10,680 [INFO] hpo:Potion ← Прозрей-зелье (hpo:Prozrei-zele)
# 2025-12-17 08:55:10,814 [INFO] 🧪 Зелье: Прозрей-зелье --effect--> Восстанавливает зрение и снимает проклятие конъюктивита
# 2025-12-17 08:55:10,815 [INFO] hpo:Potion ← Противодраконья сыворотка (hpo:Protivodrakonia_syvorotka)
# 2025-12-17 08:55:10,936 [INFO] 🧪 Зелье: Противодраконья сыворотка --effect--> Лечение драконьей оспы
# 2025-12-17 08:55:10,936 [INFO] 🧪 Зелье (obj): Противодраконья сыворотка --hasCreator--> Ганхильда из Горсмура
# 2025-12-17 08:55:10,936 [INFO] hpo:Potion ← Противоожоговая мазь (hpo:Protivoozhogovaia_maz)
# 2025-12-17 08:55:11,052 [INFO] hpo:Potion ← Противоядие от истерики (hpo:Protivoiadie_ot_isteriki)
# 2025-12-17 08:55:11,282 [INFO] hpo:Potion ← Противоядие от любовных зелий (hpo:Protivoiadie_ot_liubovnykh_zelii)
# 2025-12-17 08:55:11,401 [INFO] hpo:Potion ← Противоядие от магических ядов (hpo:Protivoiadie_ot_magicheskikh_iadov)
# 2025-12-17 08:55:11,528 [INFO] 🧪 Зелье: Противоядие от магических ядов --effect--> Лечит от ядов магического происхождения [ 1 ]
# 2025-12-17 08:55:11,528 [INFO] hpo:Potion ← Противоядие от обычных ядов (hpo:Protivoiadie_ot_obychnykh_iadov)
# 2025-12-17 08:55:11,642 [INFO] 🧪 Зелье: Противоядие от обычных ядов --effect--> Излечивает от действия обычных ядов
# 2025-12-17 08:55:11,642 [INFO] hpo:Potion ← Противоядие по Третьему закону Голпалотта (hpo:Protivoiadie_po_Tretemu_zakonu_Golpalotta)
# 2025-12-17 08:55:11,771 [INFO] 🧪 Зелье: Противоядие по Третьему закону Голпалотта --effect--> Противоядие к Сложным составным ядам
# 2025-12-17 08:55:11,771 [INFO] 🧪 Зелье (obj): Противоядие по Третьему закону Голпалотта --hasCreator--> Голпалотт
# 2025-12-17 08:55:11,771 [INFO] hpo:Thing ← Опытные зельевары (hpo:Opytnye_zelevary)
# 2025-12-17 08:55:11,771 [INFO] 🧪 Зелье (obj): Противоядие по Третьему закону Голпалотта --hasManufacturer--> Опытные зельевары
# 2025-12-17 08:55:11,772 [INFO] hpo:Potion ← Пятновыводитель Блитзера (hpo:Piatnovyvoditel_Blitzera)
# 2025-12-17 08:55:11,895 [INFO] hpo:Potion ← Раздувающий раствор (hpo:Razduvaiushchii_rastvor)
# 2025-12-17 08:55:12,127 [INFO] 🧪 Зелье: Раздувающий раствор --effect--> Увеличивает объекты в объёме
# 2025-12-17 08:55:12,127 [INFO] hpo:Potion ← Рябиновый отвар (hpo:Riabinovyi_otvar)
# 2025-12-17 08:55:12,258 [INFO] 🧪 Зелье: Рябиновый отвар --effect--> Залечивает раны и восстанавливает силы
# 2025-12-17 08:55:12,258 [INFO] hpo:Potion ← Сдувающий напиток (hpo:Sduvaiushchii_napitok)
# 2025-12-17 08:55:12,368 [INFO] 🧪 Зелье: Сдувающий напиток --effect--> Уменьшает объект
# 2025-12-17 08:55:12,368 [INFO] hpo:Potion ← Система по уходу за волосами от Златопуста Локонса (hpo:Sistema_po_ukhodu_za_volosami_ot_Zlatopusta_Lokonsa)
# 2025-12-17 08:55:12,487 [INFO] 🧪 Зелье: Система по уходу за волосами от Златопуста Локонса --effect--> Улучшение структуры и внешнего вида волос
# 2025-12-17 08:55:12,487 [INFO] 🧪 Зелье (obj): Система по уходу за волосами от Златопуста Локонса --hasCreator--> Златопуст Локонс
# 2025-12-17 08:55:12,488 [INFO] hpo:Potion ← Слезинки большого горя (hpo:Slezinki_bolshogo_goria)
# 2025-12-17 08:55:12,596 [INFO] hpo:Potion ← Снадобье «Простоблеск» (hpo:Snadobe_Prostoblesk)
# 2025-12-17 08:55:12,831 [INFO] 🧪 Зелье: Снадобье «Простоблеск» --effect--> Делает волосы более послушными
# 2025-12-17 08:55:12,832 [INFO] 🧪 Зелье (obj): Снадобье «Простоблеск» --hasCreator--> Флимонт Поттер
# 2025-12-17 08:55:12,832 [INFO] hpo:Potion ← Средство для полировки рукояти (hpo:Sredstvo_dlia_polirovki_rukoiati)
# 2025-12-17 08:55:12,923 [INFO] hpo:Potion ← Средство от плотоядных слизняков (hpo:Sredstvo_ot_plotoiadnykh_slizniakov)
# 2025-12-17 08:55:13,034 [INFO] hpo:Potion ← Средство против сыворотки правды (hpo:Sredstvo_protiv_syvorotki_pravdy)
# 2025-12-17 08:55:13,160 [INFO] hpo:Potion ← Сумеречные лунные лучи (hpo:Sumerechnye_lunnye_luchi)
# 2025-12-17 08:55:13,272 [INFO] hpo:Potion ← Сыворотка правды (hpo:Syvorotka_pravdy)
# 2025-12-17 08:55:13,400 [INFO] 🧪 Зелье: Сыворотка правды --effect--> Заставляет говорить правду
# 2025-12-17 08:55:13,401 [INFO] 🧪 Зелье (obj): Сыворотка правды --hasManufacturer--> Северус Снегг Гораций Слизнорт
# 2025-12-17 08:55:13,401 [INFO] hpo:Potion ← Сырные зелья (hpo:Syrnye_zelia)
# 2025-12-17 08:55:13,629 [INFO] hpo:Potion ← Тонизирующий глоток мандрагоры (hpo:Toniziruiushchii_glotok_mandragory)
# 2025-12-17 08:55:13,737 [INFO] 🧪 Зелье: Тонизирующий глоток мандрагоры --effect--> Возвращает в нормальное состояние тех, кто был проклят или превращен.
# 2025-12-17 08:55:13,737 [INFO] hpo:Potion ← Уидосорос (hpo:Uidosoros)
# 2025-12-17 08:55:13,860 [INFO] 🧪 Зелье: Уидосорос --effect--> Яд
# 2025-12-17 08:55:13,861 [INFO] hpo:Potion ← Укрепляющий раствор (hpo:Ukrepliaiushchii_rastvor)
# 2025-12-17 08:55:13,982 [INFO] 🧪 Зелье: Укрепляющий раствор --effect--> Исцеление физических и волшебных ранений
# 2025-12-17 08:55:13,982 [INFO] hpo:Potion ← Уменьшающее зелье (hpo:Umenshaiushchee_zele)
# 2025-12-17 08:55:14,109 [INFO] 🧪 Зелье: Уменьшающее зелье --effect--> Уменьшение
# 2025-12-17 08:55:14,110 [INFO] 🧪 Зелье (obj): Уменьшающее зелье --hasCreator--> Зигмунт Бадж
# 2025-12-17 08:55:14,110 [INFO] hpo:Potion ← Умиротворяющий бальзам (hpo:Umirotvoriaiushchii_balzam)
# 2025-12-17 08:55:14,238 [INFO] 🧪 Зелье: Умиротворяющий бальзам --effect--> Помогает бороться с тревогой и снимать беспокойство [ 1 ]
# 2025-12-17 08:55:14,238 [INFO] hpo:Potion ← Умострильное зелье (hpo:Umostrilnoe_zele)
# 2025-12-17 08:55:14,472 [INFO] hpo:Potion ← Универсальный волшебный пятновыводитель миссис Чистикс (hpo:Universalnyi_volshebnyi_piatnovyvoditel_missis_Chistiks)
# 2025-12-17 08:55:14,584 [INFO] 🧪 Зелье: Универсальный волшебный пятновыводитель миссис Чистикс --effect--> Выведение пятен
# 2025-12-17 08:55:14,584 [INFO] hpo:Thing ← Миссис Чистикс (hpo:Missis_Chistiks)
# 2025-12-17 08:55:14,585 [INFO] 🧪 Зелье (obj): Универсальный волшебный пятновыводитель миссис Чистикс --hasManufacturer--> Миссис Чистикс
# 2025-12-17 08:55:14,585 [INFO] hpo:Potion ← Успокаивающая настойка (hpo:Uspokaivaiushchaia_nastoika)
# 2025-12-17 08:55:14,692 [INFO] 🧪 Зелье: Успокаивающая настойка --effect--> Успокаивает
# 2025-12-17 08:55:14,692 [INFO] hpo:Potion ← Усыпляющее зелье (hpo:Usypliaiushchee_zele)
# 2025-12-17 08:55:14,834 [INFO] 🧪 Зелье: Усыпляющее зелье --effect--> Погружает в сон
# 2025-12-17 08:55:14,834 [INFO] 🧪 Зелье (obj): Усыпляющее зелье --hasCreator--> Зигмунт Бадж
# 2025-12-17 08:55:14,834 [INFO] hpo:Potion ← Утончающий эликсир доктора Пингуиса (hpo:Utonchaiushchii_eliksir_doktora_Pinguisa)
# 2025-12-17 08:55:14,952 [INFO] hpo:Potion ← Феликс Фелицис (hpo:Feliks_Felitsis)
# 2025-12-17 08:55:15,179 [INFO] 🧪 Зелье: Феликс Фелицис --effect--> Приносит удачу
# 2025-12-17 08:55:15,180 [INFO] 🧪 Зелье (obj): Феликс Фелицис --hasCreator--> Зигмунт Бадж
# 2025-12-17 08:55:15,180 [INFO] 🧪 Зелье (obj): Феликс Фелицис --hasManufacturer--> Зигмунт Бадж Гораций Слизнорт
# 2025-12-17 08:55:15,180 [INFO] hpo:Potion ← Флиртующие фантазии (hpo:Flirtuiushchie_fantazii)
# 2025-12-17 08:55:15,300 [INFO] 🧪 Зелье: Флиртующие фантазии --effect--> Настроить человека на романтический лад (возможно)
# 2025-12-17 08:55:15,498 [INFO] Сохранено в harrypotter_kg_ru.ttl (триплетов: 6892)
# 2025-12-17 08:55:15,499 [INFO] 🧪 Зелье (obj): Флиртующие фантазии --hasManufacturer--> Фред и Джордж Уизли
# 2025-12-17 08:55:15,499 [INFO] hpo:Potion ← Фокусирующее зелье (hpo:Fokusiruiushchee_zele)
# 2025-12-17 08:55:15,616 [INFO] 🧪 Зелье: Фокусирующее зелье --effect--> Снимает время перезарядки заклинаний выпившего [ 1 ]
# 2025-12-17 08:55:15,617 [INFO] hpo:Potion ← Целующееся зелье (hpo:Tseluiushcheesia_zele)
# 2025-12-17 08:55:15,722 [INFO] 🧪 Зелье: Целующееся зелье --effect--> заставляет поцеловать
# 2025-12-17 08:55:15,722 [INFO] hpo:Potion ← Эверклена (hpo:Everklena)
# 2025-12-17 08:55:15,829 [INFO] hpo:Potion ← Эйфорийный эликсир (hpo:Eiforiinyi_eliksir)
# 2025-12-17 08:55:15,963 [INFO] 🧪 Зелье: Эйфорийный эликсир --effect--> Вызывает радостное настроение
# 2025-12-17 08:55:15,963 [INFO] hpo:Potion ← Экстракт бадьяна (hpo:Ekstrakt_badiana)
# 2025-12-17 08:55:16,191 [INFO] 🧪 Зелье: Экстракт бадьяна --effect--> лечит раны
# 2025-12-17 08:55:16,192 [INFO] hpo:Potion ← Эликсир жизни (hpo:Eliksir_zhizni)
# 2025-12-17 08:55:16,309 [INFO] 🧪 Зелье: Эликсир жизни --effect--> Бессмертие
# 2025-12-17 08:55:16,310 [INFO] hpo:Thing ← Николас Фламель (hpo:Nikolas_Flamel)
# 2025-12-17 08:55:16,310 [INFO] 🧪 Зелье (obj): Эликсир жизни --hasCreator--> Николас Фламель
# 2025-12-17 08:55:16,310 [INFO] hpo:Potion ← Эликсир из мандрагоры (hpo:Eliksir_iz_mandragory)
# 2025-12-17 08:55:16,417 [INFO] hpo:Potion ← Яды, не оставляющие следа (hpo:Iady_ne_ostavliaiushchie_sleda)
# 2025-12-17 08:55:16,881 [INFO] hpo:Potion ← Абиссинская смоковница (hpo:Abissinskaia_smokovnitsa)
# 2025-12-17 08:55:16,990 [INFO] hpo:Potion ← Аконит (hpo:Akonit)
# 2025-12-17 08:55:17,091 [INFO] hpo:Potion ← Алихоция (hpo:Alikhotsiia)
# 2025-12-17 08:55:17,314 [INFO] hpo:Potion ← Армотенция (hpo:Armotentsiia)
# 2025-12-17 08:55:17,413 [INFO] hpo:Potion ← Асфодель (hpo:Asfodel)
# 2025-12-17 08:55:17,515 [INFO] hpo:Potion ← Бадьян (hpo:Badian)
# 2025-12-17 08:55:17,621 [INFO] hpo:Potion ← Безоар (hpo:Bezoar)
# 2025-12-17 08:55:17,723 [INFO] hpo:Potion ← Белладонна (hpo:Belladonna)
# 2025-12-17 08:55:17,820 [INFO] hpo:Potion ← Болиголов (hpo:Boligolov)
# 2025-12-17 08:55:18,130 [INFO] hpo:Potion ← Бубонтюбер (hpo:Bubontiuber)
# 2025-12-17 08:55:18,221 [INFO] hpo:Potion ← Валериана (hpo:Valeriana)
# 2025-12-17 08:55:18,319 [INFO] hpo:Potion ← Взрывчатая жидкость (hpo:Vzryvchataia_zhidkost)
# 2025-12-17 08:55:18,419 [INFO] hpo:Potion ← Вода из реки Лета (hpo:Voda_iz_reki_Leta)
# 2025-12-17 08:55:18,511 [INFO] hpo:Potion ← Водоросли (hpo:Vodorosli)
# 2025-12-17 08:55:18,612 [INFO] hpo:Potion ← Волос африканской русалки (hpo:Volos_afrikanskoi_rusalki)
# 2025-12-17 08:55:18,823 [INFO] hpo:Potion ← Волос из хвоста фестрала (hpo:Volos_iz_khvosta_festrala)
# 2025-12-17 08:55:18,922 [INFO] hpo:Potion ← Волос курупиры (hpo:Volos_kurupiry)
# 2025-12-17 08:55:19,027 [INFO] hpo:Potion ← Волосы кельпи (hpo:Volosy_kelpi)
# 2025-12-17 08:55:19,116 [INFO] hpo:Potion ← Выделения бундимунов (hpo:Vydeleniia_bundimunov)
# 2025-12-17 08:55:19,212 [INFO] hpo:Potion ← Ганглии ведьмы (hpo:Ganglii_vedmy)
# 2025-12-17 08:55:19,331 [INFO] hpo:Potion ← Глаза жуков (hpo:Glaza_zhukov)
# 2025-12-17 08:55:19,433 [INFO] hpo:Potion ← Глаза рыбы-собаки (hpo:Glaza_ryby-sobaki)
# 2025-12-17 08:55:19,638 [INFO] hpo:Potion ← Глаза угря (hpo:Glaza_ugria)
# 2025-12-17 08:55:19,729 [INFO] hpo:Potion ← Гной бубонтюбера (hpo:Gnoi_bubontiubera)
# 2025-12-17 08:55:19,820 [INFO] hpo:Potion ← Гранатовый сок (hpo:Granatovyi_sok)
# 2025-12-17 08:55:19,925 [INFO] hpo:Potion ← Гусеница (hpo:Gusenitsa)
# 2025-12-17 08:55:20,032 [INFO] hpo:Potion ← Драконий навоз (hpo:Drakonii_navoz)
# 2025-12-17 08:55:20,137 [INFO] hpo:Potion ← Дремоносные бобы (hpo:Dremonosnye_boby)
# 2025-12-17 08:55:20,281 [INFO] hpo:Potion ← Жабросли (hpo:Zhabrosli)
# 2025-12-17 08:55:20,569 [INFO] hpo:Potion ← Жала веретенницы (hpo:Zhala_veretennitsy)
# 2025-12-17 08:55:20,708 [INFO] hpo:Potion ← Желчь броненосца (hpo:Zhelch_bronenostsa)
# 2025-12-17 08:55:20,851 [INFO] hpo:Potion ← Жемчужная пыль (hpo:Zhemchuzhnaia_pyl)
# 2025-12-17 08:55:20,992 [INFO] hpo:Potion ← Жук (hpo:Zhuk)
# 2025-12-17 08:55:21,167 [INFO] hpo:Potion ← Златоглазки (hpo:Zlatoglazki)
# 2025-12-17 08:55:21,327 [INFO] hpo:Potion ← Змеиные зубы (hpo:Zmeinye_zuby)
# 2025-12-17 08:55:21,463 [INFO] hpo:Potion ← Иглы дикобраза (hpo:Igly_dikobraza)
# 2025-12-17 08:55:21,751 [INFO] hpo:Potion ← Икра (hpo:Ikra)
# 2025-12-17 08:55:21,916 [INFO] hpo:Potion ← Имбирь (hpo:Imbir)
# 2025-12-17 08:55:22,076 [INFO] hpo:Potion ← Калган-трава (hpo:Kalgan-trava)
# 2025-12-17 08:55:22,237 [INFO] hpo:Potion ← Касторовое масло (hpo:Kastorovoe_maslo)
# 2025-12-17 08:55:22,386 [INFO] hpo:Potion ← Каша проповедника (hpo:Kasha_propovednika)
# 2025-12-17 08:55:22,603 [INFO] hpo:Potion ← Китайская жующая капуста (hpo:Kitaiskaia_zhuiushchaia_kapusta)
# 2025-12-17 08:55:22,925 [INFO] hpo:Potion ← Клещевина (hpo:Kleshchevina)
# 2025-12-17 08:55:23,013 [INFO] hpo:Potion ← Клыки чизпурфла (hpo:Klyki_chizpurfla)
# 2025-12-17 08:55:23,103 [INFO] hpo:Potion ← Корица (hpo:Koritsa)
# 2025-12-17 08:55:23,206 [INFO] hpo:Potion ← Крапива (hpo:Krapiva)
# 2025-12-17 08:55:23,323 [INFO] hpo:Potion ← Кровь (hpo:Krov)
# 2025-12-17 08:55:23,436 [INFO] hpo:Potion ← Кровь дракона (hpo:Krov_drakona)
# 2025-12-17 08:55:23,529 [INFO] hpo:Potion ← Кровь единорога (hpo:Krov_edinoroga)
# 2025-12-17 08:55:23,746 [INFO] hpo:Potion ← Кровь ре-эма (hpo:Krov_re-ema)
# 2025-12-17 08:55:23,837 [INFO] hpo:Potion ← Кровь саламандры (hpo:Krov_salamandry)
# 2025-12-17 08:55:23,933 [INFO] hpo:Potion ← Крылья летучей мыши (hpo:Krylia_letuchei_myshi)
# 2025-12-17 08:55:24,036 [INFO] hpo:Potion ← Крылья феи (hpo:Krylia_fei)
# 2025-12-17 08:55:24,131 [INFO] hpo:Potion ← Лаванда (hpo:Lavanda)
# 2025-12-17 08:55:24,237 [INFO] hpo:Potion ← Лепесток розы (hpo:Lepestok_rozy)
# 2025-12-17 08:55:24,466 [INFO] hpo:Potion ← Летающий морской конёк (hpo:Letaiushchii_morskoi_koniok)
# 2025-12-17 08:55:24,572 [INFO] hpo:Potion ← Лирный корень (hpo:Lirnyi_koren)
# 2025-12-17 08:55:24,673 [INFO] hpo:Potion ← Ложечница (hpo:Lozhechnitsa)
# 2025-12-17 08:55:24,778 [INFO] hpo:Potion ← Прыгучая Луковица (hpo:Pryguchaia_Lukovitsa)
# 2025-12-17 08:55:24,882 [INFO] hpo:Potion ← Лунная роса (hpo:Lunnaia_rosa)
# 2025-12-17 08:55:24,975 [INFO] hpo:Potion ← Лунный камень (hpo:Lunnyi_kamen)
# 2025-12-17 08:55:25,079 [INFO] hpo:Potion ← Любисток (hpo:Liubistok)
# 2025-12-17 08:55:25,285 [INFO] hpo:Potion ← Мёд (hpo:Miod)
# 2025-12-17 08:55:25,401 [INFO] hpo:Potion ← Мандрагора (hpo:Mandragora)
# 2025-12-17 08:55:25,513 [INFO] hpo:Potion ← Манжетка (hpo:Manzhetka)
# 2025-12-17 08:55:25,603 [INFO] hpo:Potion ← Маргаритка (hpo:Margaritka)
# 2025-12-17 08:55:25,694 [INFO] hpo:Potion ← Медленнодействующий яд (hpo:Medlennodeistvuiushchii_iad)
# 2025-12-17 08:55:25,785 [INFO] hpo:Potion ← Медовая вода (hpo:Medovaia_voda)
# 2025-12-17 08:55:26,117 [INFO] hpo:Potion ← Моли (hpo:Moli)
# 2025-12-17 08:55:26,210 [INFO] hpo:Potion ← Мясной соус (hpo:Miasnoi_sous)
# 2025-12-17 08:55:26,308 [INFO] hpo:Potion ← Мята (hpo:Miata)
# 2025-12-17 08:55:26,429 [INFO] hpo:Potion ← Перечная мята (hpo:Perechnaia_miata)
# 2025-12-17 08:55:26,526 [INFO] hpo:Potion ← Навоз лунных тельцов (hpo:Navoz_lunnykh_teltsov)
# 2025-12-17 08:55:26,619 [INFO] hpo:Potion ← Огненные семена (hpo:Ognennye_semena)
# 2025-12-17 08:55:26,848 [INFO] hpo:Potion ← Омела (hpo:Omela)
# 2025-12-17 08:55:26,952 [INFO] hpo:Potion ← Панцирь чизпурфла (hpo:Pantsir_chizpurfla)
# 2025-12-17 08:55:27,041 [INFO] hpo:Potion ← Паук (hpo:Pauk)
# 2025-12-17 08:55:27,146 [INFO] hpo:Potion ← Перо птицы-гром (hpo:Pero_ptitsy-grom)
# 2025-12-17 08:55:27,249 [INFO] hpo:Potion ← Перо феникса (hpo:Pero_feniksa)
# 2025-12-17 08:55:27,347 [INFO] hpo:Potion ← Перья болтрушайки (hpo:Peria_boltrushaiki)
# 2025-12-17 08:55:27,668 [INFO] Сохранено в harrypotter_kg_ru.ttl (триплетов: 7080)
# 2025-12-17 08:55:27,669 [INFO] Готово. Триплетов в графе: 7080

# %% [markdown]
# Преобразование RDF в формат для KGE
# (RDF-триплеты в формат (head, relation, tail) без полного URI

# %%
import pandas as pd
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDF, RDFS, OWL
import re
import numpy as np

g = Graph()
g.parse("harrypotter_kg_ru.ttl", format="turtle")

BASE_IRI = "http://www.semanticweb.org/ekaterinakulesova/ontologies/2025/0/harry_potter#"

def qn_clean(term):
    if isinstance(term, URIRef):
        term_str = str(term)
        if term_str.startswith(BASE_IRI):
            return "hpo:" + term_str.split("#")[-1]
        for prefix, uri in g.namespaces():
            if term_str.startswith(uri):
                return f"{prefix}:{term_str[len(uri):].replace('#', '')}"
        return term_str
    if isinstance(term, Literal):
        return str(term)
    return str(term)


all_triples = []
for s, p, o in g:
    s_clean = qn_clean(s)
    p_clean = qn_clean(p)
    o_clean = qn_clean(o)

    if isinstance(o, Literal):
        continue

    if p in (RDFS.label, RDFS.comment):
        continue
    if p == RDF.type and "Class" in o_clean:
        continue

    all_triples.append((s_clean, p_clean, o_clean))

all_triples_df = pd.DataFrame(list(set(all_triples)), columns=["head", "relation", "tail"])

print(f"Общее количество триплетов для KGE: {len(all_triples_df)}")
print(all_triples_df.head())
# Out:
# Общее количество триплетов для KGE: 3696
#                                                 head       relation  \
# 0                              hpo:Kuinni_Goldshtein      hpo:sonOf
# 1                       hpo:Doch_Kallidory_i_Arfanga       rdf:type
# 2                                          hpo:Genri    hpo:hasRole
# 3  hpo:Garantirovannyi_desiatisekundnyi_pryshchev...       rdf:type
# 4                                 hpo:Sirius_Blek_II  hpo:hasSister
#
#                                           tail
# 0                          hpo:Niut_Salamander
# 1                                hpo:Character
# 2  hpo:Podsobnyi_rabochii_v_bulochnoi_Kovalski
# 3                                   hpo:Potion
# 4                             hpo:Belvina_Blek

# %% [markdown]
# Разбиение датасета (Train/Test)

# %%
from sklearn.model_selection import train_test_split

train_kg_df, test_kg_df = train_test_split(
    all_triples_df,
    test_size=0.1,
    random_state=42
)

# %% [markdown]
# Используем PyKEEN для инициализации и обучения модели.

# %%
from pykeen.pipeline import pipeline
from pykeen.triples import TriplesFactory
from pykeen.models import TransE
import torch
import numpy as np
import pandas as pd


all_factory = TriplesFactory.from_labeled_triples(
    triples=all_triples_df.values,
    create_inverse_triples=True
)
training_data_factory = TriplesFactory.from_labeled_triples(
    triples=train_kg_df.values,
    entity_to_id=all_factory.entity_to_id,
    relation_to_id=all_factory.relation_to_id,
    create_inverse_triples=True
)

training_factory, validation_factory = training_data_factory.split(
    ratios=[0.98, 0.02],
    random_state=42
)

results = pipeline(
    training=training_factory,
    validation=validation_factory,
    testing=validation_factory,
    model=TransE,
    model_kwargs=dict(
        embedding_dim=400,
        scoring_fct_norm=1,
    ),
    loss='MarginRankingLoss',
    loss_kwargs=dict(margin=5.0),
    negative_sampler='basic',
    negative_sampler_kwargs=dict(num_negs_per_pos=10),
    regularizer='Lp',
    regularizer_kwargs=dict(p=2, weight=1e-6),
    optimizer='Adam',
    optimizer_kwargs=dict(lr=1e-3),
    training_kwargs=dict(num_epochs=1200, batch_size=1024),
    stopper='early',
    stopper_kwargs=dict(frequency=5, patience=20, relative_delta=1e-3),
    random_seed=42,
    device='cuda' if torch.cuda.is_available() else 'cpu',
)

model = results.model
results.save_to_directory('pykeen_hp_kg_transe_tuned')

print("Обучение KGE завершено.")
print("--- Метрики после внутреннего сплита ---")
print(str(results.metric_results))

global ALL_FACTORY
ALL_FACTORY = all_factory
# Out:
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [1257, 67]
# INFO:pykeen.pipeline.api:Using device: cpu
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding(
#   (regularizer): LpRegularizer()
# )
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding(
#   (regularizer): LpRegularizer()
# )
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Training epochs on cpu:   0%|          | 0/1200 [00:00<?, ?epoch/s]
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.60s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 5: 0.27611940298507465. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 5.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 10: 0.4626865671641791. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 10.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.77s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 15: 0.5074626865671642. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 15.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.36s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.94s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.49s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.72s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.64s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.29s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 45: 0.5149253731343284. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 45.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.50s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 50: 0.5223880597014925. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 50.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.54s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.48s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 65: 0.5373134328358209. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 65.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.56s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 70: 0.5447761194029851. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 70.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.43s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 75: 0.5597014925373134. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 75.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.56s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.48s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.59s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 90: 0.5746268656716418. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 90.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.61s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.60s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.40s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 105: 0.5970149253731343. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 105.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.88s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.61s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.60s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.57s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.62s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.62s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.55s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.64s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.62s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.45s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.61s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.38s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.56s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.38s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 205: 0.6044776119402985. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 205.
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.38s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.61s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.56s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.60s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.38s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.50s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.62s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.61s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.61s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.62s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.49s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.60s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.40s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.84s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.59s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.59s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.39s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.62s seconds
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/7.00 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.40s seconds
# INFO:pykeen.stoppers.early_stopping:Stopping early at epoch 305. The best result 0.6044776119402985 occurred at epoch 205.
# INFO:pykeen.stoppers.early_stopping:Re-loading weights from best epoch from /root/.data/pykeen/checkpoints/best-model-weights-27d66611-9b51-4107-88e4-885c91545947.pt
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/67.0 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.49s seconds
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=2149, num_relations=50, create_inverse_triples=True, num_triples=3259) to file:///content/pykeen_hp_kg_transe_tuned/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /content/pykeen_hp_kg_transe_tuned
# Обучение KGE завершено.
# --- Метрики после внутреннего сплита ---
# <pykeen.evaluation.rank_based_evaluator.RankBasedMetricResults object at 0x7d542d801d00>

# %% [markdown]
# Оценка на валидационной выборке.

# %%
flat_metrics = results.metric_results.to_flat_dict()

MR_KEY = 'both.realistic.arithmetic_mean_rank'
MRR_KEY = 'both.realistic.inverse_harmonic_mean_rank'
HITS10_KEY = 'both.realistic.hits_at_10'
HITS3_KEY = 'both.realistic.hits_at_3'
HITS1_KEY = 'both.realistic.hits_at_1'

try:
    print(f"MRR (Mean Reciprocal Rank): {flat_metrics[MRR_KEY]:.4f}")
    print(f"Hits@10: {flat_metrics[HITS10_KEY]:.4f}")
    print(f"Hits@3: {flat_metrics[HITS3_KEY]:.4f}")
    print(f"Hits@1: {flat_metrics[HITS1_KEY]:.4f}")
except KeyError as e:
    print(f"Критическая ошибка: Не удалось найти метрику по ключу: {e}. Проверьте, что обучение прошло успешно.")
# Out:
# MRR (Mean Reciprocal Rank): 0.2015
# Hits@10: 0.6045
# Hits@3: 0.3433
# Hits@1: 0.0000

# %% [markdown]
# Кластеризация.

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import adjusted_rand_score
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import numpy as np
import pandas as pd
from rdflib.namespace import RDF
from rdflib import URIRef

if 'ALL_FACTORY' not in globals() or 'model' not in globals() or 'g' not in globals():
    raise NameError("Критические переменные (ALL_FACTORY, model, g) не найдены. Убедитесь, что нужная ячейка выполнена.")

entity_ids = torch.tensor(list(ALL_FACTORY.entity_to_id.values()), dtype=torch.long)
all_entity_embeddings = model.entity_representations[0](indices=entity_ids).detach().cpu().numpy()

id_to_entity = {v: k for k, v in ALL_FACTORY.entity_to_id.items()}
entity_to_embedding = {id_to_entity[i]: all_entity_embeddings[i] for i in entity_ids.tolist()}

all_entity_types = {}
BASE_IRI = "http://www.semanticweb.org/ekaterinakulesova/ontologies/2025/0/harry_potter#"

def qn_clean(term):
    if isinstance(term, URIRef):
        term_str = str(term)
        if term_str.startswith(BASE_IRI):
            return "hpo:" + term_str.split("#")[-1]
        for prefix, uri in g.namespaces():
            if term_str.startswith(uri):
                return f"{prefix}:{term_str[len(uri):].replace('#', '')}"
        return term_str
    return str(term)

for s, p, o in g.triples((None, RDF.type, None)):
    s_clean = qn_clean(s)
    o_clean = qn_clean(o)
    if s_clean.startswith("hpo:"):
        if s_clean not in all_entity_types:
            all_entity_types[s_clean] = set()
        all_entity_types[s_clean].add(o_clean.replace("hpo:", ""))

PRIORITY = {
    "Wizard": 5, "Muggle": 4, "Squib": 3,
    "Centaur": 3, "Ghost": 3, "Giant": 3, "House_elf": 3, "Mermaid": 3,
    "Magical_creature": 2,
    "Human": 1,
    "Character": 0
}

entity_type_map = {}
for entity, types in all_entity_types.items():
    best_type = "Non_Character"
    max_priority = -2

    for t in types:
        prio = PRIORITY.get(t, -1) # -1 для типов, которые не в списке (например, Artifact, Location)

        if prio > max_priority:
            max_priority = prio
            best_type = t

    if max_priority >= PRIORITY["Character"]:
        entity_type_map[entity] = best_type

valid_characters_set = {e for e in entity_type_map if entity_type_map[e] != "Non_Character" and e in entity_to_embedding}
valid_characters = list(valid_characters_set)

X = np.array([entity_to_embedding[e] for e in valid_characters])
labels_true_all = [entity_type_map[e] for e in valid_characters]

y_binary_for_ars = np.array([1 if l == "Wizard" else 0 for l in labels_true_all])

print(f"Общее количество персонажей для классификации: {len(X)}")
print(f"Распределение классов в labels_true: \n{pd.Series(labels_true_all).value_counts()}")

global character_embeddings, labels_true_all, valid_characters
character_embeddings = X
labels_true_all = labels_true_all
valid_characters = valid_characters


# снижение размерности
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x=X_reduced[:, 0], y=X_reduced[:, 1], hue=labels_true_all, palette='viridis', legend='full')
plt.title('Ожидаемые кластеры (Ground Truth)')
plt.xlabel('PCA-1')
plt.ylabel('PCA-2')

# Применение KMeans
k = len(set(labels_true_all))
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
y_pred = kmeans.fit_predict(X)

plt.subplot(1, 2, 2)
sns.scatterplot(x=X_reduced[:, 0], y=X_reduced[:, 1], hue=y_pred, palette='tab10', legend='full')
plt.title(f'Результаты KMeans (K={k})')
plt.xlabel('PCA-1')
plt.ylabel('PCA-2')
plt.tight_layout()
plt.show()

ars = adjusted_rand_score(y_binary_for_ars, y_pred)
print(f"\nAdjusted Rand Score (Ground Truth Wizard/Non-Wizard vs KMeans): {ars:.4f}")
# Out:
# Общее количество персонажей для классификации: 762
# Распределение классов в labels_true:
# Human        308
# Wizard       267
# Character     75
# Muggle        50
# Ghost         26
# Squib         16
# Giant         12
# Centaur        8
# Name: count, dtype: int64
# Adjusted Rand Score (Ground Truth Wizard/Non-Wizard vs KMeans): 0.2471

# %% [markdown]
# Классификация.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# Wizard 1 Non-Wizard 0
X = character_embeddings
y_binary = np.array([1 if l == "Wizard" else 0 for l in labels_true_all])

print(f"Распределение классов (0:Non-Wizard, 1:Wizard) в полном наборе: {pd.Series(y_binary).value_counts()}")

X_train, X_test, y_train, y_test = train_test_split(
    X, y_binary,
    test_size=0.2,
    random_state=42,
    stratify=y_binary
)

print(f"Размер обучающей выборки (Train/Test): {len(X_train)} / {len(X_test)}")

# применение модели классификации (Logistic Regression)
clf = LogisticRegression(random_state=42, max_iter=1000)
clf.fit(X_train, y_train)
y_pred_kge = clf.predict(X_test)
accuracy_kge = accuracy_score(y_test, y_pred_kge)

print("\n--- Оценка Классификации (Wizard/Non-Wizard) ---")
print(f"Точность модели KGE-embeddings: {accuracy_kge:.4f}")


#модель 1: выдает наиболее часто встречающийся класс
majority_class = pd.Series(y_train).mode()[0]
y_base1_pred = np.full_like(y_test, majority_class)
accuracy_base1 = accuracy_score(y_test, y_base1_pred)
print(f"Точность базовой модели (Majority Class {majority_class}): {accuracy_base1:.4f}")

# модель 2: One-Hot Encoding Representation
ohe_data = pd.get_dummies(pd.Series(valid_characters))
X_ohe = ohe_data.values

# Выполняем тот же сплит на OHE-данных
X_ohe_train, X_ohe_test, _, _ = train_test_split(
    X_ohe, y_binary,
    test_size=0.2,
    random_state=42,
    stratify=y_binary
)

# Обучение на OHE
clf_ohe = LogisticRegression(random_state=42, max_iter=1000)
clf_ohe.fit(X_ohe_train, y_train)
y_pred_ohe = clf_ohe.predict(X_ohe_test)
accuracy_base2 = accuracy_score(y_test, y_pred_ohe)
print(f"Точность базовой модели (One-Hot Encoding): {accuracy_base2:.4f}")

# Вывод
improvement = accuracy_kge - accuracy_base2
print(f"\nВывод: Точность улучшилась на {improvement:.4f} по сравнению с OHE.")
# Out:
# Распределение классов (0:Non-Wizard, 1:Wizard) в полном наборе: 0    495
# 1    267
# Name: count, dtype: int64
# Размер обучающей выборки (Train/Test): 609 / 153
#
# --- Оценка Классификации (Wizard/Non-Wizard) ---
# Точность модели KGE-embeddings: 0.9477
# Точность базовой модели (Majority Class 0): 0.6471
# Точность базовой модели (One-Hot Encoding): 0.6471
#
# Вывод: Точность улучшилась на 0.3007 по сравнению с OHE.

# %% [markdown]
# Предсказание недостающих ссылок
# Цель: Использовать KGE-модель для оценки ее способности предсказывать недостающие триплеты в оригинальной тестовой выборке (test_kg_df - 20% всех триплетов).

# %%
from pykeen.evaluation import RankBasedEvaluator
from pykeen.triples import TriplesFactory
import torch

testing_factory = TriplesFactory.from_labeled_triples(
    triples=test_kg_df.values,
    entity_to_id=ALL_FACTORY.entity_to_id,
    relation_to_id=ALL_FACTORY.relation_to_id,
    create_inverse_triples=True # Должно соответствовать настройкам обучения
)

# Выполнение оценки (предсказание и ранжирование)
evaluator = RankBasedEvaluator()
metric_results = evaluator.evaluate(
    model=model,
    mapped_triples=testing_factory.mapped_triples,
    additional_filter_triples=[training_data_factory.mapped_triples],
    batch_size=256,
)

print("\n--- Оценка на финальной Тестовой Выборке (Link Prediction) ---")

# количественная оценка (MRR, Hits@10)
flat_metrics = metric_results.to_flat_dict()
MR_KEY = 'both.realistic.arithmetic_mean_rank'
MRR_KEY = 'both.realistic.inverse_harmonic_mean_rank'
HITS10_KEY = 'both.realistic.hits_at_10'

try:
    #print(f"MR (Mean Rank) на Test Set: {flat_metrics[MR_KEY]:.2f}")
    print(f"MRR (Mean Reciprocal Rank) на Test Set: {flat_metrics[MRR_KEY]:.4f}")
    print(f"Hits@10 на Test Set: {flat_metrics[HITS10_KEY]:.4f}")
except KeyError as e:
     print(f"Ошибка: Не удалось найти метрику по ключу: {e}. Проверьте правильность ключей.")
# Out:
# Evaluating on cpu:   0%|          | 0.00/370 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 8.21s seconds
# --- Оценка на финальной Тестовой Выборке (Link Prediction) ---
# MRR (Mean Reciprocal Rank) на Test Set: 0.1171
# Hits@10 на Test Set: 0.3905

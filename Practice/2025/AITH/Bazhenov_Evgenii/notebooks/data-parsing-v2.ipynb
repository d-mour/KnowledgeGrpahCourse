# %%
from bs4 import BeautifulSoup
from pathlib import Path
import os
from rdflib import Graph, Namespace, Literal, RDF

path = Path("../data/civilopedia/www.civilopedia.net/gathering-storm/")
civilization_and_leaders_folder_path = path / "civilizations"
ontology_file = "civ6-ontology-v2.rdf"
ns = Namespace("http://n4d.sh/civ6#")

# %%
g = Graph()
if os.path.exists(ontology_file):
    g.parse(ontology_file, format="xml")
else:
    print(f"Ontology file '{ontology_file}' not found. A new file will be created.")

# %%
import importlib
import src.features.process_civilizations

importlib.reload(src.features.process_civilizations)

from src.features.process_civilizations import process_civilization

process_civilization(civilization_and_leaders_folder_path, g=g, ns=ns)

g.serialize(destination=ontology_file, format="xml")
print(f"Updated ontology saved to {ontology_file}")
# Out:
# Updated ontology saved to civ6-ontology-v2.rdf

# %%
import importlib
import src.features.process_religions

importlib.reload(src.features.process_religions)

from src.features.process_religions import process_religions

process_religions(path / "religions", g=g, ns=ns, replace=True)

g.serialize(destination=ontology_file, format="xml")
print(f"Updated ontology saved to {ontology_file}")
# Out:
# Added Catholicism religion
# Added Islam religion
# Added Buddhism religion
# Added Hinduism religion
# Added Protestantism religion
# Added Confucianism religion
# Added Shinto religion
# Added Sikhism religion
# Added Judaism religion
# Added Taoism religion
# Added Zoroastrianism religion
# Added Eastern Orthodoxy religion
# Updated ontology saved to civ6-ontology-v2.rdf

# %%
import importlib
import src.features.process_leaders

importlib.reload(src.features.process_leaders)

from src.features.process_leaders import process_leaders
process_leaders(civilization_and_leaders_folder_path, g=g, ns=ns)

g.serialize(destination=ontology_file, format="xml")
print(f"Updated ontology saved to {ontology_file}")
# Out:
# Added leader John_Curtin
# Linked leader John_Curtin to civilization Australia
# Added leader Seondeok
# Linked leader Seondeok to religion Korea
# Linked leader Seondeok to civilization Korea
# Added leader Sejong
# Linked leader Sejong to religion Korea
# Linked leader Sejong to civilization Korea
# Added leader Pedro_II
# Linked leader Pedro_II to religion Brazil
# Linked leader Pedro_II to civilization Brazil
# Added leader Gitarja
# Linked leader Gitarja to religion Indonesia
# Linked leader Gitarja to civilization Indonesia
# Added leader Harald_Hardrada
# Linked leader Harald_Hardrada to religion Norway
# Linked leader Harald_Hardrada to civilization Norway
# Added leader Gorgo
# Linked leader Gorgo to civilization Greece
# Added leader Peter_I
# Linked leader Peter_I to religion Russia
# Linked leader Peter_I to civilization Russia
# Added leader Teddy_Roosevelt_(Rough_Rider)
# Linked leader Teddy_Roosevelt_(Rough_Rider) to religion America
# Linked leader Teddy_Roosevelt_(Rough_Rider) to civilization America
# Added leader Wu_Zetian
# Linked leader Wu_Zetian to religion China
# Linked leader Wu_Zetian to civilization China
# Added leader Yongle
# Linked leader Yongle to religion China
# Linked leader Yongle to civilization China
# Added leader Cleopatra_VII
# Linked leader Cleopatra_VII to civilization Egypt
# Added leader Eleanor_of_Aquitaine
# Linked leader Eleanor_of_Aquitaine to religion England
# Linked leader Eleanor_of_Aquitaine to civilization England
# Added leader Abraham_Lincoln
# Linked leader Abraham_Lincoln to religion America
# Linked leader Abraham_Lincoln to civilization America
# Added leader Hojo_Tokimune
# Linked leader Hojo_Tokimune to religion Japan
# Linked leader Hojo_Tokimune to civilization Japan
# Added leader Suleiman_(Muhteşem)
# Linked leader Suleiman_(Muhteşem) to religion Ottomans
# Linked leader Suleiman_(Muhteşem) to civilization Ottomans
# Added leader Philip_II
# Linked leader Philip_II to religion Spain
# Linked leader Philip_II to civilization Spain
# Added leader Kristina
# Linked leader Kristina to religion Sweden
# Linked leader Kristina to civilization Sweden
# Added leader Qin_Shi_Huang
# Linked leader Qin_Shi_Huang to religion China
# Linked leader Qin_Shi_Huang to civilization China
# Added leader Eleanor_of_Aquitaine
# Linked leader Eleanor_of_Aquitaine to religion France
# Linked leader Eleanor_of_Aquitaine to civilization France
# Added leader Menelik_II
# Linked leader Menelik_II to religion Ethiopia
# Linked leader Menelik_II to civilization Ethiopia
# Added leader Jadwiga
# Linked leader Jadwiga to religion Poland
# Linked leader Jadwiga to civilization Poland
# Added leader Shaka
# Linked leader Shaka to civilization Zulu
# Added leader Genghis_Khan
# Linked leader Genghis_Khan to civilization Mongolia
# Added leader Saladin
# Linked leader Saladin to religion Arabia
# Linked leader Saladin to civilization Arabia
# Added leader Kublai_Khan_(Mongolia)
# Linked leader Kublai_Khan_(Mongolia) to religion Mongolia
# Linked leader Kublai_Khan_(Mongolia) to civilization Mongolia
# Added leader Mansa_Musa
# Linked leader Mansa_Musa to religion Mali
# Linked leader Mansa_Musa to civilization Mali
# Added leader Simón_Bolívar
# Linked leader Simón_Bolívar to religion Gran_Colombia
# Linked leader Simón_Bolívar to civilization Gran_Colombia
# Added leader Mvemba_a_Nzinga
# Linked leader Mvemba_a_Nzinga to religion Kongo
# Linked leader Mvemba_a_Nzinga to civilization Kongo
# Added leader Wilhelmina
# Linked leader Wilhelmina to religion Netherlands
# Linked leader Wilhelmina to civilization Netherlands
# Added leader Kupe
# Linked leader Kupe to civilization Māori
# Added leader Lautaro
# Linked leader Lautaro to civilization Mapuche
# Added leader João_III
# Linked leader João_III to religion Portugal
# Linked leader João_III to civilization Portugal
# Added leader Ambiorix
# Linked leader Ambiorix to civilization Gaul
# Added leader Mohandas_Karamchand_Gandhi
# Linked leader Mohandas_Karamchand_Gandhi to religion India
# Linked leader Mohandas_Karamchand_Gandhi to civilization India
# Added leader Dido_of_Carthage
# Linked leader Dido_of_Carthage to religion Phoenicia
# Linked leader Dido_of_Carthage to civilization Phoenicia
# Added leader Elizabeth_I
# Linked leader Elizabeth_I to religion England
# Linked leader Elizabeth_I to civilization England
# Added leader Pericles
# Linked leader Pericles to civilization Greece
# Added leader Trajan
# Linked leader Trajan to civilization Rome
# Added leader Ludwig_II
# Linked leader Ludwig_II to religion Germany
# Linked leader Ludwig_II to civilization Germany
# Added leader Victoria
# Linked leader Victoria to religion England
# Linked leader Victoria to civilization England
# Added leader Tomyris
# Linked leader Tomyris to civilization Scythia
# Added leader Chandragupta
# Linked leader Chandragupta to religion India
# Linked leader Chandragupta to civilization India
# Added leader Lady_Six_Sky
# Linked leader Lady_Six_Sky to civilization Maya
# Added leader Julius_Caesar
# Linked leader Julius_Caesar to civilization Rome
# Added leader Harald_Hardrada_(Varangian)
# Linked leader Harald_Hardrada_(Varangian) to religion Norway
# Linked leader Harald_Hardrada_(Varangian) to civilization Norway
# Added leader Poundmaker_(Pitikwahanapiwiyin)
# Linked leader Poundmaker_(Pitikwahanapiwiyin) to civilization Cree
# Added leader Catherine_de_Medici_(Magnificence)
# Linked leader Catherine_de_Medici_(Magnificence) to religion France
# Linked leader Catherine_de_Medici_(Magnificence) to civilization France
# Added leader Qin_(Unifier)
# Linked leader Qin_(Unifier) to religion China
# Linked leader Qin_(Unifier) to civilization China
# Added leader Gilgamesh
# Linked leader Gilgamesh to civilization Sumeria
# Added leader Theodora
# Linked leader Theodora to religion Byzantium
# Linked leader Theodora to civilization Byzantium
# Added leader Cyrus
# Linked leader Cyrus to religion Persia
# Linked leader Cyrus to civilization Persia
# Added leader Nader_Shah
# Linked leader Nader_Shah to religion Persia
# Linked leader Nader_Shah to civilization Persia
# Added leader Tamar_the_Great
# Linked leader Tamar_the_Great to religion Georgia
# Linked leader Tamar_the_Great to civilization Georgia
# Added leader Hammurabi
# Linked leader Hammurabi to civilization Babylon
# Added leader Jayavarman_VII
# Linked leader Jayavarman_VII to religion Khmer
# Linked leader Jayavarman_VII to civilization Khmer
# Added leader Saladin_(Sultan)
# Linked leader Saladin_(Sultan) to religion Arabia
# Linked leader Saladin_(Sultan) to civilization Arabia
# Added leader Bà_Triệu
# Linked leader Bà_Triệu to civilization Vietnam
# Added leader Kublai_Khan_(China)
# Linked leader Kublai_Khan_(China) to religion China
# Linked leader Kublai_Khan_(China) to civilization China
# Added leader Alexander
# Linked leader Alexander to civilization Macedon
# Added leader Victoria_(Age_of_Steam)
# Linked leader Victoria_(Age_of_Steam) to religion England
# Linked leader Victoria_(Age_of_Steam) to civilization England
# Added leader Amanitore
# Linked leader Amanitore to civilization Nubia
# Added leader Theodore_Roosevelt
# Linked leader Theodore_Roosevelt to religion America
# Linked leader Theodore_Roosevelt to civilization America
# Added leader Matthias_Corvinus
# Linked leader Matthias_Corvinus to religion Hungary
# Linked leader Matthias_Corvinus to civilization Hungary
# Added leader Catherine_de_Medici
# Linked leader Catherine_de_Medici to religion France
# Linked leader Catherine_de_Medici to civilization France
# Added leader Wilfrid_Laurier
# Linked leader Wilfrid_Laurier to religion Canada
# Linked leader Wilfrid_Laurier to civilization Canada
# Added leader Ramses_II
# Linked leader Ramses_II to civilization Egypt
# Added leader Basil_II
# Linked leader Basil_II to religion Byzantium
# Linked leader Basil_II to civilization Byzantium
# Added leader Suleiman_I,_The_Magnificent
# Linked leader Suleiman_I,_The_Magnificent to religion Ottomans
# Linked leader Suleiman_I,_The_Magnificent to civilization Ottomans
# Added leader Frederick_Barbarossa
# Linked leader Frederick_Barbarossa to religion Germany
# Linked leader Frederick_Barbarossa to civilization Germany
# Added leader Cleopatra_(Ptolemaic)
# Linked leader Cleopatra_(Ptolemaic) to civilization Egypt
# Added leader Nzinga_Mbande
# Linked leader Nzinga_Mbande to civilization Kongo
# Added leader Tokugawa
# Linked leader Tokugawa to religion Japan
# Linked leader Tokugawa to civilization Japan
# Added leader Sundiata_Keita
# Linked leader Sundiata_Keita to religion Mali
# Linked leader Sundiata_Keita to civilization Mali
# Added leader Pachacuti_Inca_Yupanqui
# Linked leader Pachacuti_Inca_Yupanqui to civilization Inca
# Added leader Montezuma_I
# Linked leader Montezuma_I to civilization Aztec
# Added leader Robert_the_Bruce
# Linked leader Robert_the_Bruce to religion Scotland
# Linked leader Robert_the_Bruce to civilization Scotland
# Updated ontology saved to civ6-ontology-v2.rdf

# %%
import importlib
import src.features.process_city_states

importlib.reload(src.features.process_city_states)

from src.features.process_city_states import process_city_states

process_city_states(path / "citystates", g=g, ns=ns)

g.serialize(destination=ontology_file, format="xml")
print(f"Updated ontology saved to {ontology_file}")
# Out:
# Processed city-state: Cahokia
# Processed city-state: Bandar_Brunei
# Processed city-state: Nan_Madol
# Processed city-state: Wolin
# Processed city-state: Nalanda
# Processed city-state: Akkad
# Processed city-state: Jerusalem
# Processed city-state: Antananarivo
# Processed city-state: Geneva
# Processed city-state: Muscat
# Processed city-state: Rapa_Nui
# Processed city-state: Fez
# Processed city-state: Yerevan
# Processed city-state: Caguana
# Processed city-state: Kandy
# Processed city-state: Kumasi
# Processed city-state: Ngazargamu
# Processed city-state: Chinguetti
# Processed city-state: Mitla
# Processed city-state: Mogadishu
# Processed city-state: Taruga
# Processed city-state: Kabul
# Processed city-state: Ayutthaya
# Processed city-state: Zanzibar
# Processed city-state: Lahore
# Processed city-state: Preslav
# Processed city-state: Hunza
# Processed city-state: Vatican_City
# Processed city-state: Samarkand
# Processed city-state: La_Venta
# Processed city-state: Armagh
# Processed city-state: Mohenjo-Daro
# Processed city-state: Hattusa
# Processed city-state: Valletta
# Processed city-state: Granada
# Processed city-state: Bologna
# Processed city-state: Nazca
# Processed city-state: Anshan
# Processed city-state: Venice
# Processed city-state: Vilnius
# Updated ontology saved to civ6-ontology-v2.rdf

# %%
import importlib
import src.features.process_technologies

importlib.reload(src.features.process_technologies)

from src.features.process_technologies import process_technologies

process_technologies(path / "technologies", g=g, ns=ns)

g.serialize(destination=ontology_file, format="xml")
print(f"Updated ontology saved to {ontology_file}")
# Out:
# Processed technology: Military_Science
# Processed technology: Electricity
# Processed technology: Siege_Tactics
# Processed technology: Banking
# Processed technology: Military_Tactics
# Processed technology: Predictive_Systems
# Processed technology: Buttress
# Processed technology: Cartography
# Processed technology: Ballistics
# Processed technology: Military_Engineering
# Processed technology: Guidance_Systems
# Processed technology: Castles
# Processed technology: Shipbuilding
# Processed technology: Construction
# Processed technology: Rifling
# Processed technology: Sanitation
# Processed technology: Advanced_Flight
# Processed technology: Replaceable_Parts
# Processed technology: Scientific_Theory
# Processed technology: Square_Rigging
# Processed technology: Synthetic_Materials
# Processed technology: Printing
# Processed technology: Satellites
# Processed technology: Refining
# Processed technology: Flight
# Processed technology: Nuclear_Fission
# Processed technology: Mathematics
# Processed technology: Stealth_Technology
# Processed technology: Mining
# Processed technology: Astronomy
# Processed technology: Bronze_Working
# Processed technology: Composites
# Processed technology: Offworld_Mission
# Processed technology: Wheel
# Processed technology: Radio
# Processed technology: Horseback_Riding
# Processed technology: Computers
# Processed technology: Gunpowder
# Processed technology: Currency
# Processed technology: Iron_Working
# Processed technology: Irrigation
# Processed technology: Sailing
# Processed technology: Nuclear_Fusion
# Processed technology: Combined_Arms
# Processed technology: Advanced_AI
# Processed technology: Cybernetics
# Processed technology: Smart_Materials
# Processed technology: Plastics
# Processed technology: Machinery
# Processed technology: Pottery
# Processed technology: Telecommunications
# Processed technology: Future_Tech
# Processed technology: Advanced_Ballistics
# Processed technology: Combustion
# Processed technology: Writing
# Processed technology: Industrialization
# Processed technology: Masonry
# Processed technology: Robotics
# Processed technology: Economics
# Processed technology: Engineering
# Processed technology: Astrology
# Processed technology: Animal_Husbandry
# Processed technology: Advanced_Power_Cells
# Processed technology: Nanotechnology
# Processed technology: Mass_Production
# Processed technology: Archery
# Processed technology: Lasers
# Processed technology: Steam_Power
# Processed technology: Steel
# Processed technology: Seasteads
# Processed technology: Rocketry
# Processed technology: Stirrups
# Processed technology: Metal_Casting
# Processed technology: Celestial_Navigation
# Processed technology: Apprenticeship
# Processed technology: Education
# Processed technology: Chemistry
# Updated ontology saved to civ6-ontology-v2.rdf

# %%
import importlib
import src.features.process_civics

importlib.reload(src.features.process_civics)

from src.features.process_civics import process_civics

process_civics(path / "civics", g=g, ns=ns)

g.serialize(destination=ontology_file, format="xml")
print(f"Updated ontology saved to {ontology_file}")
# Out:
# Processed technology: Natural_History
# Processed technology: Political_Philosophy
# Processed technology: Reformed_Church
# Processed technology: Optimization_Imperative
# Processed technology: Drama_and_Poetry
# Processed technology: Class_Struggle
# Processed technology: Mercenaries
# Processed technology: Mysticism
# Processed technology: Future_Civic
# Processed technology: Feudalism
# Processed technology: Military_Training
# Processed technology: Diplomatic_Service
# Processed technology: Defensive_Tactics
# Processed technology: Exploration
# Processed technology: Capitalism
# Processed technology: Environmentalism
# Processed technology: Distributed_Sovereignty
# Processed technology: Cultural_Hegemony
# Processed technology: Space_Race
# Processed technology: Colonialism
# Processed technology: Nuclear_Program
# Processed technology: Recorded_History
# Processed technology: Suffrage
# Processed technology: Early_Empire
# Processed technology: Smart_Power_Doctrine
# Processed technology: Guilds
# Processed technology: Scorched_Earth
# Processed technology: Globalization
# Processed technology: Information_Warfare
# Processed technology: Foreign_Trade
# Processed technology: Mass_Media
# Processed technology: Medieval_Faires
# Processed technology: Ideology
# Processed technology: Cold_War
# Processed technology: Opera_and_Ballet
# Processed technology: Craftsmanship
# Processed technology: Urbanization
# Processed technology: Conservation
# Processed technology: Totalitarianism
# Processed technology: Global_Warming_Mitigation
# Processed technology: Professional_Sports
# Processed technology: Exodus_Imperative
# Processed technology: State_Workforce
# Processed technology: Civil_Engineering
# Processed technology: Rapid_Deployment
# Processed technology: Venture_Politics
# Processed technology: Games_and_Recreation
# Processed technology: Military_Tradition
# Processed technology: Mercantilism
# Processed technology: Nationalism
# Processed technology: Cultural_Heritage
# Processed technology: Near_Future_Governance
# Processed technology: Naval_Tradition
# Processed technology: Theology
# Processed technology: Mobilization
# Processed technology: Civil_Service
# Processed technology: Code_of_Laws
# Processed technology: The_Enlightenment
# Processed technology: Social_Media
# Processed technology: Humanism
# Processed technology: Divine_Right
# Updated ontology saved to civ6-ontology-v2.rdf

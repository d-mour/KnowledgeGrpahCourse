# %%
from rdflib import Graph, Namespace
import pandas as pd

ns = Namespace("http://n4d.sh/civ6#")

# Загрузите онтологию
g = Graph()
g.parse("civ6-ontology-v2.rdf", format="xml")
# Out:
# <Graph identifier=N2f3c74198326490da5a59207993c4945 (<class 'rdflib.graph.Graph'>)>

# %%
def run_sparql_query(query, graph):
    """
    Executes a SPARQL query and returns results as a pandas DataFrame.
    """
    results = graph.query(query)
    data = []

    for row in results:
        data.append(
            {var: row[var] for var in row.labels}
        )  # Collect variables and their values

    return pd.DataFrame(data)

# %% [markdown]
# Отобразим найденных с помощью wikidata лидеров

# %%
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://n4d.sh/civ6#>

SELECT ?entity ?name ?civilizationName
WHERE {
  # ?entity :source "wikidata" ;
          :name ?name .
  OPTIONAL {
    # ?entity :rules ?civilization .
    # ?civilization :name ?civilizationName .
  }
}
"""

run_sparql_query(query, g)
# Out:
#                                             entity  \
# 0           http://n4d.sh/civ6#Alexander_the_Great
# 1                http://n4d.sh/civ6#Jayavarman_VII
# 2                       http://n4d.sh/civ6#Tomyris
# 3                       http://n4d.sh/civ6#Tomyris
# 4          http://n4d.sh/civ6#Harald_III_of_Norway
# 5                     http://n4d.sh/civ6#Cleopatra
# 6                       http://n4d.sh/civ6#Saladin
# 7               http://n4d.sh/civ6#Cyrus_the_Great
# 8               http://n4d.sh/civ6#Cyrus_the_Great
# 9                 http://n4d.sh/civ6#Hōjō_Tokimune
# 10                  http://n4d.sh/civ6#John_Curtin
# 11                     http://n4d.sh/civ6#Pericles
# 12                     http://n4d.sh/civ6#Pericles
# 13         http://n4d.sh/civ6#Catherine_de'_Medici
# 14           http://n4d.sh/civ6#Philip_II_of_Spain
# 15           http://n4d.sh/civ6#Philip_II_of_Spain
# 16         http://n4d.sh/civ6#Frédéric_Barberousse
# 17                     http://n4d.sh/civ6#Victoria
# 18                     http://n4d.sh/civ6#Victoria
# 19                    http://n4d.sh/civ6#Amanitore
# 20                    http://n4d.sh/civ6#Amanitore
# 21              http://n4d.sh/civ6#Peter_the_Great
# 22              http://n4d.sh/civ6#Peter_the_Great
# 23                       http://n4d.sh/civ6#Trajan
# 24                       http://n4d.sh/civ6#Trajan
# 25           http://n4d.sh/civ6#Theodore_Roosevelt
# 26           http://n4d.sh/civ6#Theodore_Roosevelt
# 27            http://n4d.sh/civ6#Hedwig_of_Silesia
# 28                        http://n4d.sh/civ6#Gorgo
# 29                        http://n4d.sh/civ6#Gorgo
# 30                  http://n4d.sh/civ6#Moctezuma_I
# 31            http://n4d.sh/civ6#Afonso_I_of_Kongo
# 32  http://n4d.sh/civ6#Tribhuwana_Wijayatunggadewi
# 33           http://n4d.sh/civ6#Pedro_II_of_Brazil
#
#                            name                             civilizationName
# 0           Alexander the Great                                    Macedonia
# 1                Jayavarman VII                                        Khmer
# 2                       Tomyris                                      Scythia
# 3                       Tomyris                                   Massagetae
# 4          Harald III of Norway                            Kingdom of Norway
# 5                     Cleopatra                            Ptolemaic Kingdom
# 6                       Saladin                                       Arabia
# 7               Cyrus the Great                            Achaemenid Empire
# 8               Cyrus the Great                                Anshan Persia
# 9                 Hōjō Tokimune                                        Japan
# 10                  John Curtin                                    Australia
# 11                     Pericles                                       Greece
# 12                     Pericles                             Classical Athens
# 13         Catherine de' Medici                                       France
# 14           Philip II of Spain                          Kingdom of Portugal
# 15           Philip II of Spain                                        Spain
# 16         Frédéric Barberousse                            Holy Roman Empire
# 17                     Victoria                                      England
# 18                     Victoria  United Kingdom of Great Britain and Ireland
# 19                    Amanitore                                        Nubia
# 20                    Amanitore                                         Kush
# 21              Peter the Great                            Tsardom of Russia
# 22              Peter the Great                               Russian Empire
# 23                       Trajan                                         Rome
# 24                       Trajan                                 Ancient Rome
# 25           Theodore Roosevelt                                      America
# 26           Theodore Roosevelt                                United States
# 27            Hedwig of Silesia                            Holy Roman Empire
# 28                        Gorgo                                       Greece
# 29                        Gorgo                                       Sparta
# 30                  Moctezuma I                                         None
# 31            Afonso I of Kongo                             Kingdom of Kongo
# 32  Tribhuwana Wijayatunggadewi                                         None
# 33           Pedro II of Brazil                                       Brazil

# %%
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://n4d.sh/civ6#>

SELECT ?leader ?name
WHERE {
  # ?leader a :Leader ;
          :name ?name ;
          :rules "None" .
}
"""

run_sparql_query(query, g)[0:10]
# Out:
#                                            leader                         name
# 0               http://n4d.sh/civ6#Jayavarman_VII               Jayavarman VII
# 1                      http://n4d.sh/civ6#Saladin                      Saladin
# 2                  http://n4d.sh/civ6#Moctezuma_I                  Moctezuma I
# 3  http://n4d.sh/civ6#Tribhuwana_Wijayatunggadewi  Tribhuwana Wijayatunggadewi

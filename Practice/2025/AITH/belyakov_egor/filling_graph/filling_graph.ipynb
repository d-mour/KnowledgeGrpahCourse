# %%
import requests

# %%
heroes = requests.get("https://api.opendota.com/api/heroes").json()
heroes
# Out:
# [{'id': 1,
#   'name': 'npc_dota_hero_antimage',
#   'localized_name': 'Anti-Mage',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'legs': 2},
#  {'id': 2,
#   'name': 'npc_dota_hero_axe',
#   'localized_name': 'Axe',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Carry'],
#   'legs': 2},
#  {'id': 3,
#   'name': 'npc_dota_hero_bane',
#   'localized_name': 'Bane',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Durable'],
#   'legs': 4},
#  {'id': 4,
#   'name': 'npc_dota_hero_bloodseeker',
#   'localized_name': 'Bloodseeker',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': 2},
#  {'id': 5,
#   'name': 'npc_dota_hero_crystal_maiden',
#   'localized_name': 'Crystal Maiden',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 6,
#   'name': 'npc_dota_hero_drow_ranger',
#   'localized_name': 'Drow Ranger',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Disabler', 'Pusher'],
#   'legs': 2},
#  {'id': 7,
#   'name': 'npc_dota_hero_earthshaker',
#   'localized_name': 'Earthshaker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 8,
#   'name': 'npc_dota_hero_juggernaut',
#   'localized_name': 'Juggernaut',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Escape'],
#   'legs': 2},
#  {'id': 9,
#   'name': 'npc_dota_hero_mirana',
#   'localized_name': 'Mirana',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Escape', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 10,
#   'name': 'npc_dota_hero_morphling',
#   'localized_name': 'Morphling',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Durable', 'Nuker', 'Disabler'],
#   'legs': 0},
#  {'id': 11,
#   'name': 'npc_dota_hero_nevermore',
#   'localized_name': 'Shadow Fiend',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker'],
#   'legs': 0},
#  {'id': 12,
#   'name': 'npc_dota_hero_phantom_lancer',
#   'localized_name': 'Phantom Lancer',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Pusher', 'Nuker'],
#   'legs': 2},
#  {'id': 13,
#   'name': 'npc_dota_hero_puck',
#   'localized_name': 'Puck',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Initiator', 'Disabler', 'Escape', 'Nuker'],
#   'legs': 2},
#  {'id': 14,
#   'name': 'npc_dota_hero_pudge',
#   'localized_name': 'Pudge',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 15,
#   'name': 'npc_dota_hero_razor',
#   'localized_name': 'Razor',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Nuker', 'Pusher'],
#   'legs': 0},
#  {'id': 16,
#   'name': 'npc_dota_hero_sand_king',
#   'localized_name': 'Sand King',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Support', 'Nuker', 'Escape'],
#   'legs': 6},
#  {'id': 17,
#   'name': 'npc_dota_hero_storm_spirit',
#   'localized_name': 'Storm Spirit',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Initiator', 'Disabler'],
#   'legs': 2},
#  {'id': 18,
#   'name': 'npc_dota_hero_sven',
#   'localized_name': 'Sven',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 19,
#   'name': 'npc_dota_hero_tiny',
#   'localized_name': 'Tiny',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Nuker', 'Pusher', 'Initiator', 'Durable', 'Disabler'],
#   'legs': 2},
#  {'id': 20,
#   'name': 'npc_dota_hero_vengefulspirit',
#   'localized_name': 'Vengeful Spirit',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'legs': 2},
#  {'id': 21,
#   'name': 'npc_dota_hero_windrunner',
#   'localized_name': 'Windranger',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Disabler', 'Escape', 'Nuker'],
#   'legs': 2},
#  {'id': 22,
#   'name': 'npc_dota_hero_zuus',
#   'localized_name': 'Zeus',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Carry'],
#   'legs': 2},
#  {'id': 23,
#   'name': 'npc_dota_hero_kunkka',
#   'localized_name': 'Kunkka',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 25,
#   'name': 'npc_dota_hero_lina',
#   'localized_name': 'Lina',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Carry', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 26,
#   'name': 'npc_dota_hero_lion',
#   'localized_name': 'Lion',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': 2},
#  {'id': 27,
#   'name': 'npc_dota_hero_shadow_shaman',
#   'localized_name': 'Shadow Shaman',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': 2},
#  {'id': 28,
#   'name': 'npc_dota_hero_slardar',
#   'localized_name': 'Slardar',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler', 'Escape'],
#   'legs': 0},
#  {'id': 29,
#   'name': 'npc_dota_hero_tidehunter',
#   'localized_name': 'Tidehunter',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Nuker', 'Carry'],
#   'legs': 2},
#  {'id': 30,
#   'name': 'npc_dota_hero_witch_doctor',
#   'localized_name': 'Witch Doctor',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 31,
#   'name': 'npc_dota_hero_lich',
#   'localized_name': 'Lich',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker'],
#   'legs': 2},
#  {'id': 32,
#   'name': 'npc_dota_hero_riki',
#   'localized_name': 'Riki',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler'],
#   'legs': 2},
#  {'id': 33,
#   'name': 'npc_dota_hero_enigma',
#   'localized_name': 'Enigma',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Disabler', 'Initiator', 'Pusher'],
#   'legs': 0},
#  {'id': 34,
#   'name': 'npc_dota_hero_tinker',
#   'localized_name': 'Tinker',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'legs': 2},
#  {'id': 35,
#   'name': 'npc_dota_hero_sniper',
#   'localized_name': 'Sniper',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker'],
#   'legs': 2},
#  {'id': 36,
#   'name': 'npc_dota_hero_necrolyte',
#   'localized_name': 'Necrophos',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Durable', 'Disabler'],
#   'legs': 2},
#  {'id': 37,
#   'name': 'npc_dota_hero_warlock',
#   'localized_name': 'Warlock',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Initiator', 'Disabler'],
#   'legs': 2},
#  {'id': 38,
#   'name': 'npc_dota_hero_beastmaster',
#   'localized_name': 'Beastmaster',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 39,
#   'name': 'npc_dota_hero_queenofpain',
#   'localized_name': 'Queen of Pain',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Escape'],
#   'legs': 2},
#  {'id': 40,
#   'name': 'npc_dota_hero_venomancer',
#   'localized_name': 'Venomancer',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Initiator', 'Pusher', 'Disabler'],
#   'legs': 0},
#  {'id': 41,
#   'name': 'npc_dota_hero_faceless_void',
#   'localized_name': 'Faceless Void',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Escape', 'Durable'],
#   'legs': 2},
#  {'id': 42,
#   'name': 'npc_dota_hero_skeleton_king',
#   'localized_name': 'Wraith King',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator'],
#   'legs': 2},
#  {'id': 43,
#   'name': 'npc_dota_hero_death_prophet',
#   'localized_name': 'Death Prophet',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 44,
#   'name': 'npc_dota_hero_phantom_assassin',
#   'localized_name': 'Phantom Assassin',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape'],
#   'legs': 2},
#  {'id': 45,
#   'name': 'npc_dota_hero_pugna',
#   'localized_name': 'Pugna',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Pusher'],
#   'legs': 2},
#  {'id': 46,
#   'name': 'npc_dota_hero_templar_assassin',
#   'localized_name': 'Templar Assassin',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape'],
#   'legs': 2},
#  {'id': 47,
#   'name': 'npc_dota_hero_viper',
#   'localized_name': 'Viper',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler'],
#   'legs': 0},
#  {'id': 48,
#   'name': 'npc_dota_hero_luna',
#   'localized_name': 'Luna',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'legs': 2},
#  {'id': 49,
#   'name': 'npc_dota_hero_dragon_knight',
#   'localized_name': 'Dragon Knight',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Durable', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': 2},
#  {'id': 50,
#   'name': 'npc_dota_hero_dazzle',
#   'localized_name': 'Dazzle',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 51,
#   'name': 'npc_dota_hero_rattletrap',
#   'localized_name': 'Clockwerk',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 52,
#   'name': 'npc_dota_hero_leshrac',
#   'localized_name': 'Leshrac',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Nuker', 'Pusher', 'Disabler'],
#   'legs': 4},
#  {'id': 53,
#   'name': 'npc_dota_hero_furion',
#   'localized_name': "Nature's Prophet",
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Escape', 'Nuker'],
#   'legs': 2},
#  {'id': 54,
#   'name': 'npc_dota_hero_life_stealer',
#   'localized_name': 'Lifestealer',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Escape', 'Disabler'],
#   'legs': 2},
#  {'id': 55,
#   'name': 'npc_dota_hero_dark_seer',
#   'localized_name': 'Dark Seer',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Escape', 'Disabler'],
#   'legs': 2},
#  {'id': 56,
#   'name': 'npc_dota_hero_clinkz',
#   'localized_name': 'Clinkz',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Pusher'],
#   'legs': 2},
#  {'id': 57,
#   'name': 'npc_dota_hero_omniknight',
#   'localized_name': 'Omniknight',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 58,
#   'name': 'npc_dota_hero_enchantress',
#   'localized_name': 'Enchantress',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher', 'Durable', 'Disabler'],
#   'legs': 4},
#  {'id': 59,
#   'name': 'npc_dota_hero_huskar',
#   'localized_name': 'Huskar',
#   'primary_attr': 'str',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Initiator'],
#   'legs': 2},
#  {'id': 60,
#   'name': 'npc_dota_hero_night_stalker',
#   'localized_name': 'Night Stalker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 61,
#   'name': 'npc_dota_hero_broodmother',
#   'localized_name': 'Broodmother',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Escape', 'Nuker'],
#   'legs': 8},
#  {'id': 62,
#   'name': 'npc_dota_hero_bounty_hunter',
#   'localized_name': 'Bounty Hunter',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Escape', 'Nuker'],
#   'legs': 2},
#  {'id': 63,
#   'name': 'npc_dota_hero_weaver',
#   'localized_name': 'Weaver',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape'],
#   'legs': 4},
#  {'id': 64,
#   'name': 'npc_dota_hero_jakiro',
#   'localized_name': 'Jakiro',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Pusher', 'Disabler'],
#   'legs': 2},
#  {'id': 65,
#   'name': 'npc_dota_hero_batrider',
#   'localized_name': 'Batrider',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Initiator', 'Disabler', 'Escape'],
#   'legs': 2},
#  {'id': 66,
#   'name': 'npc_dota_hero_chen',
#   'localized_name': 'Chen',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher'],
#   'legs': 2},
#  {'id': 67,
#   'name': 'npc_dota_hero_spectre',
#   'localized_name': 'Spectre',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Escape'],
#   'legs': 0},
#  {'id': 68,
#   'name': 'npc_dota_hero_ancient_apparition',
#   'localized_name': 'Ancient Apparition',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': 0},
#  {'id': 69,
#   'name': 'npc_dota_hero_doom_bringer',
#   'localized_name': 'Doom',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 70,
#   'name': 'npc_dota_hero_ursa',
#   'localized_name': 'Ursa',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Disabler'],
#   'legs': 2},
#  {'id': 71,
#   'name': 'npc_dota_hero_spirit_breaker',
#   'localized_name': 'Spirit Breaker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Durable', 'Escape'],
#   'legs': 2},
#  {'id': 72,
#   'name': 'npc_dota_hero_gyrocopter',
#   'localized_name': 'Gyrocopter',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 73,
#   'name': 'npc_dota_hero_alchemist',
#   'localized_name': 'Alchemist',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': 2},
#  {'id': 74,
#   'name': 'npc_dota_hero_invoker',
#   'localized_name': 'Invoker',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Escape', 'Pusher'],
#   'legs': 2},
#  {'id': 75,
#   'name': 'npc_dota_hero_silencer',
#   'localized_name': 'Silencer',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': 2},
#  {'id': 76,
#   'name': 'npc_dota_hero_obsidian_destroyer',
#   'localized_name': 'Outworld Destroyer',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'legs': 4},
#  {'id': 77,
#   'name': 'npc_dota_hero_lycan',
#   'localized_name': 'Lycan',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Durable', 'Escape'],
#   'legs': 2},
#  {'id': 78,
#   'name': 'npc_dota_hero_brewmaster',
#   'localized_name': 'Brewmaster',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 79,
#   'name': 'npc_dota_hero_shadow_demon',
#   'localized_name': 'Shadow Demon',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Initiator', 'Nuker'],
#   'legs': 2},
#  {'id': 80,
#   'name': 'npc_dota_hero_lone_druid',
#   'localized_name': 'Lone Druid',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Durable'],
#   'legs': 2},
#  {'id': 81,
#   'name': 'npc_dota_hero_chaos_knight',
#   'localized_name': 'Chaos Knight',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Durable', 'Pusher', 'Initiator'],
#   'legs': 2},
#  {'id': 82,
#   'name': 'npc_dota_hero_meepo',
#   'localized_name': 'Meepo',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator', 'Pusher'],
#   'legs': 2},
#  {'id': 83,
#   'name': 'npc_dota_hero_treant',
#   'localized_name': 'Treant Protector',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Initiator', 'Durable', 'Disabler', 'Escape'],
#   'legs': 2},
#  {'id': 84,
#   'name': 'npc_dota_hero_ogre_magi',
#   'localized_name': 'Ogre Magi',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Initiator'],
#   'legs': 2},
#  {'id': 85,
#   'name': 'npc_dota_hero_undying',
#   'localized_name': 'Undying',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Durable', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 86,
#   'name': 'npc_dota_hero_rubick',
#   'localized_name': 'Rubick',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 87,
#   'name': 'npc_dota_hero_disruptor',
#   'localized_name': 'Disruptor',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'legs': 2},
#  {'id': 88,
#   'name': 'npc_dota_hero_nyx_assassin',
#   'localized_name': 'Nyx Assassin',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Disabler', 'Nuker', 'Initiator', 'Escape'],
#   'legs': 6},
#  {'id': 89,
#   'name': 'npc_dota_hero_naga_siren',
#   'localized_name': 'Naga Siren',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Pusher', 'Disabler', 'Initiator', 'Escape'],
#   'legs': 0},
#  {'id': 90,
#   'name': 'npc_dota_hero_keeper_of_the_light',
#   'localized_name': 'Keeper of the Light',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 91,
#   'name': 'npc_dota_hero_wisp',
#   'localized_name': 'Io',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Escape', 'Nuker'],
#   'legs': 0},
#  {'id': 92,
#   'name': 'npc_dota_hero_visage',
#   'localized_name': 'Visage',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Durable', 'Disabler', 'Pusher'],
#   'legs': 2},
#  {'id': 93,
#   'name': 'npc_dota_hero_slark',
#   'localized_name': 'Slark',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 94,
#   'name': 'npc_dota_hero_medusa',
#   'localized_name': 'Medusa',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Disabler', 'Durable'],
#   'legs': 0},
#  {'id': 95,
#   'name': 'npc_dota_hero_troll_warlord',
#   'localized_name': 'Troll Warlord',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Disabler', 'Durable'],
#   'legs': 2},
#  {'id': 96,
#   'name': 'npc_dota_hero_centaur',
#   'localized_name': 'Centaur Warrunner',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Durable', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'legs': 4},
#  {'id': 97,
#   'name': 'npc_dota_hero_magnataur',
#   'localized_name': 'Magnus',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'legs': 4},
#  {'id': 98,
#   'name': 'npc_dota_hero_shredder',
#   'localized_name': 'Timbersaw',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Nuker', 'Durable', 'Escape'],
#   'legs': 2},
#  {'id': 99,
#   'name': 'npc_dota_hero_bristleback',
#   'localized_name': 'Bristleback',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Nuker'],
#   'legs': 2},
#  {'id': 100,
#   'name': 'npc_dota_hero_tusk',
#   'localized_name': 'Tusk',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 101,
#   'name': 'npc_dota_hero_skywrath_mage',
#   'localized_name': 'Skywrath Mage',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 102,
#   'name': 'npc_dota_hero_abaddon',
#   'localized_name': 'Abaddon',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Carry', 'Durable'],
#   'legs': 2},
#  {'id': 103,
#   'name': 'npc_dota_hero_elder_titan',
#   'localized_name': 'Elder Titan',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Durable'],
#   'legs': 2},
#  {'id': 104,
#   'name': 'npc_dota_hero_legion_commander',
#   'localized_name': 'Legion Commander',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'legs': 2},
#  {'id': 105,
#   'name': 'npc_dota_hero_techies',
#   'localized_name': 'Techies',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Disabler'],
#   'legs': 6},
#  {'id': 106,
#   'name': 'npc_dota_hero_ember_spirit',
#   'localized_name': 'Ember Spirit',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator'],
#   'legs': 2},
#  {'id': 107,
#   'name': 'npc_dota_hero_earth_spirit',
#   'localized_name': 'Earth Spirit',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Nuker', 'Escape', 'Disabler', 'Initiator', 'Durable'],
#   'legs': 2},
#  {'id': 108,
#   'name': 'npc_dota_hero_abyssal_underlord',
#   'localized_name': 'Underlord',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Escape'],
#   'legs': 2},
#  {'id': 109,
#   'name': 'npc_dota_hero_terrorblade',
#   'localized_name': 'Terrorblade',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Nuker'],
#   'legs': 2},
#  {'id': 110,
#   'name': 'npc_dota_hero_phoenix',
#   'localized_name': 'Phoenix',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Initiator', 'Escape', 'Disabler'],
#   'legs': 2},
#  {'id': 111,
#   'name': 'npc_dota_hero_oracle',
#   'localized_name': 'Oracle',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': 2},
#  {'id': 112,
#   'name': 'npc_dota_hero_winter_wyvern',
#   'localized_name': 'Winter Wyvern',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'legs': 2},
#  {'id': 113,
#   'name': 'npc_dota_hero_arc_warden',
#   'localized_name': 'Arc Warden',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'legs': 2},
#  {'id': 114,
#   'name': 'npc_dota_hero_monkey_king',
#   'localized_name': 'Monkey King',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler', 'Initiator'],
#   'legs': 2},
#  {'id': 119,
#   'name': 'npc_dota_hero_dark_willow',
#   'localized_name': 'Dark Willow',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': 2},
#  {'id': 120,
#   'name': 'npc_dota_hero_pangolier',
#   'localized_name': 'Pangolier',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Durable', 'Escape', 'Initiator'],
#   'legs': 2},
#  {'id': 121,
#   'name': 'npc_dota_hero_grimstroke',
#   'localized_name': 'Grimstroke',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': 0},
#  {'id': 123,
#   'name': 'npc_dota_hero_hoodwink',
#   'localized_name': 'Hoodwink',
#   'primary_attr': 'agi',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Escape', 'Disabler'],
#   'legs': 4},
#  {'id': 126,
#   'name': 'npc_dota_hero_void_spirit',
#   'localized_name': 'Void Spirit',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 128,
#   'name': 'npc_dota_hero_snapfire',
#   'localized_name': 'Snapfire',
#   'primary_attr': 'all',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'legs': 2},
#  {'id': 129,
#   'name': 'npc_dota_hero_mars',
#   'localized_name': 'Mars',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Durable'],
#   'legs': 2},
#  {'id': 131,
#   'name': 'npc_dota_hero_ringmaster',
#   'localized_name': 'Ringmaster',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Escape', 'Disabler'],
#   'legs': 2},
#  {'id': 135,
#   'name': 'npc_dota_hero_dawnbreaker',
#   'localized_name': 'Dawnbreaker',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable'],
#   'legs': 2},
#  {'id': 136,
#   'name': 'npc_dota_hero_marci',
#   'localized_name': 'Marci',
#   'primary_attr': 'all',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Carry', 'Initiator', 'Disabler', 'Escape'],
#   'legs': 2},
#  {'id': 137,
#   'name': 'npc_dota_hero_primal_beast',
#   'localized_name': 'Primal Beast',
#   'primary_attr': 'str',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler'],
#   'legs': 2},
#  {'id': 138,
#   'name': 'npc_dota_hero_muerta',
#   'localized_name': 'Muerta',
#   'primary_attr': 'int',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'legs': 2},
#  {'id': 145,
#   'name': 'npc_dota_hero_kez',
#   'localized_name': 'Kez',
#   'primary_attr': 'agi',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler'],
#   'legs': 2}]

# %%
id_to_name = {el["id"]: el["localized_name"] for el in heroes}

# %%
for hero in heroes:
    hero_id = hero["id"]
    hero_stats = requests.get(f"https://api.opendota.com/api/heroes/{hero_id}/matchups").json()
    hero_stats = [{"hero_name": id_to_name[el["hero_id"]], "win_rate": el["wins"] / el["games_played"]} for el in hero_stats]
    hero_stats = sorted(hero_stats, key=lambda x: x["win_rate"], reverse=True)
    best_versus = [el["hero_name"] for el in hero_stats[:10]]
    hero["best_versus"] = best_versus

# %%
import json

with open("../item_ids.json") as f:
    item_ids = json.load(f)


for hero in heroes:
    hero_id = hero["id"]
    hero_name = id_to_name[hero_id]
    items_info = requests.get(f"https://api.opendota.com/api/heroes/{hero_id}/itemPopularity").json()
    best_items = items_info.get("mid_game_items")
    if best_items is None:
        best_items = items_info.get("late_game_items")
    best_items = sorted(best_items.items(), key=lambda x: x[1], reverse=True)
    best_items = [best_items[i][0] for i in range(min(3, len(best_items)))]
    best_items = [item_ids[item_id] for item_id in best_items]
    hero["best_items"] = best_items

# %%
# dota2_relatives = [("Zeus", "Mars"), ("Ember-Spirit", "Storm-Spirit", "Void-Spirit", "Earth-Spirit"), ("Terrorblade", "Nature`s-Profit", "Enchantress"), 
#                    ("Snapfire", "Timbersaw"), ("Winter-Wyvern", "Dragon-Knight", "Jakiro"), ("Bane", "Faceless-Void"), ("Lina", "Crystal-Maiden")]

with open("../dota_relatives.txt") as f:
    dota_relatives = f.readlines()
    dota_relatives = [el.split() for el in dota_relatives]

relatives = dict()

for rel_el in dota_relatives:
    for i in range(len(rel_el)):
        hero_relatives = rel_el[:i]
        if i < len(rel_el) - 1:
            hero_relatives += rel_el[i + 1:]
        relatives[rel_el[i]] = hero_relatives
    
for hero in heroes:
    hero["relatives"] = relatives.get(hero["localized_name"].replace(" ", "-"), [])

# %%
relatives
# Out:
# {'Zeus': ['Mars'],
#  'Mars': ['Zeus'],
#  'Ember-Spirit': ['Storm-Spirit', 'Void-Spirit', 'Earth-Spirit'],
#  'Storm-Spirit': ['Ember-Spirit', 'Void-Spirit', 'Earth-Spirit'],
#  'Void-Spirit': ['Ember-Spirit', 'Storm-Spirit', 'Earth-Spirit'],
#  'Earth-Spirit': ['Ember-Spirit', 'Storm-Spirit', 'Void-Spirit'],
#  'Terrorblade': ['Natures-Prophet', 'Enchantress'],
#  'Natures-Prophet': ['Terrorblade', 'Enchantress'],
#  'Enchantress': ['Terrorblade', 'Natures-Prophet'],
#  'Snapfire': ['Timbersaw'],
#  'Timbersaw': ['Snapfire'],
#  'Winter-Wyvern': ['Dragon-Knight', 'Jakiro'],
#  'Dragon-Knight': ['Winter-Wyvern', 'Jakiro'],
#  'Jakiro': ['Winter-Wyvern', 'Dragon-Knight'],
#  'Bane': ['Faceless-Void'],
#  'Faceless-Void': ['Bane'],
#  'Lina': ['Crystal-Maiden'],
#  'Crystal-Maiden': ['Lina']}

# %%
cleaned_heroes = []

for hero in heroes:
    new_hero = {"name": hero["localized_name"].replace(" ", "-"), "attack_type": hero["attack_type"], "roles": hero["roles"]}
    attr = hero["primary_attr"]
    subclass = {"agi": "agile_hero", "str": "strong_hero", "all": "universal_hero", "int": "intellectual_hero"}[attr]
    new_hero["subclass"] = subclass
    new_hero["items"] = hero["best_items"]
    cleaned_best_bersus = [el.replace(" ", "-") for el in hero["best_versus"]]
    new_hero["best_versus"] = cleaned_best_bersus
    new_hero["relatives"] = hero["relatives"]

    cleaned_heroes.append(new_hero)

cleaned_heroes
# Out:
# [{'name': 'Anti-Mage',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'yasha', 'diadem'],
#   'best_versus': ['Phantom-Lancer',
#    'Enchantress',
#    'Naga-Siren',
#    'Broodmother',
#    'Arc-Warden',
#    'Chaos-Knight',
#    'Faceless-Void',
#    'Razor',
#    'Death-Prophet',
#    'Visage'],
#   'relatives': []},
#  {'name': 'Axe',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Carry'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'ogre_axe', 'blade_mail'],
#   'best_versus': ['Lone-Druid',
#    'Viper',
#    'Bristleback',
#    'Riki',
#    'Anti-Mage',
#    'Naga-Siren',
#    'Wraith-King',
#    'Silencer',
#    'Tinker',
#    'Skywrath-Mage'],
#   'relatives': []},
#  {'name': 'Bane',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Durable'],
#   'subclass': 'universal_hero',
#   'items': ['arcane_boots', 'staff_of_wizardry', 'aether_lens'],
#   'best_versus': ['Necrophos',
#    'Warlock',
#    'Arc-Warden',
#    'Meepo',
#    'Kunkka',
#    'Bristleback',
#    'Sniper',
#    'Dawnbreaker',
#    'Witch-Doctor',
#    'Nyx-Assassin'],
#   'relatives': ['Faceless-Void']},
#  {'name': 'Bloodseeker',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Nuker', 'Initiator'],
#   'subclass': 'agile_hero',
#   'items': ['ogre_axe', 'mithril_hammer', 'blade_of_alacrity'],
#   'best_versus': ['Underlord',
#    'Drow-Ranger',
#    'Naga-Siren',
#    'Tinker',
#    'Outworld-Destroyer',
#    'Ancient-Apparition',
#    'Lifestealer',
#    'Huskar',
#    'Dark-Seer',
#    'Doom'],
#   'relatives': []},
#  {'name': 'Crystal-Maiden',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['shadow_amulet', 'glimmer_cape', 'staff_of_wizardry'],
#   'best_versus': ['Phantom-Lancer',
#    'Bloodseeker',
#    'Anti-Mage',
#    'Huskar',
#    'Arc-Warden',
#    'Spectre',
#    'Dazzle',
#    'Outworld-Destroyer',
#    'Sniper',
#    'Sand-King'],
#   'relatives': ['Lina']},
#  {'name': 'Drow-Ranger',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Disabler', 'Pusher'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'dragon_lance', 'staff_of_wizardry'],
#   'best_versus': ['Meepo',
#    'Razor',
#    'Tidehunter',
#    'Sniper',
#    'Phantom-Lancer',
#    'Wraith-King',
#    'Bounty-Hunter',
#    'Omniknight',
#    'Axe',
#    'Ursa'],
#   'relatives': []},
#  {'name': 'Earthshaker',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'blink', 'point_booster'],
#   'best_versus': ['Dazzle',
#    'Arc-Warden',
#    'Witch-Doctor',
#    'Sand-King',
#    'Chaos-Knight',
#    'Juggernaut',
#    'Centaur-Warrunner',
#    'Kunkka',
#    'Spectre',
#    'Huskar'],
#   'relatives': []},
#  {'name': 'Juggernaut',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Escape'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'yasha', 'ogre_axe'],
#   'best_versus': ['Bristleback',
#    'Anti-Mage',
#    'Phantom-Lancer',
#    'Sand-King',
#    'Lone-Druid',
#    'Clinkz',
#    'Arc-Warden',
#    'Troll-Warlord',
#    'Snapfire',
#    'Dazzle'],
#   'relatives': []},
#  {'name': 'Mirana',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Escape', 'Nuker', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['staff_of_wizardry', 'aghanims_shard', 'blade_of_alacrity'],
#   'best_versus': ['Tinker',
#    'Abaddon',
#    'Necrophos',
#    'Brewmaster',
#    'Outworld-Destroyer',
#    'Silencer',
#    'Faceless-Void',
#    'Slark',
#    'Night-Stalker',
#    'Magnus'],
#   'relatives': []},
#  {'name': 'Morphling',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Durable', 'Nuker', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': ['diadem', 'blade_of_alacrity', 'yasha'],
#   'best_versus': ['Ringmaster',
#    'Phantom-Lancer',
#    'Arc-Warden',
#    'Dazzle',
#    'Jakiro',
#    'Necrophos',
#    'Tusk',
#    'Phantom-Assassin',
#    'Bounty-Hunter',
#    'Omniknight'],
#   'relatives': []},
#  {'name': 'Shadow-Fiend',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'dragon_lance', 'claymore'],
#   'best_versus': ['Meepo',
#    'Underlord',
#    'Spectre',
#    'Arc-Warden',
#    'Razor',
#    'Anti-Mage',
#    'Juggernaut',
#    'Kunkka',
#    'Dazzle',
#    'Ember-Spirit'],
#   'relatives': []},
#  {'name': 'Phantom-Lancer',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Pusher', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'staff_of_wizardry', 'point_booster'],
#   'best_versus': ['Io',
#    'Bloodseeker',
#    'Chaos-Knight',
#    'Oracle',
#    'Viper',
#    'Dazzle',
#    'Lycan',
#    'Bristleback',
#    'Shadow-Fiend',
#    'Tinker'],
#   'relatives': []},
#  {'name': 'Puck',
#   'attack_type': 'Ranged',
#   'roles': ['Initiator', 'Disabler', 'Escape', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['witch_blade', 'blink', 'oblivion_staff'],
#   'best_versus': ['Necrophos',
#    'Riki',
#    'Tinker',
#    'Phoenix',
#    'Vengeful-Spirit',
#    'Bristleback',
#    'Underlord',
#    'Witch-Doctor',
#    'Oracle',
#    'Terrorblade'],
#   'relatives': []},
#  {'name': 'Pudge',
#   'attack_type': 'Melee',
#   'roles': ['Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['aether_lens', 'ogre_axe', 'staff_of_wizardry'],
#   'best_versus': ['Ringmaster',
#    'Anti-Mage',
#    'Spectre',
#    'Arc-Warden',
#    'Underlord',
#    'Tinker',
#    'Oracle',
#    'Axe',
#    'Marci',
#    'Phantom-Lancer'],
#   'relatives': []},
#  {'name': 'Razor',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Nuker', 'Pusher'],
#   'subclass': 'agile_hero',
#   'items': ['ogre_axe', 'mithril_hammer', 'yasha'],
#   'best_versus': ['Visage',
#    'Void-Spirit',
#    'Juggernaut',
#    'Oracle',
#    'Viper',
#    'Arc-Warden',
#    'Bounty-Hunter',
#    'Witch-Doctor',
#    'Troll-Warlord',
#    'Bristleback'],
#   'relatives': []},
#  {'name': 'Sand-King',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Support', 'Nuker', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['blink', 'soul_booster', 'bloodstone'],
#   'best_versus': ['Phantom-Lancer',
#    'Arc-Warden',
#    'Witch-Doctor',
#    'Medusa',
#    'Warlock',
#    'Meepo',
#    'Oracle',
#    'Lich',
#    'Pugna',
#    'Tinker'],
#   'relatives': []},
#  {'name': 'Storm-Spirit',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Initiator', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['ogre_axe', 'oblivion_staff', 'blitz_knuckles'],
#   'best_versus': ['Phantom-Lancer',
#    'Dazzle',
#    'Viper',
#    'Drow-Ranger',
#    'Skywrath-Mage',
#    'Lich',
#    'Clinkz',
#    'Brewmaster',
#    'Phantom-Assassin',
#    'Void-Spirit'],
#   'relatives': ['Ember-Spirit', 'Void-Spirit', 'Earth-Spirit']},
#  {'name': 'Sven',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'broadsword', 'echo_sabre'],
#   'best_versus': ['Bloodseeker',
#    'Drow-Ranger',
#    'Dazzle',
#    'Earth-Spirit',
#    'Visage',
#    'Zeus',
#    'Witch-Doctor',
#    'Huskar',
#    'Juggernaut',
#    'Wraith-King'],
#   'relatives': []},
#  {'name': 'Tiny',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Nuker', 'Pusher', 'Initiator', 'Durable', 'Disabler'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'ogre_axe', 'diadem'],
#   'best_versus': ['Riki',
#    'Phantom-Lancer',
#    'Outworld-Destroyer',
#    'Huskar',
#    'Axe',
#    'Ursa',
#    'Razor',
#    'Ancient-Apparition',
#    'Phantom-Assassin',
#    'Mars'],
#   'relatives': []},
#  {'name': 'Vengeful-Spirit',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['blade_of_alacrity', 'staff_of_wizardry', 'point_booster'],
#   'best_versus': ['Arc-Warden',
#    'Drow-Ranger',
#    'Bristleback',
#    'Juggernaut',
#    'Anti-Mage',
#    'Alchemist',
#    'Ancient-Apparition',
#    'Lycan',
#    'Io',
#    'Riki'],
#   'relatives': []},
#  {'name': 'Windranger',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Disabler', 'Escape', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['mithril_hammer', 'maelstrom', 'staff_of_wizardry'],
#   'best_versus': ['Arc-Warden',
#    'Medusa',
#    'Dazzle',
#    'Winter-Wyvern',
#    'Lich',
#    'Viper',
#    'Huskar',
#    'Undying',
#    'Anti-Mage',
#    'Muerta'],
#   'relatives': []},
#  {'name': 'Zeus',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Carry'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'point_booster', 'ogre_axe'],
#   'best_versus': ['Bloodseeker',
#    'Arc-Warden',
#    'Drow-Ranger',
#    'Riki',
#    'Mars',
#    'Pugna',
#    'Outworld-Destroyer',
#    'Night-Stalker',
#    'Anti-Mage',
#    'Chaos-Knight'],
#   'relatives': ['Mars']},
#  {'name': 'Kunkka',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['blade_mail', 'ogre_axe', 'staff_of_wizardry'],
#   'best_versus': ['Silencer',
#    'Bloodseeker',
#    'Phantom-Assassin',
#    'Phantom-Lancer',
#    'Sand-King',
#    'Drow-Ranger',
#    'Spectre',
#    'Axe',
#    'Slark',
#    'Jakiro'],
#   'relatives': []},
#  {'name': 'Lina',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Carry', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'ogre_axe', 'blade_of_alacrity'],
#   'best_versus': ['Ringmaster',
#    'Jakiro',
#    'Dawnbreaker',
#    'Anti-Mage',
#    'Bloodseeker',
#    'Tidehunter',
#    'Bristleback',
#    'Venomancer',
#    'Huskar',
#    'Witch-Doctor'],
#   'relatives': ['Crystal-Maiden']},
#  {'name': 'Lion',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'subclass': 'intellectual_hero',
#   'items': ['blink', 'staff_of_wizardry', 'shadow_amulet'],
#   'best_versus': ['Huskar',
#    'Silencer',
#    'Dazzle',
#    'Disruptor',
#    'Bane',
#    'Medusa',
#    'Earthshaker',
#    'Underlord',
#    'Naga-Siren',
#    'Undying'],
#   'relatives': []},
#  {'name': 'Shadow-Shaman',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher', 'Disabler', 'Nuker', 'Initiator'],
#   'subclass': 'intellectual_hero',
#   'items': ['blink', 'aether_lens', 'arcane_boots'],
#   'best_versus': ['Arc-Warden',
#    'Riki',
#    'Bloodseeker',
#    'Drow-Ranger',
#    'Tidehunter',
#    'Meepo',
#    'Ursa',
#    'Enchantress',
#    'Huskar',
#    'Clinkz'],
#   'relatives': []},
#  {'name': 'Slardar',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler', 'Escape'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'ogre_axe', 'aghanims_shard'],
#   'best_versus': ['Arc-Warden',
#    'Bloodseeker',
#    'Ancient-Apparition',
#    'Dazzle',
#    'Lycan',
#    'Bristleback',
#    'Night-Stalker',
#    'Lich',
#    'Chaos-Knight',
#    'Keeper-of-the-Light'],
#   'relatives': []},
#  {'name': 'Tidehunter',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Nuker', 'Carry'],
#   'subclass': 'strong_hero',
#   'items': ['aghanims_shard', 'blink', 'vladmir'],
#   'best_versus': ['Earthshaker',
#    'Phantom-Lancer',
#    'Juggernaut',
#    'Monkey-King',
#    'Snapfire',
#    'Huskar',
#    'Omniknight',
#    'Ember-Spirit',
#    'Chaos-Knight',
#    'Terrorblade'],
#   'relatives': []},
#  {'name': 'Witch-Doctor',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['shadow_amulet', 'aghanims_shard', 'glimmer_cape'],
#   'best_versus': ['Viper',
#    'Elder-Titan',
#    'Spectre',
#    'Tidehunter',
#    'Slark',
#    'Spirit-Breaker',
#    'Keeper-of-the-Light',
#    'Drow-Ranger',
#    'Bloodseeker',
#    'Io'],
#   'relatives': []},
#  {'name': 'Lich',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['aghanims_shard', 'shadow_amulet', 'blink'],
#   'best_versus': ['Ringmaster',
#    'Meepo',
#    'Legion-Commander',
#    'Enigma',
#    'Anti-Mage',
#    'Drow-Ranger',
#    'Pangolier',
#    'Undying',
#    'Razor',
#    'Outworld-Destroyer'],
#   'relatives': []},
#  {'name': 'Riki',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'diffusal_blade', 'point_booster'],
#   'best_versus': ['Troll-Warlord',
#    'Brewmaster',
#    'Void-Spirit',
#    'Meepo',
#    'Huskar',
#    'Spectre',
#    'Sven',
#    'Disruptor',
#    'Phoenix',
#    'Templar-Assassin'],
#   'relatives': []},
#  {'name': 'Enigma',
#   'attack_type': 'Ranged',
#   'roles': ['Disabler', 'Initiator', 'Pusher'],
#   'subclass': 'universal_hero',
#   'items': ['blink', 'boots_of_bearing', 'ogre_axe'],
#   'best_versus': ['Arc-Warden',
#    'Ancient-Apparition',
#    'Skywrath-Mage',
#    'Spectre',
#    'Bloodseeker',
#    'Dazzle',
#    'Lifestealer',
#    'Visage',
#    'Treant-Protector',
#    'Medusa'],
#   'relatives': []},
#  {'name': 'Tinker',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'subclass': 'intellectual_hero',
#   'items': ['holy_locket', 'diadem', 'arcane_boots'],
#   'best_versus': ['Meepo',
#    'Elder-Titan',
#    'Faceless-Void',
#    'Riki',
#    'Grimstroke',
#    'Ember-Spirit',
#    'Juggernaut',
#    'Huskar',
#    'Dark-Seer',
#    'Disruptor'],
#   'relatives': []},
#  {'name': 'Sniper',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'maelstrom', 'blade_of_alacrity'],
#   'best_versus': ['Anti-Mage',
#    'Juggernaut',
#    'Tinker',
#    'Razor',
#    'Faceless-Void',
#    'Warlock',
#    'Outworld-Destroyer',
#    'Spectre',
#    'Earthshaker',
#    'Lich'],
#   'relatives': []},
#  {'name': 'Necrophos',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Durable', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['aghanims_shard', 'talisman_of_evasion', 'radiance'],
#   'best_versus': ['Huskar',
#    'Warlock',
#    'Oracle',
#    'Underlord',
#    'Outworld-Destroyer',
#    'Earth-Spirit',
#    'Juggernaut',
#    'Sven',
#    'Dawnbreaker',
#    'Spirit-Breaker'],
#   'relatives': []},
#  {'name': 'Warlock',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Initiator', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['shadow_amulet', 'arcane_boots', 'glimmer_cape'],
#   'best_versus': ['Lone-Druid',
#    'Dark-Seer',
#    'Silencer',
#    'Anti-Mage',
#    'Monkey-King',
#    'Axe',
#    'Medusa',
#    'Drow-Ranger',
#    'Dragon-Knight',
#    'Gyrocopter'],
#   'relatives': []},
#  {'name': 'Beastmaster',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['ogre_axe', 'ultimate_scepter', 'blade_of_alacrity'],
#   'best_versus': ['Drow-Ranger',
#    'Bloodseeker',
#    'Spectre',
#    'Juggernaut',
#    'Slark',
#    'Abaddon',
#    'Wraith-King',
#    'Lich',
#    'Huskar',
#    'Tinker'],
#   'relatives': []},
#  {'name': 'Queen-of-Pain',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Escape'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'dagon', 'kaya'],
#   'best_versus': ['Io',
#    'Lich',
#    'Clinkz',
#    'Slardar',
#    'Dazzle',
#    'Silencer',
#    'Bloodseeker',
#    'Phantom-Assassin',
#    'Razor',
#    'Ursa'],
#   'relatives': []},
#  {'name': 'Venomancer',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Initiator', 'Pusher', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['mekansm', 'guardian_greaves', 'staff_of_wizardry'],
#   'best_versus': ['Drow-Ranger',
#    'Tinker',
#    'Dazzle',
#    'Dawnbreaker',
#    'Juggernaut',
#    'Sniper',
#    'Lich',
#    'Underlord',
#    'Anti-Mage',
#    'Mirana'],
#   'relatives': []},
#  {'name': 'Faceless-Void',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Escape', 'Durable'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'maelstrom', 'blade_of_alacrity'],
#   'best_versus': ['Riki',
#    'Spectre',
#    'Razor',
#    'Juggernaut',
#    'Ancient-Apparition',
#    'Earth-Spirit',
#    'Kunkka',
#    'Lone-Druid',
#    'Marci',
#    'Bloodseeker'],
#   'relatives': ['Bane']},
#  {'name': 'Wraith-King',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator'],
#   'subclass': 'strong_hero',
#   'items': ['mithril_hammer', 'armlet', 'blink'],
#   'best_versus': ['Clinkz',
#    'Witch-Doctor',
#    'Night-Stalker',
#    'Mars',
#    'Skywrath-Mage',
#    'Spectre',
#    'Io',
#    'Anti-Mage',
#    'Outworld-Destroyer',
#    'Kunkka'],
#   'relatives': []},
#  {'name': 'Death-Prophet',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'ogre_axe', 'vitality_booster'],
#   'best_versus': ['Riki',
#    'Phantom-Lancer',
#    'Outworld-Destroyer',
#    'Lifestealer',
#    'Meepo',
#    'Necrophos',
#    'Omniknight',
#    'Bane',
#    'Night-Stalker',
#    'Jakiro'],
#   'relatives': []},
#  {'name': 'Phantom-Assassin',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'ogre_axe', 'bfury'],
#   'best_versus': ['Phantom-Lancer',
#    'Outworld-Destroyer',
#    'Medusa',
#    'Spectre',
#    'Riki',
#    'Lich',
#    'Warlock',
#    'Axe',
#    'Pangolier',
#    'Anti-Mage'],
#   'relatives': []},
#  {'name': 'Pugna',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Pusher'],
#   'subclass': 'intellectual_hero',
#   'items': ['arcane_boots', 'shadow_amulet', 'glimmer_cape'],
#   'best_versus': ['Lich',
#    'Spectre',
#    'Axe',
#    'Bloodseeker',
#    'Outworld-Destroyer',
#    'Warlock',
#    'Anti-Mage',
#    'Clinkz',
#    'Phantom-Assassin',
#    'Techies'],
#   'relatives': []},
#  {'name': 'Templar-Assassin',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'blink', 'desolator'],
#   'best_versus': ['Anti-Mage',
#    'Bloodseeker',
#    'Arc-Warden',
#    'Void-Spirit',
#    'Spectre',
#    'Ancient-Apparition',
#    'Oracle',
#    'Night-Stalker',
#    'Axe',
#    'Bounty-Hunter'],
#   'relatives': []},
#  {'name': 'Viper',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'dragon_lance', 'staff_of_wizardry'],
#   'best_versus': ['Spectre',
#    'Riki',
#    'Necrophos',
#    'Pugna',
#    'Spirit-Breaker',
#    'Tidehunter',
#    'Huskar',
#    'Shadow-Shaman',
#    'Silencer',
#    'Meepo'],
#   'relatives': []},
#  {'name': 'Luna',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'yasha', 'diadem'],
#   'best_versus': ['Arc-Warden',
#    'Dazzle',
#    'Phantom-Assassin',
#    'Grimstroke',
#    'Tinker',
#    'Drow-Ranger',
#    'Slark',
#    'Huskar',
#    'Lich',
#    'Snapfire'],
#   'relatives': []},
#  {'name': 'Dragon-Knight',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Durable', 'Disabler', 'Initiator', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'broadsword', 'mask_of_madness'],
#   'best_versus': ['Phantom-Lancer',
#    'Riki',
#    'Drow-Ranger',
#    'Lifestealer',
#    'Muerta',
#    'Pugna',
#    'Pangolier',
#    'Jakiro',
#    'Slark',
#    'Mars'],
#   'relatives': ['Winter-Wyvern', 'Jakiro']},
#  {'name': 'Dazzle',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['aghanims_shard', 'staff_of_wizardry', 'blade_of_alacrity'],
#   'best_versus': ['Outworld-Destroyer',
#    'Meepo',
#    'Bristleback',
#    'Drow-Ranger',
#    'Troll-Warlord',
#    'Keeper-of-the-Light',
#    'Witch-Doctor',
#    'Void-Spirit',
#    'Mirana',
#    'Lifestealer'],
#   'relatives': []},
#  {'name': 'Clockwerk',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['pavise', 'solar_crest', 'staff_of_wizardry'],
#   'best_versus': ['Anti-Mage',
#    'Skywrath-Mage',
#    'Earthshaker',
#    'Night-Stalker',
#    'Phantom-Assassin',
#    'Oracle',
#    'Slardar',
#    'Meepo',
#    'Spirit-Breaker',
#    'Snapfire'],
#   'relatives': []},
#  {'name': 'Leshrac',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Nuker', 'Pusher', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'kaya', 'ogre_axe'],
#   'best_versus': ['Riki',
#    'Lone-Druid',
#    'Meepo',
#    'Tinker',
#    'Spectre',
#    'Phantom-Lancer',
#    'Elder-Titan',
#    'Bounty-Hunter',
#    'Phantom-Assassin',
#    'Dawnbreaker'],
#   'relatives': []},
#  {'name': 'Natures-Prophet',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Escape', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['mithril_hammer', 'staff_of_wizardry', 'maelstrom'],
#   'best_versus': ['Witch-Doctor',
#    'Drow-Ranger',
#    'Riki',
#    'Skywrath-Mage',
#    'Earthshaker',
#    'Necrophos',
#    'Phantom-Assassin',
#    'Dazzle',
#    'Axe',
#    'Clinkz'],
#   'relatives': ['Terrorblade', 'Enchantress']},
#  {'name': 'Lifestealer',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Escape', 'Disabler'],
#   'subclass': 'strong_hero',
#   'items': ['blade_of_alacrity', 'ogre_axe', 'radiance'],
#   'best_versus': ['Tinker',
#    'Slark',
#    'Muerta',
#    'Anti-Mage',
#    'Viper',
#    'Arc-Warden',
#    'Faceless-Void',
#    'Winter-Wyvern',
#    'Juggernaut',
#    'Phantom-Lancer'],
#   'relatives': []},
#  {'name': 'Dark-Seer',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Escape', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['mekansm', 'ring_of_tarrasque', 'pipe'],
#   'best_versus': ['Phantom-Lancer',
#    'Viper',
#    'Necrophos',
#    'Wraith-King',
#    'Drow-Ranger',
#    'Tusk',
#    'Arc-Warden',
#    'Abaddon',
#    'Bane',
#    'Dazzle'],
#   'relatives': []},
#  {'name': 'Clinkz',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Pusher'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'blade_of_alacrity', 'dragon_lance'],
#   'best_versus': ['Huskar',
#    'Warlock',
#    'Drow-Ranger',
#    'Slark',
#    'Io',
#    'Night-Stalker',
#    'Spectre',
#    'Tinker',
#    'Muerta',
#    'Death-Prophet'],
#   'relatives': []},
#  {'name': 'Omniknight',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Durable', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['arcane_boots', 'pavise', 'solar_crest'],
#   'best_versus': ['Huskar',
#    'Arc-Warden',
#    'Io',
#    'Phantom-Assassin',
#    'Legion-Commander',
#    'Dazzle',
#    'Oracle',
#    'Lina',
#    'Lich',
#    'Mars'],
#   'relatives': []},
#  {'name': 'Enchantress',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher', 'Durable', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['blade_of_alacrity', 'staff_of_wizardry', 'dragon_lance'],
#   'best_versus': ['Phantom-Lancer',
#    'Silencer',
#    'Abaddon',
#    'Spectre',
#    'Chaos-Knight',
#    'Drow-Ranger',
#    'Grimstroke',
#    'Ursa',
#    'Earthshaker',
#    'Viper'],
#   'relatives': ['Terrorblade', 'Natures-Prophet']},
#  {'name': 'Huskar',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Durable', 'Initiator'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'sange', 'blade_of_alacrity'],
#   'best_versus': ['Oracle',
#    'Underlord',
#    'Faceless-Void',
#    'Bane',
#    'Skywrath-Mage',
#    'Invoker',
#    'Dawnbreaker',
#    'Batrider',
#    'Night-Stalker',
#    'Anti-Mage'],
#   'relatives': []},
#  {'name': 'Night-Stalker',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'blink', 'mithril_hammer'],
#   'best_versus': ['Ringmaster',
#    'Arc-Warden',
#    'Dazzle',
#    'Phantom-Lancer',
#    'Meepo',
#    'Underlord',
#    'Razor',
#    'Pudge',
#    'Phantom-Assassin',
#    'Omniknight'],
#   'relatives': []},
#  {'name': 'Broodmother',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Escape', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['ogre_axe', 'orchid', 'oblivion_staff'],
#   'best_versus': ['Riki',
#    'Tinker',
#    'Arc-Warden',
#    'Dazzle',
#    'Bane',
#    'Lifestealer',
#    'Bristleback',
#    'Underlord',
#    'Chaos-Knight',
#    'Lycan'],
#   'relatives': []},
#  {'name': 'Bounty-Hunter',
#   'attack_type': 'Melee',
#   'roles': ['Escape', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['staff_of_wizardry', 'point_booster', 'ogre_axe'],
#   'best_versus': ['Necrophos',
#    'Medusa',
#    'Riki',
#    'Brewmaster',
#    'Grimstroke',
#    'Chaos-Knight',
#    'Tinker',
#    'Techies',
#    'Ancient-Apparition',
#    'Anti-Mage'],
#   'relatives': []},
#  {'name': 'Weaver',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'blade_of_alacrity', 'maelstrom'],
#   'best_versus': ['Ancient-Apparition',
#    'Tidehunter',
#    'Arc-Warden',
#    'Axe',
#    'Death-Prophet',
#    'Outworld-Destroyer',
#    'Night-Stalker',
#    'Medusa',
#    'Riki',
#    'Meepo'],
#   'relatives': []},
#  {'name': 'Jakiro',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Pusher', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'arcane_boots', 'cyclone'],
#   'best_versus': ['Underlord',
#    'Tinker',
#    'Medusa',
#    'Bristleback',
#    'Pugna',
#    'Wraith-King',
#    'Night-Stalker',
#    'Phoenix',
#    'Dark-Seer',
#    'Bounty-Hunter'],
#   'relatives': ['Winter-Wyvern', 'Dragon-Knight']},
#  {'name': 'Batrider',
#   'attack_type': 'Ranged',
#   'roles': ['Initiator', 'Disabler', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['blink', 'staff_of_wizardry', 'force_staff'],
#   'best_versus': ['Arc-Warden',
#    'Axe',
#    'Outworld-Destroyer',
#    'Dazzle',
#    'Phantom-Assassin',
#    'Razor',
#    'Silencer',
#    'Skywrath-Mage',
#    'Wraith-King',
#    'Medusa'],
#   'relatives': []},
#  {'name': 'Chen',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Pusher'],
#   'subclass': 'universal_hero',
#   'items': ['mekansm', 'arcane_boots', 'ancient_janggo'],
#   'best_versus': ['Arc-Warden',
#    'Lone-Druid',
#    'Riki',
#    'Outworld-Destroyer',
#    'Drow-Ranger',
#    'Bane',
#    'Broodmother',
#    'Necrophos',
#    'Snapfire',
#    'Anti-Mage'],
#   'relatives': []},
#  {'name': 'Spectre',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Escape'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'yasha', 'diadem'],
#   'best_versus': ['Dazzle',
#    'Medusa',
#    'Elder-Titan',
#    'Razor',
#    'Phantom-Lancer',
#    'Chaos-Knight',
#    'Drow-Ranger',
#    'Underlord',
#    'Lina',
#    'Lifestealer'],
#   'relatives': []},
#  {'name': 'Ancient-Apparition',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['shadow_amulet', 'staff_of_wizardry', 'arcane_boots'],
#   'best_versus': ['Dark-Seer',
#    'Juggernaut',
#    'Chaos-Knight',
#    'Undying',
#    'Phoenix',
#    'Morphling',
#    'Troll-Warlord',
#    'Axe',
#    'Void-Spirit',
#    'Razor'],
#   'relatives': []},
#  {'name': 'Doom',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'ancient_janggo', 'blink'],
#   'best_versus': ['Silencer',
#    'Phantom-Lancer',
#    'Io',
#    'Huskar',
#    'Arc-Warden',
#    'Slark',
#    'Outworld-Destroyer',
#    'Necrophos',
#    'Chaos-Knight',
#    'Bane'],
#   'relatives': []},
#  {'name': 'Ursa',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'bfury', 'blink'],
#   'best_versus': ['Pugna',
#    'Underlord',
#    'Faceless-Void',
#    'Dawnbreaker',
#    'Phantom-Lancer',
#    'Tinker',
#    'Void-Spirit',
#    'Earthshaker',
#    'Medusa',
#    'Undying'],
#   'relatives': []},
#  {'name': 'Spirit-Breaker',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Durable', 'Escape'],
#   'subclass': 'strong_hero',
#   'items': ['broadsword', 'shadow_amulet', 'blitz_knuckles'],
#   'best_versus': ['Spectre',
#    'Meepo',
#    'Elder-Titan',
#    'Io',
#    'Axe',
#    'Earth-Spirit',
#    'Nyx-Assassin',
#    'Medusa',
#    'Phantom-Lancer',
#    'Silencer'],
#   'relatives': []},
#  {'name': 'Gyrocopter',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': ['ogre_axe', 'blade_of_alacrity', 'staff_of_wizardry'],
#   'best_versus': ['Silencer',
#    'Anti-Mage',
#    'Arc-Warden',
#    'Juggernaut',
#    'Undying',
#    'Abaddon',
#    'Necrophos',
#    'Shadow-Shaman',
#    'Dazzle',
#    'Treant-Protector'],
#   'relatives': []},
#  {'name': 'Alchemist',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'radiance', 'blink'],
#   'best_versus': ['Phantom-Lancer',
#    'Ancient-Apparition',
#    'Witch-Doctor',
#    'Riki',
#    'Drow-Ranger',
#    'Silencer',
#    'Arc-Warden',
#    'Phoenix',
#    'Axe',
#    'Shadow-Shaman'],
#   'relatives': []},
#  {'name': 'Invoker',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Escape', 'Pusher'],
#   'subclass': 'universal_hero',
#   'items': ['blade_of_alacrity', 'oblivion_staff', 'dragon_lance'],
#   'best_versus': ['Silencer',
#    'Phantom-Lancer',
#    'Anti-Mage',
#    'Slark',
#    'Undying',
#    'Lifestealer',
#    'Abaddon',
#    'Outworld-Destroyer',
#    'Omniknight',
#    'Sven'],
#   'relatives': []},
#  {'name': 'Silencer',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Support', 'Disabler', 'Initiator', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'force_staff', 'power_treads'],
#   'best_versus': ['Anti-Mage',
#    'Primal-Beast',
#    'Winter-Wyvern',
#    'Lich',
#    'Dawnbreaker',
#    'Dazzle',
#    'Spectre',
#    'Earth-Spirit',
#    'Zeus',
#    'Tidehunter'],
#   'relatives': []},
#  {'name': 'Outworld-Destroyer',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'witch_blade', 'blade_of_alacrity'],
#   'best_versus': ['Drow-Ranger',
#    'Arc-Warden',
#    'Disruptor',
#    'Chaos-Knight',
#    'Legion-Commander',
#    'Mars',
#    'Spectre',
#    'Tinker',
#    'Grimstroke',
#    'Silencer'],
#   'relatives': []},
#  {'name': 'Lycan',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Durable', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['ogre_axe', 'diadem', 'echo_sabre'],
#   'best_versus': ['Dazzle',
#    'Sven',
#    'Void-Spirit',
#    'Arc-Warden',
#    'Visage',
#    'Keeper-of-the-Light',
#    'Oracle',
#    'Juggernaut',
#    'Enigma',
#    'Meepo'],
#   'relatives': []},
#  {'name': 'Brewmaster',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['radiance', 'relic', 'talisman_of_evasion'],
#   'best_versus': ['Drow-Ranger',
#    'Silencer',
#    'Wraith-King',
#    'Meepo',
#    'Arc-Warden',
#    'Muerta',
#    'Venomancer',
#    'Techies',
#    'Lycan',
#    'Necrophos'],
#   'relatives': []},
#  {'name': 'Shadow-Demon',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Initiator', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['arcane_boots', 'shadow_amulet', 'glimmer_cape'],
#   'best_versus': ['Oracle',
#    'Riki',
#    'Silencer',
#    'Wraith-King',
#    'Drow-Ranger',
#    'Juggernaut',
#    'Ancient-Apparition',
#    'Abaddon',
#    'Shadow-Fiend',
#    'Witch-Doctor'],
#   'relatives': []},
#  {'name': 'Lone-Druid',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Durable'],
#   'subclass': 'universal_hero',
#   'items': ['mithril_hammer', 'aghanims_shard', 'diffusal_blade'],
#   'best_versus': ['Phantom-Lancer',
#    'Riki',
#    'Broodmother',
#    'Shadow-Shaman',
#    'Clinkz',
#    'Oracle',
#    'Dazzle',
#    'Dawnbreaker',
#    'Meepo',
#    'Skywrath-Mage'],
#   'relatives': []},
#  {'name': 'Chaos-Knight',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Durable', 'Pusher', 'Initiator'],
#   'subclass': 'strong_hero',
#   'items': ['armlet', 'blitz_knuckles', 'oblivion_staff'],
#   'best_versus': ['Arc-Warden',
#    'Death-Prophet',
#    'Meepo',
#    'Faceless-Void',
#    'Primal-Beast',
#    'Dawnbreaker',
#    'Juggernaut',
#    'Queen-of-Pain',
#    'Dazzle',
#    'Void-Spirit'],
#   'relatives': []},
#  {'name': 'Meepo',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator', 'Pusher'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'ogre_axe', 'point_booster'],
#   'best_versus': ['Skywrath-Mage',
#    'Bloodseeker',
#    'Clinkz',
#    'Spectre',
#    'Tusk',
#    'Razor',
#    'Dawnbreaker',
#    'Storm-Spirit',
#    'Lina',
#    'Arc-Warden'],
#   'relatives': []},
#  {'name': 'Treant-Protector',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Initiator', 'Durable', 'Disabler', 'Escape'],
#   'subclass': 'strong_hero',
#   'items': ['aghanims_shard', 'arcane_boots', 'blink'],
#   'best_versus': ['Bane',
#    'Tidehunter',
#    'Grimstroke',
#    'Wraith-King',
#    'Spirit-Breaker',
#    'Silencer',
#    'Slark',
#    'Monkey-King',
#    'Jakiro',
#    'Skywrath-Mage'],
#   'relatives': []},
#  {'name': 'Ogre-Magi',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Initiator'],
#   'subclass': 'strong_hero',
#   'items': ['arcane_boots', 'hand_of_midas', 'pavise'],
#   'best_versus': ['Death-Prophet',
#    'Huskar',
#    'Warlock',
#    'Mars',
#    'Spectre',
#    'Batrider',
#    'Chaos-Knight',
#    'Sven',
#    'Skywrath-Mage',
#    'Omniknight'],
#   'relatives': []},
#  {'name': 'Undying',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Durable', 'Disabler', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['arcane_boots', 'pavise', 'broadsword'],
#   'best_versus': ['Skywrath-Mage',
#    'Spectre',
#    'Witch-Doctor',
#    'Outworld-Destroyer',
#    'Lone-Druid',
#    'Dazzle',
#    'Razor',
#    'Lifestealer',
#    'Bristleback',
#    'Mars'],
#   'relatives': []},
#  {'name': 'Rubick',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'subclass': 'intellectual_hero',
#   'items': ['blink', 'aether_lens', 'staff_of_wizardry'],
#   'best_versus': ['Phantom-Lancer',
#    'Underlord',
#    'Bloodseeker',
#    'Tinker',
#    'Arc-Warden',
#    'Spectre',
#    'Witch-Doctor',
#    'Spirit-Breaker',
#    'Queen-of-Pain',
#    'Anti-Mage'],
#   'relatives': []},
#  {'name': 'Disruptor',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'subclass': 'intellectual_hero',
#   'items': ['arcane_boots', 'shadow_amulet', 'staff_of_wizardry'],
#   'best_versus': ['Lone-Druid',
#    'Huskar',
#    'Arc-Warden',
#    'Dazzle',
#    'Sven',
#    'Naga-Siren',
#    'Dragon-Knight',
#    'Bristleback',
#    'Vengeful-Spirit',
#    'Viper'],
#   'relatives': []},
#  {'name': 'Nyx-Assassin',
#   'attack_type': 'Melee',
#   'roles': ['Disabler', 'Nuker', 'Initiator', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['dagon', 'diadem', 'dagon_2'],
#   'best_versus': ['Underlord',
#    'Huskar',
#    'Razor',
#    'Warlock',
#    'Morphling',
#    'Winter-Wyvern',
#    'Phantom-Assassin',
#    'Timbersaw',
#    'Meepo',
#    'Kunkka'],
#   'relatives': []},
#  {'name': 'Naga-Siren',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Support', 'Pusher', 'Disabler', 'Initiator', 'Escape'],
#   'subclass': 'agile_hero',
#   'items': ['arcane_boots', 'manta', 'diadem'],
#   'best_versus': ['Huskar',
#    'Arc-Warden',
#    'Pugna',
#    'Abaddon',
#    'Lich',
#    'Bounty-Hunter',
#    'Drow-Ranger',
#    'Night-Stalker',
#    'Troll-Warlord',
#    'Winter-Wyvern'],
#   'relatives': []},
#  {'name': 'Keeper-of-the-Light',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['vitality_booster', 'spirit_vessel', 'point_booster'],
#   'best_versus': ['Phantom-Lancer',
#    'Marci',
#    'Spectre',
#    'Riki',
#    'Axe',
#    'Huskar',
#    'Sand-King',
#    'Broodmother',
#    'Bristleback',
#    'Treant-Protector'],
#   'relatives': []},
#  {'name': 'Io',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Escape', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['mekansm', 'holy_locket', 'diadem'],
#   'best_versus': ['Riki',
#    'Meepo',
#    'Tinker',
#    'Arc-Warden',
#    'Drow-Ranger',
#    'Dazzle',
#    'Enchantress',
#    'Lone-Druid',
#    'Morphling',
#    'Legion-Commander'],
#   'relatives': []},
#  {'name': 'Visage',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Durable', 'Disabler', 'Pusher'],
#   'subclass': 'universal_hero',
#   'items': ['boots_of_bearing', 'ring_of_tarrasque', 'pipe'],
#   'best_versus': ['Outworld-Destroyer',
#    'Arc-Warden',
#    'Oracle',
#    'Ancient-Apparition',
#    'Lone-Druid',
#    'Wraith-King',
#    'Riki',
#    'Undying',
#    'Phantom-Lancer',
#    'Bloodseeker'],
#   'relatives': []},
#  {'name': 'Slark',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'ogre_axe', 'diffusal_blade'],
#   'best_versus': ['Dark-Seer',
#    'Anti-Mage',
#    'Viper',
#    'Skywrath-Mage',
#    'Monkey-King',
#    'Abaddon',
#    'Bristleback',
#    'Snapfire',
#    'Phantom-Lancer',
#    'Tinker'],
#   'relatives': []},
#  {'name': 'Medusa',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Disabler', 'Durable'],
#   'subclass': 'agile_hero',
#   'items': ['diadem', 'manta', 'claymore'],
#   'best_versus': ['Huskar',
#    'Silencer',
#    'Outworld-Destroyer',
#    'Abaddon',
#    'Phantom-Lancer',
#    'Techies',
#    'Undying',
#    'Beastmaster',
#    'Witch-Doctor',
#    'Morphling'],
#   'relatives': []},
#  {'name': 'Troll-Warlord',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Pusher', 'Disabler', 'Durable'],
#   'subclass': 'agile_hero',
#   'items': ['ogre_axe', 'blade_of_alacrity', 'yasha'],
#   'best_versus': ['Bristleback',
#    'Arc-Warden',
#    'Undying',
#    'Bounty-Hunter',
#    'Snapfire',
#    'Spectre',
#    'Medusa',
#    'Ursa',
#    'Underlord',
#    'Keeper-of-the-Light'],
#   'relatives': []},
#  {'name': 'Centaur-Warrunner',
#   'attack_type': 'Melee',
#   'roles': ['Durable', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'blade_mail', 'ring_of_tarrasque'],
#   'best_versus': ['Anti-Mage',
#    'Night-Stalker',
#    'Riki',
#    'Phantom-Assassin',
#    'Axe',
#    'Jakiro',
#    'Arc-Warden',
#    'Abaddon',
#    'Drow-Ranger',
#    'Outworld-Destroyer'],
#   'relatives': []},
#  {'name': 'Magnus',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['blink', 'aghanims_shard', 'ogre_axe'],
#   'best_versus': ['Tinker',
#    'Necrophos',
#    'Phantom-Lancer',
#    'Anti-Mage',
#    'Snapfire',
#    'Earthshaker',
#    'Phantom-Assassin',
#    'Dark-Willow',
#    'Visage',
#    'Arc-Warden'],
#   'relatives': []},
#  {'name': 'Timbersaw',
#   'attack_type': 'Melee',
#   'roles': ['Nuker', 'Durable', 'Escape'],
#   'subclass': 'strong_hero',
#   'items': ['staff_of_wizardry', 'ogre_axe', 'kaya'],
#   'best_versus': ['Anti-Mage',
#    'Phantom-Lancer',
#    'Dazzle',
#    'Medusa',
#    'Faceless-Void',
#    'Witch-Doctor',
#    'Bounty-Hunter',
#    'Bloodseeker',
#    'Silencer',
#    'Earth-Spirit'],
#   'relatives': ['Snapfire']},
#  {'name': 'Bristleback',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable', 'Initiator', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['aghanims_shard', 'blade_of_alacrity', 'point_booster'],
#   'best_versus': ['Spectre',
#    'Tidehunter',
#    'Necrophos',
#    'Medusa',
#    'Death-Prophet',
#    'Lycan',
#    'Visage',
#    'Ancient-Apparition',
#    'Weaver',
#    'Witch-Doctor'],
#   'relatives': []},
#  {'name': 'Tusk',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'ogre_axe', 'pavise'],
#   'best_versus': ['Arc-Warden',
#    'Dazzle',
#    'Lina',
#    'Legion-Commander',
#    'Phantom-Assassin',
#    'Ancient-Apparition',
#    'Huskar',
#    'Skywrath-Mage',
#    'Drow-Ranger',
#    'Ursa'],
#   'relatives': []},
#  {'name': 'Skywrath-Mage',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'arcane_boots', 'vitality_booster'],
#   'best_versus': ['Phantom-Lancer',
#    'Earthshaker',
#    'Mars',
#    'Bristleback',
#    'Anti-Mage',
#    'Oracle',
#    'Kunkka',
#    'Razor',
#    'Brewmaster',
#    'Omniknight'],
#   'relatives': []},
#  {'name': 'Abaddon',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Carry', 'Durable'],
#   'subclass': 'universal_hero',
#   'items': ['diadem', 'ogre_axe', 'pavise'],
#   'best_versus': ['Anti-Mage',
#    'Bristleback',
#    'Undying',
#    'Riki',
#    'Spectre',
#    'Phantom-Assassin',
#    'Clinkz',
#    'Disruptor',
#    'Dazzle',
#    'Phantom-Lancer'],
#   'relatives': []},
#  {'name': 'Elder-Titan',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Durable'],
#   'subclass': 'strong_hero',
#   'items': ['ancient_janggo', 'staff_of_wizardry', 'ogre_axe'],
#   'best_versus': ['Necrophos',
#    'Bane',
#    'Silencer',
#    'Riki',
#    'Meepo',
#    'Drow-Ranger',
#    'Razor',
#    'Io',
#    'Tusk',
#    'Night-Stalker'],
#   'relatives': []},
#  {'name': 'Legion-Commander',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'ogre_axe', 'blade_mail'],
#   'best_versus': ['Troll-Warlord',
#    'Naga-Siren',
#    'Viper',
#    'Brewmaster',
#    'Tinker',
#    'Night-Stalker',
#    'Terrorblade',
#    'Meepo',
#    'Arc-Warden',
#    'Shadow-Shaman'],
#   'relatives': []},
#  {'name': 'Techies',
#   'attack_type': 'Ranged',
#   'roles': ['Nuker', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['arcane_boots', 'staff_of_wizardry', 'ogre_axe'],
#   'best_versus': ['Drow-Ranger',
#    'Phantom-Lancer',
#    'Axe',
#    'Tinker',
#    'Witch-Doctor',
#    'Anti-Mage',
#    'Snapfire',
#    'Lich',
#    'Lone-Druid',
#    'Nyx-Assassin'],
#   'relatives': []},
#  {'name': 'Ember-Spirit',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator'],
#   'subclass': 'agile_hero',
#   'items': ['mage_slayer', 'oblivion_staff', 'mithril_hammer'],
#   'best_versus': ['Phantom-Lancer',
#    'Viper',
#    'Bane',
#    'Lycan',
#    'Arc-Warden',
#    'Shadow-Shaman',
#    'Death-Prophet',
#    'Pugna',
#    'Phantom-Assassin',
#    'Spectre'],
#   'relatives': ['Storm-Spirit', 'Void-Spirit', 'Earth-Spirit']},
#  {'name': 'Earth-Spirit',
#   'attack_type': 'Melee',
#   'roles': ['Nuker', 'Escape', 'Disabler', 'Initiator', 'Durable'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'blade_mail', 'mithril_hammer'],
#   'best_versus': ['Arc-Warden',
#    'Anti-Mage',
#    'Morphling',
#    'Lich',
#    'Juggernaut',
#    'Legion-Commander',
#    'Abaddon',
#    'Spectre',
#    'Queen-of-Pain',
#    'Viper'],
#   'relatives': ['Ember-Spirit', 'Storm-Spirit', 'Void-Spirit']},
#  {'name': 'Underlord',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Escape'],
#   'subclass': 'strong_hero',
#   'items': ['staff_of_wizardry', 'pipe', 'ring_of_tarrasque'],
#   'best_versus': ['Riki',
#    'Anti-Mage',
#    'Skywrath-Mage',
#    'Io',
#    'Viper',
#    'Arc-Warden',
#    'Disruptor',
#    'Techies',
#    'Muerta',
#    'Tidehunter'],
#   'relatives': []},
#  {'name': 'Terrorblade',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Pusher', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['blade_of_alacrity', 'yasha', 'aghanims_shard'],
#   'best_versus': ['Skywrath-Mage',
#    'Anti-Mage',
#    'Phantom-Lancer',
#    'Wraith-King',
#    'Abaddon',
#    'Chaos-Knight',
#    'Snapfire',
#    'Phantom-Assassin',
#    'Meepo',
#    'Spectre'],
#   'relatives': ['Natures-Prophet', 'Enchantress']},
#  {'name': 'Phoenix',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Initiator', 'Escape', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['staff_of_wizardry', 'pavise', 'solar_crest'],
#   'best_versus': ['Outworld-Destroyer',
#    'Phantom-Lancer',
#    'Necrophos',
#    'Lycan',
#    'Sand-King',
#    'Huskar',
#    'Arc-Warden',
#    'Phantom-Assassin',
#    'Bounty-Hunter',
#    'Silencer'],
#   'relatives': []},
#  {'name': 'Oracle',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'subclass': 'intellectual_hero',
#   'items': ['aether_lens', 'arcane_boots', 'diadem'],
#   'best_versus': ['Arc-Warden',
#    'Bloodseeker',
#    'Tidehunter',
#    'Queen-of-Pain',
#    'Outworld-Destroyer',
#    'Warlock',
#    'Sniper',
#    'Dazzle',
#    'Abaddon',
#    'Nyx-Assassin'],
#   'relatives': []},
#  {'name': 'Winter-Wyvern',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'subclass': 'universal_hero',
#   'items': ['blink', 'arcane_boots', 'staff_of_wizardry'],
#   'best_versus': ['Skywrath-Mage',
#    'Spectre',
#    'Dawnbreaker',
#    'Warlock',
#    'Clockwerk',
#    'Ursa',
#    'Lich',
#    'Arc-Warden',
#    'Beastmaster',
#    'Earthshaker'],
#   'relatives': ['Dragon-Knight', 'Jakiro']},
#  {'name': 'Arc-Warden',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'subclass': 'agile_hero',
#   'items': ['staff_of_wizardry', 'mithril_hammer', 'maelstrom'],
#   'best_versus': ['Riki',
#    'Drow-Ranger',
#    'Silencer',
#    'Axe',
#    'Witch-Doctor',
#    'Slark',
#    'Ancient-Apparition',
#    'Snapfire',
#    'Lich',
#    'Skywrath-Mage'],
#   'relatives': []},
#  {'name': 'Monkey-King',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler', 'Initiator'],
#   'subclass': 'agile_hero',
#   'items': ['mithril_hammer', 'ogre_axe', 'maelstrom'],
#   'best_versus': ['Visage',
#    'Riki',
#    'Marci',
#    'Medusa',
#    'Necrophos',
#    'Oracle',
#    'Earthshaker',
#    'Drow-Ranger',
#    'Spectre',
#    'Pugna'],
#   'relatives': []},
#  {'name': 'Dark-Willow',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['staff_of_wizardry', 'cyclone', 'blink'],
#   'best_versus': ['Phantom-Lancer',
#    'Viper',
#    'Silencer',
#    'Witch-Doctor',
#    'Slark',
#    'Techies',
#    'Anti-Mage',
#    'Underlord',
#    'Sven',
#    'Venomancer'],
#   'relatives': []},
#  {'name': 'Pangolier',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Durable', 'Escape', 'Initiator'],
#   'subclass': 'universal_hero',
#   'items': ['blade_of_alacrity', 'ogre_axe', 'staff_of_wizardry'],
#   'best_versus': ['Dazzle',
#    'Witch-Doctor',
#    'Silencer',
#    'Abaddon',
#    'Drow-Ranger',
#    'Oracle',
#    'Spectre',
#    'Skywrath-Mage',
#    'Meepo',
#    'Shadow-Shaman'],
#   'relatives': []},
#  {'name': 'Grimstroke',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'subclass': 'intellectual_hero',
#   'items': ['arcane_boots', 'aghanims_shard', 'aether_lens'],
#   'best_versus': ['Spectre',
#    'Phantom-Assassin',
#    'Jakiro',
#    'Legion-Commander',
#    'Phantom-Lancer',
#    'Skywrath-Mage',
#    'Drow-Ranger',
#    'Clinkz',
#    'Silencer',
#    'Nyx-Assassin'],
#   'relatives': []},
#  {'name': 'Hoodwink',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Escape', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': ['staff_of_wizardry', 'vitality_booster', 'rod_of_atos'],
#   'best_versus': ['Meepo',
#    'Bloodseeker',
#    'Omniknight',
#    'Beastmaster',
#    'Drow-Ranger',
#    'Lion',
#    'Ancient-Apparition',
#    'Winter-Wyvern',
#    'Grimstroke',
#    'Arc-Warden'],
#   'relatives': []},
#  {'name': 'Void-Spirit',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler'],
#   'subclass': 'universal_hero',
#   'items': ['blade_of_alacrity', 'ogre_axe', 'staff_of_wizardry'],
#   'best_versus': ['Phantom-Lancer',
#    'Spectre',
#    'Arc-Warden',
#    'Lich',
#    'Death-Prophet',
#    'Bloodseeker',
#    'Sand-King',
#    'Witch-Doctor',
#    'Drow-Ranger',
#    'Keeper-of-the-Light'],
#   'relatives': ['Ember-Spirit', 'Storm-Spirit', 'Earth-Spirit']},
#  {'name': 'Snapfire',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['staff_of_wizardry', 'arcane_boots', 'force_staff'],
#   'best_versus': ['Phantom-Lancer',
#    'Riki',
#    'Wraith-King',
#    'Io',
#    'Dazzle',
#    'Underlord',
#    'Huskar',
#    'Chaos-Knight',
#    'Lone-Druid',
#    'Lich'],
#   'relatives': ['Timbersaw']},
#  {'name': 'Mars',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Durable'],
#   'subclass': 'strong_hero',
#   'items': ['blink', 'mithril_hammer', 'ogre_axe'],
#   'best_versus': ['Warlock',
#    'Drow-Ranger',
#    'Dazzle',
#    'Huskar',
#    'Abaddon',
#    'Earthshaker',
#    'Silencer',
#    'Ursa',
#    'Arc-Warden',
#    'Tinker'],
#   'relatives': ['Zeus']},
#  {'name': 'Ringmaster',
#   'attack_type': 'Ranged',
#   'roles': ['Support', 'Nuker', 'Escape', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'arcane_boots'],
#   'best_versus': ['Pudge', 'Lich', 'Lina', 'Morphling', 'Night-Stalker'],
#   'relatives': []},
#  {'name': 'Dawnbreaker',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Durable'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'broadsword', 'blade_mail'],
#   'best_versus': ['Riki',
#    'Wraith-King',
#    'Viper',
#    'Undying',
#    'Spirit-Breaker',
#    'Underlord',
#    'Witch-Doctor',
#    'Warlock',
#    'Drow-Ranger',
#    'Queen-of-Pain'],
#   'relatives': []},
#  {'name': 'Marci',
#   'attack_type': 'Melee',
#   'roles': ['Support', 'Carry', 'Initiator', 'Disabler', 'Escape'],
#   'subclass': 'universal_hero',
#   'items': ['ogre_axe', 'mithril_hammer', 'phase_boots'],
#   'best_versus': ['Dazzle',
#    'Phantom-Lancer',
#    'Oracle',
#    'Viper',
#    'Outworld-Destroyer',
#    'Juggernaut',
#    'Axe',
#    'Ursa',
#    'Grimstroke',
#    'Lifestealer'],
#   'relatives': []},
#  {'name': 'Primal-Beast',
#   'attack_type': 'Melee',
#   'roles': ['Initiator', 'Durable', 'Disabler'],
#   'subclass': 'strong_hero',
#   'items': ['ogre_axe', 'mithril_hammer', 'blade_mail'],
#   'best_versus': ['Juggernaut',
#    'Phantom-Lancer',
#    'Arc-Warden',
#    'Huskar',
#    'Legion-Commander',
#    'Snapfire',
#    'Ancient-Apparition',
#    'Wraith-King',
#    'Undying',
#    'Medusa'],
#   'relatives': []},
#  {'name': 'Muerta',
#   'attack_type': 'Ranged',
#   'roles': ['Carry', 'Nuker', 'Disabler'],
#   'subclass': 'intellectual_hero',
#   'items': ['staff_of_wizardry', 'rod_of_atos', 'vitality_booster'],
#   'best_versus': ['Meepo',
#    'Undying',
#    'Chaos-Knight',
#    'Riki',
#    'Juggernaut',
#    'Dazzle',
#    'Queen-of-Pain',
#    'Lich',
#    'Legion-Commander',
#    'Tidehunter'],
#   'relatives': []},
#  {'name': 'Kez',
#   'attack_type': 'Melee',
#   'roles': ['Carry', 'Escape', 'Disabler'],
#   'subclass': 'agile_hero',
#   'items': [],
#   'best_versus': [],
#   'relatives': []}]

# %%
from rdflib import Graph, URIRef, Literal, RDF, Namespace

# Создаем граф и загружаем существующую онтологию
g = Graph()
g.parse("../empty_ontology.rdf", format="xml")  # Замените путь на путь к вашему RDF файлу

# Определяем пространство имен
NS = Namespace("http://www.semanticweb.org/root/ontologies/2025/0/dota2#")
g.bind("dota2", NS)

# %%
# Добавляем данные в граф (существующую онтологию)
for hero_data in cleaned_heroes:
    hero_uri = URIRef(NS[hero_data["name"]])  # Создаем уникальный идентификатор для героя
    
    # Устанавливаем основной класс hero
    # g.add((hero_uri, RDF.type, URIRef(NS.hero)))
    g.add((hero_uri, NS.hero_name, Literal(hero_data["name"])))
    g.add((hero_uri, NS.hero_attack_type, Literal(hero_data["attack_type"])))
    
    # Устанавливаем подкатегорию (subclass) для героя
    subclass_uri = URIRef(NS[hero_data["subclass"]])  # Получаем URI подкласса
    g.add((hero_uri, RDF.type, subclass_uri))  # Добавляем индивид как тип подкласса (не создаем новый класс)

    # Связи с ролями (если роли существуют в онтологии)
    for role_name in hero_data["roles"]:
        role_uri = URIRef(NS[role_name])
        # Убедимся, что роль существует, если нет — добавим ее
        g.add((role_uri, RDF.type, URIRef(NS.role)))  # Убедимся, что роль - это экземпляр класса role
        g.add((hero_uri, URIRef(NS.hasRole), role_uri))
        g.add((role_uri, NS.role_name, Literal(role_name)))
    
    # Связи с расами (если расы существуют в онтологии)
    for item_name in hero_data["items"]:
        item_uri = URIRef(NS[item_name])
        g.add((item_uri, RDF.type, URIRef(NS.item)))
        g.add((hero_uri, URIRef(NS.buysItem), item_uri))
        g.add((item_uri, NS.item_name, Literal(item_name)))
    
    # Отношение bestVersus
    for opponent in hero_data["best_versus"]:
        opponent_uri = URIRef(NS[opponent])
        g.add((hero_uri, URIRef(NS.bestVersus), opponent_uri))
    
    for relative in hero_data["relatives"]:
        relative_uri = URIRef(NS[relative])
        g.add((hero_uri, URIRef(NS.relativeTo), relative_uri))
        

# Сохраняем изменения обратно в файл (перезаписываем)
g.serialize("dota2_ontology_v2.rdf", format="xml")
# Out:
# <Graph identifier=N02b8af0228964cd2a79da7d1d17295f3 (<class 'rdflib.graph.Graph'>)>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/final_df.csv")
df.tail()
# Out:
#                    track_id                 name          artist  \
# 3812216  TRATHTH128F42BC347                Ragoo   Kings of Leon
# 3812217  TROZZNY128F14782F7  All the Wild Horses  Ray LaMontagne
# 3812218  TRONYHY128F92C9D11              Revelry   Kings of Leon
# 3812219  TRVWLZP128E0792690         O Girlfriend          Weezer
# 3812220  TRWUFEW128F14782F3    Forever My Friend  Ray LaMontagne
#
#                                        spotify_preview_url  \
# 3812216  https://p.scdn.co/mp3-preview/b0c4d00c0cebe181...
# 3812217  https://p.scdn.co/mp3-preview/ef262fe3c859100b...
# 3812218  https://p.scdn.co/mp3-preview/1c2604b381e6106c...
# 3812219  https://p.scdn.co/mp3-preview/a116270a4ab8e651...
# 3812220  https://p.scdn.co/mp3-preview/d0ba5c2742a26013...
#
#                      spotify_id  \
# 3812216  01BmduYsgEwoqkFpDo8tao
# 3812217  0FFmbqx2J0gzIIO3TTiATi
# 3812218  039Q3UlFQ6kavVIZHpO4mL
# 3812219  1EYwaLwf6fdS3NIlTbUZ3X
# 3812220  0Ev7atdl0qS2n39OO7051O
#
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'name', 'artist', 'spotify_preview_url', 'spotify_id',
#        'tags', 'genre', 'year', 'duration_ms', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'user_id',
#        'playcount', 'song_frequency_per_user', 'rating'],
#       dtype='object')

# %%
len(df), len(df["spotify_id"].unique())
# Out:
# (3812221, 28757)

# %%
df["spotify_id"].value_counts()
# Out:
# spotify_id
# 039Q3UlFQ6kavVIZHpO4mL    10995
# 1Urf1M52P3R6NYdAOJizoW     8937
# 0cs7BfenkAuxTVJv96KMme     7414
# 0CXHrBetrvDx4PwBar1ZWj     7304
# 0jLnevC3Vn34qVWrAa4X6x     7003
#                           ...
# 1ZQRxKu2P7CinQLcyJgrRG        1
# 1hmhbDdePE8opubIeIW3mU        1
# 5ioOfDbvTs5plon0hQZipF        1
# 0G9BZ87c2n2ZXk6KLVHHY3        1
# 0k5sE8ZwOHpaSAIOckeovo        1
# Name: count, Length: 28757, dtype: int64

# %%
df[df["spotify_id"] == "039Q3UlFQ6kavVIZHpO4mL"]
# Out:
#                    track_id     name         artist  \
# 577      TRONYHY128F92C9D11  Revelry  Kings of Leon
# 722      TRONYHY128F92C9D11  Revelry  Kings of Leon
# 986      TRONYHY128F92C9D11  Revelry  Kings of Leon
# 1324     TRONYHY128F92C9D11  Revelry  Kings of Leon
# 1905     TRONYHY128F92C9D11  Revelry  Kings of Leon
# ...                     ...      ...            ...
# 3811330  TRONYHY128F92C9D11  Revelry  Kings of Leon
# 3811709  TRONYHY128F92C9D11  Revelry  Kings of Leon
# 3811875  TRONYHY128F92C9D11  Revelry  Kings of Leon
# 3811920  TRONYHY128F92C9D11  Revelry  Kings of Leon
# 3812218  TRONYHY128F92C9D11  Revelry  Kings of Leon
#
#                                        spotify_preview_url  \
# 577      https://p.scdn.co/mp3-preview/1c2604b381e6106c...
# 722      https://p.scdn.co/mp3-preview/1c2604b381e6106c...
# 986      https://p.scdn.co/mp3-preview/1c2604b381e6106c...
# 1324     https://p.scdn.co/mp3-preview/1c2604b381e6106c...
# ...

# %%
triplets = pd.read_csv("../data/triplets_file.csv")
triplets
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# ...                                           ...                 ...
# 1999995  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJEYPO12AAA8C6B0E
# 1999996  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJJYDE12AF729FC16
# 1999997  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJKQSF12A6D4F5EE9
# 1999998  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJUXGA12AC961885C
# 1999999  d8bfd4ec88f0f3773a9e022e3c1a0f1d3b7b6a92  SOJYOLS12A8C13C06F
#
#          listen_count
# 0                   1
# 1                   2
# 2                   1
# 3                   1
# ...

# %%
triplets_users_id_len = [len(user_id) for user_id in triplets["user_id"]]
min(triplets_users_id_len), max(triplets_users_id_len)
# Out:
# (40, 40)

# %%
df_unique_users = df["user_id"].unique()
triplets_unique_users = triplets["user_id"].unique()
len(df_unique_users), len(triplets_unique_users)
# Out:
# (85333, 76353)

# %%
len(np.intersect1d(df_unique_users, triplets_unique_users))
# Out:
# 6517
